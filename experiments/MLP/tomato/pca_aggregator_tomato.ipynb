# %%
# Importing the necessary libraries
import pandas as pd
import numpy as np
import kennard_stone as ks
pd.options.plotting.backend = 'plotly'  # setting plotly as the backend for pandas plotting

# Add parent directory to sys.path so local module 'synthetic' can be imported
import sys
from pathlib import Path # for path manipulations
# Move three levels up from current working directory to reach workspace root
workspace_root = Path.cwd().parent.parent.parent.resolve() 
smx_dir = workspace_root / 'smx'  # Path to smx folder
if str(smx_dir) not in sys.path: # check to avoid duplicates
    sys.path.insert(0, str(smx_dir)) # insert at the start of sys.path to prioritize local modules

# Loading a soil spectral dataset based on X-ray fluorescence (XRF)
data_complete = pd.read_csv(f'{workspace_root}/real_datasets/xrf/tomato.csv', sep=';') # local copy of Toledo 2022 dataset (os ... indica para omitir o caminho longo)
data = data_complete.loc[:, '2.12':'23.08']

# Split dataset by class and create calibration/prediction sets using Kennard-Stone (as in original pipeline)
data_A = data_complete[data_complete['Class'] == 'A'].reset_index(drop=True)
data_B = data_complete[data_complete['Class'] == 'B'].reset_index(drop=True)

# splitting the data into calibration and prediction sets by kennard-stone algorithm
XA_cal, XA_pred = ks.train_test_split(data_A.loc[:, '2.12':'23.08'], test_size=0.30)  # class A
XA_cal = XA_cal.reset_index(drop=True)
XA_pred = XA_pred.reset_index(drop=True)

XB_cal, XB_pred = ks.train_test_split(data_B.loc[:, '2.12':'23.08'], test_size=0.30)  # class B
XB_cal = XB_cal.reset_index(drop=True)
XB_pred = XB_pred.reset_index(drop=True)

Xcalclass = pd.concat([XA_cal, XB_cal], axis=0).reset_index(drop=True)  # concatenating both classes
Xpredclass = pd.concat([XA_pred, XB_pred], axis=0).reset_index(drop=True)
ycalclass = pd.Series(['A']*XA_cal.shape[0] + ['B']*XB_cal.shape[0])  # target for calibration set
ypredclass = pd.Series(['A']*XA_pred.shape[0] + ['B']*XB_pred.shape[0])  # target for prediction set

# preprocessings
import preprocessings as prepr  # preprocessing methods for XRF data

Xcalclass_prep, mean_calclass, mean_calclass_poisson  = prepr.poisson(Xcalclass, mc=True)
Xpredclass_prep = ((Xpredclass/np.sqrt(mean_calclass)) - mean_calclass_poisson)
# Out:
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-02-27 09:58:31,796 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-02-27 09:58:31,800 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-02-27 09:58:31,819 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-02-27 09:58:31,823 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
from modeling import mlp_optimized

mlp_model = mlp_optimized(Xcalclass_prep, ycalclass, Xpredclass_prep, ypredclass, 
                          aim='classification', 
                          hidden_layer_sizes=(64,32),
                          activation='tanh',
                          learning_rate='adaptive',
                          max_iter=10,
                          random_state=1)
mlp_model[0]
# Out:
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (10) reached and the optimization hasn't converged yet.
#   warnings.warn(
#   Model  Accuracy Cal  Sensitivity Cal  Specificity Cal              CM Cal  \
# 0   MLP      0.777778         0.818182         0.714286  [[10, 4], [4, 18]]
#
#    Accuracy Pred  Sensitivity Pred  Specificity Pred           CM Pred
# 0          0.625               0.9          0.166667  [[1, 5], [1, 9]]

# %% [markdown]
# ## Definição das Zonas Espectrais

# %%
spectral_cuts = [
('S', 2.12, 2.4),
('Cl', 2.4, 3.04),
('K ka', 3.0, 3.44),
('K kb + Ca ka', 3.44, 3.84),
('background1', 3.84, 5.7),
('Mn', 5.7, 6.04),
('Fe', 6.04, 7.3),
('Cu', 7.3, 8.32),
('Zn', 8.32, 8.84),
('background2', 8.84, 11.56),
('Br ka', 11.56, 12.5),
('Rb ka + Br kb', 12.5, 13.8),
('background3', 13.8, 17.0),
('Rh ka Compton', 17.0, 19.9),
('Rh ka Rayleigh', 19.9, 20.8),
('Rh kb Compton', 20.8, 22.3),
('Rh kb Rayleigh', 22.3, 23.08)
]

# %% [markdown]
# ## SHAP

# %%
shap_global_importance = pd.read_csv('shap_tomato.csv', sep=';') # loading previously saved shap_unique_df
# vamos gerar uma nova coluna em shap_global_importance com o nome da zona espectral correspondente de acordo com a lista spectral_cuts
energy_to_zone_shap = {}
for zone_name, start, end in spectral_cuts:
    for i in shap_global_importance['energy']:
        i_float = float(i)
        if start <= i_float <= end:
            energy_to_zone_shap[i] = zone_name
shap_global_importance['Zone'] = shap_global_importance['energy'].map(energy_to_zone_shap)

# agora vamos filtrar shap_global_importance para manter apenas as zonas espectrais únicas com maior SHAP score
shap_unique_df = shap_global_importance.sort_values(by='Mean_Abs_SHAP', ascending=False).reset_index(drop=True)
shap_unique_df = shap_unique_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
shap_unique_df
# Out:
#     energy  Mean_Abs_SHAP              Zone
# 0     3.73       0.041364             Ca ka
# 1     4.54       0.028252             Ti ka
# 2     6.38       0.013990             Fe ka
# 3     8.09       0.007152             Cu ka
# 4     4.88       0.003056             Ti kb
# 5     7.04       0.002463             Fe kb
# 6    22.28       0.002394  Ag ka scattering
# 7     4.06       0.000760             Ca kb
# 8    19.40       0.000475       background3
# 9     9.33       0.000432             Zn kb
# 10    8.98       0.000338             Cu kb
# 11    5.92       0.000264       background1
# 12    8.49       0.000243             Zn ka
# 13    7.45       0.000235       background2
# 14    3.07       0.000207      Ar ka + Ag L
# 15    2.74       0.000131               NaN

# %% [markdown]
# ## Funções de Agregação por PCA
#
# Aqui implementamos as funções para agregar zonas espectrais usando PCA com 1 componente principal.

# %%
import explaining as exp

# Extração das zonas espectrais
spectral_zones_class = exp.extract_spectral_zones(Xcalclass_prep, spectral_cuts)
zone_scores_df, pca_info_dict = exp.aggregate_spectral_zones_pca(spectral_zones_class) # apca aggregation
print(f"\nScores DataFrame shape: {zone_scores_df.shape}")
# Out:
# Zone 'Ar ka + Ag L': VE = 5.85%, dim = 29 variables
# Zone 'Ca ka': VE = 98.41%, dim = 17 variables
# Zone 'Ca kb': VE = 90.24%, dim = 13 variables
# Zone 'Ti ka': VE = 96.36%, dim = 19 variables
# Zone 'Ti kb': VE = 80.62%, dim = 16 variables
# Zone 'background1': VE = 12.07%, dim = 39 variables
# Zone 'Fe ka': VE = 99.63%, dim = 25 variables
# Zone 'Fe kb': VE = 96.66%, dim = 22 variables
# Zone 'background2': VE = 8.40%, dim = 18 variables
# Zone 'Cu ka': VE = 97.03%, dim = 20 variables
# Zone 'Zn ka': VE = 20.69%, dim = 21 variables
# Zone 'Cu kb': VE = 63.49%, dim = 19 variables
# Zone 'Zn kb': VE = 5.72%, dim = 30 variables
# Zone 'background3': VE = 2.51%, dim = 451 variables
# Zone 'Ag ka scattering': VE = 27.73%, dim = 49 variables
#
# Scores DataFrame shape: (284, 15)

# %%
y_pred = mlp_model[4]['MLP'].values # using the continuous predictions from SVM, extracting as 1D array
predicates_quantiles = exp.predicates_by_quantiles(zone_scores_df, [0.2, 0.4, 0.6, 0.8])
predicate_info_dict = exp.create_predicate_info_dict(
    predicates_df=predicates_quantiles[0],
    predicate_indicator_df=predicates_quantiles[1],
    zone_aggregated_df=zone_scores_df,
    y_predicted_numeric=y_pred
)

# %%
import explaining as exp

# LISTA DE SEMENTES A TESTAR
random_seeds = [0, 1, 2, 3]

all_results_cov = {}
training_samples = len(Xcalclass)

# LOOP: PROCESSAR CADA SEMENTE

y_pred = pd.Series(mlp_model[4]['MLP'].values) # using the continuous predictions from SVM, extracting as 1D array

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando semente: {seed}")
    print(f"{'='*70}\n")
    # Bagging
    bags_result_seed = exp.bagging_predicates(
        zone_sums_df=zone_scores_df,
        y_predicted_numeric=y_pred,
        predicates_df=predicates_quantiles[0],
        n_bags=10,
        #n_predicates_per_bag=40,
        n_samples_per_bag=int(training_samples*0.8), # 80 % da base para amostrar (convertido para int)
        min_samples_per_predicate=int(training_samples*0.2), # 20 % da base para limitar (convertido para int)
        replace=False,
        sample_bagging=True,
        predicate_bagging=False,
        random_seed=seed
    )
    
    # Inserir classe prevista
    for bag_name, pred_dict in bags_result_seed.items(): # iterando sobre cada bag
        for pred_rule, df_info in pred_dict.items():
            df_info['Class_Predicted'] = np.where(df_info['Predicted_Y'] >= 0.5, 'A', 'B') # binarizando com threshold 0.5, A = eut, B = dist
    
    # Calcular MI
    cov_results_dict_seed = exp.calculate_predicate_metrics(
        bags_result=bags_result_seed,
        metric='covariance', # covariance ou mutual_information
        threshold=0.01, # threshold para cortar predicados irrelevantes
        n_neighbors=5
    )
    
    # Salvar no dicionário principal
    all_results_cov[seed] = {
        'bags_result': bags_result_seed,
        'cov_results_dict': cov_results_dict_seed
    }

# CONSTRUÇÃO DE GRAFOS PARA MÚLTIPLAS SEMENTES (LOOP EXTERNO)
# Dicionário para armazenar grafos
graphs_by_seed = {}

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando Grafo - Semente: {seed}")
    print(f"{'='*70}\n")
    
    # Construir grafo para esta semente (sem predicates_df - extraído da regra)
    DG = exp.build_predicate_graph(
        bags_result=all_results_cov[seed]['bags_result'],
        predicate_ranking_dict=all_results_cov[seed]['cov_results_dict'],
        metric_column='Covariance',
        random_state=seed,
        show_details=True,
        var_exp=True,
        pca_info_dict=pca_info_dict
    )
    # Armazenar grafo
    graphs_by_seed[seed] = DG

# Calcular LRC usando a função pronta do explaining.py
lrc_cov_by_seed = {}
for seed in random_seeds:
    DG = graphs_by_seed[seed]
    lrc_cov_df_seed = exp.calculate_lrc_single_graph(DG, predicates_quantiles[0])
    lrc_cov_df_seed['Seed'] = seed  # Adicionar coluna com a semente
    lrc_cov_by_seed[seed] = lrc_cov_df_seed

# junando todas as colunas 'Node' de lrc_by_seed em um único dataframe
lrc_cov_all_seeds_df = pd.DataFrame()
for seed in random_seeds:
    lrc_cov_df_seed = lrc_cov_by_seed[seed].rename(columns={'Node': f'Predicate_Cov_Seed_{seed}'})
    lrc_cov_all_seeds_df = pd.concat([lrc_cov_all_seeds_df, lrc_cov_df_seed[[f'Predicate_Cov_Seed_{seed}']]], axis=1)

# vamos filtrar lrc_by_seed em cada semente para manter apenas as zonas espectrais únicas com maior LRC em um mesmo dataframe
lrc_cov_unique_by_seed = {}
for seed, lrc_df in lrc_cov_by_seed.items():
    lrc_cov_unique_df = lrc_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
    lrc_cov_unique_df = lrc_cov_unique_df.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
    lrc_cov_unique_by_seed[seed] = lrc_cov_unique_df

lrc_cov_all_seeds_df # exibindo o dataframe consolidado com predicados de todas as sementes
# Out:
# ======================================================================
# Processando semente: 0
# ======================================================================
#
# Bag_1 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_2 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_3 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_4 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_5 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_6 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_7 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_8 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_9 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_10 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Computing Covariance for Predicates
# Metric: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando semente: 1
# ======================================================================
#
# Bag_1 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_2 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_3 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_4 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_5 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_6 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_7 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_8 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_9 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_10 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Computing Covariance for Predicates
# Metric: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando semente: 2
# ======================================================================
#
# Bag_1 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_2 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_3 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_4 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_5 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_6 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_7 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_8 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_9 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_10 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Computing Covariance for Predicates
# Metric: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando semente: 3
# ======================================================================
#
# Bag_1 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_2 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_3 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_4 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_5 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_6 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_7 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_8 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_9 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_10 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Computing Covariance for Predicates
# Metric: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando Grafo - Semente: 0
# ======================================================================
#
#
# Total bidirectional pairs found: 103
# Removed: Ca ka > -21.19 -> Ca ka > -26.11 (62.0257) | Kept: Ca ka > -26.11 -> Ca ka > -21.19 (63.6147)
# Removed: Ca ka > -6.65 -> Fe kb > -7.02 (9.3037) | Kept: Fe kb > -7.02 -> Ca ka > -6.65 (59.9828)
# Removed: Ti ka <= 19.85 -> Fe kb > -7.02 (8.0830) | Kept: Fe kb > -7.02 -> Ti ka <= 19.85 (28.0884)
# Removed: Ti ka <= 19.85 -> Ca ka > -6.65 (15.9971) | Kept: Ca ka > -6.65 -> Ti ka <= 19.85 (59.8550)
# Removed: Ti ka > -28.53 -> Fe kb > -7.41 (19.4972) | Kept: Fe kb > -7.41 -> Ti ka > -28.53 (21.0586)
# Removed: Ti ka <= 9.34 -> Fe kb > -7.41 (17.8996) | Kept: Fe kb > -7.41 -> Ti ka <= 9.34 (19.4735)
# Removed: Ti ka <= 9.34 -> Ti ka > -28.53 (12.6583) | Kept: Ti ka > -28.53 -> Ti ka <= 9.34 (38.9792)
# Removed: Ca kb > -8.59 -> Ca kb > -6.07 (7.9923) | Kept: Ca kb > -6.07 -> Ca kb > -8.59 (30.8124)
# Removed: Cu ka > -9.68 -> Cu ka > -10.68 (6.5758) | Kept: Cu ka > -10.68 -> Cu ka > -9.68 (29.1975)
# Removed: Ti kb <= 6.95 -> Ca kb > -2.67 (9.2100) | Kept: Ca kb > -2.67 -> Ti kb <= 6.95 (13.5502)
# Removed: Ca kb > -2.67 -> Cu ka > -8.43 (2.5096) | Kept: Cu ka > -8.43 -> Ca kb > -2.67 (12.6557)
# Removed: Ti kb <= 6.95 -> Cu ka > -8.43 (4.5170) | Kept: Cu ka > -8.43 -> Ti kb <= 6.95 (6.2391)
# Removed: Ca ka <= 33.38 -> Ti kb <= 6.95 (2.8206) | Kept: Ti kb <= 6.95 -> Ca ka <= 33.38 (4.5319)
# Removed: Ti kb > -10.26 -> Cu ka > -8.43 (2.1886) | Kept: Cu ka > -8.43 -> Ti kb > -10.26 (7.9488)
# Removed: Ti kb > -10.26 -> Ca ka <= 33.38 (2.0605) | Kept: Ca ka <= 33.38 -> Ti kb > -10.26 (10.3781)
# Removed: Ca ka <= 33.38 -> Ti kb <= 2.45 (4.7858) | Kept: Ti kb <= 2.45 -> Ca ka <= 33.38 (5.2005)
# Removed: Cu kb > -2.30 -> Ti ka <= -4.69 (0.7390) | Kept: Ti ka <= -4.69 -> Cu kb > -2.30 (4.9555)
# Removed: Cu kb > -2.30 -> Cu kb > -1.61 (0.6620) | Kept: Cu kb > -1.61 -> Cu kb > -2.30 (2.1236)
# Removed: Ag ka scattering <= 3.49 -> Cu kb > -2.88 (0.2719) | Kept: Cu kb > -2.88 -> Ag ka scattering <= 3.49 (1.7855)
# Removed: Ag ka scattering <= -0.18 -> Ag ka scattering <= 3.49 (0.2399) | Kept: Ag ka scattering <= 3.49 -> Ag ka scattering <= -0.18 (1.6011)
# Removed: Cu kb > -2.88 -> Cu kb > -1.61 (0.5842) | Kept: Cu kb > -1.61 -> Cu kb > -2.88 (0.6450)
# Removed: Cu kb > -2.88 -> Ag ka scattering <= 1.67 (0.5187) | Kept: Ag ka scattering <= 1.67 -> Cu kb > -2.88 (0.5232)
# Removed: Cu kb > -2.88 -> Ca kb <= 12.61 (1.1982) | Kept: Ca kb <= 12.61 -> Cu kb > -2.88 (1.6454)
# Removed: Ag ka scattering <= -0.18 -> Cu kb > -1.61 (0.7902) | Kept: Cu kb > -1.61 -> Ag ka scattering <= -0.18 (1.1623)
# Removed: Ag ka scattering <= 1.67 -> Ca ka <= -6.65 (0.6868) | Kept: Ca ka <= -6.65 -> Ag ka scattering <= 1.67 (2.3805)
# Removed: background3 <= 1.29 -> Ca kb <= 12.61 (0.0154) | Kept: Ca kb <= 12.61 -> background3 <= 1.29 (1.2415)
# Removed: background3 <= 2.86 -> background3 <= 1.29 (0.0138) | Kept: background3 <= 1.29 -> background3 <= 2.86 (0.0866)
# Removed: background3 <= -0.30 -> background3 <= 2.86 (0.0251) | Kept: background3 <= 2.86 -> background3 <= -0.30 (0.0844)
# Removed: background3 <= -0.30 -> Ag ka scattering > -1.65 (0.0476) | Kept: Ag ka scattering > -1.65 -> background3 <= -0.30 (0.1112)
# Removed: Ag ka scattering > -1.65 -> Ti kb <= -2.91 (0.3256) | Kept: Ti kb <= -2.91 -> Ag ka scattering > -1.65 (1.6179)
# Removed: Ag ka scattering > -0.18 -> Ti kb <= -2.91 (0.0953) | Kept: Ti kb <= -2.91 -> Ag ka scattering > -0.18 (0.8607)
# Removed: Ca kb <= -2.67 -> Ag ka scattering > -0.18 (0.2626) | Kept: Ag ka scattering > -0.18 -> Ca kb <= -2.67 (0.3425)
# Removed: Zn ka > -1.75 -> Ag ka scattering > -0.18 (0.0620) | Kept: Ag ka scattering > -0.18 -> Zn ka > -1.75 (0.2571)
# Removed: Zn ka > -1.75 -> Ca kb <= -2.67 (0.1707) | Kept: Ca kb <= -2.67 -> Zn ka > -1.75 (0.5385)
# Removed: Cu ka <= -3.28 -> Ca kb <= -2.67 (0.4748) | Kept: Ca kb <= -2.67 -> Cu ka <= -3.28 (0.7486)
# Removed: Zn ka > -1.75 -> Cu ka <= -3.28 (0.0529) | Kept: Cu ka <= -3.28 -> Zn ka > -1.75 (0.5272)
# Removed: background1 <= 2.08 -> Zn ka > -1.75 (0.0296) | Kept: Zn ka > -1.75 -> background1 <= 2.08 (0.0527)
# Removed: Ti ka > -4.69 -> Cu ka <= -3.28 (0.5133) | Kept: Cu ka <= -3.28 -> Ti ka > -4.69 (0.7699)
# Removed: Zn ka > -0.78 -> Cu ka <= -3.28 (0.1050) | Kept: Cu ka <= -3.28 -> Zn ka > -0.78 (0.4561)
# Removed: background1 <= 2.08 -> Ti ka > -4.69 (0.0502) | Kept: Ti ka > -4.69 -> background1 <= 2.08 (0.2558)
# Removed: Zn ka <= 1.38 -> background1 <= 2.08 (0.0474) | Kept: background1 <= 2.08 -> Zn ka <= 1.38 (0.0514)
# Removed: Zn ka <= 1.38 -> Ca ka <= -21.19 (0.1313) | Kept: Ca ka <= -21.19 -> Zn ka <= 1.38 (0.3904)
# Removed: Ag ka scattering > 1.67 -> Zn ka <= 1.38 (0.0579) | Kept: Zn ka <= 1.38 -> Ag ka scattering > 1.67 (0.0832)
# Removed: background1 <= 2.08 -> Zn ka > -0.78 (0.0251) | Kept: Zn ka > -0.78 -> background1 <= 2.08 (0.1354)
# Removed: background1 <= 2.08 -> Ag ka scattering > 1.67 (0.0256) | Kept: Ag ka scattering > 1.67 -> background1 <= 2.08 (0.0516)
# Removed: Zn ka > -0.78 -> Ca ka <= -21.19 (0.0424) | Kept: Ca ka <= -21.19 -> Zn ka > -0.78 (0.2105)
# Removed: Ag ka scattering > 1.67 -> Zn ka > -0.78 (0.0490) | Kept: Zn ka > -0.78 -> Ag ka scattering > 1.67 (0.1340)
# Removed: Ag ka scattering > 1.67 -> Ca ka <= -21.19 (0.0605) | Kept: Ca ka <= -21.19 -> Ag ka scattering > 1.67 (0.4021)
# Removed: background3 > -2.55 -> background1 <= -0.11 (0.0110) | Kept: background1 <= -0.11 -> background3 > -2.55 (0.0462)
# Removed: background3 > -2.55 -> Zn ka <= 0.08 (0.0090) | Kept: Zn ka <= 0.08 -> background3 > -2.55 (0.0251)
# Removed: background3 > -2.55 -> Cu ka <= -8.43 (0.0032) | Kept: Cu ka <= -8.43 -> background3 > -2.55 (0.1263)
# Removed: background1 <= -0.11 -> Zn ka <= 0.08 (0.0179) | Kept: Zn ka <= 0.08 -> background1 <= -0.11 (0.0235)
# Removed: background3 > 1.29 -> background1 <= -0.11 (0.0031) | Kept: background1 <= -0.11 -> background3 > 1.29 (0.0276)
# Removed: background1 <= -0.11 -> background1 > -0.11 (0.0151) | Kept: background1 > -0.11 -> background1 <= -0.11 (0.0159)
# Removed: background1 > -1.87 -> background1 <= -0.11 (0.0114) | Kept: background1 <= -0.11 -> background1 > -1.87 (0.0172)
# Removed: Zn ka <= 0.08 -> Ca kb <= -6.07 (0.0683) | Kept: Ca kb <= -6.07 -> Zn ka <= 0.08 (0.1101)
# Removed: background1 > -0.11 -> Zn ka <= 0.08 (0.0141) | Kept: Zn ka <= 0.08 -> background1 > -0.11 (0.0289)
# Removed: Ar ka + Ag L <= 0.28 -> Zn ka <= -0.78 (0.0126) | Kept: Zn ka <= -0.78 -> Ar ka + Ag L <= 0.28 (0.0387)
# Removed: Zn ka <= -0.78 -> Ca kb <= -6.07 (0.0241) | Kept: Ca kb <= -6.07 -> Zn ka <= -0.78 (0.0894)
# Removed: Ar ka + Ag L <= 0.28 -> Ar ka + Ag L <= 1.07 (0.0046) | Kept: Ar ka + Ag L <= 1.07 -> Ar ka + Ag L <= 0.28 (0.0129)
# Removed: Ca kb <= -6.07 -> Ti kb > -2.91 (0.1021) | Kept: Ti kb > -2.91 -> Ca kb <= -6.07 (0.1656)
# Removed: background1 > -1.87 -> Ca kb <= -6.07 (0.0092) | Kept: Ca kb <= -6.07 -> background1 > -1.87 (0.0956)
# Removed: background3 > 1.29 -> Ca kb <= -6.07 (0.0031) | Kept: Ca kb <= -6.07 -> background3 > 1.29 (0.0972)
# Removed: Ar ka + Ag L <= 1.07 -> background1 <= -1.03 (0.0053) | Kept: background1 <= -1.03 -> Ar ka + Ag L <= 1.07 (0.0120)
# Removed: background2 <= -0.37 -> Ar ka + Ag L <= 1.07 (0.0060) | Kept: Ar ka + Ag L <= 1.07 -> background2 <= -0.37 (0.0082)
# Removed: background1 <= -1.03 -> Cu ka <= -8.43 (0.0109) | Kept: Cu ka <= -8.43 -> background1 <= -1.03 (0.0913)
# Removed: background3 > 1.29 -> background1 <= -1.03 (0.0026) | Kept: background1 <= -1.03 -> background3 > 1.29 (0.0132)
# Removed: Ar ka + Ag L > -1.05 -> background1 <= -1.03 (0.0037) | Kept: background1 <= -1.03 -> Ar ka + Ag L > -1.05 (0.0093)
# Removed: background1 <= -1.03 -> Zn ka > 0.08 (0.0155) | Kept: Zn ka > 0.08 -> background1 <= -1.03 (0.0196)
# Removed: background2 <= -0.37 -> background1 <= -1.03 (0.0065) | Kept: background1 <= -1.03 -> background2 <= -0.37 (0.0103)
# Removed: Ar ka + Ag L <= -0.29 -> background1 > -0.11 (0.0042) | Kept: background1 > -0.11 -> Ar ka + Ag L <= -0.29 (0.0161)
# Removed: background3 > -0.30 -> Ar ka + Ag L <= -0.29 (0.0019) | Kept: Ar ka + Ag L <= -0.29 -> background3 > -0.30 (0.0045)
# Removed: Ar ka + Ag L > -1.05 -> background2 <= -0.37 (0.0038) | Kept: background2 <= -0.37 -> Ar ka + Ag L > -1.05 (0.0125)
# Removed: Zn kb > 0.29 -> background2 <= -0.37 (0.0032) | Kept: background2 <= -0.37 -> Zn kb > 0.29 (0.0055)
# Removed: background3 > -0.30 -> background2 <= -0.37 (0.0039) | Kept: background2 <= -0.37 -> background3 > -0.30 (0.0060)
# Removed: background3 > -0.30 -> Ar ka + Ag L > -1.05 (0.0018) | Kept: Ar ka + Ag L > -1.05 -> background3 > -0.30 (0.0038)
# Removed: Cu kb <= 0.18 -> Fe ka <= -23.71 (0.0348) | Kept: Fe ka <= -23.71 -> Cu kb <= 0.18 (0.0533)
# Removed: background2 > -0.92 -> Fe ka <= -23.71 (0.0047) | Kept: Fe ka <= -23.71 -> background2 > -0.92 (0.0320)
# Removed: background1 > -1.87 -> Cu kb <= 0.18 (0.0084) | Kept: Cu kb <= 0.18 -> background1 > -1.87 (0.0278)
# Removed: Cu kb <= 0.18 -> Fe ka <= -22.90 (0.0267) | Kept: Fe ka <= -22.90 -> Cu kb <= 0.18 (0.0407)
# Removed: Cu kb <= 0.18 -> Cu ka <= -9.68 (0.0440) | Kept: Cu ka <= -9.68 -> Cu kb <= 0.18 (0.0443)
# Removed: background1 > -1.87 -> Fe ka <= -22.90 (0.0052) | Kept: Fe ka <= -22.90 -> background1 > -1.87 (0.0507)
# Removed: Zn kb > -1.05 -> Fe ka <= -22.90 (0.0017) | Kept: Fe ka <= -22.90 -> Zn kb > -1.05 (0.0502)
# Removed: background2 <= 0.98 -> Fe ka <= -22.90 (0.0043) | Kept: Fe ka <= -22.90 -> background2 <= 0.98 (0.0280)
# Removed: Fe ka <= -22.90 -> Fe ka <= -24.15 (0.0358) | Kept: Fe ka <= -24.15 -> Fe ka <= -22.90 (0.0449)
# Removed: Fe ka <= -22.90 -> Cu ka <= -9.68 (0.0377) | Kept: Cu ka <= -9.68 -> Fe ka <= -22.90 (0.0403)
# Removed: Ar ka + Ag L > 0.28 -> Fe ka <= -22.90 (0.0014) | Kept: Fe ka <= -22.90 -> Ar ka + Ag L > 0.28 (0.0515)
# Removed: background2 > 0.27 -> Fe ka <= -24.15 (0.0035) | Kept: Fe ka <= -24.15 -> background2 > 0.27 (0.0326)
# Removed: background2 > 0.27 -> Fe kb <= -7.02 (0.0032) | Kept: Fe kb <= -7.02 -> background2 > 0.27 (0.0292)
# Removed: Ar ka + Ag L > 0.28 -> Zn kb <= -0.29 (0.0014) | Kept: Zn kb <= -0.29 -> Ar ka + Ag L > 0.28 (0.0020)
# Removed: Ar ka + Ag L > 0.28 -> background2 <= 0.98 (0.0020) | Kept: background2 <= 0.98 -> Ar ka + Ag L > 0.28 (0.0023)
# Removed: Ar ka + Ag L > 0.28 -> background2 > -0.37 (0.0015) | Kept: background2 > -0.37 -> Ar ka + Ag L > 0.28 (0.0026)
# Removed: Fe kb <= -7.02 -> Fe ka <= -24.15 (0.0347) | Kept: Fe ka <= -24.15 -> Fe kb <= -7.02 (0.0575)
# Removed: Fe kb <= -7.02 -> Fe kb <= -6.37 (0.0286) | Kept: Fe kb <= -6.37 -> Fe kb <= -7.02 (0.0382)
# Removed: background2 > -0.37 -> Cu kb <= -1.61 (0.0019) | Kept: Cu kb <= -1.61 -> background2 > -0.37 (0.0200)
# Removed: background2 > -0.92 -> Ti ka > 9.34 (0.0019) | Kept: Ti ka > 9.34 -> background2 > -0.92 (0.0202)
# Removed: Zn kb > -1.05 -> background2 > -0.92 (0.0006) | Kept: background2 > -0.92 -> Zn kb > -1.05 (0.0025)
# Removed: background2 > -0.92 -> Fe kb <= -6.37 (0.0017) | Kept: Fe kb <= -6.37 -> background2 > -0.92 (0.0284)
# Removed: Ti ka > 9.34 -> Fe kb <= -6.37 (0.0414) | Kept: Fe kb <= -6.37 -> Ti ka > 9.34 (0.0444)
# Removed: Cu kb <= -2.30 -> Fe kb <= -6.37 (0.0178) | Kept: Fe kb <= -6.37 -> Cu kb <= -2.30 (0.0243)
# Removed: Cu kb <= -2.30 -> Ti kb > 2.45 (0.0093) | Kept: Ti kb > 2.45 -> Cu kb <= -2.30 (0.0114)
# Removed: Ar ka + Ag L > -0.29 -> Fe kb <= -7.41 (0.0008) | Kept: Fe kb <= -7.41 -> Ar ka + Ag L > -0.29 (0.0126)
# Removed: Ti kb > 2.45 -> Fe kb <= -7.41 (0.0107) | Kept: Fe kb <= -7.41 -> Ti kb > 2.45 (0.0284)
#
# ======================================================================
# CONSTRUCTED GRAPH SUMMARY
# ======================================================================
# Initial edges: 526 | Removed: 103
# Predicate nodes: 90
# Metric: Covariance
# Weighting by explained variance: ENABLED
#
# ======================================================================
# Processando Grafo - Semente: 1
# ======================================================================
#
#
# Total bidirectional pairs found: 91
# Removed: Ca ka > -21.19 -> Ca ka > -26.11 (12.5875) | Kept: Ca ka > -26.11 -> Ca ka > -21.19 (114.4447)
# Removed: Ti ka <= 19.85 -> Fe kb > -7.02 (7.9467) | Kept: Fe kb > -7.02 -> Ti ka <= 19.85 (37.6257)
# Removed: Ti ka <= 19.85 -> Ca ka > -6.65 (32.0407) | Kept: Ca ka > -6.65 -> Ti ka <= 19.85 (50.0024)
# Removed: Ti ka > -28.53 -> Fe kb > -7.41 (12.9141) | Kept: Fe kb > -7.41 -> Ti ka > -28.53 (27.5015)
# Removed: Fe kb > -7.41 -> Ti ka <= 9.34 (6.2159) | Kept: Ti ka <= 9.34 -> Fe kb > -7.41 (24.3429)
# Removed: Ti ka <= 9.34 -> Ti ka > -28.53 (6.2746) | Kept: Ti ka > -28.53 -> Ti ka <= 9.34 (51.0169)
# Removed: Ca kb > -8.59 -> Fe kb > -7.79 (3.9793) | Kept: Fe kb > -7.79 -> Ca kb > -8.59 (20.4455)
# Removed: Ca kb > -8.59 -> Ca kb > -6.07 (15.5001) | Kept: Ca kb > -6.07 -> Ca kb > -8.59 (19.4292)
# Removed: Cu ka > -9.68 -> Cu ka > -10.68 (11.0363) | Kept: Cu ka > -10.68 -> Cu ka > -9.68 (25.1180)
# Removed: Ti kb <= 6.95 -> Ca kb > -2.67 (4.5217) | Kept: Ca kb > -2.67 -> Ti kb <= 6.95 (18.3668)
# Removed: Ti kb > -10.26 -> Ca kb > -2.67 (2.0482) | Kept: Ca kb > -2.67 -> Ti kb > -10.26 (4.9008)
# Removed: Ca ka <= 33.38 -> Ti kb <= 6.95 (5.9585) | Kept: Ti kb <= 6.95 -> Ca ka <= 33.38 (9.2002)
# Removed: Ti kb > -10.26 -> Ca ka <= 33.38 (6.2447) | Kept: Ca ka <= 33.38 -> Ti kb > -10.26 (10.2824)
# Removed: Cu kb > -2.30 -> Cu kb > -1.61 (1.4529) | Kept: Cu kb > -1.61 -> Cu kb > -2.30 (2.1525)
# Removed: Cu kb > -2.30 -> Ti ka <= -4.69 (0.6832) | Kept: Ti ka <= -4.69 -> Cu kb > -2.30 (2.4760)
# Removed: Cu kb > -1.61 -> Cu kb > -2.88 (0.6161) | Kept: Cu kb > -2.88 -> Cu kb > -1.61 (0.6329)
# Removed: Ag ka scattering <= -0.18 -> Cu kb > -1.61 (0.5417) | Kept: Cu kb > -1.61 -> Ag ka scattering <= -0.18 (1.3234)
# Removed: Cu kb > -1.61 -> Ti ka <= -4.69 (0.7051) | Kept: Ti ka <= -4.69 -> Cu kb > -1.61 (2.4401)
# Removed: Cu kb > -2.88 -> Ca kb <= 12.61 (0.5655) | Kept: Ca kb <= 12.61 -> Cu kb > -2.88 (1.7700)
# Removed: Ag ka scattering <= -0.18 -> Ca kb <= 12.61 (0.2523) | Kept: Ca kb <= 12.61 -> Ag ka scattering <= -0.18 (2.6429)
# Removed: Ag ka scattering <= 1.67 -> Ca kb <= 12.61 (0.4870) | Kept: Ca kb <= 12.61 -> Ag ka scattering <= 1.67 (0.8147)
# Removed: Ag ka scattering <= 3.49 -> Cu kb > -2.88 (0.5217) | Kept: Cu kb > -2.88 -> Ag ka scattering <= 3.49 (1.2117)
# Removed: Ag ka scattering <= 1.67 -> Cu kb > -2.88 (0.5008) | Kept: Cu kb > -2.88 -> Ag ka scattering <= 1.67 (1.7347)
# Removed: Ag ka scattering <= -0.18 -> Cu kb > -2.88 (0.2631) | Kept: Cu kb > -2.88 -> Ag ka scattering <= -0.18 (1.2014)
# Removed: Ag ka scattering <= -0.18 -> Ag ka scattering <= 3.49 (0.2651) | Kept: Ag ka scattering <= 3.49 -> Ag ka scattering <= -0.18 (0.5193)
# Removed: Ag ka scattering <= 1.67 -> Ti ka <= -4.69 (0.2327) | Kept: Ti ka <= -4.69 -> Ag ka scattering <= 1.67 (0.9405)
# Removed: background3 <= 2.86 -> background3 <= 1.29 (0.0306) | Kept: background3 <= 1.29 -> background3 <= 2.86 (0.0829)
# Removed: background3 <= -0.30 -> background3 <= 2.86 (0.0283) | Kept: background3 <= 2.86 -> background3 <= -0.30 (0.0780)
# Removed: Ti kb <= -2.91 -> Ag ka scattering > -1.65 (0.3192) | Kept: Ag ka scattering > -1.65 -> Ti kb <= -2.91 (0.8337)
# Removed: Zn ka > -1.75 -> Ag ka scattering > -0.18 (0.0612) | Kept: Ag ka scattering > -0.18 -> Zn ka > -1.75 (0.4405)
# Removed: Zn ka > -1.75 -> Cu ka <= -3.28 (0.1211) | Kept: Cu ka <= -3.28 -> Zn ka > -1.75 (0.4966)
# Removed: Zn ka > -1.75 -> Ca kb <= -2.67 (0.1680) | Kept: Ca kb <= -2.67 -> Zn ka > -1.75 (0.4928)
# Removed: Cu ka <= -3.28 -> Ti ka > -4.69 (0.2487) | Kept: Ti ka > -4.69 -> Cu ka <= -3.28 (0.2561)
# Removed: Cu ka <= -3.28 -> Ca kb <= -2.67 (0.2848) | Kept: Ca kb <= -2.67 -> Cu ka <= -3.28 (0.6730)
# Removed: Zn ka > -0.78 -> Cu ka <= -3.28 (0.0504) | Kept: Cu ka <= -3.28 -> Zn ka > -0.78 (0.4406)
# Removed: Ca kb <= -2.67 -> Ti ka > -4.69 (0.4843) | Kept: Ti ka > -4.69 -> Ca kb <= -2.67 (0.7453)
# Removed: Zn ka <= 1.38 -> Zn ka > -0.78 (0.1425) | Kept: Zn ka > -0.78 -> Zn ka <= 1.38 (0.2336)
# Removed: background1 <= 2.08 -> Zn ka <= 1.38 (0.0277) | Kept: Zn ka <= 1.38 -> background1 <= 2.08 (0.2218)
# Removed: Zn ka > -0.78 -> Ca ka <= -21.19 (0.0902) | Kept: Ca ka <= -21.19 -> Zn ka > -0.78 (0.1884)
# Removed: Ag ka scattering > 1.67 -> Ca ka <= -21.19 (0.1071) | Kept: Ca ka <= -21.19 -> Ag ka scattering > 1.67 (0.7469)
# Removed: background3 > -2.55 -> Ca ka <= -21.19 (0.0046) | Kept: Ca ka <= -21.19 -> background3 > -2.55 (0.1912)
# Removed: background1 <= 2.08 -> Ag ka scattering > 1.67 (0.0476) | Kept: Ag ka scattering > 1.67 -> background1 <= 2.08 (0.1526)
# Removed: background3 > -2.55 -> Ti kb > -2.91 (0.0028) | Kept: Ti kb > -2.91 -> background3 > -2.55 (0.2564)
# Removed: background3 > -2.55 -> Zn ka <= 0.08 (0.0072) | Kept: Zn ka <= 0.08 -> background3 > -2.55 (0.0297)
# Removed: background3 > -2.55 -> background1 > -1.87 (0.0034) | Kept: background1 > -1.87 -> background3 > -2.55 (0.0195)
# Removed: background3 > -2.55 -> Zn ka <= -0.78 (0.0033) | Kept: Zn ka <= -0.78 -> background3 > -2.55 (0.0181)
# Removed: background1 <= -0.11 -> Zn ka <= 0.08 (0.0533) | Kept: Zn ka <= 0.08 -> background1 <= -0.11 (0.0548)
# Removed: background3 > -0.30 -> Zn ka <= 0.08 (0.0023) | Kept: Zn ka <= 0.08 -> background3 > -0.30 (0.0236)
# Removed: Zn ka <= 0.08 -> Cu ka <= -8.43 (0.0399) | Kept: Cu ka <= -8.43 -> Zn ka <= 0.08 (0.2053)
# Removed: background3 > 1.29 -> background1 <= -0.11 (0.0061) | Kept: background1 <= -0.11 -> background3 > 1.29 (0.0134)
# Removed: Ar ka + Ag L > -1.05 -> Zn ka <= -0.78 (0.0052) | Kept: Zn ka <= -0.78 -> Ar ka + Ag L > -1.05 (0.0183)
# Removed: Ar ka + Ag L <= 1.07 -> Zn ka <= -0.78 (0.0059) | Kept: Zn ka <= -0.78 -> Ar ka + Ag L <= 1.07 (0.0603)
# Removed: background3 > 1.29 -> background1 > -1.87 (0.0027) | Kept: background1 > -1.87 -> background3 > 1.29 (0.0145)
# Removed: background1 <= -1.03 -> Ca kb <= -6.07 (0.0380) | Kept: Ca kb <= -6.07 -> background1 <= -1.03 (0.0818)
# Removed: Ar ka + Ag L > -1.05 -> background1 <= -1.03 (0.0040) | Kept: background1 <= -1.03 -> Ar ka + Ag L > -1.05 (0.0079)
# Removed: Ca kb <= -6.07 -> Cu ka <= -8.43 (0.0877) | Kept: Cu ka <= -8.43 -> Ca kb <= -6.07 (0.0905)
# Removed: background3 > -0.30 -> Ca kb <= -6.07 (0.0022) | Kept: Ca kb <= -6.07 -> background3 > -0.30 (0.0869)
# Removed: background1 > -1.03 -> Cu kb <= 0.18 (0.0054) | Kept: Cu kb <= 0.18 -> background1 > -1.03 (0.0388)
# Removed: background2 <= -0.37 -> Ar ka + Ag L > -1.05 (0.0070) | Kept: Ar ka + Ag L > -1.05 -> background2 <= -0.37 (0.0089)
# Removed: background2 <= -0.37 -> Fe ka <= -23.71 (0.0050) | Kept: Fe ka <= -23.71 -> background2 <= -0.37 (0.0513)
# Removed: background2 <= -0.37 -> Ar ka + Ag L <= 0.28 (0.0079) | Kept: Ar ka + Ag L <= 0.28 -> background2 <= -0.37 (0.0114)
# Removed: Zn kb > 0.29 -> Ar ka + Ag L > -1.05 (0.0039) | Kept: Ar ka + Ag L > -1.05 -> Zn kb > 0.29 (0.0046)
# Removed: Ar ka + Ag L > -1.05 -> Fe ka <= -22.90 (0.0029) | Kept: Fe ka <= -22.90 -> Ar ka + Ag L > -1.05 (0.0453)
# Removed: Zn kb > 0.29 -> Ar ka + Ag L <= -0.29 (0.0027) | Kept: Ar ka + Ag L <= -0.29 -> Zn kb > 0.29 (0.0119)
# Removed: Ar ka + Ag L <= 1.07 -> background1 > -0.11 (0.0050) | Kept: background1 > -0.11 -> Ar ka + Ag L <= 1.07 (0.0090)
# Removed: background1 > -0.11 -> Fe kb <= -7.02 (0.0041) | Kept: Fe kb <= -7.02 -> background1 > -0.11 (0.0269)
# Removed: Ar ka + Ag L <= 0.28 -> background1 > -0.11 (0.0050) | Kept: background1 > -0.11 -> Ar ka + Ag L <= 0.28 (0.0116)
# Removed: Ar ka + Ag L <= 0.28 -> Ar ka + Ag L <= 1.07 (0.0062) | Kept: Ar ka + Ag L <= 1.07 -> Ar ka + Ag L <= 0.28 (0.0134)
# Removed: background2 > -0.92 -> Cu ka <= -9.68 (0.0047) | Kept: Cu ka <= -9.68 -> background2 > -0.92 (0.0299)
# Removed: Zn ka > 0.08 -> Cu ka <= -9.68 (0.0097) | Kept: Cu ka <= -9.68 -> Zn ka > 0.08 (0.0595)
# Removed: Ar ka + Ag L <= -0.29 -> Fe ka <= -23.71 (0.0029) | Kept: Fe ka <= -23.71 -> Ar ka + Ag L <= -0.29 (0.0573)
# Removed: Zn ka > 0.08 -> Fe ka <= -23.71 (0.0099) | Kept: Fe ka <= -23.71 -> Zn ka > 0.08 (0.0571)
# Removed: background1 > -1.03 -> Fe ka <= -23.71 (0.0070) | Kept: Fe ka <= -23.71 -> background1 > -1.03 (0.0455)
# Removed: Zn kb > -0.29 -> Fe ka <= -24.15 (0.0022) | Kept: Fe ka <= -24.15 -> Zn kb > -0.29 (0.0368)
# Removed: background1 > -1.03 -> Fe ka <= -24.15 (0.0045) | Kept: Fe ka <= -24.15 -> background1 > -1.03 (0.0402)
# Removed: background2 > -0.92 -> Fe ka <= -24.15 (0.0036) | Kept: Fe ka <= -24.15 -> background2 > -0.92 (0.0350)
# Removed: background2 > 0.27 -> background2 <= 0.98 (0.0019) | Kept: background2 <= 0.98 -> background2 > 0.27 (0.0028)
# Removed: Zn kb > -0.29 -> Cu kb <= -2.30 (0.0020) | Kept: Cu kb <= -2.30 -> Zn kb > -0.29 (0.0246)
# Removed: Zn kb > -0.29 -> Fe kb <= -7.02 (0.0011) | Kept: Fe kb <= -7.02 -> Zn kb > -0.29 (0.0379)
# Removed: Zn kb > -0.29 -> Fe kb <= -6.37 (0.0031) | Kept: Fe kb <= -6.37 -> Zn kb > -0.29 (0.0237)
# Removed: Zn kb > -0.29 -> Ti ka > 9.34 (0.0014) | Kept: Ti ka > 9.34 -> Zn kb > -0.29 (0.0208)
# Removed: Zn kb > -1.05 -> Cu kb <= -1.61 (0.0041) | Kept: Cu kb <= -1.61 -> Zn kb > -1.05 (0.0146)
# Removed: Ar ka + Ag L > 0.28 -> Zn ka > 0.08 (0.0031) | Kept: Zn ka > 0.08 -> Ar ka + Ag L > 0.28 (0.0100)
# Removed: Ar ka + Ag L > -0.29 -> background2 > -0.92 (0.0026) | Kept: background2 > -0.92 -> Ar ka + Ag L > -0.29 (0.0039)
# Removed: Fe kb <= -6.37 -> Fe ka <= -22.90 (0.0194) | Kept: Fe ka <= -22.90 -> Fe kb <= -6.37 (0.0338)
# Removed: Ar ka + Ag L > 0.28 -> Cu kb <= -2.30 (0.0020) | Kept: Cu kb <= -2.30 -> Ar ka + Ag L > 0.28 (0.0168)
# Removed: background2 > -0.92 -> Cu kb <= -2.30 (0.0025) | Kept: Cu kb <= -2.30 -> background2 > -0.92 (0.0209)
# Removed: Cu kb <= -2.30 -> Fe kb <= -6.37 (0.0129) | Kept: Fe kb <= -6.37 -> Cu kb <= -2.30 (0.0354)
# Removed: Zn kb > -1.05 -> Zn kb <= 0.29 (0.0009) | Kept: Zn kb <= 0.29 -> Zn kb > -1.05 (0.0009)
# Removed: background2 <= 0.27 -> Fe kb <= -7.02 (0.0060) | Kept: Fe kb <= -7.02 -> background2 <= 0.27 (0.0280)
# Removed: background2 > -0.37 -> Ti ka > 9.34 (0.0018) | Kept: Ti ka > 9.34 -> background2 > -0.37 (0.0196)
#
# ======================================================================
# CONSTRUCTED GRAPH SUMMARY
# ======================================================================
# Initial edges: 495 | Removed: 91
# Predicate nodes: 90
# Metric: Covariance
# Weighting by explained variance: ENABLED
#
# ======================================================================
# Processando Grafo - Semente: 2
# ======================================================================
#
#
# Total bidirectional pairs found: 103
# Removed: Ca ka > -26.11 -> Ca ka > -21.19 (51.2364) | Kept: Ca ka > -21.19 -> Ca ka > -26.11 (74.6650)
# Removed: Ca ka > -6.65 -> Fe kb > -7.02 (8.7870) | Kept: Fe kb > -7.02 -> Ca ka > -6.65 (77.5102)
# Removed: Ti ka <= 19.85 -> Ca ka > -6.65 (7.9745) | Kept: Ca ka > -6.65 -> Ti ka <= 19.85 (69.3537)
# Removed: Ti ka > -28.53 -> Fe kb > -7.41 (11.8940) | Kept: Fe kb > -7.41 -> Ti ka > -28.53 (21.0501)
# Removed: Fe kb > -7.41 -> Ti ka <= 9.34 (13.6464) | Kept: Ti ka <= 9.34 -> Fe kb > -7.41 (17.8977)
# Removed: Ti ka <= 9.34 -> Ti ka > -28.53 (24.9523) | Kept: Ti ka > -28.53 -> Ti ka <= 9.34 (38.4885)
# Removed: Ca kb > -6.07 -> Fe kb > -7.79 (4.0081) | Kept: Fe kb > -7.79 -> Ca kb > -6.07 (36.1503)
# Removed: Ca kb > -8.59 -> Ca kb > -6.07 (7.8537) | Kept: Ca kb > -6.07 -> Ca kb > -8.59 (26.7721)
# Removed: Ti kb <= 6.95 -> Ca kb > -2.67 (6.8276) | Kept: Ca kb > -2.67 -> Ti kb <= 6.95 (13.7765)
# Removed: Ti kb <= 6.95 -> Cu ka > -8.43 (9.1380) | Kept: Cu ka > -8.43 -> Ti kb <= 6.95 (9.2182)
# Removed: Ca ka <= 33.38 -> Ti kb <= 6.95 (2.7715) | Kept: Ti kb <= 6.95 -> Ca ka <= 33.38 (4.5487)
# Removed: Ca ka <= 33.38 -> Cu ka > -8.43 (2.5343) | Kept: Cu ka > -8.43 -> Ca ka <= 33.38 (10.3695)
# Removed: Ti kb > -10.26 -> Ca ka <= 33.38 (5.9299) | Kept: Ca ka <= 33.38 -> Ti kb > -10.26 (12.9376)
# Removed: Cu kb > -2.30 -> Ti ka <= -4.69 (0.7095) | Kept: Ti ka <= -4.69 -> Cu kb > -2.30 (3.6921)
# Removed: Ag ka scattering <= 3.49 -> Ti ka <= -4.69 (0.2474) | Kept: Ti ka <= -4.69 -> Ag ka scattering <= 3.49 (0.8574)
# Removed: Cu kb > -1.61 -> Cu kb > -2.30 (0.7190) | Kept: Cu kb > -2.30 -> Cu kb > -1.61 (2.6372)
# Removed: Ag ka scattering <= 3.49 -> Cu kb > -2.30 (0.2625) | Kept: Cu kb > -2.30 -> Ag ka scattering <= 3.49 (1.9390)
# Removed: Ag ka scattering <= -0.18 -> Cu kb > -1.61 (0.2661) | Kept: Cu kb > -1.61 -> Ag ka scattering <= -0.18 (2.5693)
# Removed: Ag ka scattering <= 3.49 -> Cu kb > -1.61 (0.5197) | Kept: Cu kb > -1.61 -> Ag ka scattering <= 3.49 (1.2499)
# Removed: Ag ka scattering <= -0.18 -> Ca kb <= 12.61 (0.5145) | Kept: Ca kb <= 12.61 -> Ag ka scattering <= -0.18 (0.8709)
# Removed: Ag ka scattering <= -0.18 -> Cu kb > -2.88 (0.5312) | Kept: Cu kb > -2.88 -> Ag ka scattering <= -0.18 (1.1464)
# Removed: Ag ka scattering <= -0.18 -> Ag ka scattering <= 3.49 (0.2946) | Kept: Ag ka scattering <= 3.49 -> Ag ka scattering <= -0.18 (0.5077)
# Removed: Ag ka scattering <= 3.49 -> Ca kb <= 12.61 (0.2835) | Kept: Ca kb <= 12.61 -> Ag ka scattering <= 3.49 (0.8132)
# Removed: Ca kb <= 12.61 -> Ag ka scattering <= 1.67 (0.8648) | Kept: Ag ka scattering <= 1.67 -> Ca kb <= 12.61 (0.9481)
# Removed: Ag ka scattering <= 3.49 -> Cu kb > -2.88 (0.2423) | Kept: Cu kb > -2.88 -> Ag ka scattering <= 3.49 (1.1416)
# Removed: Ag ka scattering <= 1.67 -> Cu kb > -2.88 (0.5019) | Kept: Cu kb > -2.88 -> Ag ka scattering <= 1.67 (1.6713)
# Removed: background3 <= 1.29 -> background3 <= 2.86 (0.0577) | Kept: background3 <= 2.86 -> background3 <= 1.29 (0.0580)
# Removed: background3 <= -0.30 -> background3 <= 2.86 (0.0263) | Kept: background3 <= 2.86 -> background3 <= -0.30 (0.0414)
# Removed: background3 <= -0.30 -> Ti kb <= -2.91 (0.0748) | Kept: Ti kb <= -2.91 -> background3 <= -0.30 (0.7493)
# Removed: Ag ka scattering > -1.65 -> Ti kb <= -2.91 (0.1069) | Kept: Ti kb <= -2.91 -> Ag ka scattering > -1.65 (1.8264)
# Removed: Zn ka > -1.75 -> Ag ka scattering > -0.18 (0.0642) | Kept: Ag ka scattering > -0.18 -> Zn ka > -1.75 (0.2539)
# Removed: Zn ka > -0.78 -> Zn ka > -1.75 (0.0645) | Kept: Zn ka > -1.75 -> Zn ka > -0.78 (0.1341)
# Removed: Zn ka > -1.75 -> Cu ka <= -3.28 (0.2197) | Kept: Cu ka <= -3.28 -> Zn ka > -1.75 (0.2244)
# Removed: Zn ka > -1.75 -> Ti ka > -4.69 (0.1107) | Kept: Ti ka > -4.69 -> Zn ka > -1.75 (0.2600)
# Removed: Zn ka > -0.78 -> Zn ka <= 1.38 (0.0498) | Kept: Zn ka <= 1.38 -> Zn ka > -0.78 (0.1374)
# Removed: Cu ka <= -3.28 -> Ca kb <= -2.67 (0.2572) | Kept: Ca kb <= -2.67 -> Cu ka <= -3.28 (0.7010)
# Removed: Ca kb <= -2.67 -> Ti ka > -4.69 (0.2574) | Kept: Ti ka > -4.69 -> Ca kb <= -2.67 (0.4832)
# Removed: Cu ka <= -3.28 -> Ti ka > -4.69 (0.2508) | Kept: Ti ka > -4.69 -> Cu ka <= -3.28 (0.5100)
# Removed: Zn ka <= 1.38 -> Ca ka <= -21.19 (0.0923) | Kept: Ca ka <= -21.19 -> Zn ka <= 1.38 (0.3881)
# Removed: Zn ka <= 1.38 -> Ag ka scattering > 1.67 (0.0436) | Kept: Ag ka scattering > 1.67 -> Zn ka <= 1.38 (0.0580)
# Removed: Ag ka scattering > 1.67 -> Ca ka <= -21.19 (0.0927) | Kept: Ca ka <= -21.19 -> Ag ka scattering > 1.67 (0.3870)
# Removed: background1 <= 2.08 -> Ca ka <= -21.19 (0.0479) | Kept: Ca ka <= -21.19 -> background1 <= 2.08 (0.1768)
# Removed: background1 <= 2.08 -> Ag ka scattering > 1.67 (0.0246) | Kept: Ag ka scattering > 1.67 -> background1 <= 2.08 (0.1105)
# Removed: Ag ka scattering > 1.67 -> Ti ka > -4.69 (0.0449) | Kept: Ti ka > -4.69 -> Ag ka scattering > 1.67 (0.1597)
# Removed: background1 <= 2.08 -> Zn ka > 0.08 (0.0245) | Kept: Zn ka > 0.08 -> background1 <= 2.08 (0.0371)
# Removed: Zn kb > 0.29 -> Zn ka > 0.08 (0.0037) | Kept: Zn ka > 0.08 -> Zn kb > 0.29 (0.0150)
# Removed: background1 <= 2.08 -> Ti ka > -4.69 (0.0209) | Kept: Ti ka > -4.69 -> background1 <= 2.08 (0.2267)
# Removed: background3 > -2.55 -> background1 <= 2.08 (0.0053) | Kept: background1 <= 2.08 -> background3 > -2.55 (0.0223)
# Removed: background3 > -2.55 -> Ti ka > -4.69 (0.0044) | Kept: Ti ka > -4.69 -> background3 > -2.55 (0.1619)
# Removed: background3 > -2.55 -> Ti kb > -2.91 (0.0077) | Kept: Ti kb > -2.91 -> background3 > -2.55 (0.0898)
# Removed: background3 > -2.55 -> background1 <= -1.03 (0.0033) | Kept: background1 <= -1.03 -> background3 > -2.55 (0.0104)
# Removed: background3 > 1.29 -> Ti kb > -2.91 (0.0024) | Kept: Ti kb > -2.91 -> background3 > 1.29 (0.1292)
# Removed: background1 <= -0.11 -> Ti kb > -2.91 (0.0343) | Kept: Ti kb > -2.91 -> background1 <= -0.11 (0.1267)
# Removed: Ar ka + Ag L <= 0.28 -> Ti kb > -2.91 (0.0065) | Kept: Ti kb > -2.91 -> Ar ka + Ag L <= 0.28 (0.0767)
# Removed: background1 <= -0.11 -> Zn ka <= 0.08 (0.0117) | Kept: Zn ka <= 0.08 -> background1 <= -0.11 (0.0761)
# Removed: background3 > 1.29 -> Zn ka <= 0.08 (0.0031) | Kept: Zn ka <= 0.08 -> background3 > 1.29 (0.0232)
# Removed: background3 > 1.29 -> background1 <= -0.11 (0.0024) | Kept: background1 <= -0.11 -> background3 > 1.29 (0.0278)
# Removed: background1 > -0.11 -> background1 <= -0.11 (0.0172) | Kept: background1 <= -0.11 -> background1 > -0.11 (0.0305)
# Removed: background3 > 1.29 -> Zn ka <= -0.78 (0.0025) | Kept: Zn ka <= -0.78 -> background3 > 1.29 (0.0426)
# Removed: Zn ka <= -0.78 -> Cu ka <= -8.43 (0.0222) | Kept: Cu ka <= -8.43 -> Zn ka <= -0.78 (0.1811)
# Removed: Zn ka <= -0.78 -> Ca kb <= -6.07 (0.0229) | Kept: Ca kb <= -6.07 -> Zn ka <= -0.78 (0.0989)
# Removed: background1 > -0.11 -> Zn ka <= -0.78 (0.0088) | Kept: Zn ka <= -0.78 -> background1 > -0.11 (0.0177)
# Removed: Ar ka + Ag L <= 1.07 -> background1 > -0.11 (0.0036) | Kept: background1 > -0.11 -> Ar ka + Ag L <= 1.07 (0.0101)
# Removed: Ar ka + Ag L <= 1.07 -> Ca kb <= -6.07 (0.0048) | Kept: Ca kb <= -6.07 -> Ar ka + Ag L <= 1.07 (0.0874)
# Removed: Ar ka + Ag L > -1.05 -> Ar ka + Ag L <= 1.07 (0.0039) | Kept: Ar ka + Ag L <= 1.07 -> Ar ka + Ag L > -1.05 (0.0051)
# Removed: background3 > -0.30 -> Ar ka + Ag L <= 1.07 (0.0027) | Kept: Ar ka + Ag L <= 1.07 -> background3 > -0.30 (0.0048)
# Removed: background1 <= -1.03 -> Ca kb <= -6.07 (0.0357) | Kept: Ca kb <= -6.07 -> background1 <= -1.03 (0.0721)
# Removed: background1 <= -1.03 -> Cu ka <= -8.43 (0.0098) | Kept: Cu ka <= -8.43 -> background1 <= -1.03 (0.1800)
# Removed: Ar ka + Ag L <= 0.28 -> Ca kb <= -6.07 (0.0108) | Kept: Ca kb <= -6.07 -> Ar ka + Ag L <= 0.28 (0.0861)
# Removed: Ar ka + Ag L > -1.05 -> Ar ka + Ag L <= 0.28 (0.0046) | Kept: Ar ka + Ag L <= 0.28 -> Ar ka + Ag L > -1.05 (0.0135)
# Removed: Zn kb > 0.29 -> background3 > -0.30 (0.0038) | Kept: background3 > -0.30 -> Zn kb > 0.29 (0.0038)
# Removed: background3 > -0.30 -> background2 <= -0.37 (0.0020) | Kept: background2 <= -0.37 -> background3 > -0.30 (0.0070)
# Removed: Zn kb > 0.29 -> Cu ka <= -8.43 (0.0053) | Kept: Cu ka <= -8.43 -> Zn kb > 0.29 (0.0747)
# Removed: background2 <= -0.37 -> Cu ka <= -8.43 (0.0070) | Kept: Cu ka <= -8.43 -> background2 <= -0.37 (0.1426)
# Removed: Zn kb > 0.29 -> background2 <= -0.37 (0.0033) | Kept: background2 <= -0.37 -> Zn kb > 0.29 (0.0131)
# Removed: background1 > -0.11 -> Fe ka <= -22.90 (0.0073) | Kept: Fe ka <= -22.90 -> background1 > -0.11 (0.0433)
# Removed: Ar ka + Ag L > 0.28 -> Fe ka <= -23.71 (0.0033) | Kept: Fe ka <= -23.71 -> Ar ka + Ag L > 0.28 (0.0638)
# Removed: Fe ka <= -22.90 -> Fe ka <= -23.71 (0.0369) | Kept: Fe ka <= -23.71 -> Fe ka <= -22.90 (0.0477)
# Removed: background2 > -0.92 -> Fe ka <= -23.71 (0.0043) | Kept: Fe ka <= -23.71 -> background2 > -0.92 (0.1047)
# Removed: Ar ka + Ag L > 0.28 -> background2 <= -0.37 (0.0037) | Kept: background2 <= -0.37 -> Ar ka + Ag L > 0.28 (0.0048)
# Removed: Ar ka + Ag L > 0.28 -> Fe ka <= -24.15 (0.0033) | Kept: Fe ka <= -24.15 -> Ar ka + Ag L > 0.28 (0.0283)
# Removed: background2 <= -0.37 -> background1 > -1.87 (0.0059) | Kept: background1 > -1.87 -> background2 <= -0.37 (0.0102)
# Removed: Ar ka + Ag L > -0.29 -> Fe ka <= -24.15 (0.0041) | Kept: Fe ka <= -24.15 -> Ar ka + Ag L > -0.29 (0.0528)
# Removed: background2 <= 0.98 -> Fe ka <= -24.15 (0.0029) | Kept: Fe ka <= -24.15 -> background2 <= 0.98 (0.0364)
# Removed: background1 > -1.87 -> Fe ka <= -22.90 (0.0036) | Kept: Fe ka <= -22.90 -> background1 > -1.87 (0.0501)
# Removed: Fe ka <= -22.90 -> Fe kb <= -7.02 (0.0441) | Kept: Fe kb <= -7.02 -> Fe ka <= -22.90 (0.0832)
# Removed: Zn kb > -1.05 -> background1 > -1.87 (0.0018) | Kept: background1 > -1.87 -> Zn kb > -1.05 (0.0051)
# Removed: background1 > -1.87 -> Cu kb <= 0.18 (0.0083) | Kept: Cu kb <= 0.18 -> background1 > -1.87 (0.0353)
# Removed: Zn kb > -1.05 -> background2 > 0.27 (0.0021) | Kept: background2 > 0.27 -> Zn kb > -1.05 (0.0038)
# Removed: background2 <= 0.27 -> Zn kb > -1.05 (0.0012) | Kept: Zn kb > -1.05 -> background2 <= 0.27 (0.0017)
# Removed: Zn kb > -1.05 -> Cu ka <= -9.68 (0.0024) | Kept: Cu ka <= -9.68 -> Zn kb > -1.05 (0.0283)
# Removed: Zn kb <= -0.29 -> Cu ka <= -9.68 (0.0016) | Kept: Cu ka <= -9.68 -> Zn kb <= -0.29 (0.0416)
# Removed: background2 <= 0.98 -> Cu ka <= -9.68 (0.0027) | Kept: Cu ka <= -9.68 -> background2 <= 0.98 (0.0675)
# Removed: Ti ka > 9.34 -> Cu ka <= -9.68 (0.0226) | Kept: Cu ka <= -9.68 -> Ti ka > 9.34 (0.0244)
# Removed: Zn kb > -0.29 -> Cu ka <= -9.68 (0.0015) | Kept: Cu ka <= -9.68 -> Zn kb > -0.29 (0.0354)
# Removed: Cu kb <= -2.30 -> Ti kb > 2.45 (0.0108) | Kept: Ti kb > 2.45 -> Cu kb <= -2.30 (0.0189)
# Removed: Zn kb > -0.29 -> Fe kb <= -7.02 (0.0022) | Kept: Fe kb <= -7.02 -> Zn kb > -0.29 (0.0640)
# Removed: Zn kb <= 0.29 -> Fe kb <= -7.02 (0.0011) | Kept: Fe kb <= -7.02 -> Zn kb <= 0.29 (0.0194)
# Removed: background2 > -0.37 -> Fe kb <= -6.37 (0.0028) | Kept: Fe kb <= -6.37 -> background2 > -0.37 (0.0176)
# Removed: Ti ka > 9.34 -> Fe kb <= -6.37 (0.0196) | Kept: Fe kb <= -6.37 -> Ti ka > 9.34 (0.0258)
# Removed: background2 > -0.37 -> Ti ka > 9.34 (0.0015) | Kept: Ti ka > 9.34 -> background2 > -0.37 (0.0235)
# Removed: Zn kb <= 0.29 -> Ti ka > 9.34 (0.0017) | Kept: Ti ka > 9.34 -> Zn kb <= 0.29 (0.0369)
# Removed: background2 <= 0.27 -> Ti ka > 9.34 (0.0015) | Kept: Ti ka > 9.34 -> background2 <= 0.27 (0.0431)
#
# ======================================================================
# CONSTRUCTED GRAPH SUMMARY
# ======================================================================
# Initial edges: 522 | Removed: 103
# Predicate nodes: 90
# Metric: Covariance
# Weighting by explained variance: ENABLED
#
# ======================================================================
# Processando Grafo - Semente: 3
# ======================================================================
#
#
# Total bidirectional pairs found: 99
# Removed: Ca ka > -26.11 -> Ca ka > -21.19 (63.7886) | Kept: Ca ka > -21.19 -> Ca ka > -26.11 (63.9594)
# Removed: Ca ka > -6.65 -> Fe kb > -7.02 (17.4202) | Kept: Fe kb > -7.02 -> Ca ka > -6.65 (74.7063)
# Removed: Ti ka <= 9.34 -> Ti ka > -28.53 (12.1995) | Kept: Ti ka > -28.53 -> Ti ka <= 9.34 (38.0839)
# Removed: Fe kb > -7.41 -> Ti ka <= 9.34 (12.8327) | Kept: Ti ka <= 9.34 -> Fe kb > -7.41 (29.5730)
# Removed: Fe kb > -7.41 -> Ti ka > -28.53 (6.6794) | Kept: Ti ka > -28.53 -> Fe kb > -7.41 (25.2766)
# Removed: Ca kb > -8.59 -> Ca kb > -6.07 (7.7513) | Kept: Ca kb > -6.07 -> Ca kb > -8.59 (31.3147)
# Removed: Ca kb > -8.59 -> Fe kb > -7.79 (3.8463) | Kept: Fe kb > -7.79 -> Ca kb > -8.59 (10.6203)
# Removed: Cu ka > -9.68 -> Cu ka > -10.68 (10.3157) | Kept: Cu ka > -10.68 -> Cu ka > -9.68 (20.7644)
# Removed: Ca kb > -2.67 -> Cu ka > -9.68 (2.9207) | Kept: Cu ka > -9.68 -> Ca kb > -2.67 (12.1803)
# Removed: Ca kb > -2.67 -> Cu ka > -8.43 (5.6689) | Kept: Cu ka > -8.43 -> Ca kb > -2.67 (12.4869)
# Removed: Cu ka > -8.43 -> Ti kb <= 6.95 (5.6956) | Kept: Ti kb <= 6.95 -> Cu ka > -8.43 (6.8571)
# Removed: Ti kb > -10.26 -> Cu ka > -8.43 (2.0443) | Kept: Cu ka > -8.43 -> Ti kb > -10.26 (5.2476)
# Removed: Ca ka <= 33.38 -> Ti kb > -10.26 (7.7053) | Kept: Ti kb > -10.26 -> Ca ka <= 33.38 (9.9316)
# Removed: Ti kb <= 2.45 -> Ca ka <= 33.38 (1.7111) | Kept: Ca ka <= 33.38 -> Ti kb <= 2.45 (13.6217)
# Removed: Cu kb > -2.30 -> Ti ka <= -4.69 (0.6724) | Kept: Ti ka <= -4.69 -> Cu kb > -2.30 (2.4016)
# Removed: Ag ka scattering <= 3.49 -> Ti ka <= -4.69 (0.2852) | Kept: Ti ka <= -4.69 -> Ag ka scattering <= 3.49 (3.3004)
# Removed: Cu kb > -2.30 -> Ag ka scattering <= 3.49 (0.6115) | Kept: Ag ka scattering <= 3.49 -> Cu kb > -2.30 (0.8292)
# Removed: Cu kb > -2.30 -> Cu kb > -1.61 (1.2747) | Kept: Cu kb > -1.61 -> Cu kb > -2.30 (2.1117)
# Removed: Ag ka scattering <= 3.49 -> Cu kb > -1.61 (0.2661) | Kept: Cu kb > -1.61 -> Ag ka scattering <= 3.49 (0.6775)
# Removed: Ag ka scattering <= 3.49 -> Cu kb > -2.88 (0.2613) | Kept: Cu kb > -2.88 -> Ag ka scattering <= 3.49 (1.7887)
# Removed: Ag ka scattering <= 3.49 -> Ca kb <= 12.61 (0.2512) | Kept: Ca kb <= 12.61 -> Ag ka scattering <= 3.49 (0.8541)
# Removed: Ag ka scattering <= -0.18 -> Cu kb > -1.61 (0.2648) | Kept: Cu kb > -1.61 -> Ag ka scattering <= -0.18 (1.2644)
# Removed: Ag ka scattering <= 1.67 -> Cu kb > -1.61 (0.4702) | Kept: Cu kb > -1.61 -> Ag ka scattering <= 1.67 (0.6016)
# Removed: Ag ka scattering <= -0.18 -> Ca kb <= 12.61 (0.7712) | Kept: Ca kb <= 12.61 -> Ag ka scattering <= -0.18 (0.7959)
# Removed: Ag ka scattering <= 1.67 -> Ca ka <= -6.65 (0.6891) | Kept: Ca ka <= -6.65 -> Ag ka scattering <= 1.67 (0.8487)
# Removed: Ca kb <= 12.61 -> Ca ka <= -6.65 (0.7568) | Kept: Ca ka <= -6.65 -> Ca kb <= 12.61 (2.2744)
# Removed: Cu kb > -2.88 -> Ag ka scattering <= 1.67 (0.5803) | Kept: Ag ka scattering <= 1.67 -> Cu kb > -2.88 (0.7228)
# Removed: Ag ka scattering <= 1.67 -> Ca kb <= 12.61 (0.2333) | Kept: Ca kb <= 12.61 -> Ag ka scattering <= 1.67 (1.6236)
# Removed: Ca kb <= 12.61 -> Cu kb > -2.88 (0.6963) | Kept: Cu kb > -2.88 -> Ca kb <= 12.61 (1.0909)
# Removed: background3 <= 2.86 -> background3 <= 1.29 (0.0408) | Kept: background3 <= 1.29 -> background3 <= 2.86 (0.1035)
# Removed: background3 <= -0.30 -> Ti kb <= -2.91 (0.0591) | Kept: Ti kb <= -2.91 -> background3 <= -0.30 (0.3791)
# Removed: Ag ka scattering > -1.65 -> Ti kb <= -2.91 (0.3028) | Kept: Ti kb <= -2.91 -> Ag ka scattering > -1.65 (1.5265)
# Removed: Zn ka > -1.75 -> Cu ka <= -3.28 (0.0586) | Kept: Cu ka <= -3.28 -> Zn ka > -1.75 (0.5495)
# Removed: Zn ka > -1.75 -> Ag ka scattering > -0.18 (0.2448) | Kept: Ag ka scattering > -0.18 -> Zn ka > -1.75 (0.2493)
# Removed: Zn ka > -1.75 -> Ca kb <= -2.67 (0.1740) | Kept: Ca kb <= -2.67 -> Zn ka > -1.75 (0.2541)
# Removed: Zn ka > -0.78 -> Ag ka scattering > -0.18 (0.0611) | Kept: Ag ka scattering > -0.18 -> Zn ka > -0.78 (0.1480)
# Removed: Zn ka > -0.78 -> Ti ka > -4.69 (0.0558) | Kept: Ti ka > -4.69 -> Zn ka > -0.78 (0.2612)
# Removed: Zn ka <= 1.38 -> Zn ka > -0.78 (0.0451) | Kept: Zn ka > -0.78 -> Zn ka <= 1.38 (0.0986)
# Removed: Zn ka > -0.78 -> Cu ka <= -3.28 (0.0522) | Kept: Cu ka <= -3.28 -> Zn ka > -0.78 (0.4977)
# Removed: Cu ka <= -3.28 -> Ca kb <= -2.67 (0.2727) | Kept: Ca kb <= -2.67 -> Cu ka <= -3.28 (0.7588)
# Removed: Ca kb <= -2.67 -> Ti ka > -4.69 (0.4995) | Kept: Ti ka > -4.69 -> Ca kb <= -2.67 (0.5138)
# Removed: Ti ka > -4.69 -> Cu ka <= -3.28 (0.2507) | Kept: Cu ka <= -3.28 -> Ti ka > -4.69 (0.2607)
# Removed: Ag ka scattering > 1.67 -> Ti ka > -4.69 (0.0941) | Kept: Ti ka > -4.69 -> Ag ka scattering > 1.67 (0.2517)
# Removed: background1 > -1.87 -> Ti ka > -4.69 (0.0069) | Kept: Ti ka > -4.69 -> background1 > -1.87 (0.1486)
# Removed: background1 <= 2.08 -> Zn ka <= 1.38 (0.0760) | Kept: Zn ka <= 1.38 -> background1 <= 2.08 (0.0881)
# Removed: Ag ka scattering > 1.67 -> Zn ka <= 1.38 (0.0626) | Kept: Zn ka <= 1.38 -> Ag ka scattering > 1.67 (0.1673)
# Removed: background1 <= 2.08 -> Ca ka <= -21.19 (0.1279) | Kept: Ca ka <= -21.19 -> background1 <= 2.08 (0.4013)
# Removed: Ag ka scattering > 1.67 -> Ca ka <= -21.19 (0.1143) | Kept: Ca ka <= -21.19 -> Ag ka scattering > 1.67 (0.3923)
# Removed: background3 > -2.55 -> Ag ka scattering > 1.67 (0.0085) | Kept: Ag ka scattering > 1.67 -> background3 > -2.55 (0.0488)
# Removed: background3 > -2.55 -> Zn ka > 0.08 (0.0038) | Kept: Zn ka > 0.08 -> background3 > -2.55 (0.0327)
# Removed: background3 > 1.29 -> Zn ka > 0.08 (0.0040) | Kept: Zn ka > 0.08 -> background3 > 1.29 (0.0286)
# Removed: Ar ka + Ag L <= 1.07 -> Zn ka > 0.08 (0.0044) | Kept: Zn ka > 0.08 -> Ar ka + Ag L <= 1.07 (0.0153)
# Removed: background3 > -2.55 -> Ti kb > -2.91 (0.0041) | Kept: Ti kb > -2.91 -> background3 > -2.55 (0.1280)
# Removed: background1 <= -0.11 -> Zn ka <= 0.08 (0.0441) | Kept: Zn ka <= 0.08 -> background1 <= -0.11 (0.0499)
# Removed: background1 <= -0.11 -> Ti kb > -2.91 (0.0134) | Kept: Ti kb > -2.91 -> background1 <= -0.11 (0.2641)
# Removed: Zn ka <= 0.08 -> Ca kb <= -6.07 (0.0429) | Kept: Ca kb <= -6.07 -> Zn ka <= 0.08 (0.0994)
# Removed: background1 > -0.11 -> Zn ka <= 0.08 (0.0130) | Kept: Zn ka <= 0.08 -> background1 > -0.11 (0.0256)
# Removed: Zn ka <= 0.08 -> Ti kb > -2.91 (0.0222) | Kept: Ti kb > -2.91 -> Zn ka <= 0.08 (0.2227)
# Removed: background1 > -1.87 -> Zn ka <= -0.78 (0.0151) | Kept: Zn ka <= -0.78 -> background1 > -1.87 (0.0453)
# Removed: background1 <= -1.03 -> Zn ka <= -0.78 (0.0105) | Kept: Zn ka <= -0.78 -> background1 <= -1.03 (0.0180)
# Removed: Zn ka <= -0.78 -> Cu ka <= -8.43 (0.0449) | Kept: Cu ka <= -8.43 -> Zn ka <= -0.78 (0.0908)
# Removed: Zn ka <= -0.78 -> Ca kb <= -6.07 (0.0217) | Kept: Ca kb <= -6.07 -> Zn ka <= -0.78 (0.0860)
# Removed: Ar ka + Ag L <= -0.29 -> background1 > -1.87 (0.0026) | Kept: background1 > -1.87 -> Ar ka + Ag L <= -0.29 (0.0073)
# Removed: background3 > 1.29 -> Ar ka + Ag L <= 0.28 (0.0028) | Kept: Ar ka + Ag L <= 0.28 -> background3 > 1.29 (0.0106)
# Removed: Ar ka + Ag L <= 0.28 -> Cu ka <= -8.43 (0.0060) | Kept: Cu ka <= -8.43 -> Ar ka + Ag L <= 0.28 (0.2631)
# Removed: Ar ka + Ag L <= 0.28 -> background1 <= -1.03 (0.0053) | Kept: background1 <= -1.03 -> Ar ka + Ag L <= 0.28 (0.0122)
# Removed: Ar ka + Ag L <= 1.07 -> Cu ka <= -8.43 (0.0100) | Kept: Cu ka <= -8.43 -> Ar ka + Ag L <= 1.07 (0.0929)
# Removed: Ca kb <= -6.07 -> Cu ka <= -8.43 (0.0929) | Kept: Cu ka <= -8.43 -> Ca kb <= -6.07 (0.1131)
# Removed: Ar ka + Ag L > 0.28 -> Ar ka + Ag L <= 1.07 (0.0029) | Kept: Ar ka + Ag L <= 1.07 -> Ar ka + Ag L > 0.28 (0.0045)
# Removed: Ar ka + Ag L > -1.05 -> Ar ka + Ag L <= 1.07 (0.0044) | Kept: Ar ka + Ag L <= 1.07 -> Ar ka + Ag L > -1.05 (0.0045)
# Removed: background3 > -0.30 -> Cu kb <= 0.18 (0.0018) | Kept: Cu kb <= 0.18 -> background3 > -0.30 (0.0402)
# Removed: background1 <= -1.03 -> Ca kb <= -6.07 (0.0126) | Kept: Ca kb <= -6.07 -> background1 <= -1.03 (0.3539)
# Removed: background2 <= -0.37 -> background1 <= -1.03 (0.0053) | Kept: background1 <= -1.03 -> background2 <= -0.37 (0.0255)
# Removed: Zn kb > 0.29 -> Ar ka + Ag L <= -0.29 (0.0047) | Kept: Ar ka + Ag L <= -0.29 -> Zn kb > 0.29 (0.0047)
# Removed: Ar ka + Ag L <= -0.29 -> background2 > 0.27 (0.0035) | Kept: background2 > 0.27 -> Ar ka + Ag L <= -0.29 (0.0076)
# Removed: Zn kb > 0.29 -> background2 <= -0.37 (0.0042) | Kept: background2 <= -0.37 -> Zn kb > 0.29 (0.0047)
# Removed: Zn kb > 0.29 -> Cu kb <= 0.18 (0.0032) | Kept: Cu kb <= 0.18 -> Zn kb > 0.29 (0.0705)
# Removed: background2 <= -0.37 -> Fe ka <= -23.71 (0.0142) | Kept: Fe ka <= -23.71 -> background2 <= -0.37 (0.0617)
# Removed: Cu kb <= 0.18 -> Fe ka <= -23.71 (0.0350) | Kept: Fe ka <= -23.71 -> Cu kb <= 0.18 (0.1132)
# Removed: Fe ka <= -24.15 -> Cu ka <= -9.68 (0.0455) | Kept: Cu ka <= -9.68 -> Fe ka <= -24.15 (0.0842)
# Removed: Fe ka <= -22.90 -> Fe ka <= -24.15 (0.0351) | Kept: Fe ka <= -24.15 -> Fe ka <= -22.90 (0.0466)
# Removed: Fe kb <= -7.02 -> Fe ka <= -22.90 (0.0332) | Kept: Fe ka <= -22.90 -> Fe kb <= -7.02 (0.0457)
# Removed: Fe kb <= -6.37 -> Fe ka <= -22.90 (0.0411) | Kept: Fe ka <= -22.90 -> Fe kb <= -6.37 (0.0634)
# Removed: background2 <= 0.27 -> Fe ka <= -22.90 (0.0028) | Kept: Fe ka <= -22.90 -> background2 <= 0.27 (0.0317)
# Removed: background2 > -0.92 -> Fe kb <= -7.02 (0.0071) | Kept: Fe kb <= -7.02 -> background2 > -0.92 (0.0410)
# Removed: Ti ka > 9.34 -> Fe kb <= -7.02 (0.0219) | Kept: Fe kb <= -7.02 -> Ti ka > 9.34 (0.0440)
# Removed: Zn kb <= -0.29 -> Cu kb <= -2.30 (0.0018) | Kept: Cu kb <= -2.30 -> Zn kb <= -0.29 (0.0159)
# Removed: Zn kb > -0.29 -> Cu kb <= -2.30 (0.0017) | Kept: Cu kb <= -2.30 -> Zn kb > -0.29 (0.0180)
# Removed: Ti ka > 9.34 -> Fe kb <= -6.37 (0.0202) | Kept: Fe kb <= -6.37 -> Ti ka > 9.34 (0.0275)
# Removed: Zn kb > -0.29 -> background1 > -1.03 (0.0015) | Kept: background1 > -1.03 -> Zn kb > -0.29 (0.0019)
# Removed: Zn kb > -1.05 -> Zn kb > -0.29 (0.0021) | Kept: Zn kb > -0.29 -> Zn kb > -1.05 (0.0031)
# Removed: Zn kb <= 1.07 -> background1 > -1.03 (0.0011) | Kept: background1 > -1.03 -> Zn kb <= 1.07 (0.0046)
# Removed: Ar ka + Ag L > -0.29 -> Ti ka > 9.34 (0.0015) | Kept: Ti ka > 9.34 -> Ar ka + Ag L > -0.29 (0.0159)
# Removed: Zn kb > -1.05 -> Ti ka > 9.34 (0.0017) | Kept: Ti ka > 9.34 -> Zn kb > -1.05 (0.0224)
# Removed: Zn kb > -1.05 -> Ti kb > 2.45 (0.0008) | Kept: Ti kb > 2.45 -> Zn kb > -1.05 (0.0099)
# Removed: Zn kb <= 0.29 -> Ti kb > 2.45 (0.0019) | Kept: Ti kb > 2.45 -> Zn kb <= 0.29 (0.0109)
# Removed: background2 > -0.37 -> background2 > 0.27 (0.0009) | Kept: background2 > 0.27 -> background2 > -0.37 (0.0031)
# Removed: Ar ka + Ag L > -0.29 -> background2 > 0.27 (0.0009) | Kept: background2 > 0.27 -> Ar ka + Ag L > -0.29 (0.0059)
# Removed: Zn kb <= 0.29 -> background2 > 0.27 (0.0013) | Kept: background2 > 0.27 -> Zn kb <= 0.29 (0.0030)
#
# ======================================================================
# CONSTRUCTED GRAPH SUMMARY
# ======================================================================
# Initial edges: 506 | Removed: 99
# Predicate nodes: 90
# Metric: Covariance
# Weighting by explained variance: ENABLED
#
# Processing graph LRC...
#
# Processing graph LRC...
#
# Processing graph LRC...
#
# Processing graph LRC...
#    Predicate_Cov_Seed_0 Predicate_Cov_Seed_1 Predicate_Cov_Seed_2  \
# 0        Fe ka > -23.71       Fe ka > -23.71       Fe ka > -23.71
# 1        Fe ka > -24.15       Fe ka > -24.15       Fe ka > -24.15
# 2        Fe ka > -24.62       Fe ka > -24.62       Fe ka > -24.62
# 3        Ca ka > -26.11       Ca ka > -26.11       Ca ka > -26.11
# 4        Ca ka > -21.19       Ca ka > -21.19       Ca ka > -21.19
# ..                  ...                  ...                  ...
# 87        Zn kb <= 1.07        Zn kb <= 0.29  background2 > -0.37
# 88       Zn kb <= -0.29       Fe kb <= -7.41        Zn kb <= 0.29
# 89        Zn kb <= 0.29        Zn kb <= 1.07         Zn kb > 0.29
# 90              Class_A              Class_A              Class_A
# 91              Class_B              Class_B              Class_B
#
#    Predicate_Cov_Seed_3
# 0        Fe ka > -23.71
# 1        Fe ka > -24.15
# 2        Fe ka > -24.62
# 3        Ca ka > -21.19
# 4        Ca ka > -26.11
# ..                  ...
# 87       Fe kb <= -7.41
# 88        Zn kb > -1.05
# 89  background2 <= 0.27
# 90              Class_A
# 91              Class_B
#
# [92 rows x 4 columns]

# %%
# Somar LRCs de predicados equivalentes entre diferentes seeds
lrc_combined_list = []

for seed in random_seeds:
    lrc_df = lrc_cov_by_seed[seed].copy()
    lrc_combined_list.append(lrc_df) # o append adiciona o dataframe ao final da lista

# Concatenar todos os dataframes
lrc_all_seeds = pd.concat(lrc_combined_list, ignore_index=True) 

# Agrupar por predicado (Node) e somar as LRCs, mantendo Zone, Threshold e Operator
lrc_summed_df_cov = lrc_all_seeds.groupby('Node').agg({ # o .agg pode ser usado para aplicar múltiplas funções de agregação
    'Local_Reaching_Centrality': 'mean', # sum = somando as LRCs, poderia ser média ou outro agregado
    'Zone': 'first',
    'Threshold': 'first',
    'Operator': 'first'
}).reset_index()

# Ordenar pelo valor de LRC somado (maior para menor)
lrc_summed_df_cov = lrc_summed_df_cov.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
# vamoss pegar so os valore sunicos de lrc_summed_df baseado na zona espectral
lrc_summed_unique_df_cov = lrc_summed_df_cov.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
#lrc_summed_unique_df_cov = lrc_summed_unique_df_cov.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
lrc_summed_unique_df_cov
# Out:
#                         Node  Local_Reaching_Centrality              Zone  \
# 0             Fe ka > -23.71                  15.988192             Fe ka
# 1             Ca ka > -26.11                   6.489697             Ca ka
# 2              Fe kb > -7.02                   5.279888             Fe kb
# 3             Ti ka <= 19.85                   3.638187             Ti ka
# 4              Ca kb > -6.07                   2.314792             Ca kb
# 5             Cu ka > -10.68                   1.694605             Cu ka
# 6              Ti kb <= 6.95                   0.731985             Ti kb
# 7              Cu kb > -2.30                   0.177316             Cu kb
# 8   Ag ka scattering <= 3.49                   0.128208  Ag ka scattering
# 9       background3 <= -0.30                   0.045245       background3
# 10             Zn ka > -1.75                   0.028257             Zn ka
# 11       background1 <= 2.08                   0.019317       background1
# 12      background2 <= -0.37                   0.011678       background2
# 13              Zn kb > 0.29                   0.010995             Zn kb
# 14      Ar ka + Ag L <= 1.07                   0.010958      Ar ka + Ag L
# 15                   Class_A                   0.000000              None
#
#    Threshold Operator
# 0     -23.71        >
# 1     -26.11        >
# 2      -7.02        >
# 3      19.85       <=
# 4      -6.07        >
# 5     -10.68        >
# 6       6.95       <=
# 7      -2.30        >
# 8       3.49       <=
# 9      -0.30       <=
# 10     -1.75        >
# 11      2.08       <=
# 12     -0.37       <=
# 13      0.29        >
# 14      1.07       <=
# 15      None     None

# %%
# Criar zone_sums_df para dados NÃO pré-processados (Xcalclass)
spectral_zones_original = exp.extract_spectral_zones(Xcalclass, spectral_cuts)
zones_original = exp.aggregate_spectral_zones_pca(spectral_zones_original) # apca aggregation

# Aplicar o mapeamento
lrc_summed_df_cov_natural = exp.map_thresholds_to_natural(
    lrc_df=lrc_summed_df_cov,
    zone_sums_preprocessed=zone_scores_df,
    zone_sums_natural=zones_original[0]
)

lrc_summed_df_cov_natural
# Out:
# Zone 'Ar ka + Ag L': VE = 9.76%, dim = 29 variables
# Zone 'Ca ka': VE = 99.20%, dim = 17 variables
# Zone 'Ca kb': VE = 93.13%, dim = 13 variables
# Zone 'Ti ka': VE = 98.39%, dim = 19 variables
# Zone 'Ti kb': VE = 85.13%, dim = 16 variables
# Zone 'background1': VE = 12.27%, dim = 39 variables
# Zone 'Fe ka': VE = 99.86%, dim = 25 variables
# Zone 'Fe kb': VE = 97.91%, dim = 22 variables
# Zone 'background2': VE = 8.43%, dim = 18 variables
# Zone 'Cu ka': VE = 98.29%, dim = 20 variables
# Zone 'Zn ka': VE = 24.14%, dim = 21 variables
# Zone 'Cu kb': VE = 66.75%, dim = 19 variables
# Zone 'Zn kb': VE = 7.95%, dim = 30 variables
# Zone 'background3': VE = 2.98%, dim = 451 variables
# Zone 'Ag ka scattering': VE = 38.41%, dim = 49 variables
#                    Node  Local_Reaching_Centrality         Zone Threshold  \
# 0        Fe ka > -23.71                  15.988192        Fe ka    -23.71
# 1        Fe ka > -24.15                  11.434537        Fe ka    -24.15
# 2        Fe ka > -24.62                   8.060821        Fe ka    -24.62
# 3        Ca ka > -26.11                   6.489697        Ca ka    -26.11
# 4        Ca ka > -21.19                   6.180080        Ca ka    -21.19
# ..                  ...                        ...          ...       ...
# 87       Fe kb <= -7.41                   0.008405        Fe kb     -7.41
# 88  background2 <= 0.27                   0.008022  background2      0.27
# 89        Zn kb <= 1.07                   0.007872        Zn kb      1.07
# 90              Class_A                   0.000000         None      None
# 91              Class_B                   0.000000         None      None
#
#    Operator  Threshold_Natural  Reference_Sample_Index  Approximation_Error  \
# 0         >        -228.336686                    46.0             0.003068
# 1         >        -232.833909                   112.0             0.002150
# 2         >        -240.227437                    43.0             0.003827
# 3         >        -287.239935                   110.0             0.000994
# 4         >        -238.439137                   152.0             0.149595
# ..      ...                ...                     ...                  ...
# 87       <=         -32.289144                     4.0             0.001335
# 88       <=           0.811175                    47.0             0.000881
# 89       <=          -2.546607                   108.0             0.003444
# 90     None                NaN                     NaN                  NaN
# 91     None                NaN                     NaN                  NaN
#
#                Node_Natural
# 0       Fe ka > -228.336686
# 1       Fe ka > -232.833909
# 2       Fe ka > -240.227437
# 3       Ca ka > -287.239935
# 4       Ca ka > -238.439137
# ..                      ...
# 87      Fe kb <= -32.289144
# 88  background2 <= 0.811175
# 89       Zn kb <= -2.546607
# 90                     None
# 91                     None
#
# [92 rows x 9 columns]

# %% [markdown]
# ## Reconstrução de Thresholds Multivariados
#
# Agora vamos pegar os thresholds dos predicados mais importantes e reconstruí-los como espectros completos.

# %%
import plotly.graph_objects as go

n = 0
zone_name = lrc_summed_df_cov_natural.iloc[n]['Zone']
threshold_score = float(lrc_summed_df_cov_natural.iloc[n]['Threshold_Natural'])  # Corrigido: usa n em vez de 7

# Usar pca_info_dict dos dados ORIGINAIS (zones_original[1])
pca_info_dict_original = zones_original[1]

# Reconstrução: τ = mean + threshold * loadings (no espaço original)
threshold_spectrum = exp.reconstruct_threshold_to_spectrum(
    threshold_value=threshold_score,
    zone_name=zone_name,
    pca_info_dict=pca_info_dict_original
)
print(f"\nEspectro de threshold reconstruído para zona '{zone_name}':")
print(f"  - Dimensão: {len(threshold_spectrum)} variáveis espectrais")
print(f"  - Range de energias: {threshold_spectrum.index[0]} - {threshold_spectrum.index[-1]}")
print(f"  - Variância explicada pela PC1: {pca_info_dict_original[zone_name]['variance_explained']:.2%}")

# Usar dados ORIGINAIS para plotar (spectral_zones_original)
zone_df = spectral_zones_original[zone_name]

# Plotar zona com threshold (inline)
fig = go.Figure()
x_values = pd.to_numeric(zone_df.columns, errors='coerce')

# Plotar espectros das amostras coloridas por classe
colors = {'A': 'gold', 'B': 'blue'}
for idx, row in zone_df.iterrows():
    class_label = ycalclass.iloc[idx] if idx < len(ycalclass) else 'Unknown'
    fig.add_trace(go.Scatter(
        x=x_values,
        y=row.values,
        mode='lines',
        line=dict(color=colors.get(class_label, 'rgba(128,128,128,0.3)'), width=0.5),
        name=f'Class {class_label}',
        showlegend=False,
        hoverinfo='skip'
    ))

# Plotar espectro de threshold (destaque)
fig.add_trace(go.Scatter(
    x=x_values,
    y=threshold_spectrum.values,
    mode='lines',
    line=dict(color='red', width=4, dash='dash'),
    name=f'Threshold Spectrum ({threshold_spectrum.name})'
))

# Layout do gráfico
fig.update_layout(
    title=f"Zona '{zone_name}' com Threshold Multivariado (Predicado: {lrc_summed_df_cov_natural.iloc[n]['Node_Natural']})",
    xaxis_title='Energia / Comprimento de Onda',
    yaxis_title='Intensidade',
    template='plotly_white',
    showlegend=True,
    legend=dict(yanchor="top", y=0.99, xanchor="left", x=0.01)
)

fig.show()
# Out:
# Espectro de threshold reconstruído para zona 'Fe ka':
#   - Dimensão: 25 variáveis espectrais
#   - Range de energias: 6.15 - 6.76
#   - Variância explicada pela PC1: 99.86%

# %%
import explaining as exp

# LISTA DE SEMENTES A TESTAR
random_seeds = [0, 1, 2, 3]

all_results_pert = {}
training_samples = len(Xcalclass)

# LOOP: PROCESSAR CADA SEMENTE

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando semente: {seed}")
    print(f"{'='*70}\n")
    # Bagging
    bags_result_seed = exp.bagging_predicates(
        zone_sums_df=zone_scores_df,
        y_predicted_numeric=y_pred,
        predicates_df=predicates_quantiles[0],
        n_bags=10,
        #n_predicates_per_bag=40,
        n_samples_per_bag=int(training_samples*0.8), # 80 % da base para amostrar (convertido para int)
        min_samples_per_predicate=int(training_samples*0.2), # 20 % da base para limitar (convertido para int)
        replace=False,
        sample_bagging=True,
        predicate_bagging=False,
        random_seed=seed
    )
    # Inserir classe prevista
    for bag_name, pred_dict in bags_result_seed.items(): # iterando sobre cada bag
        for pred_rule, df_info in pred_dict.items():
            df_info['Class_Predicted'] = np.where(df_info['Predicted_Y'] >= 0.5, 'A', 'B') # binarizando com threshold 0.5, A = eut, B = dist

    pert_results_seed = exp.calculate_predicate_perturbation(
        estimator=mlp_model[3],
        Xcalclass_prep=Xcalclass_prep,
        folds_struct=bags_result_seed,
        predicates_df=predicates_quantiles[0],
        spectral_cuts=spectral_cuts,
        #perturbation_value=0,
        perturbation_mode='median', # valores entre 'mean' ou 'min'
        stats_source='full', # full indica usar todas as amostras para calcular estatísticas enquanto que 'fold' usa apenas as amostras do fold atual
        #metric='mean_abs_diff',   # Média com sinal (pode ser negativo)
        aim='classification',
        metric='probability_shift', 
        verbose=True
    )

    # Salvar no dicionário principal
    all_results_pert[seed] = {
        'bags_result': bags_result_seed,
        'pert_results_dict': pert_results_seed
    }

# CONSTRUÇÃO DE GRAFOS PARA MÚLTIPLAS SEMENTES (LOOP EXTERNO)
# Dicionário para armazenar grafos
graphs_pert_by_seed = {}

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando Grafo - Semente: {seed}")
    print(f"{'='*70}\n")
    
    # Construir grafo para esta semente (sem predicates_df - extraído da regra)
    DG = exp.build_predicate_graph(
        bags_result=all_results_pert[seed]['bags_result'],
        predicate_ranking_dict=all_results_pert[seed]['pert_results_dict'],
        metric_column='Perturbation',
        random_state=seed,
        show_details=True,
        var_exp=True,
        pca_info_dict=pca_info_dict
    )

    # Armazenar grafo
    graphs_pert_by_seed[seed] = DG  

# Calcular LRC usando a função pronta do explaining.py
lrc_pert_by_seed = {}
for seed in random_seeds:
    DG = graphs_pert_by_seed[seed]
    lrc_pert_df_seed = exp.calculate_lrc_single_graph(DG, predicates_quantiles[0])
    lrc_pert_df_seed['Seed'] = seed  # Adicionar coluna com a semente
    lrc_pert_by_seed[seed] = lrc_pert_df_seed

# junando todas as colunas 'Node' de lrc_by_seed em um único dataframe
lrc_pert_all_seeds_df = pd.DataFrame()
for seed in random_seeds:
    lrc_pert_df_seed = lrc_pert_by_seed[seed].rename(columns={'Node': f'Predicate_pert_Seed_{seed}'})
    lrc_pert_all_seeds_df = pd.concat([lrc_pert_all_seeds_df, lrc_pert_df_seed[[f'Predicate_pert_Seed_{seed}']]], axis=1)

# vamos filtrar lrc_by_seed em cada semente para manter apenas as zonas espectrais únicas com maior LRC em um mesmo dataframe
lrc_pert_unique_by_seed = {}
for seed, lrc_df in lrc_pert_by_seed.items():
    lrc_pert_unique_df = lrc_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
    lrc_pert_unique_df = lrc_pert_unique_df.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
    lrc_pert_unique_by_seed[seed] = lrc_pert_unique_df

lrc_pert_all_seeds_df # exibindo o dataframe consolidado com predicados de todas as sementes
# Out:
# ======================================================================
# Processando semente: 0
# ======================================================================
#
# Bag_1 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_2 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_3 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_4 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_5 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_6 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_7 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_8 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_9 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_10 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# ======================================================================
# PERTURBATION IMPORTANCE FOR PREDICATES
# ======================================================================
# Task type (aim): classification
# Perturbation mode: median
# Statistics source: full
# Metric: probability_shift
# Total folds: 10
#
#
# [Bag_1] Processing 90 predicates...
#   Predicate: Ar ka + Ag L > -1.05 (n=177)
#     Zone: 29 columns
#     Importance: 0.001439
#   Predicate: Ar ka + Ag L <= -0.29 (n=98)
#     Zone: 29 columns
#     Importance: 0.002036
#   Predicate: Ar ka + Ag L > -0.29 (n=129)
#     Zone: 29 columns
#     Importance: 0.001110
#   Predicate: Ar ka + Ag L <= 0.28 (n=138)
#     Zone: 29 columns
#     Importance: 0.001689
#   Predicate: Ar ka + Ag L > 0.28 (n=89)
#     Zone: 29 columns
#     Importance: 0.001232
#   Predicate: Ar ka + Ag L <= 1.07 (n=183)
#     Zone: 29 columns
#     Importance: 0.001636
#   Predicate: Ca ka > -26.11 (n=175)
#     Zone: 17 columns
#     Importance: 0.031840
#   Predicate: Ca ka <= -21.19 (n=94)
#     Zone: 17 columns
#     Importance: 0.016269
#   Predicate: Ca ka > -21.19 (n=133)
#     Zone: 17 columns
#     Importance: 0.040061
#   Predicate: Ca ka <= -6.65 (n=140)
#     Zone: 17 columns
#     Importance: 0.011086
#   Predicate: Ca ka > -6.65 (n=87)
#     Zone: 17 columns
#     Importance: 0.060982
#   Predicate: Ca ka <= 33.38 (n=183)
#     Zone: 17 columns
#     Importance: 0.009760
#   Predicate: Ca kb > -8.59 (n=174)
#     Zone: 13 columns
#     Importance: 0.000916
#   Predicate: Ca kb <= -6.07 (n=94)
#     Zone: 13 columns
#     Importance: 0.001921
#   Predicate: Ca kb > -6.07 (n=133)
#     Zone: 13 columns
#     Importance: 0.000830
#   Predicate: Ca kb <= -2.67 (n=140)
#     Zone: 13 columns
#     Importance: 0.001403
#   Predicate: Ca kb > -2.67 (n=87)
#     Zone: 13 columns
#     Importance: 0.001087
#   Predicate: Ca kb <= 12.61 (n=182)
#     Zone: 13 columns
#     Importance: 0.001232
#   Predicate: Ti ka > -28.53 (n=184)
#     Zone: 19 columns
#     Importance: 0.022458
#   Predicate: Ti ka <= -4.69 (n=91)
#     Zone: 19 columns
#     Importance: 0.060808
#   Predicate: Ti ka > -4.69 (n=136)
#     Zone: 19 columns
#     Importance: 0.005426
#   Predicate: Ti ka <= 9.34 (n=136)
#     Zone: 19 columns
#     Importance: 0.042351
#   Predicate: Ti ka > 9.34 (n=91)
#     Zone: 19 columns
#     Importance: 0.005623
#   Predicate: Ti ka <= 19.85 (n=181)
#     Zone: 19 columns
#     Importance: 0.032945
#   Predicate: Ti kb > -10.26 (n=182)
#     Zone: 16 columns
#     Importance: 0.003327
#   Predicate: Ti kb <= -2.91 (n=91)
#     Zone: 16 columns
#     Importance: 0.010883
#   Predicate: Ti kb > -2.91 (n=136)
#     Zone: 16 columns
#     Importance: 0.001435
#   Predicate: Ti kb <= 2.45 (n=138)
#     Zone: 16 columns
#     Importance: 0.007738
#   Predicate: Ti kb > 2.45 (n=89)
#     Zone: 16 columns
#     Importance: 0.001323
#   Predicate: Ti kb <= 6.95 (n=185)
#     Zone: 16 columns
#     Importance: 0.006072
#   Predicate: background1 > -1.87 (n=181)
#     Zone: 39 columns
#     Importance: 0.001004
#   Predicate: background1 <= -1.03 (n=91)
#     Zone: 39 columns
#     Importance: 0.003216
#   Predicate: background1 > -1.03 (n=136)
#     Zone: 39 columns
#     Importance: 0.000944
#   Predicate: background1 <= -0.11 (n=136)
#     Zone: 39 columns
#     Importance: 0.002438
#   Predicate: background1 > -0.11 (n=91)
#     Zone: 39 columns
#     Importance: 0.000984
#   Predicate: background1 <= 2.08 (n=183)
#     Zone: 39 columns
#     Importance: 0.002073
#   Predicate: Fe ka > -24.62 (n=183)
#     Zone: 25 columns
#     Importance: 0.001365
#   Predicate: Fe ka <= -24.15 (n=86)
#     Zone: 25 columns
#     Importance: 0.000870
#   Predicate: Fe ka > -24.15 (n=141)
#     Zone: 25 columns
#     Importance: 0.001616
#   Predicate: Fe ka <= -23.71 (n=136)
#     Zone: 25 columns
#     Importance: 0.000868
#   Predicate: Fe ka > -23.71 (n=91)
#     Zone: 25 columns
#     Importance: 0.002029
#   Predicate: Fe ka <= -22.90 (n=179)
#     Zone: 25 columns
#     Importance: 0.000808
#   Predicate: Fe kb > -7.79 (n=181)
#     Zone: 22 columns
#     Importance: 0.001462
#   Predicate: Fe kb <= -7.41 (n=91)
#     Zone: 22 columns
#     Importance: 0.000804
#   Predicate: Fe kb > -7.41 (n=136)
#     Zone: 22 columns
#     Importance: 0.001684
#   Predicate: Fe kb <= -7.02 (n=135)
#     Zone: 22 columns
#     Importance: 0.000940
#   Predicate: Fe kb > -7.02 (n=92)
#     Zone: 22 columns
#     Importance: 0.001905
#   Predicate: Fe kb <= -6.37 (n=181)
#     Zone: 22 columns
#     Importance: 0.000901
#   Predicate: background2 > -0.92 (n=177)
#     Zone: 18 columns
#     Importance: 0.000809
#   Predicate: background2 <= -0.37 (n=96)
#     Zone: 18 columns
#     Importance: 0.000667
#   Predicate: background2 > -0.37 (n=131)
#     Zone: 18 columns
#     Importance: 0.000928
#   Predicate: background2 <= 0.27 (n=142)
#     Zone: 18 columns
#     Importance: 0.000736
#   Predicate: background2 > 0.27 (n=85)
#     Zone: 18 columns
#     Importance: 0.000954
#   Predicate: background2 <= 0.98 (n=186)
#     Zone: 18 columns
#     Importance: 0.000808
#   Predicate: Cu ka > -10.68 (n=181)
#     Zone: 20 columns
#     Importance: 0.006378
#   Predicate: Cu ka <= -9.68 (n=93)
#     Zone: 20 columns
#     Importance: 0.002513
#   Predicate: Cu ka > -9.68 (n=134)
#     Zone: 20 columns
#     Importance: 0.008219
#   Predicate: Cu ka <= -8.43 (n=140)
#     Zone: 20 columns
#     Importance: 0.001955
#   Predicate: Cu ka > -8.43 (n=87)
#     Zone: 20 columns
#     Importance: 0.012199
#   Predicate: Cu ka <= -3.28 (n=182)
#     Zone: 20 columns
#     Importance: 0.001667
#   Predicate: Zn ka > -1.75 (n=181)
#     Zone: 21 columns
#     Importance: 0.001010
#   Predicate: Zn ka <= -0.78 (n=89)
#     Zone: 21 columns
#     Importance: 0.001380
#   Predicate: Zn ka > -0.78 (n=138)
#     Zone: 21 columns
#     Importance: 0.000907
#   Predicate: Zn ka <= 0.08 (n=138)
#     Zone: 21 columns
#     Importance: 0.001178
#   Predicate: Zn ka > 0.08 (n=89)
#     Zone: 21 columns
#     Importance: 0.000959
#   Predicate: Zn ka <= 1.38 (n=184)
#     Zone: 21 columns
#     Importance: 0.001168
#   Predicate: Cu kb > -2.88 (n=177)
#     Zone: 19 columns
#     Importance: 0.000747
#   Predicate: Cu kb <= -2.30 (n=92)
#     Zone: 19 columns
#     Importance: 0.001142
#   Predicate: Cu kb > -2.30 (n=135)
#     Zone: 19 columns
#     Importance: 0.000709
#   Predicate: Cu kb <= -1.61 (n=137)
#     Zone: 19 columns
#     Importance: 0.000954
#   Predicate: Cu kb > -1.61 (n=90)
#     Zone: 19 columns
#     Importance: 0.000779
#   Predicate: Cu kb <= 0.18 (n=180)
#     Zone: 19 columns
#     Importance: 0.000915
#   Predicate: Zn kb > -1.05 (n=182)
#     Zone: 30 columns
#     Importance: 0.001449
#   Predicate: Zn kb <= -0.29 (n=93)
#     Zone: 30 columns
#     Importance: 0.001706
#   Predicate: Zn kb > -0.29 (n=134)
#     Zone: 30 columns
#     Importance: 0.001220
#   Predicate: Zn kb <= 0.29 (n=142)
#     Zone: 30 columns
#     Importance: 0.001476
#   Predicate: Zn kb > 0.29 (n=85)
#     Zone: 30 columns
#     Importance: 0.001325
#   Predicate: Zn kb <= 1.07 (n=182)
#     Zone: 30 columns
#     Importance: 0.001322
#   Predicate: background3 > -2.55 (n=179)
#     Zone: 451 columns
#     Importance: 0.004685
#   Predicate: background3 <= -0.30 (n=95)
#     Zone: 451 columns
#     Importance: 0.027621
#   Predicate: background3 > -0.30 (n=132)
#     Zone: 451 columns
#     Importance: 0.002861
#   Predicate: background3 <= 1.29 (n=133)
#     Zone: 451 columns
#     Importance: 0.021069
#   Predicate: background3 > 1.29 (n=94)
#     Zone: 451 columns
#     Importance: 0.002122
#   Predicate: background3 <= 2.86 (n=184)
#     Zone: 451 columns
#     Importance: 0.015876
#   Predicate: Ag ka scattering > -1.65 (n=180)
#     Zone: 49 columns
#     Importance: 0.002292
#   Predicate: Ag ka scattering <= -0.18 (n=93)
#     Zone: 49 columns
#     Importance: 0.017216
#   Predicate: Ag ka scattering > -0.18 (n=134)
#     Zone: 49 columns
#     Importance: 0.002795
#   Predicate: Ag ka scattering <= 1.67 (n=133)
#     Zone: 49 columns
#     Importance: 0.012885
#   Predicate: Ag ka scattering > 1.67 (n=94)
#     Zone: 49 columns
#     Importance: 0.002787
#   Predicate: Ag ka scattering <= 3.49 (n=180)
#     Zone: 49 columns
#     Importance: 0.010037
#
# [Bag_2] Processing 90 predicates...
#   Predicate: Ar ka + Ag L > -1.05 (n=182)
#     Zone: 29 columns
#     Importance: 0.001079
#   Predicate: Ar ka + Ag L <= -0.29 (n=91)
#     Zone: 29 columns
#     Importance: 0.001523
#   Predicate: Ar ka + Ag L > -0.29 (n=136)
#     Zone: 29 columns
#     Importance: 0.001037
#   Predicate: Ar ka + Ag L <= 0.28 (n=137)
#     Zone: 29 columns
#     Importance: 0.001265
#   Predicate: Ar ka + Ag L > 0.28 (n=90)
#     Zone: 29 columns
#     Importance: 0.001182
#   Predicate: Ar ka + Ag L <= 1.07 (n=181)
#     Zone: 29 columns
#     Importance: 0.001306
#   Predicate: Ca ka > -26.11 (n=182)
#     Zone: 17 columns
#     Importance: 0.032924
#   Predicate: Ca ka <= -21.19 (n=93)
#     Zone: 17 columns
#     Importance: 0.015540
#   Predicate: Ca ka > -21.19 (n=134)
#     Zone: 17 columns
#     Importance: 0.042744
#   Predicate: Ca ka <= -6.65 (n=136)
#     Zone: 17 columns
#     Importance: 0.010822
#   Predicate: Ca ka > -6.65 (n=91)
#     Zone: 17 columns
#     Importance: 0.062651
#   Predicate: Ca ka <= 33.38 (n=179)
#     Zone: 17 columns
#     Importance: 0.009665
#   Predicate: Ca kb > -8.59 (n=183)
#     Zone: 13 columns
#     Importance: 0.000863
#   Predicate: Ca kb <= -6.07 (n=93)
#     Zone: 13 columns
#     Importance: 0.001650
#   Predicate: Ca kb > -6.07 (n=134)
#     Zone: 13 columns
#     Importance: 0.000902
#   Predicate: Ca kb <= -2.67 (n=137)
#     Zone: 13 columns
#     Importance: 0.001239
#   Predicate: Ca kb > -2.67 (n=90)
#     Zone: 13 columns
#     Importance: 0.001161
#   Predicate: Ca kb <= 12.61 (n=179)
#     Zone: 13 columns
#     Importance: 0.001141
#   Predicate: Ti ka > -28.53 (n=178)
#     Zone: 19 columns
#     Importance: 0.021356
#   Predicate: Ti ka <= -4.69 (n=94)
#     Zone: 19 columns
#     Importance: 0.051522
#   Predicate: Ti ka > -4.69 (n=133)
#     Zone: 19 columns
#     Importance: 0.005114
#   Predicate: Ti ka <= 9.34 (n=134)
#     Zone: 19 columns
#     Importance: 0.037346
#   Predicate: Ti ka > 9.34 (n=93)
#     Zone: 19 columns
#     Importance: 0.005578
#   Predicate: Ti ka <= 19.85 (n=178)
#     Zone: 19 columns
#     Importance: 0.029107
#   Predicate: Ti kb > -10.26 (n=182)
#     Zone: 16 columns
#     Importance: 0.003195
#   Predicate: Ti kb <= -2.91 (n=94)
#     Zone: 16 columns
#     Importance: 0.009640
#   Predicate: Ti kb > -2.91 (n=133)
#     Zone: 16 columns
#     Importance: 0.001419
#   Predicate: Ti kb <= 2.45 (n=131)
#     Zone: 16 columns
#     Importance: 0.007408
#   Predicate: Ti kb > 2.45 (n=96)
#     Zone: 16 columns
#     Importance: 0.001296
#   Predicate: Ti kb <= 6.95 (n=179)
#     Zone: 16 columns
#     Importance: 0.005693
#   Predicate: background1 > -1.87 (n=185)
#     Zone: 39 columns
#     Importance: 0.001003
#   Predicate: background1 <= -1.03 (n=88)
#     Zone: 39 columns
#     Importance: 0.002654
#   Predicate: background1 > -1.03 (n=139)
#     Zone: 39 columns
#     Importance: 0.000955
#   Predicate: background1 <= -0.11 (n=132)
#     Zone: 39 columns
#     Importance: 0.002073
#   Predicate: background1 > -0.11 (n=95)
#     Zone: 39 columns
#     Importance: 0.000975
#   Predicate: background1 <= 2.08 (n=179)
#     Zone: 39 columns
#     Importance: 0.001865
#   Predicate: Fe ka > -24.62 (n=180)
#     Zone: 25 columns
#     Importance: 0.001253
#   Predicate: Fe ka <= -24.15 (n=91)
#     Zone: 25 columns
#     Importance: 0.000841
#   Predicate: Fe ka > -24.15 (n=136)
#     Zone: 25 columns
#     Importance: 0.001514
#   Predicate: Fe ka <= -23.71 (n=140)
#     Zone: 25 columns
#     Importance: 0.000851
#   Predicate: Fe ka > -23.71 (n=87)
#     Zone: 25 columns
#     Importance: 0.001877
#   Predicate: Fe ka <= -22.90 (n=183)
#     Zone: 25 columns
#     Importance: 0.000791
#   Predicate: Fe kb > -7.79 (n=178)
#     Zone: 22 columns
#     Importance: 0.001425
#   Predicate: Fe kb <= -7.41 (n=89)
#     Zone: 22 columns
#     Importance: 0.000817
#   Predicate: Fe kb > -7.41 (n=138)
#     Zone: 22 columns
#     Importance: 0.001623
#   Predicate: Fe kb <= -7.02 (n=136)
#     Zone: 22 columns
#     Importance: 0.000917
#   Predicate: Fe kb > -7.02 (n=91)
#     Zone: 22 columns
#     Importance: 0.001888
#   Predicate: Fe kb <= -6.37 (n=183)
#     Zone: 22 columns
#     Importance: 0.000892
#   Predicate: background2 > -0.92 (n=184)
#     Zone: 18 columns
#     Importance: 0.000750
#   Predicate: background2 <= -0.37 (n=86)
#     Zone: 18 columns
#     Importance: 0.000630
#   Predicate: background2 > -0.37 (n=141)
#     Zone: 18 columns
#     Importance: 0.000870
#   Predicate: background2 <= 0.27 (n=131)
#     Zone: 18 columns
#     Importance: 0.000695
#   Predicate: background2 > 0.27 (n=96)
#     Zone: 18 columns
#     Importance: 0.000893
#   Predicate: background2 <= 0.98 (n=184)
#     Zone: 18 columns
#     Importance: 0.000765
#   Predicate: Cu ka > -10.68 (n=180)
#     Zone: 20 columns
#     Importance: 0.004675
#   Predicate: Cu ka <= -9.68 (n=93)
#     Zone: 20 columns
#     Importance: 0.002178
#   Predicate: Cu ka > -9.68 (n=134)
#     Zone: 20 columns
#     Importance: 0.005907
#   Predicate: Cu ka <= -8.43 (n=139)
#     Zone: 20 columns
#     Importance: 0.001741
#   Predicate: Cu ka > -8.43 (n=88)
#     Zone: 20 columns
#     Importance: 0.008547
#   Predicate: Cu ka <= -3.28 (n=186)
#     Zone: 20 columns
#     Importance: 0.001547
#   Predicate: Zn ka > -1.75 (n=179)
#     Zone: 21 columns
#     Importance: 0.000954
#   Predicate: Zn ka <= -0.78 (n=95)
#     Zone: 21 columns
#     Importance: 0.001063
#   Predicate: Zn ka > -0.78 (n=132)
#     Zone: 21 columns
#     Importance: 0.000854
#   Predicate: Zn ka <= 0.08 (n=142)
#     Zone: 21 columns
#     Importance: 0.000977
#   Predicate: Zn ka > 0.08 (n=85)
#     Zone: 21 columns
#     Importance: 0.000882
#   Predicate: Zn ka <= 1.38 (n=186)
#     Zone: 21 columns
#     Importance: 0.001016
#   Predicate: Cu kb > -2.88 (n=178)
#     Zone: 19 columns
#     Importance: 0.000632
#   Predicate: Cu kb <= -2.30 (n=89)
#     Zone: 19 columns
#     Importance: 0.001078
#   Predicate: Cu kb > -2.30 (n=138)
#     Zone: 19 columns
#     Importance: 0.000626
#   Predicate: Cu kb <= -1.61 (n=139)
#     Zone: 19 columns
#     Importance: 0.000886
#   Predicate: Cu kb > -1.61 (n=88)
#     Zone: 19 columns
#     Importance: 0.000673
#   Predicate: Cu kb <= 0.18 (n=184)
#     Zone: 19 columns
#     Importance: 0.000830
#   Predicate: Zn kb > -1.05 (n=183)
#     Zone: 30 columns
#     Importance: 0.001294
#   Predicate: Zn kb <= -0.29 (n=94)
#     Zone: 30 columns
#     Importance: 0.001850
#   Predicate: Zn kb > -0.29 (n=133)
#     Zone: 30 columns
#     Importance: 0.000809
#   Predicate: Zn kb <= 0.29 (n=144)
#     Zone: 30 columns
#     Importance: 0.001507
#   Predicate: Zn kb > 0.29 (n=83)
#     Zone: 30 columns
#     Importance: 0.000776
#   Predicate: Zn kb <= 1.07 (n=189)
#     Zone: 30 columns
#     Importance: 0.001322
#   Predicate: background3 > -2.55 (n=180)
#     Zone: 451 columns
#     Importance: 0.004469
#   Predicate: background3 <= -0.30 (n=92)
#     Zone: 451 columns
#     Importance: 0.018407
#   Predicate: background3 > -0.30 (n=135)
#     Zone: 451 columns
#     Importance: 0.003056
#   Predicate: background3 <= 1.29 (n=140)
#     Zone: 451 columns
#     Importance: 0.013650
#   Predicate: background3 > 1.29 (n=87)
#     Zone: 451 columns
#     Importance: 0.002242
#   Predicate: background3 <= 2.86 (n=184)
#     Zone: 451 columns
#     Importance: 0.010971
#   Predicate: Ag ka scattering > -1.65 (n=180)
#     Zone: 49 columns
#     Importance: 0.001993
#   Predicate: Ag ka scattering <= -0.18 (n=92)
#     Zone: 49 columns
#     Importance: 0.015779
#   Predicate: Ag ka scattering > -0.18 (n=135)
#     Zone: 49 columns
#     Importance: 0.002366
#   Predicate: Ag ka scattering <= 1.67 (n=135)
#     Zone: 49 columns
#     Importance: 0.011079
#   Predicate: Ag ka scattering > 1.67 (n=92)
#     Zone: 49 columns
#     Importance: 0.002994
#   Predicate: Ag ka scattering <= 3.49 (n=180)
#     Zone: 49 columns
#     Importance: 0.008830
#
# [Bag_3] Processing 90 predicates...
#   Predicate: Ar ka + Ag L > -1.05 (n=181)
#     Zone: 29 columns
#     Importance: 0.001423
#   Predicate: Ar ka + Ag L <= -0.29 (n=89)
#     Zone: 29 columns
#     Importance: 0.001945
#   Predicate: Ar ka + Ag L > -0.29 (n=138)
#     Zone: 29 columns
#     Importance: 0.001079
#   Predicate: Ar ka + Ag L <= 0.28 (n=136)
#     Zone: 29 columns
#     Importance: 0.001587
#   Predicate: Ar ka + Ag L > 0.28 (n=91)
#     Zone: 29 columns
#     Importance: 0.001168
#   Predicate: Ar ka + Ag L <= 1.07 (n=180)
#     Zone: 29 columns
#     Importance: 0.001546
#   Predicate: Ca ka > -26.11 (n=183)
#     Zone: 17 columns
#     Importance: 0.029189
#   Predicate: Ca ka <= -21.19 (n=90)
#     Zone: 17 columns
#     Importance: 0.016731
#   Predicate: Ca ka > -21.19 (n=137)
#     Zone: 17 columns
#     Importance: 0.036852
#   Predicate: Ca ka <= -6.65 (n=135)
#     Zone: 17 columns
#     Importance: 0.011305
#   Predicate: Ca ka > -6.65 (n=92)
#     Zone: 17 columns
#     Importance: 0.054656
#   Predicate: Ca ka <= 33.38 (n=183)
#     Zone: 17 columns
#     Importance: 0.010241
#   Predicate: Ca kb > -8.59 (n=180)
#     Zone: 13 columns
#     Importance: 0.000927
#   Predicate: Ca kb <= -6.07 (n=91)
#     Zone: 13 columns
#     Importance: 0.001849
#   Predicate: Ca kb > -6.07 (n=136)
#     Zone: 13 columns
#     Importance: 0.000838
#   Predicate: Ca kb <= -2.67 (n=135)
#     Zone: 13 columns
#     Importance: 0.001375
#   Predicate: Ca kb > -2.67 (n=92)
#     Zone: 13 columns
#     Importance: 0.001051
#   Predicate: Ca kb <= 12.61 (n=183)
#     Zone: 13 columns
#     Importance: 0.001203
#   Predicate: Ti ka > -28.53 (n=185)
#     Zone: 19 columns
#     Importance: 0.023050
#   Predicate: Ti ka <= -4.69 (n=92)
#     Zone: 19 columns
#     Importance: 0.060267
#   Predicate: Ti ka > -4.69 (n=135)
#     Zone: 19 columns
#     Importance: 0.005362
#   Predicate: Ti ka <= 9.34 (n=138)
#     Zone: 19 columns
#     Importance: 0.042147
#   Predicate: Ti ka > 9.34 (n=89)
#     Zone: 19 columns
#     Importance: 0.005080
#   Predicate: Ti ka <= 19.85 (n=179)
#     Zone: 19 columns
#     Importance: 0.033320
#   Predicate: Ti kb > -10.26 (n=182)
#     Zone: 16 columns
#     Importance: 0.003515
#   Predicate: Ti kb <= -2.91 (n=94)
#     Zone: 16 columns
#     Importance: 0.010739
#   Predicate: Ti kb > -2.91 (n=133)
#     Zone: 16 columns
#     Importance: 0.001470
#   Predicate: Ti kb <= 2.45 (n=137)
#     Zone: 16 columns
#     Importance: 0.007900
#   Predicate: Ti kb > 2.45 (n=90)
#     Zone: 16 columns
#     Importance: 0.001363
#   Predicate: Ti kb <= 6.95 (n=182)
#     Zone: 16 columns
#     Importance: 0.006263
#   Predicate: background1 > -1.87 (n=182)
#     Zone: 39 columns
#     Importance: 0.001064
#   Predicate: background1 <= -1.03 (n=90)
#     Zone: 39 columns
#     Importance: 0.003048
#   Predicate: background1 > -1.03 (n=137)
#     Zone: 39 columns
#     Importance: 0.001026
#   Predicate: background1 <= -0.11 (n=136)
#     Zone: 39 columns
#     Importance: 0.002302
#   Predicate: background1 > -0.11 (n=91)
#     Zone: 39 columns
#     Importance: 0.001119
#   Predicate: background1 <= 2.08 (n=179)
#     Zone: 39 columns
#     Importance: 0.002080
#   Predicate: Fe ka > -24.62 (n=185)
#     Zone: 25 columns
#     Importance: 0.001236
#   Predicate: Fe ka <= -24.15 (n=93)
#     Zone: 25 columns
#     Importance: 0.000962
#   Predicate: Fe ka > -24.15 (n=134)
#     Zone: 25 columns
#     Importance: 0.001430
#   Predicate: Fe ka <= -23.71 (n=137)
#     Zone: 25 columns
#     Importance: 0.000947
#   Predicate: Fe ka > -23.71 (n=90)
#     Zone: 25 columns
#     Importance: 0.001680
#   Predicate: Fe ka <= -22.90 (n=177)
#     Zone: 25 columns
#     Importance: 0.000889
#   Predicate: Fe kb > -7.79 (n=179)
#     Zone: 22 columns
#     Importance: 0.001218
#   Predicate: Fe kb <= -7.41 (n=96)
#     Zone: 22 columns
#     Importance: 0.000856
#   Predicate: Fe kb > -7.41 (n=131)
#     Zone: 22 columns
#     Importance: 0.001387
#   Predicate: Fe kb <= -7.02 (n=143)
#     Zone: 22 columns
#     Importance: 0.000829
#   Predicate: Fe kb > -7.02 (n=84)
#     Zone: 22 columns
#     Importance: 0.001729
#   Predicate: Fe kb <= -6.37 (n=179)
#     Zone: 22 columns
#     Importance: 0.000817
#   Predicate: background2 > -0.92 (n=184)
#     Zone: 18 columns
#     Importance: 0.000830
#   Predicate: background2 <= -0.37 (n=91)
#     Zone: 18 columns
#     Importance: 0.000710
#   Predicate: background2 > -0.37 (n=136)
#     Zone: 18 columns
#     Importance: 0.000917
#   Predicate: background2 <= 0.27 (n=136)
#     Zone: 18 columns
#     Importance: 0.000799
#   Predicate: background2 > 0.27 (n=91)
#     Zone: 18 columns
#     Importance: 0.000886
#   Predicate: background2 <= 0.98 (n=181)
#     Zone: 18 columns
#     Importance: 0.000860
#   Predicate: Cu ka > -10.68 (n=185)
#     Zone: 20 columns
#     Importance: 0.006928
#   Predicate: Cu ka <= -9.68 (n=87)
#     Zone: 20 columns
#     Importance: 0.002779
#   Predicate: Cu ka > -9.68 (n=140)
#     Zone: 20 columns
#     Importance: 0.008805
#   Predicate: Cu ka <= -8.43 (n=135)
#     Zone: 20 columns
#     Importance: 0.002082
#   Predicate: Cu ka > -8.43 (n=92)
#     Zone: 20 columns
#     Importance: 0.012971
#   Predicate: Cu ka <= -3.28 (n=179)
#     Zone: 20 columns
#     Importance: 0.001693
#   Predicate: Zn ka > -1.75 (n=186)
#     Zone: 21 columns
#     Importance: 0.000994
#   Predicate: Zn ka <= -0.78 (n=85)
#     Zone: 21 columns
#     Importance: 0.001481
#   Predicate: Zn ka > -0.78 (n=142)
#     Zone: 21 columns
#     Importance: 0.000873
#   Predicate: Zn ka <= 0.08 (n=134)
#     Zone: 21 columns
#     Importance: 0.001260
#   Predicate: Zn ka > 0.08 (n=93)
#     Zone: 21 columns
#     Importance: 0.000871
#   Predicate: Zn ka <= 1.38 (n=183)
#     Zone: 21 columns
#     Importance: 0.001204
#   Predicate: Cu kb > -2.88 (n=184)
#     Zone: 19 columns
#     Importance: 0.000779
#   Predicate: Cu kb <= -2.30 (n=89)
#     Zone: 19 columns
#     Importance: 0.001135
#   Predicate: Cu kb > -2.30 (n=138)
#     Zone: 19 columns
#     Importance: 0.000684
#   Predicate: Cu kb <= -1.61 (n=139)
#     Zone: 19 columns
#     Importance: 0.000914
#   Predicate: Cu kb > -1.61 (n=88)
#     Zone: 19 columns
#     Importance: 0.000778
#   Predicate: Cu kb <= 0.18 (n=181)
#     Zone: 19 columns
#     Importance: 0.000883
#   Predicate: Zn kb > -1.05 (n=184)
#     Zone: 30 columns
#     Importance: 0.001502
#   Predicate: Zn kb <= -0.29 (n=90)
#     Zone: 30 columns
#     Importance: 0.001926
#   Predicate: Zn kb > -0.29 (n=137)
#     Zone: 30 columns
#     Importance: 0.001177
#   Predicate: Zn kb <= 0.29 (n=137)
#     Zone: 30 columns
#     Importance: 0.001625
#   Predicate: Zn kb > 0.29 (n=90)
#     Zone: 30 columns
#     Importance: 0.001243
#   Predicate: Zn kb <= 1.07 (n=179)
#     Zone: 30 columns
#     Importance: 0.001418
#   Predicate: background3 > -2.55 (n=181)
#     Zone: 451 columns
#     Importance: 0.004614
#   Predicate: background3 <= -0.30 (n=97)
#     Zone: 451 columns
#     Importance: 0.027272
#   Predicate: background3 > -0.30 (n=130)
#     Zone: 451 columns
#     Importance: 0.002852
#   Predicate: background3 <= 1.29 (n=141)
#     Zone: 451 columns
#     Importance: 0.020203
#   Predicate: background3 > 1.29 (n=86)
#     Zone: 451 columns
#     Importance: 0.001949
#   Predicate: background3 <= 2.86 (n=182)
#     Zone: 451 columns
#     Importance: 0.016057
#   Predicate: Ag ka scattering > -1.65 (n=178)
#     Zone: 49 columns
#     Importance: 0.002520
#   Predicate: Ag ka scattering <= -0.18 (n=95)
#     Zone: 49 columns
#     Importance: 0.017561
#   Predicate: Ag ka scattering > -0.18 (n=132)
#     Zone: 49 columns
#     Importance: 0.003082
#   Predicate: Ag ka scattering <= 1.67 (n=136)
#     Zone: 49 columns
#     Importance: 0.012958
#   Predicate: Ag ka scattering > 1.67 (n=91)
#     Zone: 49 columns
#     Importance: 0.003438
#   Predicate: Ag ka scattering <= 3.49 (n=180)
#     Zone: 49 columns
#     Importance: 0.010298
#
# [Bag_4] Processing 90 predicates...
#   Predicate: Ar ka + Ag L > -1.05 (n=179)
#     Zone: 29 columns
#     Importance: 0.001308
#   Predicate: Ar ka + Ag L <= -0.29 (n=95)
#     Zone: 29 columns
#     Importance: 0.002099
#   Predicate: Ar ka + Ag L > -0.29 (n=132)
#     Zone: 29 columns
#     Importance: 0.000919
#   Predicate: Ar ka + Ag L <= 0.28 (n=139)
#     Zone: 29 columns
#     Importance: 0.001694
#   Predicate: Ar ka + Ag L > 0.28 (n=88)
#     Zone: 29 columns
#     Importance: 0.000968
#   Predicate: Ar ka + Ag L <= 1.07 (n=183)
#     Zone: 29 columns
#     Importance: 0.001517
#   Predicate: Ca ka > -26.11 (n=181)
#     Zone: 17 columns
#     Importance: 0.035160
#   Predicate: Ca ka <= -21.19 (n=90)
#     Zone: 17 columns
#     Importance: 0.016903
#   Predicate: Ca ka > -21.19 (n=137)
#     Zone: 17 columns
#     Importance: 0.044315
#   Predicate: Ca ka <= -6.65 (n=135)
#     Zone: 17 columns
#     Importance: 0.011478
#   Predicate: Ca ka > -6.65 (n=92)
#     Zone: 17 columns
#     Importance: 0.065683
#   Predicate: Ca ka <= 33.38 (n=181)
#     Zone: 17 columns
#     Importance: 0.010750
#   Predicate: Ca kb > -8.59 (n=182)
#     Zone: 13 columns
#     Importance: 0.001052
#   Predicate: Ca kb <= -6.07 (n=90)
#     Zone: 13 columns
#     Importance: 0.001828
#   Predicate: Ca kb > -6.07 (n=137)
#     Zone: 13 columns
#     Importance: 0.001028
#   Predicate: Ca kb <= -2.67 (n=133)
#     Zone: 13 columns
#     Importance: 0.001363
#   Predicate: Ca kb > -2.67 (n=94)
#     Zone: 13 columns
#     Importance: 0.001320
#   Predicate: Ca kb <= 12.61 (n=181)
#     Zone: 13 columns
#     Importance: 0.001215
#   Predicate: Ti ka > -28.53 (n=182)
#     Zone: 19 columns
#     Importance: 0.022103
#   Predicate: Ti ka <= -4.69 (n=93)
#     Zone: 19 columns
#     Importance: 0.050892
#   Predicate: Ti ka > -4.69 (n=134)
#     Zone: 19 columns
#     Importance: 0.005574
#   Predicate: Ti ka <= 9.34 (n=140)
#     Zone: 19 columns
#     Importance: 0.035651
#   Predicate: Ti ka > 9.34 (n=87)
#     Zone: 19 columns
#     Importance: 0.005617
#   Predicate: Ti ka <= 19.85 (n=180)
#     Zone: 19 columns
#     Importance: 0.028694
#   Predicate: Ti kb > -10.26 (n=185)
#     Zone: 16 columns
#     Importance: 0.003346
#   Predicate: Ti kb <= -2.91 (n=92)
#     Zone: 16 columns
#     Importance: 0.008835
#   Predicate: Ti kb > -2.91 (n=135)
#     Zone: 16 columns
#     Importance: 0.001522
#   Predicate: Ti kb <= 2.45 (n=136)
#     Zone: 16 columns
#     Importance: 0.006509
#   Predicate: Ti kb > 2.45 (n=91)
#     Zone: 16 columns
#     Importance: 0.001463
#   Predicate: Ti kb <= 6.95 (n=182)
#     Zone: 16 columns
#     Importance: 0.005200
#   Predicate: background1 > -1.87 (n=181)
#     Zone: 39 columns
#     Importance: 0.001071
#   Predicate: background1 <= -1.03 (n=90)
#     Zone: 39 columns
#     Importance: 0.003057
#   Predicate: background1 > -1.03 (n=137)
#     Zone: 39 columns
#     Importance: 0.001011
#   Predicate: background1 <= -0.11 (n=136)
#     Zone: 39 columns
#     Importance: 0.002283
#   Predicate: background1 > -0.11 (n=91)
#     Zone: 39 columns
#     Importance: 0.001133
#   Predicate: background1 <= 2.08 (n=182)
#     Zone: 39 columns
#     Importance: 0.002038
#   Predicate: Fe ka > -24.62 (n=181)
#     Zone: 25 columns
#     Importance: 0.001239
#   Predicate: Fe ka <= -24.15 (n=94)
#     Zone: 25 columns
#     Importance: 0.000822
#   Predicate: Fe ka > -24.15 (n=133)
#     Zone: 25 columns
#     Importance: 0.001505
#   Predicate: Fe ka <= -23.71 (n=137)
#     Zone: 25 columns
#     Importance: 0.000867
#   Predicate: Fe ka > -23.71 (n=90)
#     Zone: 25 columns
#     Importance: 0.001763
#   Predicate: Fe ka <= -22.90 (n=183)
#     Zone: 25 columns
#     Importance: 0.000806
#   Predicate: Fe kb > -7.79 (n=180)
#     Zone: 22 columns
#     Importance: 0.001390
#   Predicate: Fe kb <= -7.41 (n=91)
#     Zone: 22 columns
#     Importance: 0.000815
#   Predicate: Fe kb > -7.41 (n=136)
#     Zone: 22 columns
#     Importance: 0.001615
#   Predicate: Fe kb <= -7.02 (n=138)
#     Zone: 22 columns
#     Importance: 0.000962
#   Predicate: Fe kb > -7.02 (n=89)
#     Zone: 22 columns
#     Importance: 0.001810
#   Predicate: Fe kb <= -6.37 (n=182)
#     Zone: 22 columns
#     Importance: 0.000909
#   Predicate: background2 > -0.92 (n=185)
#     Zone: 18 columns
#     Importance: 0.000767
#   Predicate: background2 <= -0.37 (n=89)
#     Zone: 18 columns
#     Importance: 0.000730
#   Predicate: background2 > -0.37 (n=138)
#     Zone: 18 columns
#     Importance: 0.000868
#   Predicate: background2 <= 0.27 (n=137)
#     Zone: 18 columns
#     Importance: 0.000774
#   Predicate: background2 > 0.27 (n=90)
#     Zone: 18 columns
#     Importance: 0.000874
#   Predicate: background2 <= 0.98 (n=182)
#     Zone: 18 columns
#     Importance: 0.000818
#   Predicate: Cu ka > -10.68 (n=181)
#     Zone: 20 columns
#     Importance: 0.007279
#   Predicate: Cu ka <= -9.68 (n=96)
#     Zone: 20 columns
#     Importance: 0.002579
#   Predicate: Cu ka > -9.68 (n=131)
#     Zone: 20 columns
#     Importance: 0.009646
#   Predicate: Cu ka <= -8.43 (n=137)
#     Zone: 20 columns
#     Importance: 0.002028
#   Predicate: Cu ka > -8.43 (n=90)
#     Zone: 20 columns
#     Importance: 0.013704
#   Predicate: Cu ka <= -3.28 (n=182)
#     Zone: 20 columns
#     Importance: 0.001769
#   Predicate: Zn ka > -1.75 (n=185)
#     Zone: 21 columns
#     Importance: 0.001001
#   Predicate: Zn ka <= -0.78 (n=83)
#     Zone: 21 columns
#     Importance: 0.001427
#   Predicate: Zn ka > -0.78 (n=144)
#     Zone: 21 columns
#     Importance: 0.000886
#   Predicate: Zn ka <= 0.08 (n=136)
#     Zone: 21 columns
#     Importance: 0.001192
#   Predicate: Zn ka > 0.08 (n=91)
#     Zone: 21 columns
#     Importance: 0.000922
#   Predicate: Zn ka <= 1.38 (n=181)
#     Zone: 21 columns
#     Importance: 0.001188
#   Predicate: Cu kb > -2.88 (n=176)
#     Zone: 19 columns
#     Importance: 0.000704
#   Predicate: Cu kb <= -2.30 (n=95)
#     Zone: 19 columns
#     Importance: 0.001138
#   Predicate: Cu kb > -2.30 (n=132)
#     Zone: 19 columns
#     Importance: 0.000658
#   Predicate: Cu kb <= -1.61 (n=140)
#     Zone: 19 columns
#     Importance: 0.000952
#   Predicate: Cu kb > -1.61 (n=87)
#     Zone: 19 columns
#     Importance: 0.000708
#   Predicate: Cu kb <= 0.18 (n=182)
#     Zone: 19 columns
#     Importance: 0.000882
#   Predicate: Zn kb > -1.05 (n=184)
#     Zone: 30 columns
#     Importance: 0.001577
#   Predicate: Zn kb <= -0.29 (n=94)
#     Zone: 30 columns
#     Importance: 0.001869
#   Predicate: Zn kb > -0.29 (n=133)
#     Zone: 30 columns
#     Importance: 0.001225
#   Predicate: Zn kb <= 0.29 (n=142)
#     Zone: 30 columns
#     Importance: 0.001622
#   Predicate: Zn kb > 0.29 (n=85)
#     Zone: 30 columns
#     Importance: 0.001274
#   Predicate: Zn kb <= 1.07 (n=186)
#     Zone: 30 columns
#     Importance: 0.001406
#   Predicate: background3 > -2.55 (n=181)
#     Zone: 451 columns
#     Importance: 0.004785
#   Predicate: background3 <= -0.30 (n=93)
#     Zone: 451 columns
#     Importance: 0.025730
#   Predicate: background3 > -0.30 (n=134)
#     Zone: 451 columns
#     Importance: 0.003088
#   Predicate: background3 <= 1.29 (n=139)
#     Zone: 451 columns
#     Importance: 0.018823
#   Predicate: background3 > 1.29 (n=88)
#     Zone: 451 columns
#     Importance: 0.002162
#   Predicate: background3 <= 2.86 (n=184)
#     Zone: 451 columns
#     Importance: 0.014831
#   Predicate: Ag ka scattering > -1.65 (n=179)
#     Zone: 49 columns
#     Importance: 0.002469
#   Predicate: Ag ka scattering <= -0.18 (n=91)
#     Zone: 49 columns
#     Importance: 0.015645
#   Predicate: Ag ka scattering > -0.18 (n=136)
#     Zone: 49 columns
#     Importance: 0.002962
#   Predicate: Ag ka scattering <= 1.67 (n=133)
#     Zone: 49 columns
#     Importance: 0.011485
#   Predicate: Ag ka scattering > 1.67 (n=94)
#     Zone: 49 columns
#     Importance: 0.003181
#   Predicate: Ag ka scattering <= 3.49 (n=177)
#     Zone: 49 columns
#     Importance: 0.009046
#
# [Bag_5] Processing 90 predicates...
#   Predicate: Ar ka + Ag L > -1.05 (n=183)
#     Zone: 29 columns
#     Importance: 0.001113
#   Predicate: Ar ka + Ag L <= -0.29 (n=89)
#     Zone: 29 columns
#     Importance: 0.001198
#   Predicate: Ar ka + Ag L > -0.29 (n=138)
#     Zone: 29 columns
#     Importance: 0.001116
#   Predicate: Ar ka + Ag L <= 0.28 (n=139)
#     Zone: 29 columns
#     Importance: 0.001098
#   Predicate: Ar ka + Ag L > 0.28 (n=88)
#     Zone: 29 columns
#     Importance: 0.001227
#   Predicate: Ar ka + Ag L <= 1.07 (n=183)
#     Zone: 29 columns
#     Importance: 0.001180
#   Predicate: Ca ka > -26.11 (n=187)
#     Zone: 17 columns
#     Importance: 0.032343
#   Predicate: Ca ka <= -21.19 (n=87)
#     Zone: 17 columns
#     Importance: 0.013669
#   Predicate: Ca ka > -21.19 (n=140)
#     Zone: 17 columns
#     Importance: 0.041791
#   Predicate: Ca ka <= -6.65 (n=132)
#     Zone: 17 columns
#     Importance: 0.009245
#   Predicate: Ca ka > -6.65 (n=95)
#     Zone: 17 columns
#     Importance: 0.061260
#   Predicate: Ca ka <= 33.38 (n=183)
#     Zone: 17 columns
#     Importance: 0.008694
#   Predicate: Ca kb > -8.59 (n=188)
#     Zone: 13 columns
#     Importance: 0.000901
#   Predicate: Ca kb <= -6.07 (n=87)
#     Zone: 13 columns
#     Importance: 0.001541
#   Predicate: Ca kb > -6.07 (n=140)
#     Zone: 13 columns
#     Importance: 0.000955
#   Predicate: Ca kb <= -2.67 (n=134)
#     Zone: 13 columns
#     Importance: 0.001153
#   Predicate: Ca kb > -2.67 (n=93)
#     Zone: 13 columns
#     Importance: 0.001218
#   Predicate: Ca kb <= 12.61 (n=182)
#     Zone: 13 columns
#     Importance: 0.001060
#   Predicate: Ti ka > -28.53 (n=184)
#     Zone: 19 columns
#     Importance: 0.018060
#   Predicate: Ti ka <= -4.69 (n=90)
#     Zone: 19 columns
#     Importance: 0.046719
#   Predicate: Ti ka > -4.69 (n=137)
#     Zone: 19 columns
#     Importance: 0.004460
#   Predicate: Ti ka <= 9.34 (n=136)
#     Zone: 19 columns
#     Importance: 0.031818
#   Predicate: Ti ka > 9.34 (n=91)
#     Zone: 19 columns
#     Importance: 0.005368
#   Predicate: Ti ka <= 19.85 (n=183)
#     Zone: 19 columns
#     Importance: 0.024701
#   Predicate: Ti kb > -10.26 (n=183)
#     Zone: 16 columns
#     Importance: 0.002780
#   Predicate: Ti kb <= -2.91 (n=89)
#     Zone: 16 columns
#     Importance: 0.008939
#   Predicate: Ti kb > -2.91 (n=138)
#     Zone: 16 columns
#     Importance: 0.001352
#   Predicate: Ti kb <= 2.45 (n=135)
#     Zone: 16 columns
#     Importance: 0.006240
#   Predicate: Ti kb > 2.45 (n=92)
#     Zone: 16 columns
#     Importance: 0.001519
#   Predicate: Ti kb <= 6.95 (n=181)
#     Zone: 16 columns
#     Importance: 0.004990
#   Predicate: background1 > -1.87 (n=185)
#     Zone: 39 columns
#     Importance: 0.000994
#   Predicate: background1 <= -1.03 (n=86)
#     Zone: 39 columns
#     Importance: 0.002321
#   Predicate: background1 > -1.03 (n=141)
#     Zone: 39 columns
#     Importance: 0.000933
#   Predicate: background1 <= -0.11 (n=136)
#     Zone: 39 columns
#     Importance: 0.001810
#   Predicate: background1 > -0.11 (n=91)
#     Zone: 39 columns
#     Importance: 0.000933
#   Predicate: background1 <= 2.08 (n=179)
#     Zone: 39 columns
#     Importance: 0.001616
#   Predicate: Fe ka > -24.62 (n=182)
#     Zone: 25 columns
#     Importance: 0.001188
#   Predicate: Fe ka <= -24.15 (n=87)
#     Zone: 25 columns
#     Importance: 0.000929
#   Predicate: Fe ka > -24.15 (n=140)
#     Zone: 25 columns
#     Importance: 0.001302
#   Predicate: Fe ka <= -23.71 (n=133)
#     Zone: 25 columns
#     Importance: 0.000799
#   Predicate: Fe ka > -23.71 (n=94)
#     Zone: 25 columns
#     Importance: 0.001668
#   Predicate: Fe ka <= -22.90 (n=177)
#     Zone: 25 columns
#     Importance: 0.000736
#   Predicate: Fe kb > -7.79 (n=182)
#     Zone: 22 columns
#     Importance: 0.001322
#   Predicate: Fe kb <= -7.41 (n=89)
#     Zone: 22 columns
#     Importance: 0.000842
#   Predicate: Fe kb > -7.41 (n=138)
#     Zone: 22 columns
#     Importance: 0.001495
#   Predicate: Fe kb <= -7.02 (n=138)
#     Zone: 22 columns
#     Importance: 0.000909
#   Predicate: Fe kb > -7.02 (n=89)
#     Zone: 22 columns
#     Importance: 0.001752
#   Predicate: Fe kb <= -6.37 (n=182)
#     Zone: 22 columns
#     Importance: 0.000848
#   Predicate: background2 > -0.92 (n=182)
#     Zone: 18 columns
#     Importance: 0.000770
#   Predicate: background2 <= -0.37 (n=89)
#     Zone: 18 columns
#     Importance: 0.000790
#   Predicate: background2 > -0.37 (n=138)
#     Zone: 18 columns
#     Importance: 0.000809
#   Predicate: background2 <= 0.27 (n=137)
#     Zone: 18 columns
#     Importance: 0.000787
#   Predicate: background2 > 0.27 (n=90)
#     Zone: 18 columns
#     Importance: 0.000823
#   Predicate: background2 <= 0.98 (n=180)
#     Zone: 18 columns
#     Importance: 0.000849
#   Predicate: Cu ka > -10.68 (n=185)
#     Zone: 20 columns
#     Importance: 0.007129
#   Predicate: Cu ka <= -9.68 (n=85)
#     Zone: 20 columns
#     Importance: 0.001747
#   Predicate: Cu ka > -9.68 (n=142)
#     Zone: 20 columns
#     Importance: 0.008969
#   Predicate: Cu ka <= -8.43 (n=132)
#     Zone: 20 columns
#     Importance: 0.001414
#   Predicate: Cu ka > -8.43 (n=95)
#     Zone: 20 columns
#     Importance: 0.013006
#   Predicate: Cu ka <= -3.28 (n=179)
#     Zone: 20 columns
#     Importance: 0.001331
#   Predicate: Zn ka > -1.75 (n=186)
#     Zone: 21 columns
#     Importance: 0.000880
#   Predicate: Zn ka <= -0.78 (n=84)
#     Zone: 21 columns
#     Importance: 0.000832
#   Predicate: Zn ka > -0.78 (n=143)
#     Zone: 21 columns
#     Importance: 0.000899
#   Predicate: Zn ka <= 0.08 (n=136)
#     Zone: 21 columns
#     Importance: 0.000837
#   Predicate: Zn ka > 0.08 (n=91)
#     Zone: 21 columns
#     Importance: 0.000930
#   Predicate: Zn ka <= 1.38 (n=183)
#     Zone: 21 columns
#     Importance: 0.000887
#   Predicate: Cu kb > -2.88 (n=180)
#     Zone: 19 columns
#     Importance: 0.000708
#   Predicate: Cu kb <= -2.30 (n=88)
#     Zone: 19 columns
#     Importance: 0.001167
#   Predicate: Cu kb > -2.30 (n=139)
#     Zone: 19 columns
#     Importance: 0.000638
#   Predicate: Cu kb <= -1.61 (n=135)
#     Zone: 19 columns
#     Importance: 0.000954
#   Predicate: Cu kb > -1.61 (n=92)
#     Zone: 19 columns
#     Importance: 0.000680
#   Predicate: Cu kb <= 0.18 (n=181)
#     Zone: 19 columns
#     Importance: 0.000850
#   Predicate: Zn kb > -1.05 (n=183)
#     Zone: 30 columns
#     Importance: 0.001089
#   Predicate: Zn kb <= -0.29 (n=89)
#     Zone: 30 columns
#     Importance: 0.001608
#   Predicate: Zn kb > -0.29 (n=138)
#     Zone: 30 columns
#     Importance: 0.000785
#   Predicate: Zn kb <= 0.29 (n=134)
#     Zone: 30 columns
#     Importance: 0.001389
#   Predicate: Zn kb > 0.29 (n=93)
#     Zone: 30 columns
#     Importance: 0.000702
#   Predicate: Zn kb <= 1.07 (n=181)
#     Zone: 30 columns
#     Importance: 0.001240
#   Predicate: background3 > -2.55 (n=185)
#     Zone: 451 columns
#     Importance: 0.004659
#   Predicate: background3 <= -0.30 (n=90)
#     Zone: 451 columns
#     Importance: 0.015948
#   Predicate: background3 > -0.30 (n=137)
#     Zone: 451 columns
#     Importance: 0.003239
#   Predicate: background3 <= 1.29 (n=137)
#     Zone: 451 columns
#     Importance: 0.012185
#   Predicate: background3 > 1.29 (n=90)
#     Zone: 451 columns
#     Importance: 0.002329
#   Predicate: background3 <= 2.86 (n=182)
#     Zone: 451 columns
#     Importance: 0.009767
#   Predicate: Ag ka scattering > -1.65 (n=182)
#     Zone: 49 columns
#     Importance: 0.001896
#   Predicate: Ag ka scattering <= -0.18 (n=89)
#     Zone: 49 columns
#     Importance: 0.009493
#   Predicate: Ag ka scattering > -0.18 (n=138)
#     Zone: 49 columns
#     Importance: 0.002151
#   Predicate: Ag ka scattering <= 1.67 (n=136)
#     Zone: 49 columns
#     Importance: 0.006627
#   Predicate: Ag ka scattering > 1.67 (n=91)
#     Zone: 49 columns
#     Importance: 0.002642
#   Predicate: Ag ka scattering <= 3.49 (n=182)
#     Zone: 49 columns
#     Importance: 0.005452
#
# [Bag_6] Processing 90 predicates...
#   Predicate: Ar ka + Ag L > -1.05 (n=182)
#     Zone: 29 columns
#     Importance: 0.001334
#   Predicate: Ar ka + Ag L <= -0.29 (n=92)
#     Zone: 29 columns
#     Importance: 0.001954
#   Predicate: Ar ka + Ag L > -0.29 (n=135)
#     Zone: 29 columns
#     Importance: 0.000946
#   Predicate: Ar ka + Ag L <= 0.28 (n=133)
#     Zone: 29 columns
#     Importance: 0.001647
#   Predicate: Ar ka + Ag L > 0.28 (n=94)
#     Zone: 29 columns
#     Importance: 0.000940
#   Predicate: Ar ka + Ag L <= 1.07 (n=178)
#     Zone: 29 columns
#     Importance: 0.001586
#   Predicate: Ca ka > -26.11 (n=186)
#     Zone: 17 columns
#     Importance: 0.026444
#   Predicate: Ca ka <= -21.19 (n=94)
#     Zone: 17 columns
#     Importance: 0.016663
#   Predicate: Ca ka > -21.19 (n=133)
#     Zone: 17 columns
#     Importance: 0.034706
#   Predicate: Ca ka <= -6.65 (n=142)
#     Zone: 17 columns
#     Importance: 0.011238
#   Predicate: Ca ka > -6.65 (n=85)
#     Zone: 17 columns
#     Importance: 0.053958
#   Predicate: Ca ka <= 33.38 (n=185)
#     Zone: 17 columns
#     Importance: 0.010038
#   Predicate: Ca kb > -8.59 (n=183)
#     Zone: 13 columns
#     Importance: 0.000982
#   Predicate: Ca kb <= -6.07 (n=94)
#     Zone: 13 columns
#     Importance: 0.001751
#   Predicate: Ca kb > -6.07 (n=133)
#     Zone: 13 columns
#     Importance: 0.000933
#   Predicate: Ca kb <= -2.67 (n=143)
#     Zone: 13 columns
#     Importance: 0.001293
#   Predicate: Ca kb > -2.67 (n=84)
#     Zone: 13 columns
#     Importance: 0.001236
#   Predicate: Ca kb <= 12.61 (n=184)
#     Zone: 13 columns
#     Importance: 0.001178
#   Predicate: Ti ka > -28.53 (n=186)
#     Zone: 19 columns
#     Importance: 0.019202
#   Predicate: Ti ka <= -4.69 (n=89)
#     Zone: 19 columns
#     Importance: 0.048976
#   Predicate: Ti ka > -4.69 (n=138)
#     Zone: 19 columns
#     Importance: 0.004985
#   Predicate: Ti ka <= 9.34 (n=136)
#     Zone: 19 columns
#     Importance: 0.033642
#   Predicate: Ti ka > 9.34 (n=91)
#     Zone: 19 columns
#     Importance: 0.005180
#   Predicate: Ti ka <= 19.85 (n=181)
#     Zone: 19 columns
#     Importance: 0.026081
#   Predicate: Ti kb > -10.26 (n=182)
#     Zone: 16 columns
#     Importance: 0.002964
#   Predicate: Ti kb <= -2.91 (n=88)
#     Zone: 16 columns
#     Importance: 0.009729
#   Predicate: Ti kb > -2.91 (n=139)
#     Zone: 16 columns
#     Importance: 0.001380
#   Predicate: Ti kb <= 2.45 (n=135)
#     Zone: 16 columns
#     Importance: 0.006758
#   Predicate: Ti kb > 2.45 (n=92)
#     Zone: 16 columns
#     Importance: 0.001474
#   Predicate: Ti kb <= 6.95 (n=179)
#     Zone: 16 columns
#     Importance: 0.005421
#   Predicate: background1 > -1.87 (n=186)
#     Zone: 39 columns
#     Importance: 0.000985
#   Predicate: background1 <= -1.03 (n=82)
#     Zone: 39 columns
#     Importance: 0.003285
#   Predicate: background1 > -1.03 (n=145)
#     Zone: 39 columns
#     Importance: 0.000920
#   Predicate: background1 <= -0.11 (n=129)
#     Zone: 39 columns
#     Importance: 0.002408
#   Predicate: background1 > -0.11 (n=98)
#     Zone: 39 columns
#     Importance: 0.000941
#   Predicate: background1 <= 2.08 (n=176)
#     Zone: 39 columns
#     Importance: 0.002038
#   Predicate: Fe ka > -24.62 (n=182)
#     Zone: 25 columns
#     Importance: 0.001203
#   Predicate: Fe ka <= -24.15 (n=87)
#     Zone: 25 columns
#     Importance: 0.000860
#   Predicate: Fe ka > -24.15 (n=140)
#     Zone: 25 columns
#     Importance: 0.001417
#   Predicate: Fe ka <= -23.71 (n=131)
#     Zone: 25 columns
#     Importance: 0.000828
#   Predicate: Fe ka > -23.71 (n=96)
#     Zone: 25 columns
#     Importance: 0.001717
#   Predicate: Fe ka <= -22.90 (n=177)
#     Zone: 25 columns
#     Importance: 0.000767
#   Predicate: Fe kb > -7.79 (n=182)
#     Zone: 22 columns
#     Importance: 0.001360
#   Predicate: Fe kb <= -7.41 (n=90)
#     Zone: 22 columns
#     Importance: 0.000850
#   Predicate: Fe kb > -7.41 (n=137)
#     Zone: 22 columns
#     Importance: 0.001552
#   Predicate: Fe kb <= -7.02 (n=139)
#     Zone: 22 columns
#     Importance: 0.000996
#   Predicate: Fe kb > -7.02 (n=88)
#     Zone: 22 columns
#     Importance: 0.001713
#   Predicate: Fe kb <= -6.37 (n=180)
#     Zone: 22 columns
#     Importance: 0.000923
#   Predicate: background2 > -0.92 (n=180)
#     Zone: 18 columns
#     Importance: 0.000737
#   Predicate: background2 <= -0.37 (n=91)
#     Zone: 18 columns
#     Importance: 0.000700
#   Predicate: background2 > -0.37 (n=136)
#     Zone: 18 columns
#     Importance: 0.000817
#   Predicate: background2 <= 0.27 (n=138)
#     Zone: 18 columns
#     Importance: 0.000778
#   Predicate: background2 > 0.27 (n=89)
#     Zone: 18 columns
#     Importance: 0.000759
#   Predicate: background2 <= 0.98 (n=182)
#     Zone: 18 columns
#     Importance: 0.000845
#   Predicate: Cu ka > -10.68 (n=181)
#     Zone: 20 columns
#     Importance: 0.007496
#   Predicate: Cu ka <= -9.68 (n=89)
#     Zone: 20 columns
#     Importance: 0.002340
#   Predicate: Cu ka > -9.68 (n=138)
#     Zone: 20 columns
#     Importance: 0.009527
#   Predicate: Cu ka <= -8.43 (n=135)
#     Zone: 20 columns
#     Importance: 0.001817
#   Predicate: Cu ka > -8.43 (n=92)
#     Zone: 20 columns
#     Importance: 0.013888
#   Predicate: Cu ka <= -3.28 (n=178)
#     Zone: 20 columns
#     Importance: 0.001617
#   Predicate: Zn ka > -1.75 (n=177)
#     Zone: 21 columns
#     Importance: 0.000890
#   Predicate: Zn ka <= -0.78 (n=91)
#     Zone: 21 columns
#     Importance: 0.001328
#   Predicate: Zn ka > -0.78 (n=136)
#     Zone: 21 columns
#     Importance: 0.000813
#   Predicate: Zn ka <= 0.08 (n=136)
#     Zone: 21 columns
#     Importance: 0.001149
#   Predicate: Zn ka > 0.08 (n=91)
#     Zone: 21 columns
#     Importance: 0.000826
#   Predicate: Zn ka <= 1.38 (n=178)
#     Zone: 21 columns
#     Importance: 0.001083
#   Predicate: Cu kb > -2.88 (n=180)
#     Zone: 19 columns
#     Importance: 0.000687
#   Predicate: Cu kb <= -2.30 (n=91)
#     Zone: 19 columns
#     Importance: 0.000945
#   Predicate: Cu kb > -2.30 (n=136)
#     Zone: 19 columns
#     Importance: 0.000674
#   Predicate: Cu kb <= -1.61 (n=135)
#     Zone: 19 columns
#     Importance: 0.000809
#   Predicate: Cu kb > -1.61 (n=92)
#     Zone: 19 columns
#     Importance: 0.000744
#   Predicate: Cu kb <= 0.18 (n=181)
#     Zone: 19 columns
#     Importance: 0.000786
#   Predicate: Zn kb > -1.05 (n=181)
#     Zone: 30 columns
#     Importance: 0.001554
#   Predicate: Zn kb <= -0.29 (n=95)
#     Zone: 30 columns
#     Importance: 0.001941
#   Predicate: Zn kb > -0.29 (n=132)
#     Zone: 30 columns
#     Importance: 0.001165
#   Predicate: Zn kb <= 0.29 (n=133)
#     Zone: 30 columns
#     Importance: 0.001627
#   Predicate: Zn kb > 0.29 (n=94)
#     Zone: 30 columns
#     Importance: 0.001296
#   Predicate: Zn kb <= 1.07 (n=180)
#     Zone: 30 columns
#     Importance: 0.001411
#   Predicate: background3 > -2.55 (n=180)
#     Zone: 451 columns
#     Importance: 0.003820
#   Predicate: background3 <= -0.30 (n=93)
#     Zone: 451 columns
#     Importance: 0.022391
#   Predicate: background3 > -0.30 (n=134)
#     Zone: 451 columns
#     Importance: 0.002898
#   Predicate: background3 <= 1.29 (n=137)
#     Zone: 451 columns
#     Importance: 0.016651
#   Predicate: background3 > 1.29 (n=90)
#     Zone: 451 columns
#     Importance: 0.002106
#   Predicate: background3 <= 2.86 (n=185)
#     Zone: 451 columns
#     Importance: 0.012907
#   Predicate: Ag ka scattering > -1.65 (n=182)
#     Zone: 49 columns
#     Importance: 0.002271
#   Predicate: Ag ka scattering <= -0.18 (n=85)
#     Zone: 49 columns
#     Importance: 0.014708
#   Predicate: Ag ka scattering > -0.18 (n=142)
#     Zone: 49 columns
#     Importance: 0.002689
#   Predicate: Ag ka scattering <= 1.67 (n=135)
#     Zone: 49 columns
#     Importance: 0.010122
#   Predicate: Ag ka scattering > 1.67 (n=92)
#     Zone: 49 columns
#     Importance: 0.002887
#   Predicate: Ag ka scattering <= 3.49 (n=181)
#     Zone: 49 columns
#     Importance: 0.007963
#
# [Bag_7] Processing 90 predicates...
#   Predicate: Ar ka + Ag L > -1.05 (n=180)
#     Zone: 29 columns
#     Importance: 0.001413
#   Predicate: Ar ka + Ag L <= -0.29 (n=91)
#     Zone: 29 columns
#     Importance: 0.001982
#   Predicate: Ar ka + Ag L > -0.29 (n=136)
#     Zone: 29 columns
#     Importance: 0.001051
#   Predicate: Ar ka + Ag L <= 0.28 (n=135)
#     Zone: 29 columns
#     Importance: 0.001632
#   Predicate: Ar ka + Ag L > 0.28 (n=92)
#     Zone: 29 columns
#     Importance: 0.001121
#   Predicate: Ar ka + Ag L <= 1.07 (n=177)
#     Zone: 29 columns
#     Importance: 0.001591
#   Predicate: Ca ka > -26.11 (n=180)
#     Zone: 17 columns
#     Importance: 0.030029
#   Predicate: Ca ka <= -21.19 (n=92)
#     Zone: 17 columns
#     Importance: 0.016167
#   Predicate: Ca ka > -21.19 (n=135)
#     Zone: 17 columns
#     Importance: 0.037946
#   Predicate: Ca ka <= -6.65 (n=138)
#     Zone: 17 columns
#     Importance: 0.010982
#   Predicate: Ca ka > -6.65 (n=89)
#     Zone: 17 columns
#     Importance: 0.057242
#   Predicate: Ca ka <= 33.38 (n=180)
#     Zone: 17 columns
#     Importance: 0.010391
#   Predicate: Ca kb > -8.59 (n=180)
#     Zone: 13 columns
#     Importance: 0.000985
#   Predicate: Ca kb <= -6.07 (n=92)
#     Zone: 13 columns
#     Importance: 0.001798
#   Predicate: Ca kb > -6.07 (n=135)
#     Zone: 13 columns
#     Importance: 0.000922
#   Predicate: Ca kb <= -2.67 (n=139)
#     Zone: 13 columns
#     Importance: 0.001323
#   Predicate: Ca kb > -2.67 (n=88)
#     Zone: 13 columns
#     Importance: 0.001203
#   Predicate: Ca kb <= 12.61 (n=180)
# ...
#
# ======================================================================
# CONSTRUCTED GRAPH SUMMARY
# ======================================================================
# Initial edges: 518 | Removed: 114
# Predicate nodes: 90
# Metric: Perturbation
# Weighting by explained variance: ENABLED
#
# ======================================================================
# Processando Grafo - Semente: 3
# ======================================================================
#
#
# Total bidirectional pairs found: 127
# Removed: Ti ka <= -4.69 -> Ca ka > -6.65 (0.0585) | Kept: Ca ka > -6.65 -> Ti ka <= -4.69 (0.5630)
# Removed: Ca ka > -21.19 -> Ti ka <= 9.34 (0.1726) | Kept: Ti ka <= 9.34 -> Ca ka > -21.19 (0.2429)
# Removed: Ti ka <= 19.85 -> Ca ka > -26.11 (0.0615) | Kept: Ca ka > -26.11 -> Ti ka <= 19.85 (0.2304)
# Removed: background3 <= -0.30 -> Ca ka > -26.11 (0.0008) | Kept: Ca ka > -26.11 -> background3 <= -0.30 (0.0322)
# Removed: background3 <= -0.30 -> Ti ka > -28.53 (0.0047) | Kept: Ti ka > -28.53 -> background3 <= -0.30 (0.0391)
# Removed: background3 <= 1.29 -> Ca ka <= -21.19 (0.0035) | Kept: Ca ka <= -21.19 -> background3 <= 1.29 (0.0320)
# Removed: background3 <= 2.86 -> Ag ka scattering <= -0.18 (0.0015) | Kept: Ag ka scattering <= -0.18 -> background3 <= 2.86 (0.0186)
# Removed: background3 <= 2.86 -> Ca ka <= -21.19 (0.0004) | Kept: Ca ka <= -21.19 -> background3 <= 2.86 (0.0681)
# Removed: Ag ka scattering <= 1.67 -> Ca ka <= -6.65 (0.0068) | Kept: Ca ka <= -6.65 -> Ag ka scattering <= 1.67 (0.0231)
# Removed: Ag ka scattering <= 1.67 -> Cu ka > -8.43 (0.0094) | Kept: Cu ka > -8.43 -> Ag ka scattering <= 1.67 (0.0217)
# Removed: Ag ka scattering <= 1.67 -> Ca ka <= 33.38 (0.0063) | Kept: Ca ka <= 33.38 -> Ag ka scattering <= 1.67 (0.0314)
# Removed: Ti kb <= -2.91 -> Ca ka <= 33.38 (0.0256) | Kept: Ca ka <= 33.38 -> Ti kb <= -2.91 (0.0526)
# Removed: Ti kb <= -2.91 -> Cu ka > -8.43 (0.0081) | Kept: Cu ka > -8.43 -> Ti kb <= -2.91 (0.0105)
# Removed: Ti kb <= 2.45 -> Ag ka scattering <= 3.49 (0.0118) | Kept: Ag ka scattering <= 3.49 -> Ti kb <= 2.45 (0.0122)
# Removed: Ag ka scattering <= 3.49 -> Cu ka > -9.68 (0.0071) | Kept: Cu ka > -9.68 -> Ag ka scattering <= 3.49 (0.0278)
# Removed: Ti kb <= 2.45 -> Cu ka > -9.68 (0.0185) | Kept: Cu ka > -9.68 -> Ti kb <= 2.45 (0.0247)
# Removed: Cu ka > -10.68 -> Ti kb <= 2.45 (0.0073) | Kept: Ti kb <= 2.45 -> Cu ka > -10.68 (0.0245)
# Removed: Ti kb <= 6.95 -> Cu ka > -10.68 (0.0047) | Kept: Cu ka > -10.68 -> Ti kb <= 6.95 (0.0337)
# Removed: Cu ka > -10.68 -> Ti ka > -4.69 (0.0055) | Kept: Ti ka > -4.69 -> Cu ka > -10.68 (0.0109)
# Removed: Ti ka > 9.34 -> Ti ka > -4.69 (0.0160) | Kept: Ti ka > -4.69 -> Ti ka > 9.34 (0.0320)
# Removed: Ti ka > 9.34 -> Cu ka > -10.68 (0.0049) | Kept: Cu ka > -10.68 -> Ti ka > 9.34 (0.0055)
# Removed: Ag ka scattering > 1.67 -> Ti kb > -10.26 (0.0009) | Kept: Ti kb > -10.26 -> Ag ka scattering > 1.67 (0.0056)
# Removed: Ag ka scattering > -0.18 -> Ti kb > -10.26 (0.0009) | Kept: Ti kb > -10.26 -> Ag ka scattering > -0.18 (0.0026)
# Removed: background3 > -0.30 -> Ag ka scattering > 1.67 (0.0001) | Kept: Ag ka scattering > 1.67 -> background3 > -0.30 (0.0009)
# Removed: background1 <= -1.03 -> Ag ka scattering > 1.67 (0.0004) | Kept: Ag ka scattering > 1.67 -> background1 <= -1.03 (0.0026)
# Removed: Ag ka scattering > -0.18 -> Ag ka scattering > 1.67 (0.0015) | Kept: Ag ka scattering > 1.67 -> Ag ka scattering > -0.18 (0.0016)
# Removed: background1 <= -0.11 -> Ag ka scattering > 1.67 (0.0003) | Kept: Ag ka scattering > 1.67 -> background1 <= -0.11 (0.0006)
# Removed: background3 > -0.30 -> Ag ka scattering > -0.18 (0.0002) | Kept: Ag ka scattering > -0.18 -> background3 > -0.30 (0.0008)
# Removed: background3 > -0.30 -> background1 <= -1.03 (0.0003) | Kept: background1 <= -1.03 -> background3 > -0.30 (0.0011)
# Removed: Ag ka scattering > -0.18 -> background1 <= -1.03 (0.0008) | Kept: background1 <= -1.03 -> Ag ka scattering > -0.18 (0.0010)
# Removed: Ag ka scattering > -0.18 -> Cu ka <= -9.68 (0.0016) | Kept: Cu ka <= -9.68 -> Ag ka scattering > -0.18 (0.0024)
# Removed: Ag ka scattering > -1.65 -> Cu ka <= -9.68 (0.0012) | Kept: Cu ka <= -9.68 -> Ag ka scattering > -1.65 (0.0104)
# Removed: background3 > 1.29 -> Cu ka <= -9.68 (0.0001) | Kept: Cu ka <= -9.68 -> background3 > 1.29 (0.0022)
# Removed: background1 <= -0.11 -> Cu ka <= -9.68 (0.0003) | Kept: Cu ka <= -9.68 -> background1 <= -0.11 (0.0049)
# Removed: background1 <= -0.11 -> Ag ka scattering > -1.65 (0.0005) | Kept: Ag ka scattering > -1.65 -> background1 <= -0.11 (0.0034)
# Removed: background1 <= 2.08 -> Ag ka scattering > -1.65 (0.0002) | Kept: Ag ka scattering > -1.65 -> background1 <= 2.08 (0.0006)
# Removed: background3 > 1.29 -> background1 <= -0.11 (0.0001) | Kept: background1 <= -0.11 -> background3 > 1.29 (0.0011)
# Removed: background3 > 1.29 -> Ar ka + Ag L <= -0.29 (0.0001) | Kept: Ar ka + Ag L <= -0.29 -> background3 > 1.29 (0.0001)
# Removed: background3 > 1.29 -> background1 <= 2.08 (0.0001) | Kept: background1 <= 2.08 -> background3 > 1.29 (0.0002)
# Removed: Ar ka + Ag L <= -0.29 -> Cu ka <= -8.43 (0.0004) | Kept: Cu ka <= -8.43 -> Ar ka + Ag L <= -0.29 (0.0021)
# Removed: background1 <= 2.08 -> Cu ka <= -8.43 (0.0005) | Kept: Cu ka <= -8.43 -> background1 <= 2.08 (0.0041)
# Removed: Ca kb <= -6.07 -> Cu ka <= -8.43 (0.0017) | Kept: Cu ka <= -8.43 -> Ca kb <= -6.07 (0.0018)
# Removed: Fe ka > -23.71 -> Cu ka <= -8.43 (0.0017) | Kept: Cu ka <= -8.43 -> Fe ka > -23.71 (0.0019)
# Removed: Ar ka + Ag L <= -0.29 -> background1 <= 2.08 (0.0004) | Kept: background1 <= 2.08 -> Ar ka + Ag L <= -0.29 (0.0005)
# Removed: Zn kb <= -0.29 -> Fe ka > -23.71 (0.0002) | Kept: Fe ka > -23.71 -> Zn kb <= -0.29 (0.0038)
# Removed: Cu ka <= -3.28 -> Fe ka > -23.71 (0.0033) | Kept: Fe ka > -23.71 -> Cu ka <= -3.28 (0.0056)
# Removed: Ca kb <= -6.07 -> Fe ka > -23.71 (0.0017) | Kept: Fe ka > -23.71 -> Ca kb <= -6.07 (0.0036)
# Removed: Zn kb <= -0.29 -> Cu ka <= -3.28 (0.0002) | Kept: Cu ka <= -3.28 -> Zn kb <= -0.29 (0.0035)
# Removed: Zn kb <= -0.29 -> Fe kb > -7.02 (0.0002) | Kept: Fe kb > -7.02 -> Zn kb <= -0.29 (0.0018)
# Removed: Zn kb <= -0.29 -> Ca kb <= -6.07 (0.0001) | Kept: Ca kb <= -6.07 -> Zn kb <= -0.29 (0.0018)
# Removed: Ca kb <= -6.07 -> Cu ka <= -3.28 (0.0016) | Kept: Cu ka <= -3.28 -> Ca kb <= -6.07 (0.0018)
# Removed: Zn kb > -1.05 -> Cu ka <= -3.28 (0.0001) | Kept: Cu ka <= -3.28 -> Zn kb > -1.05 (0.0013)
# Removed: Ca kb <= -6.07 -> Fe kb > -7.02 (0.0032) | Kept: Fe kb > -7.02 -> Ca kb <= -6.07 (0.0053)
# Removed: Ar ka + Ag L <= 0.28 -> Fe kb > -7.02 (0.0001) | Kept: Fe kb > -7.02 -> Ar ka + Ag L <= 0.28 (0.0016)
# Removed: Ar ka + Ag L <= 0.28 -> Zn kb <= 0.29 (0.0001) | Kept: Zn kb <= 0.29 -> Ar ka + Ag L <= 0.28 (0.0002)
# Removed: Zn kb <= 0.29 -> Ar ka + Ag L <= 1.07 (0.0001) | Kept: Ar ka + Ag L <= 1.07 -> Zn kb <= 0.29 (0.0003)
# Removed: Zn kb <= 0.29 -> Ti kb > -2.91 (0.0002) | Kept: Ti kb > -2.91 -> Zn kb <= 0.29 (0.0012)
# Removed: Ar ka + Ag L <= 1.07 -> Fe ka > -24.15 (0.0002) | Kept: Fe ka > -24.15 -> Ar ka + Ag L <= 1.07 (0.0016)
# Removed: Ar ka + Ag L <= 1.07 -> Fe kb > -7.41 (0.0002) | Kept: Fe kb > -7.41 -> Ar ka + Ag L <= 1.07 (0.0016)
# Removed: Ar ka + Ag L <= 1.07 -> Ca kb <= -2.67 (0.0001) | Kept: Ca kb <= -2.67 -> Ar ka + Ag L <= 1.07 (0.0011)
# Removed: Zn kb > -1.05 -> Fe ka > -24.15 (0.0002) | Kept: Fe ka > -24.15 -> Zn kb > -1.05 (0.0031)
# Removed: Fe kb > -7.41 -> Fe ka > -24.15 (0.0015) | Kept: Fe ka > -24.15 -> Fe kb > -7.41 (0.0015)
# Removed: Zn kb > -1.05 -> Ti kb > -2.91 (0.0002) | Kept: Ti kb > -2.91 -> Zn kb > -1.05 (0.0013)
# Removed: Zn kb > -1.05 -> Fe kb > -7.41 (0.0001) | Kept: Fe kb > -7.41 -> Zn kb > -1.05 (0.0030)
# Removed: Ti kb > -2.91 -> Fe kb > -7.41 (0.0013) | Kept: Fe kb > -7.41 -> Ti kb > -2.91 (0.0014)
# Removed: Zn ka <= -0.78 -> Fe kb > -7.79 (0.0003) | Kept: Fe kb > -7.79 -> Zn ka <= -0.78 (0.0013)
# Removed: Zn kb > 0.29 -> Zn ka <= -0.78 (0.0001) | Kept: Zn ka <= -0.78 -> Zn kb > 0.29 (0.0005)
# Removed: Zn ka <= -0.78 -> Fe ka > -24.62 (0.0003) | Kept: Fe ka > -24.62 -> Zn ka <= -0.78 (0.0026)
# Removed: Zn kb <= 1.07 -> Ar ka + Ag L > -1.05 (0.0002) | Kept: Ar ka + Ag L > -1.05 -> Zn kb <= 1.07 (0.0002)
# Removed: Ar ka + Ag L > -1.05 -> Ti kb > 2.45 (0.0002) | Kept: Ti kb > 2.45 -> Ar ka + Ag L > -1.05 (0.0012)
# Removed: Ar ka + Ag L > -1.05 -> Fe kb > -7.79 (0.0001) | Kept: Fe kb > -7.79 -> Ar ka + Ag L > -1.05 (0.0013)
# Removed: Ar ka + Ag L > -1.05 -> Ca kb <= -2.67 (0.0001) | Kept: Ca kb <= -2.67 -> Ar ka + Ag L > -1.05 (0.0013)
# Removed: Ar ka + Ag L > -1.05 -> Fe ka > -24.62 (0.0002) | Kept: Fe ka > -24.62 -> Ar ka + Ag L > -1.05 (0.0014)
# Removed: Zn kb <= 1.07 -> Ti kb > 2.45 (0.0002) | Kept: Ti kb > 2.45 -> Zn kb <= 1.07 (0.0023)
# Removed: Ti kb > 2.45 -> Fe kb > -7.41 (0.0012) | Kept: Fe kb > -7.41 -> Ti kb > 2.45 (0.0029)
# Removed: Ti kb > 2.45 -> Fe kb > -7.79 (0.0011) | Kept: Fe kb > -7.79 -> Ti kb > 2.45 (0.0027)
# Removed: Zn kb > 0.29 -> Ca kb <= -2.67 (0.0001) | Kept: Ca kb <= -2.67 -> Zn kb > 0.29 (0.0012)
# Removed: Zn kb > 0.29 -> Cu kb <= -2.30 (0.0002) | Kept: Cu kb <= -2.30 -> Zn kb > 0.29 (0.0008)
# Removed: Ca kb <= -2.67 -> Fe kb > -7.79 (0.0013) | Kept: Fe kb > -7.79 -> Ca kb <= -2.67 (0.0027)
# Removed: Zn kb > -0.29 -> Zn ka <= 0.08 (0.0001) | Kept: Zn ka <= 0.08 -> Zn kb > -0.29 (0.0003)
# Removed: Ar ka + Ag L > 0.28 -> Zn ka <= 0.08 (0.0001) | Kept: Zn ka <= 0.08 -> Ar ka + Ag L > 0.28 (0.0005)
# Removed: Zn ka <= 0.08 -> Zn ka <= 1.38 (0.0007) | Kept: Zn ka <= 1.38 -> Zn ka <= 0.08 (0.0009)
# Removed: Zn kb > -0.29 -> Ca kb > -2.67 (0.0001) | Kept: Ca kb > -2.67 -> Zn kb > -0.29 (0.0023)
# Removed: Zn kb > -0.29 -> Cu kb <= -2.30 (0.0001) | Kept: Cu kb <= -2.30 -> Zn kb > -0.29 (0.0015)
# Removed: Zn kb > -0.29 -> Ca kb <= 12.61 (0.0001) | Kept: Ca kb <= 12.61 -> Zn kb > -0.29 (0.0011)
# Removed: Zn ka <= 1.38 -> background1 > -0.11 (0.0002) | Kept: background1 > -0.11 -> Zn ka <= 1.38 (0.0003)
# Removed: Ar ka + Ag L > -0.29 -> Zn ka <= 1.38 (0.0001) | Kept: Zn ka <= 1.38 -> Ar ka + Ag L > -0.29 (0.0002)
# Removed: Ar ka + Ag L > 0.28 -> Ca kb <= 12.61 (0.0002) | Kept: Ca kb <= 12.61 -> Ar ka + Ag L > 0.28 (0.0022)
# Removed: Ar ka + Ag L > 0.28 -> background1 > -0.11 (0.0001) | Kept: background1 > -0.11 -> Ar ka + Ag L > 0.28 (0.0001)
# Removed: Cu kb <= -2.30 -> Ca kb <= 12.61 (0.0008) | Kept: Ca kb <= 12.61 -> Cu kb <= -2.30 (0.0010)
# Removed: Ca kb > -2.67 -> Ca kb <= 12.61 (0.0012) | Kept: Ca kb <= 12.61 -> Ca kb > -2.67 (0.0021)
# Removed: Ca kb > -2.67 -> Cu kb <= -2.30 (0.0010) | Kept: Cu kb <= -2.30 -> Ca kb > -2.67 (0.0016)
# Removed: Ar ka + Ag L > -0.29 -> background1 > -0.11 (0.0001) | Kept: background1 > -0.11 -> Ar ka + Ag L > -0.29 (0.0002)
# Removed: Ar ka + Ag L > -0.29 -> Fe ka <= -24.15 (0.0001) | Kept: Fe ka <= -24.15 -> Ar ka + Ag L > -0.29 (0.0010)
# Removed: Ar ka + Ag L > -0.29 -> background1 > -1.87 (0.0001) | Kept: background1 > -1.87 -> Ar ka + Ag L > -0.29 (0.0001)
# Removed: background1 > -1.87 -> background1 > -0.11 (0.0001) | Kept: background1 > -0.11 -> background1 > -1.87 (0.0001)
# Removed: background1 > -1.03 -> background1 > -1.87 (0.0001) | Kept: background1 > -1.87 -> background1 > -1.03 (0.0001)
# Removed: background1 > -1.87 -> Zn ka > -1.75 (0.0002) | Kept: Zn ka > -1.75 -> background1 > -1.87 (0.0004)
# Removed: background1 > -1.87 -> Ca kb > -6.07 (0.0001) | Kept: Ca kb > -6.07 -> background1 > -1.87 (0.0009)
# Removed: background1 > -1.03 -> Fe ka <= -23.71 (0.0003) | Kept: Fe ka <= -23.71 -> background1 > -1.03 (0.0010)
# Removed: background1 > -1.03 -> Cu kb <= -1.61 (0.0001) | Kept: Cu kb <= -1.61 -> background1 > -1.03 (0.0007)
# Removed: Zn ka > -1.75 -> Zn ka > 0.08 (0.0002) | Kept: Zn ka > 0.08 -> Zn ka > -1.75 (0.0002)
# Removed: Cu kb <= -1.61 -> Fe ka <= -24.15 (0.0007) | Kept: Fe ka <= -24.15 -> Cu kb <= -1.61 (0.0019)
# Removed: Cu kb <= -1.61 -> Ca kb > -8.59 (0.0007) | Kept: Ca kb > -8.59 -> Cu kb <= -1.61 (0.0027)
# Removed: Ca kb > -6.07 -> Fe ka <= -23.71 (0.0008) | Kept: Fe ka <= -23.71 -> Ca kb > -6.07 (0.0010)
# Removed: Zn ka > 0.08 -> Cu kb <= 0.18 (0.0004) | Kept: Cu kb <= 0.18 -> Zn ka > 0.08 (0.0006)
# Removed: Zn ka > -0.78 -> Zn ka > 0.08 (0.0002) | Kept: Zn ka > 0.08 -> Zn ka > -0.78 (0.0006)
# Removed: Fe kb <= -7.02 -> Cu kb <= 0.18 (0.0009) | Kept: Cu kb <= 0.18 -> Fe kb <= -7.02 (0.0018)
# Removed: Ca kb > -6.07 -> Cu kb <= 0.18 (0.0009) | Kept: Cu kb <= 0.18 -> Ca kb > -6.07 (0.0012)
# Removed: background2 > 0.27 -> Cu kb <= 0.18 (0.0001) | Kept: Cu kb <= 0.18 -> background2 > 0.27 (0.0006)
# Removed: background2 > -0.37 -> Zn ka > -0.78 (0.0002) | Kept: Zn ka > -0.78 -> background2 > -0.37 (0.0004)
# Removed: background2 > -0.37 -> Fe kb <= -6.37 (0.0001) | Kept: Fe kb <= -6.37 -> background2 > -0.37 (0.0008)
# Removed: background2 > -0.37 -> Fe kb <= -7.41 (0.0001) | Kept: Fe kb <= -7.41 -> background2 > -0.37 (0.0008)
# Removed: background2 > 0.27 -> background2 > -0.37 (0.0001) | Kept: background2 > -0.37 -> background2 > 0.27 (0.0001)
# Removed: background2 > -0.92 -> background2 > 0.27 (0.0001) | Kept: background2 > 0.27 -> background2 > -0.92 (0.0001)
# Removed: Ca kb > -6.07 -> Fe ka <= -22.90 (0.0008) | Kept: Fe ka <= -22.90 -> Ca kb > -6.07 (0.0009)
# Removed: background2 > -0.92 -> Fe ka <= -22.90 (0.0001) | Kept: Fe ka <= -22.90 -> background2 > -0.92 (0.0007)
# Removed: background2 > -0.92 -> background2 <= 0.98 (0.0001) | Kept: background2 <= 0.98 -> background2 > -0.92 (0.0002)
# Removed: background2 > -0.92 -> Cu kb > -2.88 (0.0001) | Kept: Cu kb > -2.88 -> background2 > -0.92 (0.0010)
# Removed: background2 <= -0.37 -> background2 > -0.92 (0.0001) | Kept: background2 > -0.92 -> background2 <= -0.37 (0.0001)
# Removed: background2 > -0.92 -> Fe kb <= -7.41 (0.0001) | Kept: Fe kb <= -7.41 -> background2 > -0.92 (0.0008)
# Removed: background2 <= 0.98 -> Fe kb <= -7.41 (0.0002) | Kept: Fe kb <= -7.41 -> background2 <= 0.98 (0.0016)
# Removed: background2 <= -0.37 -> Cu kb > -2.88 (0.0001) | Kept: Cu kb > -2.88 -> background2 <= -0.37 (0.0005)
# Removed: background2 <= 0.27 -> Cu kb > -2.88 (0.0002) | Kept: Cu kb > -2.88 -> background2 <= 0.27 (0.0005)
# Removed: Cu kb > -2.88 -> Cu kb > -1.61 (0.0005) | Kept: Cu kb > -1.61 -> Cu kb > -2.88 (0.0010)
# Removed: background2 <= -0.37 -> Cu kb > -1.61 (0.0002) | Kept: Cu kb > -1.61 -> background2 <= -0.37 (0.0010)
# Removed: background2 <= -0.37 -> Cu kb > -2.30 (0.0002) | Kept: Cu kb > -2.30 -> background2 <= -0.37 (0.0009)
#
# ======================================================================
# CONSTRUCTED GRAPH SUMMARY
# ======================================================================
# Initial edges: 532 | Removed: 127
# Predicate nodes: 90
# Metric: Perturbation
# Weighting by explained variance: ENABLED
#
# Processing graph LRC...
#
# Processing graph LRC...
#
# Processing graph LRC...
#
# Processing graph LRC...
#    Predicate_pert_Seed_0 Predicate_pert_Seed_1 Predicate_pert_Seed_2  \
# 0          Ca ka > -6.65         Ca ka > -6.65         Ca ka > -6.65
# 1         Ti ka <= -4.69        Ti ka <= -4.69        Ti ka <= -4.69
# 2          Ti ka <= 9.34        Ca ka > -21.19         Ti ka <= 9.34
# 3         Ca ka > -26.11         Ti ka <= 9.34        Ca ka > -21.19
# 4         Ca ka > -21.19        Ca ka > -26.11        Ca ka > -26.11
# ..                   ...                   ...                   ...
# 87         Cu kb > -2.30         Cu kb > -2.30          Zn kb > 0.29
# 88   background2 <= 0.27   background2 <= 0.27         Cu kb > -2.30
# 89  background2 <= -0.37   background2 > -0.92  background2 <= -0.37
# 90               Class_A               Class_A               Class_A
# 91               Class_B               Class_B               Class_B
#
#    Predicate_pert_Seed_3
# 0          Ca ka > -6.65
# 1         Ti ka <= -4.69
# 2          Ti ka <= 9.34
# 3         Ca ka > -26.11
# 4         Ca ka > -21.19
# ..                   ...
# 87   background2 > -0.37
# 88         Cu kb > -2.30
# 89  background2 <= -0.37
# 90               Class_A
# 91               Class_B
#
# [92 rows x 4 columns]

# %%
all_results_pert[0]['pert_results_dict']['Bag_1']
# Out:
#                Predicate  Perturbation
# 0          Ca ka > -6.65      0.060982
# 1         Ti ka <= -4.69      0.060808
# 2          Ti ka <= 9.34      0.042351
# 3         Ca ka > -21.19      0.040061
# 4         Ti ka <= 19.85      0.032945
# ..                   ...           ...
# 85         Cu kb > -1.61      0.000779
# 86         Cu kb > -2.88      0.000747
# 87   background2 <= 0.27      0.000736
# 88         Cu kb > -2.30      0.000709
# 89  background2 <= -0.37      0.000667
#
# [90 rows x 2 columns]

# %%
# Somar LRCs de predicados equivalentes entre diferentes seeds
lrc_combined_list = []

for seed in random_seeds:
    lrc_df = lrc_pert_by_seed[seed].copy()
    lrc_combined_list.append(lrc_df) # o append adiciona o dataframe ao final da lista

# Concatenar todos os dataframes
lrc_all_seeds = pd.concat(lrc_combined_list, ignore_index=True) 

# Agrupar por predicado (Node) e somar as LRCs, mantendo Zone, Threshold e Operator
lrc_summed_df_pert = lrc_all_seeds.groupby('Node').agg({ # o .agg pode ser usado para aplicar múltiplas funções de agregação
    'Local_Reaching_Centrality': 'mean', # sum = somando as LRCs, poderia ser média ou outro agregado
    'Zone': 'first',
    'Threshold': 'first',
    'Operator': 'first'
}).reset_index()

# Ordenar pelo valor de LRC somado (maior para menor)
lrc_summed_df_pert = lrc_summed_df_pert.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
# vamoss pegar so os valore sunicos de lrc_summed_df baseado na zona espectral
lrc_summed_unique_df_pert = lrc_summed_df_pert.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
lrc_summed_unique_df_pert = lrc_summed_unique_df_pert.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
lrc_summed_unique_df_pert
# Out:
#                          Node  Local_Reaching_Centrality              Zone  \
# 0               Ca ka > -6.65                  10.655246             Ca ka
# 1              Ti ka <= -4.69                   7.334458             Ti ka
# 2        background3 <= -0.30                   2.112321       background3
# 3               Cu ka > -8.43                   2.080085             Cu ka
# 4   Ag ka scattering <= -0.18                   1.706129  Ag ka scattering
# 5              Ti kb <= -2.91                   1.337856             Ti kb
# 6        background1 <= -1.03                   0.203091       background1
# 7              Fe ka > -23.71                   0.201094             Fe ka
# 8               Fe kb > -7.02                   0.193328             Fe kb
# 9              Ca kb <= -6.07                   0.182308             Ca kb
# 10             Zn kb <= -0.29                   0.145015             Zn kb
# 11      Ar ka + Ag L <= -0.29                   0.138472      Ar ka + Ag L
# 12             Cu kb <= -2.30                   0.113720             Cu kb
# 13             Zn ka <= -0.78                   0.097402             Zn ka
# 14         background2 > 0.27                   0.088469       background2
# 15                    Class_A                   0.000000              None
#
#    Threshold Operator
# 0      -6.65        >
# 1      -4.69       <=
# 2      -0.30       <=
# 3      -8.43        >
# 4      -0.18       <=
# 5      -2.91       <=
# 6      -1.03       <=
# 7     -23.71        >
# 8      -7.02        >
# 9      -6.07       <=
# 10     -0.29       <=
# 11     -0.29       <=
# 12     -2.30       <=
# 13     -0.78       <=
# 14      0.27        >
# 15      None     None

# %%
# Aplicar o mapeamento
lrc_summed_df_pert_natural = exp.map_thresholds_to_natural(
    lrc_df=lrc_summed_df_pert,
    zone_sums_preprocessed=zone_scores_df,
    zone_sums_natural=zones_original[0]
)

lrc_summed_df_pert_natural
# Out:
#                     Node  Local_Reaching_Centrality         Zone Threshold  \
# 0          Ca ka > -6.65                  10.655246        Ca ka     -6.65
# 1         Ti ka <= -4.69                   7.334458        Ti ka     -4.69
# 2          Ti ka <= 9.34                   5.280687        Ti ka      9.34
# 3         Ca ka > -21.19                   4.919432        Ca ka    -21.19
# 4         Ca ka > -26.11                   3.974427        Ca ka    -26.11
# ..                   ...                        ...          ...       ...
# 87   background2 <= 0.27                   0.071704  background2      0.27
# 88         Cu kb > -2.30                   0.041151        Cu kb     -2.30
# 89  background2 <= -0.37                   0.019814  background2     -0.37
# 90               Class_A                   0.000000         None      None
# 91               Class_B                   0.000000         None      None
#
#    Operator  Threshold_Natural  Reference_Sample_Index  Approximation_Error  \
# 0         >         -72.180511                   102.0             0.000511
# 1        <=         -49.917691                    64.0             0.070519
# 2        <=         101.580304                    11.0             0.037350
# 3         >        -238.439137                   152.0             0.149595
# 4         >        -287.239935                   110.0             0.000994
# ..      ...                ...                     ...                  ...
# 87       <=           0.811175                    47.0             0.000881
# 88        >          -8.474542                   221.0             0.000430
# 89       <=          -1.184782                   277.0             0.010577
# 90     None                NaN                     NaN                  NaN
# 91     None                NaN                     NaN                  NaN
#
#                 Node_Natural
# 0         Ca ka > -72.180511
# 1        Ti ka <= -49.917691
# 2        Ti ka <= 101.580304
# 3        Ca ka > -238.439137
# 4        Ca ka > -287.239935
# ..                       ...
# 87   background2 <= 0.811175
# 88         Cu kb > -8.474542
# 89  background2 <= -1.184782
# 90                      None
# 91                      None
#
# [92 rows x 9 columns]

# %%
import plotly.graph_objects as go

n = 0
zone_name = lrc_summed_df_pert_natural.iloc[n]['Zone'] # o n indica a linha do dataframe lrc_summed_df_pert_natural que queremos acessar para pegar o nome da zona espectral (coluna 'Zone')
threshold_score = float(lrc_summed_df_pert_natural.iloc[n]['Threshold_Natural']) # o iloc acessa a linha n e a coluna 'Threshold_Natural' para pegar o valor do threshold já mapeado para o espaço natural (não pré-processado)

# Usar pca_info_dict dos dados ORIGINAIS (zones_original[1])
pca_info_dict_original = zones_original[1]

# Reconstrução: τ = mean + threshold * loadings (no espaço original)
threshold_spectrum = exp.reconstruct_threshold_to_spectrum(
    threshold_value=threshold_score,
    zone_name=zone_name,
    pca_info_dict=pca_info_dict_original
)
print(f"\nEspectro de threshold reconstruído para zona '{zone_name}':")
print(f"  - Dimensão: {len(threshold_spectrum)} variáveis espectrais")
#print(f"  - Range de energias: {threshold_spectrum.index[n]} - {threshold_spectrum.index[-1]}")
print(f"  - Variância explicada pela PC1: {pca_info_dict_original[zone_name]['variance_explained']:.2%}")

# Usar dados ORIGINAIS para plotar (spectral_zones_original)
zone_df = spectral_zones_original[zone_name]

# Plotar zona com threshold (inline)
fig = go.Figure()
x_values = pd.to_numeric(zone_df.columns, errors='coerce')

# Plotar espectros das amostras coloridas por classe
colors = {'A': 'gold', 'B': 'blue'}
for idx, row in zone_df.iterrows():
    class_label = ycalclass.iloc[idx] if idx < len(ycalclass) else 'Unknown'
    fig.add_trace(go.Scatter(
        x=x_values,
        y=row.values,
        mode='lines',
        line=dict(color=colors.get(class_label, 'rgba(128,128,128,0.3)'), width=0.5),
        name=f'Class {class_label}',
        showlegend=False,
        hoverinfo='skip'
    ))

# Plotar espectro de threshold (destaque)
fig.add_trace(go.Scatter(
    x=x_values,
    y=threshold_spectrum.values,
    mode='lines',
    line=dict(color='red', width=4, dash='dash'),
    name=f'Threshold Spectrum ({threshold_spectrum.name})'
))

# Layout do gráfico
fig.update_layout(
    title=f"Zona '{zone_name}' com Threshold Multivariado (Predicado: {lrc_summed_df_pert_natural.iloc[n]['Node_Natural']})",
    xaxis_title='Energia / Comprimento de Onda',
    yaxis_title='Intensidade',
    template='plotly_white',
    showlegend=True,
    legend=dict(yanchor="top", y=0.99, xanchor="left", x=0.01)
)

fig.show()
# Out:
# Espectro de threshold reconstruído para zona 'Ca ka':
#   - Dimensão: 17 variáveis espectrais
#   - Variância explicada pela PC1: 99.20%

# %%
# Permutation importance baseado em mudança nas probabilidades previstas (predict_proba)
# Medimos a média da diferença absoluta entre as probabilidades originais e as probabilidades
# obtidas após permutar cada variável. Isso fornece uma métrica contínua de importância.
n_repeats = 10
rng = np.random.RandomState(42)
# Probabilidades base (classe 'B' mapeada para 1)
baseline_proba = mlp_model[3].predict_proba(Xcalclass_prep)[:, 1]
importance_list = []
X_arr = Xcalclass_prep.copy()
for col in Xcalclass_prep.columns:
    diffs = []
    for _ in range(n_repeats):
        X_perm = X_arr.copy()
        X_perm[col] = rng.permutation(X_perm[col].values)
        perm_proba = mlp_model[3].predict_proba(X_perm)[:, 1]
        diffs.append(np.mean(np.abs(baseline_proba - perm_proba)))
    importance_list.append(np.mean(diffs))

permutation_df = pd.DataFrame({
    'energy': Xcalclass_prep.columns,
    'Permutation_importance_proba': importance_list
})
permutation_df.sort_values(by='Permutation_importance_proba', ascending=False, inplace=True)
energy_to_zone_vip = {}
for zone_name, start, end in spectral_cuts:
    for e in permutation_df['energy']:
        ef = float(e)
        if start <= ef <= end:
            energy_to_zone_vip[e] = zone_name
permutation_df['Zone'] = permutation_df['energy'].map(energy_to_zone_vip)
permutation_unique_df = permutation_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
permutation_unique_df = permutation_unique_df.sort_values(by='Permutation_importance_proba', ascending=False)
permutation_unique_df
# Out:
#    energy  Permutation_importance_proba              Zone
# 0    6.38                      0.018148             Fe ka
# 1    3.73                      0.005747             Ca ka
# 2    4.49                      0.004113             Ti ka
# 3    8.06                      0.002176             Cu ka
# 4    7.07                      0.001709             Fe kb
# 5    4.88                      0.001061             Ti kb
# 6    4.06                      0.001044             Ca kb
# 7   22.28                      0.000854  Ag ka scattering
# 8    8.98                      0.000675             Cu kb
# 9   12.75                      0.000597       background3
# 10   8.65                      0.000506             Zn ka
# 11   5.92                      0.000416       background1
# 12   9.36                      0.000404             Zn kb
# 13   2.79                      0.000386      Ar ka + Ag L
# 14   7.35                      0.000294       background2
# 15   2.74                      0.000216               NaN

# %%
import numpy as np

max_len = max(
    len(shap_unique_df['Zone']),
    len(permutation_unique_df['Zone']),
    len(lrc_summed_unique_df_pert['Zone']),
    len(lrc_summed_unique_df_cov['Zone'])
)

def pad_list(lst, length):
    return list(lst) + [None] * (length - len(lst))

features_importance = pd.DataFrame({
    'Shap': pad_list(shap_unique_df['Zone'], max_len),
    'Permutation' : pad_list(permutation_unique_df['Zone'], max_len),
    'LRC_perturbation' : pad_list(lrc_summed_unique_df_pert['Zone'], max_len),
    'LRC_covariance' : pad_list(lrc_summed_unique_df_cov['Zone'], max_len),
})

features_importance.to_csv('feature_importance.csv', index=False, sep=';')
features_importance
# Out:
#                 Shap       Permutation  LRC_perturbation    LRC_covariance
# 0              Ca ka             Fe ka             Ca ka             Fe ka
# 1              Ti ka             Ca ka             Ti ka             Ca ka
# 2              Fe ka             Ti ka       background3             Fe kb
# 3              Cu ka             Cu ka             Cu ka             Ti ka
# 4              Ti kb             Fe kb  Ag ka scattering             Ca kb
# 5              Fe kb             Ti kb             Ti kb             Cu ka
# 6   Ag ka scattering             Ca kb       background1             Ti kb
# 7              Ca kb  Ag ka scattering             Fe ka             Cu kb
# 8        background3             Cu kb             Fe kb  Ag ka scattering
# 9              Zn kb       background3             Ca kb       background3
# 10             Cu kb             Zn ka             Zn kb             Zn ka
# 11       background1       background1      Ar ka + Ag L       background1
# 12             Zn ka             Zn kb             Cu kb       background2
# 13       background2      Ar ka + Ag L             Zn ka             Zn kb
# 14      Ar ka + Ag L       background2       background2      Ar ka + Ag L
# 15               NaN               NaN              None              None

# %%
import rbo
rbo_comparison = pd.DataFrame(columns=['Method_1', 'Method_2', 'RBO_Score'])
methods = features_importance.columns.tolist()
for i in range(len(methods)):
    for j in range(i + 1, len(methods)):
        method_1 = methods[i]
        method_2 = methods[j]
        # Remove None values from the lists
        list_1 = [x for x in features_importance[method_1].tolist() if x is not None]
        list_2 = [x for x in features_importance[method_2].tolist() if x is not None]
        # Truncate both lists to the same length (minimum of both)
        min_len = min(len(list_1), len(list_2))
        list_1_trunc = list_1[:min_len]
        list_2_trunc = list_2[:min_len]
        rbo_score = rbo.RankingSimilarity(list_1_trunc, list_2_trunc).rbo(p=0.7, k=10)
        rbo_comparison = pd.concat([rbo_comparison, pd.DataFrame({
            'Method_1': [method_1],
            'Method_2': [method_2],
            'RBO_Score': [rbo_score]
        })], ignore_index=True)
rbo_comparison.sort_values(by='RBO_Score', ascending=False, inplace=True)
rbo_comparison.to_csv('rbo_rank.csv', index=False, sep=';')
rbo_comparison
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_5908\3097109587.py:16: FutureWarning:
#
# The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#            Method_1          Method_2  RBO_Score
# 4       Permutation    LRC_covariance   0.871130
# 1              Shap  LRC_perturbation   0.832015
# 0              Shap       Permutation   0.544172
# 2              Shap    LRC_covariance   0.443549
# 3       Permutation  LRC_perturbation   0.420052
# 5  LRC_perturbation    LRC_covariance   0.319429

# %%
lrc_summed_df_cov_natural.to_csv('lrc_cov_natural.csv', index=False, sep=';')
lrc_summed_df_pert_natural.to_csv('lrc_pert_natural.csv', index=False, sep=';')
