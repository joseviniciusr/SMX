# %%
# Importing the necessary libraries
import pandas as pd
import numpy as np
import kennard_stone as ks
pd.options.plotting.backend = 'plotly'  # setting plotly as the backend for pandas plotting

# Add parent directory to sys.path so local module 'synthetic' can be imported
import sys
from pathlib import Path # for path manipulations
# Move three levels up from current working directory to reach workspace root
workspace_root = Path.cwd().parent.parent.parent.resolve() 
smx_dir = workspace_root / 'smx'  # Path to smx folder
if str(smx_dir) not in sys.path: # check to avoid duplicates
    sys.path.insert(0, str(smx_dir)) # insert at the start of sys.path to prioritize local modules

# Loading a soil spectral dataset based on X-ray fluorescence (XRF)
data_complete = pd.read_csv(f'{workspace_root}/real_datasets/xrf/tomato.csv', sep=';') # local copy of Toledo 2022 dataset (os ... indica para omitir o caminho longo)
data = data_complete.loc[:, '2.12':'23.08']

# Split dataset by class and create calibration/prediction sets using Kennard-Stone (as in original pipeline)
data_A = data_complete[data_complete['Class'] == 'A'].reset_index(drop=True)
data_B = data_complete[data_complete['Class'] == 'B'].reset_index(drop=True)

# splitting the data into calibration and prediction sets by kennard-stone algorithm
XA_cal, XA_pred = ks.train_test_split(data_A.loc[:, '2.12':'23.08'], test_size=0.30)  # class A
XA_cal = XA_cal.reset_index(drop=True)
XA_pred = XA_pred.reset_index(drop=True)

XB_cal, XB_pred = ks.train_test_split(data_B.loc[:, '2.12':'23.08'], test_size=0.30)  # class B
XB_cal = XB_cal.reset_index(drop=True)
XB_pred = XB_pred.reset_index(drop=True)

Xcalclass = pd.concat([XA_cal, XB_cal], axis=0).reset_index(drop=True)  # concatenating both classes
Xpredclass = pd.concat([XA_pred, XB_pred], axis=0).reset_index(drop=True)
ycalclass = pd.Series(['A']*XA_cal.shape[0] + ['B']*XB_cal.shape[0])  # target for calibration set
ypredclass = pd.Series(['A']*XA_pred.shape[0] + ['B']*XB_pred.shape[0])  # target for prediction set

# preprocessings
import preprocessings as prepr  # preprocessing methods for XRF data

Xcalclass_prep, mean_calclass, mean_calclass_poisson  = prepr.poisson(Xcalclass, mc=True)
Xpredclass_prep = ((Xpredclass/np.sqrt(mean_calclass)) - mean_calclass_poisson)
# Out:
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-02-27 09:58:31,796 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-02-27 09:58:31,800 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-02-27 09:58:31,819 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-02-27 09:58:31,823 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
from modeling import mlp_optimized

mlp_model = mlp_optimized(Xcalclass_prep, ycalclass, Xpredclass_prep, ypredclass, 
                          aim='classification', 
                          hidden_layer_sizes=(64,32),
                          activation='tanh',
                          learning_rate='adaptive',
                          max_iter=10,
                          random_state=1)
mlp_model[0]
# Out:
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (10) reached and the optimization hasn't converged yet.
#   warnings.warn(
#   Model  Accuracy Cal  Sensitivity Cal  Specificity Cal              CM Cal  \
# 0   MLP      0.777778         0.818182         0.714286  [[10, 4], [4, 18]]
#
#    Accuracy Pred  Sensitivity Pred  Specificity Pred           CM Pred
# 0          0.625               0.9          0.166667  [[1, 5], [1, 9]]

# %% [markdown]
# ## Definição das Zonas Espectrais

# %%
spectral_cuts = [
('S', 2.12, 2.4),
('Cl', 2.4, 3.04),
('K ka', 3.0, 3.44),
('K kb + Ca ka', 3.44, 3.84),
('background1', 3.84, 5.7),
('Mn', 5.7, 6.04),
('Fe', 6.04, 7.3),
('Cu', 7.3, 8.32),
('Zn', 8.32, 8.84),
('background2', 8.84, 11.56),
('Br ka', 11.56, 12.5),
('Rb ka + Br kb', 12.5, 13.8),
('background3', 13.8, 17.0),
('Rh ka Compton', 17.0, 19.9),
('Rh ka Rayleigh', 19.9, 20.8),
('Rh kb Compton', 20.8, 22.3),
('Rh kb Rayleigh', 22.3, 23.08)
]

# %% [markdown]
# ## SHAP

# %%
shap_global_importance = pd.read_csv('shap_tomato.csv', sep=';') # loading previously saved shap_unique_df
# vamos gerar uma nova coluna em shap_global_importance com o nome da zona espectral correspondente de acordo com a lista spectral_cuts
energy_to_zone_shap = {}
for zone_name, start, end in spectral_cuts:
    for i in shap_global_importance['energy']:
        i_float = float(i)
        if start <= i_float <= end:
            energy_to_zone_shap[i] = zone_name
shap_global_importance['Zone'] = shap_global_importance['energy'].map(energy_to_zone_shap)

# agora vamos filtrar shap_global_importance para manter apenas as zonas espectrais únicas com maior SHAP score
shap_unique_df = shap_global_importance.sort_values(by='Mean_Abs_SHAP', ascending=False).reset_index(drop=True)
shap_unique_df = shap_unique_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
shap_unique_df
# Out:
#     energy  Mean_Abs_SHAP            Zone
# 0    13.42       0.007621   Rb ka + Br kb
# 1     3.34       0.005800            K ka
# 2    19.18       0.004615   Rh ka Compton
# 3     2.58       0.003643              Cl
# 4    20.28       0.002579  Rh ka Rayleigh
# 5     3.70       0.002521    K kb + Ca ka
# 6    21.00       0.001957   Rh kb Compton
# 7    15.00       0.001146     background3
# 8     2.30       0.001020               S
# 9    12.26       0.000914           Br ka
# 10    8.06       0.000860              Cu
# 11    7.00       0.000625              Fe
# 12    5.74       0.000560              Mn
# 13   11.14       0.000445     background2
# 14    4.84       0.000393     background1
# 15    8.70       0.000375              Zn
# 16   22.48       0.000355  Rh kb Rayleigh

# %% [markdown]
# ## Funções de Agregação por PCA
#
# Aqui implementamos as funções para agregar zonas espectrais usando PCA com 1 componente principal.

# %%
import explaining as exp

# Extração das zonas espectrais
spectral_zones_class = exp.extract_spectral_zones(Xcalclass_prep, spectral_cuts)
zone_scores_df, pca_info_dict = exp.aggregate_spectral_zones_pca(spectral_zones_class) # apca aggregation
print(f"\nScores DataFrame shape: {zone_scores_df.shape}")
# Out:
# Zone 'S': VE = 52.67%, dim = 15 variables
# Zone 'Cl': VE = 79.94%, dim = 33 variables
# Zone 'K ka': VE = 98.21%, dim = 23 variables
# Zone 'K kb + Ca ka': VE = 63.19%, dim = 21 variables
# Zone 'background1': VE = 17.34%, dim = 94 variables
# Zone 'Mn': VE = 56.93%, dim = 18 variables
# Zone 'Fe': VE = 57.33%, dim = 64 variables
# Zone 'Cu': VE = 53.40%, dim = 52 variables
# Zone 'Zn': VE = 60.08%, dim = 27 variables
# Zone 'background2': VE = 68.69%, dim = 137 variables
# Zone 'Br ka': VE = 65.01%, dim = 48 variables
# Zone 'Rb ka + Br kb': VE = 74.53%, dim = 66 variables
# Zone 'background3': VE = 70.02%, dim = 161 variables
# Zone 'Rh ka Compton': VE = 88.63%, dim = 146 variables
# Zone 'Rh ka Rayleigh': VE = 82.31%, dim = 46 variables
# Zone 'Rh kb Compton': VE = 81.75%, dim = 76 variables
# Zone 'Rh kb Rayleigh': VE = 69.11%, dim = 40 variables
#
# Scores DataFrame shape: (36, 17)

# %%
y_pred = mlp_model[4]['MLP'].values # using the continuous predictions from SVM, extracting as 1D array
predicates_quantiles = exp.predicates_by_quantiles(zone_scores_df, [0.2, 0.4, 0.6, 0.8])
predicate_info_dict = exp.create_predicate_info_dict(
    predicates_df=predicates_quantiles[0],
    predicate_indicator_df=predicates_quantiles[1],
    zone_aggregated_df=zone_scores_df,
    y_predicted_numeric=y_pred
)

# %%
import explaining as exp

# LISTA DE SEMENTES A TESTAR
random_seeds = [0, 1, 2, 3]

all_results_cov = {}
training_samples = len(Xcalclass)

# LOOP: PROCESSAR CADA SEMENTE

y_pred = pd.Series(mlp_model[4]['MLP'].values) # using the continuous predictions from SVM, extracting as 1D array

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando semente: {seed}")
    print(f"{'='*70}\n")
    # Bagging
    bags_result_seed = exp.bagging_predicates(
        zone_sums_df=zone_scores_df,
        y_predicted_numeric=y_pred,
        predicates_df=predicates_quantiles[0],
        n_bags=10,
        #n_predicates_per_bag=40,
        n_samples_per_bag=int(training_samples*0.8), # 80 % da base para amostrar (convertido para int)
        min_samples_per_predicate=int(training_samples*0.2), # 20 % da base para limitar (convertido para int)
        replace=False,
        sample_bagging=True,
        predicate_bagging=False,
        random_seed=seed
    )
    
    # Inserir classe prevista
    for bag_name, pred_dict in bags_result_seed.items(): # iterando sobre cada bag
        for pred_rule, df_info in pred_dict.items():
            df_info['Class_Predicted'] = np.where(df_info['Predicted_Y'] >= 0.5, 'A', 'B') # binarizando com threshold 0.5, A = eut, B = dist
    
    # Calcular MI
    cov_results_dict_seed = exp.calculate_predicate_metrics(
        bags_result=bags_result_seed,
        metric='covariance', # covariance ou mutual_information
        threshold=0.01, # threshold para cortar predicados irrelevantes
        n_neighbors=5
    )
    
    # Salvar no dicionário principal
    all_results_cov[seed] = {
        'bags_result': bags_result_seed,
        'cov_results_dict': cov_results_dict_seed
    }

# CONSTRUÇÃO DE GRAFOS PARA MÚLTIPLAS SEMENTES (LOOP EXTERNO)
# Dicionário para armazenar grafos
graphs_by_seed = {}

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando Grafo - Semente: {seed}")
    print(f"{'='*70}\n")
    
    # Construir grafo para esta semente (sem predicates_df - extraído da regra)
    DG = exp.build_predicate_graph(
        bags_result=all_results_cov[seed]['bags_result'],
        predicate_ranking_dict=all_results_cov[seed]['cov_results_dict'],
        metric_column='Covariance',
        random_state=seed,
        show_details=True,
        var_exp=True,
        pca_info_dict=pca_info_dict
    )
    # Armazenar grafo
    graphs_by_seed[seed] = DG

# Calcular LRC usando a função pronta do explaining.py
lrc_cov_by_seed = {}
for seed in random_seeds:
    DG = graphs_by_seed[seed]
    lrc_cov_df_seed = exp.calculate_lrc_single_graph(DG, predicates_quantiles[0])
    lrc_cov_df_seed['Seed'] = seed  # Adicionar coluna com a semente
    lrc_cov_by_seed[seed] = lrc_cov_df_seed

# junando todas as colunas 'Node' de lrc_by_seed em um único dataframe
lrc_cov_all_seeds_df = pd.DataFrame()
for seed in random_seeds:
    lrc_cov_df_seed = lrc_cov_by_seed[seed].rename(columns={'Node': f'Predicate_Cov_Seed_{seed}'})
    lrc_cov_all_seeds_df = pd.concat([lrc_cov_all_seeds_df, lrc_cov_df_seed[[f'Predicate_Cov_Seed_{seed}']]], axis=1)

# vamos filtrar lrc_by_seed em cada semente para manter apenas as zonas espectrais únicas com maior LRC em um mesmo dataframe
lrc_cov_unique_by_seed = {}
for seed, lrc_df in lrc_cov_by_seed.items():
    lrc_cov_unique_df = lrc_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
    lrc_cov_unique_df = lrc_cov_unique_df.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
    lrc_cov_unique_by_seed[seed] = lrc_cov_unique_df

lrc_cov_all_seeds_df # exibindo o dataframe consolidado com predicados de todas as sementes
# Out:
# ======================================================================
# Processando semente: 0
# ======================================================================
#
# Bag_1 | Samples: Yes | Predicates: No (All) | Valid: 110 | Discarded: 26
# Bag_2 | Samples: Yes | Predicates: No (All) | Valid: 110 | Discarded: 26
# Bag_3 | Samples: Yes | Predicates: No (All) | Valid: 113 | Discarded: 23
# Bag_4 | Samples: Yes | Predicates: No (All) | Valid: 108 | Discarded: 28
# Bag_5 | Samples: Yes | Predicates: No (All) | Valid: 107 | Discarded: 29
# Bag_6 | Samples: Yes | Predicates: No (All) | Valid: 106 | Discarded: 30
# Bag_7 | Samples: Yes | Predicates: No (All) | Valid: 116 | Discarded: 20
# Bag_8 | Samples: Yes | Predicates: No (All) | Valid: 119 | Discarded: 17
# Bag_9 | Samples: Yes | Predicates: No (All) | Valid: 112 | Discarded: 24
# Bag_10 | Samples: Yes | Predicates: No (All) | Valid: 110 | Discarded: 26
# Computing Covariance for Predicates
# Metric: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando semente: 1
# ======================================================================
#
# Bag_1 | Samples: Yes | Predicates: No (All) | Valid: 119 | Discarded: 17
# Bag_2 | Samples: Yes | Predicates: No (All) | Valid: 111 | Discarded: 25
# Bag_3 | Samples: Yes | Predicates: No (All) | Valid: 115 | Discarded: 21
# Bag_4 | Samples: Yes | Predicates: No (All) | Valid: 111 | Discarded: 25
# Bag_5 | Samples: Yes | Predicates: No (All) | Valid: 106 | Discarded: 30
# Bag_6 | Samples: Yes | Predicates: No (All) | Valid: 109 | Discarded: 27
# Bag_7 | Samples: Yes | Predicates: No (All) | Valid: 119 | Discarded: 17
# Bag_8 | Samples: Yes | Predicates: No (All) | Valid: 115 | Discarded: 21
# Bag_9 | Samples: Yes | Predicates: No (All) | Valid: 113 | Discarded: 23
# Bag_10 | Samples: Yes | Predicates: No (All) | Valid: 114 | Discarded: 22
# Computing Covariance for Predicates
# Metric: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando semente: 2
# ======================================================================
#
# Bag_1 | Samples: Yes | Predicates: No (All) | Valid: 118 | Discarded: 18
# Bag_2 | Samples: Yes | Predicates: No (All) | Valid: 118 | Discarded: 18
# Bag_3 | Samples: Yes | Predicates: No (All) | Valid: 113 | Discarded: 23
# Bag_4 | Samples: Yes | Predicates: No (All) | Valid: 115 | Discarded: 21
# Bag_5 | Samples: Yes | Predicates: No (All) | Valid: 118 | Discarded: 18
# Bag_6 | Samples: Yes | Predicates: No (All) | Valid: 115 | Discarded: 21
# Bag_7 | Samples: Yes | Predicates: No (All) | Valid: 109 | Discarded: 27
# Bag_8 | Samples: Yes | Predicates: No (All) | Valid: 111 | Discarded: 25
# Bag_9 | Samples: Yes | Predicates: No (All) | Valid: 109 | Discarded: 27
# Bag_10 | Samples: Yes | Predicates: No (All) | Valid: 107 | Discarded: 29
# Computing Covariance for Predicates
# Metric: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando semente: 3
# ======================================================================
#
# Bag_1 | Samples: Yes | Predicates: No (All) | Valid: 114 | Discarded: 22
# Bag_2 | Samples: Yes | Predicates: No (All) | Valid: 106 | Discarded: 30
# Bag_3 | Samples: Yes | Predicates: No (All) | Valid: 107 | Discarded: 29
# Bag_4 | Samples: Yes | Predicates: No (All) | Valid: 116 | Discarded: 20
# Bag_5 | Samples: Yes | Predicates: No (All) | Valid: 109 | Discarded: 27
# Bag_6 | Samples: Yes | Predicates: No (All) | Valid: 108 | Discarded: 28
# Bag_7 | Samples: Yes | Predicates: No (All) | Valid: 111 | Discarded: 25
# Bag_8 | Samples: Yes | Predicates: No (All) | Valid: 110 | Discarded: 26
# Bag_9 | Samples: Yes | Predicates: No (All) | Valid: 118 | Discarded: 18
# Bag_10 | Samples: Yes | Predicates: No (All) | Valid: 116 | Discarded: 20
# Computing Covariance for Predicates
# Metric: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando Grafo - Semente: 0
# ======================================================================
#
#
# Total bidirectional pairs found: 36
# Removed: Rb ka + Br kb > -0.02 -> Rb ka + Br kb > -0.28 (0.0434) | Kept: Rb ka + Br kb > -0.28 -> Rb ka + Br kb > -0.02 (0.0704)
# Removed: Rb ka + Br kb > -0.02 -> Rb ka + Br kb > -0.12 (0.0226) | Kept: Rb ka + Br kb > -0.12 -> Rb ka + Br kb > -0.02 (0.0627)
# Removed: Rb ka + Br kb > -0.02 -> Rh ka Compton <= 0.14 (0.0217) | Kept: Rh ka Compton <= 0.14 -> Rb ka + Br kb > -0.02 (0.0328)
# Removed: Rh ka Compton <= 0.45 -> Rb ka + Br kb > -0.28 (0.0299) | Kept: Rb ka + Br kb > -0.28 -> Rh ka Compton <= 0.45 (0.0434)
# Removed: Rb ka + Br kb > -0.12 -> Rb ka + Br kb > -0.28 (0.0744) | Kept: Rb ka + Br kb > -0.28 -> Rb ka + Br kb > -0.12 (0.0855)
# Removed: Rb ka + Br kb > -0.12 -> Rh ka Compton <= 0.14 (0.0364) | Kept: Rh ka Compton <= 0.14 -> Rb ka + Br kb > -0.12 (0.0645)
# Removed: Rh ka Compton <= 0.14 -> Rh ka Compton <= -0.05 (0.0682) | Kept: Rh ka Compton <= -0.05 -> Rh ka Compton <= 0.14 (0.1400)
# Removed: Rh ka Compton > -0.39 -> Rh ka Compton <= -0.05 (0.0186) | Kept: Rh ka Compton <= -0.05 -> Rh ka Compton > -0.39 (0.0454)
# Removed: Rh kb Compton <= 0.25 -> Rh ka Compton > -0.39 (0.0164) | Kept: Rh ka Compton > -0.39 -> Rh kb Compton <= 0.25 (0.0421)
# Removed: Rh ka Compton > -0.39 -> Rh ka Rayleigh <= 0.21 (0.0168) | Kept: Rh ka Rayleigh <= 0.21 -> Rh ka Compton > -0.39 (0.0566)
# Removed: Rh ka Compton <= -0.05 -> Rh kb Compton <= 0.25 (0.0203) | Kept: Rh kb Compton <= 0.25 -> Rh ka Compton <= -0.05 (0.0231)
# Removed: Rh ka Rayleigh <= -0.02 -> Rh ka Compton > -0.05 (0.0171) | Kept: Rh ka Compton > -0.05 -> Rh ka Rayleigh <= -0.02 (0.0172)
# Removed: Rh ka Compton > -0.05 -> Rh ka Rayleigh <= 0.21 (0.0173) | Kept: Rh ka Rayleigh <= 0.21 -> Rh ka Compton > -0.05 (0.0183)
# Removed: K ka > -0.16 -> Rh ka Compton > -0.05 (0.0198) | Kept: Rh ka Compton > -0.05 -> K ka > -0.16 (0.0343)
# Removed: background3 <= 0.08 -> Rh ka Compton > -0.05 (0.0134) | Kept: Rh ka Compton > -0.05 -> background3 <= 0.08 (0.0177)
# Removed: background3 <= 0.19 -> Rh ka Compton > -0.05 (0.0123) | Kept: Rh ka Compton > -0.05 -> background3 <= 0.19 (0.0162)
# Removed: Rh ka Rayleigh <= 0.21 -> Rh kb Compton <= 0.25 (0.0138) | Kept: Rh kb Compton <= 0.25 -> Rh ka Rayleigh <= 0.21 (0.0614)
# Removed: background3 <= 0.19 -> Rh kb Compton <= 0.25 (0.0113) | Kept: Rh kb Compton <= 0.25 -> background3 <= 0.19 (0.0189)
# Removed: Rh ka Rayleigh <= 0.21 -> background3 <= 0.19 (0.0271) | Kept: background3 <= 0.19 -> Rh ka Rayleigh <= 0.21 (0.0479)
# Removed: background3 <= 0.19 -> K ka <= 0.20 (0.0097) | Kept: K ka <= 0.20 -> background3 <= 0.19 (0.0664)
# Removed: K ka <= 0.20 -> background3 > -0.26 (0.0137) | Kept: background3 > -0.26 -> K ka <= 0.20 (0.0141)
# Removed: Cl > 0.16 -> Rh ka Rayleigh > -0.15 (0.0100) | Kept: Rh ka Rayleigh > -0.15 -> Cl > 0.16 (0.0119)
# Removed: K ka > -0.16 -> Rh kb Compton <= 0.00 (0.0119) | Kept: Rh kb Compton <= 0.00 -> K ka > -0.16 (0.0337)
# Removed: background3 > -0.26 -> K ka > -0.16 (0.0103) | Kept: K ka > -0.16 -> background3 > -0.26 (0.0511)
# Removed: K ka > -0.16 -> Rh ka Rayleigh <= -0.02 (0.0159) | Kept: Rh ka Rayleigh <= -0.02 -> K ka > -0.16 (0.0167)
# Removed: Rh ka Rayleigh > -0.15 -> Rh kb Compton > -0.20 (0.0098) | Kept: Rh kb Compton > -0.20 -> Rh ka Rayleigh > -0.15 (0.0216)
# Removed: background3 > -0.26 -> Rh ka Rayleigh <= 0.09 (0.0118) | Kept: Rh ka Rayleigh <= 0.09 -> background3 > -0.26 (0.0139)
# Removed: Rh kb Rayleigh <= -0.02 -> Rh kb Compton > -0.20 (0.0084) | Kept: Rh kb Compton > -0.20 -> Rh kb Rayleigh <= -0.02 (0.0182)
# Removed: Rh ka Rayleigh <= 0.09 -> Rh kb Compton <= 0.10 (0.0095) | Kept: Rh kb Compton <= 0.10 -> Rh ka Rayleigh <= 0.09 (0.0555)
# Removed: Rh kb Compton <= 0.10 -> background3 <= -0.04 (0.0112) | Kept: background3 <= -0.04 -> Rh kb Compton <= 0.10 (0.0126)
# Removed: background3 <= -0.04 -> Rh ka Rayleigh <= 0.09 (0.0070) | Kept: Rh ka Rayleigh <= 0.09 -> background3 <= -0.04 (0.0142)
# Removed: background3 <= 0.08 -> Rh ka Rayleigh <= 0.09 (0.0126) | Kept: Rh ka Rayleigh <= 0.09 -> background3 <= 0.08 (0.0300)
# Removed: background3 <= 0.08 -> Rh ka Rayleigh <= -0.02 (0.0093) | Kept: Rh ka Rayleigh <= -0.02 -> background3 <= 0.08 (0.0161)
# Removed: Br ka <= 0.17 -> Cl > -0.20 (0.0086) | Kept: Cl > -0.20 -> Br ka <= 0.17 (0.0087)
# Removed: Rh kb Rayleigh <= -0.02 -> Rh kb Rayleigh <= 0.12 (0.0078) | Kept: Rh kb Rayleigh <= 0.12 -> Rh kb Rayleigh <= -0.02 (0.0081)
# Removed: Rh kb Rayleigh <= -0.02 -> Rh kb Rayleigh <= 0.06 (0.0078) | Kept: Rh kb Rayleigh <= 0.06 -> Rh kb Rayleigh <= -0.02 (0.0088)
#
# ======================================================================
# CONSTRUCTED GRAPH SUMMARY
# ======================================================================
# Initial edges: 209 | Removed: 36
# Predicate nodes: 41
# Metric: Covariance
# Weighting by explained variance: ENABLED
#
# ======================================================================
# Processando Grafo - Semente: 1
# ======================================================================
#
#
# Total bidirectional pairs found: 27
# Removed: Rh ka Compton <= -0.05 -> Rh ka Compton <= 0.45 (0.0335) | Kept: Rh ka Compton <= 0.45 -> Rh ka Compton <= -0.05 (0.1409)
# Removed: Rh ka Compton <= 0.14 -> Rh ka Compton <= -0.05 (0.0611) | Kept: Rh ka Compton <= -0.05 -> Rh ka Compton <= 0.14 (0.0934)
# Removed: K ka <= 0.20 -> Rh ka Compton <= 0.14 (0.0308) | Kept: Rh ka Compton <= 0.14 -> K ka <= 0.20 (0.0491)
# Removed: Rb ka + Br kb > -0.28 -> Rh ka Compton <= -0.05 (0.0234) | Kept: Rh ka Compton <= -0.05 -> Rb ka + Br kb > -0.28 (0.0261)
# Removed: Rb ka + Br kb > -0.02 -> Rb ka + Br kb > -0.28 (0.0259) | Kept: Rb ka + Br kb > -0.28 -> Rb ka + Br kb > -0.02 (0.0886)
# Removed: Rb ka + Br kb > -0.28 -> Rb ka + Br kb > -0.12 (0.0402) | Kept: Rb ka + Br kb > -0.12 -> Rb ka + Br kb > -0.28 (0.0709)
# Removed: Rh ka Compton > -0.39 -> Rb ka + Br kb > -0.02 (0.0115) | Kept: Rb ka + Br kb > -0.02 -> Rh ka Compton > -0.39 (0.0424)
# Removed: background3 <= 0.19 -> Rh ka Compton > -0.39 (0.0143) | Kept: Rh ka Compton > -0.39 -> background3 <= 0.19 (0.0586)
# Removed: background3 <= -0.04 -> Rh ka Compton > -0.39 (0.0119) | Kept: Rh ka Compton > -0.39 -> background3 <= -0.04 (0.0163)
# Removed: K ka <= 0.20 -> Rh ka Compton > -0.39 (0.0234) | Kept: Rh ka Compton > -0.39 -> K ka <= 0.20 (0.0319)
# Removed: Rh kb Compton <= 0.25 -> background3 <= 0.19 (0.0206) | Kept: background3 <= 0.19 -> Rh kb Compton <= 0.25 (0.0297)
# Removed: background3 <= 0.19 -> Rh ka Rayleigh <= 0.21 (0.0175) | Kept: Rh ka Rayleigh <= 0.21 -> background3 <= 0.19 (0.0560)
# Removed: background3 <= 0.08 -> background3 <= 0.19 (0.0125) | Kept: background3 <= 0.19 -> background3 <= 0.08 (0.0158)
# Removed: Rh ka Compton > -0.05 -> Rh kb Compton <= 0.00 (0.0175) | Kept: Rh kb Compton <= 0.00 -> Rh ka Compton > -0.05 (0.0466)
# Removed: K ka <= 0.20 -> K ka > -0.16 (0.0180) | Kept: K ka > -0.16 -> K ka <= 0.20 (0.0193)
# Removed: background3 > -0.26 -> K ka > -0.16 (0.0104) | Kept: K ka > -0.16 -> background3 > -0.26 (0.0320)
# Removed: Rh kb Compton <= 0.00 -> background3 <= 0.08 (0.0155) | Kept: background3 <= 0.08 -> Rh kb Compton <= 0.00 (0.0598)
# Removed: background3 > -0.26 -> Rh kb Compton <= 0.10 (0.0123) | Kept: Rh kb Compton <= 0.10 -> background3 > -0.26 (0.0137)
# Removed: background3 > -0.26 -> background2 <= 0.06 (0.0080) | Kept: background2 <= 0.06 -> background3 > -0.26 (0.0096)
# Removed: Rh ka Rayleigh <= -0.02 -> background3 <= -0.04 (0.0140) | Kept: background3 <= -0.04 -> Rh ka Rayleigh <= -0.02 (0.0334)
# Removed: Rh kb Compton <= 0.10 -> Rh ka Rayleigh <= -0.02 (0.0135) | Kept: Rh ka Rayleigh <= -0.02 -> Rh kb Compton <= 0.10 (0.0525)
# Removed: Rh kb Compton > -0.20 -> Rh ka Compton <= -0.39 (0.0083) | Kept: Rh ka Compton <= -0.39 -> Rh kb Compton > -0.20 (0.0127)
# Removed: Rh ka Rayleigh <= 0.09 -> background3 <= 0.08 (0.0091) | Kept: background3 <= 0.08 -> Rh ka Rayleigh <= 0.09 (0.0096)
# Removed: background2 <= 0.18 -> Rh kb Compton > -0.20 (0.0073) | Kept: Rh kb Compton > -0.20 -> background2 <= 0.18 (0.0102)
# Removed: Cl > -0.20 -> Rh kb Rayleigh <= 0.12 (0.0090) | Kept: Rh kb Rayleigh <= 0.12 -> Cl > -0.20 (0.0179)
# Removed: background3 > -0.04 -> Cl > -0.20 (0.0080) | Kept: Cl > -0.20 -> background3 > -0.04 (0.0086)
# Removed: background2 <= 0.06 -> Rh kb Compton > 0.00 (0.0074) | Kept: Rh kb Compton > 0.00 -> background2 <= 0.06 (0.0100)
#
# ======================================================================
# CONSTRUCTED GRAPH SUMMARY
# ======================================================================
# Initial edges: 206 | Removed: 27
# Predicate nodes: 42
# Metric: Covariance
# Weighting by explained variance: ENABLED
#
# ======================================================================
# Processando Grafo - Semente: 2
# ======================================================================
#
#
# Total bidirectional pairs found: 34
# Removed: Rb ka + Br kb > -0.12 -> Rb ka + Br kb > -0.02 (0.0271) | Kept: Rb ka + Br kb > -0.02 -> Rb ka + Br kb > -0.12 (0.0926)
# Removed: Rb ka + Br kb > -0.02 -> Rh ka Compton <= 0.14 (0.0270) | Kept: Rh ka Compton <= 0.14 -> Rb ka + Br kb > -0.02 (0.0717)
# Removed: Rb ka + Br kb > -0.12 -> Rh ka Compton <= 0.45 (0.0197) | Kept: Rh ka Compton <= 0.45 -> Rb ka + Br kb > -0.12 (0.0377)
# Removed: Rb ka + Br kb > -0.28 -> Rb ka + Br kb > -0.12 (0.0201) | Kept: Rb ka + Br kb > -0.12 -> Rb ka + Br kb > -0.28 (0.0427)
# Removed: Rh ka Compton <= -0.05 -> Rh ka Compton <= 0.45 (0.0376) | Kept: Rh ka Compton <= 0.45 -> Rh ka Compton <= -0.05 (0.1150)
# Removed: Rb ka + Br kb > -0.28 -> Rh ka Compton <= -0.05 (0.0214) | Kept: Rh ka Compton <= -0.05 -> Rb ka + Br kb > -0.28 (0.0314)
# Removed: Rb ka + Br kb > -0.28 -> K ka <= 0.20 (0.0248) | Kept: K ka <= 0.20 -> Rb ka + Br kb > -0.28 (0.0395)
# Removed: Rh ka Compton > -0.39 -> Rh ka Rayleigh <= 0.09 (0.0176) | Kept: Rh ka Rayleigh <= 0.09 -> Rh ka Compton > -0.39 (0.0321)
# Removed: Rh ka Compton <= 0.14 -> Rh ka Compton <= -0.05 (0.1053) | Kept: Rh ka Compton <= -0.05 -> Rh ka Compton <= 0.14 (0.1073)
# Removed: Rh kb Rayleigh <= -0.02 -> Rh ka Compton > -0.05 (0.0079) | Kept: Rh ka Compton > -0.05 -> Rh kb Rayleigh <= -0.02 (0.0101)
# Removed: Rh kb Rayleigh <= 0.06 -> Rh ka Compton > -0.05 (0.0084) | Kept: Rh ka Compton > -0.05 -> Rh kb Rayleigh <= 0.06 (0.0112)
# Removed: Rh ka Compton > -0.05 -> Rh kb Compton <= 0.10 (0.0126) | Kept: Rh kb Compton <= 0.10 -> Rh ka Compton > -0.05 (0.0138)
# Removed: Rh ka Rayleigh <= 0.21 -> K ka <= 0.20 (0.0131) | Kept: K ka <= 0.20 -> Rh ka Rayleigh <= 0.21 (0.0232)
# Removed: Rh kb Compton <= 0.00 -> K ka <= 0.20 (0.0195) | Kept: K ka <= 0.20 -> Rh kb Compton <= 0.00 (0.0248)
# Removed: background3 <= 0.08 -> Rh kb Compton <= 0.25 (0.0174) | Kept: Rh kb Compton <= 0.25 -> background3 <= 0.08 (0.0469)
# Removed: Rh kb Compton <= 0.00 -> Rh kb Compton <= 0.25 (0.0190) | Kept: Rh kb Compton <= 0.25 -> Rh kb Compton <= 0.00 (0.0203)
# Removed: background3 <= 0.19 -> Rh kb Compton <= 0.25 (0.0195) | Kept: Rh kb Compton <= 0.25 -> background3 <= 0.19 (0.0339)
# Removed: background3 <= 0.19 -> Rh ka Rayleigh <= 0.21 (0.0311) | Kept: Rh ka Rayleigh <= 0.21 -> background3 <= 0.19 (0.0748)
# Removed: background3 <= 0.08 -> Rh ka Rayleigh <= 0.21 (0.0187) | Kept: Rh ka Rayleigh <= 0.21 -> background3 <= 0.08 (0.0194)
# Removed: background3 <= -0.04 -> Rh ka Rayleigh <= 0.21 (0.0166) | Kept: Rh ka Rayleigh <= 0.21 -> background3 <= -0.04 (0.0210)
# Removed: K ka > -0.16 -> Rh ka Rayleigh <= 0.09 (0.0159) | Kept: Rh ka Rayleigh <= 0.09 -> K ka > -0.16 (0.0171)
# Removed: Rb ka + Br kb <= -0.12 -> Rh kb Compton > -0.20 (0.0082) | Kept: Rh kb Compton > -0.20 -> Rb ka + Br kb <= -0.12 (0.0089)
# Removed: Rh kb Compton > -0.20 -> background2 <= 0.18 (0.0090) | Kept: background2 <= 0.18 -> Rh kb Compton > -0.20 (0.0173)
# Removed: background3 > -0.26 -> K ka > 0.20 (0.0081) | Kept: K ka > 0.20 -> background3 > -0.26 (0.0151)
# Removed: Rh kb Compton <= 0.10 -> Rh kb Compton <= 0.00 (0.0170) | Kept: Rh kb Compton <= 0.00 -> Rh kb Compton <= 0.10 (0.0500)
# Removed: Rh kb Rayleigh <= 0.12 -> Rh kb Compton > 0.00 (0.0079) | Kept: Rh kb Compton > 0.00 -> Rh kb Rayleigh <= 0.12 (0.0090)
# Removed: Rh ka Rayleigh <= 0.09 -> K ka <= 0.44 (0.0130) | Kept: K ka <= 0.44 -> Rh ka Rayleigh <= 0.09 (0.0204)
# Removed: Rh ka Rayleigh <= -0.02 -> background3 <= 0.08 (0.0165) | Kept: background3 <= 0.08 -> Rh ka Rayleigh <= -0.02 (0.0303)
# Removed: Rh kb Compton <= 0.10 -> Rh ka Rayleigh <= -0.02 (0.0163) | Kept: Rh ka Rayleigh <= -0.02 -> Rh kb Compton <= 0.10 (0.0171)
# Removed: Rh ka Rayleigh <= 0.09 -> background3 <= -0.04 (0.0114) | Kept: background3 <= -0.04 -> Rh ka Rayleigh <= 0.09 (0.0133)
# Removed: Rh ka Rayleigh <= -0.02 -> background3 <= -0.04 (0.0157) | Kept: background3 <= -0.04 -> Rh ka Rayleigh <= -0.02 (0.0230)
# Removed: background2 <= 0.06 -> Rh kb Rayleigh <= 0.12 (0.0079) | Kept: Rh kb Rayleigh <= 0.12 -> background2 <= 0.06 (0.0113)
# Removed: Rh kb Rayleigh <= 0.06 -> background2 <= 0.06 (0.0079) | Kept: background2 <= 0.06 -> Rh kb Rayleigh <= 0.06 (0.0108)
# Removed: Rh kb Rayleigh <= 0.06 -> background2 <= 0.18 (0.0087) | Kept: background2 <= 0.18 -> Rh kb Rayleigh <= 0.06 (0.0087)
#
# ======================================================================
# CONSTRUCTED GRAPH SUMMARY
# ======================================================================
# Initial edges: 234 | Removed: 34
# Predicate nodes: 43
# Metric: Covariance
# Weighting by explained variance: ENABLED
#
# ======================================================================
# Processando Grafo - Semente: 3
# ======================================================================
#
#
# Total bidirectional pairs found: 29
# Removed: Rh ka Compton <= 0.45 -> Rh ka Compton <= -0.05 (0.0982) | Kept: Rh ka Compton <= -0.05 -> Rh ka Compton <= 0.45 (0.1281)
# Removed: Rh ka Compton <= 0.14 -> Rb ka + Br kb > -0.02 (0.0347) | Kept: Rb ka + Br kb > -0.02 -> Rh ka Compton <= 0.14 (0.0531)
# Removed: Rb ka + Br kb > -0.12 -> Rb ka + Br kb > -0.02 (0.0373) | Kept: Rb ka + Br kb > -0.02 -> Rb ka + Br kb > -0.12 (0.0842)
# Removed: Rh ka Compton <= 0.14 -> Rh ka Compton <= -0.05 (0.0303) | Kept: Rh ka Compton <= -0.05 -> Rh ka Compton <= 0.14 (0.0932)
# Removed: Rb ka + Br kb > -0.12 -> Rb ka + Br kb > -0.28 (0.0672) | Kept: Rb ka + Br kb > -0.28 -> Rb ka + Br kb > -0.12 (0.0891)
# Removed: Rb ka + Br kb > -0.12 -> K ka <= 0.20 (0.0202) | Kept: K ka <= 0.20 -> Rb ka + Br kb > -0.12 (0.0243)
# Removed: Rh ka Compton > -0.39 -> Rh ka Compton <= -0.05 (0.0201) | Kept: Rh ka Compton <= -0.05 -> Rh ka Compton > -0.39 (0.0232)
# Removed: Rh ka Compton > -0.39 -> K ka <= 0.20 (0.0228) | Kept: K ka <= 0.20 -> Rh ka Compton > -0.39 (0.0283)
# Removed: background3 <= 0.19 -> Rh kb Compton <= 0.25 (0.0158) | Kept: Rh kb Compton <= 0.25 -> background3 <= 0.19 (0.0189)
# Removed: background3 <= 0.08 -> Rh kb Compton <= 0.25 (0.0177) | Kept: Rh kb Compton <= 0.25 -> background3 <= 0.08 (0.0179)
# Removed: background3 <= 0.19 -> Rh ka Rayleigh <= 0.21 (0.0161) | Kept: Rh ka Rayleigh <= 0.21 -> background3 <= 0.19 (0.1062)
# Removed: background3 <= 0.19 -> Rh ka Compton > -0.05 (0.0154) | Kept: Rh ka Compton > -0.05 -> background3 <= 0.19 (0.0207)
# Removed: background3 <= 0.19 -> background3 <= -0.04 (0.0157) | Kept: background3 <= -0.04 -> background3 <= 0.19 (0.0201)
# Removed: Rh ka Rayleigh <= 0.21 -> Rh kb Compton <= 0.00 (0.0194) | Kept: Rh kb Compton <= 0.00 -> Rh ka Rayleigh <= 0.21 (0.0410)
# Removed: background3 <= 0.08 -> Rh ka Rayleigh <= 0.21 (0.0152) | Kept: Rh ka Rayleigh <= 0.21 -> background3 <= 0.08 (0.0190)
# Removed: K ka > -0.16 -> Rh kb Compton <= 0.00 (0.0153) | Kept: Rh kb Compton <= 0.00 -> K ka > -0.16 (0.0156)
# Removed: Rh kb Compton <= 0.00 -> background3 <= 0.08 (0.0113) | Kept: background3 <= 0.08 -> Rh kb Compton <= 0.00 (0.0145)
# Removed: Br ka <= 0.17 -> K ka > -0.16 (0.0078) | Kept: K ka > -0.16 -> Br ka <= 0.17 (0.0117)
# Removed: K ka > -0.16 -> Rh ka Rayleigh <= -0.02 (0.0151) | Kept: Rh ka Rayleigh <= -0.02 -> K ka > -0.16 (0.0168)
# Removed: background3 > -0.26 -> Rh ka Rayleigh > -0.15 (0.0084) | Kept: Rh ka Rayleigh > -0.15 -> background3 > -0.26 (0.0113)
# Removed: Rh ka Rayleigh <= -0.02 -> Rh kb Compton <= 0.10 (0.0297) | Kept: Rh kb Compton <= 0.10 -> Rh ka Rayleigh <= -0.02 (0.0396)
# Removed: Rh ka Rayleigh <= 0.09 -> Rh ka Rayleigh <= -0.02 (0.0149) | Kept: Rh ka Rayleigh <= -0.02 -> Rh ka Rayleigh <= 0.09 (0.0423)
# Removed: Cl > 0.03 -> Rh ka Rayleigh <= -0.02 (0.0087) | Kept: Rh ka Rayleigh <= -0.02 -> Cl > 0.03 (0.0088)
# Removed: Rh kb Compton <= 0.10 -> background3 <= 0.08 (0.0133) | Kept: background3 <= 0.08 -> Rh kb Compton <= 0.10 (0.0161)
# Removed: Rh ka Rayleigh <= 0.09 -> Rh kb Compton <= 0.10 (0.0087) | Kept: Rh kb Compton <= 0.10 -> Rh ka Rayleigh <= 0.09 (0.0301)
# Removed: background2 <= 0.18 -> Rh ka Rayleigh <= 0.09 (0.0074) | Kept: Rh ka Rayleigh <= 0.09 -> background2 <= 0.18 (0.0208)
# Removed: Rh kb Rayleigh <= 0.12 -> Cl > -0.20 (0.0073) | Kept: Cl > -0.20 -> Rh kb Rayleigh <= 0.12 (0.0106)
# Removed: background2 > 0.06 -> background3 > -0.04 (0.0070) | Kept: background3 > -0.04 -> background2 > 0.06 (0.0085)
# Removed: background2 <= 0.18 -> Rh kb Rayleigh <= 0.06 (0.0093) | Kept: Rh kb Rayleigh <= 0.06 -> background2 <= 0.18 (0.0094)
#
# ======================================================================
# CONSTRUCTED GRAPH SUMMARY
# ======================================================================
# Initial edges: 229 | Removed: 29
# Predicate nodes: 44
# Metric: Covariance
# Weighting by explained variance: ENABLED
#
# Processing graph LRC...
#
# Processing graph LRC...
#
# Processing graph LRC...
#
# Processing graph LRC...
#        Predicate_Cov_Seed_0     Predicate_Cov_Seed_1     Predicate_Cov_Seed_2  \
# 0     Rh ka Compton <= 0.45    Rh ka Compton <= 0.45    Rh ka Compton <= 0.45
# 1     Rb ka + Br kb > -0.28    Rh kb Compton <= 0.25   Rh ka Compton <= -0.05
# 2    Rh ka Compton <= -0.05    Rb ka + Br kb > -0.28    Rb ka + Br kb > -0.02
# 3     Rh ka Compton <= 0.14    Rb ka + Br kb > -0.12    Rh ka Compton <= 0.14
# 4     Rb ka + Br kb > -0.12   Rh ka Compton <= -0.05   Rh ka Rayleigh <= 0.21
# 5              K ka <= 0.20    Rb ka + Br kb > -0.02    Rh kb Compton <= 0.00
# 6     Rb ka + Br kb > -0.02    Rh ka Compton <= 0.14    Rh kb Compton <= 0.25
# 7     Rh kb Compton <= 0.25    Rh ka Compton > -0.39    Rb ka + Br kb > -0.28
# 8       background3 <= 0.19             K ka <= 0.44    Rb ka + Br kb > -0.12
# 9       background2 > -0.23   Rh ka Rayleigh > -0.15     Rh kb Compton > 0.00
# 10    Rh ka Compton > -0.39      background3 <= 0.08             K ka <= 0.20
# 11    Rh kb Compton <= 0.00             K ka <= 0.20      background3 > -0.04
# 12   Rh ka Rayleigh <= 0.21  Rh ka Rayleigh <= -0.02     background3 <= -0.04
# 13             K ka > -0.16    Rh kb Compton <= 0.10   Rh ka Rayleigh <= 0.09
# 14      background3 <= 0.08             K ka > -0.16  Rh ka Rayleigh <= -0.02
# 15    Rh kb Compton <= 0.10      background3 <= 0.19    Rh ka Compton > -0.39
# 16  Rh ka Rayleigh <= -0.02   Rh ka Compton <= -0.39    Rh kb Compton <= 0.10
# 17    Rh ka Compton > -0.05      background3 > -0.26      background3 <= 0.08
# 18      background3 > -0.26   Rh ka Rayleigh <= 0.21    Rh ka Compton > -0.05
# 19             K ka <= 0.44    Rh kb Compton <= 0.00    Rh kb Compton > -0.20
# 20   Rh ka Compton <= -0.39    Rh ka Compton > -0.05                Cl > 0.03
# 21                Cl > 0.16     background3 <= -0.04             K ka > -0.16
# 22                Cl > 0.03                Cl > 0.03               Cl > -0.20
# 23     background3 <= -0.04   Rh ka Rayleigh <= 0.09            Br ka <= 0.17
# 24               Cl > -0.20               Cl > -0.04      background3 <= 0.19
# 25    Rh kb Compton > -0.20     background3 <= -0.26              K ka > 0.20
# 26   Rh ka Rayleigh <= 0.09      background2 <= 0.18   Rh ka Compton <= -0.39
# 27     Rh ka Compton > 0.14     Rh kb Compton > 0.00             K ka <= 0.44
# 28   Rh kb Rayleigh <= 0.12      background2 <= 0.06   Rh ka Rayleigh > -0.15
# 29      background2 <= 0.18  Rh ka Rayleigh <= -0.15      background3 > -0.26
# 30              K ka > 0.20  Rh kb Rayleigh <= -0.02   Rh kb Rayleigh <= 0.06
# 31   Rh kb Rayleigh <= 0.06   Rh kb Rayleigh <= 0.06      background2 <= 0.18
# 32   Rh ka Rayleigh > -0.15       background2 > 0.06                Cl > 0.16
# 33     Rh kb Compton > 0.00     Rh ka Compton > 0.14   Rh kb Rayleigh <= 0.12
# 34      background3 > -0.04    Rh kb Compton > -0.20  Rh kb Rayleigh <= -0.02
# 35  Rh kb Rayleigh <= -0.02            Br ka <= 0.17  Rh ka Rayleigh <= -0.15
# 36      background2 <= 0.06   Rh kb Rayleigh <= 0.12     background2 <= -0.07
# 37     background2 <= -0.07      background3 > -0.04           Br ka <= -0.05
# 38       background2 > 0.06               Cl > -0.20   Rb ka + Br kb <= -0.12
# 39     background3 <= -0.26                Cl > 0.16               Cl > -0.04
# 40            Br ka <= 0.17              K ka > 0.20     Rh ka Compton > 0.14
# 41                  Class_A   Rb ka + Br kb <= -0.12      background2 <= 0.06
# 42                  Class_B                  Class_A            Br ka <= 0.04
# 43                      NaN                  Class_B                  Class_A
# 44                      NaN                      NaN                  Class_B
# 45                      NaN                      NaN                      NaN
#
#        Predicate_Cov_Seed_3
# 0     Rh ka Compton <= 0.45
# 1     Rb ka + Br kb > -0.28
# 2    Rh ka Compton <= -0.05
# 3     Rh kb Compton <= 0.25
# 4    Rh ka Rayleigh <= 0.21
# 5              K ka <= 0.20
# 6     Rb ka + Br kb > -0.02
# 7     Rh ka Compton <= 0.14
# 8     Rb ka + Br kb > -0.12
# 9     Rh ka Compton > -0.39
# 10  Rh ka Rayleigh <= -0.02
# 11    Rh ka Compton > -0.05
# 12      background3 <= 0.19
# 13             K ka <= 0.44
# 14   Rh ka Rayleigh <= 0.09
# 15    Rh kb Compton <= 0.00
# 16      background3 > -0.26
# 17    Rh kb Compton <= 0.10
# 18     background3 <= -0.04
# 19   Rh kb Rayleigh <= 0.12
# 20             K ka > -0.16
# 21      background3 <= 0.08
# 22      background2 <= 0.06
# 23              K ka > 0.20
# 24            Br ka <= 0.17
# 25   Rh ka Compton <= -0.39
# 26                Cl > 0.03
# 27     background2 <= -0.07
# 28     Rh ka Compton > 0.14
# 29      background2 > -0.23
# 30   Rh kb Rayleigh <= 0.06
# 31    Rh kb Compton > -0.20
# 32   Rh ka Rayleigh > -0.15
# 33     Rh kb Compton > 0.00
# 34   Rb ka + Br kb <= -0.28
# 35      background2 <= 0.18
# 36               Cl > -0.20
# 37      background3 > -0.04
# 38   Rb ka + Br kb <= -0.12
# 39    K kb + Ca ka <= -0.14
# 40     background3 <= -0.26
# 41       background2 > 0.06
# 42  Rh kb Rayleigh <= -0.02
# 43  Rh ka Rayleigh <= -0.15
# 44                  Class_A
# 45                  Class_B

# %%
# Somar LRCs de predicados equivalentes entre diferentes seeds
lrc_combined_list = []

for seed in random_seeds:
    lrc_df = lrc_cov_by_seed[seed].copy()
    lrc_combined_list.append(lrc_df) # o append adiciona o dataframe ao final da lista

# Concatenar todos os dataframes
lrc_all_seeds = pd.concat(lrc_combined_list, ignore_index=True) 

# Agrupar por predicado (Node) e somar as LRCs, mantendo Zone, Threshold e Operator
lrc_summed_df_cov = lrc_all_seeds.groupby('Node').agg({ # o .agg pode ser usado para aplicar múltiplas funções de agregação
    'Local_Reaching_Centrality': 'mean', # sum = somando as LRCs, poderia ser média ou outro agregado
    'Zone': 'first',
    'Threshold': 'first',
    'Operator': 'first'
}).reset_index()

# Ordenar pelo valor de LRC somado (maior para menor)
lrc_summed_df_cov = lrc_summed_df_cov.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
# vamoss pegar so os valore sunicos de lrc_summed_df baseado na zona espectral
lrc_summed_unique_df_cov = lrc_summed_df_cov.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
#lrc_summed_unique_df_cov = lrc_summed_unique_df_cov.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
lrc_summed_unique_df_cov
# Out:
#                       Node  Local_Reaching_Centrality            Zone  \
# 0    Rh ka Compton <= 0.45                   3.313541   Rh ka Compton
# 1    Rb ka + Br kb > -0.28                   2.139152   Rb ka + Br kb
# 2    Rh kb Compton <= 0.25                   2.068567   Rh kb Compton
# 3             K ka <= 0.20                   1.629767            K ka
# 4   Rh ka Rayleigh <= 0.21                   1.596149  Rh ka Rayleigh
# 5      background3 <= 0.19                   1.286204     background3
# 6      background2 > -0.23                   1.210804     background2
# 7                Cl > 0.03                   1.045668              Cl
# 8   Rh kb Rayleigh <= 0.12                   0.889848  Rh kb Rayleigh
# 9           Br ka <= -0.05                   0.743256           Br ka
# 10   K kb + Ca ka <= -0.14                   0.733121    K kb + Ca ka
# 11                 Class_B                   0.000000            None
#
#    Threshold Operator
# 0       0.45       <=
# 1      -0.28        >
# 2       0.25       <=
# 3       0.20       <=
# 4       0.21       <=
# 5       0.19       <=
# 6      -0.23        >
# 7       0.03        >
# 8       0.12       <=
# 9      -0.05       <=
# 10     -0.14       <=
# 11      None     None

# %%
# Criar zone_sums_df para dados NÃO pré-processados (Xcalclass)
spectral_zones_original = exp.extract_spectral_zones(Xcalclass, spectral_cuts)
zones_original = exp.aggregate_spectral_zones_pca(spectral_zones_original) # apca aggregation

# Aplicar o mapeamento
lrc_summed_df_cov_natural = exp.map_thresholds_to_natural(
    lrc_df=lrc_summed_df_cov,
    zone_sums_preprocessed=zone_scores_df,
    zone_sums_natural=zones_original[0]
)

lrc_summed_df_cov_natural
# Out:
# Zone 'S': VE = 57.86%, dim = 15 variables
# Zone 'Cl': VE = 86.73%, dim = 33 variables
# Zone 'K ka': VE = 99.30%, dim = 23 variables
# Zone 'K kb + Ca ka': VE = 73.64%, dim = 21 variables
# Zone 'background1': VE = 21.46%, dim = 94 variables
# Zone 'Mn': VE = 58.45%, dim = 18 variables
# Zone 'Fe': VE = 62.13%, dim = 64 variables
# Zone 'Cu': VE = 55.31%, dim = 52 variables
# Zone 'Zn': VE = 60.70%, dim = 27 variables
# Zone 'background2': VE = 69.36%, dim = 137 variables
# Zone 'Br ka': VE = 64.96%, dim = 48 variables
# Zone 'Rb ka + Br kb': VE = 79.32%, dim = 66 variables
# Zone 'background3': VE = 69.90%, dim = 161 variables
# Zone 'Rh ka Compton': VE = 92.92%, dim = 146 variables
# Zone 'Rh ka Rayleigh': VE = 85.65%, dim = 46 variables
# Zone 'Rh kb Compton': VE = 83.08%, dim = 76 variables
# Zone 'Rh kb Rayleigh': VE = 69.80%, dim = 40 variables
#                        Node  Local_Reaching_Centrality            Zone  \
# 0     Rh ka Compton <= 0.45                   3.313541   Rh ka Compton
# 1     Rb ka + Br kb > -0.28                   2.139152   Rb ka + Br kb
# 2    Rh ka Compton <= -0.05                   2.133021   Rh ka Compton
# 3     Rh kb Compton <= 0.25                   2.068567   Rh kb Compton
# 4     Rb ka + Br kb > -0.02                   1.891799   Rb ka + Br kb
# 5     Rh ka Compton <= 0.14                   1.831337   Rh ka Compton
# 6     Rb ka + Br kb > -0.12                   1.752474   Rb ka + Br kb
# 7              K ka <= 0.20                   1.629767            K ka
# 8    Rh ka Rayleigh <= 0.21                   1.596149  Rh ka Rayleigh
# 9     Rh ka Compton > -0.39                   1.433699   Rh ka Compton
# 10    Rh kb Compton <= 0.00                   1.391404   Rh kb Compton
# 11      background3 <= 0.19                   1.286204     background3
# 12  Rh ka Rayleigh <= -0.02                   1.279067  Rh ka Rayleigh
# 13      background3 <= 0.08                   1.252252     background3
# 14    Rh kb Compton <= 0.10                   1.246147   Rh kb Compton
# 15             K ka <= 0.44                   1.234942            K ka
# 16    Rh ka Compton > -0.05                   1.221419   Rh ka Compton
# 17      background2 > -0.23                   1.210804     background2
# 18             K ka > -0.16                   1.206163            K ka
# 19      background3 > -0.26                   1.133539     background3
# 20     background3 <= -0.04                   1.131672     background3
# 21   Rh ka Rayleigh <= 0.09                   1.123968  Rh ka Rayleigh
# 22   Rh ka Compton <= -0.39                   1.058489   Rh ka Compton
# 23                Cl > 0.03                   1.045668              Cl
# 24     Rh kb Compton > 0.00                   1.025463   Rh kb Compton
# 25   Rh ka Rayleigh > -0.15                   1.007325  Rh ka Rayleigh
# 26    Rh kb Compton > -0.20                   0.952247   Rh kb Compton
# 27               Cl > -0.04                   0.945506              Cl
# 28      background3 > -0.04                   0.889959     background3
# 29   Rh kb Rayleigh <= 0.12                   0.889848  Rh kb Rayleigh
# 30                Cl > 0.16                   0.873958              Cl
# 31      background2 <= 0.18                   0.872103     background2
# 32               Cl > -0.20                   0.866886              Cl
# 33      background2 <= 0.06                   0.865639     background2
# 34   Rh kb Rayleigh <= 0.06                   0.865449  Rh kb Rayleigh
# 35     Rh ka Compton > 0.14                   0.862153   Rh ka Compton
# 36              K ka > 0.20                   0.858418            K ka
# 37   Rb ka + Br kb <= -0.28                   0.832859   Rb ka + Br kb
# 38  Rh ka Rayleigh <= -0.15                   0.808977  Rh ka Rayleigh
# 39  Rh kb Rayleigh <= -0.02                   0.804572  Rh kb Rayleigh
# 40     background2 <= -0.07                   0.782739     background2
# 41       background2 > 0.06                   0.765802     background2
# 42           Br ka <= -0.05                   0.743256           Br ka
# 43    K kb + Ca ka <= -0.14                   0.733121    K kb + Ca ka
# 44   Rb ka + Br kb <= -0.12                   0.726013   Rb ka + Br kb
# 45            Br ka <= 0.17                   0.706813           Br ka
# 46     background3 <= -0.26                   0.628182     background3
# 47            Br ka <= 0.04                   0.626569           Br ka
# 48                  Class_B                   0.000000            None
# 49                  Class_A                   0.000000            None
#
#    Threshold Operator  Threshold_Natural  Reference_Sample_Index  \
# 0       0.45       <=           0.421114                     2.0
# 1      -0.28        >          -0.136523                     0.0
# 2      -0.05       <=          -0.043040                    26.0
# 3       0.25       <=           0.124124                     3.0
# 4      -0.02        >          -0.003744                    27.0
# 5       0.14       <=           0.128749                     0.0
# 6      -0.12        >          -0.062361                     9.0
# 7       0.20       <=           0.254042                    24.0
# 8       0.21       <=           0.127042                    13.0
# 9      -0.39        >          -0.345973                    25.0
# 10      0.00       <=           0.004147                     8.0
# 11      0.19       <=           0.078536                    29.0
# 12     -0.02       <=          -0.020730                    10.0
# 13      0.08       <=           0.034554                    11.0
# 14      0.10       <=           0.050690                     1.0
# 15      0.44       <=           0.522114                    34.0
# 16     -0.05        >          -0.043040                    26.0
# 17     -0.23        >          -0.082411                    14.0
# 18     -0.16        >          -0.188342                    19.0
# 19     -0.26        >          -0.107514                    18.0
# 20     -0.04       <=          -0.015821                    23.0
# 21      0.09       <=           0.059533                    33.0
# 22     -0.39       <=          -0.345973                    25.0
# 23      0.03        >           0.011233                    16.0
# 24      0.00        >           0.004147                     8.0
# 25     -0.15        >          -0.093097                    25.0
# 26     -0.20        >          -0.100801                    25.0
# 27     -0.04        >          -0.015929                    14.0
# 28     -0.04        >          -0.015821                    23.0
# 29      0.12       <=           0.041475                    13.0
# 30      0.16        >           0.061122                    13.0
# 31      0.18       <=           0.065279                    20.0
# 32     -0.20        >          -0.074301                     7.0
# 33      0.06       <=           0.022907                    24.0
# 34      0.06       <=           0.020232                    11.0
# 35      0.14        >           0.128749                     0.0
# 36      0.20        >           0.254042                    24.0
# 37     -0.28       <=          -0.136523                     0.0
# 38     -0.15       <=          -0.093097                    25.0
# 39     -0.02       <=          -0.006061                     4.0
# 40     -0.07       <=          -0.026083                    18.0
# 41      0.06        >           0.022907                    24.0
# 42     -0.05       <=          -0.022028                     7.0
# 43     -0.14       <=          -0.063458                    21.0
# 44     -0.12       <=          -0.062361                     9.0
# 45      0.17       <=           0.066831                     6.0
# 46     -0.26       <=          -0.107514                    18.0
# 47      0.04       <=           0.014997                    28.0
# 48      None     None                NaN                     NaN
# 49      None     None                NaN                     NaN
#
#     Approximation_Error                 Node_Natural
# 0              0.002152    Rh ka Compton <= 0.421114
# 1              0.000198    Rb ka + Br kb > -0.136523
# 2              0.001277   Rh ka Compton <= -0.043040
# 3              0.003364    Rh kb Compton <= 0.124124
# 4              0.000729    Rb ka + Br kb > -0.003744
# 5              0.002250    Rh ka Compton <= 0.128749
# 6              0.002081    Rb ka + Br kb > -0.062361
# 7              0.004192             K ka <= 0.254042
# 8              0.003323   Rh ka Rayleigh <= 0.127042
# 9              0.002620    Rh ka Compton > -0.345973
# 10             0.003256    Rh kb Compton <= 0.004147
# 11             0.003343      background3 <= 0.078536
# 12             0.004994  Rh ka Rayleigh <= -0.020730
# 13             0.002364      background3 <= 0.034554
# 14             0.004415    Rh kb Compton <= 0.050690
# 15             0.001978             K ka <= 0.522114
# 16             0.001277    Rh ka Compton > -0.043040
# 17             0.000027      background2 > -0.082411
# 18             0.000301             K ka > -0.188342
# 19             0.002603      background3 > -0.107514
# 20             0.003626     background3 <= -0.015821
# 21             0.000379   Rh ka Rayleigh <= 0.059533
# 22             0.002620   Rh ka Compton <= -0.345973
# 23             0.003159                Cl > 0.011233
# 24             0.003256     Rh kb Compton > 0.004147
# 25             0.002291   Rh ka Rayleigh > -0.093097
# 26             0.001115    Rh kb Compton > -0.100801
# 27             0.003224               Cl > -0.015929
# 28             0.003626      background3 > -0.015821
# 29             0.001738   Rh kb Rayleigh <= 0.041475
# 30             0.002723                Cl > 0.061122
# 31             0.002897      background2 <= 0.065279
# 32             0.001135               Cl > -0.074301
# 33             0.001215      background2 <= 0.022907
# 34             0.000916   Rh kb Rayleigh <= 0.020232
# 35             0.002250     Rh ka Compton > 0.128749
# 36             0.004192              K ka > 0.254042
# 37             0.000198   Rb ka + Br kb <= -0.136523
# 38             0.002291  Rh ka Rayleigh <= -0.093097
# 39             0.001047  Rh kb Rayleigh <= -0.006061
# 40             0.003327     background2 <= -0.026083
# 41             0.001215       background2 > 0.022907
# 42             0.000425           Br ka <= -0.022028
# 43             0.000246    K kb + Ca ka <= -0.063458
# 44             0.002081   Rb ka + Br kb <= -0.062361
# 45             0.003037            Br ka <= 0.066831
# 46             0.002603     background3 <= -0.107514
# 47             0.001527            Br ka <= 0.014997
# 48                  NaN                         None
# 49                  NaN                         None

# %% [markdown]
# ## Reconstrução de Thresholds Multivariados
#
# Agora vamos pegar os thresholds dos predicados mais importantes e reconstruí-los como espectros completos.

# %%
import plotly.graph_objects as go

n = 0
zone_name = lrc_summed_df_cov_natural.iloc[n]['Zone']
threshold_score = float(lrc_summed_df_cov_natural.iloc[n]['Threshold_Natural'])  # Corrigido: usa n em vez de 7

# Usar pca_info_dict dos dados ORIGINAIS (zones_original[1])
pca_info_dict_original = zones_original[1]

# Reconstrução: τ = mean + threshold * loadings (no espaço original)
threshold_spectrum = exp.reconstruct_threshold_to_spectrum(
    threshold_value=threshold_score,
    zone_name=zone_name,
    pca_info_dict=pca_info_dict_original
)
print(f"\nEspectro de threshold reconstruído para zona '{zone_name}':")
print(f"  - Dimensão: {len(threshold_spectrum)} variáveis espectrais")
print(f"  - Range de energias: {threshold_spectrum.index[0]} - {threshold_spectrum.index[-1]}")
print(f"  - Variância explicada pela PC1: {pca_info_dict_original[zone_name]['variance_explained']:.2%}")

# Usar dados ORIGINAIS para plotar (spectral_zones_original)
zone_df = spectral_zones_original[zone_name]

# Plotar zona com threshold (inline)
fig = go.Figure()
x_values = pd.to_numeric(zone_df.columns, errors='coerce')

# Plotar espectros das amostras coloridas por classe
colors = {'A': 'gold', 'B': 'blue'}
for idx, row in zone_df.iterrows():
    class_label = ycalclass.iloc[idx] if idx < len(ycalclass) else 'Unknown'
    fig.add_trace(go.Scatter(
        x=x_values,
        y=row.values,
        mode='lines',
        line=dict(color=colors.get(class_label, 'rgba(128,128,128,0.3)'), width=0.5),
        name=f'Class {class_label}',
        showlegend=False,
        hoverinfo='skip'
    ))

# Plotar espectro de threshold (destaque)
fig.add_trace(go.Scatter(
    x=x_values,
    y=threshold_spectrum.values,
    mode='lines',
    line=dict(color='red', width=4, dash='dash'),
    name=f'Threshold Spectrum ({threshold_spectrum.name})'
))

# Layout do gráfico
fig.update_layout(
    title=f"Zona '{zone_name}' com Threshold Multivariado (Predicado: {lrc_summed_df_cov_natural.iloc[n]['Node_Natural']})",
    xaxis_title='Energia / Comprimento de Onda',
    yaxis_title='Intensidade',
    template='plotly_white',
    showlegend=True,
    legend=dict(yanchor="top", y=0.99, xanchor="left", x=0.01)
)

fig.show()
# Out:
# Espectro de threshold reconstruído para zona 'Rh ka Compton':
#   - Dimensão: 146 variáveis espectrais
#   - Range de energias: 17 - 19.9
#   - Variância explicada pela PC1: 92.92%

# %%
import explaining as exp

# LISTA DE SEMENTES A TESTAR
random_seeds = [0, 1, 2, 3]

all_results_pert = {}
training_samples = len(Xcalclass)

# LOOP: PROCESSAR CADA SEMENTE

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando semente: {seed}")
    print(f"{'='*70}\n")
    # Bagging
    bags_result_seed = exp.bagging_predicates(
        zone_sums_df=zone_scores_df,
        y_predicted_numeric=y_pred,
        predicates_df=predicates_quantiles[0],
        n_bags=10,
        #n_predicates_per_bag=40,
        n_samples_per_bag=int(training_samples*0.8), # 80 % da base para amostrar (convertido para int)
        min_samples_per_predicate=int(training_samples*0.2), # 20 % da base para limitar (convertido para int)
        replace=False,
        sample_bagging=True,
        predicate_bagging=False,
        random_seed=seed
    )
    # Inserir classe prevista
    for bag_name, pred_dict in bags_result_seed.items(): # iterando sobre cada bag
        for pred_rule, df_info in pred_dict.items():
            df_info['Class_Predicted'] = np.where(df_info['Predicted_Y'] >= 0.5, 'A', 'B') # binarizando com threshold 0.5, A = eut, B = dist

    pert_results_seed = exp.calculate_predicate_perturbation(
        estimator=mlp_model[3],
        Xcalclass_prep=Xcalclass_prep,
        folds_struct=bags_result_seed,
        predicates_df=predicates_quantiles[0],
        spectral_cuts=spectral_cuts,
        #perturbation_value=0,
        perturbation_mode='median', # valores entre 'mean' ou 'min'
        stats_source='full', # full indica usar todas as amostras para calcular estatísticas enquanto que 'fold' usa apenas as amostras do fold atual
        #metric='mean_abs_diff',   # Média com sinal (pode ser negativo)
        aim='classification',
        metric='probability_shift', 
        verbose=True
    )

    # Salvar no dicionário principal
    all_results_pert[seed] = {
        'bags_result': bags_result_seed,
        'pert_results_dict': pert_results_seed
    }

# CONSTRUÇÃO DE GRAFOS PARA MÚLTIPLAS SEMENTES (LOOP EXTERNO)
# Dicionário para armazenar grafos
graphs_pert_by_seed = {}

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando Grafo - Semente: {seed}")
    print(f"{'='*70}\n")
    
    # Construir grafo para esta semente (sem predicates_df - extraído da regra)
    DG = exp.build_predicate_graph(
        bags_result=all_results_pert[seed]['bags_result'],
        predicate_ranking_dict=all_results_pert[seed]['pert_results_dict'],
        metric_column='Perturbation',
        random_state=seed,
        show_details=True,
        var_exp=True,
        pca_info_dict=pca_info_dict
    )

    # Armazenar grafo
    graphs_pert_by_seed[seed] = DG  

# Calcular LRC usando a função pronta do explaining.py
lrc_pert_by_seed = {}
for seed in random_seeds:
    DG = graphs_pert_by_seed[seed]
    lrc_pert_df_seed = exp.calculate_lrc_single_graph(DG, predicates_quantiles[0])
    lrc_pert_df_seed['Seed'] = seed  # Adicionar coluna com a semente
    lrc_pert_by_seed[seed] = lrc_pert_df_seed

# junando todas as colunas 'Node' de lrc_by_seed em um único dataframe
lrc_pert_all_seeds_df = pd.DataFrame()
for seed in random_seeds:
    lrc_pert_df_seed = lrc_pert_by_seed[seed].rename(columns={'Node': f'Predicate_pert_Seed_{seed}'})
    lrc_pert_all_seeds_df = pd.concat([lrc_pert_all_seeds_df, lrc_pert_df_seed[[f'Predicate_pert_Seed_{seed}']]], axis=1)

# vamos filtrar lrc_by_seed em cada semente para manter apenas as zonas espectrais únicas com maior LRC em um mesmo dataframe
lrc_pert_unique_by_seed = {}
for seed, lrc_df in lrc_pert_by_seed.items():
    lrc_pert_unique_df = lrc_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
    lrc_pert_unique_df = lrc_pert_unique_df.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
    lrc_pert_unique_by_seed[seed] = lrc_pert_unique_df

lrc_pert_all_seeds_df # exibindo o dataframe consolidado com predicados de todas as sementes
# Out:
# ======================================================================
# Processando semente: 0
# ======================================================================
#
# Bag_1 | Samples: Yes | Predicates: No (All) | Valid: 110 | Discarded: 26
# Bag_2 | Samples: Yes | Predicates: No (All) | Valid: 110 | Discarded: 26
# Bag_3 | Samples: Yes | Predicates: No (All) | Valid: 113 | Discarded: 23
# Bag_4 | Samples: Yes | Predicates: No (All) | Valid: 108 | Discarded: 28
# Bag_5 | Samples: Yes | Predicates: No (All) | Valid: 107 | Discarded: 29
# Bag_6 | Samples: Yes | Predicates: No (All) | Valid: 106 | Discarded: 30
# Bag_7 | Samples: Yes | Predicates: No (All) | Valid: 116 | Discarded: 20
# Bag_8 | Samples: Yes | Predicates: No (All) | Valid: 119 | Discarded: 17
# Bag_9 | Samples: Yes | Predicates: No (All) | Valid: 112 | Discarded: 24
# Bag_10 | Samples: Yes | Predicates: No (All) | Valid: 110 | Discarded: 26
# ======================================================================
# PERTURBATION IMPORTANCE FOR PREDICATES
# ======================================================================
# Task type (aim): classification
# Perturbation mode: median
# Statistics source: full
# Metric: probability_shift
# Total folds: 10
#
#
# [Bag_1] Processing 110 predicates...
#   Predicate: S > -0.07 (n=22)
#     Zone: 15 columns
#     Importance: 0.004256
#   Predicate: S <= -0.02 (n=12)
#     Zone: 15 columns
#     Importance: 0.003450
#   Predicate: S > -0.02 (n=16)
#     Zone: 15 columns
#     Importance: 0.004880
#   Predicate: S <= 0.01 (n=17)
#     Zone: 15 columns
#     Importance: 0.003344
#   Predicate: S > 0.01 (n=11)
#     Zone: 15 columns
#     Importance: 0.005694
#   Predicate: S <= 0.05 (n=22)
#     Zone: 15 columns
#     Importance: 0.003069
#   Predicate: Cl > -0.20 (n=22)
#     Zone: 33 columns
#     Importance: 0.010299
#   Predicate: Cl <= -0.04 (n=11)
#     Zone: 33 columns
#     Importance: 0.017436
#   Predicate: Cl > -0.04 (n=17)
#     Zone: 33 columns
#     Importance: 0.010483
#   Predicate: Cl <= 0.03 (n=17)
#     Zone: 33 columns
#     Importance: 0.012447
#   Predicate: Cl > 0.03 (n=11)
#     Zone: 33 columns
#     Importance: 0.014401
#   Predicate: Cl <= 0.16 (n=21)
#     Zone: 33 columns
#     Importance: 0.011269
#   Predicate: Cl > 0.16 (n=7)
#     Zone: 33 columns
#     Importance: 0.019051
#   Predicate: K ka <= -0.48 (n=7)
#     Zone: 23 columns
#     Importance: 0.052888
#   Predicate: K ka > -0.48 (n=21)
#     Zone: 23 columns
#     Importance: 0.023385
#   Predicate: K ka <= -0.16 (n=12)
#     Zone: 23 columns
#     Importance: 0.040003
#   Predicate: K ka > -0.16 (n=16)
#     Zone: 23 columns
#     Importance: 0.023829
#   Predicate: K ka <= 0.20 (n=16)
#     Zone: 23 columns
#     Importance: 0.031187
#   Predicate: K ka > 0.20 (n=12)
#     Zone: 23 columns
#     Importance: 0.030193
#   Predicate: K ka <= 0.44 (n=22)
#     Zone: 23 columns
#     Importance: 0.027744
#   Predicate: K kb + Ca ka <= -0.14 (n=7)
#     Zone: 21 columns
#     Importance: 0.019648
#   Predicate: K kb + Ca ka > -0.14 (n=21)
#     Zone: 21 columns
#     Importance: 0.011208
#   Predicate: K kb + Ca ka <= -0.02 (n=11)
#     Zone: 21 columns
#     Importance: 0.016078
#   Predicate: K kb + Ca ka > -0.02 (n=17)
#     Zone: 21 columns
#     Importance: 0.011532
#   Predicate: K kb + Ca ka <= 0.11 (n=16)
#     Zone: 21 columns
#     Importance: 0.014139
#   Predicate: K kb + Ca ka > 0.11 (n=12)
#     Zone: 21 columns
#     Importance: 0.012223
#   Predicate: K kb + Ca ka <= 0.16 (n=22)
#     Zone: 21 columns
#     Importance: 0.013579
#   Predicate: background1 > -0.06 (n=23)
#     Zone: 94 columns
#     Importance: 0.006405
#   Predicate: background1 <= -0.02 (n=12)
#     Zone: 94 columns
#     Importance: 0.005391
#   Predicate: background1 > -0.02 (n=16)
#     Zone: 94 columns
#     Importance: 0.006884
#   Predicate: background1 <= 0.01 (n=18)
#     Zone: 94 columns
#     Importance: 0.005442
#   Predicate: background1 > 0.01 (n=10)
#     Zone: 94 columns
#     Importance: 0.007689
#   Predicate: background1 <= 0.06 (n=23)
#     Zone: 94 columns
#     Importance: 0.005436
#   Predicate: Mn > -0.05 (n=23)
#     Zone: 18 columns
#     Importance: 0.002469
#   Predicate: Mn <= -0.03 (n=10)
#     Zone: 18 columns
#     Importance: 0.002562
#   Predicate: Mn > -0.03 (n=18)
#     Zone: 18 columns
#     Importance: 0.002506
#   Predicate: Mn <= -0.02 (n=15)
#     Zone: 18 columns
#     Importance: 0.002440
#   Predicate: Mn > -0.02 (n=13)
#     Zone: 18 columns
#     Importance: 0.002625
#   Predicate: Mn <= 0.02 (n=21)
#     Zone: 18 columns
#     Importance: 0.002181
#   Predicate: Mn > 0.02 (n=7)
#     Zone: 18 columns
#     Importance: 0.003560
#   Predicate: Fe > -0.12 (n=22)
#     Zone: 64 columns
#     Importance: 0.009329
#   Predicate: Fe <= -0.07 (n=13)
#     Zone: 64 columns
#     Importance: 0.005481
#   Predicate: Fe > -0.07 (n=15)
#     Zone: 64 columns
#     Importance: 0.011875
#   Predicate: Fe <= -0.01 (n=16)
#     Zone: 64 columns
#     Importance: 0.005716
#   Predicate: Fe > -0.01 (n=12)
#     Zone: 64 columns
#     Importance: 0.013160
#   Predicate: Fe <= 0.09 (n=22)
#     Zone: 64 columns
#     Importance: 0.005345
#   Predicate: Cu > -0.13 (n=22)
#     Zone: 52 columns
#     Importance: 0.005304
#   Predicate: Cu <= -0.05 (n=12)
#     Zone: 52 columns
#     Importance: 0.004090
#   Predicate: Cu > -0.05 (n=16)
#     Zone: 52 columns
#     Importance: 0.005858
#   Predicate: Cu <= 0.01 (n=16)
#     Zone: 52 columns
#     Importance: 0.004156
#   Predicate: Cu > 0.01 (n=12)
#     Zone: 52 columns
#     Importance: 0.006359
#   Predicate: Cu <= 0.11 (n=21)
#     Zone: 52 columns
#     Importance: 0.004962
#   Predicate: Cu > 0.11 (n=7)
#     Zone: 52 columns
#     Importance: 0.005516
#   Predicate: Zn <= -0.10 (n=7)
#     Zone: 27 columns
#     Importance: 0.010780
#   Predicate: Zn > -0.10 (n=21)
#     Zone: 27 columns
#     Importance: 0.007627
#   Predicate: Zn <= -0.03 (n=11)
#     Zone: 27 columns
#     Importance: 0.008668
#   Predicate: Zn > -0.03 (n=17)
#     Zone: 27 columns
#     Importance: 0.008252
#   Predicate: Zn <= 0.02 (n=16)
#     Zone: 27 columns
#     Importance: 0.006509
#   Predicate: Zn > 0.02 (n=12)
#     Zone: 27 columns
#     Importance: 0.010957
#   Predicate: Zn <= 0.07 (n=21)
#     Zone: 27 columns
#     Importance: 0.006520
#   Predicate: Zn > 0.07 (n=7)
#     Zone: 27 columns
#     Importance: 0.014103
#   Predicate: background2 > -0.23 (n=22)
#     Zone: 137 columns
#     Importance: 0.006321
#   Predicate: background2 <= -0.07 (n=11)
#     Zone: 137 columns
#     Importance: 0.008100
#   Predicate: background2 > -0.07 (n=17)
#     Zone: 137 columns
#     Importance: 0.006468
#   Predicate: background2 <= 0.06 (n=17)
#     Zone: 137 columns
#     Importance: 0.007751
#   Predicate: background2 > 0.06 (n=11)
#     Zone: 137 columns
#     Importance: 0.006117
#   Predicate: background2 <= 0.18 (n=21)
#     Zone: 137 columns
#     Importance: 0.006973
#   Predicate: background2 > 0.18 (n=7)
#     Zone: 137 columns
#     Importance: 0.007518
#   Predicate: Br ka > -0.15 (n=22)
#     Zone: 48 columns
#     Importance: 0.003452
#   Predicate: Br ka <= -0.05 (n=11)
#     Zone: 48 columns
#     Importance: 0.003604
#   Predicate: Br ka > -0.05 (n=17)
#     Zone: 48 columns
#     Importance: 0.003237
#   Predicate: Br ka <= 0.04 (n=17)
#     Zone: 48 columns
#     Importance: 0.003036
#   Predicate: Br ka > 0.04 (n=11)
#     Zone: 48 columns
#     Importance: 0.003913
#   Predicate: Br ka <= 0.17 (n=22)
#     Zone: 48 columns
#     Importance: 0.002966
#   Predicate: Rb ka + Br kb > -0.28 (n=23)
#     Zone: 66 columns
#     Importance: 0.028365
#   Predicate: Rb ka + Br kb <= -0.12 (n=10)
#     Zone: 66 columns
#     Importance: 0.020319
#   Predicate: Rb ka + Br kb > -0.12 (n=18)
#     Zone: 66 columns
#     Importance: 0.032499
#   Predicate: Rb ka + Br kb <= -0.02 (n=17)
#     Zone: 66 columns
#     Importance: 0.014504
#   Predicate: Rb ka + Br kb > -0.02 (n=11)
#     Zone: 66 columns
#     Importance: 0.049236
#   Predicate: Rb ka + Br kb <= 0.14 (n=23)
#     Zone: 66 columns
#     Importance: 0.015364
#   Predicate: background3 > -0.26 (n=22)
#     Zone: 161 columns
#     Importance: 0.014754
#   Predicate: background3 <= -0.04 (n=11)
#     Zone: 161 columns
#     Importance: 0.018132
#   Predicate: background3 > -0.04 (n=17)
#     Zone: 161 columns
#     Importance: 0.016088
#   Predicate: background3 <= 0.08 (n=16)
#     Zone: 161 columns
#     Importance: 0.015828
#   Predicate: background3 > 0.08 (n=12)
#     Zone: 161 columns
#     Importance: 0.018309
#   Predicate: background3 <= 0.19 (n=23)
#     Zone: 161 columns
#     Importance: 0.013925
#   Predicate: Rh ka Compton > -0.39 (n=22)
#     Zone: 146 columns
#     Importance: 0.025189
#   Predicate: Rh ka Compton <= -0.05 (n=11)
#     Zone: 146 columns
#     Importance: 0.043486
#   Predicate: Rh ka Compton > -0.05 (n=17)
#     Zone: 146 columns
#     Importance: 0.025919
#   Predicate: Rh ka Compton <= 0.14 (n=18)
#     Zone: 146 columns
#     Importance: 0.028371
#   Predicate: Rh ka Compton > 0.14 (n=10)
#     Zone: 146 columns
#     Importance: 0.040828
#   Predicate: Rh ka Compton <= 0.45 (n=22)
#     Zone: 146 columns
#     Importance: 0.025384
#   Predicate: Rh ka Rayleigh > -0.15 (n=23)
#     Zone: 46 columns
#     Importance: 0.007231
#   Predicate: Rh ka Rayleigh <= -0.02 (n=12)
#     Zone: 46 columns
#     Importance: 0.011098
#   Predicate: Rh ka Rayleigh > -0.02 (n=16)
#     Zone: 46 columns
#     Importance: 0.007098
#   Predicate: Rh ka Rayleigh <= 0.09 (n=18)
#     Zone: 46 columns
#     Importance: 0.008218
#   Predicate: Rh ka Rayleigh > 0.09 (n=10)
#     Zone: 46 columns
#     Importance: 0.009882
#   Predicate: Rh ka Rayleigh <= 0.21 (n=22)
#     Zone: 46 columns
#     Importance: 0.007511
#   Predicate: Rh kb Compton > -0.20 (n=22)
#     Zone: 76 columns
#     Importance: 0.011773
#   Predicate: Rh kb Compton <= 0.00 (n=11)
#     Zone: 76 columns
#     Importance: 0.018065
#   Predicate: Rh kb Compton > 0.00 (n=17)
#     Zone: 76 columns
#     Importance: 0.011867
#   Predicate: Rh kb Compton <= 0.10 (n=18)
#     Zone: 76 columns
#     Importance: 0.012141
#   Predicate: Rh kb Compton > 0.10 (n=10)
#     Zone: 76 columns
#     Importance: 0.018192
#   Predicate: Rh kb Compton <= 0.25 (n=23)
#     Zone: 76 columns
#     Importance: 0.011619
#   Predicate: Rh kb Rayleigh > -0.08 (n=22)
#     Zone: 40 columns
#     Importance: 0.002764
#   Predicate: Rh kb Rayleigh <= -0.02 (n=12)
#     Zone: 40 columns
#     Importance: 0.002657
#   Predicate: Rh kb Rayleigh > -0.02 (n=16)
#     Zone: 40 columns
#     Importance: 0.002951
#   Predicate: Rh kb Rayleigh <= 0.06 (n=19)
#     Zone: 40 columns
#     Importance: 0.002696
#   Predicate: Rh kb Rayleigh > 0.06 (n=9)
#     Zone: 40 columns
#     Importance: 0.003097
#   Predicate: Rh kb Rayleigh <= 0.12 (n=23)
#     Zone: 40 columns
#     Importance: 0.002920
#
# [Bag_2] Processing 110 predicates...
#   Predicate: S <= -0.07 (n=7)
#     Zone: 15 columns
#     Importance: 0.004229
#   Predicate: S > -0.07 (n=21)
#     Zone: 15 columns
#     Importance: 0.004257
#   Predicate: S <= -0.02 (n=12)
#     Zone: 15 columns
#     Importance: 0.003242
#   Predicate: S > -0.02 (n=16)
#     Zone: 15 columns
#     Importance: 0.005006
#   Predicate: S <= 0.01 (n=18)
#     Zone: 15 columns
#     Importance: 0.002998
#   Predicate: S > 0.01 (n=10)
#     Zone: 15 columns
#     Importance: 0.006504
#   Predicate: S <= 0.05 (n=21)
#     Zone: 15 columns
#     Importance: 0.002785
#   Predicate: S > 0.05 (n=7)
#     Zone: 15 columns
#     Importance: 0.008646
#   Predicate: Cl > -0.20 (n=22)
#     Zone: 33 columns
#     Importance: 0.009955
#   Predicate: Cl <= -0.04 (n=10)
#     Zone: 33 columns
#     Importance: 0.016948
#   Predicate: Cl > -0.04 (n=18)
#     Zone: 33 columns
#     Importance: 0.010291
#   Predicate: Cl <= 0.03 (n=15)
#     Zone: 33 columns
#     Importance: 0.012331
#   Predicate: Cl > 0.03 (n=13)
#     Zone: 33 columns
#     Importance: 0.013058
#   Predicate: Cl <= 0.16 (n=20)
#     Zone: 33 columns
#     Importance: 0.010729
#   Predicate: Cl > 0.16 (n=8)
#     Zone: 33 columns
#     Importance: 0.017518
#   Predicate: K ka > -0.48 (n=23)
#     Zone: 23 columns
#     Importance: 0.022199
#   Predicate: K ka <= -0.16 (n=11)
#     Zone: 23 columns
#     Importance: 0.036147
#   Predicate: K ka > -0.16 (n=17)
#     Zone: 23 columns
#     Importance: 0.021960
#   Predicate: K ka <= 0.20 (n=16)
#     Zone: 23 columns
#     Importance: 0.026623
#   Predicate: K ka > 0.20 (n=12)
#     Zone: 23 columns
#     Importance: 0.028747
#   Predicate: K ka <= 0.44 (n=22)
#     Zone: 23 columns
#     Importance: 0.023637
#   Predicate: K kb + Ca ka <= -0.14 (n=8)
#     Zone: 21 columns
#     Importance: 0.017255
#   Predicate: K kb + Ca ka > -0.14 (n=20)
#     Zone: 21 columns
#     Importance: 0.008874
#   Predicate: K kb + Ca ka <= -0.02 (n=13)
#     Zone: 21 columns
#     Importance: 0.013900
#   Predicate: K kb + Ca ka > -0.02 (n=15)
#     Zone: 21 columns
#     Importance: 0.008987
#   Predicate: K kb + Ca ka <= 0.11 (n=19)
#     Zone: 21 columns
#     Importance: 0.012041
#   Predicate: K kb + Ca ka > 0.11 (n=9)
#     Zone: 21 columns
#     Importance: 0.009638
#   Predicate: K kb + Ca ka <= 0.16 (n=23)
#     Zone: 21 columns
#     Importance: 0.011050
#   Predicate: background1 <= -0.06 (n=7)
#     Zone: 94 columns
#     Importance: 0.005824
#   Predicate: background1 > -0.06 (n=21)
#     Zone: 94 columns
#     Importance: 0.006430
#   Predicate: background1 <= -0.02 (n=12)
#     Zone: 94 columns
#     Importance: 0.005729
#   Predicate: background1 > -0.02 (n=16)
#     Zone: 94 columns
#     Importance: 0.006691
#   Predicate: background1 <= 0.01 (n=19)
#     Zone: 94 columns
#     Importance: 0.005752
#   Predicate: background1 > 0.01 (n=9)
#     Zone: 94 columns
#     Importance: 0.007390
#   Predicate: background1 <= 0.06 (n=24)
#     Zone: 94 columns
#     Importance: 0.005912
#   Predicate: Mn > -0.05 (n=23)
#     Zone: 18 columns
#     Importance: 0.002227
#   Predicate: Mn <= -0.03 (n=9)
#     Zone: 18 columns
#     Importance: 0.002351
#   Predicate: Mn > -0.03 (n=19)
#     Zone: 18 columns
#     Importance: 0.002315
#   Predicate: Mn <= -0.02 (n=15)
#     Zone: 18 columns
#     Importance: 0.002058
#   Predicate: Mn > -0.02 (n=13)
#     Zone: 18 columns
#     Importance: 0.002636
#   Predicate: Mn <= 0.02 (n=22)
#     Zone: 18 columns
#     Importance: 0.001989
#   Predicate: Fe <= -0.12 (n=7)
#     Zone: 64 columns
#     Importance: 0.007739
#   Predicate: Fe > -0.12 (n=21)
#     Zone: 64 columns
#     Importance: 0.008700
#   Predicate: Fe <= -0.07 (n=13)
#     Zone: 64 columns
#     Importance: 0.006131
#   Predicate: Fe > -0.07 (n=15)
#     Zone: 64 columns
#     Importance: 0.010479
#   Predicate: Fe <= -0.01 (n=18)
#     Zone: 64 columns
#     Importance: 0.005777
#   Predicate: Fe > -0.01 (n=10)
#     Zone: 64 columns
#     Importance: 0.013289
#   Predicate: Fe <= 0.09 (n=24)
#     Zone: 64 columns
#     Importance: 0.005330
#   Predicate: Cu > -0.13 (n=22)
#     Zone: 52 columns
#     Importance: 0.006089
#   Predicate: Cu <= -0.05 (n=13)
#     Zone: 52 columns
#     Importance: 0.003347
#   Predicate: Cu > -0.05 (n=15)
#     Zone: 52 columns
#     Importance: 0.007446
#   Predicate: Cu <= 0.01 (n=16)
#     Zone: 52 columns
#     Importance: 0.003779
#   Predicate: Cu > 0.01 (n=12)
#     Zone: 52 columns
#     Importance: 0.007895
#   Predicate: Cu <= 0.11 (n=21)
#     Zone: 52 columns
#     Importance: 0.004951
#   Predicate: Cu > 0.11 (n=7)
#     Zone: 52 columns
#     Importance: 0.007320
#   Predicate: Zn <= -0.10 (n=7)
#     Zone: 27 columns
#     Importance: 0.010020
#   Predicate: Zn > -0.10 (n=21)
#     Zone: 27 columns
#     Importance: 0.006446
#   Predicate: Zn <= -0.03 (n=12)
#     Zone: 27 columns
#     Importance: 0.007565
#   Predicate: Zn > -0.03 (n=16)
#     Zone: 27 columns
#     Importance: 0.007171
#   Predicate: Zn <= 0.02 (n=18)
#     Zone: 27 columns
#     Importance: 0.005575
#   Predicate: Zn > 0.02 (n=10)
#     Zone: 27 columns
#     Importance: 0.010517
#   Predicate: Zn <= 0.07 (n=22)
#     Zone: 27 columns
#     Importance: 0.005518
#   Predicate: background2 > -0.23 (n=22)
#     Zone: 137 columns
#     Importance: 0.005684
#   Predicate: background2 <= -0.07 (n=12)
#     Zone: 137 columns
#     Importance: 0.007502
#   Predicate: background2 > -0.07 (n=16)
#     Zone: 137 columns
#     Importance: 0.005625
#   Predicate: background2 <= 0.06 (n=18)
#     Zone: 137 columns
#     Importance: 0.006747
#   Predicate: background2 > 0.06 (n=10)
#     Zone: 137 columns
#     Importance: 0.005859
#   Predicate: background2 <= 0.18 (n=22)
#     Zone: 137 columns
#     Importance: 0.006186
#   Predicate: Br ka > -0.15 (n=22)
#     Zone: 48 columns
#     Importance: 0.002748
#   Predicate: Br ka <= -0.05 (n=12)
#     Zone: 48 columns
#     Importance: 0.003312
#   Predicate: Br ka > -0.05 (n=16)
#     Zone: 48 columns
#     Importance: 0.002320
#   Predicate: Br ka <= 0.04 (n=17)
#     Zone: 48 columns
#     Importance: 0.002714
#   Predicate: Br ka > 0.04 (n=11)
#     Zone: 48 columns
#     Importance: 0.002792
#   Predicate: Br ka <= 0.17 (n=23)
#     Zone: 48 columns
#     Importance: 0.002712
#   Predicate: Rb ka + Br kb > -0.28 (n=22)
#     Zone: 66 columns
#     Importance: 0.026481
#   Predicate: Rb ka + Br kb <= -0.12 (n=11)
#     Zone: 66 columns
#     Importance: 0.021677
#   Predicate: Rb ka + Br kb > -0.12 (n=17)
#     Zone: 66 columns
#     Importance: 0.030304
#   Predicate: Rb ka + Br kb <= -0.02 (n=17)
#     Zone: 66 columns
#     Importance: 0.016260
#   Predicate: Rb ka + Br kb > -0.02 (n=11)
#     Zone: 66 columns
#     Importance: 0.043382
#   Predicate: Rb ka + Br kb <= 0.14 (n=23)
#     Zone: 66 columns
#     Importance: 0.016662
#   Predicate: background3 > -0.26 (n=23)
#     Zone: 161 columns
#     Importance: 0.014834
#   Predicate: background3 <= -0.04 (n=12)
#     Zone: 161 columns
#     Importance: 0.016990
#   Predicate: background3 > -0.04 (n=16)
#     Zone: 161 columns
#     Importance: 0.016717
#   Predicate: background3 <= 0.08 (n=17)
#     Zone: 161 columns
#     Importance: 0.015157
#   Predicate: background3 > 0.08 (n=11)
#     Zone: 161 columns
#     Importance: 0.019426
#   Predicate: background3 <= 0.19 (n=23)
#     Zone: 161 columns
#     Importance: 0.014224
#   Predicate: Rh ka Compton > -0.39 (n=22)
#     Zone: 146 columns
#     Importance: 0.025274
#   Predicate: Rh ka Compton <= -0.05 (n=12)
#     Zone: 146 columns
#     Importance: 0.043059
#   Predicate: Rh ka Compton > -0.05 (n=16)
#     Zone: 146 columns
#     Importance: 0.026807
#   Predicate: Rh ka Compton <= 0.14 (n=18)
#     Zone: 146 columns
#     Importance: 0.030197
#   Predicate: Rh ka Compton > 0.14 (n=10)
#     Zone: 146 columns
#     Importance: 0.040207
#   Predicate: Rh ka Compton <= 0.45 (n=22)
#     Zone: 146 columns
#     Importance: 0.027733
#   Predicate: Rh ka Rayleigh > -0.15 (n=22)
#     Zone: 46 columns
#     Importance: 0.007339
#   Predicate: Rh ka Rayleigh <= -0.02 (n=12)
#     Zone: 46 columns
#     Importance: 0.011824
#   Predicate: Rh ka Rayleigh > -0.02 (n=16)
#     Zone: 46 columns
#     Importance: 0.007404
#   Predicate: Rh ka Rayleigh <= 0.09 (n=18)
#     Zone: 46 columns
#     Importance: 0.008702
#   Predicate: Rh ka Rayleigh > 0.09 (n=10)
#     Zone: 46 columns
#     Importance: 0.010370
#   Predicate: Rh ka Rayleigh <= 0.21 (n=22)
#     Zone: 46 columns
#     Importance: 0.008040
#   Predicate: Rh kb Compton > -0.20 (n=22)
#     Zone: 76 columns
#     Importance: 0.011869
#   Predicate: Rh kb Compton <= 0.00 (n=12)
#     Zone: 76 columns
#     Importance: 0.016931
#   Predicate: Rh kb Compton > 0.00 (n=16)
#     Zone: 76 columns
#     Importance: 0.012658
#   Predicate: Rh kb Compton <= 0.10 (n=18)
#     Zone: 76 columns
#     Importance: 0.012226
#   Predicate: Rh kb Compton > 0.10 (n=10)
#     Zone: 76 columns
#     Importance: 0.018564
#   Predicate: Rh kb Compton <= 0.25 (n=22)
#     Zone: 76 columns
#     Importance: 0.011893
#   Predicate: Rh kb Rayleigh > -0.08 (n=22)
#     Zone: 40 columns
#     Importance: 0.002829
#   Predicate: Rh kb Rayleigh <= -0.02 (n=12)
#     Zone: 40 columns
#     Importance: 0.002648
#   Predicate: Rh kb Rayleigh > -0.02 (n=16)
#     Zone: 40 columns
#     Importance: 0.002946
#   Predicate: Rh kb Rayleigh <= 0.06 (n=19)
#     Zone: 40 columns
#     Importance: 0.002690
#   Predicate: Rh kb Rayleigh > 0.06 (n=9)
#     Zone: 40 columns
#     Importance: 0.003088
#   Predicate: Rh kb Rayleigh <= 0.12 (n=22)
#     Zone: 40 columns
#     Importance: 0.002966
#
# [Bag_3] Processing 113 predicates...
#   Predicate: S <= -0.07 (n=7)
#     Zone: 15 columns
#     Importance: 0.004229
#   Predicate: S > -0.07 (n=21)
#     Zone: 15 columns
#     Importance: 0.003752
#   Predicate: S <= -0.02 (n=12)
#     Zone: 15 columns
#     Importance: 0.003747
#   Predicate: S > -0.02 (n=16)
#     Zone: 15 columns
#     Importance: 0.003965
#   Predicate: S <= 0.01 (n=18)
#     Zone: 15 columns
#     Importance: 0.003335
#   Predicate: S > 0.01 (n=10)
#     Zone: 15 columns
#     Importance: 0.004838
#   Predicate: S <= 0.05 (n=23)
#     Zone: 15 columns
#     Importance: 0.003160
#   Predicate: Cl <= -0.20 (n=8)
#     Zone: 33 columns
#     Importance: 0.022385
#   Predicate: Cl > -0.20 (n=20)
#     Zone: 33 columns
#     Importance: 0.009102
#   Predicate: Cl <= -0.04 (n=12)
#     Zone: 33 columns
#     Importance: 0.017738
#   Predicate: Cl > -0.04 (n=16)
#     Zone: 33 columns
#     Importance: 0.009266
#   Predicate: Cl <= 0.03 (n=17)
#     Zone: 33 columns
#     Importance: 0.013468
#   Predicate: Cl > 0.03 (n=11)
#     Zone: 33 columns
#     Importance: 0.012015
#   Predicate: Cl <= 0.16 (n=22)
#     Zone: 33 columns
#     Importance: 0.011753
#   Predicate: K ka > -0.48 (n=22)
#     Zone: 23 columns
#     Importance: 0.020583
#   Predicate: K ka <= -0.16 (n=11)
#     Zone: 23 columns
#     Importance: 0.038326
#   Predicate: K ka > -0.16 (n=17)
#     Zone: 23 columns
#     Importance: 0.019543
#   Predicate: K ka <= 0.20 (n=17)
#     Zone: 23 columns
#     Importance: 0.027210
#   Predicate: K ka > 0.20 (n=11)
#     Zone: 23 columns
#     Importance: 0.026477
#   Predicate: K ka <= 0.44 (n=23)
#     Zone: 23 columns
#     Importance: 0.024495
#   Predicate: K kb + Ca ka <= -0.14 (n=9)
#     Zone: 21 columns
#     Importance: 0.018777
#   Predicate: K kb + Ca ka > -0.14 (n=19)
#     Zone: 21 columns
#     Importance: 0.009870
#   Predicate: K kb + Ca ka <= -0.02 (n=13)
#     Zone: 21 columns
#     Importance: 0.016060
#   Predicate: K kb + Ca ka > -0.02 (n=15)
#     Zone: 21 columns
#     Importance: 0.009849
#   Predicate: K kb + Ca ka <= 0.11 (n=18)
#     Zone: 21 columns
#     Importance: 0.013813
#   Predicate: K kb + Ca ka > 0.11 (n=10)
#     Zone: 21 columns
#     Importance: 0.010788
#   Predicate: K kb + Ca ka <= 0.16 (n=22)
#     Zone: 21 columns
#     Importance: 0.012455
#   Predicate: background1 <= -0.06 (n=7)
#     Zone: 94 columns
#     Importance: 0.005824
#   Predicate: background1 > -0.06 (n=21)
#     Zone: 94 columns
#     Importance: 0.006699
#   Predicate: background1 <= -0.02 (n=12)
#     Zone: 94 columns
#     Importance: 0.006082
#   Predicate: background1 > -0.02 (n=16)
#     Zone: 94 columns
#     Importance: 0.006779
#   Predicate: background1 <= 0.01 (n=17)
#     Zone: 94 columns
#     Importance: 0.006257
#   Predicate: background1 > 0.01 (n=11)
#     Zone: 94 columns
#     Importance: 0.006825
#   Predicate: background1 <= 0.06 (n=23)
#     Zone: 94 columns
#     Importance: 0.006337
#   Predicate: Mn > -0.05 (n=23)
#     Zone: 18 columns
#     Importance: 0.002214
#   Predicate: Mn <= -0.03 (n=9)
#     Zone: 18 columns
#     Importance: 0.002363
#   Predicate: Mn > -0.03 (n=19)
#     Zone: 18 columns
#     Importance: 0.002299
#   Predicate: Mn <= -0.02 (n=15)
#     Zone: 18 columns
#     Importance: 0.002202
#   Predicate: Mn > -0.02 (n=13)
#     Zone: 18 columns
#     Importance: 0.002456
#   Predicate: Mn <= 0.02 (n=23)
#     Zone: 18 columns
#     Importance: 0.001989
#   Predicate: Fe <= -0.12 (n=7)
#     Zone: 64 columns
#     Importance: 0.007739
#   Predicate: Fe > -0.12 (n=21)
#     Zone: 64 columns
#     Importance: 0.008767
#   Predicate: Fe <= -0.07 (n=11)
#     Zone: 64 columns
#     Importance: 0.006544
#   Predicate: Fe > -0.07 (n=17)
#     Zone: 64 columns
#     Importance: 0.009783
#   Predicate: Fe <= -0.01 (n=17)
#     Zone: 64 columns
#     Importance: 0.006045
#   Predicate: Fe > -0.01 (n=11)
#     Zone: 64 columns
#     Importance: 0.012319
#   Predicate: Fe <= 0.09 (n=22)
#     Zone: 64 columns
#     Importance: 0.005337
#   Predicate: Cu > -0.13 (n=23)
#     Zone: 52 columns
#     Importance: 0.006061
#   Predicate: Cu <= -0.05 (n=10)
#     Zone: 52 columns
#     Importance: 0.002742
#   Predicate: Cu > -0.05 (n=18)
#     Zone: 52 columns
#     Importance: 0.006920
#   Predicate: Cu <= 0.01 (n=15)
#     Zone: 52 columns
#     Importance: 0.003484
#   Predicate: Cu > 0.01 (n=13)
#     Zone: 52 columns
#     Importance: 0.007671
#   Predicate: Cu <= 0.11 (n=21)
#     Zone: 52 columns
#     Importance: 0.004797
#   Predicate: Cu > 0.11 (n=7)
#     Zone: 52 columns
#     Importance: 0.007320
#   Predicate: Zn > -0.10 (n=22)
#     Zone: 27 columns
#     Importance: 0.006731
#   Predicate: Zn <= -0.03 (n=10)
#     Zone: 27 columns
#     Importance: 0.008178
#   Predicate: Zn > -0.03 (n=18)
#     Zone: 27 columns
#     Importance: 0.007088
#   Predicate: Zn <= 0.02 (n=16)
#     Zone: 27 columns
#     Importance: 0.005728
#   Predicate: Zn > 0.02 (n=12)
#     Zone: 27 columns
#     Importance: 0.009809
#   Predicate: Zn <= 0.07 (n=22)
#     Zone: 27 columns
#     Importance: 0.005692
#   Predicate: background2 > -0.23 (n=23)
#     Zone: 137 columns
#     Importance: 0.005940
#   Predicate: background2 <= -0.07 (n=10)
#     Zone: 137 columns
#     Importance: 0.006673
#   Predicate: background2 > -0.07 (n=18)
#     Zone: 137 columns
#     Importance: 0.005797
#   Predicate: background2 <= 0.06 (n=16)
#     Zone: 137 columns
#     Importance: 0.006371
#   Predicate: background2 > 0.06 (n=12)
#     Zone: 137 columns
#     Importance: 0.005761
#   Predicate: background2 <= 0.18 (n=22)
#     Zone: 137 columns
#     Importance: 0.005872
#   Predicate: Br ka > -0.15 (n=23)
#     Zone: 48 columns
#     Importance: 0.003226
#   Predicate: Br ka <= -0.05 (n=10)
#     Zone: 48 columns
#     Importance: 0.002866
#   Predicate: Br ka > -0.05 (n=18)
#     Zone: 48 columns
#     Importance: 0.003027
#   Predicate: Br ka <= 0.04 (n=15)
#     Zone: 48 columns
#     Importance: 0.002621
#   Predicate: Br ka > 0.04 (n=13)
#     Zone: 48 columns
#     Importance: 0.003372
#   Predicate: Br ka <= 0.17 (n=23)
#     Zone: 48 columns
#     Importance: 0.002923
#   Predicate: Rb ka + Br kb > -0.28 (n=22)
#     Zone: 66 columns
#     Importance: 0.025691
#   Predicate: Rb ka + Br kb <= -0.12 (n=11)
#     Zone: 66 columns
#     Importance: 0.021848
#   Predicate: Rb ka + Br kb > -0.12 (n=17)
#     Zone: 66 columns
#     Importance: 0.029172
#   Predicate: Rb ka + Br kb <= -0.02 (n=18)
#     Zone: 66 columns
#     Importance: 0.015075
#   Predicate: Rb ka + Br kb > -0.02 (n=10)
#     Zone: 66 columns
#     Importance: 0.046489
#   Predicate: Rb ka + Br kb <= 0.14 (n=23)
#     Zone: 66 columns
#     Importance: 0.015906
#   Predicate: background3 > -0.26 (n=24)
#     Zone: 161 columns
#     Importance: 0.015747
#   Predicate: background3 <= -0.04 (n=10)
#     Zone: 161 columns
#     Importance: 0.017126
#   Predicate: background3 > -0.04 (n=18)
#     Zone: 161 columns
#     Importance: 0.017520
#   Predicate: background3 <= 0.08 (n=15)
#     Zone: 161 columns
#     Importance: 0.015003
#   Predicate: background3 > 0.08 (n=13)
#     Zone: 161 columns
#     Importance: 0.020121
#   Predicate: background3 <= 0.19 (n=20)
#     Zone: 161 columns
#     Importance: 0.014202
#   Predicate: background3 > 0.19 (n=8)
#     Zone: 161 columns
#     Importance: 0.025323
#   Predicate: Rh ka Compton > -0.39 (n=23)
#     Zone: 146 columns
#     Importance: 0.029059
#   Predicate: Rh ka Compton <= -0.05 (n=11)
#     Zone: 146 columns
#     Importance: 0.041163
#   Predicate: Rh ka Compton > -0.05 (n=17)
#     Zone: 146 columns
#     Importance: 0.031836
#   Predicate: Rh ka Compton <= 0.14 (n=16)
#     Zone: 146 columns
#     Importance: 0.029795
#   Predicate: Rh ka Compton > 0.14 (n=12)
#     Zone: 146 columns
#     Importance: 0.043107
#   Predicate: Rh ka Compton <= 0.45 (n=20)
#     Zone: 146 columns
#     Importance: 0.027359
#   Predicate: Rh ka Compton > 0.45 (n=8)
#     Zone: 146 columns
#     Importance: 0.055854
#   Predicate: Rh ka Rayleigh > -0.15 (n=23)
#     Zone: 46 columns
#     Importance: 0.007784
#   Predicate: Rh ka Rayleigh <= -0.02 (n=11)
#     Zone: 46 columns
#     Importance: 0.011223
#   Predicate: Rh ka Rayleigh > -0.02 (n=17)
#     Zone: 46 columns
#     Importance: 0.008002
#   Predicate: Rh ka Rayleigh <= 0.09 (n=16)
#     Zone: 46 columns
#     Importance: 0.008525
#   Predicate: Rh ka Rayleigh > 0.09 (n=12)
#     Zone: 46 columns
#     Importance: 0.010256
#   Predicate: Rh ka Rayleigh <= 0.21 (n=21)
#     Zone: 46 columns
#     Importance: 0.007652
#   Predicate: Rh ka Rayleigh > 0.21 (n=7)
#     Zone: 46 columns
#     Importance: 0.014114
#   Predicate: Rh kb Compton > -0.20 (n=23)
#     Zone: 76 columns
#     Importance: 0.013110
#   Predicate: Rh kb Compton <= 0.00 (n=11)
#     Zone: 76 columns
#     Importance: 0.016378
#   Predicate: Rh kb Compton > 0.00 (n=17)
#     Zone: 76 columns
#     Importance: 0.014292
#   Predicate: Rh kb Compton <= 0.10 (n=17)
#     Zone: 76 columns
#     Importance: 0.011591
#   Predicate: Rh kb Compton > 0.10 (n=11)
#     Zone: 76 columns
#     Importance: 0.020551
#   Predicate: Rh kb Compton <= 0.25 (n=20)
#     Zone: 76 columns
#     Importance: 0.011353
#   Predicate: Rh kb Compton > 0.25 (n=8)
#     Zone: 76 columns
#     Importance: 0.024506
#   Predicate: Rh kb Rayleigh > -0.08 (n=23)
#     Zone: 40 columns
#     Importance: 0.002845
#   Predicate: Rh kb Rayleigh <= -0.02 (n=11)
#     Zone: 40 columns
#     Importance: 0.002882
#   Predicate: Rh kb Rayleigh > -0.02 (n=17)
#     Zone: 40 columns
#     Importance: 0.002960
#   Predicate: Rh kb Rayleigh <= 0.06 (n=18)
#     Zone: 40 columns
#     Importance: 0.002704
#   Predicate: Rh kb Rayleigh > 0.06 (n=10)
#     Zone: 40 columns
#     Importance: 0.003334
#   Predicate: Rh kb Rayleigh <= 0.12 (n=21)
#     Zone: 40 columns
#     Importance: 0.003004
#   Predicate: Rh kb Rayleigh > 0.12 (n=7)
#     Zone: 40 columns
#     Importance: 0.002705
#
# [Bag_4] Processing 108 predicates...
#   Predicate: S > -0.07 (n=23)
#     Zone: 15 columns
#     Importance: 0.004424
#   Predicate: S <= -0.02 (n=11)
#     Zone: 15 columns
#     Importance: 0.003412
#   Predicate: S > -0.02 (n=17)
#     Zone: 15 columns
#     Importance: 0.005070
#   Predicate: S <= 0.01 (n=14)
#     Zone: 15 columns
#     Importance: 0.003263
#   Predicate: S > 0.01 (n=14)
#     Zone: 15 columns
#     Importance: 0.005575
#   Predicate: S <= 0.05 (n=21)
#     Zone: 15 columns
#     Importance: 0.003009
#   Predicate: S > 0.05 (n=7)
#     Zone: 15 columns
#     Importance: 0.008646
#   Predicate: Cl > -0.20 (n=23)
#     Zone: 33 columns
#     Importance: 0.009718
#   Predicate: Cl <= -0.04 (n=11)
#     Zone: 33 columns
#     Importance: 0.016455
#   Predicate: Cl > -0.04 (n=17)
#     Zone: 33 columns
#     Importance: 0.009741
#   Predicate: Cl <= 0.03 (n=17)
#     Zone: 33 columns
#     Importance: 0.011645
#   Predicate: Cl > 0.03 (n=11)
#     Zone: 33 columns
#     Importance: 0.013512
#   Predicate: Cl <= 0.16 (n=22)
#     Zone: 33 columns
#     Importance: 0.010286
#   Predicate: K ka > -0.48 (n=23)
#     Zone: 23 columns
#     Importance: 0.023506
#   Predicate: K ka <= -0.16 (n=10)
#     Zone: 23 columns
#     Importance: 0.034637
#   Predicate: K ka > -0.16 (n=18)
#     Zone: 23 columns
#     Importance: 0.023998
#   Predicate: K ka <= 0.20 (n=14)
#     Zone: 23 columns
#     Importance: 0.026626
#   Predicate: K ka > 0.20 (n=14)
#     Zone: 23 columns
#     Importance: 0.028969
#   Predicate: K ka <= 0.44 (n=21)
#     Zone: 23 columns
#     Importance: 0.023635
#   Predicate: K ka > 0.44 (n=7)
#     Zone: 23 columns
#     Importance: 0.040285
#   Predicate: K kb + Ca ka > -0.14 (n=22)
#     Zone: 21 columns
#     Importance: 0.012017
#   Predicate: K kb + Ca ka <= -0.02 (n=9)
#     Zone: 21 columns
#     Importance: 0.016031
#   Predicate: K kb + Ca ka > -0.02 (n=19)
#     Zone: 21 columns
#     Importance: 0.012267
#   Predicate: K kb + Ca ka <= 0.11 (n=15)
#     Zone: 21 columns
#     Importance: 0.013300
#   Predicate: K kb + Ca ka > 0.11 (n=13)
#     Zone: 21 columns
#     Importance: 0.013681
#   Predicate: K kb + Ca ka <= 0.16 (n=21)
#     Zone: 21 columns
#     Importance: 0.012953
#   Predicate: K kb + Ca ka > 0.16 (n=7)
#     Zone: 21 columns
#     Importance: 0.015048
#   Predicate: background1 > -0.06 (n=22)
#     Zone: 94 columns
#     Importance: 0.006314
#   Predicate: background1 <= -0.02 (n=13)
#     Zone: 94 columns
#     Importance: 0.005243
#   Predicate: background1 > -0.02 (n=15)
#     Zone: 94 columns
#     Importance: 0.006970
#   Predicate: background1 <= 0.01 (n=18)
#     Zone: 94 columns
#     Importance: 0.005193
#   Predicate: background1 > 0.01 (n=10)
#     Zone: 94 columns
#     Importance: 0.007923
#   Predicate: background1 <= 0.06 (n=23)
#     Zone: 94 columns
#     Importance: 0.005242
#   Predicate: Mn > -0.05 (n=22)
#     Zone: 18 columns
#     Importance: 0.002224
#   Predicate: Mn <= -0.03 (n=9)
#     Zone: 18 columns
#     Importance: 0.002075
#   Predicate: Mn > -0.03 (n=19)
#     Zone: 18 columns
#     Importance: 0.002336
#   Predicate: Mn <= -0.02 (n=14)
#     Zone: 18 columns
#     Importance: 0.002118
#   Predicate: Mn > -0.02 (n=14)
#     Zone: 18 columns
#     Importance: 0.002386
#   Predicate: Mn <= 0.02 (n=22)
#     Zone: 18 columns
#     Importance: 0.001916
#   Predicate: Fe > -0.12 (n=22)
#     Zone: 64 columns
#     Importance: 0.008963
#   Predicate: Fe <= -0.07 (n=13)
#     Zone: 64 columns
#     Importance: 0.005839
#   Predicate: Fe > -0.07 (n=15)
#     Zone: 64 columns
#     Importance: 0.011339
#   Predicate: Fe <= -0.01 (n=17)
#     Zone: 64 columns
#     Importance: 0.005538
#   Predicate: Fe > -0.01 (n=11)
#     Zone: 64 columns
#     Importance: 0.013803
#   Predicate: Fe <= 0.09 (n=23)
#     Zone: 64 columns
#     Importance: 0.005290
#   Predicate: Cu > -0.13 (n=23)
#     Zone: 52 columns
#     Importance: 0.005552
#   Predicate: Cu <= -0.05 (n=12)
#     Zone: 52 columns
#     Importance: 0.004138
#   Predicate: Cu > -0.05 (n=16)
#     Zone: 52 columns
#     Importance: 0.006364
#   Predicate: Cu <= 0.01 (n=18)
#     Zone: 52 columns
#     Importance: 0.004265
#   Predicate: Cu > 0.01 (n=10)
#     Zone: 52 columns
#     Importance: 0.007472
#   Predicate: Cu <= 0.11 (n=22)
#     Zone: 52 columns
#     Importance: 0.004913
#   Predicate: Zn > -0.10 (n=22)
#     Zone: 27 columns
#     Importance: 0.007066
#   Predicate: Zn <= -0.03 (n=11)
#     Zone: 27 columns
#     Importance: 0.007651
#   Predicate: Zn > -0.03 (n=17)
#     Zone: 27 columns
#     Importance: 0.007814
#   Predicate: Zn <= 0.02 (n=18)
#     Zone: 27 columns
#     Importance: 0.005709
#   Predicate: Zn > 0.02 (n=10)
#     Zone: 27 columns
#     Importance: 0.011424
#   Predicate: Zn <= 0.07 (n=23)
#     Zone: 27 columns
#     Importance: 0.005893
#   Predicate: background2 > -0.23 (n=22)
#     Zone: 137 columns
#     Importance: 0.005326
#   Predicate: background2 <= -0.07 (n=11)
#     Zone: 137 columns
#     Importance: 0.007691
#   Predicate: background2 > -0.07 (n=17)
#     Zone: 137 columns
#     Importance: 0.005445
#   Predicate: background2 <= 0.06 (n=18)
#     Zone: 137 columns
#     Importance: 0.006918
#   Predicate: background2 > 0.06 (n=10)
#     Zone: 137 columns
#     Importance: 0.005264
#   Predicate: background2 <= 0.18 (n=23)
#     Zone: 137 columns
#     Importance: 0.006154
#   Predicate: Br ka <= -0.15 (n=7)
#     Zone: 48 columns
#     Importance: 0.002919
#   Predicate: Br ka > -0.15 (n=21)
#     Zone: 48 columns
#     Importance: 0.003544
#   Predicate: Br ka <= -0.05 (n=12)
#     Zone: 48 columns
#     Importance: 0.003331
#   Predicate: Br ka > -0.05 (n=16)
#     Zone: 48 columns
#     Importance: 0.003431
#   Predicate: Br ka <= 0.04 (n=18)
#     Zone: 48 columns
#     Importance: 0.003096
#   Predicate: Br ka > 0.04 (n=10)
#     Zone: 48 columns
#     Importance: 0.003914
#   Predicate: Br ka <= 0.17 (n=24)
#     Zone: 48 columns
#     Importance: 0.003020
#   Predicate: Rb ka + Br kb > -0.28 (n=22)
#     Zone: 66 columns
#     Importance: 0.025840
#   Predicate: Rb ka + Br kb <= -0.12 (n=10)
#     Zone: 66 columns
#     Importance: 0.022984
#   Predicate: Rb ka + Br kb > -0.12 (n=18)
#     Zone: 66 columns
#     Importance: 0.028525
#   Predicate: Rb ka + Br kb <= -0.02 (n=18)
#     Zone: 66 columns
#     Importance: 0.015304
#   Predicate: Rb ka + Br kb > -0.02 (n=10)
#     Zone: 66 columns
#     Importance: 0.046782
#   Predicate: Rb ka + Br kb <= 0.14 (n=23)
#     Zone: 66 columns
#     Importance: 0.015729
#   Predicate: background3 > -0.26 (n=22)
#     Zone: 161 columns
#     Importance: 0.014996
#   Predicate: background3 <= -0.04 (n=12)
#     Zone: 161 columns
#     Importance: 0.018423
#   Predicate: background3 > -0.04 (n=16)
#     Zone: 161 columns
#     Importance: 0.016075
#   Predicate: background3 <= 0.08 (n=17)
#     Zone: 161 columns
#     Importance: 0.017257
#   Predicate: background3 > 0.08 (n=11)
#     Zone: 161 columns
#     Importance: 0.016809
#   Predicate: background3 <= 0.19 (n=23)
#     Zone: 161 columns
#     Importance: 0.015660
#   Predicate: Rh ka Compton <= -0.39 (n=7)
#     Zone: 146 columns
#     Importance: 0.058275
#   Predicate: Rh ka Compton > -0.39 (n=21)
#     Zone: 146 columns
#     Importance: 0.023491
#   Predicate: Rh ka Compton <= -0.05 (n=12)
#     Zone: 146 columns
#     Importance: 0.041683
#   Predicate: Rh ka Compton > -0.05 (n=16)
#     Zone: 146 columns
#     Importance: 0.025066
#   Predicate: Rh ka Compton <= 0.14 (n=18)
#     Zone: 146 columns
#     Importance: 0.029187
#   Predicate: Rh ka Compton > 0.14 (n=10)
#     Zone: 146 columns
#     Importance: 0.037588
#   Predicate: Rh ka Compton <= 0.45 (n=23)
#     Zone: 146 columns
#     Importance: 0.026131
#   Predicate: Rh ka Rayleigh > -0.15 (n=23)
#     Zone: 46 columns
#     Importance: 0.007090
#   Predicate: Rh ka Rayleigh <= -0.02 (n=12)
#     Zone: 46 columns
#     Importance: 0.011318
#   Predicate: Rh ka Rayleigh > -0.02 (n=16)
#     Zone: 46 columns
#     Importance: 0.007016
#   Predicate: Rh ka Rayleigh <= 0.09 (n=17)
#     Zone: 46 columns
#     Importance: 0.008800
#   Predicate: Rh ka Rayleigh > 0.09 (n=11)
#     Zone: 46 columns
#     Importance: 0.008952
#   Predicate: Rh ka Rayleigh <= 0.21 (n=23)
#     Zone: 46 columns
#     Importance: 0.007808
#   Predicate: Rh kb Compton <= -0.20 (n=7)
#     Zone: 76 columns
#     Importance: 0.022985
#   Predicate: Rh kb Compton > -0.20 (n=21)
#     Zone: 76 columns
#     Importance: 0.011295
#   Predicate: Rh kb Compton <= 0.00 (n=12)
#     Zone: 76 columns
#     Importance: 0.016856
#   Predicate: Rh kb Compton > 0.00 (n=16)
#     Zone: 76 columns
#     Importance: 0.012239
#   Predicate: Rh kb Compton <= 0.10 (n=17)
#     Zone: 76 columns
#     Importance: 0.012701
#   Predicate: Rh kb Compton > 0.10 (n=11)
#     Zone: 76 columns
#     Importance: 0.016562
#   Predicate: Rh kb Compton <= 0.25 (n=24)
#     Zone: 76 columns
#     Importance: 0.012129
#   Predicate: Rh kb Rayleigh > -0.08 (n=22)
#     Zone: 40 columns
#     Importance: 0.002478
#   Predicate: Rh kb Rayleigh <= -0.02 (n=12)
#     Zone: 40 columns
#     Importance: 0.002731
#   Predicate: Rh kb Rayleigh > -0.02 (n=16)
#     Zone: 40 columns
#     Importance: 0.002544
#   Predicate: Rh kb Rayleigh <= 0.06 (n=20)
#     Zone: 40 columns
#     Importance: 0.002516
#   Predicate: Rh kb Rayleigh > 0.06 (n=8)
#     Zone: 40 columns
#     Importance: 0.002894
#   Predicate: Rh kb Rayleigh <= 0.12 (n=23)
#     Zone: 40 columns
#     Importance: 0.002676
#
# [Bag_5] Processing 107 predicates...
#   Predicate: S > -0.07 (n=22)
#     Zone: 15 columns
#     Importance: 0.004375
#   Predicate: S <= -0.02 (n=11)
#     Zone: 15 columns
#     Importance: 0.003642
#   Predicate: S > -0.02 (n=17)
#     Zone: 15 columns
#     Importance: 0.004978
#   Predicate: S <= 0.01 (n=16)
#     Zone: 15 columns
#     Importance: 0.003343
#   Predicate: S > 0.01 (n=12)
#     Zone: 15 columns
#     Importance: 0.005933
#   Predicate: S <= 0.05 (n=21)
#     Zone: 15 columns
#     Importance: 0.003055
#   Predicate: S > 0.05 (n=7)
#     Zone: 15 columns
#     Importance: 0.008646
#   Predicate: Cl <= -0.20 (n=8)
#     Zone: 33 columns
#     Importance: 0.022385
#   Predicate: Cl > -0.20 (n=20)
#     Zone: 33 columns
#     Importance: 0.010396
#   Predicate: Cl <= -0.04 (n=12)
#     Zone: 33 columns
#     Importance: 0.017738
#   Predicate: Cl > -0.04 (n=16)
#     Zone: 33 columns
#     Importance: 0.010884
#   Predicate: Cl <= 0.03 (n=16)
#     Zone: 33 columns
#     Importance: 0.014003
#   Predicate: Cl > 0.03 (n=12)
#     Zone: 33 columns
#     Importance: 0.013580
#   Predicate: Cl <= 0.16 (n=21)
#     Zone: 33 columns
#     Importance: 0.012079
#   Predicate: Cl > 0.16 (n=7)
#     Zone: 33 columns
#     Importance: 0.019051
#   Predicate: K ka > -0.48 (n=23)
#     Zone: 23 columns
#     Importance: 0.022679
#   Predicate: K ka <= -0.16 (n=12)
#     Zone: 23 columns
#     Importance: 0.034389
#   Predicate: K ka > -0.16 (n=16)
#     Zone: 23 columns
#     Importance: 0.023082
#   Predicate: K ka <= 0.20 (n=17)
#     Zone: 23 columns
#     Importance: 0.025577
#   Predicate: K ka > 0.20 (n=11)
#     Zone: 23 columns
#     Importance: 0.031561
#   Predicate: K ka <= 0.44 (n=22)
#     Zone: 23 columns
#     Importance: 0.024139
#   Predicate: K kb + Ca ka <= -0.14 (n=8)
#     Zone: 21 columns
#     Importance: 0.017255
#   Predicate: K kb + Ca ka > -0.14 (n=20)
#     Zone: 21 columns
#     Importance: 0.008591
#   Predicate: K kb + Ca ka <= -0.02 (n=13)
#     Zone: 21 columns
#     Importance: 0.013900
#   Predicate: K kb + Ca ka > -0.02 (n=15)
#     Zone: 21 columns
#     Importance: 0.008610
#   Predicate: K kb + Ca ka <= 0.11 (n=19)
#     Zone: 21 columns
#     Importance: 0.012119
#   Predicate: K kb + Ca ka > 0.11 (n=9)
#     Zone: 21 columns
#     Importance: 0.008843
#   Predicate: K kb + Ca ka <= 0.16 (n=23)
#     Zone: 21 columns
#     Importance: 0.011115
#   Predicate: background1 > -0.06 (n=22)
#     Zone: 94 columns
#     Importance: 0.006480
#   Predicate: background1 <= -0.02 (n=12)
#     Zone: 94 columns
#     Importance: 0.005244
#   Predicate: background1 > -0.02 (n=16)
#     Zone: 94 columns
#     Importance: 0.007089
#   Predicate: background1 <= 0.01 (n=18)
#     Zone: 94 columns
#     Importance: 0.005399
#   Predicate: background1 > 0.01 (n=10)
#     Zone: 94 columns
#     Importance: 0.007918
#   Predicate: background1 <= 0.06 (n=25)
#     Zone: 94 columns
#     Importance: 0.005803
#   Predicate: Mn > -0.05 (n=23)
#     Zone: 18 columns
#     Importance: 0.002376
#   Predicate: Mn <= -0.03 (n=9)
#     Zone: 18 columns
#     Importance: 0.002312
#   Predicate: Mn > -0.03 (n=19)
#     Zone: 18 columns
#     Importance: 0.002514
#   Predicate: Mn <= -0.02 (n=14)
#     Zone: 18 columns
#     Importance: 0.002180
#   Predicate: Mn > -0.02 (n=14)
#     Zone: 18 columns
#     Importance: 0.002719
#   Predicate: Mn <= 0.02 (n=22)
#     Zone: 18 columns
#     Importance: 0.002145
#   Predicate: Fe > -0.12 (n=23)
#     Zone: 64 columns
#     Importance: 0.008503
#   Predicate: Fe <= -0.07 (n=11)
#     Zone: 64 columns
#     Importance: 0.006690
#   Predicate: Fe > -0.07 (n=17)
#     Zone: 64 columns
#     Importance: 0.009946
#   Predicate: Fe <= -0.01 (n=16)
#     Zone: 64 columns
#     Importance: 0.006118
#   Predicate: Fe > -0.01 (n=12)
#     Zone: 64 columns
#     Importance: 0.012066
#   Predicate: Fe <= 0.09 (n=22)
#     Zone: 64 columns
#     Importance: 0.005537
#   Predicate: Cu > -0.13 (n=24)
#     Zone: 52 columns
#     Importance: 0.005996
#   Predicate: Cu <= -0.05 (n=12)
#     Zone: 52 columns
#     Importance: 0.003495
#   Predicate: Cu > -0.05 (n=16)
#     Zone: 52 columns
#     Importance: 0.007346
#   Predicate: Cu <= 0.01 (n=15)
#     Zone: 52 columns
#     Importance: 0.003800
#   Predicate: Cu > 0.01 (n=13)
#     Zone: 52 columns
#     Importance: 0.007883
#   Predicate: Cu <= 0.11 (n=21)
#     Zone: 52 columns
#     Importance: 0.005154
#   Predicate: Cu > 0.11 (n=7)
#     Zone: 52 columns
#     Importance: 0.007320
#   Predicate: Zn > -0.10 (n=23)
#     Zone: 27 columns
#     Importance: 0.006641
#   Predicate: Zn <= -0.03 (n=11)
#     Zone: 27 columns
#     Importance: 0.007065
#   Predicate: Zn > -0.03 (n=17)
#     Zone: 27 columns
#     Importance: 0.007381
#   Predicate: Zn <= 0.02 (n=16)
#     Zone: 27 columns
#     Importance: 0.005223
#   Predicate: Zn > 0.02 (n=12)
#     Zone: 27 columns
#     Importance: 0.009968
#   Predicate: Zn <= 0.07 (n=22)
#     Zone: 27 columns
#     Importance: 0.005412
#   Predicate: background2 > -0.23 (n=22)
#     Zone: 137 columns
#     Importance: 0.006280
#   Predicate: background2 <= -0.07 (n=11)
#     Zone: 137 columns
#     Importance: 0.008006
#   Predicate: background2 > -0.07 (n=17)
#     Zone: 137 columns
#     Importance: 0.006477
#   Predicate: background2 <= 0.06 (n=18)
#     Zone: 137 columns
#     Importance: 0.007264
#   Predicate: background2 > 0.06 (n=10)
#     Zone: 137 columns
#     Importance: 0.006742
#   Predicate: background2 <= 0.18 (n=22)
#     Zone: 137 columns
#     Importance: 0.007011
#   Predicate: Br ka > -0.15 (n=22)
#     Zone: 48 columns
#     Importance: 0.003305
#   Predicate: Br ka <= -0.05 (n=12)
#     Zone: 48 columns
#     Importance: 0.003578
#   Predicate: Br ka > -0.05 (n=16)
#     Zone: 48 columns
#     Importance: 0.003087
#   Predicate: Br ka <= 0.04 (n=17)
#     Zone: 48 columns
#     Importance: 0.003143
#   Predicate: Br ka > 0.04 (n=11)
#     Zone: 48 columns
#     Importance: 0.003536
#   Predicate: Br ka <= 0.17 (n=23)
#     Zone: 48 columns
#     Importance: 0.003384
#   Predicate: Rb ka + Br kb > -0.28 (n=22)
#     Zone: 66 columns
#     Importance: 0.027145
#   Predicate: Rb ka + Br kb <= -0.12 (n=11)
#     Zone: 66 columns
#     Importance: 0.022212
#   Predicate: Rb ka + Br kb > -0.12 (n=17)
#     Zone: 66 columns
#     Importance: 0.031110
#   Predicate: Rb ka + Br kb <= -0.02 (n=17)
#     Zone: 66 columns
#     Importance: 0.017412
#   Predicate: Rb ka + Br kb > -0.02 (n=11)
#     Zone: 66 columns
#     Importance: 0.043382
#   Predicate: Rb ka + Br kb <= 0.14 (n=23)
#     Zone: 66 columns
#     Importance: 0.017513
#   Predicate: background3 > -0.26 (n=23)
#     Zone: 161 columns
#     Importance: 0.015354
#   Predicate: background3 <= -0.04 (n=12)
#     Zone: 161 columns
#     Importance: 0.016060
#   Predicate: background3 > -0.04 (n=16)
#     Zone: 161 columns
#     Importance: 0.017464
#   Predicate: background3 <= 0.08 (n=16)
#     Zone: 161 columns
#     Importance: 0.014962
#   Predicate: background3 > 0.08 (n=12)
#     Zone: 161 columns
#     Importance: 0.019396
#   Predicate: background3 <= 0.19 (n=23)
#     Zone: 161 columns
#     Importance: 0.013884
#   Predicate: Rh ka Compton > -0.39 (n=22)
#     Zone: 146 columns
#     Importance: 0.025137
#   Predicate: Rh ka Compton <= -0.05 (n=12)
#     Zone: 146 columns
#     Importance: 0.038851
#   Predicate: Rh ka Compton > -0.05 (n=16)
#     Zone: 146 columns
#     Importance: 0.026618
#   Predicate: Rh ka Compton <= 0.14 (n=17)
#     Zone: 146 columns
#     Importance: 0.028581
#   Predicate: Rh ka Compton > 0.14 (n=11)
#     Zone: 146 columns
#     Importance: 0.036929
#   Predicate: Rh ka Compton <= 0.45 (n=22)
#     Zone: 146 columns
#     Importance: 0.025855
#   Predicate: Rh ka Rayleigh > -0.15 (n=23)
#     Zone: 46 columns
#     Importance: 0.007500
#   Predicate: Rh ka Rayleigh <= -0.02 (n=12)
#     Zone: 46 columns
#     Importance: 0.010913
#   Predicate: Rh ka Rayleigh > -0.02 (n=16)
#     Zone: 46 columns
#     Importance: 0.007352
#   Predicate: Rh ka Rayleigh <= 0.09 (n=17)
#     Zone: 46 columns
#     Importance: 0.008514
#   Predicate: Rh ka Rayleigh > 0.09 (n=11)
#     Zone: 46 columns
#     Importance: 0.009440
#   Predicate: Rh ka Rayleigh <= 0.21 (n=22)
#     Zone: 46 columns
#     Importance: 0.007685
#   Predicate: Rh kb Compton > -0.20 (n=22)
#     Zone: 76 columns
#     Importance: 0.012089
#   Predicate: Rh kb Compton <= 0.00 (n=12)
#     Zone: 76 columns
#     Importance: 0.015564
#   Predicate: Rh kb Compton > 0.00 (n=16)
#     Zone: 76 columns
#     Importance: 0.012961
#   Predicate: Rh kb Compton <= 0.10 (n=17)
#     Zone: 76 columns
#     Importance: 0.011785
#   Predicate: Rh kb Compton > 0.10 (n=11)
#     Zone: 76 columns
#     Importance: 0.017618
#   Predicate: Rh kb Compton <= 0.25 (n=22)
#     Zone: 76 columns
#     Importance: 0.011320
#   Predicate: Rh kb Rayleigh > -0.08 (n=22)
#     Zone: 40 columns
#     Importance: 0.002993
#   Predicate: Rh kb Rayleigh <= -0.02 (n=12)
#     Zone: 40 columns
#     Importance: 0.002801
#   Predicate: Rh kb Rayleigh > -0.02 (n=16)
#     Zone: 40 columns
#     Importance: 0.003171
#   Predicate: Rh kb Rayleigh <= 0.06 (n=18)
#     Zone: 40 columns
#     Importance: 0.002805
#   Predicate: Rh kb Rayleigh > 0.06 (n=10)
#     Zone: 40 columns
#     Importance: 0.003385
#   Predicate: Rh kb Rayleigh <= 0.12 (n=22)
#     Zone: 40 columns
#     Importance: 0.003020
#
# [Bag_6] Processing 106 predicates...
#   Predicate: S <= -0.07 (n=7)
#     Zone: 15 columns
#     Importance: 0.004157
#   Predicate: S > -0.07 (n=21)
#     Zone: 15 columns
#     Importance: 0.004574
#   Predicate: S <= -0.02 (n=12)
#     Zone: 15 columns
#     Importance: 0.003395
#   Predicate: S > -0.02 (n=16)
#     Zone: 15 columns
#     Importance: 0.005276
#   Predicate: S <= 0.01 (n=16)
#     Zone: 15 columns
#     Importance: 0.003392
#   Predicate: S > 0.01 (n=12)
#     Zone: 15 columns
#     Importance: 0.005906
#   Predicate: S <= 0.05 (n=22)
#     Zone: 15 columns
#     Importance: 0.003060
#   Predicate: Cl > -0.20 (n=22)
#     Zone: 33 columns
#     Importance: 0.010510
#   Predicate: Cl <= -0.04 (n=12)
#     Zone: 33 columns
#     Importance: 0.016210
#   Predicate: Cl > -0.04 (n=16)
#     Zone: 33 columns
#     Importance: 0.010831
#   Predicate: Cl <= 0.03 (n=16)
#     Zone: 33 columns
#     Importance: 0.012732
#   Predicate: Cl > 0.03 (n=12)
#     Zone: 33 columns
#     Importance: 0.013675
#   Predicate: Cl <= 0.16 (n=20)
#     Zone: 33 columns
#     Importance: 0.011384
#   Predicate: Cl > 0.16 (n=8)
#     Zone: 33 columns
#     Importance: 0.017518
#   Predicate: K ka > -0.48 (n=24)
#     Zone: 23 columns
#     Importance: 0.022599
#   Predicate: K ka <= -0.16 (n=9)
#     Zone: 23 columns
# ...
# Removed: Rh ka Compton > -0.05 -> K ka <= 0.20 (0.0235) | Kept: K ka <= 0.20 -> Rh ka Compton > -0.05 (0.0836)
# Removed: Rh ka Compton > -0.39 -> Rb ka + Br kb > -0.28 (0.0243) | Kept: Rb ka + Br kb > -0.28 -> Rh ka Compton > -0.39 (0.0376)
# Removed: Rh ka Compton > -0.39 -> K ka <= 0.44 (0.0453) | Kept: K ka <= 0.44 -> Rh ka Compton > -0.39 (0.0764)
# Removed: Rb ka + Br kb > -0.28 -> K ka <= 0.44 (0.0194) | Kept: K ka <= 0.44 -> Rb ka + Br kb > -0.28 (0.0229)
# Removed: Rb ka + Br kb > -0.28 -> K ka <= 0.20 (0.0224) | Kept: K ka <= 0.20 -> Rb ka + Br kb > -0.28 (0.0298)
# Removed: Rh kb Compton <= -0.20 -> K ka <= 0.44 (0.0187) | Kept: K ka <= 0.44 -> Rh kb Compton <= -0.20 (0.0248)
# Removed: background3 > 0.08 -> K ka > -0.48 (0.0155) | Kept: K ka > -0.48 -> background3 > 0.08 (0.0188)
# Removed: background3 <= -0.04 -> background3 > 0.08 (0.0118) | Kept: background3 > 0.08 -> background3 <= -0.04 (0.0371)
# Removed: background3 > 0.08 -> Rh kb Compton > 0.10 (0.0248) | Kept: Rh kb Compton > 0.10 -> background3 > 0.08 (0.0316)
# Removed: K ka > -0.48 -> K ka > -0.16 (0.0820) | Kept: K ka > -0.16 -> K ka > -0.48 (0.0881)
# Removed: Cl <= -0.20 -> K ka > -0.48 (0.0184) | Kept: K ka > -0.48 -> Cl <= -0.20 (0.0452)
# Removed: Rb ka + Br kb <= -0.12 -> K ka > -0.16 (0.0161) | Kept: K ka > -0.16 -> Rb ka + Br kb <= -0.12 (0.0415)
# Removed: K ka > -0.16 -> Rh kb Compton <= 0.00 (0.0205) | Kept: Rh kb Compton <= 0.00 -> K ka > -0.16 (0.0317)
# Removed: K kb + Ca ka <= -0.14 -> Rb ka + Br kb <= -0.12 (0.0135) | Kept: Rb ka + Br kb <= -0.12 -> K kb + Ca ka <= -0.14 (0.0309)
# Removed: background3 > -0.04 -> background3 <= -0.04 (0.0119) | Kept: background3 <= -0.04 -> background3 > -0.04 (0.0135)
# Removed: background3 > -0.04 -> Cl <= -0.04 (0.0111) | Kept: Cl <= -0.04 -> background3 > -0.04 (0.0138)
# Removed: Rh kb Compton <= 0.00 -> Rh kb Compton > 0.10 (0.0322) | Kept: Rh kb Compton > 0.10 -> Rh kb Compton <= 0.00 (0.0464)
# Removed: Cl > 0.16 -> Rh kb Compton <= 0.00 (0.0140) | Kept: Rh kb Compton <= 0.00 -> Cl > 0.16 (0.0149)
# Removed: background3 <= 0.08 -> Cl <= -0.04 (0.0115) | Kept: Cl <= -0.04 -> background3 <= 0.08 (0.0128)
# Removed: Cl <= -0.04 -> background3 > -0.26 (0.0123) | Kept: background3 > -0.26 -> Cl <= -0.04 (0.0228)
# Removed: background3 > -0.26 -> background3 <= 0.19 (0.0210) | Kept: background3 <= 0.19 -> background3 > -0.26 (0.0320)
# Removed: K kb + Ca ka > 0.16 -> background3 > -0.26 (0.0102) | Kept: background3 > -0.26 -> K kb + Ca ka > 0.16 (0.0102)
# Removed: background3 > -0.26 -> Rb ka + Br kb <= -0.02 (0.0107) | Kept: Rb ka + Br kb <= -0.02 -> background3 > -0.26 (0.0115)
# Removed: Rb ka + Br kb <= 0.14 -> Cl <= -0.04 (0.0240) | Kept: Cl <= -0.04 -> Rb ka + Br kb <= 0.14 (0.0260)
# Removed: Rb ka + Br kb <= 0.14 -> Rb ka + Br kb <= -0.02 (0.0121) | Kept: Rb ka + Br kb <= -0.02 -> Rb ka + Br kb <= 0.14 (0.0131)
# Removed: Rb ka + Br kb <= 0.14 -> K kb + Ca ka > 0.11 (0.0115) | Kept: K kb + Ca ka > 0.11 -> Rb ka + Br kb <= 0.14 (0.0193)
# Removed: K kb + Ca ka <= -0.02 -> Rb ka + Br kb <= -0.02 (0.0098) | Kept: Rb ka + Br kb <= -0.02 -> K kb + Ca ka <= -0.02 (0.0115)
# Removed: K kb + Ca ka <= 0.11 -> Rb ka + Br kb <= -0.02 (0.0088) | Kept: Rb ka + Br kb <= -0.02 -> K kb + Ca ka <= 0.11 (0.0114)
# Removed: background3 <= 0.19 -> K kb + Ca ka <= -0.02 (0.0103) | Kept: K kb + Ca ka <= -0.02 -> background3 <= 0.19 (0.0106)
# Removed: Rh kb Compton <= 0.10 -> Rh kb Compton <= 0.25 (0.0113) | Kept: Rh kb Compton <= 0.25 -> Rh kb Compton <= 0.10 (0.0199)
# Removed: Rh kb Compton > 0.00 -> Rh kb Compton <= 0.10 (0.0103) | Kept: Rh kb Compton <= 0.10 -> Rh kb Compton > 0.00 (0.0211)
# Removed: K kb + Ca ka > 0.11 -> K kb + Ca ka <= -0.02 (0.0087) | Kept: K kb + Ca ka <= -0.02 -> K kb + Ca ka > 0.11 (0.0095)
# Removed: K kb + Ca ka <= -0.02 -> K kb + Ca ka > 0.16 (0.0111) | Kept: K kb + Ca ka > 0.16 -> K kb + Ca ka <= -0.02 (0.0205)
# Removed: Rh kb Compton <= 0.25 -> Rh kb Compton > 0.00 (0.0108) | Kept: Rh kb Compton > 0.00 -> Rh kb Compton <= 0.25 (0.0327)
# Removed: Rh kb Compton > -0.20 -> Rh kb Compton <= 0.25 (0.0099) | Kept: Rh kb Compton <= 0.25 -> Rh kb Compton > -0.20 (0.0101)
# Removed: Rh ka Rayleigh <= -0.02 -> Cl > 0.03 (0.0094) | Kept: Cl > 0.03 -> Rh ka Rayleigh <= -0.02 (0.0200)
# Removed: Cl > 0.03 -> Cl <= 0.16 (0.0083) | Kept: Cl <= 0.16 -> Cl > 0.03 (0.0092)
# Removed: Rh kb Compton > -0.20 -> Rh ka Rayleigh <= -0.02 (0.0100) | Kept: Rh ka Rayleigh <= -0.02 -> Rh kb Compton > -0.20 (0.0203)
# Removed: Rh ka Rayleigh <= -0.02 -> K kb + Ca ka > -0.14 (0.0096) | Kept: K kb + Ca ka > -0.14 -> Rh ka Rayleigh <= -0.02 (0.0144)
# Removed: Fe > -0.07 -> Rh ka Rayleigh <= -0.02 (0.0057) | Kept: Rh ka Rayleigh <= -0.02 -> Fe > -0.07 (0.0086)
# Removed: Cl <= 0.03 -> Rh kb Compton > -0.20 (0.0100) | Kept: Rh kb Compton > -0.20 -> Cl <= 0.03 (0.0212)
# Removed: K kb + Ca ka <= 0.16 -> Rh kb Compton > -0.20 (0.0086) | Kept: Rh kb Compton > -0.20 -> K kb + Ca ka <= 0.16 (0.0100)
# Removed: Rh ka Rayleigh > 0.21 -> Rh kb Compton > -0.20 (0.0103) | Kept: Rh kb Compton > -0.20 -> Rh ka Rayleigh > 0.21 (0.0220)
# Removed: K kb + Ca ka > -0.14 -> Cl <= 0.03 (0.0073) | Kept: Cl <= 0.03 -> K kb + Ca ka > -0.14 (0.0192)
# Removed: K kb + Ca ka > -0.02 -> K kb + Ca ka <= 0.11 (0.0072) | Kept: K kb + Ca ka <= 0.11 -> K kb + Ca ka > -0.02 (0.0158)
# Removed: K kb + Ca ka <= 0.11 -> K kb + Ca ka <= 0.16 (0.0095) | Kept: K kb + Ca ka <= 0.16 -> K kb + Ca ka <= 0.11 (0.0409)
# Removed: Fe > -0.07 -> Rh ka Rayleigh <= 0.09 (0.0052) | Kept: Rh ka Rayleigh <= 0.09 -> Fe > -0.07 (0.0067)
# Removed: Fe > -0.07 -> Rh ka Rayleigh > 0.09 (0.0059) | Kept: Rh ka Rayleigh > 0.09 -> Fe > -0.07 (0.0082)
# Removed: Cu > 0.01 -> Fe > -0.07 (0.0040) | Kept: Fe > -0.07 -> Cu > 0.01 (0.0046)
# Removed: Fe > -0.07 -> Cl > -0.04 (0.0059) | Kept: Cl > -0.04 -> Fe > -0.07 (0.0060)
# Removed: Zn <= -0.10 -> Rh ka Rayleigh > 0.09 (0.0060) | Kept: Rh ka Rayleigh > 0.09 -> Zn <= -0.10 (0.0081)
# Removed: K kb + Ca ka <= 0.16 -> Cl <= 0.16 (0.0066) | Kept: Cl <= 0.16 -> K kb + Ca ka <= 0.16 (0.0091)
# Removed: Rh ka Rayleigh > 0.09 -> Cl <= 0.16 (0.0077) | Kept: Cl <= 0.16 -> Rh ka Rayleigh > 0.09 (0.0082)
# Removed: Cl > -0.20 -> Cl > -0.04 (0.0066) | Kept: Cl > -0.04 -> Cl > -0.20 (0.0086)
# Removed: Cl > -0.20 -> Zn > 0.02 (0.0083) | Kept: Zn > 0.02 -> Cl > -0.20 (0.0184)
# Removed: Zn > 0.02 -> Rh ka Rayleigh > 0.09 (0.0062) | Kept: Rh ka Rayleigh > 0.09 -> Zn > 0.02 (0.0166)
# Removed: background1 > 0.01 -> Cl > -0.20 (0.0015) | Kept: Cl > -0.20 -> background1 > 0.01 (0.0069)
# Removed: Rh ka Rayleigh <= 0.09 -> Rh ka Rayleigh > 0.09 (0.0162) | Kept: Rh ka Rayleigh > 0.09 -> Rh ka Rayleigh <= 0.09 (0.0238)
# Removed: Fe > -0.12 -> background2 <= -0.07 (0.0049) | Kept: background2 <= -0.07 -> Fe > -0.12 (0.0116)
# Removed: background1 > -0.06 -> Fe > -0.12 (0.0012) | Kept: Fe > -0.12 -> background1 > -0.06 (0.0039)
# Removed: background2 <= -0.07 -> Zn <= -0.03 (0.0055) | Kept: Zn <= -0.03 -> background2 <= -0.07 (0.0150)
# Removed: Zn <= -0.03 -> Zn > -0.03 (0.0042) | Kept: Zn > -0.03 -> Zn <= -0.03 (0.0043)
# Removed: Zn <= -0.03 -> Rh ka Rayleigh > -0.15 (0.0048) | Kept: Rh ka Rayleigh > -0.15 -> Zn <= -0.03 (0.0062)
# Removed: background1 > 0.01 -> Zn <= -0.03 (0.0028) | Kept: Zn <= -0.03 -> background1 > 0.01 (0.0052)
# Removed: Cu > 0.01 -> Rh ka Rayleigh > -0.02 (0.0041) | Kept: Rh ka Rayleigh > -0.02 -> Cu > 0.01 (0.0064)
# Removed: Cu > 0.01 -> background2 <= 0.18 (0.0037) | Kept: background2 <= 0.18 -> Cu > 0.01 (0.0094)
# Removed: background1 > -0.02 -> Cu > 0.01 (0.0013) | Kept: Cu > 0.01 -> background1 > -0.02 (0.0041)
# Removed: Fe <= -0.07 -> background2 > 0.06 (0.0029) | Kept: background2 > 0.06 -> Fe <= -0.07 (0.0045)
# Removed: Fe <= 0.09 -> background2 > 0.06 (0.0026) | Kept: background2 > 0.06 -> Fe <= 0.09 (0.0037)
# Removed: background2 > 0.06 -> background2 > -0.07 (0.0038) | Kept: background2 > -0.07 -> background2 > 0.06 (0.0042)
# Removed: Fe <= -0.01 -> background2 > 0.06 (0.0031) | Kept: background2 > 0.06 -> Fe <= -0.01 (0.0041)
# Removed: Zn > -0.03 -> Rh ka Rayleigh > -0.02 (0.0049) | Kept: Rh ka Rayleigh > -0.02 -> Zn > -0.03 (0.0061)
# Removed: background1 > -0.02 -> Zn > -0.03 (0.0027) | Kept: Zn > -0.03 -> background1 > -0.02 (0.0047)
# Removed: Zn > -0.10 -> Rh ka Rayleigh > -0.15 (0.0046) | Kept: Rh ka Rayleigh > -0.15 -> Zn > -0.10 (0.0065)
# Removed: background1 > -0.02 -> Rh ka Rayleigh > -0.15 (0.0013) | Kept: Rh ka Rayleigh > -0.15 -> background1 > -0.02 (0.0061)
# Removed: Cu > -0.05 -> background2 <= 0.06 (0.0038) | Kept: background2 <= 0.06 -> Cu > -0.05 (0.0047)
# Removed: Cu > -0.05 -> background2 <= 0.18 (0.0036) | Kept: background2 <= 0.18 -> Cu > -0.05 (0.0141)
# Removed: Cu > -0.05 -> Zn <= 0.02 (0.0034) | Kept: Zn <= 0.02 -> Cu > -0.05 (0.0040)
# Removed: Cu > -0.05 -> Zn > -0.10 (0.0037) | Kept: Zn > -0.10 -> Cu > -0.05 (0.0042)
# Removed: background1 > 0.01 -> background2 <= 0.06 (0.0014) | Kept: background2 <= 0.06 -> background1 > 0.01 (0.0048)
# Removed: background1 > -0.02 -> background2 <= 0.06 (0.0012) | Kept: background2 <= 0.06 -> background1 > -0.02 (0.0050)
# Removed: background1 > -0.06 -> background2 <= 0.06 (0.0012) | Kept: background2 <= 0.06 -> background1 > -0.06 (0.0097)
# Removed: Zn > -0.10 -> background2 <= 0.06 (0.0045) | Kept: background2 <= 0.06 -> Zn > -0.10 (0.0047)
# Removed: Fe <= -0.07 -> background2 > -0.07 (0.0037) | Kept: background2 > -0.07 -> Fe <= -0.07 (0.0038)
# Removed: Zn > -0.10 -> background2 <= 0.18 (0.0041) | Kept: background2 <= 0.18 -> Zn > -0.10 (0.0137)
# Removed: background1 > -0.02 -> Zn > -0.10 (0.0012) | Kept: Zn > -0.10 -> background1 > -0.02 (0.0083)
# Removed: background2 > -0.23 -> S > 0.01 (0.0042) | Kept: S > 0.01 -> background2 > -0.23 (0.0058)
# Removed: Cu > -0.13 -> Fe <= 0.09 (0.0028) | Kept: Fe <= 0.09 -> Cu > -0.13 (0.0029)
# Removed: background1 <= 0.01 -> Cu > -0.13 (0.0010) | Kept: Cu > -0.13 -> background1 <= 0.01 (0.0061)
# Removed: Cu > -0.13 -> background1 <= 0.06 (0.0032) | Kept: background1 <= 0.06 -> Cu > -0.13 (0.0050)
# Removed: Zn <= 0.07 -> Zn <= 0.02 (0.0108) | Kept: Zn <= 0.02 -> Zn <= 0.07 (0.0112)
# Removed: background1 > -0.06 -> Zn <= 0.02 (0.0011) | Kept: Zn <= 0.02 -> background1 > -0.06 (0.0036)
# Removed: Zn <= 0.02 -> Fe <= -0.07 (0.0031) | Kept: Fe <= -0.07 -> Zn <= 0.02 (0.0032)
# Removed: Fe <= -0.01 -> Fe <= -0.07 (0.0029) | Kept: Fe <= -0.07 -> Fe <= -0.01 (0.0061)
# Removed: background1 <= 0.01 -> Fe <= -0.07 (0.0010) | Kept: Fe <= -0.07 -> background1 <= 0.01 (0.0031)
# Removed: background1 <= -0.02 -> Fe <= 0.09 (0.0009) | Kept: Fe <= 0.09 -> background1 <= -0.02 (0.0030)
# Removed: Cu <= 0.11 -> Fe <= -0.01 (0.0027) | Kept: Fe <= -0.01 -> Cu <= 0.11 (0.0028)
# Removed: Cu <= 0.11 -> Fe <= 0.09 (0.0052) | Kept: Fe <= 0.09 -> Cu <= 0.11 (0.0060)
# Removed: S > -0.02 -> Fe <= 0.09 (0.0026) | Kept: Fe <= 0.09 -> S > -0.02 (0.0056)
# Removed: Br ka > 0.04 -> S > -0.07 (0.0027) | Kept: S > -0.07 -> Br ka > 0.04 (0.0068)
# Removed: Cu <= 0.01 -> S > -0.07 (0.0048) | Kept: S > -0.07 -> Cu <= 0.01 (0.0067)
# Removed: Cu <= -0.05 -> S > -0.07 (0.0023) | Kept: S > -0.07 -> Cu <= -0.05 (0.0068)
# Removed: Cu <= 0.01 -> Br ka > 0.04 (0.0021) | Kept: Br ka > 0.04 -> Cu <= 0.01 (0.0029)
# Removed: S <= -0.07 -> Br ka > 0.04 (0.0023) | Kept: Br ka > 0.04 -> S <= -0.07 (0.0027)
# Removed: Cu <= -0.05 -> Cu <= 0.01 (0.0043) | Kept: Cu <= 0.01 -> Cu <= -0.05 (0.0044)
# Removed: Br ka > -0.15 -> S <= -0.02 (0.0022) | Kept: S <= -0.02 -> Br ka > -0.15 (0.0039)
# Removed: S <= -0.07 -> S <= -0.02 (0.0019) | Kept: S <= -0.02 -> S <= -0.07 (0.0020)
# Removed: Br ka <= -0.05 -> Br ka > -0.15 (0.0022) | Kept: Br ka > -0.15 -> Br ka <= -0.05 (0.0023)
# Removed: S <= -0.07 -> Br ka > -0.15 (0.0021) | Kept: Br ka > -0.15 -> S <= -0.07 (0.0025)
# Removed: S <= 0.05 -> Rh kb Rayleigh > 0.06 (0.0016) | Kept: Rh kb Rayleigh > 0.06 -> S <= 0.05 (0.0024)
# Removed: Rh kb Rayleigh > 0.06 -> Br ka <= 0.04 (0.0021) | Kept: Br ka <= 0.04 -> Rh kb Rayleigh > 0.06 (0.0039)
# Removed: S <= 0.01 -> Rh kb Rayleigh > 0.06 (0.0018) | Kept: Rh kb Rayleigh > 0.06 -> S <= 0.01 (0.0021)
# Removed: Br ka <= 0.17 -> Br ka > -0.05 (0.0019) | Kept: Br ka > -0.05 -> Br ka <= 0.17 (0.0044)
# Removed: Br ka <= -0.05 -> S <= 0.01 (0.0022) | Kept: S <= 0.01 -> Br ka <= -0.05 (0.0054)
# Removed: S <= 0.01 -> Rh kb Rayleigh <= -0.08 (0.0018) | Kept: Rh kb Rayleigh <= -0.08 -> S <= 0.01 (0.0023)
# Removed: S <= 0.01 -> Br ka <= 0.17 (0.0017) | Kept: Br ka <= 0.17 -> S <= 0.01 (0.0021)
# Removed: Br ka <= 0.17 -> Br ka <= -0.05 (0.0021) | Kept: Br ka <= -0.05 -> Br ka <= 0.17 (0.0066)
# Removed: Br ka <= 0.04 -> Br ka <= 0.17 (0.0021) | Kept: Br ka <= 0.17 -> Br ka <= 0.04 (0.0044)
# Removed: Rh kb Rayleigh > -0.02 -> S <= 0.05 (0.0020) | Kept: S <= 0.05 -> Rh kb Rayleigh > -0.02 (0.0032)
# Removed: Rh kb Rayleigh <= 0.12 -> Rh kb Rayleigh > -0.02 (0.0038) | Kept: Rh kb Rayleigh > -0.02 -> Rh kb Rayleigh <= 0.12 (0.0039)
# Removed: Rh kb Rayleigh > 0.12 -> Rh kb Rayleigh > -0.08 (0.0019) | Kept: Rh kb Rayleigh > -0.08 -> Rh kb Rayleigh > 0.12 (0.0035)
# Removed: Rh kb Rayleigh > -0.08 -> Rh kb Rayleigh <= -0.02 (0.0019) | Kept: Rh kb Rayleigh <= -0.02 -> Rh kb Rayleigh > -0.08 (0.0036)
# Removed: Mn > -0.02 -> Rh kb Rayleigh > -0.08 (0.0014) | Kept: Rh kb Rayleigh > -0.08 -> Mn > -0.02 (0.0018)
# Removed: Rh kb Rayleigh > -0.08 -> Rh kb Rayleigh <= 0.12 (0.0037) | Kept: Rh kb Rayleigh <= 0.12 -> Rh kb Rayleigh > -0.08 (0.0039)
# Removed: Rh kb Rayleigh > -0.08 -> Rh kb Rayleigh <= 0.06 (0.0018) | Kept: Rh kb Rayleigh <= 0.06 -> Rh kb Rayleigh > -0.08 (0.0018)
# Removed: Br ka <= 0.04 -> Rh kb Rayleigh <= -0.08 (0.0019) | Kept: Rh kb Rayleigh <= -0.08 -> Br ka <= 0.04 (0.0021)
# Removed: Br ka <= 0.04 -> Br ka <= -0.15 (0.0020) | Kept: Br ka <= -0.15 -> Br ka <= 0.04 (0.0020)
# Removed: Rh kb Rayleigh <= -0.02 -> Rh kb Rayleigh > 0.12 (0.0037) | Kept: Rh kb Rayleigh > 0.12 -> Rh kb Rayleigh <= -0.02 (0.0037)
# Removed: Mn <= -0.03 -> Mn > -0.02 (0.0014) | Kept: Mn > -0.02 -> Mn <= -0.03 (0.0054)
# Removed: Mn > -0.03 -> Mn <= -0.03 (0.0024) | Kept: Mn <= -0.03 -> Mn > -0.03 (0.0027)
# Removed: Mn > -0.05 -> Mn <= -0.03 (0.0013) | Kept: Mn <= -0.03 -> Mn > -0.05 (0.0025)
# Removed: Mn > -0.03 -> Mn > -0.05 (0.0039) | Kept: Mn > -0.05 -> Mn > -0.03 (0.0073)
#
# ======================================================================
# CONSTRUCTED GRAPH SUMMARY
# ======================================================================
# Initial edges: 804 | Removed: 142
# Predicate nodes: 131
# Metric: Perturbation
# Weighting by explained variance: ENABLED
#
# Processing graph LRC...
#
# Processing graph LRC...
#
# Processing graph LRC...
#
# Processing graph LRC...
#       Predicate_pert_Seed_0   Predicate_pert_Seed_1   Predicate_pert_Seed_2  \
# 0    Rh ka Compton <= -0.39  Rh ka Compton <= -0.39           K ka <= -0.48
# 1             K ka <= -0.48  Rh ka Compton <= -0.05    Rh ka Compton > 0.45
# 2     Rb ka + Br kb > -0.02           K ka <= -0.48   Rb ka + Br kb > -0.02
# 3      Rh ka Compton > 0.45    Rh ka Compton > 0.45  Rh ka Compton <= -0.05
# 4    Rh ka Compton <= -0.05   Rb ka + Br kb > -0.02  Rh ka Compton <= -0.39
# ..                      ...                     ...                     ...
# 128          Br ka <= -0.15              Mn > -0.05              Mn <= 0.02
# 129             Mn <= -0.03              Mn > -0.02                 Class_A
# 130              Mn <= 0.02              Mn <= 0.02                 Class_B
# 131                 Class_A                 Class_A                     NaN
# 132                 Class_B                 Class_B                     NaN
#
#       Predicate_pert_Seed_3
# 0     Rb ka + Br kb > -0.02
# 1               K ka > 0.44
# 2             K ka <= -0.16
# 3    Rh ka Compton <= -0.39
# 4      Rh ka Compton > 0.45
# ..                      ...
# 128             Mn <= -0.02
# 129  Rh kb Rayleigh > -0.08
# 130              Mn <= 0.02
# 131                 Class_A
# 132                 Class_B
#
# [133 rows x 4 columns]

# %%
all_results_pert[0]['pert_results_dict']['Bag_1']
# Out:
#                   Predicate  Perturbation
# 0             K ka <= -0.48      0.052888
# 1     Rb ka + Br kb > -0.02      0.049236
# 2    Rh ka Compton <= -0.05      0.043486
# 3      Rh ka Compton > 0.14      0.040828
# 4             K ka <= -0.16      0.040003
# ..                      ...           ...
# 105             Mn <= -0.03      0.002562
# 106              Mn > -0.03      0.002506
# 107              Mn > -0.05      0.002469
# 108             Mn <= -0.02      0.002440
# 109              Mn <= 0.02      0.002181
#
# [110 rows x 2 columns]

# %%
# Somar LRCs de predicados equivalentes entre diferentes seeds
lrc_combined_list = []

for seed in random_seeds:
    lrc_df = lrc_pert_by_seed[seed].copy()
    lrc_combined_list.append(lrc_df) # o append adiciona o dataframe ao final da lista

# Concatenar todos os dataframes
lrc_all_seeds = pd.concat(lrc_combined_list, ignore_index=True) 

# Agrupar por predicado (Node) e somar as LRCs, mantendo Zone, Threshold e Operator
lrc_summed_df_pert = lrc_all_seeds.groupby('Node').agg({ # o .agg pode ser usado para aplicar múltiplas funções de agregação
    'Local_Reaching_Centrality': 'mean', # sum = somando as LRCs, poderia ser média ou outro agregado
    'Zone': 'first',
    'Threshold': 'first',
    'Operator': 'first'
}).reset_index()

# Ordenar pelo valor de LRC somado (maior para menor)
lrc_summed_df_pert = lrc_summed_df_pert.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
# vamoss pegar so os valore sunicos de lrc_summed_df baseado na zona espectral
lrc_summed_unique_df_pert = lrc_summed_df_pert.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
lrc_summed_unique_df_pert = lrc_summed_unique_df_pert.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
lrc_summed_unique_df_pert
# Out:
#                        Node  Local_Reaching_Centrality            Zone  \
# 0             K ka <= -0.48                   5.345570            K ka
# 1    Rh ka Compton <= -0.39                   5.144667   Rh ka Compton
# 2     Rb ka + Br kb > -0.02                   5.143092   Rb ka + Br kb
# 3        background3 > 0.19                   2.089620     background3
# 4               Cl <= -0.20                   2.026604              Cl
# 5      Rh kb Compton > 0.25                   1.993479   Rh kb Compton
# 6                 Fe > 0.09                   1.551328              Fe
# 7     K kb + Ca ka <= -0.14                   1.388621    K kb + Ca ka
# 8   Rh ka Rayleigh <= -0.15                   1.217463  Rh ka Rayleigh
# 9                 Zn > 0.07                   1.190351              Zn
# 10     background2 <= -0.23                   0.852975     background2
# 11                 S > 0.05                   0.745083               S
# 12                Cu > 0.01                   0.657928              Cu
# 13      background1 > -0.02                   0.632579     background1
# 14             Br ka > 0.17                   0.594180           Br ka
# 15    Rh kb Rayleigh > 0.06                   0.481741  Rh kb Rayleigh
# 16                Mn > 0.02                   0.466605              Mn
# 17                  Class_A                   0.000000            None
#
#    Threshold Operator
# 0      -0.48       <=
# 1      -0.39       <=
# 2      -0.02        >
# 3       0.19        >
# 4      -0.20       <=
# 5       0.25        >
# 6       0.09        >
# 7      -0.14       <=
# 8      -0.15       <=
# 9       0.07        >
# 10     -0.23       <=
# 11      0.05        >
# 12      0.01        >
# 13     -0.02        >
# 14      0.17        >
# 15      0.06        >
# 16      0.02        >
# 17      None     None

# %%
# Aplicar o mapeamento
lrc_summed_df_pert_natural = exp.map_thresholds_to_natural(
    lrc_df=lrc_summed_df_pert,
    zone_sums_preprocessed=zone_scores_df,
    zone_sums_natural=zones_original[0]
)

lrc_summed_df_pert_natural
# Out:
#                        Node  Local_Reaching_Centrality           Zone  \
# 0             K ka <= -0.48                   5.345570           K ka
# 1    Rh ka Compton <= -0.39                   5.144667  Rh ka Compton
# 2     Rb ka + Br kb > -0.02                   5.143092  Rb ka + Br kb
# 3      Rh ka Compton > 0.45                   5.078906  Rh ka Compton
# 4    Rh ka Compton <= -0.05                   4.405067  Rh ka Compton
# ..                      ...                        ...            ...
# 131              Mn > -0.05                   0.449514             Mn
# 132             Mn <= -0.02                   0.446562             Mn
# 133              Mn <= 0.02                   0.121947             Mn
# 134                 Class_A                   0.000000           None
# 135                 Class_B                   0.000000           None
#
#     Threshold Operator  Threshold_Natural  Reference_Sample_Index  \
# 0       -0.48       <=          -0.553004                    18.0
# 1       -0.39       <=          -0.345973                    25.0
# 2       -0.02        >          -0.003744                    27.0
# 3        0.45        >           0.421114                     2.0
# 4       -0.05       <=          -0.043040                    26.0
# ..        ...      ...                ...                     ...
# 131     -0.05        >          -0.009215                    19.0
# 132     -0.02       <=          -0.003958                    18.0
# 133      0.02       <=           0.003812                     0.0
# 134      None     None                NaN                     NaN
# 135      None     None                NaN                     NaN
#
#      Approximation_Error                Node_Natural
# 0               0.004092           K ka <= -0.553004
# 1               0.002620  Rh ka Compton <= -0.345973
# 2               0.000729   Rb ka + Br kb > -0.003744
# 3               0.002152    Rh ka Compton > 0.421114
# 4               0.001277  Rh ka Compton <= -0.043040
# ..                   ...                         ...
# 131             0.000179              Mn > -0.009215
# 132             0.000109             Mn <= -0.003958
# 133             0.000531              Mn <= 0.003812
# 134                  NaN                        None
# 135                  NaN                        None
#
# [136 rows x 9 columns]

# %%
import plotly.graph_objects as go

n = 0
zone_name = lrc_summed_df_pert_natural.iloc[n]['Zone'] # o n indica a linha do dataframe lrc_summed_df_pert_natural que queremos acessar para pegar o nome da zona espectral (coluna 'Zone')
threshold_score = float(lrc_summed_df_pert_natural.iloc[n]['Threshold_Natural']) # o iloc acessa a linha n e a coluna 'Threshold_Natural' para pegar o valor do threshold já mapeado para o espaço natural (não pré-processado)

# Usar pca_info_dict dos dados ORIGINAIS (zones_original[1])
pca_info_dict_original = zones_original[1]

# Reconstrução: τ = mean + threshold * loadings (no espaço original)
threshold_spectrum = exp.reconstruct_threshold_to_spectrum(
    threshold_value=threshold_score,
    zone_name=zone_name,
    pca_info_dict=pca_info_dict_original
)
print(f"\nEspectro de threshold reconstruído para zona '{zone_name}':")
print(f"  - Dimensão: {len(threshold_spectrum)} variáveis espectrais")
#print(f"  - Range de energias: {threshold_spectrum.index[n]} - {threshold_spectrum.index[-1]}")
print(f"  - Variância explicada pela PC1: {pca_info_dict_original[zone_name]['variance_explained']:.2%}")

# Usar dados ORIGINAIS para plotar (spectral_zones_original)
zone_df = spectral_zones_original[zone_name]

# Plotar zona com threshold (inline)
fig = go.Figure()
x_values = pd.to_numeric(zone_df.columns, errors='coerce')

# Plotar espectros das amostras coloridas por classe
colors = {'A': 'gold', 'B': 'blue'}
for idx, row in zone_df.iterrows():
    class_label = ycalclass.iloc[idx] if idx < len(ycalclass) else 'Unknown'
    fig.add_trace(go.Scatter(
        x=x_values,
        y=row.values,
        mode='lines',
        line=dict(color=colors.get(class_label, 'rgba(128,128,128,0.3)'), width=0.5),
        name=f'Class {class_label}',
        showlegend=False,
        hoverinfo='skip'
    ))

# Plotar espectro de threshold (destaque)
fig.add_trace(go.Scatter(
    x=x_values,
    y=threshold_spectrum.values,
    mode='lines',
    line=dict(color='red', width=4, dash='dash'),
    name=f'Threshold Spectrum ({threshold_spectrum.name})'
))

# Layout do gráfico
fig.update_layout(
    title=f"Zona '{zone_name}' com Threshold Multivariado (Predicado: {lrc_summed_df_pert_natural.iloc[n]['Node_Natural']})",
    xaxis_title='Energia / Comprimento de Onda',
    yaxis_title='Intensidade',
    template='plotly_white',
    showlegend=True,
    legend=dict(yanchor="top", y=0.99, xanchor="left", x=0.01)
)

fig.show()
# Out:
# Espectro de threshold reconstruído para zona 'K ka':
#   - Dimensão: 23 variáveis espectrais
#   - Variância explicada pela PC1: 99.30%

# %%
# Permutation importance baseado em mudança nas probabilidades previstas (predict_proba)
# Medimos a média da diferença absoluta entre as probabilidades originais e as probabilidades
# obtidas após permutar cada variável. Isso fornece uma métrica contínua de importância.
n_repeats = 10
rng = np.random.RandomState(42)
# Probabilidades base (classe 'B' mapeada para 1)
baseline_proba = mlp_model[3].predict_proba(Xcalclass_prep)[:, 1]
importance_list = []
X_arr = Xcalclass_prep.copy()
for col in Xcalclass_prep.columns:
    diffs = []
    for _ in range(n_repeats):
        X_perm = X_arr.copy()
        X_perm[col] = rng.permutation(X_perm[col].values)
        perm_proba = mlp_model[3].predict_proba(X_perm)[:, 1]
        diffs.append(np.mean(np.abs(baseline_proba - perm_proba)))
    importance_list.append(np.mean(diffs))

permutation_df = pd.DataFrame({
    'energy': Xcalclass_prep.columns,
    'Permutation_importance_proba': importance_list
})
permutation_df.sort_values(by='Permutation_importance_proba', ascending=False, inplace=True)
energy_to_zone_vip = {}
for zone_name, start, end in spectral_cuts:
    for e in permutation_df['energy']:
        ef = float(e)
        if start <= ef <= end:
            energy_to_zone_vip[e] = zone_name
permutation_df['Zone'] = permutation_df['energy'].map(energy_to_zone_vip)
permutation_unique_df = permutation_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
permutation_unique_df = permutation_unique_df.sort_values(by='Permutation_importance_proba', ascending=False)
permutation_unique_df
# Out:
#    energy  Permutation_importance_proba            Zone
# 0    3.34                      0.009151            K ka
# 1   13.42                      0.005853   Rb ka + Br kb
# 2     3.7                      0.004843    K kb + Ca ka
# 3   19.18                      0.004251   Rh ka Compton
# 4    2.58                      0.004182              Cl
# 5   20.28                      0.002586  Rh ka Rayleigh
# 6      15                      0.002385     background3
# 7   11.92                      0.002249           Br ka
# 8    8.06                      0.002178              Cu
# 9    8.62                      0.002149              Zn
# 10     21                      0.002075   Rh kb Compton
# 11    6.4                      0.002052              Fe
# 12   2.28                      0.001850               S
# 13   4.02                      0.001651     background1
# 14  11.14                      0.001508     background2
# 15   22.4                      0.001411  Rh kb Rayleigh
# 16   5.86                      0.001190              Mn

# %%
import numpy as np

max_len = max(
    len(shap_unique_df['Zone']),
    len(permutation_unique_df['Zone']),
    len(lrc_summed_unique_df_pert['Zone']),
    len(lrc_summed_unique_df_cov['Zone'])
)

def pad_list(lst, length):
    return list(lst) + [None] * (length - len(lst))

features_importance = pd.DataFrame({
    'Shap': pad_list(shap_unique_df['Zone'], max_len),
    'Permutation' : pad_list(permutation_unique_df['Zone'], max_len),
    'LRC_perturbation' : pad_list(lrc_summed_unique_df_pert['Zone'], max_len),
    'LRC_covariance' : pad_list(lrc_summed_unique_df_cov['Zone'], max_len),
})

features_importance.to_csv('feature_importance.csv', index=False, sep=';')
features_importance
# Out:
#               Shap     Permutation LRC_perturbation  LRC_covariance
# 0    Rb ka + Br kb            K ka             K ka   Rh ka Compton
# 1             K ka   Rb ka + Br kb    Rh ka Compton   Rb ka + Br kb
# 2    Rh ka Compton    K kb + Ca ka    Rb ka + Br kb   Rh kb Compton
# 3               Cl   Rh ka Compton      background3            K ka
# 4   Rh ka Rayleigh              Cl               Cl  Rh ka Rayleigh
# 5     K kb + Ca ka  Rh ka Rayleigh    Rh kb Compton     background3
# 6    Rh kb Compton     background3               Fe     background2
# 7      background3           Br ka     K kb + Ca ka              Cl
# 8                S              Cu   Rh ka Rayleigh  Rh kb Rayleigh
# 9            Br ka              Zn               Zn           Br ka
# 10              Cu   Rh kb Compton      background2    K kb + Ca ka
# 11              Fe              Fe                S            None
# 12              Mn               S               Cu            None
# 13     background2     background1      background1            None
# 14     background1     background2            Br ka            None
# 15              Zn  Rh kb Rayleigh   Rh kb Rayleigh            None
# 16  Rh kb Rayleigh              Mn               Mn            None
# 17            None            None             None            None

# %%
import rbo
rbo_comparison = pd.DataFrame(columns=['Method_1', 'Method_2', 'RBO_Score'])
methods = features_importance.columns.tolist()
for i in range(len(methods)):
    for j in range(i + 1, len(methods)):
        method_1 = methods[i]
        method_2 = methods[j]
        # Remove None values from the lists
        list_1 = [x for x in features_importance[method_1].tolist() if x is not None]
        list_2 = [x for x in features_importance[method_2].tolist() if x is not None]
        # Truncate both lists to the same length (minimum of both)
        min_len = min(len(list_1), len(list_2))
        list_1_trunc = list_1[:min_len]
        list_2_trunc = list_2[:min_len]
        rbo_score = rbo.RankingSimilarity(list_1_trunc, list_2_trunc).rbo(p=0.7, k=10)
        rbo_comparison = pd.concat([rbo_comparison, pd.DataFrame({
            'Method_1': [method_1],
            'Method_2': [method_2],
            'RBO_Score': [rbo_score]
        })], ignore_index=True)
rbo_comparison.sort_values(by='RBO_Score', ascending=False, inplace=True)
rbo_comparison.to_csv('rbo_rank.csv', index=False, sep=';')
rbo_comparison
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9300\3097109587.py:16: FutureWarning:
#
# The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#            Method_1          Method_2  RBO_Score
# 3       Permutation  LRC_perturbation   0.738289
# 0              Shap       Permutation   0.568227
# 1              Shap  LRC_perturbation   0.492299
# 2              Shap    LRC_covariance   0.441378
# 5  LRC_perturbation    LRC_covariance   0.431076
# 4       Permutation    LRC_covariance   0.371751

# %%
lrc_summed_df_cov_natural.to_csv('lrc_cov_natural.csv', index=False, sep=';')
lrc_summed_df_pert_natural.to_csv('lrc_pert_natural.csv', index=False, sep=';')
