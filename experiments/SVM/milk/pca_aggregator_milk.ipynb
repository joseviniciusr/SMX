# %%
# Importing the necessary libraries
import pandas as pd
import numpy as np
import kennard_stone as ks
pd.options.plotting.backend = 'plotly'  # setting plotly as the backend for pandas plotting

# Add parent directory to sys.path so local module 'synthetic' can be imported
import sys
from pathlib import Path # for path manipulations
# Move three levels up from current working directory to reach workspace root
workspace_root = Path.cwd().parent.parent.parent.resolve() 
smx_dir = workspace_root / 'smx'  # Path to smx folder
if str(smx_dir) not in sys.path: # check to avoid duplicates
    sys.path.insert(0, str(smx_dir)) # insert at the start of sys.path to prioritize local modules

# Loading a soil spectral dataset based on X-ray fluorescence (XRF)
data_complete = pd.read_csv(f'{workspace_root}/real_datasets/xrf/milk.csv', sep=';') # local copy of Toledo 2022 dataset
data = data_complete.loc[:, '2.66':'22.62']

# Creating a new column 'Class' based on the condition of the samples in the 'Type' column being 'Authentic'
data_A = data_complete[data_complete['Class'] == 'A'].reset_index(drop=True)
data_B = data_complete[data_complete['Class'] == 'B'].reset_index(drop=True)

# splitting the data into calibration and prediction sets by kennard-stone algorithm
XA_cal, XA_pred = ks.train_test_split(data_A.loc[:, '2.66':'22.62'], test_size=0.30) # class A
XA_cal = XA_cal.reset_index(drop=True)
XA_pred = XA_pred.reset_index(drop=True)

XB_cal, XB_pred = ks.train_test_split(data_B.loc[:, '2.66':'22.62'], test_size=0.30) # class B
XB_cal = XB_cal.reset_index(drop=True)
XB_pred = XB_pred.reset_index(drop=True)

Xcalclass = pd.concat([XA_cal, XB_cal], axis=0).reset_index(drop=True) # concatenating both classes
Xpredclass = pd.concat([XA_pred, XB_pred], axis=0).reset_index(drop=True)
ycalclass = pd.Series(['A']*XA_cal.shape[0] + ['B']*XB_cal.shape[0]) # creating the target variable for calibration set
ypredclass = pd.Series(['A']*XA_pred.shape[0] + ['B']*XB_pred.shape[0]) # creating the target variable for prediction set

# preprocessings
import preprocessings as prepr # preprocessing methods for XRF data

Xcalclass_prep, mean_calclass, mean_calclass_poisson  = prepr.poisson(Xcalclass, mc=True)
Xpredclass_prep = ((Xpredclass/np.sqrt(mean_calclass)) - mean_calclass_poisson)
# Out:
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-02-26 15:00:01,017 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-02-26 15:00:01,041 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-02-26 15:00:01,086 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-02-26 15:00:01,160 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
from modeling import svm_optimized

svm_model = svm_optimized(Xcalclass_prep, ycalclass, Xpredclass_prep, ypredclass, aim='classification', kernel='rbf')
svm_model[0]
# Out:
#   Model  Accuracy Cal  Sensitivity Cal  Specificity Cal               CM Cal  \
# 0   SVC      0.970149         0.994048             0.93  [[93, 7], [1, 167]]
#
#    Accuracy Pred  Sensitivity Pred  Specificity Pred              CM Pred
# 0       0.843478          0.847222          0.837209  [[36, 7], [11, 61]]

# %% [markdown]
# ## Definição das Zonas Espectrais

# %%
# establishing spectral cuts based on expert knowledge of XRF spectra
spectral_cuts = [
('Ag La', 2.66, 3.10),
('Ag Lb', 3.10, 3.46),
('Ca', 3.46, 3.92),
('background', 3.92, 6.12),
('Fe', 6.12, 6.68),
('Cu', 6.70, 8.37),
('Zn', 8.37, 9.10),
('Bremsstrahlung', 9.10, 20.06),
('Ag compton', 20.06, 21.62),
('Ag ka', 21.48, 22.62)
]

# %% [markdown]
# ## Pvector and SHAP

# %%
X_sv = svm_model[3].support_vectors_            # shape (n_SV, n_features)
alpha_dual = svm_model[3].dual_coef_.ravel()    # shape (n_SV,)

# Calculando os coeficientes p usando os vetores de suporte e os multiplicadores de Lagrange
pvetor = pd.DataFrame({'energia' : Xcalclass.columns,
                       'importance': (X_sv.T) @ alpha_dual})
pvetor['importance'] = np.abs(pvetor['importance'])
pvector_df = pd.DataFrame({
    'energy': pvetor['energia'],
    'Pvector': pvetor['importance'].values
})
pvector_df = pvector_df.sort_values(by='Pvector', ascending=False).reset_index(drop=True)
energy_to_zone_vip = {}
for zone_name, start, end in spectral_cuts:
    for e in pvector_df['energy']:
        ef = float(e)
        if start <= ef <= end:
            energy_to_zone_vip[e] = zone_name
pvector_df['Zone'] = pvector_df['energy'].map(energy_to_zone_vip)
pvector_unique_df = pvector_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
pvector_unique_df
# Out:
#   energy    Pvector            Zone
# 0  22.23  72.456491           Ag ka
# 1   2.99  54.182196           Ag La
# 2   8.75  43.305839              Zn
# 3   3.22  41.848390           Ag Lb
# 4  17.99  38.304185  Bremsstrahlung
# 5   6.42  36.324355              Fe
# 6  21.41  29.586439      Ag compton
# 7   4.81  26.811026      background
# 8   3.89  26.299280              Ca
# 9   7.80  23.374915              Cu

# %%
shap_global_importance = pd.read_csv('shap_milk.csv', sep=';') # loading previously saved shap_unique_df
# vamos gerar uma nova coluna em shap_global_importance com o nome da zona espectral correspondente de acordo com a lista spectral_cuts
energy_to_zone_shap = {}
for zone_name, start, end in spectral_cuts:
    for i in shap_global_importance['energy']:
        i_float = float(i)
        if start <= i_float <= end:
            energy_to_zone_shap[i] = zone_name
shap_global_importance['Zone'] = shap_global_importance['energy'].map(energy_to_zone_shap)

# agora vamos filtrar shap_global_importance para manter apenas as zonas espectrais únicas com maior SHAP score
shap_unique_df = shap_global_importance.sort_values(by='Mean_Abs_SHAP', ascending=False).reset_index(drop=True)
shap_unique_df = shap_unique_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
shap_unique_df
# Out:
#    energy  Mean_Abs_SHAP            Zone
# 0    2.99       0.029420           Ag La
# 1   22.23       0.017223           Ag ka
# 2    3.20       0.011185           Ag Lb
# 3   17.99       0.001372  Bremsstrahlung
# 4    8.73       0.001075              Zn
# 5   21.41       0.000739      Ag compton
# 6    6.35       0.000516              Fe
# 7    3.89       0.000282              Ca
# 8    8.21       0.000146              Cu
# 9    5.45       0.000120      background

# %% [markdown]
# ## Funções de Agregação por PCA
#
# Aqui implementamos as funções para agregar zonas espectrais usando PCA com 1 componente principal.

# %%
import explaining as exp

# Extração das zonas espectrais
spectral_zones_class = exp.extract_spectral_zones(Xcalclass_prep, spectral_cuts)
zone_scores_df, pca_info_dict = exp.aggregate_spectral_zones_pca(spectral_zones_class) # apca aggregation
print(f"\nScores DataFrame shape: {zone_scores_df.shape}")
# Out:
# Zone 'Ag La': VE = 84.62%, dim = 18 variables
# Zone 'Ag Lb': VE = 86.51%, dim = 15 variables
# Zone 'Ca': VE = 21.64%, dim = 19 variables
# Zone 'background': VE = 3.44%, dim = 87 variables
# Zone 'Fe': VE = 12.88%, dim = 23 variables
# Zone 'Cu': VE = 9.26%, dim = 66 variables
# Zone 'Zn': VE = 17.17%, dim = 29 variables
# Zone 'Bremsstrahlung': VE = 30.64%, dim = 429 variables
# Zone 'Ag compton': VE = 52.31%, dim = 62 variables
# Zone 'Ag ka': VE = 76.93%, dim = 45 variables
#
# Scores DataFrame shape: (268, 10)

# %%
y_pred = svm_model[4]['SVC'].values # using the continuous predictions from SVM, extracting as 1D array
predicates_quantiles = exp.predicates_by_quantiles(zone_scores_df, [0.2, 0.4, 0.6, 0.8])
predicate_info_dict = exp.create_predicate_info_dict(
    predicates_df=predicates_quantiles[0],
    predicate_indicator_df=predicates_quantiles[1],
    zone_aggregated_df=zone_scores_df,
    y_predicted_numeric=y_pred
)

# %%
import explaining as exp

# LISTA DE SEMENTES A TESTAR
random_seeds = [0, 1, 2, 3]

all_results_cov = {}
training_samples = len(Xcalclass)

# LOOP: PROCESSAR CADA SEMENTE

y_pred = pd.Series(svm_model[4]['SVC'].values) # using the continuous predictions from SVM, extracting as 1D array

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando semente: {seed}")
    print(f"{'='*70}\n")
    # Bagging
    bags_result_seed = exp.bagging_predicates(
        zone_sums_df=zone_scores_df,
        y_predicted_numeric=y_pred,
        predicates_df=predicates_quantiles[0],
        n_bags=10,
        #n_predicates_per_bag=40,
        n_samples_per_bag=int(training_samples*0.8), # 80 % da base para amostrar (convertido para int)
        min_samples_per_predicate=int(training_samples*0.2), # 20 % da base para limitar (convertido para int)
        replace=False,
        sample_bagging=True,
        predicate_bagging=False,
        random_seed=seed
    )
    
    # Inserir classe prevista
    for bag_name, pred_dict in bags_result_seed.items(): # iterando sobre cada bag
        for pred_rule, df_info in pred_dict.items():
            df_info['Class_Predicted'] = np.where(df_info['Predicted_Y'] >= 0.5, 'A', 'B') # binarizando com threshold 0.5, A = eut, B = dist
    
    # Calcular MI
    cov_results_dict_seed = exp.calculate_predicate_metrics(
        bags_result=bags_result_seed,
        metric='covariance', # covariance ou mutual_information
        threshold=0.01, # threshold para cortar predicados irrelevantes
        n_neighbors=5
    )
    
    # Salvar no dicionário principal
    all_results_cov[seed] = {
        'bags_result': bags_result_seed,
        'cov_results_dict': cov_results_dict_seed
    }

# CONSTRUÇÃO DE GRAFOS PARA MÚLTIPLAS SEMENTES (LOOP EXTERNO)
# Dicionário para armazenar grafos
graphs_by_seed = {}

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando Grafo - Semente: {seed}")
    print(f"{'='*70}\n")
    
    # Construir grafo para esta semente (sem predicates_df - extraído da regra)
    DG = exp.build_predicate_graph(
        bags_result=all_results_cov[seed]['bags_result'],
        predicate_ranking_dict=all_results_cov[seed]['cov_results_dict'],
        metric_column='Covariance',
        random_state=seed,
        show_details=True,
        var_exp=True,
        pca_info_dict=pca_info_dict
    )
    # Armazenar grafo
    graphs_by_seed[seed] = DG

# Calcular LRC usando a função pronta do explaining.py
lrc_cov_by_seed = {}
for seed in random_seeds:
    DG = graphs_by_seed[seed]
    lrc_cov_df_seed = exp.calculate_lrc_single_graph(DG, predicates_quantiles[0])
    lrc_cov_df_seed['Seed'] = seed  # Adicionar coluna com a semente
    lrc_cov_by_seed[seed] = lrc_cov_df_seed

# junando todas as colunas 'Node' de lrc_by_seed em um único dataframe
lrc_cov_all_seeds_df = pd.DataFrame()
for seed in random_seeds:
    lrc_cov_df_seed = lrc_cov_by_seed[seed].rename(columns={'Node': f'Predicate_Cov_Seed_{seed}'})
    lrc_cov_all_seeds_df = pd.concat([lrc_cov_all_seeds_df, lrc_cov_df_seed[[f'Predicate_Cov_Seed_{seed}']]], axis=1)

# vamos filtrar lrc_by_seed em cada semente para manter apenas as zonas espectrais únicas com maior LRC em um mesmo dataframe
lrc_cov_unique_by_seed = {}
for seed, lrc_df in lrc_cov_by_seed.items():
    lrc_cov_unique_df = lrc_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
    lrc_cov_unique_df = lrc_cov_unique_df.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
    lrc_cov_unique_by_seed[seed] = lrc_cov_unique_df

lrc_cov_all_seeds_df # exibindo o dataframe consolidado com predicados de todas as sementes
# Out:
# ======================================================================
# Processando semente: 0
# ======================================================================
#
# Bag_1 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_2 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_3 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_4 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_5 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_6 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_7 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_8 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_9 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_10 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Computing Covariance for Predicates
# Metric: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando semente: 1
# ======================================================================
#
# Bag_1 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_2 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_3 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_4 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_5 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_6 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_7 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_8 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_9 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_10 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Computing Covariance for Predicates
# Metric: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando semente: 2
# ======================================================================
#
# Bag_1 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_2 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_3 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_4 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_5 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_6 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_7 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_8 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_9 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_10 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Computing Covariance for Predicates
# Metric: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando semente: 3
# ======================================================================
#
# Bag_1 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_2 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_3 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_4 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_5 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_6 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_7 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_8 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_9 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_10 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Computing Covariance for Predicates
# Metric: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando Grafo - Semente: 0
# ======================================================================
#
#
# Total bidirectional pairs found: 61
# Removed: Ag Lb <= 2.36 -> Ag La <= 7.76 (8.7957) | Kept: Ag La <= 7.76 -> Ag Lb <= 2.36 (20.3627)
# Removed: Bremsstrahlung <= 4.15 -> Bremsstrahlung <= 9.64 (0.9220) | Kept: Bremsstrahlung <= 9.64 -> Bremsstrahlung <= 4.15 (1.4555)
# Removed: Ag compton <= 6.52 -> Bremsstrahlung <= 4.15 (0.3760) | Kept: Bremsstrahlung <= 4.15 -> Ag compton <= 6.52 (0.4333)
# Removed: Bremsstrahlung <= 9.64 -> Ag ka > -7.06 (0.5432) | Kept: Ag ka > -7.06 -> Bremsstrahlung <= 9.64 (0.7315)
# Removed: Bremsstrahlung <= -1.54 -> Ag compton <= 6.52 (0.2634) | Kept: Ag compton <= 6.52 -> Bremsstrahlung <= -1.54 (0.3431)
# Removed: Bremsstrahlung <= -1.54 -> Ag ka <= 20.95 (0.2365) | Kept: Ag ka <= 20.95 -> Bremsstrahlung <= -1.54 (0.5883)
# Removed: Ag compton <= 6.52 -> Ag ka <= -7.06 (0.4103) | Kept: Ag ka <= -7.06 -> Ag compton <= 6.52 (1.4253)
# Removed: Bremsstrahlung > -9.06 -> Ag ka <= -7.06 (0.2581) | Kept: Ag ka <= -7.06 -> Bremsstrahlung > -9.06 (0.7729)
# Removed: Ag ka <= -7.06 -> Ag ka > -11.59 (0.5748) | Kept: Ag ka > -11.59 -> Ag ka <= -7.06 (0.9511)
# Removed: Ag compton <= 6.52 -> Ag ka <= 20.95 (0.4286) | Kept: Ag ka <= 20.95 -> Ag compton <= 6.52 (1.2278)
# Removed: Ag ka <= 20.95 -> Ag ka > -7.06 (0.7778) | Kept: Ag ka > -7.06 -> Ag ka <= 20.95 (2.0843)
# Removed: Bremsstrahlung > -9.06 -> Ag compton <= 2.96 (0.2262) | Kept: Ag compton <= 2.96 -> Bremsstrahlung > -9.06 (0.5931)
# Removed: Bremsstrahlung > -1.54 -> Ag ka > -11.59 (0.2098) | Kept: Ag ka > -11.59 -> Bremsstrahlung > -1.54 (1.4555)
# Removed: Bremsstrahlung > -1.54 -> Ag compton <= 2.96 (0.1854) | Kept: Ag compton <= 2.96 -> Bremsstrahlung > -1.54 (0.2998)
# Removed: Ag compton <= 2.96 -> Bremsstrahlung > 4.15 (0.2759) | Kept: Bremsstrahlung > 4.15 -> Ag compton <= 2.96 (0.7056)
# Removed: Ag compton <= -1.09 -> Ag compton > -6.71 (0.6608) | Kept: Ag compton > -6.71 -> Ag compton <= -1.09 (0.8320)
# Removed: Ag compton > -1.09 -> Ag compton <= -1.09 (0.1718) | Kept: Ag compton <= -1.09 -> Ag compton > -1.09 (0.1985)
# Removed: Ag Lb > 2.36 -> Ag La > 2.70 (0.5051) | Kept: Ag La > 2.70 -> Ag Lb > 2.36 (1.4987)
# Removed: Ag compton > -1.09 -> Ag Lb > 2.36 (0.4483) | Kept: Ag Lb > 2.36 -> Ag compton > -1.09 (0.9055)
# Removed: Cu > 0.32 -> Ag La > -18.52 (0.0090) | Kept: Ag La > -18.52 -> Cu > 0.32 (0.2509)
# Removed: Ca <= -0.68 -> Ag La > -18.52 (0.0276) | Kept: Ag La > -18.52 -> Ca <= -0.68 (0.0910)
# Removed: Ca > 0.46 -> Ag La > -18.52 (0.0239) | Kept: Ag La > -18.52 -> Ca > 0.46 (0.2413)
# Removed: Fe > 0.31 -> Cu > 0.32 (0.0128) | Kept: Cu > 0.32 -> Fe > 0.31 (0.0205)
# Removed: Cu > 0.32 -> Fe > -1.18 (0.0098) | Kept: Fe > -1.18 -> Cu > 0.32 (0.0155)
# Removed: Cu > 0.32 -> Ca > -1.79 (0.0092) | Kept: Ca > -1.79 -> Cu > 0.32 (0.0467)
# Removed: Zn > 0.56 -> Ca <= -0.68 (0.0184) | Kept: Ca <= -0.68 -> Zn > 0.56 (0.0506)
# Removed: Ca > -0.68 -> Ca <= -0.68 (0.0190) | Kept: Ca <= -0.68 -> Ca > -0.68 (0.0205)
# Removed: Ca <= -0.68 -> Ag ka > 5.37 (0.0311) | Kept: Ag ka > 5.37 -> Ca <= -0.68 (0.1507)
# Removed: Zn > 0.56 -> Fe > -0.36 (0.0295) | Kept: Fe > -0.36 -> Zn > 0.56 (0.0302)
# Removed: Ca > 0.46 -> Ag compton > 2.96 (0.0211) | Kept: Ag compton > 2.96 -> Ca > 0.46 (0.0536)
# Removed: Ca > 0.46 -> Ca <= 0.46 (0.0169) | Kept: Ca <= 0.46 -> Ca > 0.46 (0.0203)
# Removed: Ca > -1.79 -> Ca > 0.46 (0.0185) | Kept: Ca > 0.46 -> Ca > -1.79 (0.0434)
# Removed: Fe > -1.18 -> Ag Lb > -15.87 (0.0117) | Kept: Ag Lb > -15.87 -> Fe > -1.18 (0.2038)
# Removed: Fe > 0.31 -> Ag ka > 5.37 (0.0152) | Kept: Ag ka > 5.37 -> Fe > 0.31 (0.1188)
# Removed: Fe > 0.31 -> Ca > -1.79 (0.0126) | Kept: Ca > -1.79 -> Fe > 0.31 (0.0228)
# Removed: Cu > -0.64 -> Cu > -1.74 (0.0030) | Kept: Cu > -1.74 -> Cu > -0.64 (0.0088)
# Removed: background > -0.46 -> Cu > -1.74 (0.0017) | Kept: Cu > -1.74 -> background > -0.46 (0.0020)
# Removed: Fe > -0.36 -> Ca > -1.79 (0.0114) | Kept: Ca > -1.79 -> Fe > -0.36 (0.0166)
# Removed: Ca <= 0.46 -> Ca > -1.79 (0.0185) | Kept: Ca > -1.79 -> Ca <= 0.46 (0.0465)
# Removed: background > -1.23 -> Fe > -0.36 (0.0029) | Kept: Fe > -0.36 -> background > -1.23 (0.0072)
# Removed: Fe > -0.36 -> Ca > -0.68 (0.0115) | Kept: Ca > -0.68 -> Fe > -0.36 (0.0168)
# Removed: Ca <= 1.81 -> Ca <= 0.46 (0.0192) | Kept: Ca <= 0.46 -> Ca <= 1.81 (0.0766)
# Removed: Ca <= 0.46 -> Ag Lb > 6.48 (0.0166) | Kept: Ag Lb > 6.48 -> Ca <= 0.46 (0.0610)
# Removed: Zn <= 0.56 -> Ag La > 7.76 (0.0068) | Kept: Ag La > 7.76 -> Zn <= 0.56 (0.0457)
# Removed: Zn <= 1.56 -> Ag La > 7.76 (0.0068) | Kept: Ag La > 7.76 -> Zn <= 1.56 (0.0282)
# Removed: Cu > -0.64 -> Fe <= -0.36 (0.0021) | Kept: Fe <= -0.36 -> Cu > -0.64 (0.0047)
# Removed: Cu <= 0.32 -> Cu > -0.64 (0.0018) | Kept: Cu > -0.64 -> Cu <= 0.32 (0.0036)
# Removed: background > -1.23 -> Ca > -0.68 (0.0028) | Kept: Ca > -0.68 -> background > -1.23 (0.0150)
# Removed: Cu <= -0.64 -> Cu <= 0.32 (0.0020) | Kept: Cu <= 0.32 -> Cu <= -0.64 (0.0031)
# Removed: Cu <= -0.64 -> Zn <= 1.56 (0.0027) | Kept: Zn <= 1.56 -> Cu <= -0.64 (0.0046)
# Removed: background > -1.23 -> Ag Lb > 6.48 (0.0020) | Kept: Ag Lb > 6.48 -> background > -1.23 (0.1304)
# Removed: background > -0.46 -> Zn > -1.47 (0.0040) | Kept: Zn > -1.47 -> background > -0.46 (0.0102)
# Removed: background > 0.40 -> Zn <= 1.56 (0.0014) | Kept: Zn <= 1.56 -> background > 0.40 (0.0074)
# Removed: background <= 0.40 -> Zn <= 1.56 (0.0010) | Kept: Zn <= 1.56 -> background <= 0.40 (0.0049)
# Removed: background > 0.40 -> Zn <= 0.56 (0.0024) | Kept: Zn <= 0.56 -> background > 0.40 (0.0079)
# Removed: background <= 1.29 -> background > 0.40 (0.0015) | Kept: background > 0.40 -> background <= 1.29 (0.0016)
# Removed: background > 0.40 -> Fe <= 1.20 (0.0029) | Kept: Fe <= 1.20 -> background > 0.40 (0.0042)
# Removed: background <= 1.29 -> Zn <= 0.56 (0.0027) | Kept: Zn <= 0.56 -> background <= 1.29 (0.0052)
# Removed: Cu <= 0.32 -> Ag Lb > -15.87 (0.0035) | Kept: Ag Lb > -15.87 -> Cu <= 0.32 (0.0741)
# Removed: Cu <= 0.32 -> Zn > -1.47 (0.0035) | Kept: Zn > -1.47 -> Cu <= 0.32 (0.0061)
# Removed: background <= 0.40 -> Fe <= 1.20 (0.0004) | Kept: Fe <= 1.20 -> background <= 0.40 (0.0055)
#
# ======================================================================
# CONSTRUCTED GRAPH SUMMARY
# ======================================================================
# Initial edges: 377 | Removed: 61
# Predicate nodes: 60
# Metric: Covariance
# Weighting by explained variance: ENABLED
#
# ======================================================================
# Processando Grafo - Semente: 1
# ======================================================================
#
#
# Total bidirectional pairs found: 70
# Removed: Ag Lb <= 2.36 -> Ag La <= 7.76 (2.9897) | Kept: Ag La <= 7.76 -> Ag Lb <= 2.36 (26.4196)
# Removed: Bremsstrahlung <= 9.64 -> Ag ka <= -7.06 (0.5547) | Kept: Ag ka <= -7.06 -> Bremsstrahlung <= 9.64 (1.3884)
# Removed: Bremsstrahlung <= 4.15 -> Ag ka <= -7.06 (0.5709) | Kept: Ag ka <= -7.06 -> Bremsstrahlung <= 4.15 (0.9241)
# Removed: Ag ka <= -7.06 -> Ag ka <= 20.95 (0.6488) | Kept: Ag ka <= 20.95 -> Ag ka <= -7.06 (1.1954)
# Removed: Ag ka > -7.06 -> Ag ka > -11.59 (0.8424) | Kept: Ag ka > -11.59 -> Ag ka > -7.06 (0.8652)
# Removed: Ag compton <= 2.96 -> Ag ka > -11.59 (0.2863) | Kept: Ag ka > -11.59 -> Ag compton <= 2.96 (0.4268)
# Removed: Ag compton <= 6.52 -> Ag ka > -11.59 (0.3791) | Kept: Ag ka > -11.59 -> Ag compton <= 6.52 (0.5532)
# Removed: Bremsstrahlung > -9.06 -> Ag ka > -7.06 (0.2329) | Kept: Ag ka > -7.06 -> Bremsstrahlung > -9.06 (0.4951)
# Removed: Bremsstrahlung <= 4.15 -> Ag ka > -7.06 (0.2505) | Kept: Ag ka > -7.06 -> Bremsstrahlung <= 4.15 (1.5186)
# Removed: Ag ka > -7.06 -> Ag compton <= 6.52 (0.6240) | Kept: Ag compton <= 6.52 -> Ag ka > -7.06 (0.7889)
# Removed: Bremsstrahlung <= 9.64 -> Bremsstrahlung <= 4.15 (0.5490) | Kept: Bremsstrahlung <= 4.15 -> Bremsstrahlung <= 9.64 (0.8640)
# Removed: Bremsstrahlung <= -1.54 -> Bremsstrahlung <= 9.64 (0.2802) | Kept: Bremsstrahlung <= 9.64 -> Bremsstrahlung <= -1.54 (0.5143)
# Removed: Bremsstrahlung <= -1.54 -> Bremsstrahlung <= 4.15 (0.3062) | Kept: Bremsstrahlung <= 4.15 -> Bremsstrahlung <= -1.54 (0.5773)
# Removed: Bremsstrahlung <= -1.54 -> Ag ka <= 20.95 (0.5314) | Kept: Ag ka <= 20.95 -> Bremsstrahlung <= -1.54 (1.7775)
# Removed: Bremsstrahlung <= -1.54 -> Ag compton <= 6.52 (0.2528) | Kept: Ag compton <= 6.52 -> Bremsstrahlung <= -1.54 (0.8294)
# Removed: Ag compton <= 6.52 -> Ag ka <= 20.95 (0.3826) | Kept: Ag ka <= 20.95 -> Ag compton <= 6.52 (1.2866)
# Removed: Bremsstrahlung > -9.06 -> Ag compton <= 6.52 (0.4506) | Kept: Ag compton <= 6.52 -> Bremsstrahlung > -9.06 (1.1625)
# Removed: Bremsstrahlung > -9.06 -> Ag compton <= 2.96 (0.2288) | Kept: Ag compton <= 2.96 -> Bremsstrahlung > -9.06 (0.3420)
# Removed: Bremsstrahlung > -1.54 -> Ag compton <= 2.96 (0.1734) | Kept: Ag compton <= 2.96 -> Bremsstrahlung > -1.54 (0.8301)
# Removed: Ag compton > -6.71 -> Bremsstrahlung > -1.54 (0.2172) | Kept: Bremsstrahlung > -1.54 -> Ag compton > -6.71 (0.4484)
# Removed: Bremsstrahlung > 4.15 -> Bremsstrahlung > -1.54 (0.1716) | Kept: Bremsstrahlung > -1.54 -> Bremsstrahlung > 4.15 (0.3445)
# Removed: Bremsstrahlung > -1.54 -> Ag compton <= -1.09 (0.1518) | Kept: Ag compton <= -1.09 -> Bremsstrahlung > -1.54 (0.2658)
# Removed: Ag compton <= 2.96 -> Bremsstrahlung > 4.15 (0.5737) | Kept: Bremsstrahlung > 4.15 -> Ag compton <= 2.96 (0.6588)
# Removed: Ag compton > -6.71 -> Ag compton <= 2.96 (0.2843) | Kept: Ag compton <= 2.96 -> Ag compton > -6.71 (0.2910)
# Removed: Bremsstrahlung > 4.15 -> Ag compton <= -1.09 (0.1513) | Kept: Ag compton <= -1.09 -> Bremsstrahlung > 4.15 (0.2152)
# Removed: Ag compton > -6.71 -> Ag compton <= -1.09 (0.2263) | Kept: Ag compton <= -1.09 -> Ag compton > -6.71 (1.1630)
# Removed: Ag Lb > 2.36 -> Ag La > 2.70 (0.5175) | Kept: Ag La > 2.70 -> Ag Lb > 2.36 (0.7722)
# Removed: Ag compton > -1.09 -> Ag Lb > 2.36 (0.1596) | Kept: Ag Lb > 2.36 -> Ag compton > -1.09 (0.9155)
# Removed: Ag compton > -1.09 -> Ag La > 2.70 (0.1413) | Kept: Ag La > 2.70 -> Ag compton > -1.09 (1.2241)
# Removed: Fe > -1.18 -> Ag La > -18.52 (0.0112) | Kept: Ag La > -18.52 -> Fe > -1.18 (0.3211)
# Removed: Fe > -1.18 -> Ca <= -0.68 (0.0167) | Kept: Ca <= -0.68 -> Fe > -1.18 (0.0538)
# Removed: Fe > -1.18 -> Ca > -0.68 (0.0114) | Kept: Ca > -0.68 -> Fe > -1.18 (0.0217)
# Removed: Fe > 0.31 -> Fe > -1.18 (0.0114) | Kept: Fe > -1.18 -> Fe > 0.31 (0.0414)
# Removed: Fe > -1.18 -> Ca > 0.46 (0.0164) | Kept: Ca > 0.46 -> Fe > -1.18 (0.0202)
# Removed: Fe > -1.18 -> Zn > 0.56 (0.0146) | Kept: Zn > 0.56 -> Fe > -1.18 (0.0181)
# Removed: Ca <= 1.81 -> Ca <= -0.68 (0.0226) | Kept: Ca <= -0.68 -> Ca <= 1.81 (0.0237)
# Removed: Ca <= 0.46 -> Ca > 0.46 (0.0261) | Kept: Ca > 0.46 -> Ca <= 0.46 (0.0868)
# Removed: Cu > 0.32 -> Fe > 0.31 (0.0104) | Kept: Fe > 0.31 -> Cu > 0.32 (0.0154)
# Removed: Fe > 0.31 -> Ag Lb > 6.48 (0.0115) | Kept: Ag Lb > 6.48 -> Fe > 0.31 (0.0621)
# Removed: Fe > -0.36 -> Ca <= 0.46 (0.0086) | Kept: Ca <= 0.46 -> Fe > -0.36 (0.0186)
# Removed: background > -1.23 -> Fe > -0.36 (0.0022) | Kept: Fe > -0.36 -> background > -1.23 (0.0200)
# Removed: Ca > -1.79 -> Zn > 0.56 (0.0191) | Kept: Zn > 0.56 -> Ca > -1.79 (0.0362)
# Removed: Ca <= 1.81 -> Zn > 0.56 (0.0104) | Kept: Zn > 0.56 -> Ca <= 1.81 (0.0191)
# Removed: background > -1.23 -> Zn > 0.56 (0.0030) | Kept: Zn > 0.56 -> background > -1.23 (0.0143)
# Removed: Ca > -1.79 -> Ag compton > 2.96 (0.0219) | Kept: Ag compton > 2.96 -> Ca > -1.79 (0.0633)
# Removed: background > -1.23 -> Ag compton > 2.96 (0.0029) | Kept: Ag compton > 2.96 -> background > -1.23 (0.0337)
# Removed: Ca <= 0.46 -> Ag compton > 2.96 (0.0151) | Kept: Ag compton > 2.96 -> Ca <= 0.46 (0.0892)
# Removed: Ca <= 1.81 -> Ag compton > 2.96 (0.0108) | Kept: Ag compton > 2.96 -> Ca <= 1.81 (0.0379)
# Removed: background > -1.23 -> Ca <= 0.46 (0.0024) | Kept: Ca <= 0.46 -> background > -1.23 (0.0139)
# Removed: background > -0.46 -> background > 0.40 (0.0015) | Kept: background > 0.40 -> background > -0.46 (0.0019)
# Removed: background <= -0.46 -> background > 0.40 (0.0012) | Kept: background > 0.40 -> background <= -0.46 (0.0015)
# Removed: background > 0.40 -> Ag La > 7.76 (0.0010) | Kept: Ag La > 7.76 -> background > 0.40 (0.0436)
# Removed: background > 0.40 -> Fe <= -0.36 (0.0013) | Kept: Fe <= -0.36 -> background > 0.40 (0.0039)
# Removed: background > -0.46 -> Ag Lb > 6.48 (0.0029) | Kept: Ag Lb > 6.48 -> background > -0.46 (0.1129)
# Removed: background > -0.46 -> Zn > -1.47 (0.0036) | Kept: Zn > -1.47 -> background > -0.46 (0.0069)
# Removed: Zn <= 0.56 -> Cu <= 0.32 (0.0070) | Kept: Cu <= 0.32 -> Zn <= 0.56 (0.0086)
# Removed: Cu <= 0.32 -> Ag La > 7.76 (0.0050) | Kept: Ag La > 7.76 -> Cu <= 0.32 (0.0334)
# Removed: Zn <= 0.56 -> Ag La > 7.76 (0.0107) | Kept: Ag La > 7.76 -> Zn <= 0.56 (0.0380)
# Removed: Fe <= 0.31 -> Zn <= 1.56 (0.0014) | Kept: Zn <= 1.56 -> Fe <= 0.31 (0.0050)
# Removed: Cu > -1.74 -> Zn > -0.39 (0.0031) | Kept: Zn > -0.39 -> Cu > -1.74 (0.0106)
# Removed: Cu > -0.64 -> Cu > -1.74 (0.0032) | Kept: Cu > -1.74 -> Cu > -0.64 (0.0126)
# Removed: Cu > -1.74 -> Zn > -1.47 (0.0036) | Kept: Zn > -1.47 -> Cu > -1.74 (0.0050)
# Removed: Zn > -0.39 -> Zn > -1.47 (0.0058) | Kept: Zn > -1.47 -> Zn > -0.39 (0.0058)
# Removed: Zn > -1.47 -> Ag Lb > -15.87 (0.0101) | Kept: Ag Lb > -15.87 -> Zn > -1.47 (0.0664)
# Removed: Cu <= -0.64 -> Zn <= -0.39 (0.0038) | Kept: Zn <= -0.39 -> Cu <= -0.64 (0.0050)
# Removed: background <= 1.29 -> Cu > -0.64 (0.0014) | Kept: Cu > -0.64 -> background <= 1.29 (0.0054)
# Removed: background <= 0.40 -> Cu <= -0.64 (0.0013) | Kept: Cu <= -0.64 -> background <= 0.40 (0.0025)
# Removed: background <= 1.29 -> Ag Lb > 6.48 (0.0033) | Kept: Ag Lb > 6.48 -> background <= 1.29 (0.0780)
# Removed: background <= 1.29 -> Ag Lb > -15.87 (0.0021) | Kept: Ag Lb > -15.87 -> background <= 1.29 (0.0485)
# Removed: background <= 0.40 -> Fe <= -0.36 (0.0005) | Kept: Fe <= -0.36 -> background <= 0.40 (0.0017)
#
# ======================================================================
# CONSTRUCTED GRAPH SUMMARY
# ======================================================================
# Initial edges: 392 | Removed: 70
# Predicate nodes: 60
# Metric: Covariance
# Weighting by explained variance: ENABLED
#
# ======================================================================
# Processando Grafo - Semente: 2
# ======================================================================
#
#
# Total bidirectional pairs found: 63
# Removed: Bremsstrahlung > -9.06 -> Ag compton <= 6.52 (0.8076) | Kept: Ag compton <= 6.52 -> Bremsstrahlung > -9.06 (1.4629)
# Removed: Bremsstrahlung > -9.06 -> Ag ka <= -7.06 (0.3156) | Kept: Ag ka <= -7.06 -> Bremsstrahlung > -9.06 (0.6519)
# Removed: Bremsstrahlung <= 9.64 -> Ag compton <= 6.52 (0.2393) | Kept: Ag compton <= 6.52 -> Bremsstrahlung <= 9.64 (0.4298)
# Removed: Ag compton <= 6.52 -> Bremsstrahlung <= -1.54 (0.4473) | Kept: Bremsstrahlung <= -1.54 -> Ag compton <= 6.52 (0.4965)
# Removed: Bremsstrahlung > 4.15 -> Ag compton <= 6.52 (0.1821) | Kept: Ag compton <= 6.52 -> Bremsstrahlung > 4.15 (0.7664)
# Removed: Bremsstrahlung <= 4.15 -> Bremsstrahlung <= 9.64 (0.8215) | Kept: Bremsstrahlung <= 9.64 -> Bremsstrahlung <= 4.15 (1.0591)
# Removed: Bremsstrahlung <= 9.64 -> Ag ka > -7.06 (0.2253) | Kept: Ag ka > -7.06 -> Bremsstrahlung <= 9.64 (2.2697)
# Removed: Bremsstrahlung > 4.15 -> Ag ka <= -7.06 (0.2026) | Kept: Ag ka <= -7.06 -> Bremsstrahlung > 4.15 (0.5518)
# Removed: Bremsstrahlung <= -1.54 -> Ag ka <= -7.06 (0.2774) | Kept: Ag ka <= -7.06 -> Bremsstrahlung <= -1.54 (0.6832)
# Removed: Ag ka <= 20.95 -> Bremsstrahlung > -1.54 (0.5956) | Kept: Bremsstrahlung > -1.54 -> Ag ka <= 20.95 (0.6097)
# Removed: Ag ka <= 20.95 -> Ag ka > -11.59 (0.4067) | Kept: Ag ka > -11.59 -> Ag ka <= 20.95 (0.4837)
# Removed: Ag compton <= 2.96 -> Ag compton > -6.71 (0.2720) | Kept: Ag compton > -6.71 -> Ag compton <= 2.96 (0.2779)
# Removed: Ag compton <= 2.96 -> Ag ka > -11.59 (0.5508) | Kept: Ag ka > -11.59 -> Ag compton <= 2.96 (0.8301)
# Removed: Ag compton <= 2.96 -> Ag ka > -7.06 (0.2884) | Kept: Ag ka > -7.06 -> Ag compton <= 2.96 (0.4757)
# Removed: Ag compton > -1.09 -> Ag compton <= 2.96 (0.1866) | Kept: Ag compton <= 2.96 -> Ag compton > -1.09 (0.2168)
# Removed: Ag compton <= -1.09 -> Ag compton > -6.71 (0.2431) | Kept: Ag compton > -6.71 -> Ag compton <= -1.09 (0.2503)
# Removed: Ag compton > -6.71 -> Ag Lb > 2.36 (0.1958) | Kept: Ag Lb > 2.36 -> Ag compton > -6.71 (0.2374)
# Removed: Ag compton <= -1.09 -> Ag La > 2.70 (0.1831) | Kept: Ag La > 2.70 -> Ag compton <= -1.09 (0.2434)
# Removed: Ag compton <= -1.09 -> Ag compton > -1.09 (0.2217) | Kept: Ag compton > -1.09 -> Ag compton <= -1.09 (0.3837)
# Removed: Ag compton > -1.09 -> Ag La > 2.70 (0.1108) | Kept: Ag La > 2.70 -> Ag compton > -1.09 (0.5253)
# Removed: Ag La > 2.70 -> Ag Lb > 2.36 (0.9625) | Kept: Ag Lb > 2.36 -> Ag La > 2.70 (1.0248)
# Removed: Ag Lb > 2.36 -> Ag compton > -1.09 (0.4280) | Kept: Ag compton > -1.09 -> Ag Lb > 2.36 (0.5488)
# Removed: Ag compton > -1.09 -> Ag ka > 5.37 (0.2617) | Kept: Ag ka > 5.37 -> Ag compton > -1.09 (0.5411)
# Removed: Ag Lb > 2.36 -> Ag ka > 5.37 (0.2216) | Kept: Ag ka > 5.37 -> Ag Lb > 2.36 (0.2470)
# Removed: Ag ka > 5.37 -> Ag La > -18.52 (0.0982) | Kept: Ag La > -18.52 -> Ag ka > 5.37 (0.1460)
# Removed: Cu > 0.32 -> Ag ka > 5.37 (0.0133) | Kept: Ag ka > 5.37 -> Cu > 0.32 (0.1266)
# Removed: Ca > 0.46 -> Ag compton > 2.96 (0.0302) | Kept: Ag compton > 2.96 -> Ca > 0.46 (0.0455)
# Removed: Fe > -0.36 -> Ca > 0.46 (0.0101) | Kept: Ca > 0.46 -> Fe > -0.36 (0.0227)
# Removed: Ca > 0.46 -> Ca <= 0.46 (0.0236) | Kept: Ca <= 0.46 -> Ca > 0.46 (0.0237)
# Removed: Ca <= 1.81 -> Ca > 0.46 (0.0178) | Kept: Ca > 0.46 -> Ca <= 1.81 (0.0367)
# Removed: Ca > -1.79 -> Ag compton > 2.96 (0.0202) | Kept: Ag compton > 2.96 -> Ca > -1.79 (0.1641)
# Removed: Cu > 0.32 -> Ag compton > 2.96 (0.0122) | Kept: Ag compton > 2.96 -> Cu > 0.32 (0.1153)
# Removed: Fe > 0.31 -> Ag compton > 2.96 (0.0135) | Kept: Ag compton > 2.96 -> Fe > 0.31 (0.1306)
# Removed: Ca > -0.68 -> Ca > -1.79 (0.0205) | Kept: Ca > -1.79 -> Ca > -0.68 (0.0265)
# Removed: Ca > -1.79 -> Ca <= -0.68 (0.0496) | Kept: Ca <= -0.68 -> Ca > -1.79 (0.0507)
# Removed: Ca > -1.79 -> Ca <= 0.46 (0.0454) | Kept: Ca <= 0.46 -> Ca > -1.79 (0.0642)
# Removed: Zn > 0.56 -> Ca > -1.79 (0.0181) | Kept: Ca > -1.79 -> Zn > 0.56 (0.0189)
# Removed: Ca > -0.68 -> Ca <= 1.81 (0.0158) | Kept: Ca <= 1.81 -> Ca > -0.68 (0.0213)
# Removed: Ca <= 1.81 -> Zn > 0.56 (0.0333) | Kept: Zn > 0.56 -> Ca <= 1.81 (0.0349)
# Removed: background > -1.23 -> Ca <= 1.81 (0.0029) | Kept: Ca <= 1.81 -> background > -1.23 (0.0306)
# Removed: Ca <= -0.68 -> Zn > 0.56 (0.0215) | Kept: Zn > 0.56 -> Ca <= -0.68 (0.0357)
# Removed: Cu > 0.32 -> Ca <= -0.68 (0.0239) | Kept: Ca <= -0.68 -> Cu > 0.32 (0.0240)
# Removed: Fe > 0.31 -> Ca <= 0.46 (0.0130) | Kept: Ca <= 0.46 -> Fe > 0.31 (0.0222)
# Removed: Cu > 0.32 -> Fe > 0.31 (0.0089) | Kept: Fe > 0.31 -> Cu > 0.32 (0.0182)
# Removed: Fe > -0.36 -> Fe > 0.31 (0.0131) | Kept: Fe > 0.31 -> Fe > -0.36 (0.0243)
# Removed: background > -1.23 -> Fe > -0.36 (0.0049) | Kept: Fe > -0.36 -> background > -1.23 (0.0118)
# Removed: background > -1.23 -> Ag Lb > -15.87 (0.0030) | Kept: Ag Lb > -15.87 -> background > -1.23 (0.1026)
# Removed: Zn <= 0.56 -> Ag Lb > -15.87 (0.0081) | Kept: Ag Lb > -15.87 -> Zn <= 0.56 (0.0599)
# Removed: background <= 1.29 -> Ag Lb > 6.48 (0.0059) | Kept: Ag Lb > 6.48 -> background <= 1.29 (0.0445)
# Removed: background <= 1.29 -> Ag La > 7.76 (0.0027) | Kept: Ag La > 7.76 -> background <= 1.29 (0.0818)
# Removed: background <= 1.29 -> Cu > -1.74 (0.0014) | Kept: Cu > -1.74 -> background <= 1.29 (0.0050)
# Removed: Zn <= -0.39 -> Zn > -1.47 (0.0052) | Kept: Zn > -1.47 -> Zn <= -0.39 (0.0092)
# Removed: Cu > -1.74 -> Zn > -1.47 (0.0014) | Kept: Zn > -1.47 -> Cu > -1.74 (0.0062)
# Removed: Zn > -1.47 -> Zn <= 0.56 (0.0098) | Kept: Zn <= 0.56 -> Zn > -1.47 (0.0103)
# Removed: Zn <= 0.56 -> Zn <= -0.39 (0.0054) | Kept: Zn <= -0.39 -> Zn <= 0.56 (0.0299)
# Removed: Cu <= 1.92 -> Ag La > 7.76 (0.0043) | Kept: Ag La > 7.76 -> Cu <= 1.92 (0.0476)
# Removed: Fe <= -0.36 -> Zn > -0.39 (0.0035) | Kept: Zn > -0.39 -> Fe <= -0.36 (0.0081)
# Removed: Zn > -0.39 -> Fe <= 1.20 (0.0042) | Kept: Fe <= 1.20 -> Zn > -0.39 (0.0045)
# Removed: Zn > -0.39 -> Cu > -1.74 (0.0065) | Kept: Cu > -1.74 -> Zn > -0.39 (0.0086)
# Removed: background <= 0.40 -> Fe <= -0.36 (0.0005) | Kept: Fe <= -0.36 -> background <= 0.40 (0.0015)
# Removed: Fe <= 1.20 -> Cu > -1.74 (0.0020) | Kept: Cu > -1.74 -> Fe <= 1.20 (0.0036)
# Removed: background > 0.40 -> background > -0.46 (0.0012) | Kept: background > -0.46 -> background > 0.40 (0.0046)
# Removed: background > 0.40 -> Cu <= 1.92 (0.0012) | Kept: Cu <= 1.92 -> background > 0.40 (0.0015)
#
# ======================================================================
# CONSTRUCTED GRAPH SUMMARY
# ======================================================================
# Initial edges: 370 | Removed: 63
# Predicate nodes: 60
# Metric: Covariance
# Weighting by explained variance: ENABLED
#
# ======================================================================
# Processando Grafo - Semente: 3
# ======================================================================
#
#
# Total bidirectional pairs found: 60
# Removed: Ag Lb <= 2.36 -> Ag La <= 7.76 (2.9536) | Kept: Ag La <= 7.76 -> Ag Lb <= 2.36 (26.7166)
# Removed: Bremsstrahlung <= 4.15 -> Bremsstrahlung <= 9.64 (0.5582) | Kept: Bremsstrahlung <= 9.64 -> Bremsstrahlung <= 4.15 (1.7517)
# Removed: Bremsstrahlung <= 9.64 -> Ag ka <= -7.06 (0.2785) | Kept: Ag ka <= -7.06 -> Bremsstrahlung <= 9.64 (0.9394)
# Removed: Bremsstrahlung > -9.06 -> Bremsstrahlung <= 9.64 (0.2721) | Kept: Bremsstrahlung <= 9.64 -> Bremsstrahlung > -9.06 (0.5975)
# Removed: Bremsstrahlung <= 9.64 -> Ag ka > -7.06 (0.2276) | Kept: Ag ka > -7.06 -> Bremsstrahlung <= 9.64 (0.8619)
# Removed: Bremsstrahlung <= -1.54 -> Ag compton <= 6.52 (0.2509) | Kept: Ag compton <= 6.52 -> Bremsstrahlung <= -1.54 (0.7726)
# Removed: Ag ka > -7.06 -> Bremsstrahlung <= -1.54 (0.5343) | Kept: Bremsstrahlung <= -1.54 -> Ag ka > -7.06 (0.6720)
# Removed: Bremsstrahlung <= -1.54 -> Ag ka <= 20.95 (0.4567) | Kept: Ag ka <= 20.95 -> Bremsstrahlung <= -1.54 (0.6101)
# Removed: Bremsstrahlung <= -1.54 -> Bremsstrahlung > -9.06 (0.2090) | Kept: Bremsstrahlung > -9.06 -> Bremsstrahlung <= -1.54 (0.2570)
# Removed: Bremsstrahlung <= -1.54 -> Ag ka > -11.59 (0.1996) | Kept: Ag ka > -11.59 -> Bremsstrahlung <= -1.54 (0.5427)
# Removed: Bremsstrahlung > -1.54 -> Bremsstrahlung <= -1.54 (0.2191) | Kept: Bremsstrahlung <= -1.54 -> Bremsstrahlung > -1.54 (0.2394)
# Removed: Bremsstrahlung > -1.54 -> Ag compton <= 6.52 (0.2226) | Kept: Ag compton <= 6.52 -> Bremsstrahlung > -1.54 (0.3793)
# Removed: Ag compton <= 6.52 -> Ag ka <= -7.06 (0.4372) | Kept: Ag ka <= -7.06 -> Ag compton <= 6.52 (1.2391)
# Removed: Bremsstrahlung > -9.06 -> Ag ka <= -7.06 (0.4503) | Kept: Ag ka <= -7.06 -> Bremsstrahlung > -9.06 (1.0764)
# Removed: Ag ka <= -7.06 -> Ag ka > -7.06 (0.5133) | Kept: Ag ka > -7.06 -> Ag ka <= -7.06 (1.2551)
# Removed: Ag compton <= 2.96 -> Ag ka > -7.06 (0.2644) | Kept: Ag ka > -7.06 -> Ag compton <= 2.96 (0.4108)
# Removed: Bremsstrahlung > 4.15 -> Ag compton > -6.71 (0.1448) | Kept: Ag compton > -6.71 -> Bremsstrahlung > 4.15 (0.2420)
# Removed: Ag compton <= -1.09 -> Ag compton > -6.71 (0.2488) | Kept: Ag compton > -6.71 -> Ag compton <= -1.09 (0.6941)
# Removed: Ag compton > -6.71 -> Ag compton <= 2.96 (0.3318) | Kept: Ag compton <= 2.96 -> Ag compton > -6.71 (0.8428)
# Removed: Bremsstrahlung > -1.54 -> Ag La > 2.70 (0.1330) | Kept: Ag La > 2.70 -> Bremsstrahlung > -1.54 (0.2610)
# Removed: Ag compton <= 2.96 -> Bremsstrahlung > 4.15 (0.2745) | Kept: Bremsstrahlung > 4.15 -> Ag compton <= 2.96 (0.3309)
# Removed: Ag compton <= -1.09 -> Ag ka > -11.59 (0.2183) | Kept: Ag ka > -11.59 -> Ag compton <= -1.09 (0.7308)
# Removed: Bremsstrahlung > 4.15 -> Ag compton <= -1.09 (0.2605) | Kept: Ag compton <= -1.09 -> Bremsstrahlung > 4.15 (0.4865)
# Removed: Ag ka > 5.37 -> Ag La > 2.70 (0.2025) | Kept: Ag La > 2.70 -> Ag ka > 5.37 (0.2447)
# Removed: Ag Lb > 2.36 -> Ag La > 2.70 (0.4789) | Kept: Ag La > 2.70 -> Ag Lb > 2.36 (1.2946)
# Removed: Ag compton > -1.09 -> Ag Lb > 2.36 (0.2856) | Kept: Ag Lb > 2.36 -> Ag compton > -1.09 (0.9991)
# Removed: Ag compton > -1.09 -> Ag La > 2.70 (0.4869) | Kept: Ag La > 2.70 -> Ag compton > -1.09 (0.7219)
# Removed: Cu > 0.32 -> Ag La > -18.52 (0.0130) | Kept: Ag La > -18.52 -> Cu > 0.32 (0.3186)
# Removed: Cu > 0.32 -> Fe > -1.18 (0.0108) | Kept: Fe > -1.18 -> Cu > 0.32 (0.0166)
# Removed: Cu > 0.32 -> Ag compton > 2.96 (0.0175) | Kept: Ag compton > 2.96 -> Cu > 0.32 (0.0742)
# Removed: Ca > -0.68 -> Ag Lb > 6.48 (0.0145) | Kept: Ag Lb > 6.48 -> Ca > -0.68 (0.1162)
# Removed: Ca > 0.46 -> Ag Lb > 6.48 (0.0148) | Kept: Ag Lb > 6.48 -> Ca > 0.46 (0.1284)
# Removed: Ag La > 7.76 -> Ag Lb > 6.48 (0.0447) | Kept: Ag Lb > 6.48 -> Ag La > 7.76 (0.0536)
# Removed: Zn > 0.56 -> Ca > -0.68 (0.0138) | Kept: Ca > -0.68 -> Zn > 0.56 (0.0181)
# Removed: Ca > -1.79 -> Ca > -0.68 (0.0222) | Kept: Ca > -0.68 -> Ca > -1.79 (0.0241)
# Removed: Zn > 0.56 -> Ca > 0.46 (0.0183) | Kept: Ca > 0.46 -> Zn > 0.56 (0.0239)
# Removed: Ca <= 1.81 -> Ca > 0.46 (0.0184) | Kept: Ca > 0.46 -> Ca <= 1.81 (0.0701)
# Removed: Ca > -1.79 -> Ca > 0.46 (0.0177) | Kept: Ca > 0.46 -> Ca > -1.79 (0.0256)
# Removed: Fe > -0.36 -> Ca > 0.46 (0.0110) | Kept: Ca > 0.46 -> Fe > -0.36 (0.0180)
# Removed: Ca > -1.79 -> Zn > 0.56 (0.0177) | Kept: Zn > 0.56 -> Ca > -1.79 (0.0316)
# Removed: Fe > -1.18 -> Ca > -1.79 (0.0272) | Kept: Ca > -1.79 -> Fe > -1.18 (0.0397)
# Removed: Fe > -1.18 -> Ca <= -0.68 (0.0125) | Kept: Ca <= -0.68 -> Fe > -1.18 (0.0515)
# Removed: Fe > 0.31 -> Ag Lb > -15.87 (0.0091) | Kept: Ag Lb > -15.87 -> Fe > 0.31 (0.0780)
# Removed: Fe > -0.36 -> Ca <= 0.46 (0.0342) | Kept: Ca <= 0.46 -> Fe > -0.36 (0.0405)
# Removed: Ca <= 0.46 -> Ca <= -0.68 (0.0168) | Kept: Ca <= -0.68 -> Ca <= 0.46 (0.0547)
# Removed: background > -1.23 -> Cu <= 0.32 (0.0025) | Kept: Cu <= 0.32 -> background > -1.23 (0.0067)
# Removed: Ag Lb > -15.87 -> Ag compton > 2.96 (0.0434) | Kept: Ag compton > 2.96 -> Ag Lb > -15.87 (0.0509)
# Removed: Cu <= 0.32 -> Ca <= 1.81 (0.0073) | Kept: Ca <= 1.81 -> Cu <= 0.32 (0.0157)
# Removed: Cu > -1.74 -> Cu > -0.64 (0.0025) | Kept: Cu > -0.64 -> Cu > -1.74 (0.0134)
# Removed: background > -0.46 -> Cu > -0.64 (0.0012) | Kept: Cu > -0.64 -> background > -0.46 (0.0026)
# Removed: background > -0.46 -> Cu > -1.74 (0.0031) | Kept: Cu > -1.74 -> background > -0.46 (0.0053)
# Removed: background > -0.46 -> Fe <= -0.36 (0.0016) | Kept: Fe <= -0.36 -> background > -0.46 (0.0083)
# Removed: Cu <= 0.32 -> Zn > -1.47 (0.0016) | Kept: Zn > -1.47 -> Cu <= 0.32 (0.0071)
# Removed: background <= 1.29 -> Zn <= 1.56 (0.0015) | Kept: Zn <= 1.56 -> background <= 1.29 (0.0047)
# Removed: Fe <= -0.36 -> Zn <= 1.56 (0.0048) | Kept: Zn <= 1.56 -> Fe <= -0.36 (0.0057)
# Removed: Cu <= 1.92 -> Zn <= 0.56 (0.0034) | Kept: Zn <= 0.56 -> Cu <= 1.92 (0.0063)
# Removed: Zn <= 0.56 -> Ag La > 7.76 (0.0042) | Kept: Ag La > 7.76 -> Zn <= 0.56 (0.0746)
# Removed: background <= 0.40 -> Ag La > 7.76 (0.0008) | Kept: Ag La > 7.76 -> background <= 0.40 (0.0202)
# Removed: Zn <= -0.39 -> Ag La > 7.76 (0.0071) | Kept: Ag La > 7.76 -> Zn <= -0.39 (0.0173)
# Removed: Fe <= -0.36 -> Cu <= 0.32 (0.0028) | Kept: Cu <= 0.32 -> Fe <= -0.36 (0.0036)
#
# ======================================================================
# CONSTRUCTED GRAPH SUMMARY
# ======================================================================
# Initial edges: 372 | Removed: 60
# Predicate nodes: 60
# Metric: Covariance
# Weighting by explained variance: ENABLED
#
# Processing graph LRC...
#
# Processing graph LRC...
#
# Processing graph LRC...
#
# Processing graph LRC...
#    Predicate_Cov_Seed_0 Predicate_Cov_Seed_1 Predicate_Cov_Seed_2  \
# 0         Ag La <= 2.70        Ag La <= 2.70        Ag La <= 2.70
# 1         Ag La <= 7.76        Ag La <= 7.76        Ag La <= 7.76
# 2         Ag Lb <= 2.36        Ag Lb <= 2.36        Ag Lb <= 2.36
# 3         Ag Lb <= 6.48        Ag Lb <= 6.48        Ag Lb <= 6.48
# 4         Ag La <= 9.01        Ag La <= 9.01        Ag La <= 9.01
# ..                  ...                  ...                  ...
# 57  background <= -0.46   background <= 1.29           Zn > -1.47
# 58   background > -0.46    background > 0.40    background > 0.40
# 59          Cu <= -0.64           Cu <= 1.92            Cu > 0.32
# 60              Class_A              Class_A              Class_A
# 61              Class_B              Class_B              Class_B
#
#    Predicate_Cov_Seed_3
# 0         Ag La <= 2.70
# 1         Ag La <= 7.76
# 2         Ag Lb <= 2.36
# 3         Ag Lb <= 6.48
# 4         Ag La <= 9.01
# ..                  ...
# 57  background <= -0.46
# 58           Cu <= 1.92
# 59           Fe <= 0.31
# 60              Class_A
# 61              Class_B
#
# [62 rows x 4 columns]

# %%
# Somar LRCs de predicados equivalentes entre diferentes seeds
lrc_combined_list = []

for seed in random_seeds:
    lrc_df = lrc_cov_by_seed[seed].copy()
    lrc_combined_list.append(lrc_df) # o append adiciona o dataframe ao final da lista

# Concatenar todos os dataframes
lrc_all_seeds = pd.concat(lrc_combined_list, ignore_index=True) 

# Agrupar por predicado (Node) e somar as LRCs, mantendo Zone, Threshold e Operator
lrc_summed_df_cov = lrc_all_seeds.groupby('Node').agg({ # o .agg pode ser usado para aplicar múltiplas funções de agregação
    'Local_Reaching_Centrality': 'mean', # sum = somando as LRCs, poderia ser média ou outro agregado
    'Zone': 'first',
    'Threshold': 'first',
    'Operator': 'first'
}).reset_index()

# Ordenar pelo valor de LRC somado (maior para menor)
lrc_summed_df_cov = lrc_summed_df_cov.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
# vamoss pegar so os valore sunicos de lrc_summed_df baseado na zona espectral
lrc_summed_unique_df_cov = lrc_summed_df_cov.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
#lrc_summed_unique_df_cov = lrc_summed_unique_df_cov.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
lrc_summed_unique_df_cov
# Out:
#                       Node  Local_Reaching_Centrality            Zone  \
# 0            Ag La <= 2.70                  21.969468           Ag La
# 1            Ag Lb <= 2.36                  16.616148           Ag Lb
# 2            Ag ka <= 5.37                   1.612364           Ag ka
# 3       Ag compton <= 6.52                   0.921116      Ag compton
# 4   Bremsstrahlung <= 9.64                   0.854556  Bremsstrahlung
# 5               Ca > -0.68                   0.276116              Ca
# 6               Fe <= 1.20                   0.227833              Fe
# 7               Zn > -0.39                   0.225747              Zn
# 8               Cu <= 0.32                   0.216556              Cu
# 9       background > -0.46                   0.192265      background
# 10                 Class_A                   0.000000            None
#
#    Threshold Operator
# 0       2.70       <=
# 1       2.36       <=
# 2       5.37       <=
# 3       6.52       <=
# 4       9.64       <=
# 5      -0.68        >
# 6       1.20       <=
# 7      -0.39        >
# 8       0.32       <=
# 9      -0.46        >
# 10      None     None

# %%
# Criar zone_sums_df para dados NÃO pré-processados (Xcalclass)
spectral_zones_original = exp.extract_spectral_zones(Xcalclass, spectral_cuts)
zones_original = exp.aggregate_spectral_zones_pca(spectral_zones_original) # apca aggregation

# Aplicar o mapeamento
lrc_summed_df_cov_natural = exp.map_thresholds_to_natural(
    lrc_df=lrc_summed_df_cov,
    zone_sums_preprocessed=zone_scores_df,
    zone_sums_natural=zones_original[0]
)

lrc_summed_df_cov_natural
# Out:
# Zone 'Ag La': VE = 91.39%, dim = 18 variables
# Zone 'Ag Lb': VE = 90.27%, dim = 15 variables
# Zone 'Ca': VE = 27.70%, dim = 19 variables
# Zone 'background': VE = 3.72%, dim = 87 variables
# Zone 'Fe': VE = 14.68%, dim = 23 variables
# Zone 'Cu': VE = 15.48%, dim = 66 variables
# Zone 'Zn': VE = 21.60%, dim = 29 variables
# Zone 'Bremsstrahlung': VE = 38.87%, dim = 429 variables
# Zone 'Ag compton': VE = 52.69%, dim = 62 variables
# Zone 'Ag ka': VE = 80.83%, dim = 45 variables
#                    Node  Local_Reaching_Centrality        Zone Threshold  \
# 0         Ag La <= 2.70                  21.969468       Ag La      2.70
# 1         Ag La <= 7.76                  19.231198       Ag La      7.76
# 2         Ag Lb <= 2.36                  16.616148       Ag Lb      2.36
# 3         Ag Lb <= 6.48                  13.648861       Ag Lb      6.48
# 4         Ag La <= 9.01                   9.890219       Ag La      9.01
# ..                  ...                        ...         ...       ...
# 57           Zn > -1.47                   0.169627          Zn     -1.47
# 58    background > 0.40                   0.165294  background      0.40
# 59  background <= -0.46                   0.164791  background     -0.46
# 60              Class_A                   0.000000        None      None
# 61              Class_B                   0.000000        None      None
#
#    Operator  Threshold_Natural  Reference_Sample_Index  Approximation_Error  \
# 0        <=          34.935039                    86.0             0.021418
# 1        <=         105.814886                    78.0             0.002963
# 2        <=          30.578162                     0.0             0.008013
# 3        <=          75.496450                    98.0             0.013050
# 4        <=         126.903607                   239.0             0.004801
# ..      ...                ...                     ...                  ...
# 57        >         -11.950025                   222.0             0.011055
# 58        >           4.852293                   186.0             0.003287
# 59       <=          11.266506                    83.0             0.002700
# 60     None                NaN                     NaN                  NaN
# 61     None                NaN                     NaN                  NaN
#
#                Node_Natural
# 0        Ag La <= 34.935039
# 1       Ag La <= 105.814886
# 2        Ag Lb <= 30.578162
# 3        Ag Lb <= 75.496450
# 4       Ag La <= 126.903607
# ..                      ...
# 57          Zn > -11.950025
# 58    background > 4.852293
# 59  background <= 11.266506
# 60                     None
# 61                     None
#
# [62 rows x 9 columns]

# %% [markdown]
# ## Reconstrução de Thresholds Multivariados
#
# Agora vamos pegar os thresholds dos predicados mais importantes e reconstruí-los como espectros completos.

# %%
import plotly.graph_objects as go

n = 0
zone_name = lrc_summed_df_cov_natural.iloc[n]['Zone']
threshold_score = float(lrc_summed_df_cov_natural.iloc[n]['Threshold_Natural'])  # Corrigido: usa n em vez de 7

# Usar pca_info_dict dos dados ORIGINAIS (zones_original[1])
pca_info_dict_original = zones_original[1]

# Reconstrução: τ = mean + threshold * loadings (no espaço original)
threshold_spectrum = exp.reconstruct_threshold_to_spectrum(
    threshold_value=threshold_score,
    zone_name=zone_name,
    pca_info_dict=pca_info_dict_original
)
print(f"\nEspectro de threshold reconstruído para zona '{zone_name}':")
print(f"  - Dimensão: {len(threshold_spectrum)} variáveis espectrais")
print(f"  - Range de energias: {threshold_spectrum.index[0]} - {threshold_spectrum.index[-1]}")
print(f"  - Variância explicada pela PC1: {pca_info_dict_original[zone_name]['variance_explained']:.2%}")

# Usar dados ORIGINAIS para plotar (spectral_zones_original)
zone_df = spectral_zones_original[zone_name]

# Plotar zona com threshold (inline)
fig = go.Figure()
x_values = pd.to_numeric(zone_df.columns, errors='coerce')

# Plotar espectros das amostras coloridas por classe
colors = {'A': 'gold', 'B': 'blue'}
for idx, row in zone_df.iterrows():
    class_label = ycalclass.iloc[idx] if idx < len(ycalclass) else 'Unknown'
    fig.add_trace(go.Scatter(
        x=x_values,
        y=row.values,
        mode='lines',
        line=dict(color=colors.get(class_label, 'rgba(128,128,128,0.3)'), width=0.5),
        name=f'Class {class_label}',
        showlegend=False,
        hoverinfo='skip'
    ))

# Plotar espectro de threshold (destaque)
fig.add_trace(go.Scatter(
    x=x_values,
    y=threshold_spectrum.values,
    mode='lines',
    line=dict(color='red', width=4, dash='dash'),
    name=f'Threshold Spectrum ({threshold_spectrum.name})'
))

# Layout do gráfico
fig.update_layout(
    title=f"Zona '{zone_name}' com Threshold Multivariado (Predicado: {lrc_summed_df_cov_natural.iloc[n]['Node_Natural']})",
    xaxis_title='Energia / Comprimento de Onda',
    yaxis_title='Intensidade',
    template='plotly_white',
    showlegend=True,
    legend=dict(yanchor="top", y=0.99, xanchor="left", x=0.01)
)

fig.show()
# Out:
# Espectro de threshold reconstruído para zona 'Ag La':
#   - Dimensão: 18 variáveis espectrais
#   - Range de energias: 2.66 - 3.10
#   - Variância explicada pela PC1: 91.39%

# %%
import explaining as exp

# LISTA DE SEMENTES A TESTAR
random_seeds = [0, 1, 2, 3]

all_results_pert = {}
training_samples = len(Xcalclass)

# LOOP: PROCESSAR CADA SEMENTE

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando semente: {seed}")
    print(f"{'='*70}\n")
    # Bagging
    bags_result_seed = exp.bagging_predicates(
        zone_sums_df=zone_scores_df,
        y_predicted_numeric=y_pred,
        predicates_df=predicates_quantiles[0],
        n_bags=10,
        #n_predicates_per_bag=40,
        n_samples_per_bag=int(training_samples*0.8), # 80 % da base para amostrar (convertido para int)
        min_samples_per_predicate=int(training_samples*0.2), # 20 % da base para limitar (convertido para int)
        replace=False,
        sample_bagging=True,
        predicate_bagging=False,
        random_seed=seed
    )
    # Inserir classe prevista
    for bag_name, pred_dict in bags_result_seed.items(): # iterando sobre cada bag
        for pred_rule, df_info in pred_dict.items():
            df_info['Class_Predicted'] = np.where(df_info['Predicted_Y'] >= 0.5, 'A', 'B') # binarizando com threshold 0.5, A = eut, B = dist

    pert_results_seed = exp.calculate_predicate_perturbation(
        estimator=svm_model[3],
        Xcalclass_prep=Xcalclass_prep,
        folds_struct=bags_result_seed,
        predicates_df=predicates_quantiles[0],
        spectral_cuts=spectral_cuts,
        #perturbation_value=0,
        perturbation_mode='median', # valores entre 'mean' ou 'min'
        stats_source='full', # full indica usar todas as amostras para calcular estatísticas enquanto que 'fold' usa apenas as amostras do fold atual
        #metric='mean_abs_diff',   # Média com sinal (pode ser negativo)
        aim='classification',
        metric='probability_shift', 
        verbose=True
    )

    # Salvar no dicionário principal
    all_results_pert[seed] = {
        'bags_result': bags_result_seed,
        'pert_results_dict': pert_results_seed
    }

# CONSTRUÇÃO DE GRAFOS PARA MÚLTIPLAS SEMENTES (LOOP EXTERNO)
# Dicionário para armazenar grafos
graphs_pert_by_seed = {}

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando Grafo - Semente: {seed}")
    print(f"{'='*70}\n")
    
    # Construir grafo para esta semente (sem predicates_df - extraído da regra)
    DG = exp.build_predicate_graph(
        bags_result=all_results_pert[seed]['bags_result'],
        predicate_ranking_dict=all_results_pert[seed]['pert_results_dict'],
        metric_column='Perturbation',
        random_state=seed,
        show_details=True,
        var_exp=True,
        pca_info_dict=pca_info_dict
    )

    # Armazenar grafo
    graphs_pert_by_seed[seed] = DG  

# Calcular LRC usando a função pronta do explaining.py
lrc_pert_by_seed = {}
for seed in random_seeds:
    DG = graphs_pert_by_seed[seed]
    lrc_pert_df_seed = exp.calculate_lrc_single_graph(DG, predicates_quantiles[0])
    lrc_pert_df_seed['Seed'] = seed  # Adicionar coluna com a semente
    lrc_pert_by_seed[seed] = lrc_pert_df_seed

# junando todas as colunas 'Node' de lrc_by_seed em um único dataframe
lrc_pert_all_seeds_df = pd.DataFrame()
for seed in random_seeds:
    lrc_pert_df_seed = lrc_pert_by_seed[seed].rename(columns={'Node': f'Predicate_pert_Seed_{seed}'})
    lrc_pert_all_seeds_df = pd.concat([lrc_pert_all_seeds_df, lrc_pert_df_seed[[f'Predicate_pert_Seed_{seed}']]], axis=1)

# vamos filtrar lrc_by_seed em cada semente para manter apenas as zonas espectrais únicas com maior LRC em um mesmo dataframe
lrc_pert_unique_by_seed = {}
for seed, lrc_df in lrc_pert_by_seed.items():
    lrc_pert_unique_df = lrc_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
    lrc_pert_unique_df = lrc_pert_unique_df.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
    lrc_pert_unique_by_seed[seed] = lrc_pert_unique_df

lrc_pert_all_seeds_df # exibindo o dataframe consolidado com predicados de todas as sementes
# Out:
# ======================================================================
# Processando semente: 0
# ======================================================================
#
# Bag_1 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_2 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_3 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_4 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_5 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_6 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_7 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_8 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_9 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_10 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# ======================================================================
# PERTURBATION IMPORTANCE FOR PREDICATES
# ======================================================================
# Task type (aim): classification
# Perturbation mode: median
# Statistics source: full
# Metric: probability_shift
# Total folds: 10
#
#
# [Bag_1] Processing 60 predicates...
#   Predicate: Ag La > -18.52 (n=176)
#     Zone: 18 columns
#     Importance: 0.056692
#   Predicate: Ag La <= 2.70 (n=81)
#     Zone: 18 columns
#     Importance: 0.280579
#   Predicate: Ag La > 2.70 (n=133)
#     Zone: 18 columns
#     Importance: 0.031325
#   Predicate: Ag La <= 7.76 (n=130)
#     Zone: 18 columns
#     Importance: 0.182295
#   Predicate: Ag La > 7.76 (n=84)
#     Zone: 18 columns
#     Importance: 0.038033
#   Predicate: Ag La <= 9.01 (n=171)
#     Zone: 18 columns
#     Importance: 0.146835
#   Predicate: Ag Lb > -15.87 (n=173)
#     Zone: 15 columns
#     Importance: 0.038847
#   Predicate: Ag Lb <= 2.36 (n=82)
#     Zone: 15 columns
#     Importance: 0.207624
#   Predicate: Ag Lb > 2.36 (n=132)
#     Zone: 15 columns
#     Importance: 0.026642
#   Predicate: Ag Lb <= 6.48 (n=129)
#     Zone: 15 columns
#     Importance: 0.136691
#   Predicate: Ag Lb > 6.48 (n=85)
#     Zone: 15 columns
#     Importance: 0.034219
#   Predicate: Ag Lb <= 8.04 (n=170)
#     Zone: 15 columns
#     Importance: 0.109450
#   Predicate: Ca > -1.79 (n=172)
#     Zone: 19 columns
#     Importance: 0.004323
#   Predicate: Ca <= -0.68 (n=85)
#     Zone: 19 columns
#     Importance: 0.005327
#   Predicate: Ca > -0.68 (n=129)
#     Zone: 19 columns
#     Importance: 0.004623
#   Predicate: Ca <= 0.46 (n=128)
#     Zone: 19 columns
#     Importance: 0.004711
#   Predicate: Ca > 0.46 (n=86)
#     Zone: 19 columns
#     Importance: 0.005187
#   Predicate: Ca <= 1.81 (n=175)
#     Zone: 19 columns
#     Importance: 0.004470
#   Predicate: background > -1.23 (n=175)
#     Zone: 87 columns
#     Importance: 0.014102
#   Predicate: background <= -0.46 (n=84)
#     Zone: 87 columns
#     Importance: 0.011191
#   Predicate: background > -0.46 (n=130)
#     Zone: 87 columns
#     Importance: 0.014223
#   Predicate: background <= 0.40 (n=127)
#     Zone: 87 columns
#     Importance: 0.012363
#   Predicate: background > 0.40 (n=87)
#     Zone: 87 columns
#     Importance: 0.014010
#   Predicate: background <= 1.29 (n=172)
#     Zone: 87 columns
#     Importance: 0.013858
#   Predicate: Fe > -1.18 (n=173)
#     Zone: 23 columns
#     Importance: 0.006029
#   Predicate: Fe <= -0.36 (n=81)
#     Zone: 23 columns
#     Importance: 0.005976
#   Predicate: Fe > -0.36 (n=133)
#     Zone: 23 columns
#     Importance: 0.006326
#   Predicate: Fe <= 0.31 (n=122)
#     Zone: 23 columns
#     Importance: 0.005470
#   Predicate: Fe > 0.31 (n=92)
#     Zone: 23 columns
#     Importance: 0.007153
#   Predicate: Fe <= 1.20 (n=167)
#     Zone: 23 columns
#     Importance: 0.005255
#   Predicate: Cu > -1.74 (n=167)
#     Zone: 66 columns
#     Importance: 0.009479
#   Predicate: Cu <= -0.64 (n=86)
#     Zone: 66 columns
#     Importance: 0.009256
#   Predicate: Cu > -0.64 (n=128)
#     Zone: 66 columns
#     Importance: 0.009963
#   Predicate: Cu <= 0.32 (n=125)
#     Zone: 66 columns
#     Importance: 0.009880
#   Predicate: Cu > 0.32 (n=89)
#     Zone: 66 columns
#     Importance: 0.009395
#   Predicate: Cu <= 1.92 (n=167)
#     Zone: 66 columns
#     Importance: 0.010018
#   Predicate: Zn > -1.47 (n=174)
#     Zone: 29 columns
#     Importance: 0.008248
#   Predicate: Zn <= -0.39 (n=82)
#     Zone: 29 columns
#     Importance: 0.007235
#   Predicate: Zn > -0.39 (n=132)
#     Zone: 29 columns
#     Importance: 0.008222
#   Predicate: Zn <= 0.56 (n=130)
#     Zone: 29 columns
#     Importance: 0.007088
#   Predicate: Zn > 0.56 (n=84)
#     Zone: 29 columns
#     Importance: 0.009013
#   Predicate: Zn <= 1.56 (n=171)
#     Zone: 29 columns
#     Importance: 0.007042
#   Predicate: Bremsstrahlung > -9.06 (n=170)
#     Zone: 429 columns
#     Importance: 0.081003
#   Predicate: Bremsstrahlung <= -1.54 (n=84)
#     Zone: 429 columns
#     Importance: 0.118535
#   Predicate: Bremsstrahlung > -1.54 (n=130)
#     Zone: 429 columns
#     Importance: 0.065351
#   Predicate: Bremsstrahlung <= 4.15 (n=127)
#     Zone: 429 columns
#     Importance: 0.097235
#   Predicate: Bremsstrahlung > 4.15 (n=87)
#     Zone: 429 columns
#     Importance: 0.070157
#   Predicate: Bremsstrahlung <= 9.64 (n=166)
#     Zone: 429 columns
#     Importance: 0.091297
#   Predicate: Ag compton > -6.71 (n=174)
#     Zone: 62 columns
#     Importance: 0.018643
#   Predicate: Ag compton <= -1.09 (n=83)
#     Zone: 62 columns
#     Importance: 0.021114
#   Predicate: Ag compton > -1.09 (n=131)
#     Zone: 62 columns
#     Importance: 0.018758
#   Predicate: Ag compton <= 2.96 (n=127)
#     Zone: 62 columns
#     Importance: 0.019461
#   Predicate: Ag compton > 2.96 (n=87)
#     Zone: 62 columns
#     Importance: 0.019980
#   Predicate: Ag compton <= 6.52 (n=168)
#     Zone: 62 columns
#     Importance: 0.018630
#   Predicate: Ag ka > -11.59 (n=174)
#     Zone: 45 columns
#     Importance: 0.074718
#   Predicate: Ag ka <= -7.06 (n=85)
#     Zone: 45 columns
#     Importance: 0.106561
#   Predicate: Ag ka > -7.06 (n=129)
#     Zone: 45 columns
#     Importance: 0.070785
#   Predicate: Ag ka <= 5.37 (n=126)
#     Zone: 45 columns
#     Importance: 0.087377
#   Predicate: Ag ka > 5.37 (n=88)
#     Zone: 45 columns
#     Importance: 0.081586
#   Predicate: Ag ka <= 20.95 (n=168)
#     Zone: 45 columns
#     Importance: 0.082712
#
# [Bag_2] Processing 60 predicates...
#   Predicate: Ag La > -18.52 (n=170)
#     Zone: 18 columns
#     Importance: 0.052124
#   Predicate: Ag La <= 2.70 (n=87)
#     Zone: 18 columns
#     Importance: 0.288751
#   Predicate: Ag La > 2.70 (n=127)
#     Zone: 18 columns
#     Importance: 0.029775
#   Predicate: Ag La <= 7.76 (n=132)
#     Zone: 18 columns
#     Importance: 0.197241
#   Predicate: Ag La > 7.76 (n=82)
#     Zone: 18 columns
#     Importance: 0.034964
#   Predicate: Ag La <= 9.01 (n=175)
#     Zone: 18 columns
#     Importance: 0.156194
#   Predicate: Ag Lb > -15.87 (n=171)
#     Zone: 15 columns
#     Importance: 0.042901
#   Predicate: Ag Lb <= 2.36 (n=87)
#     Zone: 15 columns
#     Importance: 0.211727
#   Predicate: Ag Lb > 2.36 (n=127)
#     Zone: 15 columns
#     Importance: 0.024816
#   Predicate: Ag Lb <= 6.48 (n=131)
#     Zone: 15 columns
#     Importance: 0.145017
#   Predicate: Ag Lb > 6.48 (n=83)
#     Zone: 15 columns
#     Importance: 0.031020
#   Predicate: Ag Lb <= 8.04 (n=174)
#     Zone: 15 columns
#     Importance: 0.114858
#   Predicate: Ca > -1.79 (n=165)
#     Zone: 19 columns
#     Importance: 0.004374
#   Predicate: Ca <= -0.68 (n=83)
#     Zone: 19 columns
#     Importance: 0.005011
#   Predicate: Ca > -0.68 (n=131)
#     Zone: 19 columns
#     Importance: 0.004616
#   Predicate: Ca <= 0.46 (n=128)
#     Zone: 19 columns
#     Importance: 0.004612
#   Predicate: Ca > 0.46 (n=86)
#     Zone: 19 columns
#     Importance: 0.005004
#   Predicate: Ca <= 1.81 (n=173)
#     Zone: 19 columns
#     Importance: 0.004398
#   Predicate: background > -1.23 (n=168)
#     Zone: 87 columns
#     Importance: 0.013020
#   Predicate: background <= -0.46 (n=89)
#     Zone: 87 columns
#     Importance: 0.010582
#   Predicate: background > -0.46 (n=125)
#     Zone: 87 columns
#     Importance: 0.013427
#   Predicate: background <= 0.40 (n=126)
#     Zone: 87 columns
#     Importance: 0.011073
#   Predicate: background > 0.40 (n=88)
#     Zone: 87 columns
#     Importance: 0.013920
#   Predicate: background <= 1.29 (n=172)
#     Zone: 87 columns
#     Importance: 0.012495
#   Predicate: Fe > -1.18 (n=169)
#     Zone: 23 columns
#     Importance: 0.005957
#   Predicate: Fe <= -0.36 (n=87)
#     Zone: 23 columns
#     Importance: 0.005322
#   Predicate: Fe > -0.36 (n=127)
#     Zone: 23 columns
#     Importance: 0.006523
#   Predicate: Fe <= 0.31 (n=127)
#     Zone: 23 columns
#     Importance: 0.005368
#   Predicate: Fe > 0.31 (n=87)
#     Zone: 23 columns
#     Importance: 0.007009
#   Predicate: Fe <= 1.20 (n=169)
#     Zone: 23 columns
#     Importance: 0.005152
#   Predicate: Cu > -1.74 (n=166)
#     Zone: 66 columns
#     Importance: 0.008940
#   Predicate: Cu <= -0.64 (n=90)
#     Zone: 66 columns
#     Importance: 0.007422
#   Predicate: Cu > -0.64 (n=124)
#     Zone: 66 columns
#     Importance: 0.010101
#   Predicate: Cu <= 0.32 (n=129)
#     Zone: 66 columns
#     Importance: 0.008891
#   Predicate: Cu > 0.32 (n=85)
#     Zone: 66 columns
#     Importance: 0.009102
#   Predicate: Cu <= 1.92 (n=170)
#     Zone: 66 columns
#     Importance: 0.009580
#   Predicate: Zn > -1.47 (n=169)
#     Zone: 29 columns
#     Importance: 0.007854
#   Predicate: Zn <= -0.39 (n=86)
#     Zone: 29 columns
#     Importance: 0.005857
#   Predicate: Zn > -0.39 (n=128)
#     Zone: 29 columns
#     Importance: 0.008346
#   Predicate: Zn <= 0.56 (n=132)
#     Zone: 29 columns
#     Importance: 0.006589
#   Predicate: Zn > 0.56 (n=82)
#     Zone: 29 columns
#     Importance: 0.008563
#   Predicate: Zn <= 1.56 (n=169)
#     Zone: 29 columns
#     Importance: 0.007030
#   Predicate: Bremsstrahlung > -9.06 (n=173)
#     Zone: 429 columns
#     Importance: 0.074932
#   Predicate: Bremsstrahlung <= -1.54 (n=87)
#     Zone: 429 columns
#     Importance: 0.114322
#   Predicate: Bremsstrahlung > -1.54 (n=127)
#     Zone: 429 columns
#     Importance: 0.059230
#   Predicate: Bremsstrahlung <= 4.15 (n=134)
#     Zone: 429 columns
#     Importance: 0.094142
#   Predicate: Bremsstrahlung > 4.15 (n=80)
#     Zone: 429 columns
#     Importance: 0.060665
#   Predicate: Bremsstrahlung <= 9.64 (n=170)
#     Zone: 429 columns
#     Importance: 0.087061
#   Predicate: Ag compton > -6.71 (n=171)
#     Zone: 62 columns
#     Importance: 0.018178
#   Predicate: Ag compton <= -1.09 (n=84)
#     Zone: 62 columns
#     Importance: 0.021939
#   Predicate: Ag compton > -1.09 (n=130)
#     Zone: 62 columns
#     Importance: 0.017864
#   Predicate: Ag compton <= 2.96 (n=130)
#     Zone: 62 columns
#     Importance: 0.019662
#   Predicate: Ag compton > 2.96 (n=84)
#     Zone: 62 columns
#     Importance: 0.019157
#   Predicate: Ag compton <= 6.52 (n=173)
#     Zone: 62 columns
#     Importance: 0.018772
#   Predicate: Ag ka > -11.59 (n=169)
#     Zone: 45 columns
#     Importance: 0.080798
#   Predicate: Ag ka <= -7.06 (n=84)
#     Zone: 45 columns
#     Importance: 0.112206
#   Predicate: Ag ka > -7.06 (n=130)
#     Zone: 45 columns
#     Importance: 0.080517
#   Predicate: Ag ka <= 5.37 (n=125)
#     Zone: 45 columns
#     Importance: 0.092604
#   Predicate: Ag ka > 5.37 (n=89)
#     Zone: 45 columns
#     Importance: 0.093450
#   Predicate: Ag ka <= 20.95 (n=166)
#     Zone: 45 columns
#     Importance: 0.086606
#
# [Bag_3] Processing 60 predicates...
#   Predicate: Ag La > -18.52 (n=174)
#     Zone: 18 columns
#     Importance: 0.056077
#   Predicate: Ag La <= 2.70 (n=84)
#     Zone: 18 columns
#     Importance: 0.271858
#   Predicate: Ag La > 2.70 (n=130)
#     Zone: 18 columns
#     Importance: 0.029934
#   Predicate: Ag La <= 7.76 (n=128)
#     Zone: 18 columns
#     Importance: 0.185555
#   Predicate: Ag La > 7.76 (n=86)
#     Zone: 18 columns
#     Importance: 0.034609
#   Predicate: Ag La <= 9.01 (n=169)
#     Zone: 18 columns
#     Importance: 0.148333
#   Predicate: Ag Lb > -15.87 (n=173)
#     Zone: 15 columns
#     Importance: 0.040787
#   Predicate: Ag Lb <= 2.36 (n=84)
#     Zone: 15 columns
#     Importance: 0.197152
#   Predicate: Ag Lb > 2.36 (n=130)
#     Zone: 15 columns
#     Importance: 0.027151
#   Predicate: Ag Lb <= 6.48 (n=127)
#     Zone: 15 columns
#     Importance: 0.133942
#   Predicate: Ag Lb > 6.48 (n=87)
#     Zone: 15 columns
#     Importance: 0.035399
#   Predicate: Ag Lb <= 8.04 (n=169)
#     Zone: 15 columns
#     Importance: 0.106450
#   Predicate: Ca > -1.79 (n=171)
#     Zone: 19 columns
#     Importance: 0.004348
#   Predicate: Ca <= -0.68 (n=79)
#     Zone: 19 columns
#     Importance: 0.005199
#   Predicate: Ca > -0.68 (n=135)
#     Zone: 19 columns
#     Importance: 0.004722
#   Predicate: Ca <= 0.46 (n=126)
#     Zone: 19 columns
#     Importance: 0.004624
#   Predicate: Ca > 0.46 (n=88)
#     Zone: 19 columns
#     Importance: 0.005290
#   Predicate: Ca <= 1.81 (n=170)
#     Zone: 19 columns
#     Importance: 0.004268
#   Predicate: background > -1.23 (n=169)
#     Zone: 87 columns
#     Importance: 0.013108
#   Predicate: background <= -0.46 (n=89)
#     Zone: 87 columns
#     Importance: 0.011626
#   Predicate: background > -0.46 (n=125)
#     Zone: 87 columns
#     Importance: 0.012854
#   Predicate: background <= 0.40 (n=133)
#     Zone: 87 columns
#     Importance: 0.012356
#   Predicate: background > 0.40 (n=81)
#     Zone: 87 columns
#     Importance: 0.012323
#   Predicate: background <= 1.29 (n=174)
#     Zone: 87 columns
#     Importance: 0.013224
#   Predicate: Fe > -1.18 (n=174)
#     Zone: 23 columns
#     Importance: 0.005740
#   Predicate: Fe <= -0.36 (n=76)
#     Zone: 23 columns
#     Importance: 0.005125
#   Predicate: Fe > -0.36 (n=138)
#     Zone: 23 columns
#     Importance: 0.006437
#   Predicate: Fe <= 0.31 (n=124)
#     Zone: 23 columns
#     Importance: 0.005188
#   Predicate: Fe > 0.31 (n=90)
#     Zone: 23 columns
#     Importance: 0.007050
#   Predicate: Fe <= 1.20 (n=170)
#     Zone: 23 columns
#     Importance: 0.005038
#   Predicate: Cu > -1.74 (n=173)
#     Zone: 66 columns
#     Importance: 0.009747
#   Predicate: Cu <= -0.64 (n=84)
#     Zone: 66 columns
#     Importance: 0.008142
#   Predicate: Cu > -0.64 (n=130)
#     Zone: 66 columns
#     Importance: 0.010780
#   Predicate: Cu <= 0.32 (n=125)
#     Zone: 66 columns
#     Importance: 0.009625
#   Predicate: Cu > 0.32 (n=89)
#     Zone: 66 columns
#     Importance: 0.009912
#   Predicate: Cu <= 1.92 (n=171)
#     Zone: 66 columns
#     Importance: 0.010150
#   Predicate: Zn > -1.47 (n=170)
#     Zone: 29 columns
#     Importance: 0.007731
#   Predicate: Zn <= -0.39 (n=89)
#     Zone: 29 columns
#     Importance: 0.005707
#   Predicate: Zn > -0.39 (n=125)
#     Zone: 29 columns
#     Importance: 0.008580
#   Predicate: Zn <= 0.56 (n=130)
#     Zone: 29 columns
#     Importance: 0.006577
#   Predicate: Zn > 0.56 (n=84)
#     Zone: 29 columns
#     Importance: 0.008637
#   Predicate: Zn <= 1.56 (n=173)
#     Zone: 29 columns
#     Importance: 0.006487
#   Predicate: Bremsstrahlung > -9.06 (n=167)
#     Zone: 429 columns
#     Importance: 0.076218
#   Predicate: Bremsstrahlung <= -1.54 (n=84)
#     Zone: 429 columns
#     Importance: 0.108733
#   Predicate: Bremsstrahlung > -1.54 (n=130)
#     Zone: 429 columns
#     Importance: 0.065671
#   Predicate: Bremsstrahlung <= 4.15 (n=129)
#     Zone: 429 columns
#     Importance: 0.090070
#   Predicate: Bremsstrahlung > 4.15 (n=85)
#     Zone: 429 columns
#     Importance: 0.071197
#   Predicate: Bremsstrahlung <= 9.64 (n=173)
#     Zone: 429 columns
#     Importance: 0.085745
#   Predicate: Ag compton > -6.71 (n=170)
#     Zone: 62 columns
#     Importance: 0.018418
#   Predicate: Ag compton <= -1.09 (n=89)
#     Zone: 62 columns
#     Importance: 0.020175
#   Predicate: Ag compton > -1.09 (n=125)
#     Zone: 62 columns
#     Importance: 0.018138
#   Predicate: Ag compton <= 2.96 (n=132)
#     Zone: 62 columns
#     Importance: 0.017847
#   Predicate: Ag compton > 2.96 (n=82)
#     Zone: 62 columns
#     Importance: 0.020817
#   Predicate: Ag compton <= 6.52 (n=172)
#     Zone: 62 columns
#     Importance: 0.017695
#   Predicate: Ag ka > -11.59 (n=168)
#     Zone: 45 columns
#     Importance: 0.082021
#   Predicate: Ag ka <= -7.06 (n=91)
#     Zone: 45 columns
#     Importance: 0.106275
#   Predicate: Ag ka > -7.06 (n=123)
#     Zone: 45 columns
#     Importance: 0.081414
#   Predicate: Ag ka <= 5.37 (n=131)
#     Zone: 45 columns
#     Importance: 0.088741
#   Predicate: Ag ka > 5.37 (n=83)
#     Zone: 45 columns
#     Importance: 0.097107
#   Predicate: Ag ka <= 20.95 (n=173)
#     Zone: 45 columns
#     Importance: 0.083341
#
# [Bag_4] Processing 60 predicates...
#   Predicate: Ag La > -18.52 (n=172)
#     Zone: 18 columns
#     Importance: 0.056709
#   Predicate: Ag La <= 2.70 (n=86)
#     Zone: 18 columns
#     Importance: 0.277292
#   Predicate: Ag La > 2.70 (n=128)
#     Zone: 18 columns
#     Importance: 0.032893
#   Predicate: Ag La <= 7.76 (n=128)
#     Zone: 18 columns
#     Importance: 0.193346
#   Predicate: Ag La > 7.76 (n=86)
#     Zone: 18 columns
#     Importance: 0.038479
#   Predicate: Ag La <= 9.01 (n=172)
#     Zone: 18 columns
#     Importance: 0.152740
#   Predicate: Ag Lb > -15.87 (n=168)
#     Zone: 15 columns
#     Importance: 0.038436
#   Predicate: Ag Lb <= 2.36 (n=88)
#     Zone: 15 columns
#     Importance: 0.200164
#   Predicate: Ag Lb > 2.36 (n=126)
#     Zone: 15 columns
#     Importance: 0.029102
#   Predicate: Ag Lb <= 6.48 (n=128)
#     Zone: 15 columns
#     Importance: 0.141790
#   Predicate: Ag Lb > 6.48 (n=86)
#     Zone: 15 columns
#     Importance: 0.036420
#   Predicate: Ag Lb <= 8.04 (n=167)
#     Zone: 15 columns
#     Importance: 0.113996
#   Predicate: Ca > -1.79 (n=165)
#     Zone: 19 columns
#     Importance: 0.004873
#   Predicate: Ca <= -0.68 (n=90)
#     Zone: 19 columns
#     Importance: 0.005291
#   Predicate: Ca > -0.68 (n=124)
#     Zone: 19 columns
#     Importance: 0.005263
#   Predicate: Ca <= 0.46 (n=129)
#     Zone: 19 columns
#     Importance: 0.004897
#   Predicate: Ca > 0.46 (n=85)
#     Zone: 19 columns
#     Importance: 0.005848
#   Predicate: Ca <= 1.81 (n=171)
#     Zone: 19 columns
#     Importance: 0.004568
#   Predicate: background > -1.23 (n=170)
#     Zone: 87 columns
#     Importance: 0.014365
#   Predicate: background <= -0.46 (n=85)
#     Zone: 87 columns
#     Importance: 0.011125
#   Predicate: background > -0.46 (n=129)
#     Zone: 87 columns
#     Importance: 0.014559
#   Predicate: background <= 0.40 (n=127)
#     Zone: 87 columns
#     Importance: 0.012658
#   Predicate: background > 0.40 (n=87)
#     Zone: 87 columns
#     Importance: 0.013979
#   Predicate: background <= 1.29 (n=171)
#     Zone: 87 columns
#     Importance: 0.013528
#   Predicate: Fe > -1.18 (n=173)
#     Zone: 23 columns
#     Importance: 0.006193
#   Predicate: Fe <= -0.36 (n=82)
#     Zone: 23 columns
#     Importance: 0.005674
#   Predicate: Fe > -0.36 (n=132)
#     Zone: 23 columns
#     Importance: 0.006626
#   Predicate: Fe <= 0.31 (n=128)
#     Zone: 23 columns
#     Importance: 0.005324
#   Predicate: Fe > 0.31 (n=86)
#     Zone: 23 columns
#     Importance: 0.007657
#   Predicate: Fe <= 1.20 (n=169)
#     Zone: 23 columns
#     Importance: 0.005138
#   Predicate: Cu > -1.74 (n=169)
#     Zone: 66 columns
#     Importance: 0.009701
#   Predicate: Cu <= -0.64 (n=89)
#     Zone: 66 columns
#     Importance: 0.008749
#   Predicate: Cu > -0.64 (n=125)
#     Zone: 66 columns
#     Importance: 0.010751
#   Predicate: Cu <= 0.32 (n=128)
#     Zone: 66 columns
#     Importance: 0.009512
#   Predicate: Cu > 0.32 (n=86)
#     Zone: 66 columns
#     Importance: 0.010524
#   Predicate: Cu <= 1.92 (n=170)
#     Zone: 66 columns
#     Importance: 0.010218
#   Predicate: Zn > -1.47 (n=170)
#     Zone: 29 columns
#     Importance: 0.008594
#   Predicate: Zn <= -0.39 (n=86)
#     Zone: 29 columns
#     Importance: 0.006493
#   Predicate: Zn > -0.39 (n=128)
#     Zone: 29 columns
#     Importance: 0.008718
#   Predicate: Zn <= 0.56 (n=132)
#     Zone: 29 columns
#     Importance: 0.006936
#   Predicate: Zn > 0.56 (n=82)
#     Zone: 29 columns
#     Importance: 0.009252
#   Predicate: Zn <= 1.56 (n=172)
#     Zone: 29 columns
#     Importance: 0.007058
#   Predicate: Bremsstrahlung > -9.06 (n=173)
#     Zone: 429 columns
#     Importance: 0.075007
#   Predicate: Bremsstrahlung <= -1.54 (n=84)
#     Zone: 429 columns
#     Importance: 0.107600
#   Predicate: Bremsstrahlung > -1.54 (n=130)
#     Zone: 429 columns
#     Importance: 0.065058
#   Predicate: Bremsstrahlung <= 4.15 (n=130)
#     Zone: 429 columns
#     Importance: 0.091044
#   Predicate: Bremsstrahlung > 4.15 (n=84)
#     Zone: 429 columns
#     Importance: 0.067383
#   Predicate: Bremsstrahlung <= 9.64 (n=174)
#     Zone: 429 columns
#     Importance: 0.085515
#   Predicate: Ag compton > -6.71 (n=171)
#     Zone: 62 columns
#     Importance: 0.017873
#   Predicate: Ag compton <= -1.09 (n=87)
#     Zone: 62 columns
#     Importance: 0.020581
#   Predicate: Ag compton > -1.09 (n=127)
#     Zone: 62 columns
#     Importance: 0.017888
#   Predicate: Ag compton <= 2.96 (n=127)
#     Zone: 62 columns
#     Importance: 0.019057
#   Predicate: Ag compton > 2.96 (n=87)
#     Zone: 62 columns
#     Importance: 0.018875
#   Predicate: Ag compton <= 6.52 (n=171)
#     Zone: 62 columns
#     Importance: 0.018055
#   Predicate: Ag ka > -11.59 (n=173)
#     Zone: 45 columns
#     Importance: 0.078868
#   Predicate: Ag ka <= -7.06 (n=86)
#     Zone: 45 columns
#     Importance: 0.107305
#   Predicate: Ag ka > -7.06 (n=128)
#     Zone: 45 columns
#     Importance: 0.076155
#   Predicate: Ag ka <= 5.37 (n=127)
#     Zone: 45 columns
#     Importance: 0.089697
#   Predicate: Ag ka > 5.37 (n=87)
#     Zone: 45 columns
#     Importance: 0.087178
#   Predicate: Ag ka <= 20.95 (n=172)
#     Zone: 45 columns
#     Importance: 0.084392
#
# [Bag_5] Processing 60 predicates...
#   Predicate: Ag La > -18.52 (n=170)
#     Zone: 18 columns
#     Importance: 0.053962
#   Predicate: Ag La <= 2.70 (n=86)
#     Zone: 18 columns
#     Importance: 0.284696
#   Predicate: Ag La > 2.70 (n=128)
#     Zone: 18 columns
#     Importance: 0.032491
#   Predicate: Ag La <= 7.76 (n=129)
#     Zone: 18 columns
#     Importance: 0.196205
#   Predicate: Ag La > 7.76 (n=85)
#     Zone: 18 columns
#     Importance: 0.039203
#   Predicate: Ag La <= 9.01 (n=173)
#     Zone: 18 columns
#     Importance: 0.154720
#   Predicate: Ag Lb > -15.87 (n=169)
#     Zone: 15 columns
#     Importance: 0.041345
#   Predicate: Ag Lb <= 2.36 (n=87)
#     Zone: 15 columns
#     Importance: 0.207326
#   Predicate: Ag Lb > 2.36 (n=127)
#     Zone: 15 columns
#     Importance: 0.026370
#   Predicate: Ag Lb <= 6.48 (n=132)
#     Zone: 15 columns
#     Importance: 0.140879
#   Predicate: Ag Lb > 6.48 (n=82)
#     Zone: 15 columns
#     Importance: 0.034028
#   Predicate: Ag Lb <= 8.04 (n=174)
#     Zone: 15 columns
#     Importance: 0.112905
#   Predicate: Ca > -1.79 (n=168)
#     Zone: 19 columns
#     Importance: 0.004445
#   Predicate: Ca <= -0.68 (n=86)
#     Zone: 19 columns
#     Importance: 0.004859
#   Predicate: Ca > -0.68 (n=128)
#     Zone: 19 columns
#     Importance: 0.004834
#   Predicate: Ca <= 0.46 (n=126)
#     Zone: 19 columns
#     Importance: 0.004621
#   Predicate: Ca > 0.46 (n=88)
#     Zone: 19 columns
#     Importance: 0.005163
#   Predicate: Ca <= 1.81 (n=167)
#     Zone: 19 columns
#     Importance: 0.004459
#   Predicate: background > -1.23 (n=171)
#     Zone: 87 columns
#     Importance: 0.013432
#   Predicate: background <= -0.46 (n=87)
#     Zone: 87 columns
#     Importance: 0.010881
#   Predicate: background > -0.46 (n=127)
#     Zone: 87 columns
#     Importance: 0.014263
#   Predicate: background <= 0.40 (n=130)
#     Zone: 87 columns
#     Importance: 0.011881
#   Predicate: background > 0.40 (n=84)
#     Zone: 87 columns
#     Importance: 0.014445
#   Predicate: background <= 1.29 (n=175)
#     Zone: 87 columns
#     Importance: 0.013617
#   Predicate: Fe > -1.18 (n=173)
#     Zone: 23 columns
#     Importance: 0.006205
#   Predicate: Fe <= -0.36 (n=83)
#     Zone: 23 columns
#     Importance: 0.005953
#   Predicate: Fe > -0.36 (n=131)
#     Zone: 23 columns
#     Importance: 0.006745
#   Predicate: Fe <= 0.31 (n=127)
#     Zone: 23 columns
#     Importance: 0.005700
#   Predicate: Fe > 0.31 (n=87)
#     Zone: 23 columns
#     Importance: 0.007515
#   Predicate: Fe <= 1.20 (n=171)
#     Zone: 23 columns
#     Importance: 0.005340
#   Predicate: Cu > -1.74 (n=172)
#     Zone: 66 columns
#     Importance: 0.009816
#   Predicate: Cu <= -0.64 (n=87)
#     Zone: 66 columns
#     Importance: 0.008129
#   Predicate: Cu > -0.64 (n=127)
#     Zone: 66 columns
#     Importance: 0.010793
#   Predicate: Cu <= 0.32 (n=132)
#     Zone: 66 columns
#     Importance: 0.009374
#   Predicate: Cu > 0.32 (n=82)
#     Zone: 66 columns
#     Importance: 0.010250
#   Predicate: Cu <= 1.92 (n=173)
#     Zone: 66 columns
#     Importance: 0.010053
#   Predicate: Zn > -1.47 (n=176)
#     Zone: 29 columns
#     Importance: 0.008300
#   Predicate: Zn <= -0.39 (n=82)
#     Zone: 29 columns
#     Importance: 0.006738
#   Predicate: Zn > -0.39 (n=132)
#     Zone: 29 columns
#     Importance: 0.008374
#   Predicate: Zn <= 0.56 (n=127)
#     Zone: 29 columns
#     Importance: 0.007353
#   Predicate: Zn > 0.56 (n=87)
#     Zone: 29 columns
#     Importance: 0.008323
#   Predicate: Zn <= 1.56 (n=168)
#     Zone: 29 columns
#     Importance: 0.007239
#   Predicate: Bremsstrahlung > -9.06 (n=169)
#     Zone: 429 columns
#     Importance: 0.079082
#   Predicate: Bremsstrahlung <= -1.54 (n=87)
#     Zone: 429 columns
#     Importance: 0.112882
#   Predicate: Bremsstrahlung > -1.54 (n=127)
#     Zone: 429 columns
#     Importance: 0.062901
#   Predicate: Bremsstrahlung <= 4.15 (n=130)
#     Zone: 429 columns
#     Importance: 0.090967
#   Predicate: Bremsstrahlung > 4.15 (n=84)
#     Zone: 429 columns
#     Importance: 0.071233
#   Predicate: Bremsstrahlung <= 9.64 (n=170)
#     Zone: 429 columns
#     Importance: 0.085168
#   Predicate: Ag compton > -6.71 (n=170)
#     Zone: 62 columns
#     Importance: 0.018850
#   Predicate: Ag compton <= -1.09 (n=89)
#     Zone: 62 columns
#     Importance: 0.020823
#   Predicate: Ag compton > -1.09 (n=125)
#     Zone: 62 columns
#     Importance: 0.018866
#   Predicate: Ag compton <= 2.96 (n=129)
#     Zone: 62 columns
#     Importance: 0.019105
#   Predicate: Ag compton > 2.96 (n=85)
#     Zone: 62 columns
#     Importance: 0.020553
#   Predicate: Ag compton <= 6.52 (n=172)
#     Zone: 62 columns
#     Importance: 0.018849
#   Predicate: Ag ka > -11.59 (n=171)
#     Zone: 45 columns
#     Importance: 0.079693
#   Predicate: Ag ka <= -7.06 (n=87)
#     Zone: 45 columns
#     Importance: 0.104660
#   Predicate: Ag ka > -7.06 (n=127)
#     Zone: 45 columns
#     Importance: 0.082941
#   Predicate: Ag ka <= 5.37 (n=125)
#     Zone: 45 columns
#     Importance: 0.088384
#   Predicate: Ag ka > 5.37 (n=89)
#     Zone: 45 columns
#     Importance: 0.096528
#   Predicate: Ag ka <= 20.95 (n=167)
#     Zone: 45 columns
#     Importance: 0.084163
#
# [Bag_6] Processing 60 predicates...
#   Predicate: Ag La > -18.52 (n=170)
#     Zone: 18 columns
#     Importance: 0.051464
#   Predicate: Ag La <= 2.70 (n=83)
#     Zone: 18 columns
#     Importance: 0.289884
#   Predicate: Ag La > 2.70 (n=131)
#     Zone: 18 columns
#     Importance: 0.033262
#   Predicate: Ag La <= 7.76 (n=125)
#     Zone: 18 columns
#     Importance: 0.199534
#   Predicate: Ag La > 7.76 (n=89)
#     Zone: 18 columns
#     Importance: 0.039056
#   Predicate: Ag La <= 9.01 (n=173)
#     Zone: 18 columns
#     Importance: 0.153714
#   Predicate: Ag Lb > -15.87 (n=171)
#     Zone: 15 columns
#     Importance: 0.043248
#   Predicate: Ag Lb <= 2.36 (n=83)
#     Zone: 15 columns
#     Importance: 0.216629
#   Predicate: Ag Lb > 2.36 (n=131)
#     Zone: 15 columns
#     Importance: 0.029763
#   Predicate: Ag Lb <= 6.48 (n=126)
#     Zone: 15 columns
#     Importance: 0.147507
#   Predicate: Ag Lb > 6.48 (n=88)
#     Zone: 15 columns
#     Importance: 0.037423
#   Predicate: Ag Lb <= 8.04 (n=170)
#     Zone: 15 columns
#     Importance: 0.115706
#   Predicate: Ca > -1.79 (n=171)
#     Zone: 19 columns
#     Importance: 0.004638
#   Predicate: Ca <= -0.68 (n=88)
#     Zone: 19 columns
#     Importance: 0.004448
#   Predicate: Ca > -0.68 (n=126)
#     Zone: 19 columns
#     Importance: 0.004964
#   Predicate: Ca <= 0.46 (n=131)
#     Zone: 19 columns
#     Importance: 0.004153
#   Predicate: Ca > 0.46 (n=83)
#     Zone: 19 columns
#     Importance: 0.005698
#   Predicate: Ca <= 1.81 (n=172)
#     Zone: 19 columns
#     Importance: 0.004099
#   Predicate: background > -1.23 (n=167)
#     Zone: 87 columns
#     Importance: 0.013845
#   Predicate: background <= -0.46 (n=92)
#     Zone: 87 columns
#     Importance: 0.011259
#   Predicate: background > -0.46 (n=122)
#     Zone: 87 columns
#     Importance: 0.013861
#   Predicate: background <= 0.40 (n=136)
#     Zone: 87 columns
#     Importance: 0.012610
#   Predicate: background > 0.40 (n=78)
#     Zone: 87 columns
#     Importance: 0.012973
#   Predicate: background <= 1.29 (n=178)
#     Zone: 87 columns
#     Importance: 0.013097
#   Predicate: Fe > -1.18 (n=173)
#     Zone: 23 columns
#     Importance: 0.006458
#   Predicate: Fe <= -0.36 (n=86)
#     Zone: 23 columns
#     Importance: 0.006279
#   Predicate: Fe > -0.36 (n=128)
#     Zone: 23 columns
#     Importance: 0.007059
#   Predicate: Fe <= 0.31 (n=128)
#     Zone: 23 columns
#     Importance: 0.006117
#   Predicate: Fe > 0.31 (n=86)
#     Zone: 23 columns
#     Importance: 0.007682
#   Predicate: Fe <= 1.20 (n=176)
#     Zone: 23 columns
#     Importance: 0.005772
#   Predicate: Cu > -1.74 (n=175)
#     Zone: 66 columns
#     Importance: 0.009672
#   Predicate: Cu <= -0.64 (n=82)
#     Zone: 66 columns
#     Importance: 0.008951
#   Predicate: Cu > -0.64 (n=132)
#     Zone: 66 columns
#     Importance: 0.010399
#   Predicate: Cu <= 0.32 (n=129)
#     Zone: 66 columns
#     Importance: 0.009403
#   Predicate: Cu > 0.32 (n=85)
#     Zone: 66 columns
#     Importance: 0.010515
#   Predicate: Cu <= 1.92 (n=170)
#     Zone: 66 columns
#     Importance: 0.010000
#   Predicate: Zn > -1.47 (n=168)
#     Zone: 29 columns
#     Importance: 0.008291
#   Predicate: Zn <= -0.39 (n=85)
#     Zone: 29 columns
#     Importance: 0.006512
#   Predicate: Zn > -0.39 (n=129)
#     Zone: 29 columns
#     Importance: 0.008788
#   Predicate: Zn <= 0.56 (n=131)
#     Zone: 29 columns
#     Importance: 0.007178
#   Predicate: Zn > 0.56 (n=83)
#     Zone: 29 columns
#     Importance: 0.008997
#   Predicate: Zn <= 1.56 (n=170)
#     Zone: 29 columns
#     Importance: 0.007334
#   Predicate: Bremsstrahlung > -9.06 (n=168)
#     Zone: 429 columns
#     Importance: 0.081323
#   Predicate: Bremsstrahlung <= -1.54 (n=91)
#     Zone: 429 columns
#     Importance: 0.114959
#   Predicate: Bremsstrahlung > -1.54 (n=123)
#     Zone: 429 columns
#     Importance: 0.065672
#   Predicate: Bremsstrahlung <= 4.15 (n=132)
#     Zone: 429 columns
#     Importance: 0.097499
#   Predicate: Bremsstrahlung > 4.15 (n=82)
#     Zone: 429 columns
#     Importance: 0.069135
#   Predicate: Bremsstrahlung <= 9.64 (n=177)
#     Zone: 429 columns
#     Importance: 0.089494
#   Predicate: Ag compton > -6.71 (n=172)
#     Zone: 62 columns
#     Importance: 0.018243
#   Predicate: Ag compton <= -1.09 (n=89)
#     Zone: 62 columns
#     Importance: 0.018854
#   Predicate: Ag compton > -1.09 (n=125)
#     Zone: 62 columns
#     Importance: 0.018090
#   Predicate: Ag compton <= 2.96 (n=137)
#     Zone: 62 columns
#     Importance: 0.017724
#   Predicate: Ag compton > 2.96 (n=77)
#     Zone: 62 columns
#     Importance: 0.019625
#   Predicate: Ag compton <= 6.52 (n=177)
#     Zone: 62 columns
#     Importance: 0.017807
#   Predicate: Ag ka > -11.59 (n=174)
#     Zone: 45 columns
#     Importance: 0.080997
#   Predicate: Ag ka <= -7.06 (n=83)
#     Zone: 45 columns
#     Importance: 0.106766
#   Predicate: Ag ka > -7.06 (n=131)
#     Zone: 45 columns
#     Importance: 0.080483
#   Predicate: Ag ka <= 5.37 (n=126)
#     Zone: 45 columns
#     Importance: 0.090789
#   Predicate: Ag ka > 5.37 (n=88)
#     Zone: 45 columns
#     Importance: 0.090516
#   Predicate: Ag ka <= 20.95 (n=171)
#     Zone: 45 columns
#     Importance: 0.086192
#
# [Bag_7] Processing 60 predicates...
#   Predicate: Ag La > -18.52 (n=170)
#     Zone: 18 columns
#     Importance: 0.052162
#   Predicate: Ag La <= 2.70 (n=85)
#     Zone: 18 columns
#     Importance: 0.297473
#   Predicate: Ag La > 2.70 (n=129)
#     Zone: 18 columns
#     Importance: 0.031187
#   Predicate: Ag La <= 7.76 (n=130)
#     Zone: 18 columns
#     Importance: 0.201701
#   Predicate: Ag La > 7.76 (n=84)
#     Zone: 18 columns
#     Importance: 0.036753
#   Predicate: Ag La <= 9.01 (n=174)
#     Zone: 18 columns
#     Importance: 0.158966
#   Predicate: Ag Lb > -15.87 (n=173)
#     Zone: 15 columns
#     Importance: 0.045516
#   Predicate: Ag Lb <= 2.36 (n=86)
#     Zone: 15 columns
#     Importance: 0.214278
#   Predicate: Ag Lb > 2.36 (n=128)
#     Zone: 15 columns
#     Importance: 0.027709
#   Predicate: Ag Lb <= 6.48 (n=128)
#     Zone: 15 columns
#     Importance: 0.148433
#   Predicate: Ag Lb > 6.48 (n=86)
#     Zone: 15 columns
#     Importance: 0.034596
#   Predicate: Ag Lb <= 8.04 (n=170)
#     Zone: 15 columns
#     Importance: 0.117265
#   Predicate: Ca > -1.79 (n=172)
#     Zone: 19 columns
#     Importance: 0.004692
#   Predicate: Ca <= -0.68 (n=84)
#     Zone: 19 columns
#     Importance: 0.005295
#   Predicate: Ca > -0.68 (n=130)
#     Zone: 19 columns
#     Importance: 0.005019
#   Predicate: Ca <= 0.46 (n=126)
#     Zone: 19 columns
#     Importance: 0.004774
#   Predicate: Ca > 0.46 (n=88)
#     Zone: 19 columns
#     Importance: 0.005633
#   Predicate: Ca <= 1.81 (n=172)
#     Zone: 19 columns
#     Importance: 0.004547
#   Predicate: background > -1.23 (n=174)
#     Zone: 87 columns
#     Importance: 0.013801
#   Predicate: background <= -0.46 (n=81)
#     Zone: 87 columns
#     Importance: 0.010722
#   Predicate: background > -0.46 (n=133)
#     Zone: 87 columns
#     Importance: 0.014192
#   Predicate: background <= 0.40 (n=125)
#     Zone: 87 columns
#     Importance: 0.011548
#   Predicate: background > 0.40 (n=89)
#     Zone: 87 columns
#     Importance: 0.014748
#   Predicate: background <= 1.29 (n=170)
#     Zone: 87 columns
#     Importance: 0.013268
#   Predicate: Fe > -1.18 (n=168)
#     Zone: 23 columns
#     Importance: 0.006013
#   Predicate: Fe <= -0.36 (n=82)
#     Zone: 23 columns
#     Importance: 0.006040
#   Predicate: Fe > -0.36 (n=132)
#     Zone: 23 columns
#     Importance: 0.006620
#   Predicate: Fe <= 0.31 (n=126)
#     Zone: 23 columns
#     Importance: 0.005720
#   Predicate: Fe > 0.31 (n=88)
#     Zone: 23 columns
#     Importance: 0.007368
#   Predicate: Fe <= 1.20 (n=167)
#     Zone: 23 columns
#     Importance: 0.005217
#   Predicate: Cu > -1.74 (n=175)
#     Zone: 66 columns
#     Importance: 0.009265
#   Predicate: Cu <= -0.64 (n=90)
#     Zone: 66 columns
#     Importance: 0.008559
#   Predicate: Cu > -0.64 (n=124)
#     Zone: 66 columns
#     Importance: 0.010377
#   Predicate: Cu <= 0.32 (n=132)
#     Zone: 66 columns
#     Importance: 0.009427
#   Predicate: Cu > 0.32 (n=82)
#     Zone: 66 columns
#     Importance: 0.009911
#   Predicate: Cu <= 1.92 (n=172)
#     Zone: 66 columns
#     Importance: 0.009560
#   Predicate: Zn > -1.47 (n=172)
#     Zone: 29 columns
#     Importance: 0.008605
#   Predicate: Zn <= -0.39 (n=87)
#     Zone: 29 columns
#     Importance: 0.005911
#   Predicate: Zn > -0.39 (n=127)
#     Zone: 29 columns
#     Importance: 0.009176
#   Predicate: Zn <= 0.56 (n=127)
#     Zone: 29 columns
#     Importance: 0.006936
#   Predicate: Zn > 0.56 (n=87)
#     Zone: 29 columns
#     Importance: 0.009181
#   Predicate: Zn <= 1.56 (n=167)
#     Zone: 29 columns
#     Importance: 0.007052
#   Predicate: Bremsstrahlung > -9.06 (n=172)
#     Zone: 429 columns
#     Importance: 0.075597
#   Predicate: Bremsstrahlung <= -1.54 (n=81)
#     Zone: 429 columns
#     Importance: 0.114905
#   Predicate: Bremsstrahlung > -1.54 (n=133)
#     Zone: 429 columns
#     Importance: 0.063565
#   Predicate: Bremsstrahlung <= 4.15 (n=119)
#     Zone: 429 columns
#     Importance: 0.097896
#   Predicate: Bremsstrahlung > 4.15 (n=95)
#     Zone: 429 columns
#     Importance: 0.064334
#   Predicate: Bremsstrahlung <= 9.64 (n=165)
#     Zone: 429 columns
#     Importance: 0.088379
#   Predicate: Ag compton > -6.71 (n=174)
#     Zone: 62 columns
#     Importance: 0.018571
#   Predicate: Ag compton <= -1.09 (n=80)
#     Zone: 62 columns
#     Importance: 0.020848
#   Predicate: Ag compton > -1.09 (n=134)
#     Zone: 62 columns
#     Importance: 0.018655
#   Predicate: Ag compton <= 2.96 (n=121)
#     Zone: 62 columns
#     Importance: 0.019114
#   Predicate: Ag compton > 2.96 (n=93)
#     Zone: 62 columns
#     Importance: 0.019946
#   Predicate: Ag compton <= 6.52 (n=168)
#     Zone: 62 columns
#     Importance: 0.018799
#   Predicate: Ag ka > -11.59 (n=171)
#     Zone: 45 columns
#     Importance: 0.077086
#   Predicate: Ag ka <= -7.06 (n=89)
#     Zone: 45 columns
#     Importance: 0.110860
#   Predicate: Ag ka > -7.06 (n=125)
#     Zone: 45 columns
#     Importance: 0.074397
#   Predicate: Ag ka <= 5.37 (n=130)
#     Zone: 45 columns
#     Importance: 0.092476
#   Predicate: Ag ka > 5.37 (n=84)
#     Zone: 45 columns
#     Importance: 0.085051
#   Predicate: Ag ka <= 20.95 (n=174)
#     Zone: 45 columns
#     Importance: 0.086330
#
# [Bag_8] Processing 60 predicates...
#   Predicate: Ag La > -18.52 (n=168)
#     Zone: 18 columns
#     Importance: 0.056483
#   Predicate: Ag La <= 2.70 (n=83)
#     Zone: 18 columns
#     Importance: 0.306480
#   Predicate: Ag La > 2.70 (n=131)
#     Zone: 18 columns
#     Importance: 0.031695
#   Predicate: Ag La <= 7.76 (n=125)
#     Zone: 18 columns
#     Importance: 0.210290
#   Predicate: Ag La > 7.76 (n=89)
#     Zone: 18 columns
#     Importance: 0.037119
#   Predicate: Ag La <= 9.01 (n=172)
#     Zone: 18 columns
#     Importance: 0.161682
#   Predicate: Ag Lb > -15.87 (n=168)
#     Zone: 15 columns
#     Importance: 0.045658
#   Predicate: Ag Lb <= 2.36 (n=83)
#     Zone: 15 columns
#     Importance: 0.226798
#   Predicate: Ag Lb > 2.36 (n=131)
#     Zone: 15 columns
#     Importance: 0.027503
#   Predicate: Ag Lb <= 6.48 (n=125)
#     Zone: 15 columns
#     Importance: 0.154810
#   Predicate: Ag Lb > 6.48 (n=89)
#     Zone: 15 columns
#     Importance: 0.034560
#   Predicate: Ag Lb <= 8.04 (n=170)
#     Zone: 15 columns
#     Importance: 0.119651
#   Predicate: Ca > -1.79 (n=173)
#     Zone: 19 columns
#     Importance: 0.004606
#   Predicate: Ca <= -0.68 (n=87)
#     Zone: 19 columns
#     Importance: 0.004049
#   Predicate: Ca > -0.68 (n=127)
#     Zone: 19 columns
#     Importance: 0.004948
#   Predicate: Ca <= 0.46 (n=121)
#     Zone: 19 columns
#     Importance: 0.003963
#   Predicate: Ca > 0.46 (n=93)
#     Zone: 19 columns
#     Importance: 0.005389
#   Predicate: Ca <= 1.81 (n=166)
#     Zone: 19 columns
#     Importance: 0.003770
#   Predicate: background > -1.23 (n=167)
#     Zone: 87 columns
#     Importance: 0.013617
#   Predicate: background <= -0.46 (n=94)
#     Zone: 87 columns
#     Importance: 0.011223
#   Predicate: background > -0.46 (n=120)
#     Zone: 87 columns
#     Importance: 0.013782
#   Predicate: background <= 0.40 (n=132)
#     Zone: 87 columns
#     Importance: 0.012043
#   Predicate: background > 0.40 (n=82)
#     Zone: 87 columns
#     Importance: 0.013648
#   Predicate: background <= 1.29 (n=171)
#     Zone: 87 columns
#     Importance: 0.012644
#   Predicate: Fe > -1.18 (n=174)
#     Zone: 23 columns
#     Importance: 0.006149
#   Predicate: Fe <= -0.36 (n=89)
#     Zone: 23 columns
#     Importance: 0.005697
#   Predicate: Fe > -0.36 (n=125)
#     Zone: 23 columns
#     Importance: 0.006836
#   Predicate: Fe <= 0.31 (n=136)
#     Zone: 23 columns
#     Importance: 0.005217
#   Predicate: Fe > 0.31 (n=78)
#     Zone: 23 columns
#     Importance: 0.008358
#   Predicate: Fe <= 1.20 (n=174)
#     Zone: 23 columns
#     Importance: 0.005153
#   Predicate: Cu > -1.74 (n=170)
#     Zone: 66 columns
#     Importance: 0.009158
#   Predicate: Cu <= -0.64 (n=89)
#     Zone: 66 columns
#     Importance: 0.007808
#   Predicate: Cu > -0.64 (n=125)
#     Zone: 66 columns
#     Importance: 0.009904
#   Predicate: Cu <= 0.32 (n=131)
#     Zone: 66 columns
#     Importance: 0.008110
#   Predicate: Cu > 0.32 (n=83)
#     Zone: 66 columns
#     Importance: 0.010488
#   Predicate: Cu <= 1.92 (n=172)
#     Zone: 66 columns
#     Importance: 0.009241
#   Predicate: Zn > -1.47 (n=171)
#     Zone: 29 columns
#     Importance: 0.007918
#   Predicate: Zn <= -0.39 (n=86)
#     Zone: 29 columns
#     Importance: 0.007046
#   Predicate: Zn > -0.39 (n=128)
#     Zone: 29 columns
#     Importance: 0.007896
#   Predicate: Zn <= 0.56 (n=135)
#     Zone: 29 columns
#     Importance: 0.007216
#   Predicate: Zn > 0.56 (n=79)
#     Zone: 29 columns
#     Importance: 0.008132
#   Predicate: Zn <= 1.56 (n=175)
#     Zone: 29 columns
#     Importance: 0.007043
#   Predicate: Bremsstrahlung > -9.06 (n=171)
#     Zone: 429 columns
#     Importance: 0.076685
#   Predicate: Bremsstrahlung <= -1.54 (n=89)
#     Zone: 429 columns
#     Importance: 0.116440
#   Predicate: Bremsstrahlung > -1.54 (n=125)
#     Zone: 429 columns
#     Importance: 0.059770
#   Predicate: Bremsstrahlung <= 4.15 (n=133)
#     Zone: 429 columns
#     Importance: 0.096889
#   Predicate: Bremsstrahlung > 4.15 (n=81)
#     Zone: 429 columns
#     Importance: 0.061088
#   Predicate: Bremsstrahlung <= 9.64 (n=174)
#     Zone: 429 columns
#     Importance: 0.090934
#   Predicate: Ag compton > -6.71 (n=171)
#     Zone: 62 columns
#     Importance: 0.017801
#   Predicate: Ag compton <= -1.09 (n=86)
#     Zone: 62 columns
#     Importance: 0.020751
#   Predicate: Ag compton > -1.09 (n=128)
#     Zone: 62 columns
#     Importance: 0.017175
#   Predicate: Ag compton <= 2.96 (n=130)
#     Zone: 62 columns
#     Importance: 0.018953
#   Predicate: Ag compton > 2.96 (n=84)
#     Zone: 62 columns
#     Importance: 0.018084
#   Predicate: Ag compton <= 6.52 (n=172)
#     Zone: 62 columns
#     Importance: 0.018173
#   Predicate: Ag ka > -11.59 (n=172)
#     Zone: 45 columns
#     Importance: 0.077152
#   Predicate: Ag ka <= -7.06 (n=85)
#     Zone: 45 columns
#     Importance: 0.109694
#   Predicate: Ag ka > -7.06 (n=129)
#     Zone: 45 columns
#     Importance: 0.079495
#   Predicate: Ag ka <= 5.37 (n=131)
#     Zone: 45 columns
#     Importance: 0.090120
#   Predicate: Ag ka > 5.37 (n=83)
#     Zone: 45 columns
#     Importance: 0.093653
#   Predicate: Ag ka <= 20.95 (n=165)
#     Zone: 45 columns
#     Importance: 0.086550
#
# [Bag_9] Processing 60 predicates...
#   Predicate: Ag La > -18.52 (n=173)
#     Zone: 18 columns
#     Importance: 0.060246
#   Predicate: Ag La <= 2.70 (n=86)
#     Zone: 18 columns
#     Importance: 0.284322
#   Predicate: Ag La > 2.70 (n=128)
#     Zone: 18 columns
#     Importance: 0.031846
#   Predicate: Ag La <= 7.76 (n=133)
#     Zone: 18 columns
#     Importance: 0.191164
#   Predicate: Ag La > 7.76 (n=81)
#     Zone: 18 columns
#     Importance: 0.038310
#   Predicate: Ag La <= 9.01 (n=167)
#     Zone: 18 columns
#     Importance: 0.158950
#   Predicate: Ag Lb > -15.87 (n=172)
#     Zone: 15 columns
#     Importance: 0.046270
#   Predicate: Ag Lb <= 2.36 (n=87)
#     Zone: 15 columns
#     Importance: 0.207763
#   Predicate: Ag Lb > 2.36 (n=127)
#     Zone: 15 columns
#     Importance: 0.028020
#   Predicate: Ag Lb <= 6.48 (n=129)
#     Zone: 15 columns
#     Importance: 0.144556
#   Predicate: Ag Lb > 6.48 (n=85)
#     Zone: 15 columns
#     Importance: 0.035132
#   Predicate: Ag Lb <= 8.04 (n=168)
#     Zone: 15 columns
#     Importance: 0.116507
#   Predicate: Ca > -1.79 (n=174)
#     Zone: 19 columns
#     Importance: 0.004482
#   Predicate: Ca <= -0.68 (n=86)
#     Zone: 19 columns
#     Importance: 0.004869
#   Predicate: Ca > -0.68 (n=128)
#     Zone: 19 columns
#     Importance: 0.004850
#   Predicate: Ca <= 0.46 (n=130)
#     Zone: 19 columns
#     Importance: 0.004532
#   Predicate: Ca > 0.46 (n=84)
#     Zone: 19 columns
#     Importance: 0.005362
#   Predicate: Ca <= 1.81 (n=172)
#     Zone: 19 columns
#     Importance: 0.004256
#   Predicate: background > -1.23 (n=169)
#     Zone: 87 columns
#     Importance: 0.013521
#   Predicate: background <= -0.46 (n=84)
#     Zone: 87 columns
#     Importance: 0.011536
#   Predicate: background > -0.46 (n=130)
#     Zone: 87 columns
#     Importance: 0.013294
#   Predicate: background <= 0.40 (n=127)
#     Zone: 87 columns
#     Importance: 0.011804
#   Predicate: background > 0.40 (n=87)
#     Zone: 87 columns
#     Importance: 0.013771
#   Predicate: background <= 1.29 (n=168)
#     Zone: 87 columns
#     Importance: 0.012997
#   Predicate: Fe > -1.18 (n=173)
#     Zone: 23 columns
#     Importance: 0.005206
#   Predicate: Fe <= -0.36 (n=81)
#     Zone: 23 columns
#     Importance: 0.005839
#   Predicate: Fe > -0.36 (n=133)
#     Zone: 23 columns
#     Importance: 0.005341
#   Predicate: Fe <= 0.31 (n=128)
#     Zone: 23 columns
#     Importance: 0.005174
#   Predicate: Fe > 0.31 (n=86)
#     Zone: 23 columns
#     Importance: 0.006060
#   Predicate: Fe <= 1.20 (n=171)
#     Zone: 23 columns
#     Importance: 0.004755
#   Predicate: Cu > -1.74 (n=169)
#     Zone: 66 columns
#     Importance: 0.009385
#   Predicate: Cu <= -0.64 (n=85)
#     Zone: 66 columns
#     Importance: 0.008335
#   Predicate: Cu > -0.64 (n=129)
#     Zone: 66 columns
#     Importance: 0.010244
#   Predicate: Cu <= 0.32 (n=124)
#     Zone: 66 columns
#     Importance: 0.009278
#   Predicate: Cu > 0.32 (n=90)
#     Zone: 66 columns
#     Importance: 0.009772
#   Predicate: Cu <= 1.92 (n=166)
#     Zone: 66 columns
#     Importance: 0.009806
#   Predicate: Zn > -1.47 (n=170)
#     Zone: 29 columns
#     Importance: 0.007786
#   Predicate: Zn <= -0.39 (n=85)
#     Zone: 29 columns
#     Importance: 0.005756
#   Predicate: Zn > -0.39 (n=129)
#     Zone: 29 columns
#     Importance: 0.008339
#   Predicate: Zn <= 0.56 (n=134)
#     Zone: 29 columns
#     Importance: 0.006497
#   Predicate: Zn > 0.56 (n=80)
#     Zone: 29 columns
#     Importance: 0.008679
#   Predicate: Zn <= 1.56 (n=173)
#     Zone: 29 columns
#     Importance: 0.006766
#   Predicate: Bremsstrahlung > -9.06 (n=171)
#     Zone: 429 columns
#     Importance: 0.080076
#   Predicate: Bremsstrahlung <= -1.54 (n=84)
#     Zone: 429 columns
#     Importance: 0.109585
#   Predicate: Bremsstrahlung > -1.54 (n=130)
#     Zone: 429 columns
#     Importance: 0.065978
#   Predicate: Bremsstrahlung <= 4.15 (n=127)
#     Zone: 429 columns
#     Importance: 0.093114
#   Predicate: Bremsstrahlung > 4.15 (n=87)
#     Zone: 429 columns
#     Importance: 0.068469
#   Predicate: Bremsstrahlung <= 9.64 (n=170)
#     Zone: 429 columns
#     Importance: 0.087608
#   Predicate: Ag compton > -6.71 (n=174)
#     Zone: 62 columns
#     Importance: 0.018733
#   Predicate: Ag compton <= -1.09 (n=82)
#     Zone: 62 columns
#     Importance: 0.019800
#   Predicate: Ag compton > -1.09 (n=132)
#     Zone: 62 columns
#     Importance: 0.018495
#   Predicate: Ag compton <= 2.96 (n=126)
#     Zone: 62 columns
#     Importance: 0.017971
#   Predicate: Ag compton > 2.96 (n=88)
#     Zone: 62 columns
#     Importance: 0.020460
#   Predicate: Ag compton <= 6.52 (n=172)
#     Zone: 62 columns
#     Importance: 0.018214
#   Predicate: Ag ka > -11.59 (n=168)
#     Zone: 45 columns
#     Importance: 0.078256
#   Predicate: Ag ka <= -7.06 (n=85)
#     Zone: 45 columns
#     Importance: 0.115335
#   Predicate: Ag ka > -7.06 (n=129)
#     Zone: 45 columns
#     Importance: 0.076775
#   Predicate: Ag ka <= 5.37 (n=129)
#     Zone: 45 columns
#     Importance: 0.094769
#   Predicate: Ag ka > 5.37 (n=85)
#     Zone: 45 columns
#     Importance: 0.088028
#   Predicate: Ag ka <= 20.95 (n=171)
#     Zone: 45 columns
#     Importance: 0.088189
#
# [Bag_10] Processing 60 predicates...
#   Predicate: Ag La > -18.52 (n=174)
#     Zone: 18 columns
#     Importance: 0.055087
#   Predicate: Ag La <= 2.70 (n=80)
#     Zone: 18 columns
#     Importance: 0.284335
#   Predicate: Ag La > 2.70 (n=134)
#     Zone: 18 columns
#     Importance: 0.031354
#   Predicate: Ag La <= 7.76 (n=125)
#     Zone: 18 columns
#     Importance: 0.189920
#   Predicate: Ag La > 7.76 (n=89)
#     Zone: 18 columns
#     Importance: 0.036046
#   Predicate: Ag La <= 9.01 (n=169)
#     Zone: 18 columns
#     Importance: 0.149794
#   Predicate: Ag Lb > -15.87 (n=173)
#     Zone: 15 columns
#     Importance: 0.041069
#   Predicate: Ag Lb <= 2.36 (n=80)
#     Zone: 15 columns
#     Importance: 0.206142
#   Predicate: Ag Lb > 2.36 (n=134)
#     Zone: 15 columns
#     Importance: 0.027088
#   Predicate: Ag Lb <= 6.48 (n=125)
#     Zone: 15 columns
#     Importance: 0.136548
#   Predicate: Ag Lb > 6.48 (n=89)
#     Zone: 15 columns
#     Importance: 0.034299
#   Predicate: Ag Lb <= 8.04 (n=166)
#     Zone: 15 columns
#     Importance: 0.108194
#   Predicate: Ca > -1.79 (n=168)
#     Zone: 19 columns
#     Importance: 0.004362
#   Predicate: Ca <= -0.68 (n=89)
#     Zone: 19 columns
#     Importance: 0.005316
#   Predicate: Ca > -0.68 (n=125)
#     Zone: 19 columns
#     Importance: 0.004613
#   Predicate: Ca <= 0.46 (n=128)
#     Zone: 19 columns
#     Importance: 0.004723
#   Predicate: Ca > 0.46 (n=86)
#     Zone: 19 columns
#     Importance: 0.005176
#   Predicate: Ca <= 1.81 (n=175)
#     Zone: 19 columns
#     Importance: 0.004453
#   Predicate: background > -1.23 (n=170)
#     Zone: 87 columns
#     Importance: 0.013821
#   Predicate: background <= -0.46 (n=87)
#     Zone: 87 columns
#     Importance: 0.010943
#   Predicate: background > -0.46 (n=127)
#     Zone: 87 columns
#     Importance: 0.013785
#   Predicate: background <= 0.40 (n=129)
#     Zone: 87 columns
#     Importance: 0.011523
#   Predicate: background > 0.40 (n=85)
#     Zone: 87 columns
#     Importance: 0.014310
#   Predicate: background <= 1.29 (n=173)
#     Zone: 87 columns
#     Importance: 0.012859
#   Predicate: Fe > -1.18 (n=175)
#     Zone: 23 columns
#     Importance: 0.005788
#   Predicate: Fe <= -0.36 (n=77)
#     Zone: 23 columns
#     Importance: 0.004926
#   Predicate: Fe > -0.36 (n=137)
#     Zone: 23 columns
#     Importance: 0.006365
#   Predicate: Fe <= 0.31 (n=121)
#     Zone: 23 columns
#     Importance: 0.004549
#   Predicate: Fe > 0.31 (n=93)
#     Zone: 23 columns
#     Importance: 0.007536
#   Predicate: Fe <= 1.20 (n=170)
#     Zone: 23 columns
#     Importance: 0.004637
#   Predicate: Cu > -1.74 (n=173)
# ...
# Removed: Cu > 0.32 -> Cu > -0.64 (0.0010) | Kept: Cu > -0.64 -> Cu > 0.32 (0.0039)
# Removed: Cu > -0.64 -> Cu <= 1.92 (0.0018) | Kept: Cu <= 1.92 -> Cu > -0.64 (0.0018)
# Removed: Cu <= -0.64 -> Cu > 0.32 (0.0009) | Kept: Cu > 0.32 -> Cu <= -0.64 (0.0016)
# Removed: Zn > -0.39 -> Cu > 0.32 (0.0015) | Kept: Cu > 0.32 -> Zn > -0.39 (0.0017)
# Removed: Cu > 0.32 -> Cu > -1.74 (0.0009) | Kept: Cu > -1.74 -> Cu > 0.32 (0.0017)
# Removed: Cu > -1.74 -> Cu <= 1.92 (0.0018) | Kept: Cu <= 1.92 -> Cu > -1.74 (0.0027)
# Removed: Cu <= 0.32 -> Cu <= 1.92 (0.0009) | Kept: Cu <= 1.92 -> Cu <= 0.32 (0.0044)
# Removed: Cu <= 0.32 -> Cu > -1.74 (0.0009) | Kept: Cu > -1.74 -> Cu <= 0.32 (0.0018)
# Removed: Zn > 0.56 -> Cu > -1.74 (0.0015) | Kept: Cu > -1.74 -> Zn > 0.56 (0.0018)
# Removed: Cu <= 0.32 -> Zn > 0.56 (0.0026) | Kept: Zn > 0.56 -> Cu <= 0.32 (0.0031)
# Removed: Cu <= -0.64 -> Zn > 0.56 (0.0024) | Kept: Zn > 0.56 -> Cu <= -0.64 (0.0032)
# Removed: Zn > -1.47 -> Zn > 0.56 (0.0014) | Kept: Zn > 0.56 -> Zn > -1.47 (0.0014)
# Removed: Cu <= -0.64 -> Zn > -0.39 (0.0008) | Kept: Zn > -0.39 -> Cu <= -0.64 (0.0045)
# Removed: Cu <= -0.64 -> Zn > -1.47 (0.0008) | Kept: Zn > -1.47 -> Cu <= -0.64 (0.0028)
# Removed: Zn > -1.47 -> Zn > -0.39 (0.0028) | Kept: Zn > -0.39 -> Zn > -1.47 (0.0058)
# Removed: Fe > 0.31 -> Zn > -1.47 (0.0010) | Kept: Zn > -1.47 -> Fe > 0.31 (0.0043)
# Removed: Fe > 0.31 -> Zn <= 0.56 (0.0010) | Kept: Zn <= 0.56 -> Fe > 0.31 (0.0025)
# Removed: Fe > 0.31 -> Zn <= -0.39 (0.0018) | Kept: Zn <= -0.39 -> Fe > 0.31 (0.0024)
# Removed: Zn <= 0.56 -> Zn <= 1.56 (0.0038) | Kept: Zn <= 1.56 -> Zn <= 0.56 (0.0086)
# Removed: Zn <= -0.39 -> Zn <= 1.56 (0.0013) | Kept: Zn <= 1.56 -> Zn <= -0.39 (0.0037)
# Removed: Fe > -0.36 -> Zn <= -0.39 (0.0016) | Kept: Zn <= -0.39 -> Fe > -0.36 (0.0036)
# Removed: Fe <= -0.36 -> Fe > -1.18 (0.0008) | Kept: Fe > -1.18 -> Fe <= -0.36 (0.0048)
# Removed: Fe <= 0.31 -> Fe > -1.18 (0.0007) | Kept: Fe > -1.18 -> Fe <= 0.31 (0.0015)
# Removed: Fe > -1.18 -> Ca > 0.46 (0.0008) | Kept: Ca > 0.46 -> Fe > -1.18 (0.0013)
# Removed: Ca > 0.46 -> Fe <= -0.36 (0.0013) | Kept: Fe <= -0.36 -> Ca > 0.46 (0.0015)
# Removed: Fe <= 0.31 -> Ca > 0.46 (0.0015) | Kept: Ca > 0.46 -> Fe <= 0.31 (0.0038)
# Removed: Fe <= 1.20 -> Ca > 0.46 (0.0015) | Kept: Ca > 0.46 -> Fe <= 1.20 (0.0024)
# Removed: Ca > -0.68 -> Fe <= 1.20 (0.0011) | Kept: Fe <= 1.20 -> Ca > -0.68 (0.0034)
# Removed: Ca <= -0.68 -> Fe <= 1.20 (0.0012) | Kept: Fe <= 1.20 -> Ca <= -0.68 (0.0014)
# Removed: Ca <= -0.68 -> Ca > 0.46 (0.0012) | Kept: Ca > 0.46 -> Ca <= -0.68 (0.0012)
# Removed: Ca <= 0.46 -> Ca > -0.68 (0.0011) | Kept: Ca > -0.68 -> Ca <= 0.46 (0.0032)
# Removed: Ca > -0.68 -> Ca <= -0.68 (0.0032) | Kept: Ca <= -0.68 -> Ca > -0.68 (0.0034)
# Removed: Ca > -1.79 -> Ca <= -0.68 (0.0020) | Kept: Ca <= -0.68 -> Ca > -1.79 (0.0031)
# Removed: Ca > -1.79 -> Ca <= 0.46 (0.0030) | Kept: Ca <= 0.46 -> Ca > -1.79 (0.0031)
# Removed: Ca <= 1.81 -> Ca > -1.79 (0.0019) | Kept: Ca > -1.79 -> Ca <= 1.81 (0.0030)
#
# ======================================================================
# CONSTRUCTED GRAPH SUMMARY
# ======================================================================
# Initial edges: 222 | Removed: 58
# Predicate nodes: 60
# Metric: Perturbation
# Weighting by explained variance: ENABLED
#
# ======================================================================
# Processando Grafo - Semente: 2
# ======================================================================
#
#
# Total bidirectional pairs found: 52
# Removed: Ag Lb <= 8.04 -> Ag ka <= -7.06 (0.1064) | Kept: Ag ka <= -7.06 -> Ag Lb <= 8.04 (0.1677)
# Removed: Bremsstrahlung <= -1.54 -> Ag Lb <= 8.04 (0.1038) | Kept: Ag Lb <= 8.04 -> Bremsstrahlung <= -1.54 (0.4119)
# Removed: Bremsstrahlung <= -1.54 -> Ag ka <= -7.06 (0.2067) | Kept: Ag ka <= -7.06 -> Bremsstrahlung <= -1.54 (0.3511)
# Removed: Ag ka <= 5.37 -> Ag ka > 5.37 (0.0718) | Kept: Ag ka > 5.37 -> Ag ka <= 5.37 (0.2810)
# Removed: Bremsstrahlung <= 9.64 -> Ag ka <= 5.37 (0.0803) | Kept: Ag ka <= 5.37 -> Bremsstrahlung <= 9.64 (0.3511)
# Removed: Ag ka > 5.37 -> Bremsstrahlung <= 4.15 (0.1388) | Kept: Bremsstrahlung <= 4.15 -> Ag ka > 5.37 (0.1762)
# Removed: Bremsstrahlung <= 9.64 -> Ag ka <= 20.95 (0.1088) | Kept: Ag ka <= 20.95 -> Bremsstrahlung <= 9.64 (0.1342)
# Removed: Ag ka <= 20.95 -> Ag ka > -11.59 (0.0613) | Kept: Ag ka > -11.59 -> Ag ka <= 20.95 (0.0615)
# Removed: Bremsstrahlung > -9.06 -> Ag ka > -7.06 (0.0243) | Kept: Ag ka > -7.06 -> Bremsstrahlung > -9.06 (0.1805)
# Removed: Bremsstrahlung > -1.54 -> Bremsstrahlung > 4.15 (0.0205) | Kept: Bremsstrahlung > 4.15 -> Bremsstrahlung > -1.54 (0.1871)
# Removed: Ag La > 7.76 -> Ag Lb > -15.87 (0.0331) | Kept: Ag Lb > -15.87 -> Ag La > 7.76 (0.3293)
# Removed: Ag compton > 2.96 -> Ag compton <= -1.09 (0.0333) | Kept: Ag compton <= -1.09 -> Ag compton > 2.96 (0.0674)
# Removed: Ag compton <= 2.96 -> Ag compton > 2.96 (0.0098) | Kept: Ag compton > 2.96 -> Ag compton <= 2.96 (0.0515)
# Removed: Ag compton > -6.71 -> Ag compton <= 2.96 (0.0205) | Kept: Ag compton <= 2.96 -> Ag compton > -6.71 (0.0399)
# Removed: Ag compton <= 6.52 -> Ag compton > -6.71 (0.0287) | Kept: Ag compton > -6.71 -> Ag compton <= 6.52 (0.0390)
# Removed: Ag compton > -1.09 -> Ag compton <= 6.52 (0.0092) | Kept: Ag compton <= 6.52 -> Ag compton > -1.09 (0.0390)
# Removed: Ag compton > -1.09 -> Ag compton > -6.71 (0.0104) | Kept: Ag compton > -6.71 -> Ag compton > -1.09 (0.0379)
# Removed: background > -0.46 -> background > 0.40 (0.0014) | Kept: background > 0.40 -> background > -0.46 (0.0016)
# Removed: background > -1.23 -> background > -0.46 (0.0005) | Kept: background > -0.46 -> background > -1.23 (0.0024)
# Removed: background > -0.46 -> background <= 1.29 (0.0005) | Kept: background <= 1.29 -> background > -0.46 (0.0014)
# Removed: background > -1.23 -> background > 0.40 (0.0009) | Kept: background > 0.40 -> background > -1.23 (0.0015)
# Removed: background <= 0.40 -> background > 0.40 (0.0004) | Kept: background > 0.40 -> background <= 0.40 (0.0009)
# Removed: background <= -0.46 -> background <= 0.40 (0.0004) | Kept: background <= 0.40 -> background <= -0.46 (0.0029)
# Removed: Cu > -0.64 -> background <= -0.46 (0.0009) | Kept: background <= -0.46 -> Cu > -0.64 (0.0012)
# Removed: Cu <= 1.92 -> Cu > -0.64 (0.0019) | Kept: Cu > -0.64 -> Cu <= 1.92 (0.0038)
# Removed: Cu > 0.32 -> Cu > -0.64 (0.0019) | Kept: Cu > -0.64 -> Cu > 0.32 (0.0020)
# Removed: Cu <= 0.32 -> Cu > -0.64 (0.0009) | Kept: Cu > -0.64 -> Cu <= 0.32 (0.0019)
# Removed: Cu <= 1.92 -> Cu > 0.32 (0.0018) | Kept: Cu > 0.32 -> Cu <= 1.92 (0.0019)
# Removed: Cu > 0.32 -> Cu <= 0.32 (0.0009) | Kept: Cu <= 0.32 -> Cu > 0.32 (0.0027)
# Removed: Cu > -1.74 -> Cu > 0.32 (0.0009) | Kept: Cu > 0.32 -> Cu > -1.74 (0.0018)
# Removed: Cu <= 0.32 -> Zn > 0.56 (0.0009) | Kept: Zn > 0.56 -> Cu <= 0.32 (0.0016)
# Removed: Zn > -0.39 -> Zn > 0.56 (0.0014) | Kept: Zn > 0.56 -> Zn > -0.39 (0.0091)
# Removed: Cu <= 0.32 -> Cu > -1.74 (0.0017) | Kept: Cu > -1.74 -> Cu <= 0.32 (0.0026)
# Removed: Cu <= -0.64 -> Cu > -1.74 (0.0009) | Kept: Cu > -1.74 -> Cu <= -0.64 (0.0026)
# Removed: Zn > -1.47 -> Zn > -0.39 (0.0014) | Kept: Zn > -0.39 -> Zn > -1.47 (0.0089)
# Removed: Cu <= -0.64 -> Zn > -1.47 (0.0023) | Kept: Zn > -1.47 -> Cu <= -0.64 (0.0045)
# Removed: Zn <= 1.56 -> Zn <= 0.56 (0.0050) | Kept: Zn <= 0.56 -> Zn <= 1.56 (0.0063)
# Removed: Zn <= 1.56 -> Fe > 0.31 (0.0024) | Kept: Fe > 0.31 -> Zn <= 1.56 (0.0030)
# Removed: Fe > 0.31 -> Zn <= 0.56 (0.0010) | Kept: Zn <= 0.56 -> Fe > 0.31 (0.0012)
# Removed: Fe > 0.31 -> Zn <= -0.39 (0.0017) | Kept: Zn <= -0.39 -> Fe > 0.31 (0.0024)
# Removed: Fe > -0.36 -> Zn <= -0.39 (0.0018) | Kept: Zn <= -0.39 -> Fe > -0.36 (0.0059)
# Removed: Fe > -1.18 -> Fe <= -0.36 (0.0016) | Kept: Fe <= -0.36 -> Fe > -1.18 (0.0021)
# Removed: Fe <= 0.31 -> Fe <= -0.36 (0.0007) | Kept: Fe <= -0.36 -> Fe <= 0.31 (0.0037)
# Removed: Ca <= -0.68 -> Fe <= 0.31 (0.0011) | Kept: Fe <= 0.31 -> Ca <= -0.68 (0.0028)
# Removed: Ca > 0.46 -> Fe <= 1.20 (0.0012) | Kept: Fe <= 1.20 -> Ca > 0.46 (0.0014)
# Removed: Ca > -0.68 -> Fe <= 1.20 (0.0011) | Kept: Fe <= 1.20 -> Ca > -0.68 (0.0034)
# Removed: Ca > 0.46 -> Ca <= -0.68 (0.0011) | Kept: Ca <= -0.68 -> Ca > 0.46 (0.0012)
# Removed: Ca <= -0.68 -> Ca > -0.68 (0.0011) | Kept: Ca > -0.68 -> Ca <= -0.68 (0.0045)
# Removed: Ca > -1.79 -> Ca <= -0.68 (0.0010) | Kept: Ca <= -0.68 -> Ca > -1.79 (0.0032)
# Removed: Ca > -0.68 -> Ca <= 0.46 (0.0020) | Kept: Ca <= 0.46 -> Ca > -0.68 (0.0021)
# Removed: Ca <= 0.46 -> Ca > -1.79 (0.0010) | Kept: Ca > -1.79 -> Ca <= 0.46 (0.0051)
# Removed: Ca > -1.79 -> Ca <= 1.81 (0.0009) | Kept: Ca <= 1.81 -> Ca > -1.79 (0.0029)
#
# ======================================================================
# CONSTRUCTED GRAPH SUMMARY
# ======================================================================
# Initial edges: 213 | Removed: 52
# Predicate nodes: 60
# Metric: Perturbation
# Weighting by explained variance: ENABLED
#
# ======================================================================
# Processando Grafo - Semente: 3
# ======================================================================
#
#
# Total bidirectional pairs found: 54
# Removed: Bremsstrahlung <= -1.54 -> Ag Lb <= 8.04 (0.0682) | Kept: Ag Lb <= 8.04 -> Bremsstrahlung <= -1.54 (0.6147)
# Removed: Ag Lb <= 8.04 -> Ag ka <= -7.06 (0.0970) | Kept: Ag ka <= -7.06 -> Ag Lb <= 8.04 (0.1753)
# Removed: Ag ka <= -7.06 -> Bremsstrahlung <= -1.54 (0.0878) | Kept: Bremsstrahlung <= -1.54 -> Ag ka <= -7.06 (0.2786)
# Removed: Bremsstrahlung <= 4.15 -> Ag ka > 5.37 (0.0874) | Kept: Ag ka > 5.37 -> Bremsstrahlung <= 4.15 (0.1466)
# Removed: Ag ka > 5.37 -> Ag ka <= 5.37 (0.1382) | Kept: Ag ka <= 5.37 -> Ag ka > 5.37 (0.2760)
# Removed: Bremsstrahlung <= 9.64 -> Ag ka > 5.37 (0.0278) | Kept: Ag ka > 5.37 -> Bremsstrahlung <= 9.64 (0.2834)
# Removed: Bremsstrahlung <= 9.64 -> Ag ka <= 5.37 (0.1077) | Kept: Ag ka <= 5.37 -> Bremsstrahlung <= 9.64 (0.2016)
# Removed: Bremsstrahlung > -9.06 -> Ag ka > -11.59 (0.0742) | Kept: Ag ka > -11.59 -> Bremsstrahlung > -9.06 (0.1196)
# Removed: Bremsstrahlung > -9.06 -> Ag ka > -7.06 (0.0480) | Kept: Ag ka > -7.06 -> Bremsstrahlung > -9.06 (0.2419)
# Removed: Bremsstrahlung > -1.54 -> Bremsstrahlung > 4.15 (0.0402) | Kept: Bremsstrahlung > 4.15 -> Bremsstrahlung > -1.54 (0.1602)
# Removed: Ag Lb > 6.48 -> Ag La > 7.76 (0.0618) | Kept: Ag La > 7.76 -> Ag Lb > 6.48 (0.2540)
# Removed: Ag compton > 2.96 -> Ag compton <= -1.09 (0.0216) | Kept: Ag compton <= -1.09 -> Ag compton > 2.96 (0.0753)
# Removed: Ag compton <= 2.96 -> Ag compton > 2.96 (0.0097) | Kept: Ag compton > 2.96 -> Ag compton <= 2.96 (0.0509)
# Removed: Ag compton <= 6.52 -> Ag compton <= 2.96 (0.0192) | Kept: Ag compton <= 2.96 -> Ag compton <= 6.52 (0.0483)
# Removed: Ag compton > -1.09 -> Ag compton <= 6.52 (0.0097) | Kept: Ag compton <= 6.52 -> Ag compton > -1.09 (0.0192)
# Removed: Ag compton > -6.71 -> Ag compton <= 2.96 (0.0100) | Kept: Ag compton <= 2.96 -> Ag compton > -6.71 (0.0191)
# Removed: Ag compton > -1.09 -> Ag compton <= 2.96 (0.0094) | Kept: Ag compton <= 2.96 -> Ag compton > -1.09 (0.0099)
# Removed: Ag compton > -1.09 -> Ag compton > -6.71 (0.0097) | Kept: Ag compton > -6.71 -> Ag compton > -1.09 (0.0655)
# Removed: background > 0.40 -> background > -0.46 (0.0020) | Kept: background > -0.46 -> background > 0.40 (0.0024)
# Removed: background > -1.23 -> background > -0.46 (0.0004) | Kept: background > -0.46 -> background > -1.23 (0.0019)
# Removed: background <= 1.29 -> background > -1.23 (0.0004) | Kept: background > -1.23 -> background <= 1.29 (0.0042)
# Removed: background <= -0.46 -> background <= 0.40 (0.0004) | Kept: background <= 0.40 -> background <= -0.46 (0.0029)
# Removed: Cu > -0.64 -> background <= -0.46 (0.0009) | Kept: background <= -0.46 -> Cu > -0.64 (0.0023)
# Removed: background <= -0.46 -> Cu <= 1.92 (0.0003) | Kept: Cu <= 1.92 -> background <= -0.46 (0.0009)
# Removed: Cu > 0.32 -> Cu > -0.64 (0.0019) | Kept: Cu > -0.64 -> Cu > 0.32 (0.0047)
# Removed: Cu <= 1.92 -> Cu > -0.64 (0.0009) | Kept: Cu > -0.64 -> Cu <= 1.92 (0.0028)
# Removed: Cu <= 1.92 -> Cu > 0.32 (0.0009) | Kept: Cu > 0.32 -> Cu <= 1.92 (0.0028)
# Removed: Cu > 0.32 -> Cu <= 0.32 (0.0008) | Kept: Cu <= 0.32 -> Cu > 0.32 (0.0009)
# Removed: Cu > -1.74 -> Cu <= 1.92 (0.0018) | Kept: Cu <= 1.92 -> Cu > -1.74 (0.0027)
# Removed: Cu <= 0.32 -> Cu > -1.74 (0.0017) | Kept: Cu > -1.74 -> Cu <= 0.32 (0.0044)
# Removed: Zn > -0.39 -> Zn > 0.56 (0.0028) | Kept: Zn > 0.56 -> Zn > -0.39 (0.0090)
# Removed: Zn > 0.56 -> Zn > -1.47 (0.0014) | Kept: Zn > -1.47 -> Zn > 0.56 (0.0014)
# Removed: Cu <= -0.64 -> Zn > 0.56 (0.0008) | Kept: Zn > 0.56 -> Cu <= -0.64 (0.0014)
# Removed: Zn > -1.47 -> Zn > -0.39 (0.0014) | Kept: Zn > -0.39 -> Zn > -1.47 (0.0028)
# Removed: Cu <= -0.64 -> Zn > -0.39 (0.0008) | Kept: Zn > -0.39 -> Cu <= -0.64 (0.0060)
# Removed: Zn > -1.47 -> Cu <= -0.64 (0.0027) | Kept: Cu <= -0.64 -> Zn > -1.47 (0.0047)
# Removed: Fe > 0.31 -> Zn > -1.47 (0.0010) | Kept: Zn > -1.47 -> Fe > 0.31 (0.0029)
# Removed: Fe > 0.31 -> Zn <= 0.56 (0.0019) | Kept: Zn <= 0.56 -> Fe > 0.31 (0.0024)
# Removed: Zn <= -0.39 -> Fe > 0.31 (0.0012) | Kept: Fe > 0.31 -> Zn <= -0.39 (0.0018)
# Removed: Fe > 0.31 -> Zn <= 1.56 (0.0019) | Kept: Zn <= 1.56 -> Fe > 0.31 (0.0025)
# Removed: Zn <= 1.56 -> Zn <= 0.56 (0.0037) | Kept: Zn <= 0.56 -> Zn <= 1.56 (0.0063)
# Removed: Fe > -0.36 -> Zn <= -0.39 (0.0026) | Kept: Zn <= -0.39 -> Fe > -0.36 (0.0057)
# Removed: Fe > -0.36 -> Fe <= -0.36 (0.0008) | Kept: Fe <= -0.36 -> Fe > -0.36 (0.0008)
# Removed: Fe <= 0.31 -> Fe > -1.18 (0.0007) | Kept: Fe > -1.18 -> Fe <= 0.31 (0.0015)
# Removed: Fe <= -0.36 -> Fe > -1.18 (0.0015) | Kept: Fe > -1.18 -> Fe <= -0.36 (0.0024)
# Removed: Fe <= -0.36 -> Ca > 0.46 (0.0021) | Kept: Ca > 0.46 -> Fe <= -0.36 (0.0050)
# Removed: Fe <= 0.31 -> Ca > 0.46 (0.0014) | Kept: Ca > 0.46 -> Fe <= 0.31 (0.0023)
# Removed: Fe <= 1.20 -> Fe <= 0.31 (0.0013) | Kept: Fe <= 0.31 -> Fe <= 1.20 (0.0014)
# Removed: Fe <= 1.20 -> Ca <= -0.68 (0.0026) | Kept: Ca <= -0.68 -> Fe <= 1.20 (0.0034)
# Removed: Ca > -0.68 -> Ca <= -0.68 (0.0011) | Kept: Ca <= -0.68 -> Ca > -0.68 (0.0043)
# Removed: Ca <= 0.46 -> Ca > -0.68 (0.0010) | Kept: Ca > -0.68 -> Ca <= 0.46 (0.0064)
# Removed: Ca > -1.79 -> Ca <= -0.68 (0.0010) | Kept: Ca <= -0.68 -> Ca > -1.79 (0.0010)
# Removed: Ca > -1.79 -> Ca <= 0.46 (0.0019) | Kept: Ca <= 0.46 -> Ca > -1.79 (0.0061)
# Removed: Ca <= 1.81 -> Ca > -1.79 (0.0009) | Kept: Ca > -1.79 -> Ca <= 1.81 (0.0059)
#
# ======================================================================
# CONSTRUCTED GRAPH SUMMARY
# ======================================================================
# Initial edges: 203 | Removed: 54
# Predicate nodes: 60
# Metric: Perturbation
# Weighting by explained variance: ENABLED
#
# Processing graph LRC...
#
# Processing graph LRC...
#
# Processing graph LRC...
#
# Processing graph LRC...
#    Predicate_pert_Seed_0 Predicate_pert_Seed_1 Predicate_pert_Seed_2  \
# 0          Ag La <= 2.70         Ag La <= 2.70         Ag La <= 2.70
# 1          Ag Lb <= 2.36         Ag Lb <= 2.36         Ag Lb <= 2.36
# 2          Ag La <= 7.76         Ag La <= 7.76         Ag La <= 7.76
# 3          Ag La <= 9.01         Ag La <= 9.01         Ag La <= 9.01
# 4          Ag Lb <= 6.48         Ag Lb <= 6.48         Ag Lb <= 6.48
# ..                   ...                   ...                   ...
# 57            Fe <= 0.31            Ca > -0.68             Ca > 0.46
# 58           Fe <= -0.36            Ca > -1.79           Ca <= -0.68
# 59            Ca <= 1.81            Ca <= 1.81            Fe <= 1.20
# 60               Class_A               Class_A               Class_A
# 61               Class_B               Class_B               Class_B
#
#    Predicate_pert_Seed_3
# 0          Ag La <= 2.70
# 1          Ag Lb <= 2.36
# 2          Ag La <= 7.76
# 3          Ag La <= 9.01
# 4          Ag Lb <= 6.48
# ..                   ...
# 57            Ca <= 0.46
# 58            Ca > -1.79
# 59            Ca <= 1.81
# 60               Class_A
# 61               Class_B
#
# [62 rows x 4 columns]

# %%
all_results_pert[0]['pert_results_dict']['Bag_1']
# Out:
#                   Predicate  Perturbation
# 0             Ag La <= 2.70      0.280579
# 1             Ag Lb <= 2.36      0.207624
# 2             Ag La <= 7.76      0.182295
# 3             Ag La <= 9.01      0.146835
# 4             Ag Lb <= 6.48      0.136691
# 5   Bremsstrahlung <= -1.54      0.118535
# 6             Ag Lb <= 8.04      0.109450
# 7            Ag ka <= -7.06      0.106561
# 8    Bremsstrahlung <= 4.15      0.097235
# 9    Bremsstrahlung <= 9.64      0.091297
# 10            Ag ka <= 5.37      0.087377
# 11           Ag ka <= 20.95      0.082712
# 12             Ag ka > 5.37      0.081586
# 13   Bremsstrahlung > -9.06      0.081003
# 14           Ag ka > -11.59      0.074718
# 15            Ag ka > -7.06      0.070785
# 16    Bremsstrahlung > 4.15      0.070157
# 17   Bremsstrahlung > -1.54      0.065351
# 18           Ag La > -18.52      0.056692
# 19           Ag Lb > -15.87      0.038847
# 20             Ag La > 7.76      0.038033
# 21             Ag Lb > 6.48      0.034219
# 22             Ag La > 2.70      0.031325
# 23             Ag Lb > 2.36      0.026642
# 24      Ag compton <= -1.09      0.021114
# 25        Ag compton > 2.96      0.019980
# 26       Ag compton <= 2.96      0.019461
# 27       Ag compton > -1.09      0.018758
# 28       Ag compton > -6.71      0.018643
# 29       Ag compton <= 6.52      0.018630
# 30       background > -0.46      0.014223
# 31       background > -1.23      0.014102
# 32        background > 0.40      0.014010
# 33       background <= 1.29      0.013858
# 34       background <= 0.40      0.012363
# 35      background <= -0.46      0.011191
# 36               Cu <= 1.92      0.010018
# 37               Cu > -0.64      0.009963
# 38               Cu <= 0.32      0.009880
# 39               Cu > -1.74      0.009479
# 40                Cu > 0.32      0.009395
# 41              Cu <= -0.64      0.009256
# 42                Zn > 0.56      0.009013
# 43               Zn > -1.47      0.008248
# 44               Zn > -0.39      0.008222
# 45              Zn <= -0.39      0.007235
# 46                Fe > 0.31      0.007153
# 47               Zn <= 0.56      0.007088
# 48               Zn <= 1.56      0.007042
# 49               Fe > -0.36      0.006326
# 50               Fe > -1.18      0.006029
# 51              Fe <= -0.36      0.005976
# 52               Fe <= 0.31      0.005470
# 53              Ca <= -0.68      0.005327
# 54               Fe <= 1.20      0.005255
# 55                Ca > 0.46      0.005187
# 56               Ca <= 0.46      0.004711
# 57               Ca > -0.68      0.004623
# 58               Ca <= 1.81      0.004470
# 59               Ca > -1.79      0.004323

# %%
# Somar LRCs de predicados equivalentes entre diferentes seeds
lrc_combined_list = []

for seed in random_seeds:
    lrc_df = lrc_pert_by_seed[seed].copy()
    lrc_combined_list.append(lrc_df) # o append adiciona o dataframe ao final da lista

# Concatenar todos os dataframes
lrc_all_seeds = pd.concat(lrc_combined_list, ignore_index=True) 

# Agrupar por predicado (Node) e somar as LRCs, mantendo Zone, Threshold e Operator
lrc_summed_df_pert = lrc_all_seeds.groupby('Node').agg({ # o .agg pode ser usado para aplicar múltiplas funções de agregação
    'Local_Reaching_Centrality': 'mean', # sum = somando as LRCs, poderia ser média ou outro agregado
    'Zone': 'first',
    'Threshold': 'first',
    'Operator': 'first'
}).reset_index()

# Ordenar pelo valor de LRC somado (maior para menor)
lrc_summed_df_pert = lrc_summed_df_pert.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
# vamoss pegar so os valore sunicos de lrc_summed_df baseado na zona espectral
lrc_summed_unique_df_pert = lrc_summed_df_pert.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
lrc_summed_unique_df_pert = lrc_summed_unique_df_pert.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
lrc_summed_unique_df_pert
# Out:
#                        Node  Local_Reaching_Centrality            Zone  \
# 0             Ag La <= 2.70                   6.832186           Ag La
# 1             Ag Lb <= 2.36                   5.396403           Ag Lb
# 2            Ag ka <= -7.06                   1.603727           Ag ka
# 3   Bremsstrahlung <= -1.54                   1.517588  Bremsstrahlung
# 4       Ag compton <= -1.09                   0.138805      Ag compton
# 5        background > -1.23                   0.014875      background
# 6                Cu > -0.64                   0.014717              Cu
# 7                 Zn > 0.56                   0.014408              Zn
# 8                 Fe > 0.31                   0.009448              Fe
# 9                 Ca > 0.46                   0.008135              Ca
# 10                  Class_A                   0.000000            None
#
#    Threshold Operator
# 0       2.70       <=
# 1       2.36       <=
# 2      -7.06       <=
# 3      -1.54       <=
# 4      -1.09       <=
# 5      -1.23        >
# 6      -0.64        >
# 7       0.56        >
# 8       0.31        >
# 9       0.46        >
# 10      None     None

# %%
# Aplicar o mapeamento
lrc_summed_df_pert_natural = exp.map_thresholds_to_natural(
    lrc_df=lrc_summed_df_pert,
    zone_sums_preprocessed=zone_scores_df,
    zone_sums_natural=zones_original[0]
)

lrc_summed_df_pert_natural
# Out:
#              Node  Local_Reaching_Centrality   Zone Threshold Operator  \
# 0   Ag La <= 2.70                   6.832186  Ag La      2.70       <=
# 1   Ag Lb <= 2.36                   5.396403  Ag Lb      2.36       <=
# 2   Ag La <= 7.76                   4.350936  Ag La      7.76       <=
# 3   Ag La <= 9.01                   3.269161  Ag La      9.01       <=
# 4   Ag Lb <= 6.48                   2.284171  Ag Lb      6.48       <=
# ..            ...                        ...    ...       ...      ...
# 57     Fe <= 1.20                   0.005629     Fe      1.20       <=
# 58     Ca > -1.79                   0.005500     Ca     -1.79        >
# 59     Ca <= 1.81                   0.003701     Ca      1.81       <=
# 60        Class_A                   0.000000   None      None     None
# 61        Class_B                   0.000000   None      None     None
#
#     Threshold_Natural  Reference_Sample_Index  Approximation_Error  \
# 0           34.935039                    86.0             0.021418
# 1           30.578162                     0.0             0.008013
# 2          105.814886                    78.0             0.002963
# 3          126.903607                   239.0             0.004801
# 4           75.496450                    98.0             0.013050
# ..                ...                     ...                  ...
# 57           2.891092                    80.0             0.001648
# 58          -9.483856                   153.0             0.012409
# 59          -2.575534                   222.0             0.044016
# 60                NaN                     NaN                  NaN
# 61                NaN                     NaN                  NaN
#
#            Node_Natural
# 0    Ag La <= 34.935039
# 1    Ag Lb <= 30.578162
# 2   Ag La <= 105.814886
# 3   Ag La <= 126.903607
# 4    Ag Lb <= 75.496450
# ..                  ...
# 57       Fe <= 2.891092
# 58       Ca > -9.483856
# 59      Ca <= -2.575534
# 60                 None
# 61                 None
#
# [62 rows x 9 columns]

# %%
import plotly.graph_objects as go

n = 0
zone_name = lrc_summed_df_pert_natural.iloc[n]['Zone'] # o n indica a linha do dataframe lrc_summed_df_pert_natural que queremos acessar para pegar o nome da zona espectral (coluna 'Zone')
threshold_score = float(lrc_summed_df_pert_natural.iloc[n]['Threshold_Natural']) # o iloc acessa a linha n e a coluna 'Threshold_Natural' para pegar o valor do threshold já mapeado para o espaço natural (não pré-processado)

# Usar pca_info_dict dos dados ORIGINAIS (zones_original[1])
pca_info_dict_original = zones_original[1]

# Reconstrução: τ = mean + threshold * loadings (no espaço original)
threshold_spectrum = exp.reconstruct_threshold_to_spectrum(
    threshold_value=threshold_score,
    zone_name=zone_name,
    pca_info_dict=pca_info_dict_original
)
print(f"\nEspectro de threshold reconstruído para zona '{zone_name}':")
print(f"  - Dimensão: {len(threshold_spectrum)} variáveis espectrais")
#print(f"  - Range de energias: {threshold_spectrum.index[n]} - {threshold_spectrum.index[-1]}")
print(f"  - Variância explicada pela PC1: {pca_info_dict_original[zone_name]['variance_explained']:.2%}")

# Usar dados ORIGINAIS para plotar (spectral_zones_original)
zone_df = spectral_zones_original[zone_name]

# Plotar zona com threshold (inline)
fig = go.Figure()
x_values = pd.to_numeric(zone_df.columns, errors='coerce')

# Plotar espectros das amostras coloridas por classe
colors = {'A': 'gold', 'B': 'blue'}
for idx, row in zone_df.iterrows():
    class_label = ycalclass.iloc[idx] if idx < len(ycalclass) else 'Unknown'
    fig.add_trace(go.Scatter(
        x=x_values,
        y=row.values,
        mode='lines',
        line=dict(color=colors.get(class_label, 'rgba(128,128,128,0.3)'), width=0.5),
        name=f'Class {class_label}',
        showlegend=False,
        hoverinfo='skip'
    ))

# Plotar espectro de threshold (destaque)
fig.add_trace(go.Scatter(
    x=x_values,
    y=threshold_spectrum.values,
    mode='lines',
    line=dict(color='red', width=4, dash='dash'),
    name=f'Threshold Spectrum ({threshold_spectrum.name})'
))

# Layout do gráfico
fig.update_layout(
    title=f"Zona '{zone_name}' com Threshold Multivariado (Predicado: {lrc_summed_df_pert_natural.iloc[n]['Node_Natural']})",
    xaxis_title='Energia / Comprimento de Onda',
    yaxis_title='Intensidade',
    template='plotly_white',
    showlegend=True,
    legend=dict(yanchor="top", y=0.99, xanchor="left", x=0.01)
)

fig.show()
# Out:
# Espectro de threshold reconstruído para zona 'Ag La':
#   - Dimensão: 18 variáveis espectrais
#   - Variância explicada pela PC1: 91.39%

# %%
# Permutation importance baseado em mudança nas probabilidades previstas (predict_proba)
# Medimos a média da diferença absoluta entre as probabilidades originais e as probabilidades
# obtidas após permutar cada variável. Isso fornece uma métrica contínua de importância.
n_repeats = 10
rng = np.random.RandomState(42)
# Probabilidades base (classe 'B' mapeada para 1)
baseline_proba = svm_model[3].predict_proba(Xcalclass_prep)[:, 1]
importance_list = []
X_arr = Xcalclass_prep.copy()
for col in Xcalclass_prep.columns:
    diffs = []
    for _ in range(n_repeats):
        X_perm = X_arr.copy()
        X_perm[col] = rng.permutation(X_perm[col].values)
        perm_proba = svm_model[3].predict_proba(X_perm)[:, 1]
        diffs.append(np.mean(np.abs(baseline_proba - perm_proba)))
    importance_list.append(np.mean(diffs))

permutation_df = pd.DataFrame({
    'energy': Xcalclass_prep.columns,
    'Permutation_importance_proba': importance_list
})
permutation_df.sort_values(by='Permutation_importance_proba', ascending=False, inplace=True)
energy_to_zone_vip = {}
for zone_name, start, end in spectral_cuts:
    for e in permutation_df['energy']:
        ef = float(e)
        if start <= ef <= end:
            energy_to_zone_vip[e] = zone_name
permutation_df['Zone'] = permutation_df['energy'].map(energy_to_zone_vip)
permutation_unique_df = permutation_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
permutation_unique_df = permutation_unique_df.sort_values(by='Permutation_importance_proba', ascending=False)
permutation_unique_df
# Out:
#   energy  Permutation_importance_proba            Zone
# 0  22.23                      0.025221           Ag ka
# 1   3.02                      0.017224           Ag La
# 2   3.17                      0.009655           Ag Lb
# 3   8.73                      0.003845              Zn
# 4  17.99                      0.003762  Bremsstrahlung
# 5  21.41                      0.003521      Ag compton
# 6   6.35                      0.003235              Fe
# 7   7.80                      0.002151              Cu
# 8   3.89                      0.002094              Ca
# 9   4.84                      0.001933      background

# %%
import numpy as np

max_len = max(
    len(pvector_unique_df['Zone']),
    len(shap_unique_df['Zone']),
    len(permutation_unique_df['Zone']),
    len(lrc_summed_unique_df_pert['Zone']),
    len(lrc_summed_unique_df_cov['Zone'])
)

def pad_list(lst, length):
    return list(lst) + [None] * (length - len(lst))

features_importance = pd.DataFrame({
    'SVM_pvector': pad_list(pvector_unique_df['Zone'], max_len),
    'Shap': pad_list(shap_unique_df['Zone'], max_len),
    'Permutation' : pad_list(permutation_unique_df['Zone'], max_len),
    'LRC_perturbation' : pad_list(lrc_summed_unique_df_pert['Zone'], max_len),
    'LRC_covariance' : pad_list(lrc_summed_unique_df_cov['Zone'], max_len),
})

features_importance.to_csv('feature_importance.csv', index=False, sep=';')
features_importance
# Out:
#        SVM_pvector            Shap     Permutation LRC_perturbation  \
# 0            Ag ka           Ag La           Ag ka            Ag La
# 1            Ag La           Ag ka           Ag La            Ag Lb
# 2               Zn           Ag Lb           Ag Lb            Ag ka
# 3            Ag Lb  Bremsstrahlung              Zn   Bremsstrahlung
# 4   Bremsstrahlung              Zn  Bremsstrahlung       Ag compton
# 5               Fe      Ag compton      Ag compton       background
# 6       Ag compton              Fe              Fe               Cu
# 7       background              Ca              Cu               Zn
# 8               Ca              Cu              Ca               Fe
# 9               Cu      background      background               Ca
# 10            None            None            None             None
#
#     LRC_covariance
# 0            Ag La
# 1            Ag Lb
# 2            Ag ka
# 3       Ag compton
# 4   Bremsstrahlung
# 5               Ca
# 6               Fe
# 7               Zn
# 8               Cu
# 9       background
# 10            None

# %%
import rbo
rbo_comparison = pd.DataFrame(columns=['Method_1', 'Method_2', 'RBO_Score'])
methods = features_importance.columns.tolist()
for i in range(len(methods)):
    for j in range(i + 1, len(methods)):
        method_1 = methods[i]
        method_2 = methods[j]
        # Remove None values from the lists
        list_1 = [x for x in features_importance[method_1].tolist() if x is not None]
        list_2 = [x for x in features_importance[method_2].tolist() if x is not None]
        # Truncate both lists to the same length (minimum of both)
        min_len = min(len(list_1), len(list_2))
        list_1_trunc = list_1[:min_len]
        list_2_trunc = list_2[:min_len]
        rbo_score = rbo.RankingSimilarity(list_1_trunc, list_2_trunc).rbo(p=0.7, k=10)
        rbo_comparison = pd.concat([rbo_comparison, pd.DataFrame({
            'Method_1': [method_1],
            'Method_2': [method_2],
            'RBO_Score': [rbo_score]
        })], ignore_index=True)
rbo_comparison.sort_values(by='RBO_Score', ascending=False, inplace=True)
rbo_comparison.to_csv('rbo_rank.csv', index=False, sep=';')
rbo_comparison
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_20708\3097109587.py:16: FutureWarning:
#
# The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#            Method_1          Method_2  RBO_Score
# 9  LRC_perturbation    LRC_covariance   0.919442
# 1       SVM_pvector       Permutation   0.909339
# 5              Shap  LRC_perturbation   0.825761
# 6              Shap    LRC_covariance   0.813176
# 4              Shap       Permutation   0.642939
# 0       SVM_pvector              Shap   0.583614
# 8       Permutation    LRC_covariance   0.510088
# 7       Permutation  LRC_perturbation   0.503124
# 3       SVM_pvector    LRC_covariance   0.450762
# 2       SVM_pvector  LRC_perturbation   0.445720

# %%
lrc_summed_df_cov_natural.to_csv('lrc_cov_natural.csv', index=False, sep=';')
lrc_summed_df_pert_natural.to_csv('lrc_pert_natural.csv', index=False, sep=';')
