# %%
# Importing the necessary libraries
import pandas as pd
import numpy as np
import kennard_stone as ks
pd.options.plotting.backend = 'plotly'  # setting plotly as the backend for pandas plotting

# Add parent directory to sys.path so local module 'synthetic' can be imported
import sys
from pathlib import Path # for path manipulations
# Move three levels up from current working directory to reach workspace root
workspace_root = Path.cwd().parent.parent.parent.resolve() 
smx_dir = workspace_root / 'smx'  # Path to smx folder
if str(smx_dir) not in sys.path: # check to avoid duplicates
    sys.path.insert(0, str(smx_dir)) # insert at the start of sys.path to prioritize local modules

# Loading a soil spectral dataset based on X-ray fluorescence (XRF)
data_complete = pd.read_csv(f'{workspace_root}/real_datasets/xrf/forage.csv', sep=';') # local copy of Toledo 2022 dataset (os ... indica para omitir o caminho longo)
data = data_complete.loc[:, '1.4':'20.81']

# Split dataset by class and create calibration/prediction sets using Kennard-Stone (as in original pipeline)
data_A = data_complete[data_complete['Class'] == 'A'].reset_index(drop=True)
data_B = data_complete[data_complete['Class'] == 'B'].reset_index(drop=True)

# splitting the data into calibration and prediction sets by kennard-stone algorithm
XA_cal, XA_pred = ks.train_test_split(data_A.loc[:, '1.4':'20.81'], test_size=0.30)  # class A
XA_cal = XA_cal.reset_index(drop=True)
XA_pred = XA_pred.reset_index(drop=True)

XB_cal, XB_pred = ks.train_test_split(data_B.loc[:, '1.4':'20.81'], test_size=0.30)  # class B
XB_cal = XB_cal.reset_index(drop=True)
XB_pred = XB_pred.reset_index(drop=True)

Xcalclass = pd.concat([XA_cal, XB_cal], axis=0).reset_index(drop=True)  # concatenating both classes
Xpredclass = pd.concat([XA_pred, XB_pred], axis=0).reset_index(drop=True)
ycalclass = pd.Series(['A']*XA_cal.shape[0] + ['B']*XB_cal.shape[0])  # target for calibration set
ypredclass = pd.Series(['A']*XA_pred.shape[0] + ['B']*XB_pred.shape[0])  # target for prediction set

# preprocessings
import preprocessings as prepr  # preprocessing methods for XRF data

Xcalclass_prep, mean_calclass, mean_calclass_poisson  = prepr.poisson(Xcalclass, mc=True)
Xpredclass_prep = ((Xpredclass/np.sqrt(mean_calclass)) - mean_calclass_poisson)
# Out:
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-02-26 14:58:58,581 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-02-26 14:58:58,586 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-02-26 14:58:58,599 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-02-26 14:58:58,625 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
from modeling import svm_optimized

svm_model = svm_optimized(Xcalclass_prep, ycalclass, Xpredclass_prep, ypredclass, aim='classification', kernel='rbf')
svm_model[0]
# Out:
#   Model  Accuracy Cal  Sensitivity Cal  Specificity Cal              CM Cal  \
# 0   SVC           1.0              1.0              1.0  [[40, 0], [0, 95]]
#
#    Accuracy Pred  Sensitivity Pred  Specificity Pred             CM Pred
# 0            1.0               1.0               1.0  [[18, 0], [0, 42]]

# %% [markdown]
# ## Definição das Zonas Espectrais

# %%
spectral_cuts = [
('Al', 1.40, 1.63),
('Si', 1.63, 1.86),
('P', 1.86, 2.16),
('S', 2.16, 2.44),
('Rh L + Ar', 2.44, 3.10),
('K', 3.10, 3.46),
('Ca ka', 3.46, 3.86),
('Ca kb', 3.86, 4.16),
('background1', 4.14, 4.37),
('Ti ka', 4.37, 4.66),
('Ti kb', 4.66, 5.08),
('background2', 5.08, 5.72),
('Mn', 5.72, 6.10),
('Fe ka', 6.10, 6.76),
('Fe kb', 6.76, 7.20),
('Ni', 7.20, 7.69),
('background3', 7.69, 13.10),
('sum Fe' , 13.10, 13.63),
('background4', 13.63, 18.0),
('Compton scattering', 18.0, 19.70),
('Rayleight scattering', 19.70, 20.81)
]

# %% [markdown]
# ## Pvector and SHAP

# %%
X_sv = svm_model[3].support_vectors_            # shape (n_SV, n_features)
alpha_dual = svm_model[3].dual_coef_.ravel()    # shape (n_SV,)

# Calculando os coeficientes p usando os vetores de suporte e os multiplicadores de Lagrange
pvetor = pd.DataFrame({'energia' : Xcalclass.columns,
                       'importance': (X_sv.T) @ alpha_dual})
pvetor['importance'] = np.abs(pvetor['importance'])
pvector_df = pd.DataFrame({
    'energy': pvetor['energia'],
    'Pvector': pvetor['importance'].values
})
pvector_df = pvector_df.sort_values(by='Pvector', ascending=False).reset_index(drop=True)
energy_to_zone_vip = {}
for zone_name, start, end in spectral_cuts:
    for e in pvector_df['energy']:
        ef = float(e)
        if start <= ef <= end:
            energy_to_zone_vip[e] = zone_name
pvector_df['Zone'] = pvector_df['energy'].map(energy_to_zone_vip)
pvector_unique_df = pvector_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
pvector_unique_df
# Out:
#    energy    Pvector                  Zone
# 0    6.42  29.020377                 Fe ka
# 1     3.7  21.276746                 Ca ka
# 2    1.74  20.460692                    Si
# 3    3.34  12.997443                     K
# 4    4.02   7.862402                 Ca kb
# 5    4.52   7.835278                 Ti ka
# 6    7.08   7.213706                 Fe kb
# 7    2.62   5.597003             Rh L + Ar
# 8    1.86   3.167416                     P
# 9    2.28   2.214821                     S
# 10  13.41   2.154293                sum Fe
# 11   1.62   2.151909                    Al
# 12   4.94   2.032520                 Ti kb
# 13   7.54   1.425007                    Ni
# 14   5.92   1.240119                    Mn
# 15  19.39   1.124331    Compton scattering
# 16  11.95   1.122248           background3
# 17  20.31   0.974562  Rayleight scattering
# 18  15.41   0.831623           background4
# 19   4.14   0.743773           background1
# 20   5.12   0.699431           background2

# %%
shap_global_importance = pd.read_csv('shap_forage.csv', sep=';') # loading previously saved shap_unique_df
# vamos gerar uma nova coluna em shap_global_importance com o nome da zona espectral correspondente de acordo com a lista spectral_cuts
energy_to_zone_shap = {}
for zone_name, start, end in spectral_cuts:
    for i in shap_global_importance['energy']:
        i_float = float(i)
        if start <= i_float <= end:
            energy_to_zone_shap[i] = zone_name
shap_global_importance['Zone'] = shap_global_importance['energy'].map(energy_to_zone_shap)

# agora vamos filtrar shap_global_importance para manter apenas as zonas espectrais únicas com maior SHAP score
shap_unique_df = shap_global_importance.sort_values(by='Mean_Abs_SHAP', ascending=False).reset_index(drop=True)
shap_unique_df = shap_unique_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
shap_unique_df
# Out:
#     energy  Mean_Abs_SHAP                  Zone
# 0     1.74       0.040840                    Si
# 1     3.70       0.033018                 Ca ka
# 2     6.42       0.029003                 Fe ka
# 3     3.36       0.005098                     K
# 4    13.65       0.000478           background4
# 5     2.64       0.000472             Rh L + Ar
# 6     7.97       0.000445           background3
# 7    19.45       0.000360    Compton scattering
# 8     2.32       0.000263                     S
# 9    13.61       0.000000                sum Fe
# 10    1.40       0.000000                    Al
# 11   20.27       0.000000  Rayleight scattering
# 12    5.10       0.000000           background2
# 13    4.86       0.000000                 Ti kb
# 14    4.24       0.000000           background1
# 15    4.38       0.000000                 Ti ka
# 16    6.00       0.000000                    Mn
# 17    2.14       0.000000                     P
# 18    3.86       0.000000                 Ca kb
# 19    6.76       0.000000                 Fe kb
# 20    7.38       0.000000                    Ni

# %% [markdown]
# ## Funções de Agregação por PCA
#
# Aqui implementamos as funções para agregar zonas espectrais usando PCA com 1 componente principal.

# %%
import explaining as exp

# Extração das zonas espectrais
spectral_zones_class = exp.extract_spectral_zones(Xcalclass_prep, spectral_cuts)
zone_scores_df, pca_info_dict = exp.aggregate_spectral_zones_pca(spectral_zones_class) # apca aggregation
print(f"\nScores DataFrame shape: {zone_scores_df.shape}")
# Out:
# Zone 'Al': VE = 92.81%, dim = 12 variables
# Zone 'Si': VE = 99.42%, dim = 12 variables
# Zone 'P': VE = 94.16%, dim = 16 variables
# Zone 'S': VE = 89.31%, dim = 15 variables
# Zone 'Rh L + Ar': VE = 95.85%, dim = 34 variables
# Zone 'K': VE = 98.44%, dim = 19 variables
# Zone 'Ca ka': VE = 89.46%, dim = 21 variables
# Zone 'Ca kb': VE = 97.67%, dim = 16 variables
# Zone 'background1': VE = 53.72%, dim = 12 variables
# Zone 'Ti ka': VE = 98.15%, dim = 15 variables
# Zone 'Ti kb': VE = 76.25%, dim = 22 variables
# Zone 'background2': VE = 66.63%, dim = 33 variables
# Zone 'Mn': VE = 94.16%, dim = 20 variables
# Zone 'Fe ka': VE = 99.38%, dim = 34 variables
# Zone 'Fe kb': VE = 94.04%, dim = 23 variables
# Zone 'Ni': VE = 77.76%, dim = 25 variables
# Zone 'background3': VE = 84.69%, dim = 271 variables
# Zone 'sum Fe': VE = 88.47%, dim = 27 variables
# Zone 'background4': VE = 87.92%, dim = 219 variables
# Zone 'Compton scattering': VE = 88.73%, dim = 85 variables
# Zone 'Rayleight scattering': VE = 84.40%, dim = 56 variables
#
# Scores DataFrame shape: (135, 21)

# %%
y_pred = svm_model[4]['SVC'].values # using the continuous predictions from SVM, extracting as 1D array
predicates_quantiles = exp.predicates_by_quantiles(zone_scores_df, [0.2, 0.4, 0.6, 0.8])
predicate_info_dict = exp.create_predicate_info_dict(
    predicates_df=predicates_quantiles[0],
    predicate_indicator_df=predicates_quantiles[1],
    zone_aggregated_df=zone_scores_df,
    y_predicted_numeric=y_pred
)

# %%
import explaining as exp

# LISTA DE SEMENTES A TESTAR
random_seeds = [0, 1, 2, 3]

all_results_cov = {}
training_samples = len(Xcalclass)

# LOOP: PROCESSAR CADA SEMENTE

y_pred = pd.Series(svm_model[4]['SVC'].values) # using the continuous predictions from SVM, extracting as 1D array

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando semente: {seed}")
    print(f"{'='*70}\n")
    # Bagging
    bags_result_seed = exp.bagging_predicates(
        zone_sums_df=zone_scores_df,
        y_predicted_numeric=y_pred,
        predicates_df=predicates_quantiles[0],
        n_bags=10,
        #n_predicates_per_bag=40,
        n_samples_per_bag=int(training_samples*0.8), # 80 % da base para amostrar (convertido para int)
        min_samples_per_predicate=int(training_samples*0.2), # 20 % da base para limitar (convertido para int)
        replace=False,
        sample_bagging=True,
        predicate_bagging=False,
        random_seed=seed
    )
    
    # Inserir classe prevista
    for bag_name, pred_dict in bags_result_seed.items(): # iterando sobre cada bag
        for pred_rule, df_info in pred_dict.items():
            df_info['Class_Predicted'] = np.where(df_info['Predicted_Y'] >= 0.5, 'A', 'B') # binarizando com threshold 0.5, A = eut, B = dist
    
    # Calcular MI
    cov_results_dict_seed = exp.calculate_predicate_metrics(
        bags_result=bags_result_seed,
        metric='covariance', # covariance ou mutual_information
        threshold=0.01, # threshold para cortar predicados irrelevantes
        n_neighbors=5
    )
    
    # Salvar no dicionário principal
    all_results_cov[seed] = {
        'bags_result': bags_result_seed,
        'cov_results_dict': cov_results_dict_seed
    }

# CONSTRUÇÃO DE GRAFOS PARA MÚLTIPLAS SEMENTES (LOOP EXTERNO)
# Dicionário para armazenar grafos
graphs_by_seed = {}

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando Grafo - Semente: {seed}")
    print(f"{'='*70}\n")
    
    # Construir grafo para esta semente (sem predicates_df - extraído da regra)
    DG = exp.build_predicate_graph(
        bags_result=all_results_cov[seed]['bags_result'],
        predicate_ranking_dict=all_results_cov[seed]['cov_results_dict'],
        metric_column='Covariance',
        random_state=seed,
        show_details=True,
        var_exp=True,
        pca_info_dict=pca_info_dict
    )
    # Armazenar grafo
    graphs_by_seed[seed] = DG

# Calcular LRC usando a função pronta do explaining.py
lrc_cov_by_seed = {}
for seed in random_seeds:
    DG = graphs_by_seed[seed]
    lrc_cov_df_seed = exp.calculate_lrc_single_graph(DG, predicates_quantiles[0])
    lrc_cov_df_seed['Seed'] = seed  # Adicionar coluna com a semente
    lrc_cov_by_seed[seed] = lrc_cov_df_seed

# junando todas as colunas 'Node' de lrc_by_seed em um único dataframe
lrc_cov_all_seeds_df = pd.DataFrame()
for seed in random_seeds:
    lrc_cov_df_seed = lrc_cov_by_seed[seed].rename(columns={'Node': f'Predicate_Cov_Seed_{seed}'})
    lrc_cov_all_seeds_df = pd.concat([lrc_cov_all_seeds_df, lrc_cov_df_seed[[f'Predicate_Cov_Seed_{seed}']]], axis=1)

# vamos filtrar lrc_by_seed em cada semente para manter apenas as zonas espectrais únicas com maior LRC em um mesmo dataframe
lrc_cov_unique_by_seed = {}
for seed, lrc_df in lrc_cov_by_seed.items():
    lrc_cov_unique_df = lrc_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
    lrc_cov_unique_df = lrc_cov_unique_df.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
    lrc_cov_unique_by_seed[seed] = lrc_cov_unique_df

lrc_cov_all_seeds_df # exibindo o dataframe consolidado com predicados de todas as sementes
# Out:
# ======================================================================
# Processando semente: 0
# ======================================================================
#
# Bag_1 | Samples: Yes | Predicates: No (All) | Valid: 126 | Discarded: 42
# Bag_2 | Samples: Yes | Predicates: No (All) | Valid: 126 | Discarded: 42
# Bag_3 | Samples: Yes | Predicates: No (All) | Valid: 126 | Discarded: 42
# Bag_4 | Samples: Yes | Predicates: No (All) | Valid: 126 | Discarded: 42
# Bag_5 | Samples: Yes | Predicates: No (All) | Valid: 127 | Discarded: 41
# Bag_6 | Samples: Yes | Predicates: No (All) | Valid: 127 | Discarded: 41
# Bag_7 | Samples: Yes | Predicates: No (All) | Valid: 126 | Discarded: 42
# Bag_8 | Samples: Yes | Predicates: No (All) | Valid: 126 | Discarded: 42
# Bag_9 | Samples: Yes | Predicates: No (All) | Valid: 126 | Discarded: 42
# Bag_10 | Samples: Yes | Predicates: No (All) | Valid: 126 | Discarded: 42
# Computing Covariance for Predicates
# Metric: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando semente: 1
# ======================================================================
#
# Bag_1 | Samples: Yes | Predicates: No (All) | Valid: 126 | Discarded: 42
# Bag_2 | Samples: Yes | Predicates: No (All) | Valid: 126 | Discarded: 42
# Bag_3 | Samples: Yes | Predicates: No (All) | Valid: 126 | Discarded: 42
# Bag_4 | Samples: Yes | Predicates: No (All) | Valid: 126 | Discarded: 42
# Bag_5 | Samples: Yes | Predicates: No (All) | Valid: 126 | Discarded: 42
# Bag_6 | Samples: Yes | Predicates: No (All) | Valid: 126 | Discarded: 42
# Bag_7 | Samples: Yes | Predicates: No (All) | Valid: 126 | Discarded: 42
# Bag_8 | Samples: Yes | Predicates: No (All) | Valid: 126 | Discarded: 42
# Bag_9 | Samples: Yes | Predicates: No (All) | Valid: 127 | Discarded: 41
# Bag_10 | Samples: Yes | Predicates: No (All) | Valid: 126 | Discarded: 42
# Computing Covariance for Predicates
# Metric: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando semente: 2
# ======================================================================
#
# Bag_1 | Samples: Yes | Predicates: No (All) | Valid: 126 | Discarded: 42
# Bag_2 | Samples: Yes | Predicates: No (All) | Valid: 127 | Discarded: 41
# Bag_3 | Samples: Yes | Predicates: No (All) | Valid: 126 | Discarded: 42
# Bag_4 | Samples: Yes | Predicates: No (All) | Valid: 126 | Discarded: 42
# Bag_5 | Samples: Yes | Predicates: No (All) | Valid: 127 | Discarded: 41
# Bag_6 | Samples: Yes | Predicates: No (All) | Valid: 126 | Discarded: 42
# Bag_7 | Samples: Yes | Predicates: No (All) | Valid: 126 | Discarded: 42
# Bag_8 | Samples: Yes | Predicates: No (All) | Valid: 126 | Discarded: 42
# Bag_9 | Samples: Yes | Predicates: No (All) | Valid: 126 | Discarded: 42
# Bag_10 | Samples: Yes | Predicates: No (All) | Valid: 126 | Discarded: 42
# Computing Covariance for Predicates
# Metric: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando semente: 3
# ======================================================================
#
# Bag_1 | Samples: Yes | Predicates: No (All) | Valid: 126 | Discarded: 42
# Bag_2 | Samples: Yes | Predicates: No (All) | Valid: 126 | Discarded: 42
# Bag_3 | Samples: Yes | Predicates: No (All) | Valid: 126 | Discarded: 42
# Bag_4 | Samples: Yes | Predicates: No (All) | Valid: 126 | Discarded: 42
# Bag_5 | Samples: Yes | Predicates: No (All) | Valid: 126 | Discarded: 42
# Bag_6 | Samples: Yes | Predicates: No (All) | Valid: 126 | Discarded: 42
# Bag_7 | Samples: Yes | Predicates: No (All) | Valid: 126 | Discarded: 42
# Bag_8 | Samples: Yes | Predicates: No (All) | Valid: 128 | Discarded: 40
# Bag_9 | Samples: Yes | Predicates: No (All) | Valid: 127 | Discarded: 41
# Bag_10 | Samples: Yes | Predicates: No (All) | Valid: 126 | Discarded: 42
# Computing Covariance for Predicates
# Metric: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando Grafo - Semente: 0
# ======================================================================
#
#
# Total bidirectional pairs found: 109
# Removed: Si > -1.67 -> Si > -2.51 (3.8451) | Kept: Si > -2.51 -> Si > -1.67 (5.1906)
# Removed: Si > -2.51 -> Ca ka <= 3.95 (2.5972) | Kept: Ca ka <= 3.95 -> Si > -2.51 (4.8589)
# Removed: K > -6.69 -> Si > -2.51 (1.3607) | Kept: Si > -2.51 -> K > -6.69 (2.5819)
# Removed: Ca ka <= 3.95 -> Si > -1.67 (2.3150) | Kept: Si > -1.67 -> Ca ka <= 3.95 (2.5709)
# Removed: Si > -1.67 -> K > -6.69 (1.2759) | Kept: K > -6.69 -> Si > -1.67 (3.8829)
# Removed: K > -6.69 -> Ca ka <= 3.95 (2.7446) | Kept: Ca ka <= 3.95 -> K > -6.69 (4.7085)
# Removed: Ca ka <= 1.77 -> K <= 6.26 (3.0395) | Kept: K <= 6.26 -> Ca ka <= 1.77 (4.3843)
# Removed: K > -1.46 -> K <= 6.26 (1.9650) | Kept: K <= 6.26 -> K > -1.46 (4.0215)
# Removed: Si > -0.72 -> K > -1.46 (1.6605) | Kept: K > -1.46 -> Si > -0.72 (4.5521)
# Removed: Si > -0.72 -> K <= 6.26 (0.9581) | Kept: K <= 6.26 -> Si > -0.72 (1.8459)
# Removed: Ca ka <= -1.50 -> Ca ka > -4.65 (1.0040) | Kept: Ca ka > -4.65 -> Ca ka <= -1.50 (1.5737)
# Removed: Ca kb <= 1.58 -> Ca ka <= -1.50 (0.5047) | Kept: Ca ka <= -1.50 -> Ca kb <= 1.58 (0.9951)
# Removed: Fe kb > -0.91 -> Ca ka <= -1.50 (0.4991) | Kept: Ca ka <= -1.50 -> Fe kb > -0.91 (0.5019)
# Removed: Ca ka <= -1.50 -> Ti ka > -0.70 (0.5201) | Kept: Ti ka > -0.70 -> Ca ka <= -1.50 (2.2444)
# Removed: Ca kb <= 1.58 -> Fe kb > -0.91 (0.4936) | Kept: Fe kb > -0.91 -> Ca kb <= 1.58 (1.0403)
# Removed: Ca kb <= 1.58 -> Rh L + Ar > -0.16 (0.5496) | Kept: Rh L + Ar > -0.16 -> Ca kb <= 1.58 (1.0416)
# Removed: Ca kb <= 1.58 -> Ti ka > -0.86 (0.5437) | Kept: Ti ka > -0.86 -> Ca kb <= 1.58 (0.5639)
# Removed: Ti ka > -0.70 -> Rh L + Ar > -0.16 (0.5483) | Kept: Rh L + Ar > -0.16 -> Ti ka > -0.70 (0.6238)
# Removed: Rh L + Ar > -0.77 -> Ti ka > -0.70 (0.5385) | Kept: Ti ka > -0.70 -> Rh L + Ar > -0.77 (0.5952)
# Removed: Ti ka > -0.86 -> Fe kb > -0.63 (1.6239) | Kept: Fe kb > -0.63 -> Ti ka > -0.86 (2.1351)
# Removed: Fe kb > -0.44 -> Ti ka > -0.86 (0.4990) | Kept: Ti ka > -0.86 -> Fe kb > -0.44 (0.5627)
# Removed: Rh L + Ar > -0.16 -> Rh L + Ar > -0.77 (0.5374) | Kept: Rh L + Ar > -0.77 -> Rh L + Ar > -0.16 (1.1482)
# Removed: Fe kb > -0.91 -> Rh L + Ar > -0.77 (0.4327) | Kept: Rh L + Ar > -0.77 -> Fe kb > -0.91 (0.4363)
# Removed: Fe kb > -0.44 -> Fe kb > -0.91 (0.4617) | Kept: Fe kb > -0.91 -> Fe kb > -0.44 (0.9564)
# Removed: Rh L + Ar > -0.77 -> Ca kb <= 0.62 (0.4372) | Kept: Ca kb <= 0.62 -> Rh L + Ar > -0.77 (0.4538)
# Removed: Ti ka > -0.52 -> Fe kb > -0.44 (0.9370) | Kept: Fe kb > -0.44 -> Ti ka > -0.52 (1.4446)
# Removed: K <= 2.15 -> Ti ka > -0.52 (0.4691) | Kept: Ti ka > -0.52 -> K <= 2.15 (0.4819)
# Removed: Rh L + Ar > -1.66 -> Ti ka > -0.52 (0.4491) | Kept: Ti ka > -0.52 -> Rh L + Ar > -1.66 (0.4514)
# Removed: background4 > 0.14 -> Rh L + Ar > -1.66 (0.3373) | Kept: Rh L + Ar > -1.66 -> background4 > 0.14 (1.4515)
# Removed: Fe kb > -0.44 -> Rh L + Ar > -1.66 (0.3731) | Kept: Rh L + Ar > -1.66 -> Fe kb > -0.44 (0.4403)
# Removed: background4 > -0.62 -> K <= 2.15 (0.2152) | Kept: K <= 2.15 -> background4 > -0.62 (1.0475)
# Removed: Fe ka <= 1.10 -> background4 > -0.62 (0.3002) | Kept: background4 > -0.62 -> Fe ka <= 1.10 (0.5429)
# Removed: Ca kb > -1.81 -> Fe ka <= 1.10 (0.2306) | Kept: Fe ka <= 1.10 -> Ca kb > -1.81 (0.4645)
# Removed: Compton scattering > 0.05 -> Fe ka <= 1.10 (0.2608) | Kept: Fe ka <= 1.10 -> Compton scattering > 0.05 (0.7936)
# Removed: background4 > -1.28 -> Fe ka <= 1.10 (0.2538) | Kept: Fe ka <= 1.10 -> background4 > -1.28 (0.2907)
# Removed: background4 > -0.62 -> K > 2.15 (0.2605) | Kept: K > 2.15 -> background4 > -0.62 (0.3551)
# Removed: Compton scattering > 0.05 -> background4 > -0.62 (0.4425) | Kept: background4 > -0.62 -> Compton scattering > 0.05 (0.4835)
# Removed: Rayleight scattering > 0.03 -> K > 2.15 (0.1643) | Kept: K > 2.15 -> Rayleight scattering > 0.03 (0.2229)
# Removed: K > 2.15 -> Ca kb <= -0.59 (0.2672) | Kept: Ca kb <= -0.59 -> K > 2.15 (0.4635)
# Removed: Compton scattering > -0.40 -> Compton scattering > 0.05 (0.2365) | Kept: Compton scattering > 0.05 -> Compton scattering > -0.40 (0.5622)
# Removed: Compton scattering > 0.05 -> Ca kb > -1.81 (0.2375) | Kept: Ca kb > -1.81 -> Compton scattering > 0.05 (0.2475)
# Removed: Compton scattering > -0.40 -> Ca kb <= -0.59 (0.4533) | Kept: Ca kb <= -0.59 -> Compton scattering > -0.40 (0.5041)
# Removed: Ca kb > -1.81 -> Ca kb <= -0.59 (0.2577) | Kept: Ca kb <= -0.59 -> Ca kb > -1.81 (0.4758)
# Removed: Ca kb > -1.81 -> Compton scattering > -0.40 (0.2417) | Kept: Compton scattering > -0.40 -> Ca kb > -1.81 (0.6160)
# Removed: Ca kb > -1.81 -> background4 > -1.28 (0.2271) | Kept: background4 > -1.28 -> Ca kb > -1.81 (0.4613)
# Removed: Rayleight scattering > 0.03 -> background4 > -1.28 (0.1692) | Kept: background4 > -1.28 -> Rayleight scattering > 0.03 (0.3400)
# Removed: Rayleight scattering > 0.03 -> Compton scattering > -0.88 (0.1688) | Kept: Compton scattering > -0.88 -> Rayleight scattering > 0.03 (0.4839)
# Removed: Rayleight scattering > 0.03 -> Rayleight scattering > -0.25 (0.1164) | Kept: Rayleight scattering > -0.25 -> Rayleight scattering > 0.03 (0.1580)
# Removed: Al > -0.68 -> Rayleight scattering > 0.03 (0.1293) | Kept: Rayleight scattering > 0.03 -> Al > -0.68 (0.4148)
# Removed: sum Fe > -0.28 -> Rayleight scattering > 0.03 (0.3117) | Kept: Rayleight scattering > 0.03 -> sum Fe > -0.28 (0.3123)
# Removed: Compton scattering > -0.88 -> sum Fe > -0.28 (0.1610) | Kept: sum Fe > -0.28 -> Compton scattering > -0.88 (0.2633)
# Removed: Compton scattering > -0.88 -> Al > -0.68 (0.1370) | Kept: Al > -0.68 -> Compton scattering > -0.88 (0.1432)
# Removed: sum Fe > -0.28 -> Rayleight scattering > -0.25 (0.1598) | Kept: Rayleight scattering > -0.25 -> sum Fe > -0.28 (0.2464)
# Removed: sum Fe > -0.28 -> sum Fe > 0.07 (0.1659) | Kept: sum Fe > 0.07 -> sum Fe > -0.28 (0.4525)
# Removed: sum Fe > 0.07 -> Rayleight scattering > -0.25 (0.3097) | Kept: Rayleight scattering > -0.25 -> sum Fe > 0.07 (0.4192)
# Removed: sum Fe > 0.07 -> Al > -0.68 (0.1485) | Kept: Al > -0.68 -> sum Fe > 0.07 (0.2941)
# Removed: Rayleight scattering > -0.50 -> Al > -0.68 (0.1387) | Kept: Al > -0.68 -> Rayleight scattering > -0.50 (0.2939)
# Removed: Rayleight scattering > -0.50 -> Ti kb > -0.32 (0.0957) | Kept: Ti kb > -0.32 -> Rayleight scattering > -0.50 (0.0960)
# Removed: K <= -1.46 -> Al > -0.19 (0.1263) | Kept: Al > -0.19 -> K <= -1.46 (0.2379)
# Removed: Ti kb > -0.14 -> K <= -1.46 (0.0877) | Kept: K <= -1.46 -> Ti kb > -0.14 (0.1060)
# Removed: Al > -0.19 -> sum Fe > -0.60 (0.1136) | Kept: sum Fe > -0.60 -> Al > -0.19 (0.4485)
# Removed: Ti kb > -0.14 -> Al > -0.19 (0.0856) | Kept: Al > -0.19 -> Ti kb > -0.14 (0.2045)
# Removed: Ti kb > -0.32 -> Al > -0.19 (0.1949) | Kept: Al > -0.19 -> Ti kb > -0.32 (0.2436)
# Removed: Ti kb > -0.32 -> sum Fe > -0.60 (0.0735) | Kept: sum Fe > -0.60 -> Ti kb > -0.32 (0.2506)
# Removed: Ti kb > -0.32 -> Al <= 0.62 (0.0824) | Kept: Al <= 0.62 -> Ti kb > -0.32 (0.1875)
# Removed: Mn > 0.23 -> Al <= 0.62 (0.0958) | Kept: Al <= 0.62 -> Mn > 0.23 (0.1967)
# Removed: Ti kb > -0.32 -> P > -1.23 (0.0791) | Kept: P > -1.23 -> Ti kb > -0.32 (0.1384)
# Removed: P > 0.08 -> P > -1.23 (0.0421) | Kept: P > -1.23 -> P > 0.08 (0.2662)
# Removed: P <= -0.59 -> P > 0.08 (0.0490) | Kept: P > 0.08 -> P <= -0.59 (0.0716)
# Removed: Mn <= 1.01 -> Ti ka <= 0.53 (0.0669) | Kept: Ti ka <= 0.53 -> Mn <= 1.01 (0.1379)
# Removed: Ca ka > -1.50 -> Ti ka <= 0.53 (0.0497) | Kept: Ti ka <= 0.53 -> Ca ka > -1.50 (0.0599)
# Removed: Ti kb > 0.03 -> background3 > -1.50 (0.0681) | Kept: background3 > -1.50 -> Ti kb > 0.03 (0.0864)
# Removed: Fe kb <= 0.33 -> Mn <= 1.01 (0.0307) | Kept: Mn <= 1.01 -> Fe kb <= 0.33 (0.0547)
# Removed: sum Fe <= -0.28 -> Fe kb <= 0.33 (0.0387) | Kept: Fe kb <= 0.33 -> sum Fe <= -0.28 (0.0450)
# Removed: P <= 0.08 -> Fe kb <= 0.33 (0.0309) | Kept: Fe kb <= 0.33 -> P <= 0.08 (0.0396)
# Removed: Ni > -0.14 -> Fe kb <= 0.33 (0.0411) | Kept: Fe kb <= 0.33 -> Ni > -0.14 (0.0553)
# Removed: P <= 0.08 -> Compton scattering <= -0.40 (0.0396) | Kept: Compton scattering <= -0.40 -> P <= 0.08 (0.0398)
# Removed: Ni <= 0.13 -> P <= 0.08 (0.0477) | Kept: P <= 0.08 -> Ni <= 0.13 (0.0653)
# Removed: Mn <= 1.01 -> S <= 0.55 (0.0612) | Kept: S <= 0.55 -> Mn <= 1.01 (0.0638)
# Removed: Ni <= 0.13 -> sum Fe <= -0.28 (0.0127) | Kept: sum Fe <= -0.28 -> Ni <= 0.13 (0.0574)
# Removed: Ni > -0.14 -> sum Fe <= -0.28 (0.0294) | Kept: sum Fe <= -0.28 -> Ni > -0.14 (0.0474)
# Removed: Ni > -0.14 -> S <= 0.55 (0.0345) | Kept: S <= 0.55 -> Ni > -0.14 (0.0473)
# Removed: S <= 0.09 -> Ni > -0.14 (0.0426) | Kept: Ni > -0.14 -> S <= 0.09 (0.0829)
# Removed: Ni <= 0.13 -> Ni > -0.14 (0.0295) | Kept: Ni > -0.14 -> Ni <= 0.13 (0.0411)
# Removed: S > 0.09 -> P <= 1.06 (0.0171) | Kept: P <= 1.06 -> S > 0.09 (0.0356)
# Removed: background3 > -0.49 -> Rh L + Ar <= -0.77 (0.0183) | Kept: Rh L + Ar <= -0.77 -> background3 > -0.49 (0.0456)
# Removed: Ni <= 0.13 -> S <= 0.55 (0.0493) | Kept: S <= 0.55 -> Ni <= 0.13 (0.2190)
# Removed: S <= -0.27 -> S <= 0.55 (0.0364) | Kept: S <= 0.55 -> S <= -0.27 (0.0541)
# Removed: S <= 0.09 -> Compton scattering <= -0.40 (0.0435) | Kept: Compton scattering <= -0.40 -> S <= 0.09 (0.0667)
# Removed: background4 <= 0.14 -> Compton scattering <= -0.40 (0.0278) | Kept: Compton scattering <= -0.40 -> background4 <= 0.14 (0.0366)
# Removed: background2 > 0.11 -> Ti kb <= 0.20 (0.0187) | Kept: Ti kb <= 0.20 -> background2 > 0.11 (0.0260)
# Removed: Ti kb <= 0.20 -> Mn > -1.22 (0.0188) | Kept: Mn > -1.22 -> Ti kb <= 0.20 (0.0195)
# Removed: Ti kb <= 0.20 -> Ca kb > -0.59 (0.0180) | Kept: Ca kb > -0.59 -> Ti kb <= 0.20 (0.0204)
# Removed: Al <= 0.19 -> background3 <= 1.60 (0.0103) | Kept: background3 <= 1.60 -> Al <= 0.19 (0.0180)
# Removed: background3 <= 1.60 -> sum Fe <= 0.07 (0.0114) | Kept: sum Fe <= 0.07 -> background3 <= 1.60 (0.0193)
# Removed: Rayleight scattering <= -0.25 -> Ca kb > -0.59 (0.0180) | Kept: Ca kb > -0.59 -> Rayleight scattering <= -0.25 (0.0196)
# Removed: Mn <= -0.41 -> Al > 0.19 (0.0137) | Kept: Al > 0.19 -> Mn <= -0.41 (0.0194)
# Removed: Rh L + Ar <= -0.77 -> Al > 0.19 (0.0402) | Kept: Al > 0.19 -> Rh L + Ar <= -0.77 (0.0426)
# Removed: Ni > 0.13 -> Ni > -0.60 (0.0168) | Kept: Ni > -0.60 -> Ni > 0.13 (0.0224)
# Removed: Ni > -0.60 -> S > 0.09 (0.0162) | Kept: S > 0.09 -> Ni > -0.60 (0.0336)
# Removed: Rh L + Ar <= -0.16 -> Ni > 0.13 (0.0112) | Kept: Ni > 0.13 -> Rh L + Ar <= -0.16 (0.0159)
# Removed: Ni > 0.13 -> Al <= 0.19 (0.0090) | Kept: Al <= 0.19 -> Ni > 0.13 (0.0398)
# Removed: background2 <= 0.30 -> Ni <= 0.59 (0.0160) | Kept: Ni <= 0.59 -> background2 <= 0.30 (0.0563)
# Removed: background2 <= -0.08 -> Al <= 0.19 (0.0136) | Kept: Al <= 0.19 -> background2 <= -0.08 (0.0310)
# Removed: Ni <= -0.14 -> background2 <= -0.08 (0.0123) | Kept: background2 <= -0.08 -> Ni <= -0.14 (0.0282)
# Removed: background2 <= 0.11 -> Al <= -0.19 (0.0096) | Kept: Al <= -0.19 -> background2 <= 0.11 (0.0240)
# Removed: background1 > -0.14 -> Mn <= 0.23 (0.0083) | Kept: Mn <= 0.23 -> background1 > -0.14 (0.0137)
# Removed: background1 > -0.14 -> sum Fe <= 0.07 (0.0066) | Kept: sum Fe <= 0.07 -> background1 > -0.14 (0.0138)
# Removed: sum Fe <= 0.07 -> Ti kb <= 0.03 (0.0103) | Kept: Ti kb <= 0.03 -> sum Fe <= 0.07 (0.0122)
#
# ======================================================================
# CONSTRUCTED GRAPH SUMMARY
# ======================================================================
# Initial edges: 778 | Removed: 109
# Predicate nodes: 114
# Metric: Covariance
# Weighting by explained variance: ENABLED
#
# ======================================================================
# Processando Grafo - Semente: 1
# ======================================================================
#
#
# Total bidirectional pairs found: 117
# Removed: Fe ka > -2.26 -> Fe ka > -3.74 (2.4687) | Kept: Fe ka > -3.74 -> Fe ka > -2.26 (21.5291)
# Removed: Si > -2.51 -> Ca ka <= 3.95 (1.2872) | Kept: Ca ka <= 3.95 -> Si > -2.51 (4.8221)
# Removed: Ca ka <= 3.95 -> K > -6.69 (2.4115) | Kept: K > -6.69 -> Ca ka <= 3.95 (4.1608)
# Removed: Si > -1.67 -> Si > -2.51 (3.8358) | Kept: Si > -2.51 -> Si > -1.67 (7.7187)
# Removed: K > -6.69 -> Si > -1.67 (1.3166) | Kept: Si > -1.67 -> K > -6.69 (3.7803)
# Removed: Si > -2.51 -> K > -6.69 (1.2359) | Kept: K > -6.69 -> Si > -2.51 (3.7917)
# Removed: K <= 6.26 -> Ca ka <= 1.77 (1.1521) | Kept: Ca ka <= 1.77 -> K <= 6.26 (6.8897)
# Removed: K > -1.46 -> K <= 6.26 (1.8937) | Kept: K <= 6.26 -> K > -1.46 (3.8266)
# Removed: Si > -0.72 -> K > -1.46 (3.6110) | Kept: K > -1.46 -> Si > -0.72 (4.3841)
# Removed: Ca ka <= -1.50 -> Ca ka > -4.65 (0.5022) | Kept: Ca ka > -4.65 -> Ca ka <= -1.50 (1.0605)
# Removed: Ti ka > -0.70 -> Ca ka > -4.65 (0.5781) | Kept: Ca ka > -4.65 -> Ti ka > -0.70 (1.7053)
# Removed: Rh L + Ar > -0.16 -> Rh L + Ar > -0.77 (0.9475) | Kept: Rh L + Ar > -0.77 -> Rh L + Ar > -0.16 (1.3656)
# Removed: Rh L + Ar > -0.16 -> Ca kb <= 0.62 (0.4860) | Kept: Ca kb <= 0.62 -> Rh L + Ar > -0.16 (0.8893)
# Removed: Ca kb <= 1.58 -> Rh L + Ar > -0.77 (0.5484) | Kept: Rh L + Ar > -0.77 -> Ca kb <= 1.58 (1.0652)
# Removed: Fe kb > -0.91 -> Rh L + Ar > -0.77 (0.4355) | Kept: Rh L + Ar > -0.77 -> Fe kb > -0.91 (0.5346)
# Removed: Ca kb <= 0.62 -> Rh L + Ar > -0.77 (0.4458) | Kept: Rh L + Ar > -0.77 -> Ca kb <= 0.62 (0.8692)
# Removed: Rh L + Ar > -0.77 -> Ti ka > -0.52 (0.3974) | Kept: Ti ka > -0.52 -> Rh L + Ar > -0.77 (0.9672)
# Removed: Rh L + Ar > -0.77 -> background4 > 0.14 (0.3445) | Kept: background4 > 0.14 -> Rh L + Ar > -0.77 (0.3460)
# Removed: Ca ka <= -1.50 -> Ca kb <= 1.58 (0.5041) | Kept: Ca kb <= 1.58 -> Ca ka <= -1.50 (1.0627)
# Removed: Ca kb <= 1.58 -> Ti ka > -0.52 (0.5194) | Kept: Ti ka > -0.52 -> Ca kb <= 1.58 (1.0737)
# Removed: Fe kb > -0.44 -> Ca kb <= 1.58 (0.5116) | Kept: Ca kb <= 1.58 -> Fe kb > -0.44 (1.0448)
# Removed: Ca ka <= -1.50 -> Ti ka > -0.70 (0.4751) | Kept: Ti ka > -0.70 -> Ca ka <= -1.50 (0.6124)
# Removed: Fe kb > -0.63 -> Ca ka <= -1.50 (0.5653) | Kept: Ca ka <= -1.50 -> Fe kb > -0.63 (1.0596)
# Removed: Ca ka <= -1.50 -> Fe kb > -0.91 (0.5367) | Kept: Fe kb > -0.91 -> Ca ka <= -1.50 (0.5372)
# Removed: Ca ka <= -1.50 -> Ti ka > -0.86 (0.5221) | Kept: Ti ka > -0.86 -> Ca ka <= -1.50 (0.5950)
# Removed: Ti ka > -0.70 -> Si <= 3.71 (0.4981) | Kept: Si <= 3.71 -> Ti ka > -0.70 (0.5870)
# Removed: Ca kb <= 0.62 -> Si <= 3.71 (0.4409) | Kept: Si <= 3.71 -> Ca kb <= 0.62 (0.9356)
# Removed: Rh L + Ar > -1.66 -> Ca kb <= 0.62 (0.4549) | Kept: Ca kb <= 0.62 -> Rh L + Ar > -1.66 (0.8926)
# Removed: K <= 2.15 -> Rh L + Ar > -1.66 (0.2676) | Kept: Rh L + Ar > -1.66 -> K <= 2.15 (0.4178)
# Removed: Ti ka > -0.86 -> Fe kb > -0.63 (1.5201) | Kept: Fe kb > -0.63 -> Ti ka > -0.86 (2.1992)
# Removed: Fe kb > -0.91 -> Fe kb > -0.63 (0.5430) | Kept: Fe kb > -0.63 -> Fe kb > -0.91 (0.9978)
# Removed: Ti ka > -0.52 -> Fe kb > -0.91 (0.4433) | Kept: Fe kb > -0.91 -> Ti ka > -0.52 (0.5217)
# Removed: Ti ka > -0.52 -> Fe kb > -0.44 (0.4880) | Kept: Fe kb > -0.44 -> Ti ka > -0.52 (1.3884)
# Removed: Fe kb > -0.44 -> Fe kb > -0.91 (0.5338) | Kept: Fe kb > -0.91 -> Fe kb > -0.44 (1.0720)
# Removed: Ca kb <= 0.62 -> Fe kb > -0.44 (0.4239) | Kept: Fe kb > -0.44 -> Ca kb <= 0.62 (0.4677)
# Removed: Fe kb > -0.44 -> K <= 2.15 (0.3751) | Kept: K <= 2.15 -> Fe kb > -0.44 (0.3869)
# Removed: background4 > 0.14 -> K <= 2.15 (0.9369) | Kept: K <= 2.15 -> background4 > 0.14 (1.1252)
# Removed: background4 > -0.62 -> K <= 2.15 (0.2668) | Kept: K <= 2.15 -> background4 > -0.62 (0.3278)
# Removed: K <= 2.15 -> K > 2.15 (0.2696) | Kept: K > 2.15 -> K <= 2.15 (0.3433)
# Removed: background4 > 0.14 -> K > 2.15 (0.3307) | Kept: K > 2.15 -> background4 > 0.14 (0.4407)
# Removed: background4 > -0.62 -> Fe ka <= 1.10 (0.2611) | Kept: Fe ka <= 1.10 -> background4 > -0.62 (0.2773)
# Removed: Compton scattering > 0.05 -> Fe ka <= 1.10 (0.2245) | Kept: Fe ka <= 1.10 -> Compton scattering > 0.05 (0.2418)
# Removed: Fe ka <= 1.10 -> Compton scattering > -0.40 (0.2330) | Kept: Compton scattering > -0.40 -> Fe ka <= 1.10 (0.6752)
# Removed: Ca kb <= -0.59 -> Fe ka <= 1.10 (0.2454) | Kept: Fe ka <= 1.10 -> Ca kb <= -0.59 (0.2908)
# Removed: Ca kb <= -0.59 -> Ca kb > -1.81 (0.2457) | Kept: Ca kb > -1.81 -> Ca kb <= -0.59 (0.5034)
# Removed: Compton scattering > -0.88 -> Ca kb > -1.81 (0.1865) | Kept: Ca kb > -1.81 -> Compton scattering > -0.88 (0.3977)
# Removed: Compton scattering > -0.40 -> Ca kb > -1.81 (0.1920) | Kept: Ca kb > -1.81 -> Compton scattering > -0.40 (0.4618)
# Removed: Compton scattering > 0.05 -> Ca kb > -1.81 (0.2017) | Kept: Ca kb > -1.81 -> Compton scattering > 0.05 (0.2380)
# Removed: Compton scattering > 0.05 -> Ca kb <= -0.59 (0.4395) | Kept: Ca kb <= -0.59 -> Compton scattering > 0.05 (0.4799)
# Removed: Ca kb <= -0.59 -> K > 2.15 (0.2428) | Kept: K > 2.15 -> Ca kb <= -0.59 (0.2494)
# Removed: Ca kb <= -0.59 -> background4 > -1.28 (0.2044) | Kept: background4 > -1.28 -> Ca kb <= -0.59 (0.2323)
# Removed: background4 > -0.62 -> Ca kb <= -0.59 (0.2312) | Kept: Ca kb <= -0.59 -> background4 > -0.62 (0.2391)
# Removed: Compton scattering > 0.05 -> background4 > -0.62 (0.3846) | Kept: background4 > -0.62 -> Compton scattering > 0.05 (1.2228)
# Removed: Compton scattering > -0.40 -> Compton scattering > 0.05 (0.2203) | Kept: Compton scattering > 0.05 -> Compton scattering > -0.40 (0.2281)
# Removed: background4 > -1.28 -> Compton scattering > -0.40 (0.2017) | Kept: Compton scattering > -0.40 -> background4 > -1.28 (0.5159)
# Removed: sum Fe > -0.28 -> background4 > -1.28 (0.1329) | Kept: background4 > -1.28 -> sum Fe > -0.28 (0.1698)
# Removed: Rayleight scattering > 0.03 -> Compton scattering > -0.88 (0.4268) | Kept: Compton scattering > -0.88 -> Rayleight scattering > 0.03 (0.6767)
# Removed: Rayleight scattering > 0.03 -> sum Fe > -0.28 (0.2838) | Kept: sum Fe > -0.28 -> Rayleight scattering > 0.03 (0.3332)
# Removed: Al > -0.68 -> Rayleight scattering > 0.03 (0.1447) | Kept: Rayleight scattering > 0.03 -> Al > -0.68 (0.2699)
# Removed: Rayleight scattering > 0.03 -> sum Fe > 0.07 (0.1407) | Kept: sum Fe > 0.07 -> Rayleight scattering > 0.03 (0.2989)
# Removed: Al > -0.68 -> sum Fe > -0.28 (0.1409) | Kept: sum Fe > -0.28 -> Al > -0.68 (0.4390)
# Removed: sum Fe > -0.28 -> Rayleight scattering > -0.25 (0.1199) | Kept: Rayleight scattering > -0.25 -> sum Fe > -0.28 (0.2837)
# Removed: sum Fe > 0.07 -> Al > -0.68 (0.1442) | Kept: Al > -0.68 -> sum Fe > 0.07 (0.2851)
# Removed: Rayleight scattering > -0.25 -> Al > -0.68 (0.2547) | Kept: Al > -0.68 -> Rayleight scattering > -0.25 (0.3046)
# Removed: Al > -0.19 -> sum Fe > 0.07 (0.1129) | Kept: sum Fe > 0.07 -> Al > -0.19 (0.1150)
# Removed: Rayleight scattering > -0.25 -> sum Fe > 0.07 (0.1385) | Kept: sum Fe > 0.07 -> Rayleight scattering > -0.25 (0.2930)
# Removed: Rayleight scattering > -0.50 -> sum Fe > 0.07 (0.1131) | Kept: sum Fe > 0.07 -> Rayleight scattering > -0.50 (0.1341)
# Removed: Rayleight scattering > -0.25 -> sum Fe > -0.60 (0.1255) | Kept: sum Fe > -0.60 -> Rayleight scattering > -0.25 (0.1445)
# Removed: Rayleight scattering > -0.50 -> Al > -0.19 (0.1087) | Kept: Al > -0.19 -> Rayleight scattering > -0.50 (0.1098)
# Removed: Ti kb > -0.32 -> Al > -0.19 (0.1985) | Kept: Al > -0.19 -> Ti kb > -0.32 (0.2386)
# Removed: P > -1.23 -> Al > -0.19 (0.1299) | Kept: Al > -0.19 -> P > -1.23 (0.2355)
# Removed: sum Fe > -0.60 -> Rayleight scattering > -0.50 (0.3274) | Kept: Rayleight scattering > -0.50 -> sum Fe > -0.60 (0.3346)
# Removed: Ti kb > -0.14 -> Rayleight scattering > -0.50 (0.0860) | Kept: Rayleight scattering > -0.50 -> Ti kb > -0.14 (0.1876)
# Removed: Ti kb > -0.32 -> Rayleight scattering > -0.50 (0.0962) | Kept: Rayleight scattering > -0.50 -> Ti kb > -0.32 (0.1142)
# Removed: background3 > 0.36 -> Al <= 0.62 (0.0788) | Kept: Al <= 0.62 -> background3 > 0.36 (0.0877)
# Removed: background3 <= -0.49 -> P > 0.08 (0.0551) | Kept: P > 0.08 -> background3 <= -0.49 (0.0962)
# Removed: P > -0.59 -> P > 0.08 (0.0511) | Kept: P > 0.08 -> P > -0.59 (0.0946)
# Removed: P > 0.08 -> Ti ka <= 0.53 (0.0504) | Kept: Ti ka <= 0.53 -> P > 0.08 (0.0782)
# Removed: Ti kb > -0.14 -> background3 > 0.36 (0.0911) | Kept: background3 > 0.36 -> Ti kb > -0.14 (0.0986)
# Removed: Ti ka <= 0.53 -> Ti kb > 0.03 (0.0774) | Kept: Ti kb > 0.03 -> Ti ka <= 0.53 (0.1293)
# Removed: background4 <= -0.62 -> Ti ka <= 0.53 (0.0677) | Kept: Ti ka <= 0.53 -> background4 <= -0.62 (0.0752)
# Removed: P <= 1.06 -> S > 0.09 (0.0102) | Kept: S > 0.09 -> P <= 1.06 (0.0255)
# Removed: P <= 0.08 -> S <= -0.27 (0.0415) | Kept: S <= -0.27 -> P <= 0.08 (0.0543)
# Removed: S <= -0.27 -> Mn <= 1.01 (0.0590) | Kept: Mn <= 1.01 -> S <= -0.27 (0.1087)
# Removed: Ti kb <= 0.20 -> P <= 0.08 (0.0285) | Kept: P <= 0.08 -> Ti kb <= 0.20 (0.0338)
# Removed: P <= -0.59 -> P <= 0.08 (0.0484) | Kept: P <= 0.08 -> P <= -0.59 (0.1891)
# Removed: P <= 0.08 -> S <= 0.55 (0.0516) | Kept: S <= 0.55 -> P <= 0.08 (0.0553)
# Removed: Ca ka > -1.50 -> sum Fe <= -0.28 (0.0474) | Kept: sum Fe <= -0.28 -> Ca ka > -1.50 (0.0512)
# Removed: background3 <= 0.36 -> P > -0.59 (0.0466) | Kept: P > -0.59 -> background3 <= 0.36 (0.0911)
# Removed: P > -0.59 -> Fe kb <= 0.33 (0.0445) | Kept: Fe kb <= 0.33 -> P > -0.59 (0.0491)
# Removed: background4 <= 0.14 -> P > -0.59 (0.0455) | Kept: P > -0.59 -> background4 <= 0.14 (0.0466)
# Removed: Ni > -0.14 -> S <= 0.09 (0.0290) | Kept: S <= 0.09 -> Ni > -0.14 (0.0679)
# Removed: S <= 0.55 -> Rh L + Ar <= -0.77 (0.0385) | Kept: Rh L + Ar <= -0.77 -> S <= 0.55 (0.0638)
# Removed: P <= -0.59 -> Fe kb <= 0.33 (0.0494) | Kept: Fe kb <= 0.33 -> P <= -0.59 (0.0509)
# Removed: background4 <= 0.14 -> Ni > -0.60 (0.0190) | Kept: Ni > -0.60 -> background4 <= 0.14 (0.0250)
# Removed: Ni > -0.14 -> Compton scattering <= -0.40 (0.0294) | Kept: Compton scattering <= -0.40 -> Ni > -0.14 (0.0506)
# Removed: Mn <= 1.01 -> background3 > -0.49 (0.0277) | Kept: background3 > -0.49 -> Mn <= 1.01 (0.1300)
# Removed: Ni <= -0.14 -> Rh L + Ar <= -0.77 (0.0214) | Kept: Rh L + Ar <= -0.77 -> Ni <= -0.14 (0.0394)
# Removed: Al > 0.19 -> Ni <= -0.14 (0.0316) | Kept: Ni <= -0.14 -> Al > 0.19 (0.0471)
# Removed: Ni <= -0.14 -> background2 <= 0.30 (0.0207) | Kept: background2 <= 0.30 -> Ni <= -0.14 (0.0208)
# Removed: background2 > 0.11 -> Mn > -0.41 (0.0144) | Kept: Mn > -0.41 -> background2 > 0.11 (0.0232)
# Removed: background2 <= -0.08 -> Mn > -0.41 (0.0128) | Kept: Mn > -0.41 -> background2 <= -0.08 (0.0248)
# Removed: Mn > -0.41 -> Rayleight scattering <= -0.25 (0.0173) | Kept: Rayleight scattering <= -0.25 -> Mn > -0.41 (0.0233)
# Removed: background3 > -1.50 -> background4 <= -0.62 (0.1068) | Kept: background4 <= -0.62 -> background3 > -1.50 (0.1147)
# Removed: Rayleight scattering <= -0.25 -> Compton scattering <= 0.87 (0.0147) | Kept: Compton scattering <= 0.87 -> Rayleight scattering <= -0.25 (0.0303)
# Removed: background2 > 0.11 -> Rayleight scattering <= -0.25 (0.0148) | Kept: Rayleight scattering <= -0.25 -> background2 > 0.11 (0.0154)
# Removed: background2 <= 0.30 -> Mn <= -0.41 (0.0179) | Kept: Mn <= -0.41 -> background2 <= 0.30 (0.0315)
# Removed: background2 <= 0.30 -> background2 <= -0.08 (0.0156) | Kept: background2 <= -0.08 -> background2 <= 0.30 (0.0185)
# Removed: Al <= 0.19 -> background2 <= -0.08 (0.0106) | Kept: background2 <= -0.08 -> Al <= 0.19 (0.0114)
# Removed: Ca kb > -0.59 -> Mn > -1.22 (0.0198) | Kept: Mn > -1.22 -> Ca kb > -0.59 (0.0200)
# Removed: background2 > -0.08 -> Ni > 0.13 (0.0085) | Kept: Ni > 0.13 -> background2 > -0.08 (0.0129)
# Removed: background2 <= -0.08 -> Rayleight scattering <= -0.25 (0.0127) | Kept: Rayleight scattering <= -0.25 -> background2 <= -0.08 (0.0170)
# Removed: background2 <= -0.08 -> Ni <= 0.59 (0.0173) | Kept: Ni <= 0.59 -> background2 <= -0.08 (0.0218)
# Removed: Rayleight scattering <= -0.25 -> Ni <= 0.59 (0.0143) | Kept: Ni <= 0.59 -> Rayleight scattering <= -0.25 (0.0160)
# Removed: Ni <= 0.59 -> Mn > -1.22 (0.0126) | Kept: Mn > -1.22 -> Ni <= 0.59 (0.0264)
# Removed: background2 > -0.26 -> Ti kb <= 0.03 (0.0087) | Kept: Ti kb <= 0.03 -> background2 > -0.26 (0.0112)
# Removed: sum Fe <= 0.62 -> S > -0.27 (0.0091) | Kept: S > -0.27 -> sum Fe <= 0.62 (0.0117)
#
# ======================================================================
# CONSTRUCTED GRAPH SUMMARY
# ======================================================================
# Initial edges: 750 | Removed: 117
# Predicate nodes: 113
# Metric: Covariance
# Weighting by explained variance: ENABLED
#
# ======================================================================
# Processando Grafo - Semente: 2
# ======================================================================
#
#
# Total bidirectional pairs found: 105
# Removed: Ca ka <= 3.95 -> K > -6.69 (2.3205) | Kept: K > -6.69 -> Ca ka <= 3.95 (2.7511)
# Removed: Si > -1.67 -> K > -6.69 (2.5391) | Kept: K > -6.69 -> Si > -1.67 (3.8824)
# Removed: K > -6.69 -> Si > -2.51 (1.3403) | Kept: Si > -2.51 -> K > -6.69 (3.8617)
# Removed: Si > -2.51 -> Ca ka <= 3.95 (3.9595) | Kept: Ca ka <= 3.95 -> Si > -2.51 (4.8700)
# Removed: Si > -2.51 -> Si > -1.67 (2.6344) | Kept: Si > -1.67 -> Si > -2.51 (5.0499)
# Removed: K <= 6.26 -> Ca ka <= 1.77 (3.3749) | Kept: Ca ka <= 1.77 -> K <= 6.26 (4.0095)
# Removed: K > -1.46 -> K <= 6.26 (1.9532) | Kept: K <= 6.26 -> K > -1.46 (2.9383)
# Removed: Si > -0.72 -> K <= 6.26 (0.8869) | Kept: K <= 6.26 -> Si > -0.72 (3.9726)
# Removed: Si > -0.72 -> K > -1.46 (2.7411) | Kept: K > -1.46 -> Si > -0.72 (3.5070)
# Removed: Ca ka > -4.65 -> Ca ka <= -1.50 (0.5013) | Kept: Ca ka <= -1.50 -> Ca ka > -4.65 (0.5099)
# Removed: Ca kb <= 1.58 -> Si <= 3.71 (0.5316) | Kept: Si <= 3.71 -> Ca kb <= 1.58 (0.5562)
# Removed: Rh L + Ar > -0.77 -> Si <= 3.71 (0.4694) | Kept: Si <= 3.71 -> Rh L + Ar > -0.77 (1.4421)
# Removed: Rh L + Ar > -0.16 -> Si <= 3.71 (0.4849) | Kept: Si <= 3.71 -> Rh L + Ar > -0.16 (0.4955)
# Removed: Ti ka > -0.52 -> Si <= 3.71 (0.4474) | Kept: Si <= 3.71 -> Ti ka > -0.52 (0.5324)
# Removed: Ca kb <= 0.62 -> Si <= 3.71 (0.4547) | Kept: Si <= 3.71 -> Ca kb <= 0.62 (0.9299)
# Removed: Fe kb > -0.91 -> Si <= 3.71 (0.4717) | Kept: Si <= 3.71 -> Fe kb > -0.91 (0.5744)
# Removed: Ca kb <= 1.58 -> Ti ka > -0.70 (0.5463) | Kept: Ti ka > -0.70 -> Ca kb <= 1.58 (0.5660)
# Removed: Ca kb <= 1.58 -> Ti ka > -0.52 (0.5156) | Kept: Ti ka > -0.52 -> Ca kb <= 1.58 (0.5278)
# Removed: Ca kb <= 1.58 -> Fe kb > -0.91 (0.4932) | Kept: Fe kb > -0.91 -> Ca kb <= 1.58 (1.0463)
# Removed: Ca ka <= -1.50 -> Ti ka > -0.86 (0.4476) | Kept: Ti ka > -0.86 -> Ca ka <= -1.50 (0.5724)
# Removed: Fe kb > -0.63 -> Ca ka <= -1.50 (0.5370) | Kept: Ca ka <= -1.50 -> Fe kb > -0.63 (0.5695)
# Removed: Fe kb > -0.91 -> Ca ka <= -1.50 (0.4823) | Kept: Ca ka <= -1.50 -> Fe kb > -0.91 (0.5164)
# Removed: Fe kb > -0.63 -> Ti ka > -0.86 (1.7219) | Kept: Ti ka > -0.86 -> Fe kb > -0.63 (2.7315)
# Removed: Fe kb > -0.91 -> Fe kb > -0.63 (0.5420) | Kept: Fe kb > -0.63 -> Fe kb > -0.91 (0.5429)
# Removed: Ca kb <= 0.62 -> Ti ka > -0.52 (0.4701) | Kept: Ti ka > -0.52 -> Ca kb <= 0.62 (1.3872)
# Removed: K <= 2.15 -> Ca kb <= 0.62 (0.4566) | Kept: Ca kb <= 0.62 -> K <= 2.15 (0.8511)
# Removed: Ti ka > -0.52 -> Fe kb > -0.91 (0.4564) | Kept: Fe kb > -0.91 -> Ti ka > -0.52 (0.5336)
# Removed: Ti ka > -0.52 -> K <= 2.15 (0.4593) | Kept: K <= 2.15 -> Ti ka > -0.52 (0.4593)
# Removed: Ti ka > -0.52 -> Fe kb > -0.44 (0.5559) | Kept: Fe kb > -0.44 -> Ti ka > -0.52 (0.9335)
# Removed: Fe kb > -0.91 -> Fe kb > -0.44 (1.0160) | Kept: Fe kb > -0.44 -> Fe kb > -0.91 (1.0604)
# Removed: Rh L + Ar > -0.77 -> Fe kb > -0.91 (0.4928) | Kept: Fe kb > -0.91 -> Rh L + Ar > -0.77 (0.5245)
# Removed: Fe kb > -0.44 -> Rh L + Ar > -0.77 (0.4198) | Kept: Rh L + Ar > -0.77 -> Fe kb > -0.44 (0.4312)
# Removed: Rh L + Ar > -0.77 -> Rh L + Ar > -0.16 (1.2605) | Kept: Rh L + Ar > -0.16 -> Rh L + Ar > -0.77 (1.4032)
# Removed: Rh L + Ar > -1.66 -> K <= 2.15 (0.4230) | Kept: K <= 2.15 -> Rh L + Ar > -1.66 (1.1617)
# Removed: background4 > -0.62 -> K <= 2.15 (0.2718) | Kept: K <= 2.15 -> background4 > -0.62 (0.6828)
# Removed: background4 > -0.62 -> K > 2.15 (0.2565) | Kept: K > 2.15 -> background4 > -0.62 (1.0907)
# Removed: Ca kb <= -0.59 -> K > 2.15 (0.2330) | Kept: K > 2.15 -> Ca kb <= -0.59 (0.2387)
# Removed: Compton scattering > 0.05 -> background4 > -0.62 (0.2686) | Kept: background4 > -0.62 -> Compton scattering > 0.05 (0.4540)
# Removed: Ca kb <= -0.59 -> background4 > -0.62 (0.2370) | Kept: background4 > -0.62 -> Ca kb <= -0.59 (0.2638)
# Removed: Compton scattering > 0.05 -> Compton scattering > -0.40 (0.2143) | Kept: Compton scattering > -0.40 -> Compton scattering > 0.05 (0.8412)
# Removed: Compton scattering > 0.05 -> Ca kb <= -0.59 (0.2144) | Kept: Ca kb <= -0.59 -> Compton scattering > 0.05 (0.2407)
# Removed: Compton scattering > 0.05 -> Ca kb > -1.81 (0.2047) | Kept: Ca kb > -1.81 -> Compton scattering > 0.05 (0.2966)
# Removed: Fe ka <= 1.10 -> Ca kb > -1.81 (0.4713) | Kept: Ca kb > -1.81 -> Fe ka <= 1.10 (0.9668)
# Removed: Ca kb <= -0.59 -> Fe ka <= 1.10 (0.2198) | Kept: Fe ka <= 1.10 -> Ca kb <= -0.59 (0.2595)
# Removed: Compton scattering > -0.40 -> Ca kb <= -0.59 (0.4183) | Kept: Ca kb <= -0.59 -> Compton scattering > -0.40 (0.5128)
# Removed: sum Fe > -0.28 -> Rayleight scattering > 0.03 (0.1560) | Kept: Rayleight scattering > 0.03 -> sum Fe > -0.28 (0.6413)
# Removed: Rayleight scattering > -0.25 -> Rayleight scattering > 0.03 (0.1019) | Kept: Rayleight scattering > 0.03 -> Rayleight scattering > -0.25 (0.2957)
# Removed: Rayleight scattering > 0.03 -> Compton scattering > -0.88 (0.1550) | Kept: Compton scattering > -0.88 -> Rayleight scattering > 0.03 (0.3619)
# Removed: Rayleight scattering > -0.25 -> sum Fe > 0.07 (0.1466) | Kept: sum Fe > 0.07 -> Rayleight scattering > -0.25 (0.4320)
# Removed: Compton scattering > -0.88 -> sum Fe > 0.07 (0.1374) | Kept: sum Fe > 0.07 -> Compton scattering > -0.88 (0.1582)
# Removed: Ti kb > -0.32 -> sum Fe > 0.07 (0.0862) | Kept: sum Fe > 0.07 -> Ti kb > -0.32 (0.1210)
# Removed: sum Fe > 0.07 -> Al > -0.68 (0.1208) | Kept: Al > -0.68 -> sum Fe > 0.07 (0.2882)
# Removed: background3 > 0.36 -> Al > -0.68 (0.1386) | Kept: Al > -0.68 -> background3 > 0.36 (0.1418)
# Removed: Compton scattering > -0.88 -> Al > -0.68 (0.1332) | Kept: Al > -0.68 -> Compton scattering > -0.88 (0.1482)
# Removed: Compton scattering > -0.88 -> sum Fe > -0.28 (0.1616) | Kept: sum Fe > -0.28 -> Compton scattering > -0.88 (0.4467)
# Removed: sum Fe > -0.60 -> Al > -0.19 (0.1059) | Kept: Al > -0.19 -> sum Fe > -0.60 (0.1123)
# Removed: Al <= 0.62 -> sum Fe > -0.60 (0.2003) | Kept: sum Fe > -0.60 -> Al <= 0.62 (0.2026)
# Removed: sum Fe > -0.60 -> Ti kb > -0.32 (0.1182) | Kept: Ti kb > -0.32 -> sum Fe > -0.60 (0.1973)
# Removed: Ti kb > -0.14 -> sum Fe > -0.60 (0.0864) | Kept: sum Fe > -0.60 -> Ti kb > -0.14 (0.2204)
# Removed: sum Fe > -0.60 -> Rayleight scattering > -0.50 (0.0890) | Kept: Rayleight scattering > -0.50 -> sum Fe > -0.60 (0.1094)
# Removed: Ti kb > -0.14 -> Al <= 0.62 (0.0841) | Kept: Al <= 0.62 -> Ti kb > -0.14 (0.1849)
# Removed: Al <= 0.62 -> background3 <= -0.49 (0.1024) | Kept: background3 <= -0.49 -> Al <= 0.62 (0.2788)
# Removed: Rayleight scattering > -0.50 -> K <= -1.46 (0.0944) | Kept: K <= -1.46 -> Rayleight scattering > -0.50 (0.4079)
# Removed: Ti kb > -0.32 -> Rayleight scattering > -0.50 (0.0954) | Kept: Rayleight scattering > -0.50 -> Ti kb > -0.32 (0.2206)
# Removed: P > -1.23 -> Rayleight scattering > -0.50 (0.1038) | Kept: Rayleight scattering > -0.50 -> P > -1.23 (0.1115)
# Removed: Ti kb > -0.32 -> K <= -1.46 (0.0935) | Kept: K <= -1.46 -> Ti kb > -0.32 (0.1023)
# Removed: Ti kb > -0.14 -> K <= -1.46 (0.0891) | Kept: K <= -1.46 -> Ti kb > -0.14 (0.1150)
# Removed: Mn > 0.23 -> P > -1.23 (0.1069) | Kept: P > -1.23 -> Mn > 0.23 (0.1688)
# Removed: Ti kb > -0.14 -> background3 <= -0.49 (0.0837) | Kept: background3 <= -0.49 -> Ti kb > -0.14 (0.1712)
# Removed: Ti kb > 0.03 -> background3 <= -0.49 (0.0817) | Kept: background3 <= -0.49 -> Ti kb > 0.03 (0.1447)
# Removed: Mn <= 1.01 -> Ti ka <= 0.53 (0.1319) | Kept: Ti ka <= 0.53 -> Mn <= 1.01 (0.1450)
# Removed: S <= 0.55 -> Ti ka <= 0.53 (0.0608) | Kept: Ti ka <= 0.53 -> S <= 0.55 (0.1336)
# Removed: Mn <= 1.01 -> background3 <= 0.36 (0.0865) | Kept: background3 <= 0.36 -> Mn <= 1.01 (0.1094)
# Removed: Mn > 0.23 -> Ti kb > 0.03 (0.0934) | Kept: Ti kb > 0.03 -> Mn > 0.23 (0.1312)
# Removed: background3 > 0.36 -> Mn > 0.23 (0.0724) | Kept: Mn > 0.23 -> background3 > 0.36 (0.0747)
# Removed: P > -0.59 -> Ni > -0.14 (0.0700) | Kept: Ni > -0.14 -> P > -0.59 (0.0856)
# Removed: Ni > -0.14 -> background4 <= -0.62 (0.0328) | Kept: background4 <= -0.62 -> Ni > -0.14 (0.0397)
# Removed: S <= 0.09 -> background4 <= -0.62 (0.0300) | Kept: background4 <= -0.62 -> S <= 0.09 (0.0537)
# Removed: P <= -0.59 -> background3 <= 0.36 (0.0573) | Kept: background3 <= 0.36 -> P <= -0.59 (0.0982)
# Removed: background3 <= 0.36 -> S <= 0.55 (0.0650) | Kept: S <= 0.55 -> background3 <= 0.36 (0.0656)
# Removed: sum Fe <= -0.28 -> Compton scattering <= -0.40 (0.0539) | Kept: Compton scattering <= -0.40 -> sum Fe <= -0.28 (0.1275)
# Removed: background2 > 0.11 -> background4 <= 1.47 (0.0174) | Kept: background4 <= 1.47 -> background2 > 0.11 (0.0529)
# Removed: S <= 0.09 -> S <= -0.27 (0.0332) | Kept: S <= -0.27 -> S <= 0.09 (0.0457)
# Removed: Ni <= -0.14 -> Rayleight scattering <= -0.25 (0.0157) | Kept: Rayleight scattering <= -0.25 -> Ni <= -0.14 (0.0414)
# Removed: sum Fe <= -0.28 -> background3 > -1.50 (0.0369) | Kept: background3 > -1.50 -> sum Fe <= -0.28 (0.0734)
# Removed: S <= 0.55 -> P <= 1.06 (0.0498) | Kept: P <= 1.06 -> S <= 0.55 (0.0541)
# Removed: Ni > -0.14 -> Ca ka > -1.50 (0.0439) | Kept: Ca ka > -1.50 -> Ni > -0.14 (0.0551)
# Removed: P <= 0.08 -> Ca ka > -1.50 (0.0526) | Kept: Ca ka > -1.50 -> P <= 0.08 (0.1095)
# Removed: P <= -0.59 -> P <= 0.08 (0.0546) | Kept: P <= 0.08 -> P <= -0.59 (0.1141)
# Removed: Ni <= -0.14 -> Compton scattering <= 0.87 (0.0162) | Kept: Compton scattering <= 0.87 -> Ni <= -0.14 (0.0434)
# Removed: Rh L + Ar <= 1.37 -> Mn > -0.41 (0.0169) | Kept: Mn > -0.41 -> Rh L + Ar <= 1.37 (0.0287)
# Removed: Rh L + Ar <= -0.77 -> background3 > -1.50 (0.0241) | Kept: background3 > -1.50 -> Rh L + Ar <= -0.77 (0.0400)
# Removed: background1 > -0.14 -> Ni > 0.13 (0.0087) | Kept: Ni > 0.13 -> background1 > -0.14 (0.0150)
# Removed: Ti kb <= 0.20 -> Mn <= 0.23 (0.0161) | Kept: Mn <= 0.23 -> Ti kb <= 0.20 (0.0249)
# Removed: background2 <= -0.08 -> Al <= -0.19 (0.0093) | Kept: Al <= -0.19 -> background2 <= -0.08 (0.0133)
# Removed: background2 <= 0.11 -> background2 <= -0.08 (0.0109) | Kept: background2 <= -0.08 -> background2 <= 0.11 (0.0133)
# Removed: background3 > -0.49 -> Al > 0.19 (0.0283) | Kept: Al > 0.19 -> background3 > -0.49 (0.0406)
# Removed: Al > 0.19 -> background4 <= 0.14 (0.0198) | Kept: background4 <= 0.14 -> Al > 0.19 (0.0203)
# Removed: background2 > -0.08 -> Al <= 0.19 (0.0089) | Kept: Al <= 0.19 -> background2 > -0.08 (0.0183)
# Removed: background2 <= 0.11 -> Rayleight scattering <= 0.53 (0.0096) | Kept: Rayleight scattering <= 0.53 -> background2 <= 0.11 (0.0143)
# Removed: background2 <= 0.11 -> Ca kb > -0.59 (0.0140) | Kept: Ca kb > -0.59 -> background2 <= 0.11 (0.0220)
# Removed: background1 > -0.05 -> background1 > -0.14 (0.0088) | Kept: background1 > -0.14 -> background1 > -0.05 (0.0102)
# Removed: background1 > -0.05 -> Al <= -0.19 (0.0080) | Kept: Al <= -0.19 -> background1 > -0.05 (0.0123)
# Removed: background2 > -0.26 -> sum Fe <= 0.07 (0.0098) | Kept: sum Fe <= 0.07 -> background2 > -0.26 (0.0195)
# Removed: S > -0.55 -> Compton scattering <= 0.05 (0.0109) | Kept: Compton scattering <= 0.05 -> S > -0.55 (0.0122)
#
# ======================================================================
# CONSTRUCTED GRAPH SUMMARY
# ======================================================================
# Initial edges: 735 | Removed: 105
# Predicate nodes: 115
# Metric: Covariance
# Weighting by explained variance: ENABLED
#
# ======================================================================
# Processando Grafo - Semente: 3
# ======================================================================
#
#
# Total bidirectional pairs found: 103
# Removed: Fe ka > -2.26 -> Fe ka > -3.74 (2.3377) | Kept: Fe ka > -3.74 -> Fe ka > -2.26 (21.4864)
# Removed: Ca ka <= 3.95 -> K > -6.69 (2.4043) | Kept: K > -6.69 -> Ca ka <= 3.95 (7.0400)
# Removed: Si > -1.67 -> Si > -2.51 (6.2692) | Kept: Si > -2.51 -> Si > -1.67 (6.4877)
# Removed: Si > -2.51 -> K > -6.69 (1.2517) | Kept: K > -6.69 -> Si > -2.51 (2.6116)
# Removed: K <= 6.26 -> Ca ka <= 1.77 (2.1923) | Kept: Ca ka <= 1.77 -> K <= 6.26 (5.0686)
# Removed: K > -1.46 -> K <= 6.26 (1.9211) | Kept: K <= 6.26 -> K > -1.46 (5.2409)
# Removed: Si > -0.72 -> K <= 6.26 (0.9710) | Kept: K <= 6.26 -> Si > -0.72 (2.9099)
# Removed: Si > -0.72 -> K > -1.46 (1.7766) | Kept: K > -1.46 -> Si > -0.72 (4.6710)
# Removed: Rh L + Ar > -0.16 -> Ca ka > -4.65 (0.5603) | Kept: Ca ka > -4.65 -> Rh L + Ar > -0.16 (1.0590)
# Removed: Si <= 3.71 -> Ca kb <= 1.58 (0.5620) | Kept: Ca kb <= 1.58 -> Si <= 3.71 (1.0953)
# Removed: Si <= 3.71 -> Ca ka <= -1.50 (0.4891) | Kept: Ca ka <= -1.50 -> Si <= 3.71 (0.9536)
# Removed: Rh L + Ar > -1.66 -> Si <= 3.71 (0.4278) | Kept: Si <= 3.71 -> Rh L + Ar > -1.66 (0.5311)
# Removed: Ca kb <= 1.58 -> Ti ka > -0.86 (0.5362) | Kept: Ti ka > -0.86 -> Ca kb <= 1.58 (1.6343)
# Removed: Fe kb > -0.91 -> Ca kb <= 1.58 (1.0764) | Kept: Ca kb <= 1.58 -> Fe kb > -0.91 (1.0919)
# Removed: Ca ka <= -1.50 -> Ti ka > -0.52 (0.4724) | Kept: Ti ka > -0.52 -> Ca ka <= -1.50 (0.4904)
# Removed: Rh L + Ar > -0.77 -> Rh L + Ar > -0.16 (0.4539) | Kept: Rh L + Ar > -0.16 -> Rh L + Ar > -0.77 (1.0937)
# Removed: Rh L + Ar > -0.77 -> Ti ka > -0.70 (0.5746) | Kept: Ti ka > -0.70 -> Rh L + Ar > -0.77 (1.0740)
# Removed: Rh L + Ar > -0.77 -> Fe kb > -0.44 (0.4885) | Kept: Fe kb > -0.44 -> Rh L + Ar > -0.77 (0.5175)
# Removed: Ca kb <= 0.62 -> Rh L + Ar > -0.77 (0.4920) | Kept: Rh L + Ar > -0.77 -> Ca kb <= 0.62 (0.8869)
# Removed: Ti ka > -0.86 -> Fe kb > -0.91 (0.4855) | Kept: Fe kb > -0.91 -> Ti ka > -0.86 (0.5464)
# Removed: Fe kb > -0.63 -> Ti ka > -0.86 (1.0149) | Kept: Ti ka > -0.86 -> Fe kb > -0.63 (1.1836)
# Removed: Ca kb <= 0.62 -> Ti ka > -0.52 (0.8798) | Kept: Ti ka > -0.52 -> Ca kb <= 0.62 (1.4784)
# Removed: Rh L + Ar > -1.66 -> Ca kb <= 0.62 (0.4384) | Kept: Ca kb <= 0.62 -> Rh L + Ar > -1.66 (1.3516)
# Removed: Fe kb > -0.91 -> Fe kb > -0.63 (0.5091) | Kept: Fe kb > -0.63 -> Fe kb > -0.91 (1.1183)
# Removed: background4 > 0.14 -> K <= 2.15 (0.9547) | Kept: K <= 2.15 -> background4 > 0.14 (1.8105)
# Removed: Fe kb > -0.44 -> Fe kb > -0.91 (0.5187) | Kept: Fe kb > -0.91 -> Fe kb > -0.44 (1.3576)
# Removed: Ti ka > -0.52 -> Fe kb > -0.44 (0.4338) | Kept: Fe kb > -0.44 -> Ti ka > -0.52 (1.4048)
# Removed: Ti ka > -0.52 -> Rh L + Ar > -1.66 (0.4037) | Kept: Rh L + Ar > -1.66 -> Ti ka > -0.52 (0.4546)
# Removed: background4 > 0.14 -> Rh L + Ar > -1.66 (0.3423) | Kept: Rh L + Ar > -1.66 -> background4 > 0.14 (0.7932)
# Removed: Rh L + Ar > -1.66 -> K > 2.15 (0.3734) | Kept: K > 2.15 -> Rh L + Ar > -1.66 (0.4445)
# Removed: Ca kb <= -0.59 -> Fe ka <= 1.10 (0.2275) | Kept: Fe ka <= 1.10 -> Ca kb <= -0.59 (0.2602)
# Removed: background4 > -0.62 -> Fe ka <= 1.10 (0.2813) | Kept: Fe ka <= 1.10 -> background4 > -0.62 (0.8248)
# Removed: Ca kb > -1.81 -> Fe ka <= 1.10 (0.2528) | Kept: Fe ka <= 1.10 -> Ca kb > -1.81 (0.2768)
# Removed: background4 > -0.62 -> K > 2.15 (0.1959) | Kept: K > 2.15 -> background4 > -0.62 (0.3257)
# Removed: Ca kb <= -0.59 -> K > 2.15 (0.2026) | Kept: K > 2.15 -> Ca kb <= -0.59 (0.2426)
# Removed: K > 2.15 -> Compton scattering > 0.05 (0.2010) | Kept: Compton scattering > 0.05 -> K > 2.15 (0.2478)
# Removed: background4 > -0.62 -> Ca kb > -1.81 (0.2675) | Kept: Ca kb > -1.81 -> background4 > -0.62 (0.7288)
# Removed: Ca kb > -1.81 -> Ca kb <= -0.59 (0.4891) | Kept: Ca kb <= -0.59 -> Ca kb > -1.81 (0.4934)
# Removed: Compton scattering > -0.40 -> Ca kb > -1.81 (0.2043) | Kept: Ca kb > -1.81 -> Compton scattering > -0.40 (0.2093)
# Removed: Compton scattering > 0.05 -> Ca kb > -1.81 (0.2091) | Kept: Ca kb > -1.81 -> Compton scattering > 0.05 (0.2764)
# Removed: Compton scattering > 0.05 -> background4 > -0.62 (0.1924) | Kept: background4 > -0.62 -> Compton scattering > 0.05 (0.7009)
# Removed: Ca kb <= -0.59 -> Compton scattering > 0.05 (0.2190) | Kept: Compton scattering > 0.05 -> Ca kb <= -0.59 (0.4183)
# Removed: Compton scattering > -0.88 -> Ca kb <= -0.59 (0.2009) | Kept: Ca kb <= -0.59 -> Compton scattering > -0.88 (0.2226)
# Removed: background4 > -1.28 -> Ca kb <= -0.59 (0.1826) | Kept: Ca kb <= -0.59 -> background4 > -1.28 (0.2040)
# Removed: Compton scattering > -0.40 -> Compton scattering > 0.05 (0.1917) | Kept: Compton scattering > 0.05 -> Compton scattering > -0.40 (0.8423)
# Removed: background4 > -1.28 -> Compton scattering > 0.05 (0.2316) | Kept: Compton scattering > 0.05 -> background4 > -1.28 (0.2445)
# Removed: background4 > -1.28 -> Compton scattering > -0.40 (0.2298) | Kept: Compton scattering > -0.40 -> background4 > -1.28 (0.6426)
# Removed: background4 > -1.28 -> Compton scattering > -0.88 (0.0914) | Kept: Compton scattering > -0.88 -> background4 > -1.28 (0.1258)
# Removed: background4 > -1.28 -> Rayleight scattering > 0.03 (0.1220) | Kept: Rayleight scattering > 0.03 -> background4 > -1.28 (0.1687)
# Removed: sum Fe > -0.28 -> sum Fe > 0.07 (0.3006) | Kept: sum Fe > 0.07 -> sum Fe > -0.28 (0.3177)
# Removed: Rayleight scattering > 0.03 -> sum Fe > -0.28 (0.1590) | Kept: sum Fe > -0.28 -> Rayleight scattering > 0.03 (0.6312)
# Removed: sum Fe > -0.28 -> Compton scattering > -0.88 (0.1644) | Kept: Compton scattering > -0.88 -> sum Fe > -0.28 (0.3475)
# Removed: Al > -0.68 -> sum Fe > 0.07 (0.3138) | Kept: sum Fe > 0.07 -> Al > -0.68 (0.4550)
# Removed: sum Fe > 0.07 -> Rayleight scattering > -0.25 (0.1434) | Kept: Rayleight scattering > -0.25 -> sum Fe > 0.07 (0.2696)
# Removed: Ti kb > -0.32 -> sum Fe > 0.07 (0.0845) | Kept: sum Fe > 0.07 -> Ti kb > -0.32 (0.1230)
# Removed: Compton scattering > -0.88 -> Al > -0.68 (0.1428) | Kept: Al > -0.68 -> Compton scattering > -0.88 (0.4370)
# Removed: Rayleight scattering > 0.03 -> Al > -0.68 (0.1353) | Kept: Al > -0.68 -> Rayleight scattering > 0.03 (0.1456)
# Removed: Rayleight scattering > -0.25 -> Al > -0.68 (0.2800) | Kept: Al > -0.68 -> Rayleight scattering > -0.25 (0.3119)
# Removed: Compton scattering > -0.88 -> Rayleight scattering > 0.03 (0.1307) | Kept: Rayleight scattering > 0.03 -> Compton scattering > -0.88 (0.2886)
# Removed: Al > -0.19 -> sum Fe > -0.60 (0.1271) | Kept: sum Fe > -0.60 -> Al > -0.19 (0.3497)
# Removed: Ti kb > -0.32 -> sum Fe > -0.60 (0.0960) | Kept: sum Fe > -0.60 -> Ti kb > -0.32 (0.2296)
# Removed: background3 <= 0.36 -> sum Fe > -0.60 (0.0759) | Kept: sum Fe > -0.60 -> background3 <= 0.36 (0.1049)
# Removed: sum Fe > -0.60 -> Rayleight scattering > -0.50 (0.1291) | Kept: Rayleight scattering > -0.50 -> sum Fe > -0.60 (0.1938)
# Removed: Al > -0.19 -> K <= -1.46 (0.1105) | Kept: K <= -1.46 -> Al > -0.19 (0.1315)
# Removed: Rayleight scattering > -0.50 -> K <= -1.46 (0.1095) | Kept: K <= -1.46 -> Rayleight scattering > -0.50 (0.1128)
# Removed: background3 <= -0.49 -> K <= -1.46 (0.1182) | Kept: K <= -1.46 -> background3 <= -0.49 (0.4682)
# Removed: Rayleight scattering > -0.50 -> P > 0.08 (0.1039) | Kept: P > 0.08 -> Rayleight scattering > -0.50 (0.2227)
# Removed: Rayleight scattering > -0.50 -> Ti kb > -0.32 (0.0892) | Kept: Ti kb > -0.32 -> Rayleight scattering > -0.50 (0.1934)
# Removed: Al <= 0.62 -> Ti kb > -0.14 (0.0790) | Kept: Ti kb > -0.14 -> Al <= 0.62 (0.1659)
# Removed: P > -1.23 -> Al <= 0.62 (0.0868) | Kept: Al <= 0.62 -> P > -1.23 (0.2022)
# Removed: Mn > 0.23 -> Ti kb > -0.14 (0.0831) | Kept: Ti kb > -0.14 -> Mn > 0.23 (0.1633)
# Removed: Mn > 0.23 -> P > 0.08 (0.0802) | Kept: P > 0.08 -> Mn > 0.23 (0.0854)
# Removed: Ti kb > 0.03 -> background3 > -0.49 (0.0677) | Kept: background3 > -0.49 -> Ti kb > 0.03 (0.0713)
# Removed: background3 > 0.36 -> Ti ka <= 0.53 (0.0709) | Kept: Ti ka <= 0.53 -> background3 > 0.36 (0.0734)
# Removed: Ni <= 0.13 -> S <= 0.55 (0.0429) | Kept: S <= 0.55 -> Ni <= 0.13 (0.0536)
# Removed: Rayleight scattering <= -0.25 -> S <= 0.55 (0.0252) | Kept: S <= 0.55 -> Rayleight scattering <= -0.25 (0.0345)
# Removed: background4 <= -0.62 -> S <= 0.55 (0.0557) | Kept: S <= 0.55 -> background4 <= -0.62 (0.0619)
# Removed: P > -1.23 -> P > -0.59 (0.1049) | Kept: P > -0.59 -> P > -1.23 (0.1349)
# Removed: Mn <= 1.01 -> Fe kb <= 0.33 (0.0571) | Kept: Fe kb <= 0.33 -> Mn <= 1.01 (0.0863)
# Removed: P <= 0.08 -> Fe kb <= 0.33 (0.0318) | Kept: Fe kb <= 0.33 -> P <= 0.08 (0.0444)
# Removed: Rh L + Ar <= -0.77 -> Mn <= 1.01 (0.0426) | Kept: Mn <= 1.01 -> Rh L + Ar <= -0.77 (0.0904)
# Removed: Ti kb <= 0.20 -> background3 > 0.36 (0.0226) | Kept: background3 > 0.36 -> Ti kb <= 0.20 (0.0232)
# Removed: P > -0.59 -> background3 > 0.36 (0.0704) | Kept: background3 > 0.36 -> P > -0.59 (0.0832)
# Removed: background3 <= 1.60 -> Ni <= -0.14 (0.0205) | Kept: Ni <= -0.14 -> background3 <= 1.60 (0.0284)
# Removed: background3 <= 1.60 -> Ni > -0.60 (0.0272) | Kept: Ni > -0.60 -> background3 <= 1.60 (0.0437)
# Removed: Rayleight scattering <= -0.25 -> S <= 0.09 (0.0305) | Kept: S <= 0.09 -> Rayleight scattering <= -0.25 (0.0332)
# Removed: sum Fe <= -0.28 -> S <= 0.09 (0.0329) | Kept: S <= 0.09 -> sum Fe <= -0.28 (0.0799)
# Removed: Ni <= -0.14 -> S <= 0.09 (0.0311) | Kept: S <= 0.09 -> Ni <= -0.14 (0.0410)
# Removed: P <= 0.08 -> background3 <= 0.36 (0.0613) | Kept: background3 <= 0.36 -> P <= 0.08 (0.0666)
# Removed: background3 > -0.49 -> Mn <= -0.41 (0.0242) | Kept: Mn <= -0.41 -> background3 > -0.49 (0.0305)
# Removed: Ni <= 0.13 -> P <= -0.59 (0.0566) | Kept: P <= -0.59 -> Ni <= 0.13 (0.1052)
# Removed: P <= -0.59 -> sum Fe <= -0.28 (0.0517) | Kept: sum Fe <= -0.28 -> P <= -0.59 (0.0962)
# Removed: Ni <= 0.13 -> S <= -0.27 (0.0484) | Kept: S <= -0.27 -> Ni <= 0.13 (0.0511)
# Removed: Ca ka > -1.50 -> Ni > -0.14 (0.0495) | Kept: Ni > -0.14 -> Ca ka > -1.50 (0.0955)
# Removed: background4 <= 1.47 -> S > -0.55 (0.0141) | Kept: S > -0.55 -> background4 <= 1.47 (0.0153)
# Removed: background4 <= 0.14 -> Ni > -0.60 (0.0321) | Kept: Ni > -0.60 -> background4 <= 0.14 (0.0615)
# Removed: Ni > 0.13 -> Ca kb > -0.59 (0.0166) | Kept: Ca kb > -0.59 -> Ni > 0.13 (0.0206)
# Removed: Ni > 0.13 -> background1 > -0.05 (0.0089) | Kept: background1 > -0.05 -> Ni > 0.13 (0.0168)
# Removed: P <= 1.06 -> background4 <= -0.62 (0.0427) | Kept: background4 <= -0.62 -> P <= 1.06 (0.0533)
# Removed: background2 > 0.11 -> Rayleight scattering <= -0.25 (0.0203) | Kept: Rayleight scattering <= -0.25 -> background2 > 0.11 (0.0217)
# Removed: sum Fe <= 0.62 -> Al <= -0.19 (0.0098) | Kept: Al <= -0.19 -> sum Fe <= 0.62 (0.0111)
# Removed: background1 > -0.05 -> background1 > -0.14 (0.0058) | Kept: background1 > -0.14 -> background1 > -0.05 (0.0169)
# Removed: background1 > -0.05 -> Ti kb <= 0.03 (0.0075) | Kept: Ti kb <= 0.03 -> background1 > -0.05 (0.0087)
#
# ======================================================================
# CONSTRUCTED GRAPH SUMMARY
# ======================================================================
# Initial edges: 743 | Removed: 103
# Predicate nodes: 115
# Metric: Covariance
# Weighting by explained variance: ENABLED
#
# Processing graph LRC...
#
# Processing graph LRC...
#
# Processing graph LRC...
#
# Processing graph LRC...
#     Predicate_Cov_Seed_0          Predicate_Cov_Seed_1  \
# 0          Fe ka > -3.05                 Fe ka > -3.05
# 1          Fe ka > -3.74                 Fe ka > -3.74
# 2          Fe ka > -2.26                 Fe ka > -2.26
# 3          Ca ka <= 3.95                    Si > -2.51
# 4              K <= 6.26                 Ca ka <= 3.95
# ..                   ...                           ...
# 112            S > -0.27  Rayleight scattering <= 0.03
# 113  background1 <= 0.16                       Class_A
# 114              Class_A                       Class_B
# 115              Class_B                           NaN
# 116                  NaN                           NaN
#
#              Predicate_Cov_Seed_2          Predicate_Cov_Seed_3
# 0                   Fe ka > -3.05                 Fe ka > -3.05
# 1                   Fe ka > -3.74                 Fe ka > -3.74
# 2                   Fe ka > -2.26                 Fe ka > -2.26
# 3                   Ca ka <= 3.95                 Ca ka <= 3.95
# 4                      Si > -2.51                    Si > -2.51
# ..                            ...                           ...
# 112  Rayleight scattering <= 0.03           background1 > -0.05
# 113                Fe kb <= -0.44            background1 > 0.05
# 114          background1 <= -0.05  Rayleight scattering <= 0.53
# 115                       Class_A                       Class_A
# 116                       Class_B                       Class_B
#
# [117 rows x 4 columns]

# %%
# Somar LRCs de predicados equivalentes entre diferentes seeds
lrc_combined_list = []

for seed in random_seeds:
    lrc_df = lrc_cov_by_seed[seed].copy()
    lrc_combined_list.append(lrc_df) # o append adiciona o dataframe ao final da lista

# Concatenar todos os dataframes
lrc_all_seeds = pd.concat(lrc_combined_list, ignore_index=True) 

# Agrupar por predicado (Node) e somar as LRCs, mantendo Zone, Threshold e Operator
lrc_summed_df_cov = lrc_all_seeds.groupby('Node').agg({ # o .agg pode ser usado para aplicar múltiplas funções de agregação
    'Local_Reaching_Centrality': 'mean', # sum = somando as LRCs, poderia ser média ou outro agregado
    'Zone': 'first',
    'Threshold': 'first',
    'Operator': 'first'
}).reset_index()

# Ordenar pelo valor de LRC somado (maior para menor)
lrc_summed_df_cov = lrc_summed_df_cov.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
# vamoss pegar so os valore sunicos de lrc_summed_df baseado na zona espectral
lrc_summed_unique_df_cov = lrc_summed_df_cov.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
#lrc_summed_unique_df_cov = lrc_summed_unique_df_cov.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
lrc_summed_unique_df_cov
# Out:
#                             Node  Local_Reaching_Centrality  \
# 0                  Fe ka > -3.05                  17.647219
# 1                  Ca ka <= 3.95                   5.100415
# 2                     Si > -2.51                   4.906402
# 3                      K > -6.69                   4.158596
# 4                  Ti ka > -0.70                   1.768486
# 5                  Fe kb > -0.44                   1.582814
# 6                  Ca kb <= 1.58                   1.421033
# 7              Rh L + Ar > -1.66                   1.377371
# 8            background4 > -0.62                   0.976812
# 9      Compton scattering > 0.05                   0.883058
# 10                sum Fe > -0.28                   0.635232
# 11  Rayleight scattering > -0.25                   0.600006
# 12                    Al > -0.68                   0.530627
# 13          background3 <= -0.49                   0.418636
# 14                 Ti kb > -0.32                   0.388063
# 15                     P > -1.23                   0.370707
# 16                     Mn > 0.23                   0.357550
# 17                     S <= 0.55                   0.301817
# 18                    Ni <= 0.13                   0.280440
# 19           background2 <= 0.30                   0.251104
# 20           background1 > -0.05                   0.244255
# 21                       Class_B                   0.000000
#
#                     Zone Threshold Operator
# 0                  Fe ka     -3.05        >
# 1                  Ca ka      3.95       <=
# 2                     Si     -2.51        >
# 3                      K     -6.69        >
# 4                  Ti ka     -0.70        >
# 5                  Fe kb     -0.44        >
# 6                  Ca kb      1.58       <=
# 7              Rh L + Ar     -1.66        >
# 8            background4     -0.62        >
# 9     Compton scattering      0.05        >
# 10                sum Fe     -0.28        >
# 11  Rayleight scattering     -0.25        >
# 12                    Al     -0.68        >
# 13           background3     -0.49       <=
# 14                 Ti kb     -0.32        >
# 15                     P     -1.23        >
# 16                    Mn      0.23        >
# 17                     S      0.55       <=
# 18                    Ni      0.13       <=
# 19           background2      0.30       <=
# 20           background1     -0.05        >
# 21                  None      None     None

# %%
# Criar zone_sums_df para dados NÃO pré-processados (Xcalclass)
spectral_zones_original = exp.extract_spectral_zones(Xcalclass, spectral_cuts)
zones_original = exp.aggregate_spectral_zones_pca(spectral_zones_original) # apca aggregation

# Aplicar o mapeamento
lrc_summed_df_cov_natural = exp.map_thresholds_to_natural(
    lrc_df=lrc_summed_df_cov,
    zone_sums_preprocessed=zone_scores_df,
    zone_sums_natural=zones_original[0]
)

lrc_summed_df_cov_natural
# Out:
# Zone 'Al': VE = 95.14%, dim = 12 variables
# Zone 'Si': VE = 99.71%, dim = 12 variables
# Zone 'P': VE = 97.48%, dim = 16 variables
# Zone 'S': VE = 93.90%, dim = 15 variables
# Zone 'Rh L + Ar': VE = 96.86%, dim = 34 variables
# Zone 'K': VE = 99.17%, dim = 19 variables
# Zone 'Ca ka': VE = 93.72%, dim = 21 variables
# Zone 'Ca kb': VE = 98.47%, dim = 16 variables
# Zone 'background1': VE = 53.38%, dim = 12 variables
# Zone 'Ti ka': VE = 98.49%, dim = 15 variables
# Zone 'Ti kb': VE = 76.99%, dim = 22 variables
# Zone 'background2': VE = 66.94%, dim = 33 variables
# Zone 'Mn': VE = 95.57%, dim = 20 variables
# Zone 'Fe ka': VE = 99.73%, dim = 34 variables
# Zone 'Fe kb': VE = 94.82%, dim = 23 variables
# Zone 'Ni': VE = 79.28%, dim = 25 variables
# Zone 'background3': VE = 84.69%, dim = 271 variables
# Zone 'sum Fe': VE = 88.64%, dim = 27 variables
# Zone 'background4': VE = 87.63%, dim = 219 variables
# Zone 'Compton scattering': VE = 89.25%, dim = 85 variables
# Zone 'Rayleight scattering': VE = 84.72%, dim = 56 variables
#                              Node  Local_Reaching_Centrality  \
# 0                   Fe ka > -3.05                  17.647219
# 1                   Fe ka > -3.74                  12.389331
# 2                   Fe ka > -2.26                   6.063380
# 3                   Ca ka <= 3.95                   5.100415
# 4                      Si > -2.51                   4.906402
# ..                            ...                        ...
# 116  Rayleight scattering <= 0.53                   0.190192
# 117           background1 <= 0.05                   0.068339
# 118           background1 <= 0.16                   0.000132
# 119                       Class_B                   0.000000
# 120                       Class_A                   0.000000
#
#                      Zone Threshold Operator  Threshold_Natural  \
# 0                   Fe ka     -3.05        >         -11.993967
# 1                   Fe ka     -3.74        >         -14.394181
# 2                   Fe ka     -2.26        >          -8.585461
# 3                   Ca ka      3.95       <=          24.763583
# 4                      Si     -2.51        >          -6.726367
# ..                    ...       ...      ...                ...
# 116  Rayleight scattering      0.53       <=           0.683403
# 117           background1      0.05       <=           0.062920
# 118           background1      0.16       <=           0.220244
# 119                  None      None     None                NaN
# 120                  None      None     None                NaN
#
#      Reference_Sample_Index  Approximation_Error  \
# 0                     102.0             0.012499
# 1                      68.0             0.017162
# 2                      77.0             0.009247
# 3                      89.0             0.045885
# 4                      45.0             0.014243
# ..                      ...                  ...
# 116                    73.0             0.010942
# 117                    64.0             0.002636
# 118                    63.0             0.001524
# 119                     NaN                  NaN
# 120                     NaN                  NaN
#
#                          Node_Natural
# 0                  Fe ka > -11.993967
# 1                  Fe ka > -14.394181
# 2                   Fe ka > -8.585461
# 3                  Ca ka <= 24.763583
# 4                      Si > -6.726367
# ..                                ...
# 116  Rayleight scattering <= 0.683403
# 117           background1 <= 0.062920
# 118           background1 <= 0.220244
# 119                              None
# 120                              None
#
# [121 rows x 9 columns]

# %% [markdown]
# ## Reconstrução de Thresholds Multivariados
#
# Agora vamos pegar os thresholds dos predicados mais importantes e reconstruí-los como espectros completos.

# %%
import plotly.graph_objects as go

n = 0
zone_name = lrc_summed_df_cov_natural.iloc[n]['Zone']
threshold_score = float(lrc_summed_df_cov_natural.iloc[n]['Threshold_Natural'])  # Corrigido: usa n em vez de 7

# Usar pca_info_dict dos dados ORIGINAIS (zones_original[1])
pca_info_dict_original = zones_original[1]

# Reconstrução: τ = mean + threshold * loadings (no espaço original)
threshold_spectrum = exp.reconstruct_threshold_to_spectrum(
    threshold_value=threshold_score,
    zone_name=zone_name,
    pca_info_dict=pca_info_dict_original
)
print(f"\nEspectro de threshold reconstruído para zona '{zone_name}':")
print(f"  - Dimensão: {len(threshold_spectrum)} variáveis espectrais")
print(f"  - Range de energias: {threshold_spectrum.index[0]} - {threshold_spectrum.index[-1]}")
print(f"  - Variância explicada pela PC1: {pca_info_dict_original[zone_name]['variance_explained']:.2%}")

# Usar dados ORIGINAIS para plotar (spectral_zones_original)
zone_df = spectral_zones_original[zone_name]

# Plotar zona com threshold (inline)
fig = go.Figure()
x_values = pd.to_numeric(zone_df.columns, errors='coerce')

# Plotar espectros das amostras coloridas por classe
colors = {'A': 'gold', 'B': 'blue'}
for idx, row in zone_df.iterrows():
    class_label = ycalclass.iloc[idx] if idx < len(ycalclass) else 'Unknown'
    fig.add_trace(go.Scatter(
        x=x_values,
        y=row.values,
        mode='lines',
        line=dict(color=colors.get(class_label, 'rgba(128,128,128,0.3)'), width=0.5),
        name=f'Class {class_label}',
        showlegend=False,
        hoverinfo='skip'
    ))

# Plotar espectro de threshold (destaque)
fig.add_trace(go.Scatter(
    x=x_values,
    y=threshold_spectrum.values,
    mode='lines',
    line=dict(color='red', width=4, dash='dash'),
    name=f'Threshold Spectrum ({threshold_spectrum.name})'
))

# Layout do gráfico
fig.update_layout(
    title=f"Zona '{zone_name}' com Threshold Multivariado (Predicado: {lrc_summed_df_cov_natural.iloc[n]['Node_Natural']})",
    xaxis_title='Energia / Comprimento de Onda',
    yaxis_title='Intensidade',
    template='plotly_white',
    showlegend=True,
    legend=dict(yanchor="top", y=0.99, xanchor="left", x=0.01)
)

fig.show()
# Out:
# Espectro de threshold reconstruído para zona 'Fe ka':
#   - Dimensão: 34 variáveis espectrais
#   - Range de energias: 6.1 - 6.76
#   - Variância explicada pela PC1: 99.73%

# %%
import explaining as exp

# LISTA DE SEMENTES A TESTAR
random_seeds = [0, 1, 2, 3]

all_results_pert = {}
training_samples = len(Xcalclass)

# LOOP: PROCESSAR CADA SEMENTE

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando semente: {seed}")
    print(f"{'='*70}\n")
    # Bagging
    bags_result_seed = exp.bagging_predicates(
        zone_sums_df=zone_scores_df,
        y_predicted_numeric=y_pred,
        predicates_df=predicates_quantiles[0],
        n_bags=10,
        #n_predicates_per_bag=40,
        n_samples_per_bag=int(training_samples*0.8), # 80 % da base para amostrar (convertido para int)
        min_samples_per_predicate=int(training_samples*0.2), # 20 % da base para limitar (convertido para int)
        replace=False,
        sample_bagging=True,
        predicate_bagging=False,
        random_seed=seed
    )
    # Inserir classe prevista
    for bag_name, pred_dict in bags_result_seed.items(): # iterando sobre cada bag
        for pred_rule, df_info in pred_dict.items():
            df_info['Class_Predicted'] = np.where(df_info['Predicted_Y'] >= 0.5, 'A', 'B') # binarizando com threshold 0.5, A = eut, B = dist

    pert_results_seed = exp.calculate_predicate_perturbation(
        estimator=svm_model[3],
        Xcalclass_prep=Xcalclass_prep,
        folds_struct=bags_result_seed,
        predicates_df=predicates_quantiles[0],
        spectral_cuts=spectral_cuts,
        #perturbation_value=0,
        perturbation_mode='median', # valores entre 'mean' ou 'min'
        stats_source='full', # full indica usar todas as amostras para calcular estatísticas enquanto que 'fold' usa apenas as amostras do fold atual
        #metric='mean_abs_diff',   # Média com sinal (pode ser negativo)
        aim='classification',
        metric='probability_shift', 
        verbose=True
    )

    # Salvar no dicionário principal
    all_results_pert[seed] = {
        'bags_result': bags_result_seed,
        'pert_results_dict': pert_results_seed
    }

# CONSTRUÇÃO DE GRAFOS PARA MÚLTIPLAS SEMENTES (LOOP EXTERNO)
# Dicionário para armazenar grafos
graphs_pert_by_seed = {}

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando Grafo - Semente: {seed}")
    print(f"{'='*70}\n")
    
    # Construir grafo para esta semente (sem predicates_df - extraído da regra)
    DG = exp.build_predicate_graph(
        bags_result=all_results_pert[seed]['bags_result'],
        predicate_ranking_dict=all_results_pert[seed]['pert_results_dict'],
        metric_column='Perturbation',
        random_state=seed,
        show_details=True,
        var_exp=True,
        pca_info_dict=pca_info_dict
    )

    # Armazenar grafo
    graphs_pert_by_seed[seed] = DG  

# Calcular LRC usando a função pronta do explaining.py
lrc_pert_by_seed = {}
for seed in random_seeds:
    DG = graphs_pert_by_seed[seed]
    lrc_pert_df_seed = exp.calculate_lrc_single_graph(DG, predicates_quantiles[0])
    lrc_pert_df_seed['Seed'] = seed  # Adicionar coluna com a semente
    lrc_pert_by_seed[seed] = lrc_pert_df_seed

# junando todas as colunas 'Node' de lrc_by_seed em um único dataframe
lrc_pert_all_seeds_df = pd.DataFrame()
for seed in random_seeds:
    lrc_pert_df_seed = lrc_pert_by_seed[seed].rename(columns={'Node': f'Predicate_pert_Seed_{seed}'})
    lrc_pert_all_seeds_df = pd.concat([lrc_pert_all_seeds_df, lrc_pert_df_seed[[f'Predicate_pert_Seed_{seed}']]], axis=1)

# vamos filtrar lrc_by_seed em cada semente para manter apenas as zonas espectrais únicas com maior LRC em um mesmo dataframe
lrc_pert_unique_by_seed = {}
for seed, lrc_df in lrc_pert_by_seed.items():
    lrc_pert_unique_df = lrc_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
    lrc_pert_unique_df = lrc_pert_unique_df.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
    lrc_pert_unique_by_seed[seed] = lrc_pert_unique_df

lrc_pert_all_seeds_df # exibindo o dataframe consolidado com predicados de todas as sementes
# Out:
# ======================================================================
# Processando semente: 0
# ======================================================================
#
# Bag_1 | Samples: Yes | Predicates: No (All) | Valid: 126 | Discarded: 42
# Bag_2 | Samples: Yes | Predicates: No (All) | Valid: 126 | Discarded: 42
# Bag_3 | Samples: Yes | Predicates: No (All) | Valid: 126 | Discarded: 42
# Bag_4 | Samples: Yes | Predicates: No (All) | Valid: 126 | Discarded: 42
# Bag_5 | Samples: Yes | Predicates: No (All) | Valid: 127 | Discarded: 41
# Bag_6 | Samples: Yes | Predicates: No (All) | Valid: 127 | Discarded: 41
# Bag_7 | Samples: Yes | Predicates: No (All) | Valid: 126 | Discarded: 42
# Bag_8 | Samples: Yes | Predicates: No (All) | Valid: 126 | Discarded: 42
# Bag_9 | Samples: Yes | Predicates: No (All) | Valid: 126 | Discarded: 42
# Bag_10 | Samples: Yes | Predicates: No (All) | Valid: 126 | Discarded: 42
# ======================================================================
# PERTURBATION IMPORTANCE FOR PREDICATES
# ======================================================================
# Task type (aim): classification
# Perturbation mode: median
# Statistics source: full
# Metric: probability_shift
# Total folds: 10
#
#
# [Bag_1] Processing 126 predicates...
#   Predicate: Al > -0.68 (n=87)
#     Zone: 12 columns
#     Importance: 0.000096
#   Predicate: Al <= -0.19 (n=43)
#     Zone: 12 columns
#     Importance: 0.000135
#   Predicate: Al > -0.19 (n=65)
#     Zone: 12 columns
#     Importance: 0.000111
#   Predicate: Al <= 0.19 (n=67)
#     Zone: 12 columns
#     Importance: 0.000092
#   Predicate: Al > 0.19 (n=41)
#     Zone: 12 columns
#     Importance: 0.000168
#   Predicate: Al <= 0.62 (n=87)
#     Zone: 12 columns
#     Importance: 0.000095
#   Predicate: Si > -2.51 (n=83)
#     Zone: 12 columns
#     Importance: 0.081880
#   Predicate: Si <= -1.67 (n=45)
#     Zone: 12 columns
#     Importance: 0.008989
#   Predicate: Si > -1.67 (n=63)
#     Zone: 12 columns
#     Importance: 0.106685
#   Predicate: Si <= -0.72 (n=65)
#     Zone: 12 columns
#     Importance: 0.006392
#   Predicate: Si > -0.72 (n=43)
#     Zone: 12 columns
#     Importance: 0.156050
#   Predicate: Si <= 3.71 (n=85)
#     Zone: 12 columns
#     Importance: 0.032288
#   Predicate: P > -1.23 (n=88)
#     Zone: 16 columns
#     Importance: 0.000441
#   Predicate: P <= -0.59 (n=42)
#     Zone: 16 columns
#     Importance: 0.000243
#   Predicate: P > -0.59 (n=66)
#     Zone: 16 columns
#     Importance: 0.000530
#   Predicate: P <= 0.08 (n=63)
#     Zone: 16 columns
#     Importance: 0.000198
#   Predicate: P > 0.08 (n=45)
#     Zone: 16 columns
#     Importance: 0.000727
#   Predicate: P <= 1.06 (n=84)
#     Zone: 16 columns
#     Importance: 0.000237
#   Predicate: S > -0.55 (n=86)
#     Zone: 15 columns
#     Importance: 0.000260
#   Predicate: S <= -0.27 (n=43)
#     Zone: 15 columns
#     Importance: 0.000290
#   Predicate: S > -0.27 (n=65)
#     Zone: 15 columns
#     Importance: 0.000296
#   Predicate: S <= 0.09 (n=62)
#     Zone: 15 columns
#     Importance: 0.000222
#   Predicate: S > 0.09 (n=46)
#     Zone: 15 columns
#     Importance: 0.000390
#   Predicate: S <= 0.55 (n=84)
#     Zone: 15 columns
#     Importance: 0.000215
#   Predicate: Rh L + Ar > -1.66 (n=90)
#     Zone: 34 columns
#     Importance: 0.002146
#   Predicate: Rh L + Ar <= -0.77 (n=37)
#     Zone: 34 columns
#     Importance: 0.000746
#   Predicate: Rh L + Ar > -0.77 (n=71)
#     Zone: 34 columns
#     Importance: 0.002559
#   Predicate: Rh L + Ar <= -0.16 (n=63)
#     Zone: 34 columns
#     Importance: 0.000507
#   Predicate: Rh L + Ar > -0.16 (n=45)
#     Zone: 34 columns
#     Importance: 0.003940
#   Predicate: Rh L + Ar <= 1.37 (n=89)
#     Zone: 34 columns
#     Importance: 0.000829
#   Predicate: K > -6.69 (n=87)
#     Zone: 19 columns
#     Importance: 0.005422
#   Predicate: K <= -1.46 (n=42)
#     Zone: 19 columns
#     Importance: 0.006049
#   Predicate: K > -1.46 (n=66)
#     Zone: 19 columns
#     Importance: 0.006058
#   Predicate: K <= 2.15 (n=66)
#     Zone: 19 columns
#     Importance: 0.004266
#   Predicate: K > 2.15 (n=42)
#     Zone: 19 columns
#     Importance: 0.008865
#   Predicate: K <= 6.26 (n=86)
#     Zone: 19 columns
#     Importance: 0.004707
#   Predicate: Ca ka > -4.65 (n=86)
#     Zone: 21 columns
#     Importance: 0.010675
#   Predicate: Ca ka <= -1.50 (n=44)
#     Zone: 21 columns
#     Importance: 0.058908
#   Predicate: Ca ka > -1.50 (n=64)
#     Zone: 21 columns
#     Importance: 0.006984
#   Predicate: Ca ka <= 1.77 (n=67)
#     Zone: 21 columns
#     Importance: 0.039679
#   Predicate: Ca ka > 1.77 (n=41)
#     Zone: 21 columns
#     Importance: 0.009279
#   Predicate: Ca ka <= 3.95 (n=87)
#     Zone: 21 columns
#     Importance: 0.031655
#   Predicate: Ca kb > -1.81 (n=86)
#     Zone: 16 columns
#     Importance: 0.001339
#   Predicate: Ca kb <= -0.59 (n=45)
#     Zone: 16 columns
#     Importance: 0.004194
#   Predicate: Ca kb > -0.59 (n=63)
#     Zone: 16 columns
#     Importance: 0.000881
#   Predicate: Ca kb <= 0.62 (n=66)
#     Zone: 16 columns
#     Importance: 0.002966
#   Predicate: Ca kb > 0.62 (n=42)
#     Zone: 16 columns
#     Importance: 0.001155
#   Predicate: Ca kb <= 1.58 (n=87)
#     Zone: 16 columns
#     Importance: 0.002396
#   Predicate: background1 > -0.14 (n=87)
#     Zone: 12 columns
#     Importance: 0.000014
#   Predicate: background1 <= -0.05 (n=43)
#     Zone: 12 columns
#     Importance: 0.000016
#   Predicate: background1 > -0.05 (n=65)
#     Zone: 12 columns
#     Importance: 0.000014
#   Predicate: background1 <= 0.05 (n=68)
#     Zone: 12 columns
#     Importance: 0.000012
#   Predicate: background1 > 0.05 (n=40)
#     Zone: 12 columns
#     Importance: 0.000018
#   Predicate: background1 <= 0.16 (n=90)
#     Zone: 12 columns
#     Importance: 0.000014
#   Predicate: Ti ka > -0.86 (n=87)
#     Zone: 15 columns
#     Importance: 0.001301
#   Predicate: Ti ka <= -0.70 (n=44)
#     Zone: 15 columns
#     Importance: 0.000267
#   Predicate: Ti ka > -0.70 (n=64)
#     Zone: 15 columns
#     Importance: 0.001728
#   Predicate: Ti ka <= -0.52 (n=63)
#     Zone: 15 columns
#     Importance: 0.000197
#   Predicate: Ti ka > -0.52 (n=45)
#     Zone: 15 columns
#     Importance: 0.002444
#   Predicate: Ti ka <= 0.53 (n=87)
#     Zone: 15 columns
#     Importance: 0.000299
#   Predicate: Ti kb > -0.32 (n=88)
#     Zone: 22 columns
#     Importance: 0.000091
#   Predicate: Ti kb <= -0.14 (n=45)
#     Zone: 22 columns
#     Importance: 0.000098
#   Predicate: Ti kb > -0.14 (n=63)
#     Zone: 22 columns
#     Importance: 0.000113
#   Predicate: Ti kb <= 0.03 (n=66)
#     Zone: 22 columns
#     Importance: 0.000073
#   Predicate: Ti kb > 0.03 (n=42)
#     Zone: 22 columns
#     Importance: 0.000160
#   Predicate: Ti kb <= 0.20 (n=86)
#     Zone: 22 columns
#     Importance: 0.000075
#   Predicate: background2 > -0.26 (n=90)
#     Zone: 33 columns
#     Importance: 0.000032
#   Predicate: background2 <= -0.08 (n=43)
#     Zone: 33 columns
#     Importance: 0.000071
#   Predicate: background2 > -0.08 (n=65)
#     Zone: 33 columns
#     Importance: 0.000030
#   Predicate: background2 <= 0.11 (n=70)
#     Zone: 33 columns
#     Importance: 0.000051
#   Predicate: background2 > 0.11 (n=38)
#     Zone: 33 columns
#     Importance: 0.000038
#   Predicate: background2 <= 0.30 (n=91)
#     Zone: 33 columns
#     Importance: 0.000048
#   Predicate: Mn > -1.22 (n=88)
#     Zone: 20 columns
#     Importance: 0.000204
#   Predicate: Mn <= -0.41 (n=43)
#     Zone: 20 columns
#     Importance: 0.000380
#   Predicate: Mn > -0.41 (n=65)
#     Zone: 20 columns
#     Importance: 0.000214
#   Predicate: Mn <= 0.23 (n=67)
#     Zone: 20 columns
#     Importance: 0.000259
#   Predicate: Mn > 0.23 (n=41)
#     Zone: 20 columns
#     Importance: 0.000314
#   Predicate: Mn <= 1.01 (n=90)
#     Zone: 20 columns
#     Importance: 0.000229
#   Predicate: Fe ka > -3.74 (n=86)
#     Zone: 34 columns
#     Importance: 0.013907
#   Predicate: Fe ka <= -3.05 (n=44)
#     Zone: 34 columns
#     Importance: 0.002226
#   Predicate: Fe ka > -3.05 (n=64)
#     Zone: 34 columns
#     Importance: 0.018258
#   Predicate: Fe ka <= -2.26 (n=63)
#     Zone: 34 columns
#     Importance: 0.001690
#   Predicate: Fe ka > -2.26 (n=45)
#     Zone: 34 columns
#     Importance: 0.025777
#   Predicate: Fe ka <= 1.10 (n=87)
#     Zone: 34 columns
#     Importance: 0.003753
#   Predicate: Fe kb > -0.91 (n=87)
#     Zone: 23 columns
#     Importance: 0.001187
#   Predicate: Fe kb <= -0.63 (n=41)
#     Zone: 23 columns
#     Importance: 0.000219
#   Predicate: Fe kb > -0.63 (n=67)
#     Zone: 23 columns
#     Importance: 0.001512
#   Predicate: Fe kb <= -0.44 (n=66)
#     Zone: 23 columns
#     Importance: 0.000154
#   Predicate: Fe kb > -0.44 (n=42)
#     Zone: 23 columns
#     Importance: 0.002384
#   Predicate: Fe kb <= 0.33 (n=87)
#     Zone: 23 columns
#     Importance: 0.000197
#   Predicate: Ni > -0.60 (n=88)
#     Zone: 25 columns
#     Importance: 0.000103
#   Predicate: Ni <= -0.14 (n=44)
#     Zone: 25 columns
#     Importance: 0.000135
#   Predicate: Ni > -0.14 (n=64)
#     Zone: 25 columns
#     Importance: 0.000117
#   Predicate: Ni <= 0.13 (n=64)
#     Zone: 25 columns
#     Importance: 0.000123
#   Predicate: Ni > 0.13 (n=44)
#     Zone: 25 columns
#     Importance: 0.000127
#   Predicate: Ni <= 0.59 (n=90)
#     Zone: 25 columns
#     Importance: 0.000118
#   Predicate: background3 > -1.50 (n=88)
#     Zone: 271 columns
#     Importance: 0.000567
#   Predicate: background3 <= -0.49 (n=44)
#     Zone: 271 columns
#     Importance: 0.000970
#   Predicate: background3 > -0.49 (n=64)
#     Zone: 271 columns
#     Importance: 0.000562
#   Predicate: background3 <= 0.36 (n=67)
#     Zone: 271 columns
#     Importance: 0.000703
#   Predicate: background3 > 0.36 (n=41)
#     Zone: 271 columns
#     Importance: 0.000770
#   Predicate: background3 <= 1.60 (n=89)
#     Zone: 271 columns
#     Importance: 0.000664
#   Predicate: sum Fe > -0.60 (n=89)
#     Zone: 27 columns
#     Importance: 0.000157
#   Predicate: sum Fe <= -0.28 (n=44)
#     Zone: 27 columns
#     Importance: 0.000145
#   Predicate: sum Fe > -0.28 (n=64)
#     Zone: 27 columns
#     Importance: 0.000175
#   Predicate: sum Fe <= 0.07 (n=69)
#     Zone: 27 columns
#     Importance: 0.000102
#   Predicate: sum Fe > 0.07 (n=39)
#     Zone: 27 columns
#     Importance: 0.000269
#   Predicate: sum Fe <= 0.62 (n=89)
#     Zone: 27 columns
#     Importance: 0.000101
#   Predicate: background4 > -1.28 (n=88)
#     Zone: 219 columns
#     Importance: 0.000525
#   Predicate: background4 <= -0.62 (n=42)
#     Zone: 219 columns
#     Importance: 0.000932
#   Predicate: background4 > -0.62 (n=66)
#     Zone: 219 columns
#     Importance: 0.000576
#   Predicate: background4 <= 0.14 (n=67)
#     Zone: 219 columns
#     Importance: 0.000622
#   Predicate: background4 > 0.14 (n=41)
#     Zone: 219 columns
#     Importance: 0.000865
#   Predicate: background4 <= 1.47 (n=90)
#     Zone: 219 columns
#     Importance: 0.000536
#   Predicate: Compton scattering > -0.88 (n=86)
#     Zone: 85 columns
#     Importance: 0.000282
#   Predicate: Compton scattering <= -0.40 (n=42)
#     Zone: 85 columns
#     Importance: 0.000424
#   Predicate: Compton scattering > -0.40 (n=66)
#     Zone: 85 columns
#     Importance: 0.000313
#   Predicate: Compton scattering <= 0.05 (n=68)
#     Zone: 85 columns
#     Importance: 0.000285
#   Predicate: Compton scattering > 0.05 (n=40)
#     Zone: 85 columns
#     Importance: 0.000476
#   Predicate: Compton scattering <= 0.87 (n=88)
#     Zone: 85 columns
#     Importance: 0.000253
#   Predicate: Rayleight scattering > -0.50 (n=86)
#     Zone: 56 columns
#     Importance: 0.000111
#   Predicate: Rayleight scattering <= -0.25 (n=43)
#     Zone: 56 columns
#     Importance: 0.000155
#   Predicate: Rayleight scattering > -0.25 (n=65)
#     Zone: 56 columns
#     Importance: 0.000128
#   Predicate: Rayleight scattering <= 0.03 (n=67)
#     Zone: 56 columns
#     Importance: 0.000109
#   Predicate: Rayleight scattering > 0.03 (n=41)
#     Zone: 56 columns
#     Importance: 0.000188
#   Predicate: Rayleight scattering <= 0.53 (n=89)
#     Zone: 56 columns
#     Importance: 0.000098
#
# [Bag_2] Processing 126 predicates...
#   Predicate: Al > -0.68 (n=84)
#     Zone: 12 columns
#     Importance: 0.000102
#   Predicate: Al <= -0.19 (n=46)
#     Zone: 12 columns
#     Importance: 0.000140
#   Predicate: Al > -0.19 (n=62)
#     Zone: 12 columns
#     Importance: 0.000120
#   Predicate: Al <= 0.19 (n=66)
#     Zone: 12 columns
#     Importance: 0.000103
#   Predicate: Al > 0.19 (n=42)
#     Zone: 12 columns
#     Importance: 0.000169
#   Predicate: Al <= 0.62 (n=86)
#     Zone: 12 columns
#     Importance: 0.000103
#   Predicate: Si > -2.51 (n=83)
#     Zone: 12 columns
#     Importance: 0.067263
#   Predicate: Si <= -1.67 (n=47)
#     Zone: 12 columns
#     Importance: 0.009261
#   Predicate: Si > -1.67 (n=61)
#     Zone: 12 columns
#     Importance: 0.090325
#   Predicate: Si <= -0.72 (n=68)
#     Zone: 12 columns
#     Importance: 0.006571
#   Predicate: Si > -0.72 (n=40)
#     Zone: 12 columns
#     Importance: 0.137456
#   Predicate: Si <= 3.71 (n=87)
#     Zone: 12 columns
#     Importance: 0.026687
#   Predicate: P > -1.23 (n=84)
#     Zone: 16 columns
#     Importance: 0.000418
#   Predicate: P <= -0.59 (n=44)
#     Zone: 16 columns
#     Importance: 0.000396
#   Predicate: P > -0.59 (n=64)
#     Zone: 16 columns
#     Importance: 0.000512
#   Predicate: P <= 0.08 (n=65)
#     Zone: 16 columns
#     Importance: 0.000303
#   Predicate: P > 0.08 (n=43)
#     Zone: 16 columns
#     Importance: 0.000709
#   Predicate: P <= 1.06 (n=87)
#     Zone: 16 columns
#     Importance: 0.000319
#   Predicate: S > -0.55 (n=87)
#     Zone: 15 columns
#     Importance: 0.000264
#   Predicate: S <= -0.27 (n=44)
#     Zone: 15 columns
#     Importance: 0.000228
#   Predicate: S > -0.27 (n=64)
#     Zone: 15 columns
#     Importance: 0.000312
#   Predicate: S <= 0.09 (n=66)
#     Zone: 15 columns
#     Importance: 0.000185
#   Predicate: S > 0.09 (n=42)
#     Zone: 15 columns
#     Importance: 0.000424
#   Predicate: S <= 0.55 (n=87)
#     Zone: 15 columns
#     Importance: 0.000188
#   Predicate: Rh L + Ar > -1.66 (n=88)
#     Zone: 34 columns
#     Importance: 0.002947
#   Predicate: Rh L + Ar <= -0.77 (n=42)
#     Zone: 34 columns
#     Importance: 0.000476
#   Predicate: Rh L + Ar > -0.77 (n=66)
#     Zone: 34 columns
#     Importance: 0.003790
#   Predicate: Rh L + Ar <= -0.16 (n=67)
#     Zone: 34 columns
#     Importance: 0.000362
#   Predicate: Rh L + Ar > -0.16 (n=41)
#     Zone: 34 columns
#     Importance: 0.005997
#   Predicate: Rh L + Ar <= 1.37 (n=90)
#     Zone: 34 columns
#     Importance: 0.000736
#   Predicate: K > -6.69 (n=85)
#     Zone: 19 columns
#     Importance: 0.005511
#   Predicate: K <= -1.46 (n=45)
#     Zone: 19 columns
#     Importance: 0.006392
#   Predicate: K > -1.46 (n=63)
#     Zone: 19 columns
#     Importance: 0.006220
#   Predicate: K <= 2.15 (n=64)
#     Zone: 19 columns
#     Importance: 0.004901
#   Predicate: K > 2.15 (n=44)
#     Zone: 19 columns
#     Importance: 0.008314
#   Predicate: K <= 6.26 (n=87)
#     Zone: 19 columns
#     Importance: 0.005104
#   Predicate: Ca ka > -4.65 (n=89)
#     Zone: 21 columns
#     Importance: 0.008968
#   Predicate: Ca ka <= -1.50 (n=41)
#     Zone: 21 columns
#     Importance: 0.061526
#   Predicate: Ca ka > -1.50 (n=67)
#     Zone: 21 columns
#     Importance: 0.006519
#   Predicate: Ca ka <= 1.77 (n=67)
#     Zone: 21 columns
#     Importance: 0.038685
#   Predicate: Ca ka > 1.77 (n=41)
#     Zone: 21 columns
#     Importance: 0.008963
#   Predicate: Ca ka <= 3.95 (n=87)
#     Zone: 21 columns
#     Importance: 0.030932
#   Predicate: Ca kb > -1.81 (n=89)
#     Zone: 16 columns
#     Importance: 0.001252
#   Predicate: Ca kb <= -0.59 (n=41)
#     Zone: 16 columns
#     Importance: 0.004735
#   Predicate: Ca kb > -0.59 (n=67)
#     Zone: 16 columns
#     Importance: 0.000850
#   Predicate: Ca kb <= 0.62 (n=66)
#     Zone: 16 columns
#     Importance: 0.003067
#   Predicate: Ca kb > 0.62 (n=42)
#     Zone: 16 columns
#     Importance: 0.001158
#   Predicate: Ca kb <= 1.58 (n=87)
#     Zone: 16 columns
#     Importance: 0.002485
#   Predicate: background1 > -0.14 (n=86)
#     Zone: 12 columns
#     Importance: 0.000013
#   Predicate: background1 <= -0.05 (n=42)
#     Zone: 12 columns
#     Importance: 0.000022
#   Predicate: background1 > -0.05 (n=66)
#     Zone: 12 columns
#     Importance: 0.000012
#   Predicate: background1 <= 0.05 (n=63)
#     Zone: 12 columns
#     Importance: 0.000017
#   Predicate: background1 > 0.05 (n=45)
#     Zone: 12 columns
#     Importance: 0.000015
#   Predicate: background1 <= 0.16 (n=83)
#     Zone: 12 columns
#     Importance: 0.000016
#   Predicate: Ti ka > -0.86 (n=84)
#     Zone: 15 columns
#     Importance: 0.001433
#   Predicate: Ti ka <= -0.70 (n=45)
#     Zone: 15 columns
#     Importance: 0.000312
#   Predicate: Ti ka > -0.70 (n=63)
#     Zone: 15 columns
#     Importance: 0.001859
#   Predicate: Ti ka <= -0.52 (n=67)
#     Zone: 15 columns
#     Importance: 0.000221
#   Predicate: Ti ka > -0.52 (n=41)
#     Zone: 15 columns
#     Importance: 0.002838
#   Predicate: Ti ka <= 0.53 (n=88)
#     Zone: 15 columns
#     Importance: 0.000277
#   Predicate: Ti kb > -0.32 (n=84)
#     Zone: 22 columns
#     Importance: 0.000091
#   Predicate: Ti kb <= -0.14 (n=44)
#     Zone: 22 columns
#     Importance: 0.000141
#   Predicate: Ti kb > -0.14 (n=64)
#     Zone: 22 columns
#     Importance: 0.000107
#   Predicate: Ti kb <= 0.03 (n=65)
#     Zone: 22 columns
#     Importance: 0.000101
#   Predicate: Ti kb > 0.03 (n=43)
#     Zone: 22 columns
#     Importance: 0.000150
#   Predicate: Ti kb <= 0.20 (n=86)
#     Zone: 22 columns
#     Importance: 0.000092
#   Predicate: background2 > -0.26 (n=89)
#     Zone: 33 columns
#     Importance: 0.000030
#   Predicate: background2 <= -0.08 (n=44)
#     Zone: 33 columns
#     Importance: 0.000094
#   Predicate: background2 > -0.08 (n=64)
#     Zone: 33 columns
#     Importance: 0.000028
#   Predicate: background2 <= 0.11 (n=65)
#     Zone: 33 columns
#     Importance: 0.000071
#   Predicate: background2 > 0.11 (n=43)
#     Zone: 33 columns
#     Importance: 0.000031
#   Predicate: background2 <= 0.30 (n=84)
#     Zone: 33 columns
#     Importance: 0.000061
#   Predicate: Mn > -1.22 (n=85)
#     Zone: 20 columns
#     Importance: 0.000229
#   Predicate: Mn <= -0.41 (n=42)
#     Zone: 20 columns
#     Importance: 0.000628
#   Predicate: Mn > -0.41 (n=66)
#     Zone: 20 columns
#     Importance: 0.000235
#   Predicate: Mn <= 0.23 (n=66)
#     Zone: 20 columns
#     Importance: 0.000412
#   Predicate: Mn > 0.23 (n=42)
#     Zone: 20 columns
#     Importance: 0.000349
#   Predicate: Mn <= 1.01 (n=86)
#     Zone: 20 columns
#     Importance: 0.000350
#   Predicate: Fe ka > -3.74 (n=85)
#     Zone: 34 columns
#     Importance: 0.011680
#   Predicate: Fe ka <= -3.05 (n=45)
#     Zone: 34 columns
#     Importance: 0.002352
#   Predicate: Fe ka > -3.05 (n=63)
#     Zone: 34 columns
#     Importance: 0.015237
#   Predicate: Fe ka <= -2.26 (n=68)
#     Zone: 34 columns
#     Importance: 0.001720
#   Predicate: Fe ka > -2.26 (n=40)
#     Zone: 34 columns
#     Importance: 0.023720
#   Predicate: Fe ka <= 1.10 (n=89)
#     Zone: 34 columns
#     Importance: 0.003292
#   Predicate: Fe kb > -0.91 (n=87)
#     Zone: 23 columns
#     Importance: 0.001314
#   Predicate: Fe kb <= -0.63 (n=41)
#     Zone: 23 columns
#     Importance: 0.000289
#   Predicate: Fe kb > -0.63 (n=67)
#     Zone: 23 columns
#     Importance: 0.001677
#   Predicate: Fe kb <= -0.44 (n=64)
#     Zone: 23 columns
#     Importance: 0.000202
#   Predicate: Fe kb > -0.44 (n=44)
#     Zone: 23 columns
#     Importance: 0.002530
#   Predicate: Fe kb <= 0.33 (n=89)
#     Zone: 23 columns
#     Importance: 0.000214
#   Predicate: Ni > -0.60 (n=87)
#     Zone: 25 columns
#     Importance: 0.000102
#   Predicate: Ni <= -0.14 (n=42)
#     Zone: 25 columns
#     Importance: 0.000191
#   Predicate: Ni > -0.14 (n=66)
#     Zone: 25 columns
#     Importance: 0.000111
#   Predicate: Ni <= 0.13 (n=62)
#     Zone: 25 columns
#     Importance: 0.000158
#   Predicate: Ni > 0.13 (n=46)
#     Zone: 25 columns
#     Importance: 0.000122
#   Predicate: Ni <= 0.59 (n=86)
#     Zone: 25 columns
#     Importance: 0.000145
#   Predicate: background3 > -1.50 (n=88)
#     Zone: 271 columns
#     Importance: 0.000605
#   Predicate: background3 <= -0.49 (n=42)
#     Zone: 271 columns
#     Importance: 0.001110
#   Predicate: background3 > -0.49 (n=66)
#     Zone: 271 columns
#     Importance: 0.000614
#   Predicate: background3 <= 0.36 (n=63)
#     Zone: 271 columns
#     Importance: 0.000806
#   Predicate: background3 > 0.36 (n=45)
#     Zone: 271 columns
#     Importance: 0.000808
#   Predicate: background3 <= 1.60 (n=85)
#     Zone: 271 columns
#     Importance: 0.000747
#   Predicate: sum Fe > -0.60 (n=87)
#     Zone: 27 columns
#     Importance: 0.000144
#   Predicate: sum Fe <= -0.28 (n=40)
#     Zone: 27 columns
#     Importance: 0.000179
#   Predicate: sum Fe > -0.28 (n=68)
#     Zone: 27 columns
#     Importance: 0.000156
#   Predicate: sum Fe <= 0.07 (n=62)
#     Zone: 27 columns
#     Importance: 0.000128
#   Predicate: sum Fe > 0.07 (n=46)
#     Zone: 27 columns
#     Importance: 0.000215
#   Predicate: sum Fe <= 0.62 (n=86)
#     Zone: 27 columns
#     Importance: 0.000113
#   Predicate: background4 > -1.28 (n=88)
#     Zone: 219 columns
#     Importance: 0.000574
#   Predicate: background4 <= -0.62 (n=40)
#     Zone: 219 columns
#     Importance: 0.000860
#   Predicate: background4 > -0.62 (n=68)
#     Zone: 219 columns
#     Importance: 0.000641
#   Predicate: background4 <= 0.14 (n=61)
#     Zone: 219 columns
#     Importance: 0.000591
#   Predicate: background4 > 0.14 (n=47)
#     Zone: 219 columns
#     Importance: 0.000892
#   Predicate: background4 <= 1.47 (n=86)
#     Zone: 219 columns
#     Importance: 0.000515
#   Predicate: Compton scattering > -0.88 (n=89)
#     Zone: 85 columns
#     Importance: 0.000297
#   Predicate: Compton scattering <= -0.40 (n=40)
#     Zone: 85 columns
#     Importance: 0.000404
#   Predicate: Compton scattering > -0.40 (n=68)
#     Zone: 85 columns
#     Importance: 0.000329
#   Predicate: Compton scattering <= 0.05 (n=61)
#     Zone: 85 columns
#     Importance: 0.000288
#   Predicate: Compton scattering > 0.05 (n=47)
#     Zone: 85 columns
#     Importance: 0.000445
#   Predicate: Compton scattering <= 0.87 (n=87)
#     Zone: 85 columns
#     Importance: 0.000251
#   Predicate: Rayleight scattering > -0.50 (n=89)
#     Zone: 56 columns
#     Importance: 0.000110
#   Predicate: Rayleight scattering <= -0.25 (n=40)
#     Zone: 56 columns
#     Importance: 0.000148
#   Predicate: Rayleight scattering > -0.25 (n=68)
#     Zone: 56 columns
#     Importance: 0.000126
#   Predicate: Rayleight scattering <= 0.03 (n=60)
#     Zone: 56 columns
#     Importance: 0.000109
#   Predicate: Rayleight scattering > 0.03 (n=48)
#     Zone: 56 columns
#     Importance: 0.000166
#   Predicate: Rayleight scattering <= 0.53 (n=86)
#     Zone: 56 columns
#     Importance: 0.000093
#
# [Bag_3] Processing 126 predicates...
#   Predicate: Al > -0.68 (n=86)
#     Zone: 12 columns
#     Importance: 0.000091
#   Predicate: Al <= -0.19 (n=45)
#     Zone: 12 columns
#     Importance: 0.000141
#   Predicate: Al > -0.19 (n=63)
#     Zone: 12 columns
#     Importance: 0.000105
#   Predicate: Al <= 0.19 (n=68)
#     Zone: 12 columns
#     Importance: 0.000096
#   Predicate: Al > 0.19 (n=40)
#     Zone: 12 columns
#     Importance: 0.000160
#   Predicate: Al <= 0.62 (n=86)
#     Zone: 12 columns
#     Importance: 0.000091
#   Predicate: Si > -2.51 (n=89)
#     Zone: 12 columns
#     Importance: 0.058843
#   Predicate: Si <= -1.67 (n=44)
#     Zone: 12 columns
#     Importance: 0.008640
#   Predicate: Si > -1.67 (n=64)
#     Zone: 12 columns
#     Importance: 0.080522
#   Predicate: Si <= -0.72 (n=68)
#     Zone: 12 columns
#     Importance: 0.005773
#   Predicate: Si > -0.72 (n=40)
#     Zone: 12 columns
#     Importance: 0.128524
#   Predicate: Si <= 3.71 (n=87)
#     Zone: 12 columns
#     Importance: 0.024582
#   Predicate: P > -1.23 (n=85)
#     Zone: 16 columns
#     Importance: 0.000332
#   Predicate: P <= -0.59 (n=46)
#     Zone: 16 columns
#     Importance: 0.000419
#   Predicate: P > -0.59 (n=62)
#     Zone: 16 columns
#     Importance: 0.000383
#   Predicate: P <= 0.08 (n=66)
#     Zone: 16 columns
#     Importance: 0.000305
#   Predicate: P > 0.08 (n=42)
#     Zone: 16 columns
#     Importance: 0.000545
#   Predicate: P <= 1.06 (n=90)
#     Zone: 16 columns
#     Importance: 0.000313
#   Predicate: S > -0.55 (n=88)
#     Zone: 15 columns
#     Importance: 0.000266
#   Predicate: S <= -0.27 (n=46)
#     Zone: 15 columns
#     Importance: 0.000218
#   Predicate: S > -0.27 (n=62)
#     Zone: 15 columns
#     Importance: 0.000323
#   Predicate: S <= 0.09 (n=64)
#     Zone: 15 columns
#     Importance: 0.000182
#   Predicate: S > 0.09 (n=44)
#     Zone: 15 columns
#     Importance: 0.000417
#   Predicate: S <= 0.55 (n=87)
#     Zone: 15 columns
#     Importance: 0.000186
#   Predicate: Rh L + Ar > -1.66 (n=85)
#     Zone: 34 columns
#     Importance: 0.003737
#   Predicate: Rh L + Ar <= -0.77 (n=45)
#     Zone: 34 columns
#     Importance: 0.000679
#   Predicate: Rh L + Ar > -0.77 (n=63)
#     Zone: 34 columns
#     Importance: 0.004866
#   Predicate: Rh L + Ar <= -0.16 (n=64)
#     Zone: 34 columns
#     Importance: 0.000515
#   Predicate: Rh L + Ar > -0.16 (n=44)
#     Zone: 34 columns
#     Importance: 0.006912
#   Predicate: Rh L + Ar <= 1.37 (n=88)
#     Zone: 34 columns
#     Importance: 0.000797
#   Predicate: K > -6.69 (n=86)
#     Zone: 19 columns
#     Importance: 0.004881
#   Predicate: K <= -1.46 (n=45)
#     Zone: 19 columns
#     Importance: 0.006255
#   Predicate: K > -1.46 (n=63)
#     Zone: 19 columns
#     Importance: 0.005390
#   Predicate: K <= 2.15 (n=68)
#     Zone: 19 columns
#     Importance: 0.004421
#   Predicate: K > 2.15 (n=40)
#     Zone: 19 columns
#     Importance: 0.008011
#   Predicate: K <= 6.26 (n=86)
#     Zone: 19 columns
#     Importance: 0.004060
#   Predicate: Ca ka > -4.65 (n=87)
#     Zone: 21 columns
#     Importance: 0.008571
#   Predicate: Ca ka <= -1.50 (n=41)
#     Zone: 21 columns
#     Importance: 0.055830
#   Predicate: Ca ka > -1.50 (n=67)
#     Zone: 21 columns
#     Importance: 0.006090
#   Predicate: Ca ka <= 1.77 (n=66)
#     Zone: 21 columns
#     Importance: 0.035693
#   Predicate: Ca ka > 1.77 (n=42)
#     Zone: 21 columns
#     Importance: 0.008126
#   Predicate: Ca ka <= 3.95 (n=86)
#     Zone: 21 columns
#     Importance: 0.028572
#   Predicate: Ca kb > -1.81 (n=87)
#     Zone: 16 columns
#     Importance: 0.001189
#   Predicate: Ca kb <= -0.59 (n=42)
#     Zone: 16 columns
#     Importance: 0.004483
#   Predicate: Ca kb > -0.59 (n=66)
#     Zone: 16 columns
#     Importance: 0.000805
#   Predicate: Ca kb <= 0.62 (n=66)
#     Zone: 16 columns
#     Importance: 0.002974
#   Predicate: Ca kb > 0.62 (n=42)
#     Zone: 16 columns
#     Importance: 0.001074
#   Predicate: Ca kb <= 1.58 (n=86)
#     Zone: 16 columns
#     Importance: 0.002425
#   Predicate: background1 > -0.14 (n=87)
#     Zone: 12 columns
#     Importance: 0.000012
#   Predicate: background1 <= -0.05 (n=40)
#     Zone: 12 columns
#     Importance: 0.000019
#   Predicate: background1 > -0.05 (n=68)
#     Zone: 12 columns
#     Importance: 0.000013
#   Predicate: background1 <= 0.05 (n=63)
#     Zone: 12 columns
#     Importance: 0.000014
#   Predicate: background1 > 0.05 (n=45)
#     Zone: 12 columns
#     Importance: 0.000016
#   Predicate: background1 <= 0.16 (n=83)
#     Zone: 12 columns
#     Importance: 0.000014
#   Predicate: Ti ka > -0.86 (n=89)
#     Zone: 15 columns
#     Importance: 0.001325
#   Predicate: Ti ka <= -0.70 (n=43)
#     Zone: 15 columns
#     Importance: 0.000230
#   Predicate: Ti ka > -0.70 (n=65)
#     Zone: 15 columns
#     Importance: 0.001759
#   Predicate: Ti ka <= -0.52 (n=66)
#     Zone: 15 columns
#     Importance: 0.000160
#   Predicate: Ti ka > -0.52 (n=42)
#     Zone: 15 columns
#     Importance: 0.002705
#   Predicate: Ti ka <= 0.53 (n=86)
#     Zone: 15 columns
#     Importance: 0.000216
#   Predicate: Ti kb > -0.32 (n=88)
#     Zone: 22 columns
#     Importance: 0.000091
#   Predicate: Ti kb <= -0.14 (n=43)
#     Zone: 22 columns
#     Importance: 0.000116
#   Predicate: Ti kb > -0.14 (n=65)
#     Zone: 22 columns
#     Importance: 0.000110
#   Predicate: Ti kb <= 0.03 (n=65)
#     Zone: 22 columns
#     Importance: 0.000085
#   Predicate: Ti kb > 0.03 (n=43)
#     Zone: 22 columns
#     Importance: 0.000155
#   Predicate: Ti kb <= 0.20 (n=85)
#     Zone: 22 columns
#     Importance: 0.000078
#   Predicate: background2 > -0.26 (n=89)
#     Zone: 33 columns
#     Importance: 0.000032
#   Predicate: background2 <= -0.08 (n=42)
#     Zone: 33 columns
#     Importance: 0.000090
#   Predicate: background2 > -0.08 (n=66)
#     Zone: 33 columns
#     Importance: 0.000029
#   Predicate: background2 <= 0.11 (n=64)
#     Zone: 33 columns
#     Importance: 0.000064
#   Predicate: background2 > 0.11 (n=44)
#     Zone: 33 columns
#     Importance: 0.000035
#   Predicate: background2 <= 0.30 (n=85)
#     Zone: 33 columns
#     Importance: 0.000057
#   Predicate: Mn > -1.22 (n=88)
#     Zone: 20 columns
#     Importance: 0.000221
#   Predicate: Mn <= -0.41 (n=43)
#     Zone: 20 columns
#     Importance: 0.000569
#   Predicate: Mn > -0.41 (n=65)
#     Zone: 20 columns
#     Importance: 0.000225
#   Predicate: Mn <= 0.23 (n=65)
#     Zone: 20 columns
#     Importance: 0.000389
#   Predicate: Mn > 0.23 (n=43)
#     Zone: 20 columns
#     Importance: 0.000320
#   Predicate: Mn <= 1.01 (n=87)
#     Zone: 20 columns
#     Importance: 0.000326
#   Predicate: Fe ka > -3.74 (n=87)
#     Zone: 34 columns
#     Importance: 0.012562
#   Predicate: Fe ka <= -3.05 (n=44)
#     Zone: 34 columns
#     Importance: 0.002213
#   Predicate: Fe ka > -3.05 (n=64)
#     Zone: 34 columns
#     Importance: 0.016602
#   Predicate: Fe ka <= -2.26 (n=64)
#     Zone: 34 columns
#     Importance: 0.001678
#   Predicate: Fe ka > -2.26 (n=44)
#     Zone: 34 columns
#     Importance: 0.023919
#   Predicate: Fe ka <= 1.10 (n=87)
#     Zone: 34 columns
#     Importance: 0.003081
#   Predicate: Fe kb > -0.91 (n=87)
#     Zone: 23 columns
#     Importance: 0.001243
#   Predicate: Fe kb <= -0.63 (n=40)
#     Zone: 23 columns
#     Importance: 0.000201
#   Predicate: Fe kb > -0.63 (n=68)
#     Zone: 23 columns
#     Importance: 0.001565
#   Predicate: Fe kb <= -0.44 (n=64)
#     Zone: 23 columns
#     Importance: 0.000142
#   Predicate: Fe kb > -0.44 (n=44)
#     Zone: 23 columns
#     Importance: 0.002396
#   Predicate: Fe kb <= 0.33 (n=87)
#     Zone: 23 columns
#     Importance: 0.000168
#   Predicate: Ni > -0.60 (n=87)
#     Zone: 25 columns
#     Importance: 0.000087
#   Predicate: Ni <= -0.14 (n=42)
#     Zone: 25 columns
#     Importance: 0.000171
#   Predicate: Ni > -0.14 (n=66)
#     Zone: 25 columns
#     Importance: 0.000098
#   Predicate: Ni <= 0.13 (n=63)
#     Zone: 25 columns
#     Importance: 0.000137
#   Predicate: Ni > 0.13 (n=45)
#     Zone: 25 columns
#     Importance: 0.000110
#   Predicate: Ni <= 0.59 (n=85)
#     Zone: 25 columns
#     Importance: 0.000121
#   Predicate: background3 > -1.50 (n=88)
#     Zone: 271 columns
#     Importance: 0.000564
#   Predicate: background3 <= -0.49 (n=44)
#     Zone: 271 columns
#     Importance: 0.001001
#   Predicate: background3 > -0.49 (n=64)
#     Zone: 271 columns
#     Importance: 0.000587
#   Predicate: background3 <= 0.36 (n=67)
#     Zone: 271 columns
#     Importance: 0.000716
#   Predicate: background3 > 0.36 (n=41)
#     Zone: 271 columns
#     Importance: 0.000820
#   Predicate: background3 <= 1.60 (n=87)
#     Zone: 271 columns
#     Importance: 0.000685
#   Predicate: sum Fe > -0.60 (n=87)
#     Zone: 27 columns
#     Importance: 0.000146
#   Predicate: sum Fe <= -0.28 (n=44)
#     Zone: 27 columns
#     Importance: 0.000166
#   Predicate: sum Fe > -0.28 (n=64)
#     Zone: 27 columns
#     Importance: 0.000162
#   Predicate: sum Fe <= 0.07 (n=67)
#     Zone: 27 columns
#     Importance: 0.000119
#   Predicate: sum Fe > 0.07 (n=41)
#     Zone: 27 columns
#     Importance: 0.000236
#   Predicate: sum Fe <= 0.62 (n=89)
#     Zone: 27 columns
#     Importance: 0.000113
#   Predicate: background4 > -1.28 (n=86)
#     Zone: 219 columns
#     Importance: 0.000455
#   Predicate: background4 <= -0.62 (n=45)
#     Zone: 219 columns
#     Importance: 0.000824
#   Predicate: background4 > -0.62 (n=63)
#     Zone: 219 columns
#     Importance: 0.000476
#   Predicate: background4 <= 0.14 (n=68)
#     Zone: 219 columns
#     Importance: 0.000579
#   Predicate: background4 > 0.14 (n=40)
#     Zone: 219 columns
#     Importance: 0.000693
#   Predicate: background4 <= 1.47 (n=90)
#     Zone: 219 columns
#     Importance: 0.000517
#   Predicate: Compton scattering > -0.88 (n=86)
#     Zone: 85 columns
#     Importance: 0.000228
#   Predicate: Compton scattering <= -0.40 (n=46)
#     Zone: 85 columns
#     Importance: 0.000371
#   Predicate: Compton scattering > -0.40 (n=62)
#     Zone: 85 columns
#     Importance: 0.000242
#   Predicate: Compton scattering <= 0.05 (n=69)
#     Zone: 85 columns
#     Importance: 0.000266
#   Predicate: Compton scattering > 0.05 (n=39)
#     Zone: 85 columns
#     Importance: 0.000351
#   Predicate: Compton scattering <= 0.87 (n=89)
#     Zone: 85 columns
#     Importance: 0.000245
#   Predicate: Rayleight scattering > -0.50 (n=86)
#     Zone: 56 columns
#     Importance: 0.000087
#   Predicate: Rayleight scattering <= -0.25 (n=47)
#     Zone: 56 columns
#     Importance: 0.000138
#   Predicate: Rayleight scattering > -0.25 (n=61)
#     Zone: 56 columns
#     Importance: 0.000098
#   Predicate: Rayleight scattering <= 0.03 (n=68)
#     Zone: 56 columns
#     Importance: 0.000104
#   Predicate: Rayleight scattering > 0.03 (n=40)
#     Zone: 56 columns
#     Importance: 0.000133
#   Predicate: Rayleight scattering <= 0.53 (n=89)
#     Zone: 56 columns
#     Importance: 0.000093
#
# [Bag_4] Processing 126 predicates...
#   Predicate: Al > -0.68 (n=84)
#     Zone: 12 columns
#     Importance: 0.000095
#   Predicate: Al <= -0.19 (n=48)
#     Zone: 12 columns
#     Importance: 0.000138
#   Predicate: Al > -0.19 (n=60)
#     Zone: 12 columns
#     Importance: 0.000112
#   Predicate: Al <= 0.19 (n=67)
#     Zone: 12 columns
#     Importance: 0.000103
#   Predicate: Al > 0.19 (n=41)
#     Zone: 12 columns
#     Importance: 0.000156
#   Predicate: Al <= 0.62 (n=86)
#     Zone: 12 columns
#     Importance: 0.000099
#   Predicate: Si > -2.51 (n=87)
#     Zone: 12 columns
#     Importance: 0.060056
#   Predicate: Si <= -1.67 (n=42)
#     Zone: 12 columns
#     Importance: 0.007590
#   Predicate: Si > -1.67 (n=66)
#     Zone: 12 columns
#     Importance: 0.078037
#   Predicate: Si <= -0.72 (n=66)
#     Zone: 12 columns
#     Importance: 0.004994
#   Predicate: Si > -0.72 (n=42)
#     Zone: 12 columns
#     Importance: 0.122373
#   Predicate: Si <= 3.71 (n=88)
#     Zone: 12 columns
#     Importance: 0.026595
#   Predicate: P > -1.23 (n=85)
#     Zone: 16 columns
#     Importance: 0.000448
#   Predicate: P <= -0.59 (n=42)
#     Zone: 16 columns
#     Importance: 0.000233
#   Predicate: P > -0.59 (n=66)
#     Zone: 16 columns
#     Importance: 0.000523
#   Predicate: P <= 0.08 (n=62)
#     Zone: 16 columns
#     Importance: 0.000184
#   Predicate: P > 0.08 (n=46)
#     Zone: 16 columns
#     Importance: 0.000714
#   Predicate: P <= 1.06 (n=85)
#     Zone: 16 columns
#     Importance: 0.000240
#   Predicate: S > -0.55 (n=87)
#     Zone: 15 columns
#     Importance: 0.000279
#   Predicate: S <= -0.27 (n=43)
#     Zone: 15 columns
#     Importance: 0.000242
#   Predicate: S > -0.27 (n=65)
#     Zone: 15 columns
#     Importance: 0.000337
#   Predicate: S <= 0.09 (n=65)
#     Zone: 15 columns
#     Importance: 0.000177
#   Predicate: S > 0.09 (n=43)
#     Zone: 15 columns
#     Importance: 0.000484
#   Predicate: S <= 0.55 (n=85)
#     Zone: 15 columns
#     Importance: 0.000170
#   Predicate: Rh L + Ar > -1.66 (n=86)
#     Zone: 34 columns
#     Importance: 0.002460
#   Predicate: Rh L + Ar <= -0.77 (n=44)
#     Zone: 34 columns
#     Importance: 0.000651
#   Predicate: Rh L + Ar > -0.77 (n=64)
#     Zone: 34 columns
#     Importance: 0.003129
#   Predicate: Rh L + Ar <= -0.16 (n=66)
#     Zone: 34 columns
#     Importance: 0.000486
#   Predicate: Rh L + Ar > -0.16 (n=42)
#     Zone: 34 columns
#     Importance: 0.004686
#   Predicate: Rh L + Ar <= 1.37 (n=88)
#     Zone: 34 columns
#     Importance: 0.000733
#   Predicate: K > -6.69 (n=83)
#     Zone: 19 columns
#     Importance: 0.005003
#   Predicate: K <= -1.46 (n=48)
#     Zone: 19 columns
#     Importance: 0.006310
#   Predicate: K > -1.46 (n=60)
#     Zone: 19 columns
#     Importance: 0.005508
#   Predicate: K <= 2.15 (n=67)
#     Zone: 19 columns
#     Importance: 0.004901
#   Predicate: K > 2.15 (n=41)
#     Zone: 19 columns
#     Importance: 0.007439
#   Predicate: K <= 6.26 (n=88)
#     Zone: 19 columns
#     Importance: 0.005009
#   Predicate: Ca ka > -4.65 (n=87)
#     Zone: 21 columns
#     Importance: 0.008973
#   Predicate: Ca ka <= -1.50 (n=38)
#     Zone: 21 columns
#     Importance: 0.055465
#   Predicate: Ca ka > -1.50 (n=70)
#     Zone: 21 columns
#     Importance: 0.006649
#   Predicate: Ca ka <= 1.77 (n=61)
#     Zone: 21 columns
#     Importance: 0.035505
#   Predicate: Ca ka > 1.77 (n=47)
#     Zone: 21 columns
#     Importance: 0.008665
#   Predicate: Ca ka <= 3.95 (n=85)
#     Zone: 21 columns
#     Importance: 0.026931
#   Predicate: Ca kb > -1.81 (n=87)
#     Zone: 16 columns
#     Importance: 0.001198
#   Predicate: Ca kb <= -0.59 (n=38)
#     Zone: 16 columns
#     Importance: 0.004288
#   Predicate: Ca kb > -0.59 (n=70)
#     Zone: 16 columns
#     Importance: 0.000848
#   Predicate: Ca kb <= 0.62 (n=60)
#     Zone: 16 columns
#     Importance: 0.002825
#   Predicate: Ca kb > 0.62 (n=48)
#     Zone: 16 columns
#     Importance: 0.001101
#   Predicate: Ca kb <= 1.58 (n=85)
#     Zone: 16 columns
#     Importance: 0.002183
#   Predicate: background1 > -0.14 (n=87)
#     Zone: 12 columns
#     Importance: 0.000013
#   Predicate: background1 <= -0.05 (n=39)
#     Zone: 12 columns
#     Importance: 0.000019
#   Predicate: background1 > -0.05 (n=69)
#     Zone: 12 columns
#     Importance: 0.000013
#   Predicate: background1 <= 0.05 (n=62)
#     Zone: 12 columns
#     Importance: 0.000014
#   Predicate: background1 > 0.05 (n=46)
#     Zone: 12 columns
#     Importance: 0.000016
#   Predicate: background1 <= 0.16 (n=84)
#     Zone: 12 columns
#     Importance: 0.000015
#   Predicate: Ti ka > -0.86 (n=86)
#     Zone: 15 columns
#     Importance: 0.001170
#   Predicate: Ti ka <= -0.70 (n=45)
#     Zone: 15 columns
#     Importance: 0.000260
#   Predicate: Ti ka > -0.70 (n=63)
#     Zone: 15 columns
#     Importance: 0.001558
#   Predicate: Ti ka <= -0.52 (n=65)
#     Zone: 15 columns
#     Importance: 0.000190
#   Predicate: Ti ka > -0.52 (n=43)
#     Zone: 15 columns
#     Importance: 0.002268
#   Predicate: Ti ka <= 0.53 (n=87)
#     Zone: 15 columns
#     Importance: 0.000271
#   Predicate: Ti kb > -0.32 (n=88)
#     Zone: 22 columns
#     Importance: 0.000085
#   Predicate: Ti kb <= -0.14 (n=42)
#     Zone: 22 columns
#     Importance: 0.000113
#   Predicate: Ti kb > -0.14 (n=66)
#     Zone: 22 columns
#     Importance: 0.000102
#   Predicate: Ti kb <= 0.03 (n=63)
#     Zone: 22 columns
#     Importance: 0.000082
#   Predicate: Ti kb > 0.03 (n=45)
#     Zone: 22 columns
#     Importance: 0.000139
#   Predicate: Ti kb <= 0.20 (n=85)
#     Zone: 22 columns
#     Importance: 0.000078
#   Predicate: background2 > -0.26 (n=88)
#     Zone: 33 columns
#     Importance: 0.000031
#   Predicate: background2 <= -0.08 (n=43)
#     Zone: 33 columns
#     Importance: 0.000083
#   Predicate: background2 > -0.08 (n=65)
#     Zone: 33 columns
#     Importance: 0.000030
#   Predicate: background2 <= 0.11 (n=61)
#     Zone: 33 columns
#     Importance: 0.000064
#   Predicate: background2 > 0.11 (n=47)
#     Zone: 33 columns
#     Importance: 0.000033
#   Predicate: background2 <= 0.30 (n=84)
#     Zone: 33 columns
#     Importance: 0.000056
#   Predicate: Mn > -1.22 (n=89)
#     Zone: 20 columns
#     Importance: 0.000230
#   Predicate: Mn <= -0.41 (n=39)
#     Zone: 20 columns
#     Importance: 0.000533
#   Predicate: Mn > -0.41 (n=69)
#     Zone: 20 columns
#     Importance: 0.000226
#   Predicate: Mn <= 0.23 (n=62)
#     Zone: 20 columns
#     Importance: 0.000349
#   Predicate: Mn > 0.23 (n=46)
#     Zone: 20 columns
#     Importance: 0.000320
#   Predicate: Mn <= 1.01 (n=86)
#     Zone: 20 columns
#     Importance: 0.000289
#   Predicate: Fe ka > -3.74 (n=87)
#     Zone: 34 columns
#     Importance: 0.012595
#   Predicate: Fe ka <= -3.05 (n=44)
#     Zone: 34 columns
#     Importance: 0.001956
#   Predicate: Fe ka > -3.05 (n=64)
#     Zone: 34 columns
#     Importance: 0.016705
#   Predicate: Fe ka <= -2.26 (n=68)
#     Zone: 34 columns
#     Importance: 0.001436
#   Predicate: Fe ka > -2.26 (n=40)
#     Zone: 34 columns
#     Importance: 0.026440
#   Predicate: Fe ka <= 1.10 (n=87)
#     Zone: 34 columns
#     Importance: 0.002900
#   Predicate: Fe kb > -0.91 (n=87)
#     Zone: 23 columns
#     Importance: 0.001014
#   Predicate: Fe kb <= -0.63 (n=40)
#     Zone: 23 columns
#     Importance: 0.000235
#   Predicate: Fe kb > -0.63 (n=68)
#     Zone: 23 columns
#     Importance: 0.001280
#   Predicate: Fe kb <= -0.44 (n=64)
#     Zone: 23 columns
#     Importance: 0.000166
#   Predicate: Fe kb > -0.44 (n=44)
#     Zone: 23 columns
#     Importance: 0.001950
#   Predicate: Fe kb <= 0.33 (n=87)
#     Zone: 23 columns
#     Importance: 0.000186
#   Predicate: Ni > -0.60 (n=87)
#     Zone: 25 columns
#     Importance: 0.000086
#   Predicate: Ni <= -0.14 (n=43)
#     Zone: 25 columns
#     Importance: 0.000160
#   Predicate: Ni > -0.14 (n=65)
#     Zone: 25 columns
#     Importance: 0.000096
#   Predicate: Ni <= 0.13 (n=61)
#     Zone: 25 columns
#     Importance: 0.000138
#   Predicate: Ni > 0.13 (n=47)
#     Zone: 25 columns
#     Importance: 0.000100
#   Predicate: Ni <= 0.59 (n=85)
#     Zone: 25 columns
#     Importance: 0.000130
#   Predicate: background3 > -1.50 (n=88)
#     Zone: 271 columns
#     Importance: 0.000565
#   Predicate: background3 <= -0.49 (n=40)
#     Zone: 271 columns
#     Importance: 0.001124
#   Predicate: background3 > -0.49 (n=68)
#     Zone: 271 columns
#     Importance: 0.000554
#   Predicate: background3 <= 0.36 (n=62)
#     Zone: 271 columns
#     Importance: 0.000796
#   Predicate: background3 > 0.36 (n=46)
#     Zone: 271 columns
#     Importance: 0.000723
#   Predicate: background3 <= 1.60 (n=84)
#     Zone: 271 columns
#     Importance: 0.000685
#   Predicate: sum Fe > -0.60 (n=87)
#     Zone: 27 columns
#     Importance: 0.000132
#   Predicate: sum Fe <= -0.28 (n=39)
#     Zone: 27 columns
#     Importance: 0.000161
#   Predicate: sum Fe > -0.28 (n=69)
#     Zone: 27 columns
#     Importance: 0.000142
#   Predicate: sum Fe <= 0.07 (n=64)
#     Zone: 27 columns
#     Importance: 0.000110
#   Predicate: sum Fe > 0.07 (n=44)
#     Zone: 27 columns
#     Importance: 0.000205
#   Predicate: sum Fe <= 0.62 (n=87)
#     Zone: 27 columns
#     Importance: 0.000096
#   Predicate: background4 > -1.28 (n=88)
#     Zone: 219 columns
#     Importance: 0.000500
#   Predicate: background4 <= -0.62 (n=38)
#     Zone: 219 columns
#     Importance: 0.001031
#   Predicate: background4 > -0.62 (n=70)
#     Zone: 219 columns
#     Importance: 0.000534
#   Predicate: background4 <= 0.14 (n=62)
#     Zone: 219 columns
#     Importance: 0.000670
#   Predicate: background4 > 0.14 (n=46)
#     Zone: 219 columns
#     Importance: 0.000761
#   Predicate: background4 <= 1.47 (n=86)
#     Zone: 219 columns
#     Importance: 0.000559
#   Predicate: Compton scattering > -0.88 (n=88)
#     Zone: 85 columns
#     Importance: 0.000262
#   Predicate: Compton scattering <= -0.40 (n=39)
#     Zone: 85 columns
#     Importance: 0.000464
#   Predicate: Compton scattering > -0.40 (n=69)
#     Zone: 85 columns
#     Importance: 0.000279
#   Predicate: Compton scattering <= 0.05 (n=63)
#     Zone: 85 columns
#     Importance: 0.000312
#   Predicate: Compton scattering > 0.05 (n=45)
#     Zone: 85 columns
#     Importance: 0.000394
#   Predicate: Compton scattering <= 0.87 (n=86)
#     Zone: 85 columns
#     Importance: 0.000261
#   Predicate: Rayleight scattering > -0.50 (n=87)
#     Zone: 56 columns
#     Importance: 0.000102
#   Predicate: Rayleight scattering <= -0.25 (n=38)
#     Zone: 56 columns
#     Importance: 0.000171
#   Predicate: Rayleight scattering > -0.25 (n=70)
#     Zone: 56 columns
#     Importance: 0.000111
#   Predicate: Rayleight scattering <= 0.03 (n=62)
#     Zone: 56 columns
#     Importance: 0.000117
#   Predicate: Rayleight scattering > 0.03 (n=46)
#     Zone: 56 columns
#     Importance: 0.000153
#   Predicate: Rayleight scattering <= 0.53 (n=87)
#     Zone: 56 columns
#     Importance: 0.000100
#
# [Bag_5] Processing 127 predicates...
#   Predicate: Al > -0.68 (n=88)
#     Zone: 12 columns
#     Importance: 0.000116
#   Predicate: Al <= -0.19 (n=39)
#     Zone: 12 columns
#     Importance: 0.000124
#   Predicate: Al > -0.19 (n=69)
#     Zone: 12 columns
#     Importance: 0.000136
#   Predicate: Al <= 0.19 (n=61)
#     Zone: 12 columns
#     Importance: 0.000084
#   Predicate: Al > 0.19 (n=47)
#     Zone: 12 columns
#     Importance: 0.000193
#   Predicate: Al <= 0.62 (n=84)
#     Zone: 12 columns
#     Importance: 0.000089
#   Predicate: Si > -2.51 (n=85)
#     Zone: 12 columns
#     Importance: 0.067343
#   Predicate: Si <= -1.67 (n=43)
#     Zone: 12 columns
#     Importance: 0.009205
#   Predicate: Si > -1.67 (n=65)
#     Zone: 12 columns
#     Importance: 0.087023
#   Predicate: Si <= -0.72 (n=66)
#     Zone: 12 columns
#     Importance: 0.006158
#   Predicate: Si > -0.72 (n=42)
#     Zone: 12 columns
#     Importance: 0.134425
#   Predicate: Si <= 3.71 (n=87)
#     Zone: 12 columns
#     Importance: 0.035352
#   Predicate: P > -1.23 (n=88)
#     Zone: 16 columns
#     Importance: 0.000405
#   Predicate: P <= -0.59 (n=43)
#     Zone: 16 columns
#     Importance: 0.000456
#   Predicate: P > -0.59 (n=65)
#     Zone: 16 columns
#     Importance: 0.000474
#   Predicate: P <= 0.08 (n=68)
#     Zone: 16 columns
#     Importance: 0.000326
#   Predicate: P > 0.08 (n=40)
#     Zone: 16 columns
#     Importance: 0.000705
#   Predicate: P <= 1.06 (n=87)
#     Zone: 16 columns
#     Importance: 0.000351
#   Predicate: S > -0.55 (n=86)
#     Zone: 15 columns
#     Importance: 0.000291
#   Predicate: S <= -0.27 (n=45)
#     Zone: 15 columns
#     Importance: 0.000257
#   Predicate: S > -0.27 (n=63)
#     Zone: 15 columns
#     Importance: 0.000348
#   Predicate: S <= 0.09 (n=65)
#     Zone: 15 columns
#     Importance: 0.000209
#   Predicate: S > 0.09 (n=43)
#     Zone: 15 columns
#     Importance: 0.000462
#   Predicate: S <= 0.55 (n=84)
#     Zone: 15 columns
#     Importance: 0.000209
#   Predicate: Rh L + Ar > -1.66 (n=87)
#     Zone: 34 columns
#     Importance: 0.003664
#   Predicate: Rh L + Ar <= -0.77 (n=45)
#     Zone: 34 columns
#     Importance: 0.000628
#   Predicate: Rh L + Ar > -0.77 (n=63)
#     Zone: 34 columns
#     Importance: 0.004876
#   Predicate: Rh L + Ar <= -0.16 (n=66)
#     Zone: 34 columns
#     Importance: 0.000482
#   Predicate: Rh L + Ar > -0.16 (n=42)
#     Zone: 34 columns
#     Importance: 0.007230
#   Predicate: Rh L + Ar <= 1.37 (n=86)
#     Zone: 34 columns
#     Importance: 0.000806
#   Predicate: K > -6.69 (n=89)
#     Zone: 19 columns
#     Importance: 0.005965
#   Predicate: K <= -1.46 (n=39)
#     Zone: 19 columns
#     Importance: 0.005537
#   Predicate: K > -1.46 (n=69)
#     Zone: 19 columns
#     Importance: 0.006812
#   Predicate: K <= 2.15 (n=60)
#     Zone: 19 columns
#     Importance: 0.004047
#   Predicate: K > 2.15 (n=48)
#     Zone: 19 columns
#     Importance: 0.009233
#   Predicate: K <= 6.26 (n=85)
#     Zone: 19 columns
#     Importance: 0.004426
#   Predicate: Ca ka > -4.65 (n=83)
#     Zone: 21 columns
#     Importance: 0.008154
#   Predicate: Ca ka <= -1.50 (n=48)
#     Zone: 21 columns
#     Importance: 0.063895
#   Predicate: Ca ka > -1.50 (n=60)
#     Zone: 21 columns
#     Importance: 0.005939
#   Predicate: Ca ka <= 1.77 (n=69)
#     Zone: 21 columns
#     Importance: 0.044961
#   Predicate: Ca ka > 1.77 (n=39)
#     Zone: 21 columns
#     Importance: 0.008230
#   Predicate: Ca ka <= 3.95 (n=90)
#     Zone: 21 columns
#     Importance: 0.035637
#   Predicate: Ca kb > -1.81 (n=83)
#     Zone: 16 columns
#     Importance: 0.001152
#   Predicate: Ca kb <= -0.59 (n=47)
#     Zone: 16 columns
#     Importance: 0.005047
#   Predicate: Ca kb > -0.59 (n=61)
#     Zone: 16 columns
#     Importance: 0.000747
#   Predicate: Ca kb <= 0.62 (n=69)
#     Zone: 16 columns
#     Importance: 0.003510
#   Predicate: Ca kb > 0.62 (n=39)
#     Zone: 16 columns
#     Importance: 0.001041
#   Predicate: Ca kb <= 1.58 (n=90)
#     Zone: 16 columns
#     Importance: 0.002838
#   Predicate: background1 > -0.14 (n=82)
#     Zone: 12 columns
#     Importance: 0.000012
#   Predicate: background1 <= -0.05 (n=45)
#     Zone: 12 columns
#     Importance: 0.000022
#   Predicate: background1 > -0.05 (n=63)
#     Zone: 12 columns
#     Importance: 0.000012
#   Predicate: background1 <= 0.05 (n=67)
#     Zone: 12 columns
#     Importance: 0.000017
#   Predicate: background1 > 0.05 (n=41)
#     Zone: 12 columns
#     Importance: 0.000015
#   Predicate: background1 <= 0.16 (n=88)
#     Zone: 12 columns
#     Importance: 0.000017
#   Predicate: Ti ka > -0.86 (n=84)
#     Zone: 15 columns
#     Importance: 0.002036
#   Predicate: Ti ka <= -0.70 (n=48)
#     Zone: 15 columns
#     Importance: 0.000278
#   Predicate: Ti ka > -0.70 (n=60)
#     Zone: 15 columns
#     Importance: 0.002796
#   Predicate: Ti ka <= -0.52 (n=64)
#     Zone: 15 columns
#     Importance: 0.000215
#   Predicate: Ti ka > -0.52 (n=44)
#     Zone: 15 columns
#     Importance: 0.003803
#   Predicate: Ti ka <= 0.53 (n=84)
#     Zone: 15 columns
#     Importance: 0.000289
#   Predicate: Ti kb > -0.32 (n=83)
#     Zone: 22 columns
#     Importance: 0.000120
#   Predicate: Ti kb <= -0.14 (n=45)
#     Zone: 22 columns
#     Importance: 0.000134
#   Predicate: Ti kb > -0.14 (n=63)
#     Zone: 22 columns
#     Importance: 0.000146
#   Predicate: Ti kb <= 0.03 (n=66)
#     Zone: 22 columns
#     Importance: 0.000098
#   Predicate: Ti kb > 0.03 (n=42)
#     Zone: 22 columns
#     Importance: 0.000208
#   Predicate: Ti kb <= 0.20 (n=84)
#     Zone: 22 columns
#     Importance: 0.000092
#   Predicate: background2 > -0.26 (n=84)
#     Zone: 33 columns
#     Importance: 0.000031
#   Predicate: background2 <= -0.08 (n=44)
#     Zone: 33 columns
# ...
# Removed: K <= 2.15 -> K <= 6.26 (0.0048) | Kept: K <= 6.26 -> K <= 2.15 (0.0266)
# Removed: Ca kb <= 0.62 -> Fe ka <= 1.10 (0.0069) | Kept: Fe ka <= 1.10 -> Ca kb <= 0.62 (0.0104)
# Removed: Fe ka <= 1.10 -> Fe kb > -0.44 (0.0064) | Kept: Fe kb > -0.44 -> Fe ka <= 1.10 (0.0102)
# Removed: Ti ka > -0.52 -> Fe ka <= 1.10 (0.0031) | Kept: Fe ka <= 1.10 -> Ti ka > -0.52 (0.0032)
# Removed: Ti ka > -0.52 -> Ca kb <= 0.62 (0.0036) | Kept: Ca kb <= 0.62 -> Ti ka > -0.52 (0.0065)
# Removed: Fe ka <= -3.05 -> Ca kb <= 1.58 (0.0047) | Kept: Ca kb <= 1.58 -> Fe ka <= -3.05 (0.0073)
# Removed: Ti ka > -0.70 -> Fe ka <= -3.05 (0.0021) | Kept: Fe ka <= -3.05 -> Ti ka > -0.70 (0.0088)
# Removed: Fe ka <= -3.05 -> Fe kb > -0.63 (0.0022) | Kept: Fe kb > -0.63 -> Fe ka <= -3.05 (0.0067)
# Removed: background3 <= -0.49 -> Ca kb > 0.62 (0.0029) | Kept: Ca kb > 0.62 -> background3 <= -0.49 (0.0073)
# Removed: P > 0.08 -> Rh L + Ar <= 1.37 (0.0007) | Kept: Rh L + Ar <= 1.37 -> P > 0.08 (0.0029)
# Removed: background3 <= 0.36 -> Rh L + Ar <= 1.37 (0.0013) | Kept: Rh L + Ar <= 1.37 -> background3 <= 0.36 (0.0014)
# Removed: background3 <= 1.60 -> Rh L + Ar <= 1.37 (0.0006) | Kept: Rh L + Ar <= 1.37 -> background3 <= 1.60 (0.0007)
# Removed: background4 > 0.14 -> background4 <= -0.62 (0.0008) | Kept: background4 <= -0.62 -> background4 > 0.14 (0.0026)
# Removed: background3 <= 0.36 -> Ca kb > -0.59 (0.0014) | Kept: Ca kb > -0.59 -> background3 <= 0.36 (0.0024)
# Removed: background4 <= -0.62 -> Ca kb > -0.59 (0.0007) | Kept: Ca kb > -0.59 -> background4 <= -0.62 (0.0016)
# Removed: background3 > 0.36 -> Ca kb > -0.59 (0.0007) | Kept: Ca kb > -0.59 -> background3 > 0.36 (0.0024)
# Removed: background3 <= 0.36 -> background4 <= -0.62 (0.0006) | Kept: background4 <= -0.62 -> background3 <= 0.36 (0.0016)
# Removed: background3 <= 0.36 -> P > 0.08 (0.0006) | Kept: P > 0.08 -> background3 <= 0.36 (0.0007)
# Removed: background3 > 0.36 -> background4 <= -0.62 (0.0014) | Kept: background4 <= -0.62 -> background3 > 0.36 (0.0022)
# Removed: background3 <= 1.60 -> background3 > 0.36 (0.0007) | Kept: background3 > 0.36 -> background3 <= 1.60 (0.0013)
# Removed: background3 <= 1.60 -> P > 0.08 (0.0018) | Kept: P > 0.08 -> background3 <= 1.60 (0.0020)
# Removed: P > 0.08 -> background4 <= 0.14 (0.0007) | Kept: background4 <= 0.14 -> P > 0.08 (0.0012)
# Removed: Compton scattering > 0.05 -> Mn <= -0.41 (0.0004) | Kept: Mn <= -0.41 -> Compton scattering > 0.05 (0.0010)
# Removed: Mn <= -0.41 -> Rh L + Ar <= -0.16 (0.0004) | Kept: Rh L + Ar <= -0.16 -> Mn <= -0.41 (0.0005)
# Removed: Mn <= -0.41 -> background4 > -1.28 (0.0005) | Kept: background4 > -1.28 -> Mn <= -0.41 (0.0005)
# Removed: Mn <= -0.41 -> background3 > -1.50 (0.0005) | Kept: background3 > -1.50 -> Mn <= -0.41 (0.0009)
# Removed: background4 > -0.62 -> Rh L + Ar <= -0.77 (0.0011) | Kept: Rh L + Ar <= -0.77 -> background4 > -0.62 (0.0019)
# Removed: background4 > -1.28 -> Rh L + Ar <= -0.77 (0.0005) | Kept: Rh L + Ar <= -0.77 -> background4 > -1.28 (0.0011)
# Removed: Rh L + Ar <= -0.77 -> background4 <= 0.14 (0.0006) | Kept: background4 <= 0.14 -> Rh L + Ar <= -0.77 (0.0006)
# Removed: background3 > -1.50 -> background4 > -0.62 (0.0010) | Kept: background4 > -0.62 -> background3 > -1.50 (0.0011)
# Removed: background3 > -0.49 -> background4 > -0.62 (0.0005) | Kept: background4 > -0.62 -> background3 > -0.49 (0.0011)
# Removed: background4 <= 1.47 -> background4 > -0.62 (0.0004) | Kept: background4 > -0.62 -> background4 <= 1.47 (0.0006)
# Removed: background3 > -1.50 -> background3 > -0.49 (0.0010) | Kept: background3 > -0.49 -> background3 > -1.50 (0.0020)
# Removed: background3 > -1.50 -> background4 <= 0.14 (0.0005) | Kept: background4 <= 0.14 -> background3 > -1.50 (0.0006)
# Removed: background3 > -0.49 -> background4 <= 1.47 (0.0004) | Kept: background4 <= 1.47 -> background3 > -0.49 (0.0011)
# Removed: background4 > -1.28 -> background4 <= 0.14 (0.0005) | Kept: background4 <= 0.14 -> background4 > -1.28 (0.0010)
# Removed: P > -0.59 -> S > 0.09 (0.0005) | Kept: S > 0.09 -> P > -0.59 (0.0009)
# Removed: Mn > 0.23 -> S > 0.09 (0.0003) | Kept: S > 0.09 -> Mn > 0.23 (0.0003)
# Removed: Compton scattering <= -0.40 -> S > 0.09 (0.0004) | Kept: S > 0.09 -> Compton scattering <= -0.40 (0.0004)
# Removed: P > -0.59 -> background4 <= 1.47 (0.0005) | Kept: background4 <= 1.47 -> P > -0.59 (0.0013)
# Removed: P > -0.59 -> Compton scattering > 0.05 (0.0005) | Kept: Compton scattering > 0.05 -> P > -0.59 (0.0009)
# Removed: Compton scattering > 0.05 -> Rh L + Ar <= -0.16 (0.0004) | Kept: Rh L + Ar <= -0.16 -> Compton scattering > 0.05 (0.0010)
# Removed: Rh L + Ar <= -0.16 -> Compton scattering <= -0.40 (0.0004) | Kept: Compton scattering <= -0.40 -> Rh L + Ar <= -0.16 (0.0011)
# Removed: P <= -0.59 -> Compton scattering > 0.05 (0.0004) | Kept: Compton scattering > 0.05 -> P <= -0.59 (0.0007)
# Removed: P > -1.23 -> P <= -0.59 (0.0004) | Kept: P <= -0.59 -> P > -1.23 (0.0011)
# Removed: P <= -0.59 -> P <= 1.06 (0.0002) | Kept: P <= 1.06 -> P <= -0.59 (0.0002)
# Removed: P > -1.23 -> Mn <= 0.23 (0.0008) | Kept: Mn <= 0.23 -> P > -1.23 (0.0012)
# Removed: Mn <= 0.23 -> Compton scattering <= -0.40 (0.0003) | Kept: Compton scattering <= -0.40 -> Mn <= 0.23 (0.0004)
# Removed: sum Fe > 0.07 -> Mn <= 0.23 (0.0003) | Kept: Mn <= 0.23 -> sum Fe > 0.07 (0.0003)
# Removed: Compton scattering > -0.40 -> Mn <= 0.23 (0.0003) | Kept: Mn <= 0.23 -> Compton scattering > -0.40 (0.0007)
# Removed: S > -0.27 -> Mn <= 1.01 (0.0003) | Kept: Mn <= 1.01 -> S > -0.27 (0.0006)
# Removed: Mn > 0.23 -> S > -0.27 (0.0003) | Kept: S > -0.27 -> Mn > 0.23 (0.0009)
# Removed: Compton scattering <= 0.05 -> S > -0.27 (0.0002) | Kept: S > -0.27 -> Compton scattering <= 0.05 (0.0003)
# Removed: Mn > 0.23 -> Mn <= 1.01 (0.0003) | Kept: Mn <= 1.01 -> Mn > 0.23 (0.0003)
# Removed: Compton scattering <= 0.05 -> Mn <= 1.01 (0.0003) | Kept: Mn <= 1.01 -> Compton scattering <= 0.05 (0.0006)
# Removed: Mn > 0.23 -> Compton scattering <= -0.40 (0.0003) | Kept: Compton scattering <= -0.40 -> Mn > 0.23 (0.0007)
# Removed: S > -0.55 -> Compton scattering > -0.88 (0.0003) | Kept: Compton scattering > -0.88 -> S > -0.55 (0.0005)
# Removed: Ti ka <= -0.70 -> S > -0.55 (0.0003) | Kept: S > -0.55 -> Ti ka <= -0.70 (0.0005)
# Removed: S > -0.55 -> Ti ka <= 0.53 (0.0003) | Kept: Ti ka <= 0.53 -> S > -0.55 (0.0003)
# Removed: Compton scattering > -0.88 -> P <= 0.08 (0.0003) | Kept: P <= 0.08 -> Compton scattering > -0.88 (0.0003)
# Removed: sum Fe > 0.07 -> Ti ka <= 0.53 (0.0003) | Kept: Ti ka <= 0.53 -> sum Fe > 0.07 (0.0006)
# Removed: Compton scattering > -0.40 -> Ti ka <= 0.53 (0.0003) | Kept: Ti ka <= 0.53 -> Compton scattering > -0.40 (0.0003)
# Removed: Compton scattering > -0.88 -> Ti ka <= 0.53 (0.0002) | Kept: Ti ka <= 0.53 -> Compton scattering > -0.88 (0.0006)
# Removed: Compton scattering > -0.40 -> Mn > 0.23 (0.0003) | Kept: Mn > 0.23 -> Compton scattering > -0.40 (0.0003)
# Removed: Compton scattering > -0.40 -> Compton scattering <= 0.05 (0.0002) | Kept: Compton scattering <= 0.05 -> Compton scattering > -0.40 (0.0003)
# Removed: S <= -0.27 -> Ti ka <= -0.70 (0.0002) | Kept: Ti ka <= -0.70 -> S <= -0.27 (0.0002)
# Removed: Mn > -0.41 -> Ti ka <= -0.70 (0.0003) | Kept: Ti ka <= -0.70 -> Mn > -0.41 (0.0005)
# Removed: Mn > -0.41 -> Compton scattering > -0.88 (0.0002) | Kept: Compton scattering > -0.88 -> Mn > -0.41 (0.0003)
# Removed: Mn > -1.22 -> S <= -0.27 (0.0002) | Kept: S <= -0.27 -> Mn > -1.22 (0.0004)
# Removed: S <= -0.27 -> Compton scattering <= 0.87 (0.0002) | Kept: Compton scattering <= 0.87 -> S <= -0.27 (0.0004)
# Removed: Fe kb <= -0.63 -> Compton scattering <= 0.05 (0.0002) | Kept: Compton scattering <= 0.05 -> Fe kb <= -0.63 (0.0003)
# Removed: Fe kb <= -0.63 -> Compton scattering <= 0.87 (0.0003) | Kept: Compton scattering <= 0.87 -> Fe kb <= -0.63 (0.0005)
# Removed: Mn > -0.41 -> Fe kb <= -0.63 (0.0002) | Kept: Fe kb <= -0.63 -> Mn > -0.41 (0.0005)
# Removed: Compton scattering <= 0.87 -> Mn > -1.22 (0.0002) | Kept: Mn > -1.22 -> Compton scattering <= 0.87 (0.0007)
# Removed: S <= 0.55 -> S <= 0.09 (0.0002) | Kept: S <= 0.09 -> S <= 0.55 (0.0009)
# Removed: S <= 0.09 -> Al > 0.19 (0.0003) | Kept: Al > 0.19 -> S <= 0.09 (0.0004)
# Removed: Ti kb > 0.03 -> S <= 0.09 (0.0001) | Kept: S <= 0.09 -> Ti kb > 0.03 (0.0002)
# Removed: Fe kb <= 0.33 -> S <= 0.55 (0.0002) | Kept: S <= 0.55 -> Fe kb <= 0.33 (0.0004)
# Removed: sum Fe <= -0.28 -> S <= 0.55 (0.0002) | Kept: S <= 0.55 -> sum Fe <= -0.28 (0.0002)
# Removed: S <= 0.55 -> Ti ka <= -0.52 (0.0002) | Kept: Ti ka <= -0.52 -> S <= 0.55 (0.0002)
# Removed: Fe kb <= 0.33 -> sum Fe > -0.28 (0.0004) | Kept: sum Fe > -0.28 -> Fe kb <= 0.33 (0.0004)
# Removed: Ti ka <= -0.52 -> Fe kb <= 0.33 (0.0002) | Kept: Fe kb <= 0.33 -> Ti ka <= -0.52 (0.0006)
# Removed: Rayleight scattering > 0.03 -> Fe kb <= 0.33 (0.0002) | Kept: Fe kb <= 0.33 -> Rayleight scattering > 0.03 (0.0002)
# Removed: sum Fe > -0.28 -> Ti ka <= -0.52 (0.0002) | Kept: Ti ka <= -0.52 -> sum Fe > -0.28 (0.0002)
# Removed: sum Fe > -0.28 -> Rayleight scattering <= -0.25 (0.0001) | Kept: Rayleight scattering <= -0.25 -> sum Fe > -0.28 (0.0001)
# Removed: Rayleight scattering <= -0.25 -> Ti ka <= -0.52 (0.0001) | Kept: Ti ka <= -0.52 -> Rayleight scattering <= -0.25 (0.0002)
# Removed: Al > 0.19 -> Ti ka <= -0.52 (0.0002) | Kept: Ti ka <= -0.52 -> Al > 0.19 (0.0002)
# Removed: Ni <= -0.14 -> Ti ka <= -0.52 (0.0002) | Kept: Ti ka <= -0.52 -> Ni <= -0.14 (0.0003)
# Removed: Mn > -1.22 -> Mn > -0.41 (0.0002) | Kept: Mn > -0.41 -> Mn > -1.22 (0.0009)
# Removed: sum Fe > -0.60 -> Rayleight scattering > 0.03 (0.0002) | Kept: Rayleight scattering > 0.03 -> sum Fe > -0.60 (0.0003)
# Removed: Rayleight scattering > 0.03 -> Fe kb <= -0.44 (0.0002) | Kept: Fe kb <= -0.44 -> Rayleight scattering > 0.03 (0.0004)
# Removed: sum Fe <= -0.28 -> Fe kb <= -0.44 (0.0001) | Kept: Fe kb <= -0.44 -> sum Fe <= -0.28 (0.0003)
# Removed: Al > 0.19 -> Rayleight scattering > 0.03 (0.0002) | Kept: Rayleight scattering > 0.03 -> Al > 0.19 (0.0003)
# Removed: Ni <= -0.14 -> Ti kb > 0.03 (0.0001) | Kept: Ti kb > 0.03 -> Ni <= -0.14 (0.0001)
# Removed: Ti kb > 0.03 -> sum Fe <= -0.28 (0.0001) | Kept: sum Fe <= -0.28 -> Ti kb > 0.03 (0.0003)
# Removed: sum Fe <= -0.28 -> Rayleight scattering > 0.03 (0.0001) | Kept: Rayleight scattering > 0.03 -> sum Fe <= -0.28 (0.0002)
# Removed: Ni <= 0.13 -> Rayleight scattering > 0.03 (0.0001) | Kept: Rayleight scattering > 0.03 -> Ni <= 0.13 (0.0001)
# Removed: Ni <= 0.13 -> Rayleight scattering > -0.25 (0.0002) | Kept: Rayleight scattering > -0.25 -> Ni <= 0.13 (0.0002)
# Removed: Ti kb > -0.14 -> Ni <= 0.13 (0.0001) | Kept: Ni <= 0.13 -> Ti kb > -0.14 (0.0001)
# Removed: Al > -0.19 -> Ni <= 0.59 (0.0001) | Kept: Ni <= 0.59 -> Al > -0.19 (0.0002)
# Removed: Ni > 0.13 -> Ni <= 0.59 (0.0002) | Kept: Ni <= 0.59 -> Ni > 0.13 (0.0002)
# Removed: Ni > 0.13 -> Al > -0.19 (0.0001) | Kept: Al > -0.19 -> Ni > 0.13 (0.0001)
# Removed: Ni > 0.13 -> Rayleight scattering <= 0.03 (0.0001) | Kept: Rayleight scattering <= 0.03 -> Ni > 0.13 (0.0001)
# Removed: Ti kb <= -0.14 -> Ni > 0.13 (0.0001) | Kept: Ni > 0.13 -> Ti kb <= -0.14 (0.0001)
# Removed: Rayleight scattering > -0.25 -> Al <= -0.19 (0.0001) | Kept: Al <= -0.19 -> Rayleight scattering > -0.25 (0.0002)
# Removed: Rayleight scattering <= 0.03 -> Al <= -0.19 (0.0001) | Kept: Al <= -0.19 -> Rayleight scattering <= 0.03 (0.0001)
# Removed: Al <= -0.19 -> sum Fe <= 0.07 (0.0001) | Kept: sum Fe <= 0.07 -> Al <= -0.19 (0.0001)
# Removed: Ti kb <= -0.14 -> Al > -0.19 (0.0002) | Kept: Al > -0.19 -> Ti kb <= -0.14 (0.0002)
# Removed: Ti kb > -0.14 -> sum Fe <= 0.07 (0.0001) | Kept: sum Fe <= 0.07 -> Ti kb > -0.14 (0.0001)
# Removed: Rayleight scattering > -0.50 -> sum Fe <= 0.07 (0.0002) | Kept: sum Fe <= 0.07 -> Rayleight scattering > -0.50 (0.0002)
# Removed: Rayleight scattering > -0.25 -> Al > -0.19 (0.0001) | Kept: Al > -0.19 -> Rayleight scattering > -0.25 (0.0002)
# Removed: Rayleight scattering > -0.50 -> Al > -0.19 (0.0001) | Kept: Al > -0.19 -> Rayleight scattering > -0.50 (0.0001)
# Removed: Al > -0.68 -> sum Fe <= 0.62 (0.0001) | Kept: sum Fe <= 0.62 -> Al > -0.68 (0.0002)
# Removed: sum Fe <= 0.62 -> Rayleight scattering <= 0.03 (0.0001) | Kept: Rayleight scattering <= 0.03 -> sum Fe <= 0.62 (0.0003)
# Removed: Ti kb > -0.32 -> sum Fe <= 0.62 (0.0001) | Kept: sum Fe <= 0.62 -> Ti kb > -0.32 (0.0001)
# Removed: Rayleight scattering > -0.50 -> Ni > -0.14 (0.0001) | Kept: Ni > -0.14 -> Rayleight scattering > -0.50 (0.0002)
# Removed: Ni > -0.14 -> Rayleight scattering <= 0.53 (0.0001) | Kept: Rayleight scattering <= 0.53 -> Ni > -0.14 (0.0001)
# Removed: Ni > -0.14 -> Ti kb > -0.32 (0.0001) | Kept: Ti kb > -0.32 -> Ni > -0.14 (0.0001)
# Removed: Rayleight scattering <= 0.53 -> Al > -0.68 (0.0001) | Kept: Al > -0.68 -> Rayleight scattering <= 0.53 (0.0002)
# Removed: background2 <= -0.08 -> Ni > -0.60 (0.0001) | Kept: Ni > -0.60 -> background2 <= -0.08 (0.0001)
# Removed: Ti kb <= 0.20 -> Ni > -0.60 (0.0001) | Kept: Ni > -0.60 -> Ti kb <= 0.20 (0.0001)
# Removed: Ni > -0.60 -> Rayleight scattering <= 0.03 (0.0001) | Kept: Rayleight scattering <= 0.03 -> Ni > -0.60 (0.0001)
# Removed: Ti kb <= 0.03 -> background2 <= -0.08 (0.0001) | Kept: background2 <= -0.08 -> Ti kb <= 0.03 (0.0002)
# Removed: background2 <= -0.08 -> Ti kb <= 0.20 (0.0001) | Kept: Ti kb <= 0.20 -> background2 <= -0.08 (0.0001)
# Removed: Ti kb <= 0.03 -> Al <= 0.62 (0.0001) | Kept: Al <= 0.62 -> Ti kb <= 0.03 (0.0002)
# Removed: Al <= 0.19 -> Al <= 0.62 (0.0001) | Kept: Al <= 0.62 -> Al <= 0.19 (0.0004)
# Removed: Rayleight scattering <= 0.53 -> Al <= 0.19 (0.0001) | Kept: Al <= 0.19 -> Rayleight scattering <= 0.53 (0.0003)
# Removed: Ti kb <= 0.20 -> Rayleight scattering <= 0.53 (0.0001) | Kept: Rayleight scattering <= 0.53 -> Ti kb <= 0.20 (0.0001)
# Removed: background2 > -0.26 -> background2 > 0.11 (0.0000) | Kept: background2 > 0.11 -> background2 > -0.26 (0.0002)
# Removed: background1 <= 0.05 -> background1 <= 0.16 (0.0000) | Kept: background1 <= 0.16 -> background1 <= 0.05 (0.0001)
# Removed: background1 <= 0.16 -> background1 > 0.05 (0.0000) | Kept: background1 > 0.05 -> background1 <= 0.16 (0.0001)
# Removed: background1 > 0.05 -> background1 <= 0.05 (0.0000) | Kept: background1 <= 0.05 -> background1 > 0.05 (0.0000)
# Removed: background1 > -0.05 -> background1 > -0.14 (0.0000) | Kept: background1 > -0.14 -> background1 > -0.05 (0.0001)
#
# ======================================================================
# CONSTRUCTED GRAPH SUMMARY
# ======================================================================
# Initial edges: 704 | Removed: 156
# Predicate nodes: 129
# Metric: Perturbation
# Weighting by explained variance: ENABLED
#
# Processing graph LRC...
#
# Processing graph LRC...
#
# Processing graph LRC...
#
# Processing graph LRC...
#     Predicate_pert_Seed_0 Predicate_pert_Seed_1 Predicate_pert_Seed_2  \
# 0              Si > -0.72            Si > -0.72            Si > -0.72
# 1              Si > -1.67            Si > -1.67            Si > -1.67
# 2              Si > -2.51            Si > -2.51            Si > -2.51
# 3          Ca ka <= -1.50        Ca ka <= -1.50        Ca ka <= -1.50
# 4           Ca ka <= 1.77         Ca ka <= 1.77         Ca ka <= 1.77
# ..                    ...                   ...                   ...
# 126   background1 > -0.05   background1 > -0.05   background1 <= 0.05
# 127   background1 > -0.14               Class_A   background1 > -0.05
# 128               Class_A               Class_B               Class_A
# 129               Class_B                   NaN               Class_B
# 130                   NaN                   NaN                   NaN
#
#     Predicate_pert_Seed_3
# 0              Si > -0.72
# 1              Si > -1.67
# 2              Si > -2.51
# 3          Ca ka <= -1.50
# 4           Ca ka <= 1.77
# ..                    ...
# 126   background1 <= 0.05
# 127   background1 > -0.14
# 128   background1 > -0.05
# 129               Class_A
# 130               Class_B
#
# [131 rows x 4 columns]

# %%
all_results_pert[0]['pert_results_dict']['Bag_1']
# Out:
#                 Predicate  Perturbation
# 0              Si > -0.72      0.156050
# 1              Si > -1.67      0.106685
# 2              Si > -2.51      0.081880
# 3          Ca ka <= -1.50      0.058908
# 4           Ca ka <= 1.77      0.039679
# ..                    ...           ...
# 121  background1 <= -0.05      0.000016
# 122   background1 > -0.05      0.000014
# 123   background1 <= 0.16      0.000014
# 124   background1 > -0.14      0.000014
# 125   background1 <= 0.05      0.000012
#
# [126 rows x 2 columns]

# %%
# Somar LRCs de predicados equivalentes entre diferentes seeds
lrc_combined_list = []

for seed in random_seeds:
    lrc_df = lrc_pert_by_seed[seed].copy()
    lrc_combined_list.append(lrc_df) # o append adiciona o dataframe ao final da lista

# Concatenar todos os dataframes
lrc_all_seeds = pd.concat(lrc_combined_list, ignore_index=True) 

# Agrupar por predicado (Node) e somar as LRCs, mantendo Zone, Threshold e Operator
lrc_summed_df_pert = lrc_all_seeds.groupby('Node').agg({ # o .agg pode ser usado para aplicar múltiplas funções de agregação
    'Local_Reaching_Centrality': 'mean', # sum = somando as LRCs, poderia ser média ou outro agregado
    'Zone': 'first',
    'Threshold': 'first',
    'Operator': 'first'
}).reset_index()

# Ordenar pelo valor de LRC somado (maior para menor)
lrc_summed_df_pert = lrc_summed_df_pert.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
# vamoss pegar so os valore sunicos de lrc_summed_df baseado na zona espectral
lrc_summed_unique_df_pert = lrc_summed_df_pert.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
lrc_summed_unique_df_pert = lrc_summed_unique_df_pert.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
lrc_summed_unique_df_pert
# Out:
#                            Node  Local_Reaching_Centrality  \
# 0                    Si > -0.72                  22.227542
# 1                Ca ka <= -1.50                   8.819182
# 2                 Fe ka > -2.26                   3.624858
# 3                      K > 2.15                   0.887142
# 4             Rh L + Ar > -0.16                   0.631738
# 5                Ca kb <= -0.59                   0.616816
# 6                 Ti ka > -0.52                   0.548980
# 7                 Fe kb > -0.44                   0.416064
# 8          background3 <= -0.49                   0.136167
# 9          background4 <= -0.62                   0.130165
# 10                     P > 0.08                   0.091554
# 11                  Mn <= -0.41                   0.076906
# 12    Compton scattering > 0.05                   0.071781
# 13                     S > 0.09                   0.066026
# 14                sum Fe > 0.07                   0.054509
# 15                  Ni <= -0.14                   0.045638
# 16  Rayleight scattering > 0.03                   0.045547
# 17                 Ti kb > 0.03                   0.045171
# 18                    Al > 0.19                   0.045098
# 19         background2 <= -0.08                   0.035236
# 20         background1 <= -0.05                   0.000184
# 21                      Class_B                   0.000000
#
#                     Zone Threshold Operator
# 0                     Si     -0.72        >
# 1                  Ca ka     -1.50       <=
# 2                  Fe ka     -2.26        >
# 3                      K      2.15        >
# 4              Rh L + Ar     -0.16        >
# 5                  Ca kb     -0.59       <=
# 6                  Ti ka     -0.52        >
# 7                  Fe kb     -0.44        >
# 8            background3     -0.49       <=
# 9            background4     -0.62       <=
# 10                     P      0.08        >
# 11                    Mn     -0.41       <=
# 12    Compton scattering      0.05        >
# 13                     S      0.09        >
# 14                sum Fe      0.07        >
# 15                    Ni     -0.14       <=
# 16  Rayleight scattering      0.03        >
# 17                 Ti kb      0.03        >
# 18                    Al      0.19        >
# 19           background2     -0.08       <=
# 20           background1     -0.05       <=
# 21                  None      None     None

# %%
# Aplicar o mapeamento
lrc_summed_df_pert_natural = exp.map_thresholds_to_natural(
    lrc_df=lrc_summed_df_pert,
    zone_sums_preprocessed=zone_scores_df,
    zone_sums_natural=zones_original[0]
)

lrc_summed_df_pert_natural
# Out:
#                     Node  Local_Reaching_Centrality         Zone Threshold  \
# 0             Si > -0.72                  22.227542           Si     -0.72
# 1             Si > -1.67                  15.670557           Si     -1.67
# 2             Si > -2.51                  11.844408           Si     -2.51
# 3         Ca ka <= -1.50                   8.819182        Ca ka     -1.50
# 4          Ca ka <= 1.77                   6.359126        Ca ka      1.77
# ..                   ...                        ...          ...       ...
# 128  background1 <= 0.05                   0.000114  background1      0.05
# 129  background1 > -0.14                   0.000101  background1     -0.14
# 130  background1 > -0.05                   0.000071  background1     -0.05
# 131              Class_B                   0.000000         None      None
# 132              Class_A                   0.000000         None      None
#
#     Operator  Threshold_Natural  Reference_Sample_Index  Approximation_Error  \
# 0          >          -2.087044                   129.0             0.038926
# 1          >          -4.200922                   133.0             0.023527
# 2          >          -6.726367                    45.0             0.014243
# 3         <=          -9.476439                    94.0             0.083086
# 4         <=          11.953266                    82.0             0.013408
# ..       ...                ...                     ...                  ...
# 128       <=           0.062920                    64.0             0.002636
# 129        >          -0.162473                   129.0             0.000043
# 130        >          -0.076696                    26.0             0.002030
# 131     None                NaN                     NaN                  NaN
# 132     None                NaN                     NaN                  NaN
#
#                 Node_Natural
# 0             Si > -2.087044
# 1             Si > -4.200922
# 2             Si > -6.726367
# 3         Ca ka <= -9.476439
# 4         Ca ka <= 11.953266
# ..                       ...
# 128  background1 <= 0.062920
# 129  background1 > -0.162473
# 130  background1 > -0.076696
# 131                     None
# 132                     None
#
# [133 rows x 9 columns]

# %%
import plotly.graph_objects as go

n = 0
zone_name = lrc_summed_df_pert_natural.iloc[n]['Zone'] # o n indica a linha do dataframe lrc_summed_df_pert_natural que queremos acessar para pegar o nome da zona espectral (coluna 'Zone')
threshold_score = float(lrc_summed_df_pert_natural.iloc[n]['Threshold_Natural']) # o iloc acessa a linha n e a coluna 'Threshold_Natural' para pegar o valor do threshold já mapeado para o espaço natural (não pré-processado)

# Usar pca_info_dict dos dados ORIGINAIS (zones_original[1])
pca_info_dict_original = zones_original[1]

# Reconstrução: τ = mean + threshold * loadings (no espaço original)
threshold_spectrum = exp.reconstruct_threshold_to_spectrum(
    threshold_value=threshold_score,
    zone_name=zone_name,
    pca_info_dict=pca_info_dict_original
)
print(f"\nEspectro de threshold reconstruído para zona '{zone_name}':")
print(f"  - Dimensão: {len(threshold_spectrum)} variáveis espectrais")
#print(f"  - Range de energias: {threshold_spectrum.index[n]} - {threshold_spectrum.index[-1]}")
print(f"  - Variância explicada pela PC1: {pca_info_dict_original[zone_name]['variance_explained']:.2%}")

# Usar dados ORIGINAIS para plotar (spectral_zones_original)
zone_df = spectral_zones_original[zone_name]

# Plotar zona com threshold (inline)
fig = go.Figure()
x_values = pd.to_numeric(zone_df.columns, errors='coerce')

# Plotar espectros das amostras coloridas por classe
colors = {'A': 'gold', 'B': 'blue'}
for idx, row in zone_df.iterrows():
    class_label = ycalclass.iloc[idx] if idx < len(ycalclass) else 'Unknown'
    fig.add_trace(go.Scatter(
        x=x_values,
        y=row.values,
        mode='lines',
        line=dict(color=colors.get(class_label, 'rgba(128,128,128,0.3)'), width=0.5),
        name=f'Class {class_label}',
        showlegend=False,
        hoverinfo='skip'
    ))

# Plotar espectro de threshold (destaque)
fig.add_trace(go.Scatter(
    x=x_values,
    y=threshold_spectrum.values,
    mode='lines',
    line=dict(color='red', width=4, dash='dash'),
    name=f'Threshold Spectrum ({threshold_spectrum.name})'
))

# Layout do gráfico
fig.update_layout(
    title=f"Zona '{zone_name}' com Threshold Multivariado (Predicado: {lrc_summed_df_pert_natural.iloc[n]['Node_Natural']})",
    xaxis_title='Energia / Comprimento de Onda',
    yaxis_title='Intensidade',
    template='plotly_white',
    showlegend=True,
    legend=dict(yanchor="top", y=0.99, xanchor="left", x=0.01)
)

fig.show()
# Out:
# Espectro de threshold reconstruído para zona 'Si':
#   - Dimensão: 12 variáveis espectrais
#   - Variância explicada pela PC1: 99.71%

# %%
# Permutation importance baseado em mudança nas probabilidades previstas (predict_proba)
# Medimos a média da diferença absoluta entre as probabilidades originais e as probabilidades
# obtidas após permutar cada variável. Isso fornece uma métrica contínua de importância.
n_repeats = 10
rng = np.random.RandomState(42)
# Probabilidades base (classe 'B' mapeada para 1)
baseline_proba = svm_model[3].predict_proba(Xcalclass_prep)[:, 1]
importance_list = []
X_arr = Xcalclass_prep.copy()
for col in Xcalclass_prep.columns:
    diffs = []
    for _ in range(n_repeats):
        X_perm = X_arr.copy()
        X_perm[col] = rng.permutation(X_perm[col].values)
        perm_proba = svm_model[3].predict_proba(X_perm)[:, 1]
        diffs.append(np.mean(np.abs(baseline_proba - perm_proba)))
    importance_list.append(np.mean(diffs))

permutation_df = pd.DataFrame({
    'energy': Xcalclass_prep.columns,
    'Permutation_importance_proba': importance_list
})
permutation_df.sort_values(by='Permutation_importance_proba', ascending=False, inplace=True)
energy_to_zone_vip = {}
for zone_name, start, end in spectral_cuts:
    for e in permutation_df['energy']:
        ef = float(e)
        if start <= ef <= end:
            energy_to_zone_vip[e] = zone_name
permutation_df['Zone'] = permutation_df['energy'].map(energy_to_zone_vip)
permutation_unique_df = permutation_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
permutation_unique_df = permutation_unique_df.sort_values(by='Permutation_importance_proba', ascending=False)
permutation_unique_df
# Out:
#    energy  Permutation_importance_proba                  Zone
# 0    6.42                      0.011552                 Fe ka
# 1    3.32                      0.005296                     K
# 2     3.7                      0.005252                 Ca ka
# 3    1.74                      0.004418                    Si
# 4    2.62                      0.000852             Rh L + Ar
# 5       4                      0.000563                 Ca kb
# 6    4.52                      0.000395                 Ti ka
# 7    7.06                      0.000327                 Fe kb
# 8       2                      0.000173                     P
# 9    5.88                      0.000111                    Mn
# 10    2.3                      0.000086                     S
# 11   1.62                      0.000052                    Al
# 12  13.41                      0.000037                sum Fe
# 13   7.54                      0.000030                    Ni
# 14   4.94                      0.000027                 Ti kb
# 15  11.95                      0.000021           background3
# 16  18.81                      0.000019    Compton scattering
# 17  14.13                      0.000015           background4
# 18  20.25                      0.000011  Rayleight scattering
# 19   4.14                      0.000007           background1
# 20    5.6                      0.000006           background2

# %%
import numpy as np

max_len = max(
    len(pvector_unique_df['Zone']),
    len(shap_unique_df['Zone']),
    len(permutation_unique_df['Zone']),
    len(lrc_summed_unique_df_pert['Zone']),
    len(lrc_summed_unique_df_cov['Zone'])
)

def pad_list(lst, length):
    return list(lst) + [None] * (length - len(lst))

features_importance = pd.DataFrame({
    'SVM_pvector': pad_list(pvector_unique_df['Zone'], max_len),
    'Shap': pad_list(shap_unique_df['Zone'], max_len),
    'Permutation' : pad_list(permutation_unique_df['Zone'], max_len),
    'LRC_perturbation' : pad_list(lrc_summed_unique_df_pert['Zone'], max_len),
    'LRC_covariance' : pad_list(lrc_summed_unique_df_cov['Zone'], max_len),
})

features_importance.to_csv('feature_importance.csv', index=False, sep=';')
features_importance
# Out:
#              SVM_pvector                  Shap           Permutation  \
# 0                  Fe ka                    Si                 Fe ka
# 1                  Ca ka                 Ca ka                     K
# 2                     Si                 Fe ka                 Ca ka
# 3                      K                     K                    Si
# 4                  Ca kb           background4             Rh L + Ar
# 5                  Ti ka             Rh L + Ar                 Ca kb
# 6                  Fe kb           background3                 Ti ka
# 7              Rh L + Ar    Compton scattering                 Fe kb
# 8                      P                     S                     P
# 9                      S                sum Fe                    Mn
# 10                sum Fe                    Al                     S
# 11                    Al  Rayleight scattering                    Al
# 12                 Ti kb           background2                sum Fe
# 13                    Ni                 Ti kb                    Ni
# 14                    Mn           background1                 Ti kb
# 15    Compton scattering                 Ti ka           background3
# 16           background3                    Mn    Compton scattering
# 17  Rayleight scattering                     P           background4
# 18           background4                 Ca kb  Rayleight scattering
# 19           background1                 Fe kb           background1
# 20           background2                    Ni           background2
# 21                  None                  None                  None
#
#         LRC_perturbation        LRC_covariance
# 0                     Si                 Fe ka
# 1                  Ca ka                 Ca ka
# 2                  Fe ka                    Si
# 3                      K                     K
# 4              Rh L + Ar                 Ti ka
# 5                  Ca kb                 Fe kb
# 6                  Ti ka                 Ca kb
# 7                  Fe kb             Rh L + Ar
# 8            background3           background4
# 9            background4    Compton scattering
# 10                     P                sum Fe
# 11                    Mn  Rayleight scattering
# 12    Compton scattering                    Al
# 13                     S           background3
# 14                sum Fe                 Ti kb
# 15                    Ni                     P
# 16  Rayleight scattering                    Mn
# 17                 Ti kb                     S
# 18                    Al                    Ni
# 19           background2           background2
# 20           background1           background1
# 21                  None                  None

# %%
import rbo
rbo_comparison = pd.DataFrame(columns=['Method_1', 'Method_2', 'RBO_Score'])
methods = features_importance.columns.tolist()
for i in range(len(methods)):
    for j in range(i + 1, len(methods)):
        method_1 = methods[i]
        method_2 = methods[j]
        # Remove None values from the lists
        list_1 = [x for x in features_importance[method_1].tolist() if x is not None]
        list_2 = [x for x in features_importance[method_2].tolist() if x is not None]
        # Truncate both lists to the same length (minimum of both)
        min_len = min(len(list_1), len(list_2))
        list_1_trunc = list_1[:min_len]
        list_2_trunc = list_2[:min_len]
        rbo_score = rbo.RankingSimilarity(list_1_trunc, list_2_trunc).rbo(p=0.7, k=10)
        rbo_comparison = pd.concat([rbo_comparison, pd.DataFrame({
            'Method_1': [method_1],
            'Method_2': [method_2],
            'RBO_Score': [rbo_score]
        })], ignore_index=True)
rbo_comparison.sort_values(by='RBO_Score', ascending=False, inplace=True)
rbo_comparison.to_csv('rbo_rank.csv', index=False, sep=';')
rbo_comparison
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_12616\3097109587.py:16: FutureWarning:
#
# The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#            Method_1          Method_2  RBO_Score
# 3       SVM_pvector    LRC_covariance   0.944600
# 5              Shap  LRC_perturbation   0.920197
# 1       SVM_pvector       Permutation   0.788690
# 8       Permutation    LRC_covariance   0.777155
# 2       SVM_pvector  LRC_perturbation   0.534558
# 9  LRC_perturbation    LRC_covariance   0.527365
# 6              Shap    LRC_covariance   0.501752
# 0       SVM_pvector              Shap   0.498619
# 7       Permutation  LRC_perturbation   0.408410
# 4              Shap       Permutation   0.356854

# %%
lrc_summed_df_cov_natural.to_csv('lrc_cov_natural.csv', index=False, sep=';')
lrc_summed_df_pert_natural.to_csv('lrc_pert_natural.csv', index=False, sep=';')
