# %%
# Importing the necessary libraries
import pandas as pd
import numpy as np
import kennard_stone as ks
pd.options.plotting.backend = 'plotly'  # setting plotly as the backend for pandas plotting

# Add parent directory to sys.path so local module 'synthetic' can be imported
import sys
from pathlib import Path # for path manipulations
# Move three levels up from current working directory to reach workspace root
workspace_root = Path.cwd().parent.parent.parent.resolve() 
smx_dir = workspace_root / 'smx'  # Path to smx folder
if str(smx_dir) not in sys.path: # check to avoid duplicates
    sys.path.insert(0, str(smx_dir)) # insert at the start of sys.path to prioritize local modules

# Loading a soil spectral dataset based on X-ray fluorescence (XRF)
data_complete = pd.read_csv(f'{workspace_root}/real_datasets/xrf/bank_notes.csv', sep=';') # local copy of Toledo 2022 dataset (os ... indica para omitir o caminho longo)
data = data_complete.loc[:, '2.74':'22.71']

# Split dataset by class and create calibration/prediction sets using Kennard-Stone (as in original pipeline)
data_A = data_complete[data_complete['Class'] == 'A'].reset_index(drop=True)
data_B = data_complete[data_complete['Class'] == 'B'].reset_index(drop=True)

# splitting the data into calibration and prediction sets by kennard-stone algorithm
XA_cal, XA_pred = ks.train_test_split(data_A.loc[:, '2.74':'22.71'], test_size=0.30)  # class A
XA_cal = XA_cal.reset_index(drop=True)
XA_pred = XA_pred.reset_index(drop=True)

XB_cal, XB_pred = ks.train_test_split(data_B.loc[:, '2.74':'22.71'], test_size=0.30)  # class B
XB_cal = XB_cal.reset_index(drop=True)
XB_pred = XB_pred.reset_index(drop=True)

Xcalclass = pd.concat([XA_cal, XB_cal], axis=0).reset_index(drop=True)  # concatenating both classes
Xpredclass = pd.concat([XA_pred, XB_pred], axis=0).reset_index(drop=True)
ycalclass = pd.Series(['A']*XA_cal.shape[0] + ['B']*XB_cal.shape[0])  # target for calibration set
ypredclass = pd.Series(['A']*XA_pred.shape[0] + ['B']*XB_pred.shape[0])  # target for prediction set

# preprocessings
import preprocessings as prepr  # preprocessing methods for XRF data

Xcalclass_prep, mean_calclass, mean_calclass_poisson  = prepr.poisson(Xcalclass, mc=True)
Xpredclass_prep = ((Xpredclass/np.sqrt(mean_calclass)) - mean_calclass_poisson)
# Out:
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-02-26 14:37:26,037 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-02-26 14:37:26,094 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-02-26 14:37:26,133 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-02-26 14:37:26,160 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
from modeling import svm_optimized

svm_model = svm_optimized(Xcalclass_prep, ycalclass, Xpredclass_prep, ypredclass, aim='classification', kernel='rbf')
svm_model[0]
# Out:
#   Model  Accuracy Cal  Sensitivity Cal  Specificity Cal                CM Cal  \
# 0   SVC      0.992958         0.981651              1.0  [[175, 0], [2, 107]]
#
#    Accuracy Pred  Sensitivity Pred  Specificity Pred             CM Pred
# 0            1.0               1.0               1.0  [[76, 0], [0, 47]]

# %% [markdown]
# ## Definição das Zonas Espectrais

# %%
spectral_cuts = [
('Ar ka + Ag L', 2.76, 3.47),
('Ca ka', 3.5, 3.91),
('Ca kb', 3.93, 4.24),
('Ti ka', 4.26, 4.72),
('Ti kb', 4.75, 5.13),
('background1', 5.16, 6.12),
('Fe ka', 6.15, 6.76),
('Fe kb', 6.79, 7.32),
('background2', 7.35, 7.78),
('Cu ka', 7.81, 8.29),
('Zn ka', 8.29, 8.80),
('Cu kb', 8.80, 9.26),
('Zn kb', 9.26, 10.00),
('background3', 10.00, 21.46),
('Ag ka scattering', 21.49, 22.71)
]

# %% [markdown]
# ## Pvector and SHAP

# %%
X_sv = svm_model[3].support_vectors_            # shape (n_SV, n_features)
alpha_dual = svm_model[3].dual_coef_.ravel()    # shape (n_SV,)

# Calculando os coeficientes p usando os vetores de suporte e os multiplicadores de Lagrange
pvetor = pd.DataFrame({'energia' : Xcalclass.columns,
                       'importance': (X_sv.T) @ alpha_dual})
pvetor['importance'] = np.abs(pvetor['importance'])
pvector_df = pd.DataFrame({
    'energy': pvetor['energia'],
    'Pvector': pvetor['importance'].values
})
pvector_df = pvector_df.sort_values(by='Pvector', ascending=False).reset_index(drop=True)
energy_to_zone_vip = {}
for zone_name, start, end in spectral_cuts:
    for e in pvector_df['energy']:
        ef = float(e)
        if start <= ef <= end:
            energy_to_zone_vip[e] = zone_name
pvector_df['Zone'] = pvector_df['energy'].map(energy_to_zone_vip)
pvector_unique_df = pvector_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
pvector_unique_df
# Out:
#    energy     Pvector              Zone
# 0    6.43  180.546544             Fe ka
# 1    4.54  139.472008             Ti ka
# 2    8.09   85.907624             Cu ka
# 3   21.92   63.251649  Ag ka scattering
# 4    7.09   58.576719             Fe kb
# 5    4.93   57.959596             Ti kb
# 6     3.7   53.526321             Ca ka
# 7    8.93   29.372141             Cu kb
# 8   17.23   23.040610       background3
# 9    4.01   20.460567             Ca kb
# 10   5.79   14.852457       background1
# 11   8.77   13.313171             Zn ka
# 12   2.91   11.184570      Ar ka + Ag L
# 13   2.74   10.496748               NaN
# 14   7.58    9.978306       background2
# 15   9.64    9.883348             Zn kb

# %%
shap_global_importance = pd.read_csv('shap_bank_notes.csv', sep=';') # loading previously saved shap_unique_df
# vamos gerar uma nova coluna em shap_global_importance com o nome da zona espectral correspondente de acordo com a lista spectral_cuts
energy_to_zone_shap = {}
for zone_name, start, end in spectral_cuts:
    for i in shap_global_importance['energy']:
        i_float = float(i)
        if start <= i_float <= end:
            energy_to_zone_shap[i] = zone_name
shap_global_importance['Zone'] = shap_global_importance['energy'].map(energy_to_zone_shap)

# agora vamos filtrar shap_global_importance para manter apenas as zonas espectrais únicas com maior SHAP score
shap_unique_df = shap_global_importance.sort_values(by='Mean_Abs_SHAP', ascending=False).reset_index(drop=True)
shap_unique_df = shap_unique_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
shap_unique_df
# Out:
#     energy  Mean_Abs_SHAP              Zone
# 0     4.52       0.050138             Ti ka
# 1     3.70       0.029065             Ca ka
# 2     6.43       0.012064             Fe ka
# 3     8.03       0.002786             Cu ka
# 4     4.95       0.000787             Ti kb
# 5    21.92       0.000741  Ag ka scattering
# 6     4.01       0.000431             Ca kb
# 7     7.60       0.000326       background2
# 8     5.16       0.000317       background1
# 9    17.08       0.000261       background3
# 10    7.09       0.000252             Fe kb
# 11    9.18       0.000211             Cu kb
# 12    9.41       0.000153             Zn kb
# 13    3.19       0.000136      Ar ka + Ag L
# 14    8.47       0.000109             Zn ka
# 15    2.74       0.000000               NaN

# %% [markdown]
# ## Funções de Agregação por PCA
#
# Aqui implementamos as funções para agregar zonas espectrais usando PCA com 1 componente principal.

# %%
import explaining as exp

# Extração das zonas espectrais
spectral_zones_class = exp.extract_spectral_zones(Xcalclass_prep, spectral_cuts)
zone_scores_df, pca_info_dict = exp.aggregate_spectral_zones_pca(spectral_zones_class) # apca aggregation
print(f"\nScores DataFrame shape: {zone_scores_df.shape}")
# Out:
# Zone 'Ar ka + Ag L': VE = 5.85%, dim = 29 variables
# Zone 'Ca ka': VE = 98.41%, dim = 17 variables
# Zone 'Ca kb': VE = 90.24%, dim = 13 variables
# Zone 'Ti ka': VE = 96.36%, dim = 19 variables
# Zone 'Ti kb': VE = 80.62%, dim = 16 variables
# Zone 'background1': VE = 12.07%, dim = 39 variables
# Zone 'Fe ka': VE = 99.63%, dim = 25 variables
# Zone 'Fe kb': VE = 96.66%, dim = 22 variables
# Zone 'background2': VE = 8.40%, dim = 18 variables
# Zone 'Cu ka': VE = 97.03%, dim = 20 variables
# Zone 'Zn ka': VE = 20.69%, dim = 21 variables
# Zone 'Cu kb': VE = 63.49%, dim = 19 variables
# Zone 'Zn kb': VE = 5.72%, dim = 30 variables
# Zone 'background3': VE = 2.51%, dim = 451 variables
# Zone 'Ag ka scattering': VE = 27.73%, dim = 49 variables
#
# Scores DataFrame shape: (284, 15)

# %%
y_pred = svm_model[4]['SVC'].values # using the continuous predictions from SVM, extracting as 1D array
predicates_quantiles = exp.predicates_by_quantiles(zone_scores_df, [0.2, 0.4, 0.6, 0.8])
predicate_info_dict = exp.create_predicate_info_dict(
    predicates_df=predicates_quantiles[0],
    predicate_indicator_df=predicates_quantiles[1],
    zone_aggregated_df=zone_scores_df,
    y_predicted_numeric=y_pred
)

# %%
import explaining as exp

# LISTA DE SEMENTES A TESTAR
random_seeds = [0, 1, 2, 3]

all_results_cov = {}
training_samples = len(Xcalclass)

# LOOP: PROCESSAR CADA SEMENTE

y_pred = pd.Series(svm_model[4]['SVC'].values) # using the continuous predictions from SVM, extracting as 1D array

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando semente: {seed}")
    print(f"{'='*70}\n")
    # Bagging
    bags_result_seed = exp.bagging_predicates(
        zone_sums_df=zone_scores_df,
        y_predicted_numeric=y_pred,
        predicates_df=predicates_quantiles[0],
        n_bags=10,
        #n_predicates_per_bag=40,
        n_samples_per_bag=int(training_samples*0.8), # 80 % da base para amostrar (convertido para int)
        min_samples_per_predicate=int(training_samples*0.2), # 20 % da base para limitar (convertido para int)
        replace=False,
        sample_bagging=True,
        predicate_bagging=False,
        random_seed=seed
    )
    
    # Inserir classe prevista
    for bag_name, pred_dict in bags_result_seed.items(): # iterando sobre cada bag
        for pred_rule, df_info in pred_dict.items():
            df_info['Class_Predicted'] = np.where(df_info['Predicted_Y'] >= 0.5, 'A', 'B') # binarizando com threshold 0.5, A = eut, B = dist
    
    # Calcular MI
    cov_results_dict_seed = exp.calculate_predicate_metrics(
        bags_result=bags_result_seed,
        metric='covariance', # covariance ou mutual_information
        threshold=0.01, # threshold para cortar predicados irrelevantes
        n_neighbors=5
    )
    
    # Salvar no dicionário principal
    all_results_cov[seed] = {
        'bags_result': bags_result_seed,
        'cov_results_dict': cov_results_dict_seed
    }

# CONSTRUÇÃO DE GRAFOS PARA MÚLTIPLAS SEMENTES (LOOP EXTERNO)
# Dicionário para armazenar grafos
graphs_by_seed = {}

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando Grafo - Semente: {seed}")
    print(f"{'='*70}\n")
    
    # Construir grafo para esta semente (sem predicates_df - extraído da regra)
    DG = exp.build_predicate_graph(
        bags_result=all_results_cov[seed]['bags_result'],
        predicate_ranking_dict=all_results_cov[seed]['cov_results_dict'],
        metric_column='Covariance',
        random_state=seed,
        show_details=True,
        var_exp=True,
        pca_info_dict=pca_info_dict
    )
    # Armazenar grafo
    graphs_by_seed[seed] = DG

# Calcular LRC usando a função pronta do explaining.py
lrc_cov_by_seed = {}
for seed in random_seeds:
    DG = graphs_by_seed[seed]
    lrc_cov_df_seed = exp.calculate_lrc_single_graph(DG, predicates_quantiles[0])
    lrc_cov_df_seed['Seed'] = seed  # Adicionar coluna com a semente
    lrc_cov_by_seed[seed] = lrc_cov_df_seed

# junando todas as colunas 'Node' de lrc_by_seed em um único dataframe
lrc_cov_all_seeds_df = pd.DataFrame()
for seed in random_seeds:
    lrc_cov_df_seed = lrc_cov_by_seed[seed].rename(columns={'Node': f'Predicate_Cov_Seed_{seed}'})
    lrc_cov_all_seeds_df = pd.concat([lrc_cov_all_seeds_df, lrc_cov_df_seed[[f'Predicate_Cov_Seed_{seed}']]], axis=1)

# vamos filtrar lrc_by_seed em cada semente para manter apenas as zonas espectrais únicas com maior LRC em um mesmo dataframe
lrc_cov_unique_by_seed = {}
for seed, lrc_df in lrc_cov_by_seed.items():
    lrc_cov_unique_df = lrc_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
    lrc_cov_unique_df = lrc_cov_unique_df.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
    lrc_cov_unique_by_seed[seed] = lrc_cov_unique_df

lrc_cov_all_seeds_df # exibindo o dataframe consolidado com predicados de todas as sementes
# Out:
# ======================================================================
# Processando semente: 0
# ======================================================================
#
# Bag_1 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_2 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_3 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_4 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_5 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_6 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_7 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_8 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_9 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_10 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Computing Covariance for Predicates
# Metric: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando semente: 1
# ======================================================================
#
# Bag_1 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_2 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_3 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_4 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_5 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_6 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_7 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_8 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_9 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_10 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Computing Covariance for Predicates
# Metric: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando semente: 2
# ======================================================================
#
# Bag_1 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_2 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_3 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_4 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_5 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_6 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_7 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_8 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_9 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_10 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Computing Covariance for Predicates
# Metric: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando semente: 3
# ======================================================================
#
# Bag_1 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_2 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_3 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_4 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_5 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_6 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_7 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_8 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_9 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_10 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Computing Covariance for Predicates
# Metric: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando Grafo - Semente: 0
# ======================================================================
#
#
# Total bidirectional pairs found: 109
# Removed: Ca ka > -21.19 -> Ca ka > -26.11 (50.0062) | Kept: Ca ka > -26.11 -> Ca ka > -21.19 (77.4231)
# Removed: Ti ka <= 19.85 -> Fe kb > -7.02 (16.5913) | Kept: Fe kb > -7.02 -> Ti ka <= 19.85 (19.9825)
# Removed: Ti ka <= 19.85 -> Ca ka > -6.65 (16.4278) | Kept: Ca ka > -6.65 -> Ti ka <= 19.85 (70.2012)
# Removed: Fe kb > -7.41 -> Ti ka > -28.53 (14.3429) | Kept: Ti ka > -28.53 -> Fe kb > -7.41 (26.7163)
# Removed: Ti ka <= 9.34 -> Fe kb > -7.41 (18.4741) | Kept: Fe kb > -7.41 -> Ti ka <= 9.34 (26.1226)
# Removed: Ti ka <= 9.34 -> Ti ka > -28.53 (12.9917) | Kept: Ti ka > -28.53 -> Ti ka <= 9.34 (33.4603)
# Removed: Ca kb > -6.07 -> Ca kb > -8.59 (15.4880) | Kept: Ca kb > -8.59 -> Ca kb > -6.07 (23.9229)
# Removed: Cu ka > -9.68 -> Cu ka > -10.68 (6.6026) | Kept: Cu ka > -10.68 -> Cu ka > -9.68 (29.4230)
# Removed: Ti kb <= 6.95 -> Ca kb > -2.67 (7.0733) | Kept: Ca kb > -2.67 -> Ti kb <= 6.95 (13.8038)
# Removed: Ca kb > -2.67 -> Cu ka > -8.43 (5.1340) | Kept: Cu ka > -8.43 -> Ca kb > -2.67 (9.7048)
# Removed: Ti kb > -10.26 -> Ca kb > -2.67 (2.2469) | Kept: Ca kb > -2.67 -> Ti kb > -10.26 (2.5508)
# Removed: Ti kb <= 6.95 -> Cu ka > -8.43 (2.3306) | Kept: Cu ka > -8.43 -> Ti kb <= 6.95 (9.0227)
# Removed: Ti kb > -10.26 -> Cu ka > -8.43 (2.1130) | Kept: Cu ka > -8.43 -> Ti kb > -10.26 (5.3550)
# Removed: Cu ka > -8.43 -> Ca ka <= 33.38 (2.4905) | Kept: Ca ka <= 33.38 -> Cu ka > -8.43 (2.7930)
# Removed: Ti kb > -10.26 -> Ca ka <= 33.38 (2.1074) | Kept: Ca ka <= 33.38 -> Ti kb > -10.26 (10.4296)
# Removed: Ca ka <= 33.38 -> Ti kb <= 2.45 (4.7743) | Kept: Ti kb <= 2.45 -> Ca ka <= 33.38 (5.4015)
# Removed: Cu kb > -2.30 -> Ti ka <= -4.69 (1.5147) | Kept: Ti ka <= -4.69 -> Cu kb > -2.30 (4.9254)
# Removed: Cu kb > -2.88 -> Ti ka <= -4.69 (0.5915) | Kept: Ti ka <= -4.69 -> Cu kb > -2.88 (0.9969)
# Removed: Ag ka scattering <= 3.49 -> Cu kb > -2.30 (0.2847) | Kept: Cu kb > -2.30 -> Ag ka scattering <= 3.49 (1.9795)
# Removed: Cu kb > -1.61 -> Cu kb > -2.30 (1.4389) | Kept: Cu kb > -2.30 -> Cu kb > -1.61 (1.9587)
# Removed: Ag ka scattering <= 3.49 -> Cu kb > -2.88 (0.5469) | Kept: Cu kb > -2.88 -> Ag ka scattering <= 3.49 (1.8392)
# Removed: Ag ka scattering <= -0.18 -> Ag ka scattering <= 3.49 (0.2961) | Kept: Ag ka scattering <= 3.49 -> Ag ka scattering <= -0.18 (1.0260)
# Removed: Ag ka scattering <= -0.18 -> Cu kb > -2.88 (0.2542) | Kept: Cu kb > -2.88 -> Ag ka scattering <= -0.18 (1.1937)
# Removed: Ag ka scattering <= 1.67 -> Cu kb > -2.88 (0.2733) | Kept: Cu kb > -2.88 -> Ag ka scattering <= 1.67 (0.5242)
# Removed: Cu kb > -2.88 -> Ca kb <= 12.61 (1.2013) | Kept: Ca kb <= 12.61 -> Cu kb > -2.88 (1.6451)
# Removed: Ag ka scattering <= -0.18 -> Ca kb <= 12.61 (0.2405) | Kept: Ca kb <= 12.61 -> Ag ka scattering <= -0.18 (0.8360)
# Removed: Ag ka scattering <= -0.18 -> Cu kb > -1.61 (0.2534) | Kept: Cu kb > -1.61 -> Ag ka scattering <= -0.18 (1.2613)
# Removed: Ca ka <= -6.65 -> Ag ka scattering <= 1.67 (0.7918) | Kept: Ag ka scattering <= 1.67 -> Ca ka <= -6.65 (1.1580)
# Removed: Ag ka scattering <= 1.67 -> Cu kb > -1.61 (0.2359) | Kept: Cu kb > -1.61 -> Ag ka scattering <= 1.67 (1.1979)
# Removed: Cu kb > -1.61 -> Ca ka <= -6.65 (0.5301) | Kept: Ca ka <= -6.65 -> Cu kb > -1.61 (0.8624)
# Removed: Ca ka <= -6.65 -> Ca kb <= 12.61 (0.7697) | Kept: Ca kb <= 12.61 -> Ca ka <= -6.65 (1.5513)
# Removed: background3 <= 1.29 -> Ca kb <= 12.61 (0.0158) | Kept: Ca kb <= 12.61 -> background3 <= 1.29 (1.9461)
# Removed: background3 <= 2.86 -> background3 <= 1.29 (0.0140) | Kept: background3 <= 1.29 -> background3 <= 2.86 (0.0735)
# Removed: background3 <= -0.30 -> background3 <= 2.86 (0.0406) | Kept: background3 <= 2.86 -> background3 <= -0.30 (0.0719)
# Removed: background3 <= -0.30 -> Ti kb <= -2.91 (0.0246) | Kept: Ti kb <= -2.91 -> background3 <= -0.30 (0.3297)
# Removed: Ag ka scattering > -1.65 -> Ti kb <= -2.91 (0.3283) | Kept: Ti kb <= -2.91 -> Ag ka scattering > -1.65 (1.3026)
# Removed: Ag ka scattering > -0.18 -> Ti kb <= -2.91 (0.0960) | Kept: Ti kb <= -2.91 -> Ag ka scattering > -0.18 (0.8704)
# Removed: Ca kb <= -2.67 -> Ag ka scattering > -0.18 (0.2681) | Kept: Ag ka scattering > -0.18 -> Ca kb <= -2.67 (0.3447)
# Removed: Zn ka > -1.75 -> Ag ka scattering > -0.18 (0.0631) | Kept: Ag ka scattering > -0.18 -> Zn ka > -1.75 (0.3449)
# Removed: Zn ka > -1.75 -> Ca kb <= -2.67 (0.1155) | Kept: Ca kb <= -2.67 -> Zn ka > -1.75 (0.8027)
# Removed: Cu ka <= -3.28 -> Ca kb <= -2.67 (0.2507) | Kept: Ca kb <= -2.67 -> Cu ka <= -3.28 (1.2352)
# Removed: Zn ka > -1.75 -> Cu ka <= -3.28 (0.1694) | Kept: Cu ka <= -3.28 -> Zn ka > -1.75 (0.2578)
# Removed: background1 <= 2.08 -> Zn ka > -1.75 (0.0302) | Kept: Zn ka > -1.75 -> background1 <= 2.08 (0.0533)
# Removed: Zn ka <= 1.38 -> Cu ka <= -3.28 (0.0433) | Kept: Cu ka <= -3.28 -> Zn ka <= 1.38 (0.2406)
# Removed: Zn ka > -0.78 -> Cu ka <= -3.28 (0.0557) | Kept: Cu ka <= -3.28 -> Zn ka > -0.78 (0.7678)
# Removed: background1 <= 2.08 -> Zn ka <= 1.38 (0.0219) | Kept: Zn ka <= 1.38 -> background1 <= 2.08 (0.0913)
# Removed: Zn ka <= 1.38 -> Ca ka <= -21.19 (0.0469) | Kept: Ca ka <= -21.19 -> Zn ka <= 1.38 (0.4178)
# Removed: Zn ka <= 1.38 -> Ag ka scattering > 1.67 (0.0408) | Kept: Ag ka scattering > 1.67 -> Zn ka <= 1.38 (0.1126)
# Removed: background1 <= 2.08 -> Ca ka <= -21.19 (0.0258) | Kept: Ca ka <= -21.19 -> background1 <= 2.08 (0.2227)
# Removed: Ag ka scattering > 1.67 -> Zn ka > -0.78 (0.0514) | Kept: Zn ka > -0.78 -> Ag ka scattering > 1.67 (0.0964)
# Removed: Ag ka scattering > 1.67 -> Ti ka > -4.69 (0.1483) | Kept: Ti ka > -4.69 -> Ag ka scattering > 1.67 (0.1915)
# Removed: background3 > -2.55 -> Ti ka > -4.69 (0.0089) | Kept: Ti ka > -4.69 -> background3 > -2.55 (0.1623)
# Removed: background3 > -2.55 -> Zn ka <= 0.08 (0.0094) | Kept: Zn ka <= 0.08 -> background3 > -2.55 (0.0537)
# Removed: background3 > -2.55 -> background1 <= -0.11 (0.0072) | Kept: background1 <= -0.11 -> background3 > -2.55 (0.0166)
# Removed: background3 > -2.55 -> Ti kb > -2.91 (0.0035) | Kept: Ti kb > -2.91 -> background3 > -2.55 (0.1112)
# Removed: background1 <= -0.11 -> Zn ka <= 0.08 (0.0179) | Kept: Zn ka <= 0.08 -> background1 <= -0.11 (0.0231)
# Removed: background1 <= -0.11 -> Zn ka > 0.08 (0.0130) | Kept: Zn ka > 0.08 -> background1 <= -0.11 (0.0391)
# Removed: background3 > 1.29 -> background1 <= -0.11 (0.0032) | Kept: background1 <= -0.11 -> background3 > 1.29 (0.0283)
# Removed: Ar ka + Ag L <= 0.28 -> Zn ka <= -0.78 (0.0047) | Kept: Zn ka <= -0.78 -> Ar ka + Ag L <= 0.28 (0.0429)
# Removed: Zn ka <= -0.78 -> Cu ka <= -8.43 (0.0420) | Kept: Cu ka <= -8.43 -> Zn ka <= -0.78 (0.0861)
# Removed: Ar ka + Ag L <= 1.07 -> Zn ka <= -0.78 (0.0069) | Kept: Zn ka <= -0.78 -> Ar ka + Ag L <= 1.07 (0.0205)
# Removed: Ar ka + Ag L <= 0.28 -> Ca kb <= -6.07 (0.0060) | Kept: Ca kb <= -6.07 -> Ar ka + Ag L <= 0.28 (0.2136)
# Removed: Ar ka + Ag L <= 0.28 -> Cu ka <= -8.43 (0.0126) | Kept: Cu ka <= -8.43 -> Ar ka + Ag L <= 0.28 (0.1705)
# Removed: Ar ka + Ag L <= 1.07 -> Ar ka + Ag L <= 0.28 (0.0047) | Kept: Ar ka + Ag L <= 0.28 -> Ar ka + Ag L <= 1.07 (0.0103)
# Removed: background3 > 1.29 -> Ar ka + Ag L <= 1.07 (0.0027) | Kept: Ar ka + Ag L <= 1.07 -> background3 > 1.29 (0.0057)
# Removed: Ar ka + Ag L <= 1.07 -> background2 <= -0.37 (0.0039) | Kept: background2 <= -0.37 -> Ar ka + Ag L <= 1.07 (0.0061)
# Removed: Ar ka + Ag L <= 1.07 -> Ti kb > -2.91 (0.0042) | Kept: Ti kb > -2.91 -> Ar ka + Ag L <= 1.07 (0.0569)
# Removed: background3 > -0.30 -> background1 > -0.11 (0.0018) | Kept: background1 > -0.11 -> background3 > -0.30 (0.0097)
# Removed: Zn kb > 0.29 -> background1 > -0.11 (0.0048) | Kept: background1 > -0.11 -> Zn kb > 0.29 (0.0078)
# Removed: background1 > -0.11 -> Zn ka > 0.08 (0.0076) | Kept: Zn ka > 0.08 -> background1 > -0.11 (0.0213)
# Removed: background1 > -0.11 -> background2 <= -0.37 (0.0081) | Kept: background2 <= -0.37 -> background1 > -0.11 (0.0101)
# Removed: Ar ka + Ag L <= -0.29 -> background1 > -0.11 (0.0041) | Kept: background1 > -0.11 -> Ar ka + Ag L <= -0.29 (0.0085)
# Removed: Ar ka + Ag L > -1.05 -> background1 <= -1.03 (0.0036) | Kept: background1 <= -1.03 -> Ar ka + Ag L > -1.05 (0.0100)
# Removed: background1 <= -1.03 -> Zn ka > 0.08 (0.0117) | Kept: Zn ka > 0.08 -> background1 <= -1.03 (0.0145)
# Removed: Ar ka + Ag L <= -0.29 -> Zn kb > 0.29 (0.0038) | Kept: Zn kb > 0.29 -> Ar ka + Ag L <= -0.29 (0.0095)
# Removed: Ar ka + Ag L <= -0.29 -> Cu kb <= 0.18 (0.0027) | Kept: Cu kb <= 0.18 -> Ar ka + Ag L <= -0.29 (0.0425)
# Removed: background3 > -0.30 -> Ar ka + Ag L <= -0.29 (0.0020) | Kept: Ar ka + Ag L <= -0.29 -> background3 > -0.30 (0.0047)
# Removed: background2 <= -0.37 -> Ti kb > -2.91 (0.0127) | Kept: Ti kb > -2.91 -> background2 <= -0.37 (0.0578)
# Removed: background3 > -0.30 -> background2 <= -0.37 (0.0037) | Kept: background2 <= -0.37 -> background3 > -0.30 (0.0057)
# Removed: Ar ka + Ag L > -1.05 -> background2 <= -0.37 (0.0034) | Kept: background2 <= -0.37 -> Ar ka + Ag L > -1.05 (0.0054)
# Removed: background3 > -0.30 -> Fe ka <= -22.90 (0.0013) | Kept: Fe ka <= -22.90 -> background3 > -0.30 (0.0517)
# Removed: Zn kb > -0.29 -> Ar ka + Ag L > -1.05 (0.0024) | Kept: Ar ka + Ag L > -1.05 -> Zn kb > -0.29 (0.0038)
# Removed: Ar ka + Ag L > -1.05 -> Zn ka > 0.08 (0.0040) | Kept: Zn ka > 0.08 -> Ar ka + Ag L > -1.05 (0.0128)
# Removed: Ar ka + Ag L > -1.05 -> Cu kb <= 0.18 (0.0024) | Kept: Cu kb <= 0.18 -> Ar ka + Ag L > -1.05 (0.0460)
# Removed: Ar ka + Ag L > 0.28 -> background1 > -1.03 (0.0020) | Kept: background1 > -1.03 -> Ar ka + Ag L > 0.28 (0.0042)
# Removed: background2 > -0.92 -> Fe ka <= -23.71 (0.0048) | Kept: Fe ka <= -23.71 -> background2 > -0.92 (0.0327)
# Removed: Zn kb > -1.05 -> Fe ka <= -23.71 (0.0019) | Kept: Fe ka <= -23.71 -> Zn kb > -1.05 (0.0554)
# Removed: Fe ka <= -22.90 -> Fe ka <= -23.71 (0.0526) | Kept: Fe ka <= -23.71 -> Fe ka <= -22.90 (0.0956)
# Removed: Fe ka <= -22.90 -> Cu kb <= 0.18 (0.0430) | Kept: Cu kb <= 0.18 -> Fe ka <= -22.90 (0.0568)
# Removed: background2 <= 0.98 -> Fe ka <= -22.90 (0.0044) | Kept: Fe ka <= -22.90 -> background2 <= 0.98 (0.0288)
# Removed: Zn kb > -0.29 -> Fe ka <= -22.90 (0.0014) | Kept: Fe ka <= -22.90 -> Zn kb > -0.29 (0.0520)
# Removed: background2 > 0.27 -> Cu ka <= -9.68 (0.0042) | Kept: Cu ka <= -9.68 -> background2 > 0.27 (0.0393)
# Removed: background2 > 0.27 -> Fe kb <= -7.02 (0.0033) | Kept: Fe kb <= -7.02 -> background2 > 0.27 (0.0287)
# Removed: Zn ka > 0.08 -> Cu ka <= -9.68 (0.0123) | Kept: Cu ka <= -9.68 -> Zn ka > 0.08 (0.0563)
# Removed: Ar ka + Ag L > 0.28 -> Fe ka <= -24.15 (0.0026) | Kept: Fe ka <= -24.15 -> Ar ka + Ag L > 0.28 (0.0339)
# Removed: Zn kb <= -0.29 -> Ti ka > 9.34 (0.0013) | Kept: Ti ka > 9.34 -> Zn kb <= -0.29 (0.0231)
# Removed: Zn kb > -0.29 -> background2 <= 0.98 (0.0034) | Kept: background2 <= 0.98 -> Zn kb > -0.29 (0.0042)
# Removed: background2 > -0.92 -> Fe ka <= -24.15 (0.0075) | Kept: Fe ka <= -24.15 -> background2 > -0.92 (0.1087)
# Removed: Ti ka > 9.34 -> Fe kb <= -7.02 (0.0221) | Kept: Fe kb <= -7.02 -> Ti ka > 9.34 (0.0240)
# Removed: Fe kb <= -7.02 -> Fe kb <= -6.37 (0.0275) | Kept: Fe kb <= -6.37 -> Fe kb <= -7.02 (0.0570)
# Removed: Ti kb > 2.45 -> Fe kb <= -7.02 (0.0162) | Kept: Fe kb <= -7.02 -> Ti kb > 2.45 (0.0186)
# Removed: Zn kb > -0.29 -> Ti ka > 9.34 (0.0014) | Kept: Ti ka > 9.34 -> Zn kb > -0.29 (0.0230)
# Removed: Cu kb <= -1.61 -> Ti ka > 9.34 (0.0156) | Kept: Ti ka > 9.34 -> Cu kb <= -1.61 (0.0230)
# Removed: Ti ka > 9.34 -> Fe kb <= -6.37 (0.0230) | Kept: Fe kb <= -6.37 -> Ti ka > 9.34 (0.0473)
# Removed: Ar ka + Ag L > -0.29 -> Cu kb <= -2.30 (0.0008) | Kept: Cu kb <= -2.30 -> Ar ka + Ag L > -0.29 (0.0127)
# Removed: Ar ka + Ag L > -0.29 -> Ti kb > 2.45 (0.0017) | Kept: Ti kb > 2.45 -> Ar ka + Ag L > -0.29 (0.0271)
# Removed: Ar ka + Ag L > -0.29 -> Zn kb <= 0.29 (0.0008) | Kept: Zn kb <= 0.29 -> Ar ka + Ag L > -0.29 (0.0020)
# Removed: Ti kb > 2.45 -> Fe kb <= -7.41 (0.0115) | Kept: Fe kb <= -7.41 -> Ti kb > 2.45 (0.0156)
# Removed: Ti kb > 2.45 -> Fe kb <= -6.37 (0.0151) | Kept: Fe kb <= -6.37 -> Ti kb > 2.45 (0.0171)
#
# ======================================================================
# CONSTRUCTED GRAPH SUMMARY
# ======================================================================
# Initial edges: 541 | Removed: 109
# Predicate nodes: 90
# Metric: Covariance
# Weighting by explained variance: ENABLED
#
# ======================================================================
# Processando Grafo - Semente: 1
# ======================================================================
#
#
# Total bidirectional pairs found: 98
# Removed: Ca ka > -21.19 -> Ca ka > -26.11 (12.7386) | Kept: Ca ka > -26.11 -> Ca ka > -21.19 (116.2169)
# Removed: Ti ka <= 19.85 -> Fe kb > -7.02 (8.1589) | Kept: Fe kb > -7.02 -> Ti ka <= 19.85 (37.5511)
# Removed: Ti ka <= 19.85 -> Ca ka > -6.65 (32.8552) | Kept: Ca ka > -6.65 -> Ti ka <= 19.85 (50.7858)
# Removed: Ti ka > -28.53 -> Fe kb > -7.41 (6.8319) | Kept: Fe kb > -7.41 -> Ti ka > -28.53 (27.5663)
# Removed: Fe kb > -7.41 -> Ti ka <= 9.34 (6.2333) | Kept: Ti ka <= 9.34 -> Fe kb > -7.41 (31.4810)
# Removed: Ca kb > -6.07 -> Fe kb > -7.79 (3.8857) | Kept: Fe kb > -7.79 -> Ca kb > -6.07 (9.7589)
# Removed: Ca kb > -6.07 -> Ca kb > -8.59 (7.8952) | Kept: Ca kb > -8.59 -> Ca kb > -6.07 (31.7424)
# Removed: Cu ka > -9.68 -> Cu ka > -10.68 (7.5178) | Kept: Cu ka > -10.68 -> Cu ka > -9.68 (28.8577)
# Removed: Ca ka <= 33.38 -> Cu ka > -8.43 (2.9926) | Kept: Cu ka > -8.43 -> Ca ka <= 33.38 (6.3720)
# Removed: Ti kb <= 6.95 -> Ca kb > -2.67 (2.3380) | Kept: Ca kb > -2.67 -> Ti kb <= 6.95 (18.6570)
# Removed: Ca kb > -2.67 -> Ti kb > -10.26 (2.5787) | Kept: Ti kb > -10.26 -> Ca kb > -2.67 (4.2506)
# Removed: Ca ka <= 33.38 -> Ti kb <= 6.95 (2.9882) | Kept: Ti kb <= 6.95 -> Ca ka <= 33.38 (7.0695)
# Removed: Ca ka <= 33.38 -> Ti kb > -10.26 (8.0988) | Kept: Ti kb > -10.26 -> Ca ka <= 33.38 (8.2649)
# Removed: Cu kb > -1.61 -> Cu kb > -2.30 (0.7212) | Kept: Cu kb > -2.30 -> Cu kb > -1.61 (2.8324)
# Removed: Ag ka scattering <= 3.49 -> Cu kb > -2.30 (0.5775) | Kept: Cu kb > -2.30 -> Ag ka scattering <= 3.49 (1.9656)
# Removed: Cu kb > -2.30 -> Ti ka <= -4.69 (0.6241) | Kept: Ti ka <= -4.69 -> Cu kb > -2.30 (2.3915)
# Removed: Ag ka scattering <= 3.49 -> Cu kb > -1.61 (0.2662) | Kept: Cu kb > -1.61 -> Ag ka scattering <= 3.49 (0.6995)
# Removed: Cu kb > -1.61 -> Ti ka <= -4.69 (0.6739) | Kept: Ti ka <= -4.69 -> Cu kb > -1.61 (1.1919)
# Removed: Cu kb > -2.88 -> Ca kb <= 12.61 (1.1749) | Kept: Ca kb <= 12.61 -> Cu kb > -2.88 (1.7826)
# Removed: Ag ka scattering <= -0.18 -> Ca kb <= 12.61 (0.5275) | Kept: Ca kb <= 12.61 -> Ag ka scattering <= -0.18 (1.7567)
# Removed: Ag ka scattering <= 1.67 -> Ca kb <= 12.61 (0.7344) | Kept: Ca kb <= 12.61 -> Ag ka scattering <= 1.67 (0.8213)
# Removed: Ag ka scattering <= 3.49 -> Cu kb > -2.88 (0.7955) | Kept: Cu kb > -2.88 -> Ag ka scattering <= 3.49 (1.2356)
# Removed: Ag ka scattering <= 1.67 -> Cu kb > -2.88 (0.5139) | Kept: Cu kb > -2.88 -> Ag ka scattering <= 1.67 (1.1295)
# Removed: Ag ka scattering <= -0.18 -> Cu kb > -2.88 (0.2780) | Kept: Cu kb > -2.88 -> Ag ka scattering <= -0.18 (1.2024)
# Removed: Ag ka scattering <= -0.18 -> Ag ka scattering <= 3.49 (0.5415) | Kept: Ag ka scattering <= 3.49 -> Ag ka scattering <= -0.18 (0.5434)
# Removed: Ag ka scattering <= 3.49 -> Ti ka <= -4.69 (0.2902) | Kept: Ti ka <= -4.69 -> Ag ka scattering <= 3.49 (2.2244)
# Removed: Ca ka <= -6.65 -> Ti ka <= -4.69 (0.6856) | Kept: Ti ka <= -4.69 -> Ca ka <= -6.65 (0.7813)
# Removed: background3 <= 2.86 -> background3 <= 1.29 (0.0311) | Kept: background3 <= 1.29 -> background3 <= 2.86 (0.0852)
# Removed: background3 <= -0.30 -> background3 <= 2.86 (0.0293) | Kept: background3 <= 2.86 -> background3 <= -0.30 (0.0799)
# Removed: Ti kb <= -2.91 -> Ag ka scattering > -1.65 (0.3197) | Kept: Ag ka scattering > -1.65 -> Ti kb <= -2.91 (0.8417)
# Removed: Zn ka > -1.75 -> Cu ka <= -3.28 (0.2332) | Kept: Cu ka <= -3.28 -> Zn ka > -1.75 (0.4930)
# Removed: Zn ka > -1.75 -> Ca kb <= -2.67 (0.2375) | Kept: Ca kb <= -2.67 -> Zn ka > -1.75 (0.7408)
# Removed: Ca kb <= -2.67 -> Cu ka <= -3.28 (0.2228) | Kept: Cu ka <= -3.28 -> Ca kb <= -2.67 (0.5262)
# Removed: Zn ka > -0.78 -> Cu ka <= -3.28 (0.1009) | Kept: Cu ka <= -3.28 -> Zn ka > -0.78 (0.4645)
# Removed: Zn ka <= 1.38 -> Cu ka <= -3.28 (0.0428) | Kept: Cu ka <= -3.28 -> Zn ka <= 1.38 (0.2288)
# Removed: Zn ka <= 1.38 -> Zn ka > -0.78 (0.0473) | Kept: Zn ka > -0.78 -> Zn ka <= 1.38 (0.1465)
# Removed: Ag ka scattering > 1.67 -> Zn ka <= 1.38 (0.0554) | Kept: Zn ka <= 1.38 -> Ag ka scattering > 1.67 (0.0866)
# Removed: background1 <= 2.08 -> Zn ka <= 1.38 (0.0764) | Kept: Zn ka <= 1.38 -> background1 <= 2.08 (0.1376)
# Removed: Zn ka > -0.78 -> Ti ka > -4.69 (0.0462) | Kept: Ti ka > -4.69 -> Zn ka > -0.78 (0.1807)
# Removed: background1 <= 2.08 -> Zn ka > -0.78 (0.0283) | Kept: Zn ka > -0.78 -> background1 <= 2.08 (0.0504)
# Removed: Ca ka <= -21.19 -> Ti ka > -4.69 (0.1883) | Kept: Ti ka > -4.69 -> Ca ka <= -21.19 (0.3618)
# Removed: background3 > -2.55 -> Ti ka > -4.69 (0.0043) | Kept: Ti ka > -4.69 -> background3 > -2.55 (0.3042)
# Removed: Ti ka > -4.69 -> Ag ka scattering > 1.67 (0.1647) | Kept: Ag ka scattering > 1.67 -> Ti ka > -4.69 (0.2178)
# Removed: background1 <= -0.11 -> Ti ka > -4.69 (0.0162) | Kept: Ti ka > -4.69 -> background1 <= -0.11 (0.1607)
# Removed: background1 <= 2.08 -> Ca ka <= -21.19 (0.0772) | Kept: Ca ka <= -21.19 -> background1 <= 2.08 (0.6059)
# Removed: background3 > -2.55 -> Ag ka scattering > 1.67 (0.0048) | Kept: Ag ka scattering > 1.67 -> background3 > -2.55 (0.0532)
# Removed: background3 > -2.55 -> Ti kb > -2.91 (0.0103) | Kept: Ti kb > -2.91 -> background3 > -2.55 (0.1196)
# Removed: background3 > -2.55 -> Zn ka <= 0.08 (0.0036) | Kept: Zn ka <= 0.08 -> background3 > -2.55 (0.0293)
# Removed: Ar ka + Ag L <= 1.07 -> Ti kb > -2.91 (0.0046) | Kept: Ti kb > -2.91 -> Ar ka + Ag L <= 1.07 (0.0587)
# Removed: background1 <= -0.11 -> Ti kb > -2.91 (0.0175) | Kept: Ti kb > -2.91 -> background1 <= -0.11 (0.1949)
# Removed: background1 > -1.87 -> Ti kb > -2.91 (0.0207) | Kept: Ti kb > -2.91 -> background1 > -1.87 (0.1657)
# Removed: Zn kb > 0.29 -> Ti kb > -2.91 (0.0043) | Kept: Ti kb > -2.91 -> Zn kb > 0.29 (0.0589)
# Removed: background3 > -0.30 -> Zn ka <= 0.08 (0.0024) | Kept: Zn ka <= 0.08 -> background3 > -0.30 (0.0231)
# Removed: Zn ka <= 0.08 -> background1 <= -0.11 (0.0270) | Kept: background1 <= -0.11 -> Zn ka <= 0.08 (0.0356)
# Removed: background1 <= -0.11 -> Zn ka <= -0.78 (0.0155) | Kept: Zn ka <= -0.78 -> background1 <= -0.11 (0.0237)
# Removed: background3 > -0.30 -> Zn ka <= -0.78 (0.0021) | Kept: Zn ka <= -0.78 -> background3 > -0.30 (0.0159)
# Removed: Ar ka + Ag L <= 0.28 -> Zn ka <= -0.78 (0.0062) | Kept: Zn ka <= -0.78 -> Ar ka + Ag L <= 0.28 (0.0395)
# Removed: Zn ka <= -0.78 -> Cu ka <= -8.43 (0.0265) | Kept: Cu ka <= -8.43 -> Zn ka <= -0.78 (0.0827)
# Removed: background3 > 1.29 -> Ca kb <= -6.07 (0.0085) | Kept: Ca kb <= -6.07 -> background3 > 1.29 (0.1971)
# Removed: Ar ka + Ag L > 0.28 -> background1 <= -1.03 (0.0034) | Kept: background1 <= -1.03 -> Ar ka + Ag L > 0.28 (0.0080)
# Removed: background1 <= -1.03 -> Zn ka > 0.08 (0.0069) | Kept: Zn ka > 0.08 -> background1 <= -1.03 (0.0163)
# Removed: Ar ka + Ag L <= -0.29 -> background1 <= -1.03 (0.0042) | Kept: background1 <= -1.03 -> Ar ka + Ag L <= -0.29 (0.0102)
# Removed: background2 <= -0.37 -> Ca kb <= -6.07 (0.0086) | Kept: Ca kb <= -6.07 -> background2 <= -0.37 (0.0879)
# Removed: background3 > -0.30 -> Ar ka + Ag L > -1.05 (0.0019) | Kept: Ar ka + Ag L > -1.05 -> background3 > -0.30 (0.0050)
# Removed: background3 > -0.30 -> background1 > -1.87 (0.0017) | Kept: background1 > -1.87 -> background3 > -0.30 (0.0110)
# Removed: Cu kb <= 0.18 -> Cu ka <= -8.43 (0.0445) | Kept: Cu ka <= -8.43 -> Cu kb <= 0.18 (0.0863)
# Removed: background2 <= -0.37 -> Cu ka <= -8.43 (0.0076) | Kept: Cu ka <= -8.43 -> background2 <= -0.37 (0.0849)
# Removed: background2 <= -0.37 -> Fe ka <= -23.71 (0.0051) | Kept: Fe ka <= -23.71 -> background2 <= -0.37 (0.0509)
# Removed: Ar ka + Ag L <= -0.29 -> Zn kb > 0.29 (0.0045) | Kept: Zn kb > 0.29 -> Ar ka + Ag L <= -0.29 (0.0062)
# Removed: background1 > -0.11 -> Fe kb <= -7.02 (0.0036) | Kept: Fe kb <= -7.02 -> background1 > -0.11 (0.0319)
# Removed: Ar ka + Ag L <= 1.07 -> Ar ka + Ag L > -1.05 (0.0040) | Kept: Ar ka + Ag L > -1.05 -> Ar ka + Ag L <= 1.07 (0.0044)
# Removed: Ar ka + Ag L <= 1.07 -> Ar ka + Ag L <= 0.28 (0.0039) | Kept: Ar ka + Ag L <= 0.28 -> Ar ka + Ag L <= 1.07 (0.0055)
# Removed: Zn ka > 0.08 -> Fe ka <= -23.71 (0.0111) | Kept: Fe ka <= -23.71 -> Zn ka > 0.08 (0.0568)
# Removed: background1 > -1.87 -> Fe ka <= -24.15 (0.0046) | Kept: Fe ka <= -24.15 -> background1 > -1.87 (0.0504)
# Removed: Fe ka <= -24.15 -> Cu ka <= -9.68 (0.0462) | Kept: Cu ka <= -9.68 -> Fe ka <= -24.15 (0.0738)
# Removed: Zn kb > -0.29 -> background1 > -1.87 (0.0023) | Kept: background1 > -1.87 -> Zn kb > -0.29 (0.0051)
# Removed: Zn kb > -0.29 -> Cu ka <= -9.68 (0.0023) | Kept: Cu ka <= -9.68 -> Zn kb > -0.29 (0.0481)
# Removed: background1 > -1.03 -> Cu ka <= -9.68 (0.0132) | Kept: Cu ka <= -9.68 -> background1 > -1.03 (0.0540)
# Removed: Zn kb > -0.29 -> Ar ka + Ag L <= -0.29 (0.0028) | Kept: Ar ka + Ag L <= -0.29 -> Zn kb > -0.29 (0.0029)
# Removed: Zn kb > -0.29 -> background2 > 0.27 (0.0014) | Kept: background2 > 0.27 -> Zn kb > -0.29 (0.0036)
# Removed: Zn kb > -0.29 -> background2 <= 0.98 (0.0015) | Kept: background2 <= 0.98 -> Zn kb > -0.29 (0.0030)
# Removed: Zn kb > -0.29 -> background2 > -0.92 (0.0021) | Kept: background2 > -0.92 -> Zn kb > -0.29 (0.0038)
# Removed: Ar ka + Ag L <= -0.29 -> background1 > -1.03 (0.0032) | Kept: background1 > -1.03 -> Ar ka + Ag L <= -0.29 (0.0067)
# Removed: background2 > 0.27 -> Fe kb <= -7.02 (0.0025) | Kept: Fe kb <= -7.02 -> background2 > 0.27 (0.0231)
# Removed: Ar ka + Ag L > 0.28 -> Zn ka > 0.08 (0.0034) | Kept: Zn ka > 0.08 -> Ar ka + Ag L > 0.28 (0.0113)
# Removed: background2 > -0.37 -> Cu kb <= -1.61 (0.0021) | Kept: Cu kb <= -1.61 -> background2 > -0.37 (0.0335)
# Removed: Zn kb > -1.05 -> Fe ka <= -22.90 (0.0019) | Kept: Fe ka <= -22.90 -> Zn kb > -1.05 (0.0304)
# Removed: background2 <= 0.27 -> Fe ka <= -22.90 (0.0039) | Kept: Fe ka <= -22.90 -> background2 <= 0.27 (0.0346)
# Removed: Ar ka + Ag L > -0.29 -> Ti kb > 2.45 (0.0011) | Kept: Ti kb > 2.45 -> Ar ka + Ag L > -0.29 (0.0140)
# Removed: Zn kb > -1.05 -> background2 <= 0.98 (0.0013) | Kept: background2 <= 0.98 -> Zn kb > -1.05 (0.0019)
# Removed: Zn kb > -1.05 -> Fe kb <= -6.37 (0.0009) | Kept: Fe kb <= -6.37 -> Zn kb > -1.05 (0.0227)
# Removed: Cu kb <= -2.30 -> Ti ka > 9.34 (0.0172) | Kept: Ti ka > 9.34 -> Cu kb <= -2.30 (0.0207)
# Removed: background2 > -0.92 -> Fe kb <= -7.02 (0.0028) | Kept: Fe kb <= -7.02 -> background2 > -0.92 (0.0281)
# Removed: background2 <= 0.27 -> Ti ka > 9.34 (0.0026) | Kept: Ti ka > 9.34 -> background2 <= 0.27 (0.0247)
# Removed: background2 <= 0.27 -> Fe kb <= -6.37 (0.0045) | Kept: Fe kb <= -6.37 -> background2 <= 0.27 (0.0138)
# Removed: Ti ka > 9.34 -> Fe kb <= -7.02 (0.0233) | Kept: Fe kb <= -7.02 -> Ti ka > 9.34 (0.0262)
# Removed: background2 > -0.37 -> Fe kb <= -7.02 (0.0030) | Kept: Fe kb <= -7.02 -> background2 > -0.37 (0.0236)
# Removed: Ti kb > 2.45 -> Fe kb <= -6.37 (0.0294) | Kept: Fe kb <= -6.37 -> Ti kb > 2.45 (0.0332)
#
# ======================================================================
# CONSTRUCTED GRAPH SUMMARY
# ======================================================================
# Initial edges: 503 | Removed: 98
# Predicate nodes: 90
# Metric: Covariance
# Weighting by explained variance: ENABLED
#
# ======================================================================
# Processando Grafo - Semente: 2
# ======================================================================
#
#
# Total bidirectional pairs found: 99
# Removed: Ca ka > -21.19 -> Ca ka > -26.11 (49.9821) | Kept: Ca ka > -26.11 -> Ca ka > -21.19 (77.7378)
# Removed: Ca ka > -6.65 -> Fe kb > -7.02 (17.6913) | Kept: Fe kb > -7.02 -> Ca ka > -6.65 (58.3325)
# Removed: Ti ka <= 19.85 -> Ca ka > -6.65 (16.5066) | Kept: Ca ka > -6.65 -> Ti ka <= 19.85 (53.1997)
# Removed: Ti ka > -28.53 -> Fe kb > -7.41 (12.2677) | Kept: Fe kb > -7.41 -> Ti ka > -28.53 (34.6799)
# Removed: Ti ka <= 9.34 -> Ti ka > -28.53 (12.6905) | Kept: Ti ka > -28.53 -> Ti ka <= 9.34 (46.0583)
# Removed: Ca kb > -8.59 -> Fe kb > -7.79 (4.0446) | Kept: Fe kb > -7.79 -> Ca kb > -8.59 (10.4448)
# Removed: Ca kb > -8.59 -> Ca kb > -6.07 (8.0262) | Kept: Ca kb > -6.07 -> Ca kb > -8.59 (31.1805)
# Removed: Ti kb <= 6.95 -> Ca kb > -2.67 (7.0293) | Kept: Ca kb > -2.67 -> Ti kb <= 6.95 (16.6720)
# Removed: Cu ka > -8.43 -> Ti kb <= 6.95 (9.1366) | Kept: Ti kb <= 6.95 -> Cu ka > -8.43 (9.3788)
# Removed: Cu ka > -8.43 -> Ca ka <= 33.38 (5.4408) | Kept: Ca ka <= 33.38 -> Cu ka > -8.43 (7.5065)
# Removed: Ti kb > -10.26 -> Ca ka <= 33.38 (8.0837) | Kept: Ca ka <= 33.38 -> Ti kb > -10.26 (10.8024)
# Removed: Cu kb > -1.61 -> Ti ka <= -4.69 (0.5816) | Kept: Ti ka <= -4.69 -> Cu kb > -1.61 (2.1321)
# Removed: Ag ka scattering <= 3.49 -> Ti ka <= -4.69 (0.2510) | Kept: Ti ka <= -4.69 -> Ag ka scattering <= 3.49 (1.9026)
# Removed: Cu kb > -1.61 -> Cu kb > -2.30 (0.7017) | Kept: Cu kb > -2.30 -> Cu kb > -1.61 (2.0679)
# Removed: Ag ka scattering <= -0.18 -> Cu kb > -2.30 (0.2595) | Kept: Cu kb > -2.30 -> Ag ka scattering <= -0.18 (1.2436)
# Removed: Ag ka scattering <= -0.18 -> Cu kb > -1.61 (0.5031) | Kept: Cu kb > -1.61 -> Ag ka scattering <= -0.18 (1.9585)
# Removed: Cu kb > -1.61 -> Cu kb > -2.88 (0.5719) | Kept: Cu kb > -2.88 -> Cu kb > -1.61 (0.5866)
# Removed: Ag ka scattering <= 3.49 -> Cu kb > -1.61 (0.2658) | Kept: Cu kb > -1.61 -> Ag ka scattering <= 3.49 (0.6273)
# Removed: Ag ka scattering <= -0.18 -> Cu kb > -2.88 (0.5358) | Kept: Cu kb > -2.88 -> Ag ka scattering <= -0.18 (0.5642)
# Removed: Cu kb > -2.88 -> Ca kb <= 12.61 (0.5361) | Kept: Ca kb <= 12.61 -> Cu kb > -2.88 (3.2068)
# Removed: Ca ka <= -6.65 -> Ca kb <= 12.61 (0.8011) | Kept: Ca kb <= 12.61 -> Ca ka <= -6.65 (1.5011)
# Removed: Ag ka scattering <= 1.67 -> Ca kb <= 12.61 (0.4975) | Kept: Ca kb <= 12.61 -> Ag ka scattering <= 1.67 (0.8638)
# Removed: Ag ka scattering <= 3.49 -> Ca kb <= 12.61 (0.5397) | Kept: Ca kb <= 12.61 -> Ag ka scattering <= 3.49 (0.8720)
# Removed: Cu kb > -2.88 -> Ag ka scattering <= 1.67 (0.5855) | Kept: Ag ka scattering <= 1.67 -> Cu kb > -2.88 (0.7517)
# Removed: background3 <= 2.86 -> background3 <= 1.29 (0.0299) | Kept: background3 <= 1.29 -> background3 <= 2.86 (0.0744)
# Removed: background3 <= -0.30 -> background3 <= 2.86 (0.0407) | Kept: background3 <= 2.86 -> background3 <= -0.30 (0.0580)
# Removed: background3 <= -0.30 -> Ti kb <= -2.91 (0.0764) | Kept: Ti kb <= -2.91 -> background3 <= -0.30 (0.3602)
# Removed: Ag ka scattering > -1.65 -> Ti kb <= -2.91 (0.1080) | Kept: Ti kb <= -2.91 -> Ag ka scattering > -1.65 (2.2143)
# Removed: Zn ka > -1.75 -> Ag ka scattering > -0.18 (0.0644) | Kept: Ag ka scattering > -0.18 -> Zn ka > -1.75 (0.4167)
# Removed: Ag ka scattering > -0.18 -> Ca kb <= -2.67 (0.2411) | Kept: Ca kb <= -2.67 -> Ag ka scattering > -0.18 (0.5205)
# Removed: Zn ka > -0.78 -> Zn ka > -1.75 (0.0659) | Kept: Zn ka > -1.75 -> Zn ka > -0.78 (0.1360)
# Removed: Zn ka > -1.75 -> Ca kb <= -2.67 (0.0571) | Kept: Ca kb <= -2.67 -> Zn ka > -1.75 (0.2577)
# Removed: Zn ka > -1.75 -> Cu ka <= -3.28 (0.2223) | Kept: Cu ka <= -3.28 -> Zn ka > -1.75 (0.2238)
# Removed: Zn ka > -0.78 -> Ti ka > -4.69 (0.0464) | Kept: Ti ka > -4.69 -> Zn ka > -0.78 (0.1734)
# Removed: Zn ka > -0.78 -> Zn ka <= 1.38 (0.0514) | Kept: Zn ka <= 1.38 -> Zn ka > -0.78 (0.0927)
# Removed: Cu ka <= -3.28 -> Ca kb <= -2.67 (0.4858) | Kept: Ca kb <= -2.67 -> Cu ka <= -3.28 (0.9644)
# Removed: background1 <= 2.08 -> Cu ka <= -3.28 (0.0301) | Kept: Cu ka <= -3.28 -> background1 <= 2.08 (0.2413)
# Removed: Zn ka <= 1.38 -> Ca ka <= -21.19 (0.0920) | Kept: Ca ka <= -21.19 -> Zn ka <= 1.38 (0.2103)
# Removed: background1 <= 2.08 -> Zn ka <= 1.38 (0.0237) | Kept: Zn ka <= 1.38 -> background1 <= 2.08 (0.1349)
# Removed: Zn ka <= 1.38 -> Ag ka scattering > 1.67 (0.0821) | Kept: Ag ka scattering > 1.67 -> Zn ka <= 1.38 (0.1197)
# Removed: Ag ka scattering > 1.67 -> Ca ka <= -21.19 (0.0531) | Kept: Ca ka <= -21.19 -> Ag ka scattering > 1.67 (0.2028)
# Removed: Ca ka <= -21.19 -> Ti ka > -4.69 (0.3444) | Kept: Ti ka > -4.69 -> Ca ka <= -21.19 (0.3533)
# Removed: background1 <= 2.08 -> Ca ka <= -21.19 (0.0485) | Kept: Ca ka <= -21.19 -> background1 <= 2.08 (0.3981)
# Removed: background3 > -2.55 -> Ca ka <= -21.19 (0.0045) | Kept: Ca ka <= -21.19 -> background3 > -2.55 (0.2206)
# Removed: Ag ka scattering > 1.67 -> Ti ka > -4.69 (0.1111) | Kept: Ti ka > -4.69 -> Ag ka scattering > 1.67 (0.1516)
# Removed: background1 <= 2.08 -> Zn ka > 0.08 (0.0250) | Kept: Zn ka > 0.08 -> background1 <= 2.08 (0.0386)
# Removed: background1 <= 2.08 -> Ti ka > -4.69 (0.0224) | Kept: Ti ka > -4.69 -> background1 <= 2.08 (0.1876)
# Removed: background3 > -2.55 -> background1 <= 2.08 (0.0055) | Kept: background1 <= 2.08 -> background3 > -2.55 (0.0231)
# Removed: background1 <= -0.11 -> Ti ka > -4.69 (0.0165) | Kept: Ti ka > -4.69 -> background1 <= -0.11 (0.3596)
# Removed: background3 > -2.55 -> Ti kb > -2.91 (0.0142) | Kept: Ti kb > -2.91 -> background3 > -2.55 (0.1131)
# Removed: background3 > -2.55 -> Zn ka <= 0.08 (0.0032) | Kept: Zn ka <= 0.08 -> background3 > -2.55 (0.0283)
# Removed: background3 > -2.55 -> background1 <= -0.11 (0.0043) | Kept: background1 <= -0.11 -> background3 > -2.55 (0.0137)
# Removed: background1 <= -0.11 -> Ti kb > -2.91 (0.0167) | Kept: Ti kb > -2.91 -> background1 <= -0.11 (0.1076)
# Removed: Zn ka <= 0.08 -> background1 <= -0.11 (0.0261) | Kept: background1 <= -0.11 -> Zn ka <= 0.08 (0.0297)
# Removed: background3 > 1.29 -> Zn ka <= 0.08 (0.0023) | Kept: Zn ka <= 0.08 -> background3 > 1.29 (0.0228)
# Removed: background1 > -0.11 -> Zn ka <= 0.08 (0.0141) | Kept: Zn ka <= 0.08 -> background1 > -0.11 (0.0192)
# Removed: background1 <= -0.11 -> background1 > -0.11 (0.0170) | Kept: background1 > -0.11 -> background1 <= -0.11 (0.0177)
# Removed: Ar ka + Ag L <= 1.07 -> background3 > 1.29 (0.0055) | Kept: background3 > 1.29 -> Ar ka + Ag L <= 1.07 (0.0056)
# Removed: background3 > 1.29 -> Zn kb > 0.29 (0.0025) | Kept: Zn kb > 0.29 -> background3 > 1.29 (0.0037)
# Removed: background1 <= -1.03 -> Ca kb <= -6.07 (0.0243) | Kept: Ca kb <= -6.07 -> background1 <= -1.03 (0.0918)
# Removed: background1 > -0.11 -> Ca kb <= -6.07 (0.0156) | Kept: Ca kb <= -6.07 -> background1 > -0.11 (0.1068)
# Removed: background1 > -1.87 -> Ca kb <= -6.07 (0.0148) | Kept: Ca kb <= -6.07 -> background1 > -1.87 (0.0976)
# Removed: Ar ka + Ag L <= -0.29 -> background1 <= -1.03 (0.0047) | Kept: background1 <= -1.03 -> Ar ka + Ag L <= -0.29 (0.0085)
# Removed: Zn kb > 0.29 -> Zn ka <= -0.78 (0.0041) | Kept: Zn ka <= -0.78 -> Zn kb > 0.29 (0.0158)
# Removed: Ar ka + Ag L <= 0.28 -> Zn ka <= -0.78 (0.0046) | Kept: Zn ka <= -0.78 -> Ar ka + Ag L <= 0.28 (0.0207)
# Removed: Ar ka + Ag L <= 0.28 -> Ar ka + Ag L <= 1.07 (0.0055) | Kept: Ar ka + Ag L <= 1.07 -> Ar ka + Ag L <= 0.28 (0.0057)
# Removed: Ar ka + Ag L > -1.05 -> Fe ka <= -22.90 (0.0027) | Kept: Fe ka <= -22.90 -> Ar ka + Ag L > -1.05 (0.0469)
# Removed: Ar ka + Ag L > -1.05 -> Fe kb <= -7.02 (0.0026) | Kept: Fe kb <= -7.02 -> Ar ka + Ag L > -1.05 (0.0457)
# Removed: background3 > -0.30 -> Ar ka + Ag L <= -0.29 (0.0027) | Kept: Ar ka + Ag L <= -0.29 -> background3 > -0.30 (0.0041)
# Removed: background3 > -0.30 -> background2 <= -0.37 (0.0020) | Kept: background2 <= -0.37 -> background3 > -0.30 (0.0070)
# Removed: Zn kb > 0.29 -> Cu ka <= -8.43 (0.0093) | Kept: Cu ka <= -8.43 -> Zn kb > 0.29 (0.0891)
# Removed: Zn kb > 0.29 -> background1 > -1.87 (0.0036) | Kept: background1 > -1.87 -> Zn kb > 0.29 (0.0114)
# Removed: Zn kb > 0.29 -> Ar ka + Ag L > 0.28 (0.0036) | Kept: Ar ka + Ag L > 0.28 -> Zn kb > 0.29 (0.0042)
# Removed: background2 <= -0.37 -> Cu ka <= -8.43 (0.0149) | Kept: Cu ka <= -8.43 -> background2 <= -0.37 (0.1603)
# Removed: Ar ka + Ag L <= -0.29 -> background1 > -0.11 (0.0042) | Kept: background1 > -0.11 -> Ar ka + Ag L <= -0.29 (0.0085)
# Removed: Ar ka + Ag L <= -0.29 -> Fe ka <= -23.71 (0.0029) | Kept: Fe ka <= -23.71 -> Ar ka + Ag L <= -0.29 (0.0541)
# Removed: Ar ka + Ag L <= -0.29 -> Cu ka <= -9.68 (0.0029) | Kept: Cu ka <= -9.68 -> Ar ka + Ag L <= -0.29 (0.0486)
# Removed: Ar ka + Ag L > 0.28 -> Fe ka <= -24.15 (0.0034) | Kept: Fe ka <= -24.15 -> Ar ka + Ag L > 0.28 (0.0285)
# Removed: background2 <= -0.37 -> Fe ka <= -23.71 (0.0047) | Kept: Fe ka <= -23.71 -> background2 <= -0.37 (0.0641)
# Removed: background2 > 0.27 -> Fe ka <= -23.71 (0.0038) | Kept: Fe ka <= -23.71 -> background2 > 0.27 (0.0561)
# Removed: Ar ka + Ag L > -0.29 -> Fe ka <= -24.15 (0.0042) | Kept: Fe ka <= -24.15 -> Ar ka + Ag L > -0.29 (0.0536)
# Removed: Ar ka + Ag L > -0.29 -> Fe ka <= -22.90 (0.0031) | Kept: Fe ka <= -22.90 -> Ar ka + Ag L > -0.29 (0.0371)
# Removed: Zn kb > -0.29 -> Ar ka + Ag L > -0.29 (0.0019) | Kept: Ar ka + Ag L > -0.29 -> Zn kb > -0.29 (0.0032)
# Removed: Fe ka <= -22.90 -> Cu ka <= -9.68 (0.0382) | Kept: Cu ka <= -9.68 -> Fe ka <= -22.90 (0.0484)
# Removed: Zn kb > -1.05 -> background2 > 0.27 (0.0023) | Kept: background2 > 0.27 -> Zn kb > -1.05 (0.0042)
# Removed: Zn kb > -1.05 -> Cu ka <= -9.68 (0.0019) | Kept: Cu ka <= -9.68 -> Zn kb > -1.05 (0.0204)
# Removed: Zn kb > -0.29 -> background2 > 0.27 (0.0028) | Kept: background2 > 0.27 -> Zn kb > -0.29 (0.0038)
# Removed: Zn kb <= -0.29 -> Ti kb > 2.45 (0.0009) | Kept: Ti kb > 2.45 -> Zn kb <= -0.29 (0.0124)
# Removed: Zn kb <= -0.29 -> Cu ka <= -9.68 (0.0024) | Kept: Cu ka <= -9.68 -> Zn kb <= -0.29 (0.0222)
# Removed: background2 <= 0.98 -> Cu kb <= 0.18 (0.0036) | Kept: Cu kb <= 0.18 -> background2 <= 0.98 (0.0181)
# Removed: background2 > -0.92 -> background2 <= 0.98 (0.0036) | Kept: background2 <= 0.98 -> background2 > -0.92 (0.0049)
# Removed: background2 > -0.92 -> Fe kb <= -6.37 (0.0023) | Kept: Fe kb <= -6.37 -> background2 > -0.92 (0.0152)
# Removed: Zn kb > -0.29 -> background2 > -0.92 (0.0032) | Kept: background2 > -0.92 -> Zn kb > -0.29 (0.0046)
# Removed: background1 > -1.03 -> Cu kb <= -2.30 (0.0015) | Kept: Cu kb <= -2.30 -> background1 > -1.03 (0.0185)
# Removed: Fe kb <= -7.02 -> Ti ka > 9.34 (0.0222) | Kept: Ti ka > 9.34 -> Fe kb <= -7.02 (0.0479)
# Removed: Zn kb <= 0.29 -> background2 > -0.37 (0.0008) | Kept: background2 > -0.37 -> Zn kb <= 0.29 (0.0015)
# Removed: background2 <= 0.27 -> Fe kb <= -6.37 (0.0016) | Kept: Fe kb <= -6.37 -> background2 <= 0.27 (0.0203)
# Removed: Zn kb <= 0.29 -> Ti kb > 2.45 (0.0010) | Kept: Ti kb > 2.45 -> Zn kb <= 0.29 (0.0112)
# Removed: background2 <= 0.27 -> Ti kb > 2.45 (0.0014) | Kept: Ti kb > 2.45 -> background2 <= 0.27 (0.0104)
#
# ======================================================================
# CONSTRUCTED GRAPH SUMMARY
# ======================================================================
# Initial edges: 534 | Removed: 99
# Predicate nodes: 90
# Metric: Covariance
# Weighting by explained variance: ENABLED
#
# ======================================================================
# Processando Grafo - Semente: 3
# ======================================================================
#
#
# Total bidirectional pairs found: 95
# Removed: Ca ka > -21.19 -> Ca ka > -26.11 (64.7603) | Kept: Ca ka > -26.11 -> Ca ka > -21.19 (64.8126)
# Removed: Ti ka <= 19.85 -> Ca ka > -6.65 (8.1177) | Kept: Ca ka > -6.65 -> Ti ka <= 19.85 (69.6970)
# Removed: Ca ka > -6.65 -> Fe kb > -7.02 (9.0514) | Kept: Fe kb > -7.02 -> Ca ka > -6.65 (65.3196)
# Removed: Ti ka <= 19.85 -> Fe kb > -7.02 (8.1695) | Kept: Fe kb > -7.02 -> Ti ka <= 19.85 (17.2749)
# Removed: Ti ka <= 9.34 -> Ti ka > -28.53 (12.5957) | Kept: Ti ka > -28.53 -> Ti ka <= 9.34 (39.2723)
# Removed: Fe kb > -7.41 -> Ti ka <= 9.34 (12.7586) | Kept: Ti ka <= 9.34 -> Fe kb > -7.41 (30.4528)
# Removed: Fe kb > -7.41 -> Ti ka > -28.53 (6.6565) | Kept: Ti ka > -28.53 -> Fe kb > -7.41 (26.0259)
# Removed: Ca kb > -8.59 -> Ca kb > -6.07 (7.9009) | Kept: Ca kb > -6.07 -> Ca kb > -8.59 (31.7121)
# Removed: Ca kb > -8.59 -> Fe kb > -7.79 (7.9228) | Kept: Fe kb > -7.79 -> Ca kb > -8.59 (10.5845)
# Removed: Cu ka > -9.68 -> Cu ka > -10.68 (10.3289) | Kept: Cu ka > -10.68 -> Cu ka > -9.68 (20.9874)
# Removed: Ca kb > -2.67 -> Cu ka > -9.68 (2.9628) | Kept: Cu ka > -9.68 -> Ca kb > -2.67 (9.3269)
# Removed: Ti kb <= 6.95 -> Ca kb > -2.67 (4.7201) | Kept: Ca kb > -2.67 -> Ti kb <= 6.95 (13.9127)
# Removed: Ca kb > -2.67 -> Cu ka > -8.43 (5.4732) | Kept: Cu ka > -8.43 -> Ca kb > -2.67 (6.2079)
# Removed: Cu ka > -8.43 -> Ti kb <= 6.95 (9.0444) | Kept: Ti kb <= 6.95 -> Cu ka > -8.43 (9.4406)
# Removed: Ti kb > -10.26 -> Cu ka > -8.43 (2.1051) | Kept: Cu ka > -8.43 -> Ti kb > -10.26 (7.9940)
# Removed: Ca ka <= 33.38 -> Ti kb > -10.26 (7.6939) | Kept: Ti kb > -10.26 -> Ca ka <= 33.38 (10.1920)
# Removed: Ti kb <= 2.45 -> Ca ka <= 33.38 (1.7767) | Kept: Ca ka <= 33.38 -> Ti kb <= 2.45 (13.6290)
# Removed: Cu kb > -1.61 -> Ti ka <= -4.69 (0.6570) | Kept: Ti ka <= -4.69 -> Cu kb > -1.61 (2.2506)
# Removed: Ag ka scattering <= 1.67 -> Ti ka <= -4.69 (0.2383) | Kept: Ti ka <= -4.69 -> Ag ka scattering <= 1.67 (0.9218)
# Removed: Ag ka scattering <= -0.18 -> Ti ka <= -4.69 (0.2782) | Kept: Ti ka <= -4.69 -> Ag ka scattering <= -0.18 (2.1378)
# Removed: Ag ka scattering <= -0.18 -> Ag ka scattering <= 3.49 (0.2741) | Kept: Ag ka scattering <= 3.49 -> Ag ka scattering <= -0.18 (0.8645)
# Removed: Cu kb > -1.61 -> Cu kb > -2.30 (0.7325) | Kept: Cu kb > -2.30 -> Cu kb > -1.61 (2.6695)
# Removed: Ag ka scattering <= -0.18 -> Cu kb > -2.30 (0.8166) | Kept: Cu kb > -2.30 -> Ag ka scattering <= -0.18 (1.2749)
# Removed: Ag ka scattering <= 1.67 -> Cu kb > -2.30 (0.2627) | Kept: Cu kb > -2.30 -> Ag ka scattering <= 1.67 (0.6261)
# Removed: Ca ka <= -6.65 -> Cu kb > -1.61 (0.8299) | Kept: Cu kb > -1.61 -> Ca ka <= -6.65 (1.0108)
# Removed: Cu kb > -2.88 -> Cu kb > -1.61 (0.5259) | Kept: Cu kb > -1.61 -> Cu kb > -2.88 (1.7932)
# Removed: Ag ka scattering <= -0.18 -> Ca kb <= 12.61 (0.2512) | Kept: Ca kb <= 12.61 -> Ag ka scattering <= -0.18 (0.7984)
# Removed: Ag ka scattering <= 1.67 -> Cu kb > -2.88 (0.4887) | Kept: Cu kb > -2.88 -> Ag ka scattering <= 1.67 (0.5840)
# Removed: Ag ka scattering <= 1.67 -> Ca kb <= 12.61 (0.2379) | Kept: Ca kb <= 12.61 -> Ag ka scattering <= 1.67 (2.4068)
# Removed: Ca ka <= -6.65 -> Cu kb > -2.88 (0.8505) | Kept: Cu kb > -2.88 -> Ca ka <= -6.65 (1.0684)
# Removed: Ca kb <= 12.61 -> Ca ka <= -6.65 (0.7603) | Kept: Ca ka <= -6.65 -> Ca kb <= 12.61 (1.5032)
# Removed: Ca kb <= 12.61 -> Cu kb > -2.88 (0.8440) | Kept: Cu kb > -2.88 -> Ca kb <= 12.61 (0.9890)
# Removed: background3 <= 2.86 -> background3 <= 1.29 (0.0422) | Kept: background3 <= 1.29 -> background3 <= 2.86 (0.1064)
# Removed: background3 <= -0.30 -> Ti kb <= -2.91 (0.0615) | Kept: Ti kb <= -2.91 -> background3 <= -0.30 (0.3792)
# Removed: Ag ka scattering > -1.65 -> Ti kb <= -2.91 (0.3053) | Kept: Ti kb <= -2.91 -> Ag ka scattering > -1.65 (1.5343)
# Removed: Ag ka scattering > -0.18 -> Ti kb <= -2.91 (0.0813) | Kept: Ti kb <= -2.91 -> Ag ka scattering > -0.18 (0.2692)
# Removed: Zn ka > -1.75 -> Ca kb <= -2.67 (0.2366) | Kept: Ca kb <= -2.67 -> Zn ka > -1.75 (0.5112)
# Removed: Zn ka > -1.75 -> Ag ka scattering > -0.18 (0.1267) | Kept: Ag ka scattering > -0.18 -> Zn ka > -1.75 (0.2528)
# Removed: Zn ka > -1.75 -> Cu ka <= -3.28 (0.1093) | Kept: Cu ka <= -3.28 -> Zn ka > -1.75 (0.3008)
# Removed: Zn ka > -0.78 -> Ag ka scattering > -0.18 (0.0627) | Kept: Ag ka scattering > -0.18 -> Zn ka > -0.78 (0.1478)
# Removed: Zn ka > -0.78 -> Cu ka <= -3.28 (0.1588) | Kept: Cu ka <= -3.28 -> Zn ka > -0.78 (0.2330)
# Removed: Zn ka > -0.78 -> Ca kb <= -2.67 (0.0614) | Kept: Ca kb <= -2.67 -> Zn ka > -0.78 (0.9519)
# Removed: Zn ka > -0.78 -> Ag ka scattering > 1.67 (0.0434) | Kept: Ag ka scattering > 1.67 -> Zn ka > -0.78 (0.0649)
# Removed: Ag ka scattering > -0.18 -> Ca kb <= -2.67 (0.2450) | Kept: Ca kb <= -2.67 -> Ag ka scattering > -0.18 (0.2669)
# Removed: Ag ka scattering > -0.18 -> Cu ka <= -3.28 (0.0870) | Kept: Cu ka <= -3.28 -> Ag ka scattering > -0.18 (0.2547)
# Removed: Cu ka <= -3.28 -> Ca kb <= -2.67 (0.2622) | Kept: Ca kb <= -2.67 -> Cu ka <= -3.28 (0.5216)
# Removed: Zn ka <= 1.38 -> background1 <= 2.08 (0.0443) | Kept: background1 <= 2.08 -> Zn ka <= 1.38 (0.0526)
# Removed: background1 <= 2.08 -> Ca ka <= -21.19 (0.1286) | Kept: Ca ka <= -21.19 -> background1 <= 2.08 (0.2232)
# Removed: Ag ka scattering > 1.67 -> background1 <= 2.08 (0.0576) | Kept: background1 <= 2.08 -> Ag ka scattering > 1.67 (0.0727)
# Removed: Zn ka <= 1.38 -> Ca ka <= -21.19 (0.0891) | Kept: Ca ka <= -21.19 -> Zn ka <= 1.38 (0.8402)
# Removed: Zn ka <= 1.38 -> Ti ka > -4.69 (0.0862) | Kept: Ti ka > -4.69 -> Zn ka <= 1.38 (0.1965)
# Removed: Ag ka scattering > 1.67 -> Zn ka <= 1.38 (0.0622) | Kept: Zn ka <= 1.38 -> Ag ka scattering > 1.67 (0.1232)
# Removed: Ca kb <= -6.07 -> Ti ka > -4.69 (0.1113) | Kept: Ti ka > -4.69 -> Ca kb <= -6.07 (0.1144)
# Removed: background3 > -2.55 -> Zn ka > 0.08 (0.0083) | Kept: Zn ka > 0.08 -> background3 > -2.55 (0.0343)
# Removed: Zn ka > 0.08 -> Fe ka <= -23.71 (0.0131) | Kept: Fe ka <= -23.71 -> Zn ka > 0.08 (0.0485)
# Removed: background3 > 1.29 -> Zn ka > 0.08 (0.0041) | Kept: Zn ka > 0.08 -> background3 > 1.29 (0.0165)
# Removed: Ar ka + Ag L <= 1.07 -> Zn ka > 0.08 (0.0045) | Kept: Zn ka > 0.08 -> Ar ka + Ag L <= 1.07 (0.0169)
# Removed: background1 > -1.87 -> Zn ka <= 0.08 (0.0161) | Kept: Zn ka <= 0.08 -> background1 > -1.87 (0.0218)
# Removed: background1 <= -0.11 -> Zn ka <= 0.08 (0.0141) | Kept: Zn ka <= 0.08 -> background1 <= -0.11 (0.0274)
# Removed: background3 > 1.29 -> background1 <= -0.11 (0.0030) | Kept: background1 <= -0.11 -> background3 > 1.29 (0.0169)
# Removed: Zn ka <= -0.78 -> Zn ka <= 0.08 (0.0248) | Kept: Zn ka <= 0.08 -> Zn ka <= -0.78 (0.0416)
# Removed: Ar ka + Ag L <= 0.28 -> Zn ka <= -0.78 (0.0051) | Kept: Zn ka <= -0.78 -> Ar ka + Ag L <= 0.28 (0.0201)
# Removed: background1 <= -1.03 -> Zn ka <= -0.78 (0.0120) | Kept: Zn ka <= -0.78 -> background1 <= -1.03 (0.0176)
# Removed: Ar ka + Ag L <= 1.07 -> Zn ka <= -0.78 (0.0051) | Kept: Zn ka <= -0.78 -> Ar ka + Ag L <= 1.07 (0.0215)
# Removed: background3 > 1.29 -> Zn ka <= 0.08 (0.0059) | Kept: Zn ka <= 0.08 -> background3 > 1.29 (0.0246)
# Removed: Zn ka <= 0.08 -> Ca kb <= -6.07 (0.0454) | Kept: Ca kb <= -6.07 -> Zn ka <= 0.08 (0.1886)
# Removed: background3 > 1.29 -> Ar ka + Ag L <= 0.28 (0.0047) | Kept: Ar ka + Ag L <= 0.28 -> background3 > 1.29 (0.0110)
# Removed: Ar ka + Ag L <= 0.28 -> Ar ka + Ag L <= 1.07 (0.0050) | Kept: Ar ka + Ag L <= 1.07 -> Ar ka + Ag L <= 0.28 (0.0057)
# Removed: Ar ka + Ag L <= 0.28 -> Cu ka <= -8.43 (0.0054) | Kept: Cu ka <= -8.43 -> Ar ka + Ag L <= 0.28 (0.1710)
# Removed: Ca kb <= -6.07 -> Ti kb > -2.91 (0.1037) | Kept: Ti kb > -2.91 -> Ca kb <= -6.07 (0.1915)
# Removed: Ar ka + Ag L <= 1.07 -> Ar ka + Ag L > -1.05 (0.0044) | Kept: Ar ka + Ag L > -1.05 -> Ar ka + Ag L <= 1.07 (0.0102)
# Removed: background3 > -0.30 -> Cu ka <= -8.43 (0.0023) | Kept: Cu ka <= -8.43 -> background3 > -0.30 (0.1016)
# Removed: background1 <= -1.03 -> Cu ka <= -8.43 (0.0123) | Kept: Cu ka <= -8.43 -> background1 <= -1.03 (0.2809)
# Removed: Ar ka + Ag L <= -0.29 -> background2 <= -0.37 (0.0036) | Kept: background2 <= -0.37 -> Ar ka + Ag L <= -0.29 (0.0044)
# Removed: Ar ka + Ag L > 0.28 -> Ar ka + Ag L <= -0.29 (0.0036) | Kept: Ar ka + Ag L <= -0.29 -> Ar ka + Ag L > 0.28 (0.0047)
# Removed: Ar ka + Ag L <= -0.29 -> Ar ka + Ag L > -1.05 (0.0037) | Kept: Ar ka + Ag L > -1.05 -> Ar ka + Ag L <= -0.29 (0.0050)
# Removed: Ar ka + Ag L > -1.05 -> Zn kb > 0.29 (0.0036) | Kept: Zn kb > 0.29 -> Ar ka + Ag L > -1.05 (0.0082)
# Removed: background2 <= -0.37 -> Cu kb <= 0.18 (0.0054) | Kept: Cu kb <= 0.18 -> background2 <= -0.37 (0.0378)
# Removed: background2 <= -0.37 -> Cu ka <= -9.68 (0.0048) | Kept: Cu ka <= -9.68 -> background2 <= -0.37 (0.0381)
# Removed: background2 > 0.27 -> Cu kb <= 0.18 (0.0027) | Kept: Cu kb <= 0.18 -> background2 > 0.27 (0.0389)
# Removed: Ar ka + Ag L > -1.05 -> Fe ka <= -23.71 (0.0030) | Kept: Fe ka <= -23.71 -> Ar ka + Ag L > -1.05 (0.0619)
# Removed: Ar ka + Ag L > -1.05 -> Fe ka <= -24.15 (0.0030) | Kept: Fe ka <= -24.15 -> Ar ka + Ag L > -1.05 (0.0458)
# Removed: Fe ka <= -22.90 -> Fe ka <= -24.15 (0.0363) | Kept: Fe ka <= -24.15 -> Fe ka <= -22.90 (0.0836)
# Removed: Ar ka + Ag L > -0.29 -> Fe ka <= -24.15 (0.0022) | Kept: Fe ka <= -24.15 -> Ar ka + Ag L > -0.29 (0.0712)
# Removed: Zn kb > -1.05 -> Fe ka <= -24.15 (0.0025) | Kept: Fe ka <= -24.15 -> Zn kb > -1.05 (0.0605)
# Removed: Zn kb <= 0.29 -> Fe ka <= -24.15 (0.0026) | Kept: Fe ka <= -24.15 -> Zn kb <= 0.29 (0.0187)
# Removed: Fe ka <= -22.90 -> Fe kb <= -7.02 (0.0239) | Kept: Fe kb <= -7.02 -> Fe ka <= -22.90 (0.0328)
# Removed: Fe ka <= -22.90 -> Fe kb <= -6.37 (0.0318) | Kept: Fe kb <= -6.37 -> Fe ka <= -22.90 (0.0406)
# Removed: Fe kb <= -6.37 -> Fe kb <= -7.02 (0.0102) | Kept: Fe kb <= -7.02 -> Fe kb <= -6.37 (0.0213)
# Removed: background2 <= 0.27 -> Fe kb <= -7.02 (0.0016) | Kept: Fe kb <= -7.02 -> background2 <= 0.27 (0.0219)
# Removed: background2 > 0.27 -> Fe kb <= -7.02 (0.0019) | Kept: Fe kb <= -7.02 -> background2 > 0.27 (0.0392)
# Removed: Zn kb <= 1.07 -> Cu kb <= -1.61 (0.0010) | Kept: Cu kb <= -1.61 -> Zn kb <= 1.07 (0.0281)
# Removed: Ti ka > 9.34 -> Fe kb <= -6.37 (0.0211) | Kept: Fe kb <= -6.37 -> Ti ka > 9.34 (0.0543)
# Removed: Zn kb > -1.05 -> Ti kb > 2.45 (0.0010) | Kept: Ti kb > 2.45 -> Zn kb > -1.05 (0.0126)
# Removed: Ar ka + Ag L > -0.29 -> background2 > 0.27 (0.0007) | Kept: background2 > 0.27 -> Ar ka + Ag L > -0.29 (0.0051)
#
# ======================================================================
# CONSTRUCTED GRAPH SUMMARY
# ======================================================================
# Initial edges: 517 | Removed: 95
# Predicate nodes: 90
# Metric: Covariance
# Weighting by explained variance: ENABLED
#
# Processing graph LRC...
#
# Processing graph LRC...
#
# Processing graph LRC...
#
# Processing graph LRC...
#    Predicate_Cov_Seed_0 Predicate_Cov_Seed_1 Predicate_Cov_Seed_2  \
# 0        Fe ka > -23.71       Fe ka > -23.71       Fe ka > -23.71
# 1        Fe ka > -24.15       Fe ka > -24.15       Fe ka > -24.15
# 2        Fe ka > -24.62       Fe ka > -24.62       Fe ka > -24.62
# 3        Ca ka > -21.19       Ca ka > -26.11       Ca ka > -21.19
# 4        Ca ka > -26.11       Ca ka > -21.19       Ca ka > -26.11
# ..                  ...                  ...                  ...
# 87        Zn kb <= 0.29         Ti kb > 2.45         Zn kb > 0.29
# 88  background2 <= 0.27       Fe kb <= -7.41  background3 > -0.30
# 89       Fe kb <= -7.41        Zn kb <= 1.07        Zn kb <= 1.07
# 90              Class_A              Class_A              Class_A
# 91              Class_B              Class_B              Class_B
#
#      Predicate_Cov_Seed_3
# 0          Fe ka > -23.71
# 1          Fe ka > -24.15
# 2          Fe ka > -24.62
# 3          Ca ka > -21.19
# 4           Fe kb > -7.02
# ..                    ...
# 87    background3 > -0.30
# 88          Zn kb <= 1.07
# 89  Ar ka + Ag L <= -0.29
# 90                Class_A
# 91                Class_B
#
# [92 rows x 4 columns]

# %%
# Somar LRCs de predicados equivalentes entre diferentes seeds
lrc_combined_list = []

for seed in random_seeds:
    lrc_df = lrc_cov_by_seed[seed].copy()
    lrc_combined_list.append(lrc_df) # o append adiciona o dataframe ao final da lista

# Concatenar todos os dataframes
lrc_all_seeds = pd.concat(lrc_combined_list, ignore_index=True) 

# Agrupar por predicado (Node) e somar as LRCs, mantendo Zone, Threshold e Operator
lrc_summed_df_cov = lrc_all_seeds.groupby('Node').agg({ # o .agg pode ser usado para aplicar múltiplas funções de agregação
    'Local_Reaching_Centrality': 'mean', # sum = somando as LRCs, poderia ser média ou outro agregado
    'Zone': 'first',
    'Threshold': 'first',
    'Operator': 'first'
}).reset_index()

# Ordenar pelo valor de LRC somado (maior para menor)
lrc_summed_df_cov = lrc_summed_df_cov.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
# vamoss pegar so os valore sunicos de lrc_summed_df baseado na zona espectral
lrc_summed_unique_df_cov = lrc_summed_df_cov.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
#lrc_summed_unique_df_cov = lrc_summed_unique_df_cov.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
lrc_summed_unique_df_cov
# Out:
#                          Node  Local_Reaching_Centrality              Zone  \
# 0              Fe ka > -23.71                  16.105135             Fe ka
# 1              Ca ka > -21.19                   5.942205             Ca ka
# 2               Fe kb > -7.02                   4.886055             Fe kb
# 3              Ti ka > -28.53                   3.725296             Ti ka
# 4               Ca kb > -6.07                   2.162218             Ca kb
# 5              Cu ka > -10.68                   1.623976             Cu ka
# 6               Ti kb <= 6.95                   0.786247             Ti kb
# 7               Cu kb > -2.30                   0.162589             Cu kb
# 8   Ag ka scattering <= -0.18                   0.123164  Ag ka scattering
# 9         background3 <= 1.29                   0.047431       background3
# 10              Zn ka > -0.78                   0.030001             Zn ka
# 11        background1 <= 2.08                   0.020911       background1
# 12      Ar ka + Ag L <= -0.29                   0.010480      Ar ka + Ag L
# 13        background2 > -0.92                   0.009360       background2
# 14               Zn kb > 0.29                   0.008001             Zn kb
# 15                    Class_A                   0.000000              None
#
#    Threshold Operator
# 0     -23.71        >
# 1     -21.19        >
# 2      -7.02        >
# 3     -28.53        >
# 4      -6.07        >
# 5     -10.68        >
# 6       6.95       <=
# 7      -2.30        >
# 8      -0.18       <=
# 9       1.29       <=
# 10     -0.78        >
# 11      2.08       <=
# 12     -0.29       <=
# 13     -0.92        >
# 14      0.29        >
# 15      None     None

# %%
# Criar zone_sums_df para dados NÃO pré-processados (Xcalclass)
spectral_zones_original = exp.extract_spectral_zones(Xcalclass, spectral_cuts)
zones_original = exp.aggregate_spectral_zones_pca(spectral_zones_original) # apca aggregation

# Aplicar o mapeamento
lrc_summed_df_cov_natural = exp.map_thresholds_to_natural(
    lrc_df=lrc_summed_df_cov,
    zone_sums_preprocessed=zone_scores_df,
    zone_sums_natural=zones_original[0]
)

lrc_summed_df_cov_natural
# Out:
# Zone 'Ar ka + Ag L': VE = 9.76%, dim = 29 variables
# Zone 'Ca ka': VE = 99.20%, dim = 17 variables
# Zone 'Ca kb': VE = 93.13%, dim = 13 variables
# Zone 'Ti ka': VE = 98.39%, dim = 19 variables
# Zone 'Ti kb': VE = 85.13%, dim = 16 variables
# Zone 'background1': VE = 12.27%, dim = 39 variables
# Zone 'Fe ka': VE = 99.86%, dim = 25 variables
# Zone 'Fe kb': VE = 97.91%, dim = 22 variables
# Zone 'background2': VE = 8.43%, dim = 18 variables
# Zone 'Cu ka': VE = 98.29%, dim = 20 variables
# Zone 'Zn ka': VE = 24.14%, dim = 21 variables
# Zone 'Cu kb': VE = 66.75%, dim = 19 variables
# Zone 'Zn kb': VE = 7.95%, dim = 30 variables
# Zone 'background3': VE = 2.98%, dim = 451 variables
# Zone 'Ag ka scattering': VE = 38.41%, dim = 49 variables
#                    Node  Local_Reaching_Centrality         Zone Threshold  \
# 0        Fe ka > -23.71                  16.105135        Fe ka    -23.71
# 1        Fe ka > -24.15                  11.330682        Fe ka    -24.15
# 2        Fe ka > -24.62                   7.750458        Fe ka    -24.62
# 3        Ca ka > -21.19                   5.942205        Ca ka    -21.19
# 4        Ca ka > -26.11                   5.834215        Ca ka    -26.11
# ..                  ...                        ...          ...       ...
# 87  background2 <= 0.27                   0.006812  background2      0.27
# 88       Fe kb <= -7.41                   0.005892        Fe kb     -7.41
# 89        Zn kb <= 1.07                   0.005424        Zn kb      1.07
# 90              Class_A                   0.000000         None      None
# 91              Class_B                   0.000000         None      None
#
#    Operator  Threshold_Natural  Reference_Sample_Index  Approximation_Error  \
# 0         >        -228.336686                    46.0             0.003068
# 1         >        -232.833909                   112.0             0.002150
# 2         >        -240.227437                    43.0             0.003827
# 3         >        -238.439137                   152.0             0.149595
# 4         >        -287.239935                   110.0             0.000994
# ..      ...                ...                     ...                  ...
# 87       <=           0.811175                    47.0             0.000881
# 88       <=         -32.289144                     4.0             0.001335
# 89       <=          -2.546607                   108.0             0.003444
# 90     None                NaN                     NaN                  NaN
# 91     None                NaN                     NaN                  NaN
#
#                Node_Natural
# 0       Fe ka > -228.336686
# 1       Fe ka > -232.833909
# 2       Fe ka > -240.227437
# 3       Ca ka > -238.439137
# 4       Ca ka > -287.239935
# ..                      ...
# 87  background2 <= 0.811175
# 88      Fe kb <= -32.289144
# 89       Zn kb <= -2.546607
# 90                     None
# 91                     None
#
# [92 rows x 9 columns]

# %% [markdown]
# ## Reconstrução de Thresholds Multivariados
#
# Agora vamos pegar os thresholds dos predicados mais importantes e reconstruí-los como espectros completos.

# %%
import plotly.graph_objects as go

n = 0
zone_name = lrc_summed_df_cov_natural.iloc[n]['Zone']
threshold_score = float(lrc_summed_df_cov_natural.iloc[n]['Threshold_Natural'])  # Corrigido: usa n em vez de 7

# Usar pca_info_dict dos dados ORIGINAIS (zones_original[1])
pca_info_dict_original = zones_original[1]

# Reconstrução: τ = mean + threshold * loadings (no espaço original)
threshold_spectrum = exp.reconstruct_threshold_to_spectrum(
    threshold_value=threshold_score,
    zone_name=zone_name,
    pca_info_dict=pca_info_dict_original
)
print(f"\nEspectro de threshold reconstruído para zona '{zone_name}':")
print(f"  - Dimensão: {len(threshold_spectrum)} variáveis espectrais")
print(f"  - Range de energias: {threshold_spectrum.index[0]} - {threshold_spectrum.index[-1]}")
print(f"  - Variância explicada pela PC1: {pca_info_dict_original[zone_name]['variance_explained']:.2%}")

# Usar dados ORIGINAIS para plotar (spectral_zones_original)
zone_df = spectral_zones_original[zone_name]

# Plotar zona com threshold (inline)
fig = go.Figure()
x_values = pd.to_numeric(zone_df.columns, errors='coerce')

# Plotar espectros das amostras coloridas por classe
colors = {'A': 'gold', 'B': 'blue'}
for idx, row in zone_df.iterrows():
    class_label = ycalclass.iloc[idx] if idx < len(ycalclass) else 'Unknown'
    fig.add_trace(go.Scatter(
        x=x_values,
        y=row.values,
        mode='lines',
        line=dict(color=colors.get(class_label, 'rgba(128,128,128,0.3)'), width=0.5),
        name=f'Class {class_label}',
        showlegend=False,
        hoverinfo='skip'
    ))

# Plotar espectro de threshold (destaque)
fig.add_trace(go.Scatter(
    x=x_values,
    y=threshold_spectrum.values,
    mode='lines',
    line=dict(color='red', width=4, dash='dash'),
    name=f'Threshold Spectrum ({threshold_spectrum.name})'
))

# Layout do gráfico
fig.update_layout(
    title=f"Zona '{zone_name}' com Threshold Multivariado (Predicado: {lrc_summed_df_cov_natural.iloc[n]['Node_Natural']})",
    xaxis_title='Energia / Comprimento de Onda',
    yaxis_title='Intensidade',
    template='plotly_white',
    showlegend=True,
    legend=dict(yanchor="top", y=0.99, xanchor="left", x=0.01)
)

fig.show()
# Out:
# Espectro de threshold reconstruído para zona 'Fe ka':
#   - Dimensão: 25 variáveis espectrais
#   - Range de energias: 6.15 - 6.76
#   - Variância explicada pela PC1: 99.86%

# %%
import explaining as exp

# LISTA DE SEMENTES A TESTAR
random_seeds = [0, 1, 2, 3]

all_results_pert = {}
training_samples = len(Xcalclass)

# LOOP: PROCESSAR CADA SEMENTE

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando semente: {seed}")
    print(f"{'='*70}\n")
    # Bagging
    bags_result_seed = exp.bagging_predicates(
        zone_sums_df=zone_scores_df,
        y_predicted_numeric=y_pred,
        predicates_df=predicates_quantiles[0],
        n_bags=10,
        #n_predicates_per_bag=40,
        n_samples_per_bag=int(training_samples*0.8), # 80 % da base para amostrar (convertido para int)
        min_samples_per_predicate=int(training_samples*0.2), # 20 % da base para limitar (convertido para int)
        replace=False,
        sample_bagging=True,
        predicate_bagging=False,
        random_seed=seed
    )
    # Inserir classe prevista
    for bag_name, pred_dict in bags_result_seed.items(): # iterando sobre cada bag
        for pred_rule, df_info in pred_dict.items():
            df_info['Class_Predicted'] = np.where(df_info['Predicted_Y'] >= 0.5, 'A', 'B') # binarizando com threshold 0.5, A = eut, B = dist

    pert_results_seed = exp.calculate_predicate_perturbation(
        estimator=svm_model[3],
        Xcalclass_prep=Xcalclass_prep,
        folds_struct=bags_result_seed,
        predicates_df=predicates_quantiles[0],
        spectral_cuts=spectral_cuts,
        #perturbation_value=0,
        perturbation_mode='median', # valores entre 'mean' ou 'min'
        stats_source='full', # full indica usar todas as amostras para calcular estatísticas enquanto que 'fold' usa apenas as amostras do fold atual
        #metric='mean_abs_diff',   # Média com sinal (pode ser negativo)
        aim='classification',
        metric='probability_shift', 
        verbose=True
    )

    # Salvar no dicionário principal
    all_results_pert[seed] = {
        'bags_result': bags_result_seed,
        'pert_results_dict': pert_results_seed
    }

# CONSTRUÇÃO DE GRAFOS PARA MÚLTIPLAS SEMENTES (LOOP EXTERNO)
# Dicionário para armazenar grafos
graphs_pert_by_seed = {}

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando Grafo - Semente: {seed}")
    print(f"{'='*70}\n")
    
    # Construir grafo para esta semente (sem predicates_df - extraído da regra)
    DG = exp.build_predicate_graph(
        bags_result=all_results_pert[seed]['bags_result'],
        predicate_ranking_dict=all_results_pert[seed]['pert_results_dict'],
        metric_column='Perturbation',
        random_state=seed,
        show_details=True,
        var_exp=True,
        pca_info_dict=pca_info_dict
    )

    # Armazenar grafo
    graphs_pert_by_seed[seed] = DG  

# Calcular LRC usando a função pronta do explaining.py
lrc_pert_by_seed = {}
for seed in random_seeds:
    DG = graphs_pert_by_seed[seed]
    lrc_pert_df_seed = exp.calculate_lrc_single_graph(DG, predicates_quantiles[0])
    lrc_pert_df_seed['Seed'] = seed  # Adicionar coluna com a semente
    lrc_pert_by_seed[seed] = lrc_pert_df_seed

# junando todas as colunas 'Node' de lrc_by_seed em um único dataframe
lrc_pert_all_seeds_df = pd.DataFrame()
for seed in random_seeds:
    lrc_pert_df_seed = lrc_pert_by_seed[seed].rename(columns={'Node': f'Predicate_pert_Seed_{seed}'})
    lrc_pert_all_seeds_df = pd.concat([lrc_pert_all_seeds_df, lrc_pert_df_seed[[f'Predicate_pert_Seed_{seed}']]], axis=1)

# vamos filtrar lrc_by_seed em cada semente para manter apenas as zonas espectrais únicas com maior LRC em um mesmo dataframe
lrc_pert_unique_by_seed = {}
for seed, lrc_df in lrc_pert_by_seed.items():
    lrc_pert_unique_df = lrc_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
    lrc_pert_unique_df = lrc_pert_unique_df.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
    lrc_pert_unique_by_seed[seed] = lrc_pert_unique_df

lrc_pert_all_seeds_df # exibindo o dataframe consolidado com predicados de todas as sementes
# Out:
# ======================================================================
# Processando semente: 0
# ======================================================================
#
# Bag_1 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_2 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_3 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_4 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_5 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_6 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_7 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_8 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_9 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# Bag_10 | Samples: Yes | Predicates: No (All) | Valid: 90 | Discarded: 30
# ======================================================================
# PERTURBATION IMPORTANCE FOR PREDICATES
# ======================================================================
# Task type (aim): classification
# Perturbation mode: median
# Statistics source: full
# Metric: probability_shift
# Total folds: 10
#
#
# [Bag_1] Processing 90 predicates...
#   Predicate: Ar ka + Ag L > -1.05 (n=177)
#     Zone: 29 columns
#     Importance: 0.000231
#   Predicate: Ar ka + Ag L <= -0.29 (n=98)
#     Zone: 29 columns
#     Importance: 0.000363
#   Predicate: Ar ka + Ag L > -0.29 (n=129)
#     Zone: 29 columns
#     Importance: 0.000129
#   Predicate: Ar ka + Ag L <= 0.28 (n=138)
#     Zone: 29 columns
#     Importance: 0.000307
#   Predicate: Ar ka + Ag L > 0.28 (n=89)
#     Zone: 29 columns
#     Importance: 0.000111
#   Predicate: Ar ka + Ag L <= 1.07 (n=183)
#     Zone: 29 columns
#     Importance: 0.000267
#   Predicate: Ca ka > -26.11 (n=175)
#     Zone: 17 columns
#     Importance: 0.011231
#   Predicate: Ca ka <= -21.19 (n=94)
#     Zone: 17 columns
#     Importance: 0.012986
#   Predicate: Ca ka > -21.19 (n=133)
#     Zone: 17 columns
#     Importance: 0.012674
#   Predicate: Ca ka <= -6.65 (n=140)
#     Zone: 17 columns
#     Importance: 0.009063
#   Predicate: Ca ka > -6.65 (n=87)
#     Zone: 17 columns
#     Importance: 0.018821
#   Predicate: Ca ka <= 33.38 (n=183)
#     Zone: 17 columns
#     Importance: 0.007970
#   Predicate: Ca kb > -8.59 (n=174)
#     Zone: 13 columns
#     Importance: 0.000351
#   Predicate: Ca kb <= -6.07 (n=94)
#     Zone: 13 columns
#     Importance: 0.000780
#   Predicate: Ca kb > -6.07 (n=133)
#     Zone: 13 columns
#     Importance: 0.000304
#   Predicate: Ca kb <= -2.67 (n=140)
#     Zone: 13 columns
#     Importance: 0.000563
#   Predicate: Ca kb > -2.67 (n=87)
#     Zone: 13 columns
#     Importance: 0.000402
#   Predicate: Ca kb <= 12.61 (n=182)
#     Zone: 13 columns
#     Importance: 0.000518
#   Predicate: Ti ka > -28.53 (n=184)
#     Zone: 19 columns
#     Importance: 0.073447
#   Predicate: Ti ka <= -4.69 (n=91)
#     Zone: 19 columns
#     Importance: 0.205934
#   Predicate: Ti ka > -4.69 (n=136)
#     Zone: 19 columns
#     Importance: 0.014128
#   Predicate: Ti ka <= 9.34 (n=136)
#     Zone: 19 columns
#     Importance: 0.142518
#   Predicate: Ti ka > 9.34 (n=91)
#     Zone: 19 columns
#     Importance: 0.014055
#   Predicate: Ti ka <= 19.85 (n=181)
#     Zone: 19 columns
#     Importance: 0.110712
#   Predicate: Ti kb > -10.26 (n=182)
#     Zone: 16 columns
#     Importance: 0.003700
#   Predicate: Ti kb <= -2.91 (n=91)
#     Zone: 16 columns
#     Importance: 0.006446
#   Predicate: Ti kb > -2.91 (n=136)
#     Zone: 16 columns
#     Importance: 0.001980
#   Predicate: Ti kb <= 2.45 (n=138)
#     Zone: 16 columns
#     Importance: 0.005103
#   Predicate: Ti kb > 2.45 (n=89)
#     Zone: 16 columns
#     Importance: 0.001704
#   Predicate: Ti kb <= 6.95 (n=185)
#     Zone: 16 columns
#     Importance: 0.004248
#   Predicate: background1 > -1.87 (n=181)
#     Zone: 39 columns
#     Importance: 0.000239
#   Predicate: background1 <= -1.03 (n=91)
#     Zone: 39 columns
#     Importance: 0.000544
#   Predicate: background1 > -1.03 (n=136)
#     Zone: 39 columns
#     Importance: 0.000236
#   Predicate: background1 <= -0.11 (n=136)
#     Zone: 39 columns
#     Importance: 0.000435
#   Predicate: background1 > -0.11 (n=91)
#     Zone: 39 columns
#     Importance: 0.000247
#   Predicate: background1 <= 2.08 (n=183)
#     Zone: 39 columns
#     Importance: 0.000420
#   Predicate: Fe ka > -24.62 (n=183)
#     Zone: 25 columns
#     Importance: 0.000749
#   Predicate: Fe ka <= -24.15 (n=86)
#     Zone: 25 columns
#     Importance: 0.000255
#   Predicate: Fe ka > -24.15 (n=141)
#     Zone: 25 columns
#     Importance: 0.000930
#   Predicate: Fe ka <= -23.71 (n=136)
#     Zone: 25 columns
#     Importance: 0.000200
#   Predicate: Fe ka > -23.71 (n=91)
#     Zone: 25 columns
#     Importance: 0.001383
#   Predicate: Fe ka <= -22.90 (n=179)
#     Zone: 25 columns
#     Importance: 0.000173
#   Predicate: Fe kb > -7.79 (n=181)
#     Zone: 22 columns
#     Importance: 0.001700
#   Predicate: Fe kb <= -7.41 (n=91)
#     Zone: 22 columns
#     Importance: 0.000086
#   Predicate: Fe kb > -7.41 (n=136)
#     Zone: 22 columns
#     Importance: 0.002244
#   Predicate: Fe kb <= -7.02 (n=135)
#     Zone: 22 columns
#     Importance: 0.000110
#   Predicate: Fe kb > -7.02 (n=92)
#     Zone: 22 columns
#     Importance: 0.003242
#   Predicate: Fe kb <= -6.37 (n=181)
#     Zone: 22 columns
#     Importance: 0.000140
#   Predicate: background2 > -0.92 (n=177)
#     Zone: 18 columns
#     Importance: 0.000118
#   Predicate: background2 <= -0.37 (n=96)
#     Zone: 18 columns
#     Importance: 0.000126
#   Predicate: background2 > -0.37 (n=131)
#     Zone: 18 columns
#     Importance: 0.000134
#   Predicate: background2 <= 0.27 (n=142)
#     Zone: 18 columns
#     Importance: 0.000133
#   Predicate: background2 > 0.27 (n=85)
#     Zone: 18 columns
#     Importance: 0.000127
#   Predicate: background2 <= 0.98 (n=186)
#     Zone: 18 columns
#     Importance: 0.000124
#   Predicate: Cu ka > -10.68 (n=181)
#     Zone: 20 columns
#     Importance: 0.005924
#   Predicate: Cu ka <= -9.68 (n=93)
#     Zone: 20 columns
#     Importance: 0.001927
#   Predicate: Cu ka > -9.68 (n=134)
#     Zone: 20 columns
#     Importance: 0.007650
#   Predicate: Cu ka <= -8.43 (n=140)
#     Zone: 20 columns
#     Importance: 0.001344
#   Predicate: Cu ka > -8.43 (n=87)
#     Zone: 20 columns
#     Importance: 0.011679
#   Predicate: Cu ka <= -3.28 (n=182)
#     Zone: 20 columns
#     Importance: 0.001141
#   Predicate: Zn ka > -1.75 (n=181)
#     Zone: 21 columns
#     Importance: 0.000171
#   Predicate: Zn ka <= -0.78 (n=89)
#     Zone: 21 columns
#     Importance: 0.000301
#   Predicate: Zn ka > -0.78 (n=138)
#     Zone: 21 columns
#     Importance: 0.000103
#   Predicate: Zn ka <= 0.08 (n=138)
#     Zone: 21 columns
#     Importance: 0.000245
#   Predicate: Zn ka > 0.08 (n=89)
#     Zone: 21 columns
#     Importance: 0.000081
#   Predicate: Zn ka <= 1.38 (n=184)
#     Zone: 21 columns
#     Importance: 0.000205
#   Predicate: Cu kb > -2.88 (n=177)
#     Zone: 19 columns
#     Importance: 0.000419
#   Predicate: Cu kb <= -2.30 (n=92)
#     Zone: 19 columns
#     Importance: 0.000401
#   Predicate: Cu kb > -2.30 (n=135)
#     Zone: 19 columns
#     Importance: 0.000489
#   Predicate: Cu kb <= -1.61 (n=137)
#     Zone: 19 columns
#     Importance: 0.000295
#   Predicate: Cu kb > -1.61 (n=90)
#     Zone: 19 columns
#     Importance: 0.000694
#   Predicate: Cu kb <= 0.18 (n=180)
#     Zone: 19 columns
#     Importance: 0.000267
#   Predicate: Zn kb > -1.05 (n=182)
#     Zone: 30 columns
#     Importance: 0.000188
#   Predicate: Zn kb <= -0.29 (n=93)
#     Zone: 30 columns
#     Importance: 0.000300
#   Predicate: Zn kb > -0.29 (n=134)
#     Zone: 30 columns
#     Importance: 0.000147
#   Predicate: Zn kb <= 0.29 (n=142)
#     Zone: 30 columns
#     Importance: 0.000251
#   Predicate: Zn kb > 0.29 (n=85)
#     Zone: 30 columns
#     Importance: 0.000140
#   Predicate: Zn kb <= 1.07 (n=182)
#     Zone: 30 columns
#     Importance: 0.000216
#   Predicate: background3 > -2.55 (n=179)
#     Zone: 451 columns
#     Importance: 0.001563
#   Predicate: background3 <= -0.30 (n=95)
#     Zone: 451 columns
#     Importance: 0.006522
#   Predicate: background3 > -0.30 (n=132)
#     Zone: 451 columns
#     Importance: 0.001140
#   Predicate: background3 <= 1.29 (n=133)
#     Zone: 451 columns
#     Importance: 0.005198
#   Predicate: background3 > 1.29 (n=94)
#     Zone: 451 columns
#     Importance: 0.000838
#   Predicate: background3 <= 2.86 (n=184)
#     Zone: 451 columns
#     Importance: 0.004058
#   Predicate: Ag ka scattering > -1.65 (n=180)
#     Zone: 49 columns
#     Importance: 0.002435
#   Predicate: Ag ka scattering <= -0.18 (n=93)
#     Zone: 49 columns
#     Importance: 0.013384
#   Predicate: Ag ka scattering > -0.18 (n=134)
#     Zone: 49 columns
#     Importance: 0.003071
#   Predicate: Ag ka scattering <= 1.67 (n=133)
#     Zone: 49 columns
#     Importance: 0.009600
#   Predicate: Ag ka scattering > 1.67 (n=94)
#     Zone: 49 columns
#     Importance: 0.004037
#   Predicate: Ag ka scattering <= 3.49 (n=180)
#     Zone: 49 columns
#     Importance: 0.007587
#
# [Bag_2] Processing 90 predicates...
#   Predicate: Ar ka + Ag L > -1.05 (n=182)
#     Zone: 29 columns
#     Importance: 0.000148
#   Predicate: Ar ka + Ag L <= -0.29 (n=91)
#     Zone: 29 columns
#     Importance: 0.000264
#   Predicate: Ar ka + Ag L > -0.29 (n=136)
#     Zone: 29 columns
#     Importance: 0.000111
#   Predicate: Ar ka + Ag L <= 0.28 (n=137)
#     Zone: 29 columns
#     Importance: 0.000221
#   Predicate: Ar ka + Ag L > 0.28 (n=90)
#     Zone: 29 columns
#     Importance: 0.000098
#   Predicate: Ar ka + Ag L <= 1.07 (n=181)
#     Zone: 29 columns
#     Importance: 0.000194
#   Predicate: Ca ka > -26.11 (n=182)
#     Zone: 17 columns
#     Importance: 0.011007
#   Predicate: Ca ka <= -21.19 (n=93)
#     Zone: 17 columns
#     Importance: 0.011834
#   Predicate: Ca ka > -21.19 (n=134)
#     Zone: 17 columns
#     Importance: 0.012698
#   Predicate: Ca ka <= -6.65 (n=136)
#     Zone: 17 columns
#     Importance: 0.008423
#   Predicate: Ca ka > -6.65 (n=91)
#     Zone: 17 columns
#     Importance: 0.018204
#   Predicate: Ca ka <= 33.38 (n=179)
#     Zone: 17 columns
#     Importance: 0.007302
#   Predicate: Ca kb > -8.59 (n=183)
#     Zone: 13 columns
#     Importance: 0.000318
#   Predicate: Ca kb <= -6.07 (n=93)
#     Zone: 13 columns
#     Importance: 0.000689
#   Predicate: Ca kb > -6.07 (n=134)
#     Zone: 13 columns
#     Importance: 0.000297
#   Predicate: Ca kb <= -2.67 (n=137)
#     Zone: 13 columns
#     Importance: 0.000504
#   Predicate: Ca kb > -2.67 (n=90)
#     Zone: 13 columns
#     Importance: 0.000387
#   Predicate: Ca kb <= 12.61 (n=179)
#     Zone: 13 columns
#     Importance: 0.000469
#   Predicate: Ti ka > -28.53 (n=178)
#     Zone: 19 columns
#     Importance: 0.066288
#   Predicate: Ti ka <= -4.69 (n=94)
#     Zone: 19 columns
#     Importance: 0.181517
#   Predicate: Ti ka > -4.69 (n=133)
#     Zone: 19 columns
#     Importance: 0.013819
#   Predicate: Ti ka <= 9.34 (n=134)
#     Zone: 19 columns
#     Importance: 0.131715
#   Predicate: Ti ka > 9.34 (n=93)
#     Zone: 19 columns
#     Importance: 0.013449
#   Predicate: Ti ka <= 19.85 (n=178)
#     Zone: 19 columns
#     Importance: 0.102313
#   Predicate: Ti kb > -10.26 (n=182)
#     Zone: 16 columns
#     Importance: 0.003602
#   Predicate: Ti kb <= -2.91 (n=94)
#     Zone: 16 columns
#     Importance: 0.005553
#   Predicate: Ti kb > -2.91 (n=133)
#     Zone: 16 columns
#     Importance: 0.002212
#   Predicate: Ti kb <= 2.45 (n=131)
#     Zone: 16 columns
#     Importance: 0.004838
#   Predicate: Ti kb > 2.45 (n=96)
#     Zone: 16 columns
#     Importance: 0.001900
#   Predicate: Ti kb <= 6.95 (n=179)
#     Zone: 16 columns
#     Importance: 0.004102
#   Predicate: background1 > -1.87 (n=185)
#     Zone: 39 columns
#     Importance: 0.000213
#   Predicate: background1 <= -1.03 (n=88)
#     Zone: 39 columns
#     Importance: 0.000352
#   Predicate: background1 > -1.03 (n=139)
#     Zone: 39 columns
#     Importance: 0.000226
#   Predicate: background1 <= -0.11 (n=132)
#     Zone: 39 columns
#     Importance: 0.000301
#   Predicate: background1 > -0.11 (n=95)
#     Zone: 39 columns
#     Importance: 0.000238
#   Predicate: background1 <= 2.08 (n=179)
#     Zone: 39 columns
#     Importance: 0.000327
#   Predicate: Fe ka > -24.62 (n=180)
#     Zone: 25 columns
#     Importance: 0.000689
#   Predicate: Fe ka <= -24.15 (n=91)
#     Zone: 25 columns
#     Importance: 0.000232
#   Predicate: Fe ka > -24.15 (n=136)
#     Zone: 25 columns
#     Importance: 0.000873
#   Predicate: Fe ka <= -23.71 (n=140)
#     Zone: 25 columns
#     Importance: 0.000187
#   Predicate: Fe ka > -23.71 (n=87)
#     Zone: 25 columns
#     Importance: 0.001307
#   Predicate: Fe ka <= -22.90 (n=183)
#     Zone: 25 columns
#     Importance: 0.000164
#   Predicate: Fe kb > -7.79 (n=178)
#     Zone: 22 columns
#     Importance: 0.001744
#   Predicate: Fe kb <= -7.41 (n=89)
#     Zone: 22 columns
#     Importance: 0.000088
#   Predicate: Fe kb > -7.41 (n=138)
#     Zone: 22 columns
#     Importance: 0.002234
#   Predicate: Fe kb <= -7.02 (n=136)
#     Zone: 22 columns
#     Importance: 0.000107
#   Predicate: Fe kb > -7.02 (n=91)
#     Zone: 22 columns
#     Importance: 0.003314
#   Predicate: Fe kb <= -6.37 (n=183)
#     Zone: 22 columns
#     Importance: 0.000135
#   Predicate: background2 > -0.92 (n=184)
#     Zone: 18 columns
#     Importance: 0.000097
#   Predicate: background2 <= -0.37 (n=86)
#     Zone: 18 columns
#     Importance: 0.000141
#   Predicate: background2 > -0.37 (n=141)
#     Zone: 18 columns
#     Importance: 0.000100
#   Predicate: background2 <= 0.27 (n=131)
#     Zone: 18 columns
#     Importance: 0.000124
#   Predicate: background2 > 0.27 (n=96)
#     Zone: 18 columns
#     Importance: 0.000105
#   Predicate: background2 <= 0.98 (n=184)
#     Zone: 18 columns
#     Importance: 0.000112
#   Predicate: Cu ka > -10.68 (n=180)
#     Zone: 20 columns
#     Importance: 0.004472
#   Predicate: Cu ka <= -9.68 (n=93)
#     Zone: 20 columns
#     Importance: 0.001665
#   Predicate: Cu ka > -9.68 (n=134)
#     Zone: 20 columns
#     Importance: 0.005704
#   Predicate: Cu ka <= -8.43 (n=139)
#     Zone: 20 columns
#     Importance: 0.001178
#   Predicate: Cu ka > -8.43 (n=88)
#     Zone: 20 columns
#     Importance: 0.008584
#   Predicate: Cu ka <= -3.28 (n=186)
#     Zone: 20 columns
#     Importance: 0.000988
#   Predicate: Zn ka > -1.75 (n=179)
#     Zone: 21 columns
#     Importance: 0.000161
#   Predicate: Zn ka <= -0.78 (n=95)
#     Zone: 21 columns
#     Importance: 0.000243
#   Predicate: Zn ka > -0.78 (n=132)
#     Zone: 21 columns
#     Importance: 0.000094
#   Predicate: Zn ka <= 0.08 (n=142)
#     Zone: 21 columns
#     Importance: 0.000206
#   Predicate: Zn ka > 0.08 (n=85)
#     Zone: 21 columns
#     Importance: 0.000073
#   Predicate: Zn ka <= 1.38 (n=186)
#     Zone: 21 columns
#     Importance: 0.000177
#   Predicate: Cu kb > -2.88 (n=178)
#     Zone: 19 columns
#     Importance: 0.000324
#   Predicate: Cu kb <= -2.30 (n=89)
#     Zone: 19 columns
#     Importance: 0.000380
#   Predicate: Cu kb > -2.30 (n=138)
#     Zone: 19 columns
#     Importance: 0.000363
#   Predicate: Cu kb <= -1.61 (n=139)
#     Zone: 19 columns
#     Importance: 0.000272
#   Predicate: Cu kb > -1.61 (n=88)
#     Zone: 19 columns
#     Importance: 0.000523
#   Predicate: Cu kb <= 0.18 (n=184)
#     Zone: 19 columns
#     Importance: 0.000232
#   Predicate: Zn kb > -1.05 (n=183)
#     Zone: 30 columns
#     Importance: 0.000169
#   Predicate: Zn kb <= -0.29 (n=94)
#     Zone: 30 columns
#     Importance: 0.000299
#   Predicate: Zn kb > -0.29 (n=133)
#     Zone: 30 columns
#     Importance: 0.000111
#   Predicate: Zn kb <= 0.29 (n=144)
#     Zone: 30 columns
#     Importance: 0.000248
#   Predicate: Zn kb > 0.29 (n=83)
#     Zone: 30 columns
#     Importance: 0.000087
#   Predicate: Zn kb <= 1.07 (n=189)
#     Zone: 30 columns
#     Importance: 0.000211
#   Predicate: background3 > -2.55 (n=180)
#     Zone: 451 columns
#     Importance: 0.001547
#   Predicate: background3 <= -0.30 (n=92)
#     Zone: 451 columns
#     Importance: 0.005249
#   Predicate: background3 > -0.30 (n=135)
#     Zone: 451 columns
#     Importance: 0.001183
#   Predicate: background3 <= 1.29 (n=140)
#     Zone: 451 columns
#     Importance: 0.004064
#   Predicate: background3 > 1.29 (n=87)
#     Zone: 451 columns
#     Importance: 0.000846
#   Predicate: background3 <= 2.86 (n=184)
#     Zone: 451 columns
#     Importance: 0.003357
#   Predicate: Ag ka scattering > -1.65 (n=180)
#     Zone: 49 columns
#     Importance: 0.002426
#   Predicate: Ag ka scattering <= -0.18 (n=92)
#     Zone: 49 columns
#     Importance: 0.011707
#   Predicate: Ag ka scattering > -0.18 (n=135)
#     Zone: 49 columns
#     Importance: 0.003061
#   Predicate: Ag ka scattering <= 1.67 (n=135)
#     Zone: 49 columns
#     Importance: 0.008190
#   Predicate: Ag ka scattering > 1.67 (n=92)
#     Zone: 49 columns
#     Importance: 0.004180
#   Predicate: Ag ka scattering <= 3.49 (n=180)
#     Zone: 49 columns
#     Importance: 0.006647
#
# [Bag_3] Processing 90 predicates...
#   Predicate: Ar ka + Ag L > -1.05 (n=181)
#     Zone: 29 columns
#     Importance: 0.000238
#   Predicate: Ar ka + Ag L <= -0.29 (n=89)
#     Zone: 29 columns
#     Importance: 0.000336
#   Predicate: Ar ka + Ag L > -0.29 (n=138)
#     Zone: 29 columns
#     Importance: 0.000141
#   Predicate: Ar ka + Ag L <= 0.28 (n=136)
#     Zone: 29 columns
#     Importance: 0.000278
#   Predicate: Ar ka + Ag L > 0.28 (n=91)
#     Zone: 29 columns
#     Importance: 0.000127
#   Predicate: Ar ka + Ag L <= 1.07 (n=180)
#     Zone: 29 columns
#     Importance: 0.000249
#   Predicate: Ca ka > -26.11 (n=183)
#     Zone: 17 columns
#     Importance: 0.011350
#   Predicate: Ca ka <= -21.19 (n=90)
#     Zone: 17 columns
#     Importance: 0.013818
#   Predicate: Ca ka > -21.19 (n=137)
#     Zone: 17 columns
#     Importance: 0.012678
#   Predicate: Ca ka <= -6.65 (n=135)
#     Zone: 17 columns
#     Importance: 0.009494
#   Predicate: Ca ka > -6.65 (n=92)
#     Zone: 17 columns
#     Importance: 0.018466
#   Predicate: Ca ka <= 33.38 (n=183)
#     Zone: 17 columns
#     Importance: 0.008327
#   Predicate: Ca kb > -8.59 (n=180)
#     Zone: 13 columns
#     Importance: 0.000384
#   Predicate: Ca kb <= -6.07 (n=91)
#     Zone: 13 columns
#     Importance: 0.000808
#   Predicate: Ca kb > -6.07 (n=136)
#     Zone: 13 columns
#     Importance: 0.000319
#   Predicate: Ca kb <= -2.67 (n=135)
#     Zone: 13 columns
#     Importance: 0.000584
#   Predicate: Ca kb > -2.67 (n=92)
#     Zone: 13 columns
#     Importance: 0.000415
#   Predicate: Ca kb <= 12.61 (n=183)
#     Zone: 13 columns
#     Importance: 0.000531
#   Predicate: Ti ka > -28.53 (n=185)
#     Zone: 19 columns
#     Importance: 0.077112
#   Predicate: Ti ka <= -4.69 (n=92)
#     Zone: 19 columns
#     Importance: 0.205839
#   Predicate: Ti ka > -4.69 (n=135)
#     Zone: 19 columns
#     Importance: 0.014110
#   Predicate: Ti ka <= 9.34 (n=138)
#     Zone: 19 columns
#     Importance: 0.142945
#   Predicate: Ti ka > 9.34 (n=89)
#     Zone: 19 columns
#     Importance: 0.012535
#   Predicate: Ti ka <= 19.85 (n=179)
#     Zone: 19 columns
#     Importance: 0.113226
#   Predicate: Ti kb > -10.26 (n=182)
#     Zone: 16 columns
#     Importance: 0.003925
#   Predicate: Ti kb <= -2.91 (n=94)
#     Zone: 16 columns
#     Importance: 0.006337
#   Predicate: Ti kb > -2.91 (n=133)
#     Zone: 16 columns
#     Importance: 0.002135
#   Predicate: Ti kb <= 2.45 (n=137)
#     Zone: 16 columns
#     Importance: 0.005119
#   Predicate: Ti kb > 2.45 (n=90)
#     Zone: 16 columns
#     Importance: 0.001982
#   Predicate: Ti kb <= 6.95 (n=182)
#     Zone: 16 columns
#     Importance: 0.004437
#   Predicate: background1 > -1.87 (n=182)
#     Zone: 39 columns
#     Importance: 0.000235
#   Predicate: background1 <= -1.03 (n=90)
#     Zone: 39 columns
#     Importance: 0.000533
#   Predicate: background1 > -1.03 (n=137)
#     Zone: 39 columns
#     Importance: 0.000241
#   Predicate: background1 <= -0.11 (n=136)
#     Zone: 39 columns
#     Importance: 0.000411
#   Predicate: background1 > -0.11 (n=91)
#     Zone: 39 columns
#     Importance: 0.000276
#   Predicate: background1 <= 2.08 (n=179)
#     Zone: 39 columns
#     Importance: 0.000416
#   Predicate: Fe ka > -24.62 (n=185)
#     Zone: 25 columns
#     Importance: 0.000679
#   Predicate: Fe ka <= -24.15 (n=93)
#     Zone: 25 columns
#     Importance: 0.000220
#   Predicate: Fe ka > -24.15 (n=134)
#     Zone: 25 columns
#     Importance: 0.000877
#   Predicate: Fe ka <= -23.71 (n=137)
#     Zone: 25 columns
#     Importance: 0.000186
#   Predicate: Fe ka > -23.71 (n=90)
#     Zone: 25 columns
#     Importance: 0.001250
#   Predicate: Fe ka <= -22.90 (n=177)
#     Zone: 25 columns
#     Importance: 0.000165
#   Predicate: Fe kb > -7.79 (n=179)
#     Zone: 22 columns
#     Importance: 0.001620
#   Predicate: Fe kb <= -7.41 (n=96)
#     Zone: 22 columns
#     Importance: 0.000096
#   Predicate: Fe kb > -7.41 (n=131)
#     Zone: 22 columns
#     Importance: 0.002190
#   Predicate: Fe kb <= -7.02 (n=143)
#     Zone: 22 columns
#     Importance: 0.000102
#   Predicate: Fe kb > -7.02 (n=84)
#     Zone: 22 columns
#     Importance: 0.003352
#   Predicate: Fe kb <= -6.37 (n=179)
#     Zone: 22 columns
#     Importance: 0.000130
#   Predicate: background2 > -0.92 (n=184)
#     Zone: 18 columns
#     Importance: 0.000107
#   Predicate: background2 <= -0.37 (n=91)
#     Zone: 18 columns
#     Importance: 0.000130
#   Predicate: background2 > -0.37 (n=136)
#     Zone: 18 columns
#     Importance: 0.000109
#   Predicate: background2 <= 0.27 (n=136)
#     Zone: 18 columns
#     Importance: 0.000130
#   Predicate: background2 > 0.27 (n=91)
#     Zone: 18 columns
#     Importance: 0.000098
#   Predicate: background2 <= 0.98 (n=181)
#     Zone: 18 columns
#     Importance: 0.000117
#   Predicate: Cu ka > -10.68 (n=185)
#     Zone: 20 columns
#     Importance: 0.005826
#   Predicate: Cu ka <= -9.68 (n=87)
#     Zone: 20 columns
#     Importance: 0.002081
#   Predicate: Cu ka > -9.68 (n=140)
#     Zone: 20 columns
#     Importance: 0.007381
#   Predicate: Cu ka <= -8.43 (n=135)
#     Zone: 20 columns
#     Importance: 0.001416
#   Predicate: Cu ka > -8.43 (n=92)
#     Zone: 20 columns
#     Importance: 0.011122
#   Predicate: Cu ka <= -3.28 (n=179)
#     Zone: 20 columns
#     Importance: 0.001175
#   Predicate: Zn ka > -1.75 (n=186)
#     Zone: 21 columns
#     Importance: 0.000182
#   Predicate: Zn ka <= -0.78 (n=85)
#     Zone: 21 columns
#     Importance: 0.000310
#   Predicate: Zn ka > -0.78 (n=142)
#     Zone: 21 columns
#     Importance: 0.000116
#   Predicate: Zn ka <= 0.08 (n=134)
#     Zone: 21 columns
#     Importance: 0.000268
#   Predicate: Zn ka > 0.08 (n=93)
#     Zone: 21 columns
#     Importance: 0.000075
#   Predicate: Zn ka <= 1.38 (n=183)
#     Zone: 21 columns
#     Importance: 0.000216
#   Predicate: Cu kb > -2.88 (n=184)
#     Zone: 19 columns
#     Importance: 0.000450
#   Predicate: Cu kb <= -2.30 (n=89)
#     Zone: 19 columns
#     Importance: 0.000430
#   Predicate: Cu kb > -2.30 (n=138)
#     Zone: 19 columns
#     Importance: 0.000512
#   Predicate: Cu kb <= -1.61 (n=139)
#     Zone: 19 columns
#     Importance: 0.000297
#   Predicate: Cu kb > -1.61 (n=88)
#     Zone: 19 columns
#     Importance: 0.000767
#   Predicate: Cu kb <= 0.18 (n=181)
#     Zone: 19 columns
#     Importance: 0.000269
#   Predicate: Zn kb > -1.05 (n=184)
#     Zone: 30 columns
#     Importance: 0.000185
#   Predicate: Zn kb <= -0.29 (n=90)
#     Zone: 30 columns
#     Importance: 0.000301
#   Predicate: Zn kb > -0.29 (n=137)
#     Zone: 30 columns
#     Importance: 0.000151
#   Predicate: Zn kb <= 0.29 (n=137)
#     Zone: 30 columns
#     Importance: 0.000251
#   Predicate: Zn kb > 0.29 (n=90)
#     Zone: 30 columns
#     Importance: 0.000148
#   Predicate: Zn kb <= 1.07 (n=179)
#     Zone: 30 columns
#     Importance: 0.000223
#   Predicate: background3 > -2.55 (n=181)
#     Zone: 451 columns
#     Importance: 0.001605
#   Predicate: background3 <= -0.30 (n=97)
#     Zone: 451 columns
#     Importance: 0.006487
#   Predicate: background3 > -0.30 (n=130)
#     Zone: 451 columns
#     Importance: 0.001182
#   Predicate: background3 <= 1.29 (n=141)
#     Zone: 451 columns
#     Importance: 0.005074
#   Predicate: background3 > 1.29 (n=86)
#     Zone: 451 columns
#     Importance: 0.000785
#   Predicate: background3 <= 2.86 (n=182)
#     Zone: 451 columns
#     Importance: 0.004145
#   Predicate: Ag ka scattering > -1.65 (n=178)
#     Zone: 49 columns
#     Importance: 0.002662
#   Predicate: Ag ka scattering <= -0.18 (n=95)
#     Zone: 49 columns
#     Importance: 0.014229
#   Predicate: Ag ka scattering > -0.18 (n=132)
#     Zone: 49 columns
#     Importance: 0.003355
#   Predicate: Ag ka scattering <= 1.67 (n=136)
#     Zone: 49 columns
#     Importance: 0.010054
#   Predicate: Ag ka scattering > 1.67 (n=91)
#     Zone: 49 columns
#     Importance: 0.004696
#   Predicate: Ag ka scattering <= 3.49 (n=180)
#     Zone: 49 columns
#     Importance: 0.008028
#
# [Bag_4] Processing 90 predicates...
#   Predicate: Ar ka + Ag L > -1.05 (n=179)
#     Zone: 29 columns
#     Importance: 0.000223
#   Predicate: Ar ka + Ag L <= -0.29 (n=95)
#     Zone: 29 columns
#     Importance: 0.000382
#   Predicate: Ar ka + Ag L > -0.29 (n=132)
#     Zone: 29 columns
#     Importance: 0.000118
#   Predicate: Ar ka + Ag L <= 0.28 (n=139)
#     Zone: 29 columns
#     Importance: 0.000310
#   Predicate: Ar ka + Ag L > 0.28 (n=88)
#     Zone: 29 columns
#     Importance: 0.000100
#   Predicate: Ar ka + Ag L <= 1.07 (n=183)
#     Zone: 29 columns
#     Importance: 0.000265
#   Predicate: Ca ka > -26.11 (n=181)
#     Zone: 17 columns
#     Importance: 0.014486
#   Predicate: Ca ka <= -21.19 (n=90)
#     Zone: 17 columns
#     Importance: 0.013990
#   Predicate: Ca ka > -21.19 (n=137)
#     Zone: 17 columns
#     Importance: 0.016910
#   Predicate: Ca ka <= -6.65 (n=135)
#     Zone: 17 columns
#     Importance: 0.009712
#   Predicate: Ca ka > -6.65 (n=92)
#     Zone: 17 columns
#     Importance: 0.024615
#   Predicate: Ca ka <= 33.38 (n=181)
#     Zone: 17 columns
#     Importance: 0.008646
#   Predicate: Ca kb > -8.59 (n=182)
#     Zone: 13 columns
#     Importance: 0.000386
#   Predicate: Ca kb <= -6.07 (n=90)
#     Zone: 13 columns
#     Importance: 0.000832
#   Predicate: Ca kb > -6.07 (n=137)
#     Zone: 13 columns
#     Importance: 0.000331
#   Predicate: Ca kb <= -2.67 (n=133)
#     Zone: 13 columns
#     Importance: 0.000598
#   Predicate: Ca kb > -2.67 (n=94)
#     Zone: 13 columns
#     Importance: 0.000433
#   Predicate: Ca kb <= 12.61 (n=181)
#     Zone: 13 columns
#     Importance: 0.000557
#   Predicate: Ti ka > -28.53 (n=182)
#     Zone: 19 columns
#     Importance: 0.069150
#   Predicate: Ti ka <= -4.69 (n=93)
#     Zone: 19 columns
#     Importance: 0.176922
#   Predicate: Ti ka > -4.69 (n=134)
#     Zone: 19 columns
#     Importance: 0.014403
#   Predicate: Ti ka <= 9.34 (n=140)
#     Zone: 19 columns
#     Importance: 0.122714
#   Predicate: Ti ka > 9.34 (n=87)
#     Zone: 19 columns
#     Importance: 0.013836
#   Predicate: Ti ka <= 19.85 (n=180)
#     Zone: 19 columns
#     Importance: 0.098537
#   Predicate: Ti kb > -10.26 (n=185)
#     Zone: 16 columns
#     Importance: 0.003938
#   Predicate: Ti kb <= -2.91 (n=92)
#     Zone: 16 columns
#     Importance: 0.006144
#   Predicate: Ti kb > -2.91 (n=135)
#     Zone: 16 columns
#     Importance: 0.002168
#   Predicate: Ti kb <= 2.45 (n=136)
#     Zone: 16 columns
#     Importance: 0.005018
#   Predicate: Ti kb > 2.45 (n=91)
#     Zone: 16 columns
#     Importance: 0.001928
#   Predicate: Ti kb <= 6.95 (n=182)
#     Zone: 16 columns
#     Importance: 0.004280
#   Predicate: background1 > -1.87 (n=181)
#     Zone: 39 columns
#     Importance: 0.000228
#   Predicate: background1 <= -1.03 (n=90)
#     Zone: 39 columns
#     Importance: 0.000537
#   Predicate: background1 > -1.03 (n=137)
#     Zone: 39 columns
#     Importance: 0.000217
#   Predicate: background1 <= -0.11 (n=136)
#     Zone: 39 columns
#     Importance: 0.000399
#   Predicate: background1 > -0.11 (n=91)
#     Zone: 39 columns
#     Importance: 0.000261
#   Predicate: background1 <= 2.08 (n=182)
#     Zone: 39 columns
#     Importance: 0.000401
#   Predicate: Fe ka > -24.62 (n=181)
#     Zone: 25 columns
#     Importance: 0.000647
#   Predicate: Fe ka <= -24.15 (n=94)
#     Zone: 25 columns
#     Importance: 0.000238
#   Predicate: Fe ka > -24.15 (n=133)
#     Zone: 25 columns
#     Importance: 0.000835
#   Predicate: Fe ka <= -23.71 (n=137)
#     Zone: 25 columns
#     Importance: 0.000197
#   Predicate: Fe ka > -23.71 (n=90)
#     Zone: 25 columns
#     Importance: 0.001183
#   Predicate: Fe ka <= -22.90 (n=183)
#     Zone: 25 columns
#     Importance: 0.000171
#   Predicate: Fe kb > -7.79 (n=180)
#     Zone: 22 columns
#     Importance: 0.001484
#   Predicate: Fe kb <= -7.41 (n=91)
#     Zone: 22 columns
#     Importance: 0.000082
#   Predicate: Fe kb > -7.41 (n=136)
#     Zone: 22 columns
#     Importance: 0.001947
#   Predicate: Fe kb <= -7.02 (n=138)
#     Zone: 22 columns
#     Importance: 0.000108
#   Predicate: Fe kb > -7.02 (n=89)
#     Zone: 22 columns
#     Importance: 0.002892
#   Predicate: Fe kb <= -6.37 (n=182)
#     Zone: 22 columns
#     Importance: 0.000140
#   Predicate: background2 > -0.92 (n=185)
#     Zone: 18 columns
#     Importance: 0.000115
#   Predicate: background2 <= -0.37 (n=89)
#     Zone: 18 columns
#     Importance: 0.000145
#   Predicate: background2 > -0.37 (n=138)
#     Zone: 18 columns
#     Importance: 0.000130
#   Predicate: background2 <= 0.27 (n=137)
#     Zone: 18 columns
#     Importance: 0.000149
#   Predicate: background2 > 0.27 (n=90)
#     Zone: 18 columns
#     Importance: 0.000117
#   Predicate: background2 <= 0.98 (n=182)
#     Zone: 18 columns
#     Importance: 0.000134
#   Predicate: Cu ka > -10.68 (n=181)
#     Zone: 20 columns
#     Importance: 0.005768
#   Predicate: Cu ka <= -9.68 (n=96)
#     Zone: 20 columns
#     Importance: 0.001941
#   Predicate: Cu ka > -9.68 (n=131)
#     Zone: 20 columns
#     Importance: 0.007613
#   Predicate: Cu ka <= -8.43 (n=137)
#     Zone: 20 columns
#     Importance: 0.001429
#   Predicate: Cu ka > -8.43 (n=90)
#     Zone: 20 columns
#     Importance: 0.010975
#   Predicate: Cu ka <= -3.28 (n=182)
#     Zone: 20 columns
#     Importance: 0.001215
#   Predicate: Zn ka > -1.75 (n=185)
#     Zone: 21 columns
#     Importance: 0.000168
#   Predicate: Zn ka <= -0.78 (n=83)
#     Zone: 21 columns
#     Importance: 0.000323
#   Predicate: Zn ka > -0.78 (n=144)
#     Zone: 21 columns
#     Importance: 0.000102
#   Predicate: Zn ka <= 0.08 (n=136)
#     Zone: 21 columns
#     Importance: 0.000255
#   Predicate: Zn ka > 0.08 (n=91)
#     Zone: 21 columns
#     Importance: 0.000074
#   Predicate: Zn ka <= 1.38 (n=181)
#     Zone: 21 columns
#     Importance: 0.000212
#   Predicate: Cu kb > -2.88 (n=176)
#     Zone: 19 columns
#     Importance: 0.000443
#   Predicate: Cu kb <= -2.30 (n=95)
#     Zone: 19 columns
#     Importance: 0.000410
#   Predicate: Cu kb > -2.30 (n=132)
#     Zone: 19 columns
#     Importance: 0.000520
#   Predicate: Cu kb <= -1.61 (n=140)
#     Zone: 19 columns
#     Importance: 0.000302
#   Predicate: Cu kb > -1.61 (n=87)
#     Zone: 19 columns
#     Importance: 0.000751
#   Predicate: Cu kb <= 0.18 (n=182)
#     Zone: 19 columns
#     Importance: 0.000270
#   Predicate: Zn kb > -1.05 (n=184)
#     Zone: 30 columns
#     Importance: 0.000195
#   Predicate: Zn kb <= -0.29 (n=94)
#     Zone: 30 columns
#     Importance: 0.000314
#   Predicate: Zn kb > -0.29 (n=133)
#     Zone: 30 columns
#     Importance: 0.000147
#   Predicate: Zn kb <= 0.29 (n=142)
#     Zone: 30 columns
#     Importance: 0.000265
#   Predicate: Zn kb > 0.29 (n=85)
#     Zone: 30 columns
#     Importance: 0.000135
#   Predicate: Zn kb <= 1.07 (n=186)
#     Zone: 30 columns
#     Importance: 0.000217
#   Predicate: background3 > -2.55 (n=181)
#     Zone: 451 columns
#     Importance: 0.001619
#   Predicate: background3 <= -0.30 (n=93)
#     Zone: 451 columns
#     Importance: 0.006344
#   Predicate: background3 > -0.30 (n=134)
#     Zone: 451 columns
#     Importance: 0.001259
#   Predicate: background3 <= 1.29 (n=139)
#     Zone: 451 columns
#     Importance: 0.004942
#   Predicate: background3 > 1.29 (n=88)
#     Zone: 451 columns
#     Importance: 0.000814
#   Predicate: background3 <= 2.86 (n=184)
#     Zone: 451 columns
#     Importance: 0.003983
#   Predicate: Ag ka scattering > -1.65 (n=179)
#     Zone: 49 columns
#     Importance: 0.002809
#   Predicate: Ag ka scattering <= -0.18 (n=91)
#     Zone: 49 columns
#     Importance: 0.013755
#   Predicate: Ag ka scattering > -0.18 (n=136)
#     Zone: 49 columns
#     Importance: 0.003488
#   Predicate: Ag ka scattering <= 1.67 (n=133)
#     Zone: 49 columns
#     Importance: 0.009665
#   Predicate: Ag ka scattering > 1.67 (n=94)
#     Zone: 49 columns
#     Importance: 0.004687
#   Predicate: Ag ka scattering <= 3.49 (n=177)
#     Zone: 49 columns
#     Importance: 0.007707
#
# [Bag_5] Processing 90 predicates...
#   Predicate: Ar ka + Ag L > -1.05 (n=183)
#     Zone: 29 columns
#     Importance: 0.000187
#   Predicate: Ar ka + Ag L <= -0.29 (n=89)
#     Zone: 29 columns
#     Importance: 0.000273
#   Predicate: Ar ka + Ag L > -0.29 (n=138)
#     Zone: 29 columns
#     Importance: 0.000147
#   Predicate: Ar ka + Ag L <= 0.28 (n=139)
#     Zone: 29 columns
#     Importance: 0.000250
#   Predicate: Ar ka + Ag L > 0.28 (n=88)
#     Zone: 29 columns
#     Importance: 0.000111
#   Predicate: Ar ka + Ag L <= 1.07 (n=183)
#     Zone: 29 columns
#     Importance: 0.000221
#   Predicate: Ca ka > -26.11 (n=187)
#     Zone: 17 columns
#     Importance: 0.014120
#   Predicate: Ca ka <= -21.19 (n=87)
#     Zone: 17 columns
#     Importance: 0.011501
#   Predicate: Ca ka > -21.19 (n=140)
#     Zone: 17 columns
#     Importance: 0.016588
#   Predicate: Ca ka <= -6.65 (n=132)
#     Zone: 17 columns
#     Importance: 0.007978
#   Predicate: Ca ka > -6.65 (n=95)
#     Zone: 17 columns
#     Importance: 0.023892
#   Predicate: Ca ka <= 33.38 (n=183)
#     Zone: 17 columns
#     Importance: 0.007189
#   Predicate: Ca kb > -8.59 (n=188)
#     Zone: 13 columns
#     Importance: 0.000333
#   Predicate: Ca kb <= -6.07 (n=87)
#     Zone: 13 columns
#     Importance: 0.000644
#   Predicate: Ca kb > -6.07 (n=140)
#     Zone: 13 columns
#     Importance: 0.000323
#   Predicate: Ca kb <= -2.67 (n=134)
#     Zone: 13 columns
#     Importance: 0.000460
#   Predicate: Ca kb > -2.67 (n=93)
#     Zone: 13 columns
#     Importance: 0.000426
#   Predicate: Ca kb <= 12.61 (n=182)
#     Zone: 13 columns
#     Importance: 0.000448
#   Predicate: Ti ka > -28.53 (n=184)
#     Zone: 19 columns
#     Importance: 0.055904
#   Predicate: Ti ka <= -4.69 (n=90)
#     Zone: 19 columns
#     Importance: 0.160082
#   Predicate: Ti ka > -4.69 (n=137)
#     Zone: 19 columns
#     Importance: 0.011913
#   Predicate: Ti ka <= 9.34 (n=136)
#     Zone: 19 columns
#     Importance: 0.108921
#   Predicate: Ti ka > 9.34 (n=91)
#     Zone: 19 columns
#     Importance: 0.013474
#   Predicate: Ti ka <= 19.85 (n=183)
#     Zone: 19 columns
#     Importance: 0.084417
#   Predicate: Ti kb > -10.26 (n=183)
#     Zone: 16 columns
#     Importance: 0.003584
#   Predicate: Ti kb <= -2.91 (n=89)
#     Zone: 16 columns
#     Importance: 0.006091
#   Predicate: Ti kb > -2.91 (n=138)
#     Zone: 16 columns
#     Importance: 0.001888
#   Predicate: Ti kb <= 2.45 (n=135)
#     Zone: 16 columns
#     Importance: 0.004520
#   Predicate: Ti kb > 2.45 (n=92)
#     Zone: 16 columns
#     Importance: 0.002092
#   Predicate: Ti kb <= 6.95 (n=181)
#     Zone: 16 columns
#     Importance: 0.003974
#   Predicate: background1 > -1.87 (n=185)
#     Zone: 39 columns
#     Importance: 0.000185
#   Predicate: background1 <= -1.03 (n=86)
#     Zone: 39 columns
#     Importance: 0.000364
#   Predicate: background1 > -1.03 (n=141)
#     Zone: 39 columns
#     Importance: 0.000161
#   Predicate: background1 <= -0.11 (n=136)
#     Zone: 39 columns
#     Importance: 0.000304
#   Predicate: background1 > -0.11 (n=91)
#     Zone: 39 columns
#     Importance: 0.000141
#   Predicate: background1 <= 2.08 (n=179)
#     Zone: 39 columns
#     Importance: 0.000268
#   Predicate: Fe ka > -24.62 (n=182)
#     Zone: 25 columns
#     Importance: 0.000714
#   Predicate: Fe ka <= -24.15 (n=87)
#     Zone: 25 columns
#     Importance: 0.000267
#   Predicate: Fe ka > -24.15 (n=140)
#     Zone: 25 columns
#     Importance: 0.000875
#   Predicate: Fe ka <= -23.71 (n=133)
#     Zone: 25 columns
#     Importance: 0.000200
#   Predicate: Fe ka > -23.71 (n=94)
#     Zone: 25 columns
#     Importance: 0.001267
#   Predicate: Fe ka <= -22.90 (n=177)
#     Zone: 25 columns
#     Importance: 0.000176
#   Predicate: Fe kb > -7.79 (n=182)
#     Zone: 22 columns
#     Importance: 0.001573
#   Predicate: Fe kb <= -7.41 (n=89)
#     Zone: 22 columns
#     Importance: 0.000094
#   Predicate: Fe kb > -7.41 (n=138)
#     Zone: 22 columns
#     Importance: 0.002054
#   Predicate: Fe kb <= -7.02 (n=138)
#     Zone: 22 columns
#     Importance: 0.000108
#   Predicate: Fe kb > -7.02 (n=89)
#     Zone: 22 columns
#     Importance: 0.003112
#   Predicate: Fe kb <= -6.37 (n=182)
#     Zone: 22 columns
#     Importance: 0.000126
#   Predicate: background2 > -0.92 (n=182)
#     Zone: 18 columns
#     Importance: 0.000109
#   Predicate: background2 <= -0.37 (n=89)
#     Zone: 18 columns
#     Importance: 0.000145
#   Predicate: background2 > -0.37 (n=138)
#     Zone: 18 columns
#     Importance: 0.000110
#   Predicate: background2 <= 0.27 (n=137)
#     Zone: 18 columns
#     Importance: 0.000131
#   Predicate: background2 > 0.27 (n=90)
#     Zone: 18 columns
#     Importance: 0.000111
#   Predicate: background2 <= 0.98 (n=180)
#     Zone: 18 columns
#     Importance: 0.000120
#   Predicate: Cu ka > -10.68 (n=185)
#     Zone: 20 columns
#     Importance: 0.005781
#   Predicate: Cu ka <= -9.68 (n=85)
#     Zone: 20 columns
#     Importance: 0.001448
#   Predicate: Cu ka > -9.68 (n=142)
#     Zone: 20 columns
#     Importance: 0.007171
#   Predicate: Cu ka <= -8.43 (n=132)
#     Zone: 20 columns
#     Importance: 0.001011
#   Predicate: Cu ka > -8.43 (n=95)
#     Zone: 20 columns
#     Importance: 0.010609
#   Predicate: Cu ka <= -3.28 (n=179)
#     Zone: 20 columns
#     Importance: 0.000907
#   Predicate: Zn ka > -1.75 (n=186)
#     Zone: 21 columns
#     Importance: 0.000144
#   Predicate: Zn ka <= -0.78 (n=84)
#     Zone: 21 columns
#     Importance: 0.000188
#   Predicate: Zn ka > -0.78 (n=143)
#     Zone: 21 columns
#     Importance: 0.000119
#   Predicate: Zn ka <= 0.08 (n=136)
#     Zone: 21 columns
#     Importance: 0.000187
#   Predicate: Zn ka > 0.08 (n=91)
#     Zone: 21 columns
#     Importance: 0.000082
#   Predicate: Zn ka <= 1.38 (n=183)
#     Zone: 21 columns
#     Importance: 0.000160
#   Predicate: Cu kb > -2.88 (n=180)
#     Zone: 19 columns
#     Importance: 0.000411
#   Predicate: Cu kb <= -2.30 (n=88)
#     Zone: 19 columns
#     Importance: 0.000347
#   Predicate: Cu kb > -2.30 (n=139)
#     Zone: 19 columns
#     Importance: 0.000469
#   Predicate: Cu kb <= -1.61 (n=135)
#     Zone: 19 columns
#     Importance: 0.000256
#   Predicate: Cu kb > -1.61 (n=92)
#     Zone: 19 columns
#     Importance: 0.000665
#   Predicate: Cu kb <= 0.18 (n=181)
#     Zone: 19 columns
#     Importance: 0.000220
#   Predicate: Zn kb > -1.05 (n=183)
#     Zone: 30 columns
#     Importance: 0.000161
#   Predicate: Zn kb <= -0.29 (n=89)
#     Zone: 30 columns
#     Importance: 0.000252
#   Predicate: Zn kb > -0.29 (n=138)
#     Zone: 30 columns
#     Importance: 0.000146
#   Predicate: Zn kb <= 0.29 (n=134)
#     Zone: 30 columns
#     Importance: 0.000223
#   Predicate: Zn kb > 0.29 (n=93)
#     Zone: 30 columns
#     Importance: 0.000137
#   Predicate: Zn kb <= 1.07 (n=181)
#     Zone: 30 columns
#     Importance: 0.000198
#   Predicate: background3 > -2.55 (n=185)
#     Zone: 451 columns
#     Importance: 0.001645
#   Predicate: background3 <= -0.30 (n=90)
#     Zone: 451 columns
#     Importance: 0.004187
#   Predicate: background3 > -0.30 (n=137)
#     Zone: 451 columns
#     Importance: 0.001272
#   Predicate: background3 <= 1.29 (n=137)
#     Zone: 451 columns
#     Importance: 0.003407
#   Predicate: background3 > 1.29 (n=90)
#     Zone: 451 columns
#     Importance: 0.000938
#   Predicate: background3 <= 2.86 (n=182)
#     Zone: 451 columns
#     Importance: 0.002835
#   Predicate: Ag ka scattering > -1.65 (n=182)
#     Zone: 49 columns
#     Importance: 0.002589
#   Predicate: Ag ka scattering <= -0.18 (n=89)
#     Zone: 49 columns
#     Importance: 0.009459
#   Predicate: Ag ka scattering > -0.18 (n=138)
#     Zone: 49 columns
#     Importance: 0.003146
#   Predicate: Ag ka scattering <= 1.67 (n=136)
#     Zone: 49 columns
#     Importance: 0.006432
#   Predicate: Ag ka scattering > 1.67 (n=91)
#     Zone: 49 columns
#     Importance: 0.004410
#   Predicate: Ag ka scattering <= 3.49 (n=182)
#     Zone: 49 columns
#     Importance: 0.005315
#
# [Bag_6] Processing 90 predicates...
#   Predicate: Ar ka + Ag L > -1.05 (n=182)
#     Zone: 29 columns
#     Importance: 0.000229
#   Predicate: Ar ka + Ag L <= -0.29 (n=92)
#     Zone: 29 columns
#     Importance: 0.000382
#   Predicate: Ar ka + Ag L > -0.29 (n=135)
#     Zone: 29 columns
#     Importance: 0.000134
#   Predicate: Ar ka + Ag L <= 0.28 (n=133)
#     Zone: 29 columns
#     Importance: 0.000318
#   Predicate: Ar ka + Ag L > 0.28 (n=94)
#     Zone: 29 columns
#     Importance: 0.000116
#   Predicate: Ar ka + Ag L <= 1.07 (n=178)
#     Zone: 29 columns
#     Importance: 0.000277
#   Predicate: Ca ka > -26.11 (n=186)
#     Zone: 17 columns
#     Importance: 0.009538
#   Predicate: Ca ka <= -21.19 (n=94)
#     Zone: 17 columns
#     Importance: 0.011774
#   Predicate: Ca ka > -21.19 (n=133)
#     Zone: 17 columns
#     Importance: 0.010686
#   Predicate: Ca ka <= -6.65 (n=142)
#     Zone: 17 columns
#     Importance: 0.008027
#   Predicate: Ca ka > -6.65 (n=85)
#     Zone: 17 columns
#     Importance: 0.016330
#   Predicate: Ca ka <= 33.38 (n=185)
#     Zone: 17 columns
#     Importance: 0.007176
#   Predicate: Ca kb > -8.59 (n=183)
#     Zone: 13 columns
#     Importance: 0.000308
#   Predicate: Ca kb <= -6.07 (n=94)
#     Zone: 13 columns
#     Importance: 0.000651
#   Predicate: Ca kb > -6.07 (n=133)
#     Zone: 13 columns
#     Importance: 0.000223
#   Predicate: Ca kb <= -2.67 (n=143)
#     Zone: 13 columns
#     Importance: 0.000466
#   Predicate: Ca kb > -2.67 (n=84)
#     Zone: 13 columns
#     Importance: 0.000289
#   Predicate: Ca kb <= 12.61 (n=184)
#     Zone: 13 columns
#     Importance: 0.000438
#   Predicate: Ti ka > -28.53 (n=186)
#     Zone: 19 columns
#     Importance: 0.068729
#   Predicate: Ti ka <= -4.69 (n=89)
#     Zone: 19 columns
#     Importance: 0.185031
#   Predicate: Ti ka > -4.69 (n=138)
#     Zone: 19 columns
#     Importance: 0.011855
#   Predicate: Ti ka <= 9.34 (n=136)
#     Zone: 19 columns
#     Importance: 0.124688
#   Predicate: Ti ka > 9.34 (n=91)
#     Zone: 19 columns
#     Importance: 0.012597
#   Predicate: Ti ka <= 19.85 (n=181)
#     Zone: 19 columns
#     Importance: 0.096853
#   Predicate: Ti kb > -10.26 (n=182)
#     Zone: 16 columns
#     Importance: 0.003421
#   Predicate: Ti kb <= -2.91 (n=88)
#     Zone: 16 columns
#     Importance: 0.005852
#   Predicate: Ti kb > -2.91 (n=139)
#     Zone: 16 columns
#     Importance: 0.001867
#   Predicate: Ti kb <= 2.45 (n=135)
#     Zone: 16 columns
#     Importance: 0.004346
#   Predicate: Ti kb > 2.45 (n=92)
#     Zone: 16 columns
#     Importance: 0.002041
#   Predicate: Ti kb <= 6.95 (n=179)
#     Zone: 16 columns
#     Importance: 0.003866
#   Predicate: background1 > -1.87 (n=186)
#     Zone: 39 columns
#     Importance: 0.000159
#   Predicate: background1 <= -1.03 (n=82)
#     Zone: 39 columns
#     Importance: 0.000540
#   Predicate: background1 > -1.03 (n=145)
#     Zone: 39 columns
#     Importance: 0.000147
#   Predicate: background1 <= -0.11 (n=129)
#     Zone: 39 columns
#     Importance: 0.000405
#   Predicate: background1 > -0.11 (n=98)
#     Zone: 39 columns
#     Importance: 0.000136
#   Predicate: background1 <= 2.08 (n=176)
#     Zone: 39 columns
#     Importance: 0.000336
#   Predicate: Fe ka > -24.62 (n=182)
#     Zone: 25 columns
#     Importance: 0.000676
#   Predicate: Fe ka <= -24.15 (n=87)
#     Zone: 25 columns
#     Importance: 0.000232
#   Predicate: Fe ka > -24.15 (n=140)
#     Zone: 25 columns
#     Importance: 0.000835
#   Predicate: Fe ka <= -23.71 (n=131)
#     Zone: 25 columns
#     Importance: 0.000183
#   Predicate: Fe ka > -23.71 (n=96)
#     Zone: 25 columns
#     Importance: 0.001179
#   Predicate: Fe ka <= -22.90 (n=177)
#     Zone: 25 columns
#     Importance: 0.000161
#   Predicate: Fe kb > -7.79 (n=182)
#     Zone: 22 columns
#     Importance: 0.001635
#   Predicate: Fe kb <= -7.41 (n=90)
#     Zone: 22 columns
#     Importance: 0.000092
#   Predicate: Fe kb > -7.41 (n=137)
#     Zone: 22 columns
#     Importance: 0.002150
#   Predicate: Fe kb <= -7.02 (n=139)
#     Zone: 22 columns
#     Importance: 0.000116
#   Predicate: Fe kb > -7.02 (n=88)
#     Zone: 22 columns
#     Importance: 0.003258
#   Predicate: Fe kb <= -6.37 (n=180)
#     Zone: 22 columns
#     Importance: 0.000129
#   Predicate: background2 > -0.92 (n=180)
#     Zone: 18 columns
#     Importance: 0.000109
#   Predicate: background2 <= -0.37 (n=91)
#     Zone: 18 columns
#     Importance: 0.000132
#   Predicate: background2 > -0.37 (n=136)
#     Zone: 18 columns
#     Importance: 0.000114
#   Predicate: background2 <= 0.27 (n=138)
#     Zone: 18 columns
#     Importance: 0.000136
#   Predicate: background2 > 0.27 (n=89)
#     Zone: 18 columns
#     Importance: 0.000098
#   Predicate: background2 <= 0.98 (n=182)
#     Zone: 18 columns
#     Importance: 0.000126
#   Predicate: Cu ka > -10.68 (n=181)
#     Zone: 20 columns
#     Importance: 0.006707
#   Predicate: Cu ka <= -9.68 (n=89)
#     Zone: 20 columns
#     Importance: 0.001584
#   Predicate: Cu ka > -9.68 (n=138)
#     Zone: 20 columns
#     Importance: 0.008507
#   Predicate: Cu ka <= -8.43 (n=135)
#     Zone: 20 columns
#     Importance: 0.001117
#   Predicate: Cu ka > -8.43 (n=92)
#     Zone: 20 columns
#     Importance: 0.012655
#   Predicate: Cu ka <= -3.28 (n=178)
#     Zone: 20 columns
#     Importance: 0.000989
#   Predicate: Zn ka > -1.75 (n=177)
#     Zone: 21 columns
#     Importance: 0.000135
#   Predicate: Zn ka <= -0.78 (n=91)
#     Zone: 21 columns
#     Importance: 0.000233
#   Predicate: Zn ka > -0.78 (n=136)
#     Zone: 21 columns
#     Importance: 0.000107
#   Predicate: Zn ka <= 0.08 (n=136)
#     Zone: 21 columns
#     Importance: 0.000211
#   Predicate: Zn ka > 0.08 (n=91)
#     Zone: 21 columns
#     Importance: 0.000078
#   Predicate: Zn ka <= 1.38 (n=178)
#     Zone: 21 columns
#     Importance: 0.000179
#   Predicate: Cu kb > -2.88 (n=180)
#     Zone: 19 columns
#     Importance: 0.000471
#   Predicate: Cu kb <= -2.30 (n=91)
#     Zone: 19 columns
#     Importance: 0.000337
#   Predicate: Cu kb > -2.30 (n=136)
#     Zone: 19 columns
#     Importance: 0.000550
#   Predicate: Cu kb <= -1.61 (n=135)
#     Zone: 19 columns
#     Importance: 0.000245
#   Predicate: Cu kb > -1.61 (n=92)
#     Zone: 19 columns
#     Importance: 0.000785
#   Predicate: Cu kb <= 0.18 (n=181)
#     Zone: 19 columns
#     Importance: 0.000224
#   Predicate: Zn kb > -1.05 (n=181)
#     Zone: 30 columns
#     Importance: 0.000157
#   Predicate: Zn kb <= -0.29 (n=95)
#     Zone: 30 columns
#     Importance: 0.000246
#   Predicate: Zn kb > -0.29 (n=132)
#     Zone: 30 columns
#     Importance: 0.000142
#   Predicate: Zn kb <= 0.29 (n=133)
#     Zone: 30 columns
#     Importance: 0.000220
#   Predicate: Zn kb > 0.29 (n=94)
#     Zone: 30 columns
#     Importance: 0.000136
#   Predicate: Zn kb <= 1.07 (n=180)
#     Zone: 30 columns
#     Importance: 0.000188
#   Predicate: background3 > -2.55 (n=180)
#     Zone: 451 columns
#     Importance: 0.001535
#   Predicate: background3 <= -0.30 (n=93)
#     Zone: 451 columns
#     Importance: 0.004823
#   Predicate: background3 > -0.30 (n=134)
#     Zone: 451 columns
#     Importance: 0.001321
#   Predicate: background3 <= 1.29 (n=137)
#     Zone: 451 columns
#     Importance: 0.003932
#   Predicate: background3 > 1.29 (n=90)
#     Zone: 451 columns
#     Importance: 0.000965
#   Predicate: background3 <= 2.86 (n=185)
#     Zone: 451 columns
#     Importance: 0.003205
#   Predicate: Ag ka scattering > -1.65 (n=182)
#     Zone: 49 columns
#     Importance: 0.002467
#   Predicate: Ag ka scattering <= -0.18 (n=85)
#     Zone: 49 columns
#     Importance: 0.011236
#   Predicate: Ag ka scattering > -0.18 (n=142)
#     Zone: 49 columns
#     Importance: 0.002994
#   Predicate: Ag ka scattering <= 1.67 (n=135)
#     Zone: 49 columns
#     Importance: 0.007316
#   Predicate: Ag ka scattering > 1.67 (n=92)
#     Zone: 49 columns
#     Importance: 0.004267
#   Predicate: Ag ka scattering <= 3.49 (n=181)
#     Zone: 49 columns
#     Importance: 0.005947
#
# [Bag_7] Processing 90 predicates...
#   Predicate: Ar ka + Ag L > -1.05 (n=180)
#     Zone: 29 columns
#     Importance: 0.000235
#   Predicate: Ar ka + Ag L <= -0.29 (n=91)
#     Zone: 29 columns
#     Importance: 0.000324
#   Predicate: Ar ka + Ag L > -0.29 (n=136)
#     Zone: 29 columns
#     Importance: 0.000141
#   Predicate: Ar ka + Ag L <= 0.28 (n=135)
#     Zone: 29 columns
#     Importance: 0.000286
#   Predicate: Ar ka + Ag L > 0.28 (n=92)
#     Zone: 29 columns
#     Importance: 0.000109
#   Predicate: Ar ka + Ag L <= 1.07 (n=177)
#     Zone: 29 columns
#     Importance: 0.000254
#   Predicate: Ca ka > -26.11 (n=180)
#     Zone: 17 columns
#     Importance: 0.011376
#   Predicate: Ca ka <= -21.19 (n=92)
#     Zone: 17 columns
#     Importance: 0.012170
#   Predicate: Ca ka > -21.19 (n=135)
#     Zone: 17 columns
#     Importance: 0.013045
#   Predicate: Ca ka <= -6.65 (n=138)
#     Zone: 17 columns
#     Importance: 0.008433
#   Predicate: Ca ka > -6.65 (n=89)
#     Zone: 17 columns
#     Importance: 0.019292
#   Predicate: Ca ka <= 33.38 (n=180)
#     Zone: 17 columns
#     Importance: 0.007873
#   Predicate: Ca kb > -8.59 (n=180)
#     Zone: 13 columns
#     Importance: 0.000354
#   Predicate: Ca kb <= -6.07 (n=92)
#     Zone: 13 columns
#     Importance: 0.000743
#   Predicate: Ca kb > -6.07 (n=135)
#     Zone: 13 columns
#     Importance: 0.000295
#   Predicate: Ca kb <= -2.67 (n=139)
#     Zone: 13 columns
#     Importance: 0.000521
#   Predicate: Ca kb > -2.67 (n=88)
#     Zone: 13 columns
#     Importance: 0.000406
#   Predicate: Ca kb <= 12.61 (n=180)
# ...
# Removed: Zn kb > 0.29 -> background2 <= 0.27 (0.0000) | Kept: background2 <= 0.27 -> Zn kb > 0.29 (0.0000)
# Removed: background2 <= 0.98 -> Zn ka > -0.78 (0.0000) | Kept: Zn ka > -0.78 -> background2 <= 0.98 (0.0000)
# Removed: Ar ka + Ag L > 0.28 -> background2 <= 0.98 (0.0000) | Kept: background2 <= 0.98 -> Ar ka + Ag L > 0.28 (0.0000)
# Removed: background2 > 0.27 -> Zn ka > -0.78 (0.0000) | Kept: Zn ka > -0.78 -> background2 > 0.27 (0.0000)
# Removed: background2 > -0.92 -> Zn ka > -0.78 (0.0000) | Kept: Zn ka > -0.78 -> background2 > -0.92 (0.0001)
# Removed: Zn ka > -0.78 -> Fe kb <= -7.02 (0.0000) | Kept: Fe kb <= -7.02 -> Zn ka > -0.78 (0.0002)
# Removed: background2 > 0.27 -> background2 > -0.37 (0.0000) | Kept: background2 > -0.37 -> background2 > 0.27 (0.0000)
# Removed: background2 > 0.27 -> Fe kb <= -7.41 (0.0000) | Kept: Fe kb <= -7.41 -> background2 > 0.27 (0.0001)
# Removed: background2 > -0.37 -> Ar ka + Ag L > 0.28 (0.0000) | Kept: Ar ka + Ag L > 0.28 -> background2 > -0.37 (0.0000)
# Removed: Ar ka + Ag L > 0.28 -> background2 > -0.92 (0.0000) | Kept: background2 > -0.92 -> Ar ka + Ag L > 0.28 (0.0000)
# Removed: Ar ka + Ag L > 0.28 -> Fe kb <= -7.02 (0.0000) | Kept: Fe kb <= -7.02 -> Ar ka + Ag L > 0.28 (0.0001)
# Removed: background2 > -0.92 -> Fe kb <= -7.02 (0.0000) | Kept: Fe kb <= -7.02 -> background2 > -0.92 (0.0001)
# Removed: Zn ka > 0.08 -> Fe kb <= -7.41 (0.0000) | Kept: Fe kb <= -7.41 -> Zn ka > 0.08 (0.0005)
#
# ======================================================================
# CONSTRUCTED GRAPH SUMMARY
# ======================================================================
# Initial edges: 466 | Removed: 131
# Predicate nodes: 90
# Metric: Perturbation
# Weighting by explained variance: ENABLED
#
# ======================================================================
# Processando Grafo - Semente: 3
# ======================================================================
#
#
# Total bidirectional pairs found: 115
# Removed: Ti ka > -4.69 -> Ti ka > 9.34 (0.0145) | Kept: Ti ka > 9.34 -> Ti ka > -4.69 (0.0531)
# Removed: Ti ka > -4.69 -> Ca ka > -21.19 (0.0146) | Kept: Ca ka > -21.19 -> Ti ka > -4.69 (0.0171)
# Removed: Ag ka scattering <= -0.18 -> Ti ka > 9.34 (0.0037) | Kept: Ti ka > 9.34 -> Ag ka scattering <= -0.18 (0.0260)
# Removed: Ti ka > 9.34 -> Ca ka > -21.19 (0.0254) | Kept: Ca ka > -21.19 -> Ti ka > 9.34 (0.0289)
# Removed: Ti ka > 9.34 -> Ca ka > -26.11 (0.0133) | Kept: Ca ka > -26.11 -> Ti ka > 9.34 (0.0267)
# Removed: Ti ka > 9.34 -> Cu ka > -8.43 (0.0122) | Kept: Cu ka > -8.43 -> Ti ka > 9.34 (0.0127)
# Removed: Ag ka scattering <= -0.18 -> Ca ka <= -21.19 (0.0036) | Kept: Ca ka <= -21.19 -> Ag ka scattering <= -0.18 (0.0395)
# Removed: Ag ka scattering <= -0.18 -> Cu ka > -8.43 (0.0063) | Kept: Cu ka > -8.43 -> Ag ka scattering <= -0.18 (0.0116)
# Removed: Ag ka scattering <= -0.18 -> Ca ka > -26.11 (0.0034) | Kept: Ca ka > -26.11 -> Ag ka scattering <= -0.18 (0.0225)
# Removed: Ca ka <= -21.19 -> Ca ka > -21.19 (0.0126) | Kept: Ca ka > -21.19 -> Ca ka <= -21.19 (0.0410)
# Removed: Ca ka <= -21.19 -> Ca ka > -26.11 (0.0231) | Kept: Ca ka > -26.11 -> Ca ka <= -21.19 (0.0269)
# Removed: Ca ka > -21.19 -> Cu ka > -8.43 (0.0110) | Kept: Cu ka > -8.43 -> Ca ka > -21.19 (0.0113)
# Removed: Cu ka > -8.43 -> Ca ka > -26.11 (0.0101) | Kept: Ca ka > -26.11 -> Cu ka > -8.43 (0.0233)
# Removed: Ca ka <= -6.65 -> Cu ka > -8.43 (0.0098) | Kept: Cu ka > -8.43 -> Ca ka <= -6.65 (0.0493)
# Removed: Ag ka scattering <= 1.67 -> Ca ka <= -6.65 (0.0025) | Kept: Ca ka <= -6.65 -> Ag ka scattering <= 1.67 (0.0366)
# Removed: Ag ka scattering <= 1.67 -> Ca ka <= 33.38 (0.0140) | Kept: Ca ka <= 33.38 -> Ag ka scattering <= 1.67 (0.0163)
# Removed: Cu ka > -9.68 -> Ca ka <= 33.38 (0.0079) | Kept: Ca ka <= 33.38 -> Cu ka > -9.68 (0.0334)
# Removed: Ag ka scattering <= 3.49 -> Cu ka > -9.68 (0.0017) | Kept: Cu ka > -9.68 -> Ag ka scattering <= 3.49 (0.0292)
# Removed: Ag ka scattering <= 3.49 -> Ti kb <= -2.91 (0.0018) | Kept: Ti kb <= -2.91 -> Ag ka scattering <= 3.49 (0.0052)
# Removed: Ag ka scattering <= 3.49 -> Cu ka > -10.68 (0.0019) | Kept: Cu ka > -10.68 -> Ag ka scattering <= 3.49 (0.0119)
# Removed: background3 <= -0.30 -> Ti kb <= 2.45 (0.0004) | Kept: Ti kb <= 2.45 -> background3 <= -0.30 (0.0038)
# Removed: background3 <= -0.30 -> Ti kb <= 6.95 (0.0001) | Kept: Ti kb <= 6.95 -> background3 <= -0.30 (0.0029)
# Removed: Ti kb <= 2.45 -> Cu ka > -10.68 (0.0080) | Kept: Cu ka > -10.68 -> Ti kb <= 2.45 (0.0219)
# Removed: background3 <= 1.29 -> Ti kb <= 2.45 (0.0003) | Kept: Ti kb <= 2.45 -> background3 <= 1.29 (0.0165)
# Removed: background3 <= 1.29 -> Ti kb <= 6.95 (0.0006) | Kept: Ti kb <= 6.95 -> background3 <= 1.29 (0.0033)
# Removed: background3 <= 1.29 -> Ti kb > -10.26 (0.0001) | Kept: Ti kb > -10.26 -> background3 <= 1.29 (0.0054)
# Removed: Ag ka scattering > 1.67 -> Ti kb <= 6.95 (0.0012) | Kept: Ti kb <= 6.95 -> Ag ka scattering > 1.67 (0.0137)
# Removed: background3 <= 2.86 -> Ag ka scattering > 1.67 (0.0001) | Kept: Ag ka scattering > 1.67 -> background3 <= 2.86 (0.0021)
# Removed: Ag ka scattering > 1.67 -> Ti kb > -10.26 (0.0034) | Kept: Ti kb > -10.26 -> Ag ka scattering > 1.67 (0.0061)
# Removed: background3 <= 2.86 -> Ti kb > -10.26 (0.0003) | Kept: Ti kb > -10.26 -> background3 <= 2.86 (0.0123)
# Removed: background3 <= 2.86 -> Fe kb > -7.02 (0.0001) | Kept: Fe kb > -7.02 -> background3 <= 2.86 (0.0057)
# Removed: Ag ka scattering > -0.18 -> Ti kb > -10.26 (0.0009) | Kept: Ti kb > -10.26 -> Ag ka scattering > -0.18 (0.0061)
# Removed: Ag ka scattering > -0.18 -> Fe kb > -7.02 (0.0042) | Kept: Fe kb > -7.02 -> Ag ka scattering > -0.18 (0.0059)
# Removed: Ag ka scattering > -1.65 -> Fe kb > -7.02 (0.0007) | Kept: Fe kb > -7.02 -> Ag ka scattering > -1.65 (0.0110)
# Removed: Ag ka scattering > -1.65 -> Ti kb > -2.91 (0.0014) | Kept: Ti kb > -2.91 -> Ag ka scattering > -1.65 (0.0017)
# Removed: Ti kb > -2.91 -> Ti kb > 2.45 (0.0036) | Kept: Ti kb > 2.45 -> Ti kb > -2.91 (0.0059)
# Removed: Ti kb > 2.45 -> Cu ka <= -9.68 (0.0016) | Kept: Cu ka <= -9.68 -> Ti kb > 2.45 (0.0040)
# Removed: background3 > -2.55 -> Ti kb > 2.45 (0.0000) | Kept: Ti kb > 2.45 -> background3 > -2.55 (0.0015)
# Removed: Ti kb > 2.45 -> Fe kb > -7.41 (0.0031) | Kept: Fe kb > -7.41 -> Ti kb > 2.45 (0.0095)
# Removed: background3 > -2.55 -> Cu ka <= -9.68 (0.0001) | Kept: Cu ka <= -9.68 -> background3 > -2.55 (0.0034)
# Removed: Fe kb > -7.79 -> Cu ka <= -9.68 (0.0016) | Kept: Cu ka <= -9.68 -> Fe kb > -7.79 (0.0033)
# Removed: background3 > -2.55 -> Fe kb > -7.41 (0.0000) | Kept: Fe kb > -7.41 -> background3 > -2.55 (0.0033)
# Removed: background3 > -2.55 -> Fe kb > -7.79 (0.0001) | Kept: Fe kb > -7.79 -> background3 > -2.55 (0.0046)
# Removed: background3 > -0.30 -> Cu ka <= -8.43 (0.0001) | Kept: Cu ka <= -8.43 -> background3 > -0.30 (0.0014)
# Removed: Fe kb > -7.79 -> Cu ka <= -8.43 (0.0014) | Kept: Cu ka <= -8.43 -> Fe kb > -7.79 (0.0043)
# Removed: background3 > -0.30 -> Fe kb > -7.79 (0.0000) | Kept: Fe kb > -7.79 -> background3 > -0.30 (0.0013)
# Removed: background3 > -0.30 -> Fe ka > -23.71 (0.0001) | Kept: Fe ka > -23.71 -> background3 > -0.30 (0.0048)
# Removed: Cu ka <= -3.28 -> Fe ka > -23.71 (0.0024) | Kept: Fe ka > -23.71 -> Cu ka <= -3.28 (0.0047)
# Removed: Fe ka > -24.15 -> Cu ka <= -3.28 (0.0009) | Kept: Cu ka <= -3.28 -> Fe ka > -24.15 (0.0018)
# Removed: background3 > 1.29 -> Fe ka > -24.15 (0.0001) | Kept: Fe ka > -24.15 -> background3 > 1.29 (0.0025)
# Removed: Fe ka > -24.15 -> Ca kb <= -6.07 (0.0017) | Kept: Ca kb <= -6.07 -> Fe ka > -24.15 (0.0030)
# Removed: Cu kb > -1.61 -> Ca kb <= -6.07 (0.0005) | Kept: Ca kb <= -6.07 -> Cu kb > -1.61 (0.0026)
# Removed: Ca kb <= -6.07 -> Fe ka > -24.62 (0.0006) | Kept: Fe ka > -24.62 -> Ca kb <= -6.07 (0.0020)
# Removed: Cu kb > -1.61 -> Ca kb <= -2.67 (0.0004) | Kept: Ca kb <= -2.67 -> Cu kb > -1.61 (0.0006)
# Removed: Ca kb <= 12.61 -> Ca kb <= -2.67 (0.0004) | Kept: Ca kb <= -2.67 -> Ca kb <= 12.61 (0.0039)
# Removed: background1 <= -1.03 -> Ca kb <= 12.61 (0.0001) | Kept: Ca kb <= 12.61 -> background1 <= -1.03 (0.0015)
# Removed: background1 <= -1.03 -> Cu kb > -2.30 (0.0002) | Kept: Cu kb > -2.30 -> background1 <= -1.03 (0.0013)
# Removed: background1 <= -1.03 -> Ca kb > -2.67 (0.0001) | Kept: Ca kb > -2.67 -> background1 <= -1.03 (0.0008)
# Removed: Cu kb <= -2.30 -> Cu kb > -2.88 (0.0003) | Kept: Cu kb > -2.88 -> Cu kb <= -2.30 (0.0005)
# Removed: Ar ka + Ag L <= -0.29 -> Cu kb <= -2.30 (0.0000) | Kept: Cu kb <= -2.30 -> Ar ka + Ag L <= -0.29 (0.0002)
# Removed: background1 <= 2.08 -> Cu kb <= -2.30 (0.0002) | Kept: Cu kb <= -2.30 -> background1 <= 2.08 (0.0002)
# Removed: Ca kb > -8.59 -> Cu kb > -2.88 (0.0003) | Kept: Cu kb > -2.88 -> Ca kb > -8.59 (0.0004)
# Removed: Ca kb > -2.67 -> Cu kb > -2.88 (0.0004) | Kept: Cu kb > -2.88 -> Ca kb > -2.67 (0.0006)
# Removed: background1 <= -0.11 -> Cu kb > -2.88 (0.0000) | Kept: Cu kb > -2.88 -> background1 <= -0.11 (0.0006)
# Removed: Ar ka + Ag L <= -0.29 -> background1 <= 2.08 (0.0000) | Kept: background1 <= 2.08 -> Ar ka + Ag L <= -0.29 (0.0000)
# Removed: background1 <= 2.08 -> Ca kb > -8.59 (0.0000) | Kept: Ca kb > -8.59 -> background1 <= 2.08 (0.0010)
# Removed: background1 <= 2.08 -> background1 <= -0.11 (0.0000) | Kept: background1 <= -0.11 -> background1 <= 2.08 (0.0001)
# Removed: background1 <= -0.11 -> Ca kb > -8.59 (0.0000) | Kept: Ca kb > -8.59 -> background1 <= -0.11 (0.0003)
# Removed: background1 <= -0.11 -> Ca kb > -6.07 (0.0000) | Kept: Ca kb > -6.07 -> background1 <= -0.11 (0.0003)
# Removed: Ar ka + Ag L <= -0.29 -> Ca kb > -6.07 (0.0000) | Kept: Ca kb > -6.07 -> Ar ka + Ag L <= -0.29 (0.0003)
# Removed: Zn ka <= -0.78 -> Cu kb <= -1.61 (0.0001) | Kept: Cu kb <= -1.61 -> Zn ka <= -0.78 (0.0009)
# Removed: Ar ka + Ag L > -1.05 -> Zn ka <= -0.78 (0.0000) | Kept: Zn ka <= -0.78 -> Ar ka + Ag L > -1.05 (0.0000)
# Removed: Zn ka <= -0.78 -> Cu kb <= 0.18 (0.0000) | Kept: Cu kb <= 0.18 -> Zn ka <= -0.78 (0.0001)
# Removed: Ar ka + Ag L <= 0.28 -> Cu kb <= -1.61 (0.0000) | Kept: Cu kb <= -1.61 -> Ar ka + Ag L <= 0.28 (0.0002)
# Removed: Zn kb <= -0.29 -> Cu kb <= -1.61 (0.0000) | Kept: Cu kb <= -1.61 -> Zn kb <= -0.29 (0.0002)
# Removed: background1 > -0.11 -> Cu kb <= -1.61 (0.0000) | Kept: Cu kb <= -1.61 -> background1 > -0.11 (0.0002)
# Removed: Ar ka + Ag L <= 0.28 -> Ca kb > -6.07 (0.0001) | Kept: Ca kb > -6.07 -> Ar ka + Ag L <= 0.28 (0.0009)
# Removed: Ar ka + Ag L <= 0.28 -> Zn kb <= -0.29 (0.0000) | Kept: Zn kb <= -0.29 -> Ar ka + Ag L <= 0.28 (0.0000)
# Removed: Ar ka + Ag L <= 1.07 -> Ca kb > -6.07 (0.0000) | Kept: Ca kb > -6.07 -> Ar ka + Ag L <= 1.07 (0.0005)
# Removed: background1 > -0.11 -> Zn ka <= 0.08 (0.0000) | Kept: Zn ka <= 0.08 -> background1 > -0.11 (0.0001)
# Removed: Ar ka + Ag L <= 1.07 -> background1 > -0.11 (0.0000) | Kept: background1 > -0.11 -> Ar ka + Ag L <= 1.07 (0.0000)
# Removed: Zn ka <= 0.08 -> Cu kb <= 0.18 (0.0001) | Kept: Cu kb <= 0.18 -> Zn ka <= 0.08 (0.0007)
# Removed: Zn kb <= 0.29 -> Zn ka <= 0.08 (0.0000) | Kept: Zn ka <= 0.08 -> Zn kb <= 0.29 (0.0002)
# Removed: Zn ka <= 0.08 -> Fe ka <= -23.71 (0.0000) | Kept: Fe ka <= -23.71 -> Zn ka <= 0.08 (0.0002)
# Removed: background1 > -1.87 -> Zn ka <= 0.08 (0.0000) | Kept: Zn ka <= 0.08 -> background1 > -1.87 (0.0001)
# Removed: Zn kb <= 0.29 -> Cu kb <= 0.18 (0.0000) | Kept: Cu kb <= 0.18 -> Zn kb <= 0.29 (0.0003)
# Removed: Cu kb <= 0.18 -> Fe ka <= -24.15 (0.0002) | Kept: Fe ka <= -24.15 -> Cu kb <= 0.18 (0.0002)
# Removed: Ar ka + Ag L <= 1.07 -> Fe ka <= -24.15 (0.0000) | Kept: Fe ka <= -24.15 -> Ar ka + Ag L <= 1.07 (0.0005)
# Removed: Ar ka + Ag L > -1.05 -> background1 > -1.87 (0.0000) | Kept: background1 > -1.87 -> Ar ka + Ag L > -1.05 (0.0000)
# Removed: Zn ka <= 1.38 -> background1 > -1.87 (0.0000) | Kept: background1 > -1.87 -> Zn ka <= 1.38 (0.0000)
# Removed: Ar ka + Ag L > -1.05 -> Fe ka <= -23.71 (0.0000) | Kept: Fe ka <= -23.71 -> Ar ka + Ag L > -1.05 (0.0002)
# Removed: Zn ka <= 1.38 -> Zn kb <= 1.07 (0.0000) | Kept: Zn kb <= 1.07 -> Zn ka <= 1.38 (0.0000)
# Removed: Zn kb > -1.05 -> Zn ka <= 1.38 (0.0000) | Kept: Zn ka <= 1.38 -> Zn kb > -1.05 (0.0001)
# Removed: Zn kb > -1.05 -> Zn kb <= 1.07 (0.0000) | Kept: Zn kb <= 1.07 -> Zn kb > -1.05 (0.0000)
# Removed: Zn kb <= 1.07 -> Fe ka <= -23.71 (0.0000) | Kept: Fe ka <= -23.71 -> Zn kb <= 1.07 (0.0002)
# Removed: Zn kb > -1.05 -> Fe ka <= -23.71 (0.0000) | Kept: Fe ka <= -23.71 -> Zn kb > -1.05 (0.0008)
# Removed: Zn ka > -1.75 -> Fe ka <= -23.71 (0.0000) | Kept: Fe ka <= -23.71 -> Zn ka > -1.75 (0.0002)
# Removed: Zn kb > -0.29 -> Zn ka > -1.75 (0.0000) | Kept: Zn ka > -1.75 -> Zn kb > -0.29 (0.0000)
# Removed: Zn ka > -1.75 -> Fe ka <= -22.90 (0.0001) | Kept: Fe ka <= -22.90 -> Zn ka > -1.75 (0.0004)
# Removed: Zn kb > 0.29 -> Zn kb > -0.29 (0.0000) | Kept: Zn kb > -0.29 -> Zn kb > 0.29 (0.0000)
# Removed: background2 <= 0.27 -> Zn kb > -0.29 (0.0000) | Kept: Zn kb > -0.29 -> background2 <= 0.27 (0.0000)
# Removed: Zn kb > 0.29 -> Fe ka <= -22.90 (0.0000) | Kept: Fe ka <= -22.90 -> Zn kb > 0.29 (0.0003)
# Removed: Zn kb > 0.29 -> background2 <= -0.37 (0.0000) | Kept: background2 <= -0.37 -> Zn kb > 0.29 (0.0000)
# Removed: Zn kb > 0.29 -> background2 <= 0.98 (0.0000) | Kept: background2 <= 0.98 -> Zn kb > 0.29 (0.0000)
# Removed: Ar ka + Ag L > -0.29 -> background2 <= 0.27 (0.0000) | Kept: background2 <= 0.27 -> Ar ka + Ag L > -0.29 (0.0000)
# Removed: Ar ka + Ag L > -0.29 -> background2 <= 0.98 (0.0000) | Kept: background2 <= 0.98 -> Ar ka + Ag L > -0.29 (0.0000)
# Removed: Ar ka + Ag L > -0.29 -> Fe kb <= -6.37 (0.0000) | Kept: Fe kb <= -6.37 -> Ar ka + Ag L > -0.29 (0.0001)
# Removed: background2 <= -0.37 -> background2 <= 0.27 (0.0000) | Kept: background2 <= 0.27 -> background2 <= -0.37 (0.0000)
# Removed: background2 <= -0.37 -> Fe kb <= -6.37 (0.0000) | Kept: Fe kb <= -6.37 -> background2 <= -0.37 (0.0002)
# Removed: background2 > -0.37 -> Fe kb <= -6.37 (0.0000) | Kept: Fe kb <= -6.37 -> background2 > -0.37 (0.0001)
# Removed: background2 > -0.92 -> Zn ka > -0.78 (0.0000) | Kept: Zn ka > -0.78 -> background2 > -0.92 (0.0000)
# Removed: Zn ka > -0.78 -> Fe kb <= -7.02 (0.0000) | Kept: Fe kb <= -7.02 -> Zn ka > -0.78 (0.0001)
# Removed: background2 > 0.27 -> Ar ka + Ag L > 0.28 (0.0000) | Kept: Ar ka + Ag L > 0.28 -> background2 > 0.27 (0.0000)
# Removed: Ar ka + Ag L > 0.28 -> Fe kb <= -7.02 (0.0000) | Kept: Fe kb <= -7.02 -> Ar ka + Ag L > 0.28 (0.0003)
# Removed: background2 > 0.27 -> Fe kb <= -7.02 (0.0000) | Kept: Fe kb <= -7.02 -> background2 > 0.27 (0.0004)
#
# ======================================================================
# CONSTRUCTED GRAPH SUMMARY
# ======================================================================
# Initial edges: 464 | Removed: 115
# Predicate nodes: 90
# Metric: Perturbation
# Weighting by explained variance: ENABLED
#
# Processing graph LRC...
#
# Processing graph LRC...
#
# Processing graph LRC...
#
# Processing graph LRC...
#    Predicate_pert_Seed_0 Predicate_pert_Seed_1 Predicate_pert_Seed_2  \
# 0         Ti ka <= -4.69        Ti ka <= -4.69        Ti ka <= -4.69
# 1          Ti ka <= 9.34         Ti ka <= 9.34         Ti ka <= 9.34
# 2         Ti ka <= 19.85        Ti ka <= 19.85        Ti ka <= 19.85
# 3         Ti ka > -28.53        Ti ka > -28.53        Ti ka > -28.53
# 4          Ca ka > -6.65         Ca ka > -6.65         Ca ka > -6.65
# ..                   ...                   ...                   ...
# 87    background2 > 0.27   Ar ka + Ag L > 0.28   background2 <= 0.27
# 88   background1 > -1.03          Zn ka > 0.08         Zn kb > -0.29
# 89          Zn ka > 0.08               Class_A          Zn ka > 0.08
# 90               Class_A               Class_B               Class_A
# 91               Class_B   background3 <= 2.86               Class_B
#
#    Predicate_pert_Seed_3
# 0         Ti ka <= -4.69
# 1          Ti ka <= 9.34
# 2         Ti ka <= 19.85
# 3         Ti ka > -28.53
# 4          Ca ka > -6.65
# ..                   ...
# 87         Zn kb > -0.29
# 88        Fe kb <= -7.41
# 89          Zn ka > 0.08
# 90               Class_A
# 91               Class_B
#
# [92 rows x 4 columns]

# %%
all_results_pert[0]['pert_results_dict']['Bag_1']
# Out:
#               Predicate  Perturbation
# 0        Ti ka <= -4.69      0.205934
# 1         Ti ka <= 9.34      0.142518
# 2        Ti ka <= 19.85      0.110712
# 3        Ti ka > -28.53      0.073447
# 4         Ca ka > -6.65      0.018821
# ..                  ...           ...
# 85  Ar ka + Ag L > 0.28      0.000111
# 86       Fe kb <= -7.02      0.000110
# 87        Zn ka > -0.78      0.000103
# 88       Fe kb <= -7.41      0.000086
# 89         Zn ka > 0.08      0.000081
#
# [90 rows x 2 columns]

# %%
# Somar LRCs de predicados equivalentes entre diferentes seeds
lrc_combined_list = []

for seed in random_seeds:
    lrc_df = lrc_pert_by_seed[seed].copy()
    lrc_combined_list.append(lrc_df) # o append adiciona o dataframe ao final da lista

# Concatenar todos os dataframes
lrc_all_seeds = pd.concat(lrc_combined_list, ignore_index=True) 

# Agrupar por predicado (Node) e somar as LRCs, mantendo Zone, Threshold e Operator
lrc_summed_df_pert = lrc_all_seeds.groupby('Node').agg({ # o .agg pode ser usado para aplicar múltiplas funções de agregação
    'Local_Reaching_Centrality': 'mean', # sum = somando as LRCs, poderia ser média ou outro agregado
    'Zone': 'first',
    'Threshold': 'first',
    'Operator': 'first'
}).reset_index()

# Ordenar pelo valor de LRC somado (maior para menor)
lrc_summed_df_pert = lrc_summed_df_pert.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
# vamoss pegar so os valore sunicos de lrc_summed_df baseado na zona espectral
lrc_summed_unique_df_pert = lrc_summed_df_pert.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
lrc_summed_unique_df_pert = lrc_summed_unique_df_pert.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
lrc_summed_unique_df_pert
# Out:
#                          Node  Local_Reaching_Centrality              Zone  \
# 0              Ti ka <= -4.69                  20.179513             Ti ka
# 1               Ca ka > -6.65                   1.257539             Ca ka
# 2               Cu ka > -8.43                   0.658385             Cu ka
# 3   Ag ka scattering <= -0.18                   0.553030  Ag ka scattering
# 4              Ti kb <= -2.91                   0.293793             Ti kb
# 5        background3 <= -0.30                   0.189746       background3
# 6               Fe kb > -7.02                   0.139360             Fe kb
# 7              Fe ka > -23.71                   0.055601             Fe ka
# 8              Ca kb <= -6.07                   0.040365             Ca kb
# 9               Cu kb > -1.61                   0.037932             Cu kb
# 10       background1 <= -1.03                   0.009095       background1
# 11      Ar ka + Ag L <= -0.29                   0.006679      Ar ka + Ag L
# 12              Zn ka <= 0.08                   0.005051             Zn ka
# 13             Zn kb <= -0.29                   0.004541             Zn kb
# 14        background2 <= 0.98                   0.003706       background2
# 15                    Class_A                   0.000000              None
#
#    Threshold Operator
# 0      -4.69       <=
# 1      -6.65        >
# 2      -8.43        >
# 3      -0.18       <=
# 4      -2.91       <=
# 5      -0.30       <=
# 6      -7.02        >
# 7     -23.71        >
# 8      -6.07       <=
# 9      -1.61        >
# 10     -1.03       <=
# 11     -0.29       <=
# 12      0.08       <=
# 13     -0.29       <=
# 14      0.98       <=
# 15      None     None

# %%
# Aplicar o mapeamento
lrc_summed_df_pert_natural = exp.map_thresholds_to_natural(
    lrc_df=lrc_summed_df_pert,
    zone_sums_preprocessed=zone_scores_df,
    zone_sums_natural=zones_original[0]
)

lrc_summed_df_pert_natural
# Out:
#               Node  Local_Reaching_Centrality   Zone Threshold Operator  \
# 0   Ti ka <= -4.69                  20.179513  Ti ka     -4.69       <=
# 1    Ti ka <= 9.34                  13.600255  Ti ka      9.34       <=
# 2   Ti ka <= 19.85                   8.775548  Ti ka     19.85       <=
# 3   Ti ka > -28.53                   4.452550  Ti ka    -28.53        >
# 4    Ca ka > -6.65                   1.257539  Ca ka     -6.65        >
# ..             ...                        ...    ...       ...      ...
# 87   Zn kb > -0.29                   0.002896  Zn kb     -0.29        >
# 88  Fe kb <= -7.41                   0.002550  Fe kb     -7.41       <=
# 89    Zn ka > 0.08                   0.000089  Zn ka      0.08        >
# 90         Class_A                   0.000000   None      None     None
# 91         Class_B                   0.000000   None      None     None
#
#     Threshold_Natural  Reference_Sample_Index  Approximation_Error  \
# 0          -49.917691                    64.0             0.070519
# 1          101.580304                    11.0             0.037350
# 2          207.521929                    41.0             0.066299
# 3         -308.117871                   246.0             0.007504
# 4          -72.180511                   102.0             0.000511
# ..                ...                     ...                  ...
# 87          -3.715263                   178.0             0.000440
# 88         -32.289144                     4.0             0.001335
# 89           0.501611                     1.0             0.001115
# 90                NaN                     NaN                  NaN
# 91                NaN                     NaN                  NaN
#
#            Node_Natural
# 0   Ti ka <= -49.917691
# 1   Ti ka <= 101.580304
# 2   Ti ka <= 207.521929
# 3   Ti ka > -308.117871
# 4    Ca ka > -72.180511
# ..                  ...
# 87    Zn kb > -3.715263
# 88  Fe kb <= -32.289144
# 89     Zn ka > 0.501611
# 90                 None
# 91                 None
#
# [92 rows x 9 columns]

# %%
import plotly.graph_objects as go

n = 0
zone_name = lrc_summed_df_pert_natural.iloc[n]['Zone'] # o n indica a linha do dataframe lrc_summed_df_pert_natural que queremos acessar para pegar o nome da zona espectral (coluna 'Zone')
threshold_score = float(lrc_summed_df_pert_natural.iloc[n]['Threshold_Natural']) # o iloc acessa a linha n e a coluna 'Threshold_Natural' para pegar o valor do threshold já mapeado para o espaço natural (não pré-processado)

# Usar pca_info_dict dos dados ORIGINAIS (zones_original[1])
pca_info_dict_original = zones_original[1]

# Reconstrução: τ = mean + threshold * loadings (no espaço original)
threshold_spectrum = exp.reconstruct_threshold_to_spectrum(
    threshold_value=threshold_score,
    zone_name=zone_name,
    pca_info_dict=pca_info_dict_original
)
print(f"\nEspectro de threshold reconstruído para zona '{zone_name}':")
print(f"  - Dimensão: {len(threshold_spectrum)} variáveis espectrais")
#print(f"  - Range de energias: {threshold_spectrum.index[n]} - {threshold_spectrum.index[-1]}")
print(f"  - Variância explicada pela PC1: {pca_info_dict_original[zone_name]['variance_explained']:.2%}")

# Usar dados ORIGINAIS para plotar (spectral_zones_original)
zone_df = spectral_zones_original[zone_name]

# Plotar zona com threshold (inline)
fig = go.Figure()
x_values = pd.to_numeric(zone_df.columns, errors='coerce')

# Plotar espectros das amostras coloridas por classe
colors = {'A': 'gold', 'B': 'blue'}
for idx, row in zone_df.iterrows():
    class_label = ycalclass.iloc[idx] if idx < len(ycalclass) else 'Unknown'
    fig.add_trace(go.Scatter(
        x=x_values,
        y=row.values,
        mode='lines',
        line=dict(color=colors.get(class_label, 'rgba(128,128,128,0.3)'), width=0.5),
        name=f'Class {class_label}',
        showlegend=False,
        hoverinfo='skip'
    ))

# Plotar espectro de threshold (destaque)
fig.add_trace(go.Scatter(
    x=x_values,
    y=threshold_spectrum.values,
    mode='lines',
    line=dict(color='red', width=4, dash='dash'),
    name=f'Threshold Spectrum ({threshold_spectrum.name})'
))

# Layout do gráfico
fig.update_layout(
    title=f"Zona '{zone_name}' com Threshold Multivariado (Predicado: {lrc_summed_df_pert_natural.iloc[n]['Node_Natural']})",
    xaxis_title='Energia / Comprimento de Onda',
    yaxis_title='Intensidade',
    template='plotly_white',
    showlegend=True,
    legend=dict(yanchor="top", y=0.99, xanchor="left", x=0.01)
)

fig.show()
# Out:
# Espectro de threshold reconstruído para zona 'Ti ka':
#   - Dimensão: 19 variáveis espectrais
#   - Variância explicada pela PC1: 98.39%

# %%
# Permutation importance baseado em mudança nas probabilidades previstas (predict_proba)
# Medimos a média da diferença absoluta entre as probabilidades originais e as probabilidades
# obtidas após permutar cada variável. Isso fornece uma métrica contínua de importância.
n_repeats = 10
rng = np.random.RandomState(42)
# Probabilidades base (classe 'B' mapeada para 1)
baseline_proba = svm_model[3].predict_proba(Xcalclass_prep)[:, 1]
importance_list = []
X_arr = Xcalclass_prep.copy()
for col in Xcalclass_prep.columns:
    diffs = []
    for _ in range(n_repeats):
        X_perm = X_arr.copy()
        X_perm[col] = rng.permutation(X_perm[col].values)
        perm_proba = svm_model[3].predict_proba(X_perm)[:, 1]
        diffs.append(np.mean(np.abs(baseline_proba - perm_proba)))
    importance_list.append(np.mean(diffs))

permutation_df = pd.DataFrame({
    'energy': Xcalclass_prep.columns,
    'Permutation_importance_proba': importance_list
})
permutation_df.sort_values(by='Permutation_importance_proba', ascending=False, inplace=True)
energy_to_zone_vip = {}
for zone_name, start, end in spectral_cuts:
    for e in permutation_df['energy']:
        ef = float(e)
        if start <= ef <= end:
            energy_to_zone_vip[e] = zone_name
permutation_df['Zone'] = permutation_df['energy'].map(energy_to_zone_vip)
permutation_unique_df = permutation_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
permutation_unique_df = permutation_unique_df.sort_values(by='Permutation_importance_proba', ascending=False)
permutation_unique_df
# Out:
#    energy  Permutation_importance_proba              Zone
# 0    6.43                      0.029742             Fe ka
# 1    4.52                      0.008574             Ti ka
# 2    3.73                      0.004022             Ca ka
# 3    8.06                      0.001286             Cu ka
# 4    4.93                      0.001099             Ti kb
# 5    7.04                      0.000955             Fe kb
# 6   21.92                      0.000850  Ag ka scattering
# 7    4.01                      0.000417             Ca kb
# 8   17.23                      0.000188       background3
# 9    8.93                      0.000178             Cu kb
# 10   5.79                      0.000110       background1
# 11   2.91                      0.000084      Ar ka + Ag L
# 12   8.52                      0.000082             Zn ka
# 13   9.97                      0.000070             Zn kb
# 14   7.58                      0.000069       background2
# 15   2.74                      0.000062               NaN

# %%
import numpy as np

max_len = max(
    len(pvector_unique_df['Zone']),
    len(shap_unique_df['Zone']),
    len(permutation_unique_df['Zone']),
    len(lrc_summed_unique_df_pert['Zone']),
    len(lrc_summed_unique_df_cov['Zone'])
)

def pad_list(lst, length):
    return list(lst) + [None] * (length - len(lst))

features_importance = pd.DataFrame({
    'SVM_pvector': pad_list(pvector_unique_df['Zone'], max_len),
    'Shap': pad_list(shap_unique_df['Zone'], max_len),
    'Permutation' : pad_list(permutation_unique_df['Zone'], max_len),
    'LRC_perturbation' : pad_list(lrc_summed_unique_df_pert['Zone'], max_len),
    'LRC_covariance' : pad_list(lrc_summed_unique_df_cov['Zone'], max_len),
})

features_importance.to_csv('feature_importance.csv', index=False, sep=';')
features_importance
# Out:
#          SVM_pvector              Shap       Permutation  LRC_perturbation  \
# 0              Fe ka             Ti ka             Fe ka             Ti ka
# 1              Ti ka             Ca ka             Ti ka             Ca ka
# 2              Cu ka             Fe ka             Ca ka             Cu ka
# 3   Ag ka scattering             Cu ka             Cu ka  Ag ka scattering
# 4              Fe kb             Ti kb             Ti kb             Ti kb
# 5              Ti kb  Ag ka scattering             Fe kb       background3
# 6              Ca ka             Ca kb  Ag ka scattering             Fe kb
# 7              Cu kb       background2             Ca kb             Fe ka
# 8        background3       background1       background3             Ca kb
# 9              Ca kb       background3             Cu kb             Cu kb
# 10       background1             Fe kb       background1       background1
# 11             Zn ka             Cu kb      Ar ka + Ag L      Ar ka + Ag L
# 12      Ar ka + Ag L             Zn kb             Zn ka             Zn ka
# 13               NaN      Ar ka + Ag L             Zn kb             Zn kb
# 14       background2             Zn ka       background2       background2
# 15             Zn kb               NaN               NaN              None
#
#       LRC_covariance
# 0              Fe ka
# 1              Ca ka
# 2              Fe kb
# 3              Ti ka
# 4              Ca kb
# 5              Cu ka
# 6              Ti kb
# 7              Cu kb
# 8   Ag ka scattering
# 9        background3
# 10             Zn ka
# 11       background1
# 12      Ar ka + Ag L
# 13       background2
# 14             Zn kb
# 15              None

# %%
import rbo
rbo_comparison = pd.DataFrame(columns=['Method_1', 'Method_2', 'RBO_Score'])
methods = features_importance.columns.tolist()
for i in range(len(methods)):
    for j in range(i + 1, len(methods)):
        method_1 = methods[i]
        method_2 = methods[j]
        # Remove None values from the lists
        list_1 = [x for x in features_importance[method_1].tolist() if x is not None]
        list_2 = [x for x in features_importance[method_2].tolist() if x is not None]
        # Truncate both lists to the same length (minimum of both)
        min_len = min(len(list_1), len(list_2))
        list_1_trunc = list_1[:min_len]
        list_2_trunc = list_2[:min_len]
        rbo_score = rbo.RankingSimilarity(list_1_trunc, list_2_trunc).rbo(p=0.7, k=10)
        rbo_comparison = pd.concat([rbo_comparison, pd.DataFrame({
            'Method_1': [method_1],
            'Method_2': [method_2],
            'RBO_Score': [rbo_score]
        })], ignore_index=True)
rbo_comparison.sort_values(by='RBO_Score', ascending=False, inplace=True)
rbo_comparison.to_csv('rbo_rank.csv', index=False, sep=';')
rbo_comparison
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_18680\3097109587.py:16: FutureWarning:
#
# The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#            Method_1          Method_2  RBO_Score
# 1       SVM_pvector       Permutation   0.854802
# 5              Shap  LRC_perturbation   0.851693
# 8       Permutation    LRC_covariance   0.744760
# 3       SVM_pvector    LRC_covariance   0.661631
# 4              Shap       Permutation   0.543954
# 7       Permutation  LRC_perturbation   0.452684
# 2       SVM_pvector  LRC_perturbation   0.436356
# 0       SVM_pvector              Shap   0.435407
# 6              Shap    LRC_covariance   0.428925
# 9  LRC_perturbation    LRC_covariance   0.330692

# %%
lrc_summed_df_cov_natural.to_csv('lrc_cov_natural.csv', index=False, sep=';')
lrc_summed_df_pert_natural.to_csv('lrc_pert_natural.csv', index=False, sep=';')
