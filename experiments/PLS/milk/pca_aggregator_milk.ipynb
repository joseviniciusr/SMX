# %%
# Importing the necessary libraries
import pandas as pd
import numpy as np
import kennard_stone as ks
pd.options.plotting.backend = 'plotly'  # setting plotly as the backend for pandas plotting

# Add parent directory to sys.path so local module 'synthetic' can be imported
import sys
from pathlib import Path # for path manipulations
# Move three levels up from current working directory to reach workspace root
workspace_root = Path.cwd().parent.parent.parent.resolve() 
smx_dir = workspace_root / 'smx'  # Path to smx folder
if str(smx_dir) not in sys.path: # check to avoid duplicates
    sys.path.insert(0, str(smx_dir)) # insert at the start of sys.path to prioritize local modules

# Loading a soil spectral dataset based on X-ray fluorescence (XRF)
data_complete = pd.read_csv(f'{workspace_root}/real_datasets/xrf/milk.csv', sep=';') # local copy of Toledo 2022 dataset
data = data_complete.loc[:, '2.66':'22.62']

# Creating a new column 'Class' based on the condition of the samples in the 'Type' column being 'Authentic'
data_A = data_complete[data_complete['Class'] == 'A'].reset_index(drop=True)
data_B = data_complete[data_complete['Class'] == 'B'].reset_index(drop=True)

# splitting the data into calibration and prediction sets by kennard-stone algorithm
XA_cal, XA_pred = ks.train_test_split(data_A.loc[:, '2.66':'22.62'], test_size=0.30) # class A
XA_cal = XA_cal.reset_index(drop=True)
XA_pred = XA_pred.reset_index(drop=True)

XB_cal, XB_pred = ks.train_test_split(data_B.loc[:, '2.66':'22.62'], test_size=0.30) # class B
XB_cal = XB_cal.reset_index(drop=True)
XB_pred = XB_pred.reset_index(drop=True)

Xcalclass = pd.concat([XA_cal, XB_cal], axis=0).reset_index(drop=True) # concatenating both classes
Xpredclass = pd.concat([XA_pred, XB_pred], axis=0).reset_index(drop=True)
ycalclass = pd.Series(['A']*XA_cal.shape[0] + ['B']*XB_cal.shape[0]) # creating the target variable for calibration set
ypredclass = pd.Series(['A']*XA_pred.shape[0] + ['B']*XB_pred.shape[0]) # creating the target variable for prediction set

# preprocessings
import preprocessings as prepr # preprocessing methods for XRF data

Xcalclass_prep, mean_calclass, mean_calclass_poisson  = prepr.poisson(Xcalclass, mc=True)
Xpredclass_prep = ((Xpredclass/np.sqrt(mean_calclass)) - mean_calclass_poisson)
# Out:
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-02-26 14:14:20,428 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-02-26 14:14:20,449 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-02-26 14:14:20,475 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-02-26 14:14:20,526 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
from modeling import pls_optimized
# performing PLS-DA with optimized latent variables
plsda_results = pls_optimized(Xcalclass_prep, 
                              ycalclass,
                              LVmax=4,
                              Xpred=Xpredclass_prep,
                              ypred=ypredclass,
                              aim='classification',
                              cv=10)
plsda_results[0]
# Out:
#    LVs  Accuracy Cal  Sensitivity Cal  Specificity Cal                 CM Cal  \
# 0    1      0.634328         0.755952             0.43  [[43, 57], [41, 127]]
# 1    2      0.731343         0.827381             0.57  [[57, 43], [29, 139]]
# 2    3      0.779851         0.851190             0.66  [[66, 34], [25, 143]]
# 3    4      0.820896         0.875000             0.73  [[73, 27], [21, 147]]
#
#    Accuracy CV  Sensitivity CV  Specificity CV                  CM CV  \
# 0     0.492537        0.660714            0.21  [[21, 79], [57, 111]]
# 1     0.567164        0.714286            0.32  [[32, 68], [48, 120]]
# 2     0.641791        0.744048            0.47  [[47, 53], [43, 125]]
# 3     0.619403        0.702381            0.48  [[48, 52], [50, 118]]
#
#    Accuracy Pred  Sensitivity Pred  Specificity Pred               CM Pred  \
# 0       0.626087          0.694444          0.511628  [[22, 21], [22, 50]]
# 1       0.695652          0.791667          0.534884  [[23, 20], [15, 57]]
# 2       0.782609          0.819444          0.720930  [[31, 12], [13, 59]]
# 3       0.765217          0.833333          0.651163  [[28, 15], [12, 60]]
#
#    X Cum Exp Var  Y Cum Exp Var  X Ind Exp Var  Y Ind Exp Var
# 0      11.749629       7.425722      11.749629       7.425722
# 1      29.460291       9.243836      17.710662       1.818114
# 2      51.124817      11.730577      21.664526       2.486741
# 3      61.679054      16.883401      10.554237       5.152824

# %% [markdown]
# ## Definição das Zonas Espectrais

# %%
spectral_cuts = [
('Ag La', 2.66, 3.10),
('Ag Lb', 3.10, 3.46),
('Ca', 3.46, 3.92),
('background', 3.92, 6.12),
('Fe', 6.12, 6.68),
('Cu', 6.70, 8.37),
('Zn', 8.37, 9.10),
('Bremsstrahlung', 9.10, 20.06),
('Ag compton', 20.06, 21.62),
('Ag ka', 21.48, 22.62)
]

# %% [markdown]
# ## VIP, Regression Coefficients e SHAP (como no original)

# %%
pls_model = plsda_results[3]               # fitted PLS model
vip_scores_mat = plsda_results[4]          # VIP scores matrix (features × LV)
y_pred_cont = plsda_results[5].iloc[:, -1] # continuous predictions for Xcalclass (used for MI/Cov)

# VIP scores por energia
vip_scores_df = pd.DataFrame({
    'energy': vip_scores_mat.T.index,
    'VIP_Score': vip_scores_mat.T.iloc[:,0].values
})
vip_scores_df = vip_scores_df.sort_values(by='VIP_Score', ascending=False).reset_index(drop=True)
energy_to_zone_vip = {}
for zone_name, start, end in spectral_cuts:
    for e in vip_scores_df['energy']:
        ef = float(e)
        if start <= ef <= end:
            energy_to_zone_vip[e] = zone_name
vip_scores_df['Zone'] = vip_scores_df['energy'].map(energy_to_zone_vip)
vip_scores_unique_df = vip_scores_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
vip_scores_unique_df = vip_scores_unique_df.sort_values(by='VIP_Score', ascending=False).reset_index(drop=True)

# Coeficientes de regressão do PLS
reg_vet = pd.DataFrame(pls_model.coef_, columns=pls_model.feature_names_in_).T
reg_vet.insert(0, 'energy', reg_vet.index)
reg_vet = reg_vet.reset_index(drop=True)
reg_vet.columns = ['energy','Reg_coef']
reg_vet['Abs_Reg_coef'] = reg_vet['Reg_coef'].abs()
reg_vet = reg_vet.sort_values(by='Abs_Reg_coef', ascending=False).reset_index(drop=True)
energy_to_zone_reg = {}
for zone_name, start, end in spectral_cuts:
    for e in reg_vet['energy']:
        ef = float(e)
        if start <= ef <= end:
            energy_to_zone_reg[e] = zone_name
reg_vet['Zone'] = reg_vet['energy'].map(energy_to_zone_reg)
reg_vet_unique_df = reg_vet.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
reg_vet_unique_df = reg_vet_unique_df.sort_values(by='Abs_Reg_coef', ascending=False).reset_index(drop=True)

# %%
shap_global_importance = pd.read_csv('shap_milk.csv', sep=';') # loading previously saved shap_unique_df

# vamos gerar uma nova coluna em shap_global_importance com o nome da zona espectral correspondente de acordo com a lista spectral_cuts
energy_to_zone_shap = {}
for zone_name, start, end in spectral_cuts:
    for i in shap_global_importance['energy']:
        i_float = float(i)
        if start <= i_float <= end:
            energy_to_zone_shap[i] = zone_name
shap_global_importance['Zone'] = shap_global_importance['energy'].map(energy_to_zone_shap)

# agora vamos filtrar shap_global_importance para manter apenas as zonas espectrais únicas com maior SHAP score
shap_unique_df = shap_global_importance.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
shap_unique_df = shap_unique_df.sort_values(by='Mean_Abs_SHAP', ascending=False).reset_index(drop=True)
shap_unique_df
# Out:
#    energy  Mean_Abs_SHAP            Zone
# 0    2.99       0.036791           Ag La
# 1   22.23       0.027351           Ag ka
# 2    3.22       0.013527           Ag Lb
# 3    6.35       0.001931              Fe
# 4    8.73       0.001928              Zn
# 5   21.41       0.001883      Ag compton
# 6   18.45       0.001269  Bremsstrahlung
# 7    3.74       0.000263              Ca
# 8    8.24       0.000252              Cu
# 9    4.84       0.000161      background

# %% [markdown]
# ## Funções de Agregação por PCA
#
# Aqui implementamos as funções para agregar zonas espectrais usando PCA com 1 componente principal.

# %%
import explaining as exp

# Extração das zonas espectrais
spectral_zones_class = exp.extract_spectral_zones(Xcalclass_prep, spectral_cuts)
zone_scores_df, pca_info_dict = exp.aggregate_spectral_zones_pca(spectral_zones_class) # apca aggregation
print(f"\nScores DataFrame shape: {zone_scores_df.shape}")
# Out:
# Zone 'Ag La': VE = 84.62%, dim = 18 variables
# Zone 'Ag Lb': VE = 86.51%, dim = 15 variables
# Zone 'Ca': VE = 21.64%, dim = 19 variables
# Zone 'background': VE = 3.44%, dim = 87 variables
# Zone 'Fe': VE = 12.88%, dim = 23 variables
# Zone 'Cu': VE = 9.26%, dim = 66 variables
# Zone 'Zn': VE = 17.17%, dim = 29 variables
# Zone 'Bremsstrahlung': VE = 30.64%, dim = 429 variables
# Zone 'Ag compton': VE = 52.31%, dim = 62 variables
# Zone 'Ag ka': VE = 76.93%, dim = 45 variables
#
# Scores DataFrame shape: (268, 10)

# %%
predicates_quantiles = exp.predicates_by_quantiles(zone_scores_df, [0.2, 0.4, 0.6, 0.8])
predicate_info_dict = exp.create_predicate_info_dict(
    predicates_df=predicates_quantiles[0],
    predicate_indicator_df=predicates_quantiles[1],
    zone_aggregated_df=zone_scores_df,
    y_predicted_numeric=y_pred_cont
)

# %%
import explaining as exp

# LISTA DE SEMENTES A TESTAR
random_seeds = [0, 1, 2, 3]

all_results_cov = {}
training_samples = len(Xcalclass)

# LOOP: PROCESSAR CADA SEMENTE
y_pred_conticted_numeric = pd.Series(y_pred_cont) # predições numéricas do modelo

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando semente: {seed}")
    print(f"{'='*70}\n")
    # Bagging
    bags_result_seed = exp.bagging_predicates(
        zone_sums_df=zone_scores_df,
        y_predicted_numeric=y_pred_conticted_numeric,
        predicates_df=predicates_quantiles[0],
        n_bags=10,
        #n_predicates_per_bag=40,
        n_samples_per_bag=int(training_samples*0.8), # 80 % da base para amostrar (convertido para int)
        min_samples_per_predicate=int(training_samples*0.2), # 20 % da base para limitar (convertido para int)
        replace=False,
        sample_bagging=True,
        predicate_bagging=False,
        random_seed=seed
    )
    
    # Inserir classe prevista
    for bag_name, pred_dict in bags_result_seed.items(): # iterando sobre cada bag
        for pred_rule, df_info in pred_dict.items():
            df_info['Class_Predicted'] = np.where(df_info['Predicted_Y'] >= 0.5, 'A', 'B') # binarizando com threshold 0.5, A = eut, B = dist
    
    # Calcular MI
    cov_results_dict_seed = exp.calculate_predicate_metrics(
        bags_result=bags_result_seed,
        metric='covariance', # covariance ou mutual_information
        threshold=0.01, # threshold para cortar predicados irrelevantes
        n_neighbors=5
    )
    
    # Salvar no dicionário principal
    all_results_cov[seed] = {
        'bags_result': bags_result_seed,
        'cov_results_dict': cov_results_dict_seed
    }

# CONSTRUÇÃO DE GRAFOS PARA MÚLTIPLAS SEMENTES (LOOP EXTERNO)
# Dicionário para armazenar grafos
graphs_by_seed = {}

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando Grafo - Semente: {seed}")
    print(f"{'='*70}\n")
    
    # Construir grafo para esta semente (sem predicates_df - extraído da regra)
    DG = exp.build_predicate_graph(
        bags_result=all_results_cov[seed]['bags_result'],
        predicate_ranking_dict=all_results_cov[seed]['cov_results_dict'],
        metric_column='Covariance',
        random_state=seed,
        show_details=True,
        var_exp=True,
        pca_info_dict=pca_info_dict
    )
    # Armazenar grafo
    graphs_by_seed[seed] = DG

# Calcular LRC usando a função pronta do explaining.py
lrc_cov_by_seed = {}
for seed in random_seeds:
    DG = graphs_by_seed[seed]
    lrc_cov_df_seed = exp.calculate_lrc_single_graph(DG, predicates_quantiles[0])
    lrc_cov_df_seed['Seed'] = seed  # Adicionar coluna com a semente
    lrc_cov_by_seed[seed] = lrc_cov_df_seed

# junando todas as colunas 'Node' de lrc_by_seed em um único dataframe
lrc_cov_all_seeds_df = pd.DataFrame()
for seed in random_seeds:
    lrc_cov_df_seed = lrc_cov_by_seed[seed].rename(columns={'Node': f'Predicate_Cov_Seed_{seed}'})
    lrc_cov_all_seeds_df = pd.concat([lrc_cov_all_seeds_df, lrc_cov_df_seed[[f'Predicate_Cov_Seed_{seed}']]], axis=1)

# vamos filtrar lrc_by_seed em cada semente para manter apenas as zonas espectrais únicas com maior LRC em um mesmo dataframe
lrc_cov_unique_by_seed = {}
for seed, lrc_df in lrc_cov_by_seed.items():
    lrc_cov_unique_df = lrc_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
    lrc_cov_unique_df = lrc_cov_unique_df.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
    lrc_cov_unique_by_seed[seed] = lrc_cov_unique_df

lrc_cov_all_seeds_df # exibindo o dataframe consolidado com predicados de todas as sementes
# Out:
# ======================================================================
# Processando semente: 0
# ======================================================================
#
# Bag_1 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_2 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_3 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_4 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_5 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_6 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_7 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_8 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_9 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_10 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Computing Covariance for Predicates
# Metric: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando semente: 1
# ======================================================================
#
# Bag_1 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_2 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_3 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_4 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_5 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_6 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_7 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_8 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_9 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_10 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Computing Covariance for Predicates
# Metric: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando semente: 2
# ======================================================================
#
# Bag_1 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_2 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_3 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_4 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_5 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_6 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_7 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_8 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_9 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_10 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Computing Covariance for Predicates
# Metric: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando semente: 3
# ======================================================================
#
# Bag_1 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_2 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_3 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_4 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_5 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_6 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_7 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_8 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_9 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_10 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Computing Covariance for Predicates
# Metric: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando Grafo - Semente: 0
# ======================================================================
#
#
# Total bidirectional pairs found: 63
# Removed: Ag Lb <= 6.48 -> Ag La <= 2.70 (7.3278) | Kept: Ag La <= 2.70 -> Ag Lb <= 6.48 (9.7642)
# Removed: Ag La <= 2.70 -> Ag La <= 9.01 (7.1221) | Kept: Ag La <= 9.01 -> Ag La <= 2.70 (7.1462)
# Removed: Ag Lb <= 8.04 -> Ag Lb <= 2.36 (4.5792) | Kept: Ag Lb <= 2.36 -> Ag Lb <= 8.04 (18.1425)
# Removed: Bremsstrahlung <= -1.54 -> Ag La > -18.52 (0.2252) | Kept: Ag La > -18.52 -> Bremsstrahlung <= -1.54 (2.4198)
# Removed: Bremsstrahlung <= 9.64 -> Bremsstrahlung <= -1.54 (0.2011) | Kept: Bremsstrahlung <= -1.54 -> Bremsstrahlung <= 9.64 (0.3330)
# Removed: Bremsstrahlung <= -1.54 -> Ag Lb > -15.87 (0.3516) | Kept: Ag Lb > -15.87 -> Bremsstrahlung <= -1.54 (0.4532)
# Removed: Bremsstrahlung <= -1.54 -> Ag compton <= 6.52 (0.1834) | Kept: Ag compton <= 6.52 -> Bremsstrahlung <= -1.54 (0.2839)
# Removed: Ag compton <= 6.52 -> Bremsstrahlung <= 4.15 (0.2270) | Kept: Bremsstrahlung <= 4.15 -> Ag compton <= 6.52 (0.3290)
# Removed: Bremsstrahlung > 4.15 -> Bremsstrahlung <= 9.64 (0.1104) | Kept: Bremsstrahlung <= 9.64 -> Bremsstrahlung > 4.15 (0.1117)
# Removed: Ag ka <= -7.06 -> Ag compton <= 6.52 (0.3067) | Kept: Ag compton <= 6.52 -> Ag ka <= -7.06 (0.4681)
# Removed: Ag ka <= -7.06 -> Ag Lb > -15.87 (0.2987) | Kept: Ag Lb > -15.87 -> Ag ka <= -7.06 (0.4591)
# Removed: Bremsstrahlung > 4.15 -> Ag ka > -7.06 (0.0867) | Kept: Ag ka > -7.06 -> Bremsstrahlung > 4.15 (0.1735)
# Removed: Cu > 0.32 -> Ag ka > -7.06 (0.0083) | Kept: Ag ka > -7.06 -> Cu > 0.32 (0.0966)
# Removed: Ag compton <= 6.52 -> Ag Lb > -15.87 (0.3081) | Kept: Ag Lb > -15.87 -> Ag compton <= 6.52 (0.3871)
# Removed: Bremsstrahlung > -1.54 -> Bremsstrahlung > 4.15 (0.1741) | Kept: Bremsstrahlung > 4.15 -> Bremsstrahlung > -1.54 (0.2810)
# Removed: Ag compton <= 2.96 -> Ag compton <= -1.09 (0.5594) | Kept: Ag compton <= -1.09 -> Ag compton <= 2.96 (0.5678)
# Removed: Ag compton <= -1.09 -> Ag Lb > -15.87 (0.2145) | Kept: Ag Lb > -15.87 -> Ag compton <= -1.09 (0.4528)
# Removed: Bremsstrahlung > -1.54 -> Ag compton <= -1.09 (0.0894) | Kept: Ag compton <= -1.09 -> Bremsstrahlung > -1.54 (0.3071)
# Removed: Ag compton <= 2.96 -> Ag Lb > -15.87 (0.2090) | Kept: Ag Lb > -15.87 -> Ag compton <= 2.96 (0.3115)
# Removed: Bremsstrahlung > -9.06 -> Ag compton <= 2.96 (0.1410) | Kept: Ag compton <= 2.96 -> Bremsstrahlung > -9.06 (0.7216)
# Removed: Ag compton <= 2.96 -> Ag ka <= 20.95 (0.1294) | Kept: Ag ka <= 20.95 -> Ag compton <= 2.96 (0.1996)
# Removed: Bremsstrahlung > -1.54 -> Ag compton > 2.96 (0.0638) | Kept: Ag compton > 2.96 -> Bremsstrahlung > -1.54 (0.1015)
# Removed: Ag ka > -11.59 -> Ag compton > -1.09 (0.1723) | Kept: Ag compton > -1.09 -> Ag ka > -11.59 (0.2871)
# Removed: Ag ka <= 5.37 -> Ag compton > -1.09 (0.2035) | Kept: Ag compton > -1.09 -> Ag ka <= 5.37 (0.2585)
# Removed: Ag compton > 2.96 -> Ag ka > -11.59 (0.0949) | Kept: Ag ka > -11.59 -> Ag compton > 2.96 (0.1543)
# Removed: Ag La > 2.70 -> Ag compton > 2.96 (0.1468) | Kept: Ag compton > 2.96 -> Ag La > 2.70 (0.2554)
# Removed: Ag compton > 2.96 -> Ag ka <= 20.95 (0.1013) | Kept: Ag ka <= 20.95 -> Ag compton > 2.96 (0.2394)
# Removed: Ag ka > 5.37 -> Ag La > 2.70 (0.1420) | Kept: Ag La > 2.70 -> Ag ka > 5.37 (0.1527)
# Removed: Ag Lb > 2.36 -> Ag La > 2.70 (0.1241) | Kept: Ag La > 2.70 -> Ag Lb > 2.36 (0.2362)
# Removed: Ag La > 2.70 -> Ag ka <= 20.95 (0.1307) | Kept: Ag ka <= 20.95 -> Ag La > 2.70 (0.1477)
# Removed: Cu > 0.32 -> Ag ka > 5.37 (0.0133) | Kept: Ag ka > 5.37 -> Cu > 0.32 (0.2060)
# Removed: Cu > 0.32 -> Ag Lb > 2.36 (0.0363) | Kept: Ag Lb > 2.36 -> Cu > 0.32 (0.2265)
# Removed: Cu > 0.32 -> Ca > -1.79 (0.0199) | Kept: Ca > -1.79 -> Cu > 0.32 (0.0200)
# Removed: Ca <= -0.68 -> Ag Lb > 2.36 (0.0271) | Kept: Ag Lb > 2.36 -> Ca <= -0.68 (0.3403)
# Removed: Zn > -1.47 -> Cu <= 1.92 (0.0074) | Kept: Cu <= 1.92 -> Zn > -1.47 (0.0083)
# Removed: Cu <= 1.92 -> Ca > -0.68 (0.0060) | Kept: Ca > -0.68 -> Cu <= 1.92 (0.0096)
# Removed: background > -1.23 -> Cu <= 1.92 (0.0010) | Kept: Cu <= 1.92 -> background > -1.23 (0.0051)
# Removed: Cu <= 1.92 -> Fe <= 1.20 (0.0030) | Kept: Fe <= 1.20 -> Cu <= 1.92 (0.0091)
# Removed: background <= 0.40 -> Cu <= 1.92 (0.0020) | Kept: Cu <= 1.92 -> background <= 0.40 (0.0062)
# Removed: Ag ka <= 5.37 -> Ag ka <= 20.95 (0.1358) | Kept: Ag ka <= 20.95 -> Ag ka <= 5.37 (0.1844)
# Removed: Cu > -1.74 -> Zn <= 1.56 (0.0065) | Kept: Zn <= 1.56 -> Cu > -1.74 (0.0088)
# Removed: Cu > -1.74 -> Zn > 0.56 (0.0068) | Kept: Zn > 0.56 -> Cu > -1.74 (0.0131)
# Removed: Cu > -1.74 -> Ca > 0.46 (0.0060) | Kept: Ca > 0.46 -> Cu > -1.74 (0.0171)
# Removed: Cu > -0.64 -> Fe <= 1.20 (0.0064) | Kept: Fe <= 1.20 -> Cu > -0.64 (0.0068)
# Removed: Fe > -1.18 -> Zn > 0.56 (0.0084) | Kept: Zn > 0.56 -> Fe > -1.18 (0.0390)
# Removed: Fe > -1.18 -> Ca > -1.79 (0.0093) | Kept: Ca > -1.79 -> Fe > -1.18 (0.0199)
# Removed: Fe > -1.18 -> Zn <= 1.56 (0.0108) | Kept: Zn <= 1.56 -> Fe > -1.18 (0.0124)
# Removed: Zn <= 1.56 -> Ca <= 0.46 (0.0085) | Kept: Ca <= 0.46 -> Zn <= 1.56 (0.0176)
# Removed: Fe > -0.36 -> Ca > -1.79 (0.0074) | Kept: Ca > -1.79 -> Fe > -0.36 (0.0116)
# Removed: background <= 1.29 -> Fe > -0.36 (0.0020) | Kept: Fe > -0.36 -> background <= 1.29 (0.0156)
# Removed: background > -1.23 -> Fe <= 1.20 (0.0019) | Kept: Fe <= 1.20 -> background > -1.23 (0.0059)
# Removed: Ca <= 0.46 -> Ca <= 1.81 (0.0162) | Kept: Ca <= 1.81 -> Ca <= 0.46 (0.0166)
# Removed: background <= -0.46 -> Zn > -0.39 (0.0012) | Kept: Zn > -0.39 -> background <= -0.46 (0.0035)
# Removed: background <= -0.46 -> Fe <= 0.31 (0.0011) | Kept: Fe <= 0.31 -> background <= -0.46 (0.0061)
# Removed: Fe > 0.31 -> Ag Lb > 6.48 (0.0060) | Kept: Ag Lb > 6.48 -> Fe > 0.31 (0.0389)
# Removed: background > 0.40 -> Ca > 0.46 (0.0011) | Kept: Ca > 0.46 -> background > 0.40 (0.0124)
# Removed: background > 0.40 -> Ag La > 7.76 (0.0008) | Kept: Ag La > 7.76 -> background > 0.40 (0.0260)
# Removed: background > -0.46 -> background > 0.40 (0.0020) | Kept: background > 0.40 -> background > -0.46 (0.0032)
# Removed: background > -0.46 -> Zn > -0.39 (0.0010) | Kept: Zn > -0.39 -> background > -0.46 (0.0138)
# Removed: background > -0.46 -> Fe <= 0.31 (0.0013) | Kept: Fe <= 0.31 -> background > -0.46 (0.0031)
# Removed: Ca > -0.68 -> Zn > -0.39 (0.0055) | Kept: Zn > -0.39 -> Ca > -0.68 (0.0060)
# Removed: Fe <= -0.36 -> Fe <= 0.31 (0.0028) | Kept: Fe <= 0.31 -> Fe <= -0.36 (0.0081)
# Removed: Zn <= -0.39 -> Zn > -1.47 (0.0051) | Kept: Zn > -1.47 -> Zn <= -0.39 (0.0076)
#
# ======================================================================
# CONSTRUCTED GRAPH SUMMARY
# ======================================================================
# Initial edges: 426 | Removed: 63
# Predicate nodes: 60
# Metric: Covariance
# Weighting by explained variance: ENABLED
#
# ======================================================================
# Processando Grafo - Semente: 1
# ======================================================================
#
#
# Total bidirectional pairs found: 67
# Removed: Ag Lb <= 6.48 -> Ag La <= 2.70 (4.7512) | Kept: Ag La <= 2.70 -> Ag Lb <= 6.48 (14.7649)
# Removed: Ag La <= 2.70 -> Ag La <= 9.01 (2.2243) | Kept: Ag La <= 9.01 -> Ag La <= 2.70 (4.6632)
# Removed: Ag Lb <= 2.36 -> Ag La <= 9.01 (6.9123) | Kept: Ag La <= 9.01 -> Ag Lb <= 2.36 (11.3669)
# Removed: Ag Lb <= 8.04 -> Ag Lb <= 2.36 (4.5357) | Kept: Ag Lb <= 2.36 -> Ag Lb <= 8.04 (11.2171)
# Removed: Bremsstrahlung <= -1.54 -> Ag La > -18.52 (0.4963) | Kept: Ag La > -18.52 -> Bremsstrahlung <= -1.54 (1.6499)
# Removed: Bremsstrahlung <= -1.54 -> Bremsstrahlung <= 9.64 (0.3163) | Kept: Bremsstrahlung <= 9.64 -> Bremsstrahlung <= -1.54 (0.3421)
# Removed: Bremsstrahlung <= 4.15 -> Ag La > -18.52 (0.4053) | Kept: Ag La > -18.52 -> Bremsstrahlung <= 4.15 (1.2094)
# Removed: Ag ka <= -7.06 -> Ag La > -18.52 (0.5165) | Kept: Ag La > -18.52 -> Ag ka <= -7.06 (1.3569)
# Removed: Bremsstrahlung <= 9.64 -> Bremsstrahlung <= 4.15 (0.2309) | Kept: Bremsstrahlung <= 4.15 -> Bremsstrahlung <= 9.64 (0.3622)
# Removed: Ag ka > 5.37 -> Bremsstrahlung <= 4.15 (0.5384) | Kept: Bremsstrahlung <= 4.15 -> Ag ka > 5.37 (0.5746)
# Removed: Ag compton <= 6.52 -> Bremsstrahlung <= 9.64 (0.5245) | Kept: Bremsstrahlung <= 9.64 -> Ag compton <= 6.52 (0.5981)
# Removed: Ag compton <= 6.52 -> Ag Lb > -15.87 (0.5152) | Kept: Ag Lb > -15.87 -> Ag compton <= 6.52 (1.2612)
# Removed: Ag ka > -11.59 -> Ag compton <= 6.52 (0.4319) | Kept: Ag compton <= 6.52 -> Ag ka > -11.59 (0.4807)
# Removed: Ag compton <= 6.52 -> Ag ka > 5.37 (0.2244) | Kept: Ag ka > 5.37 -> Ag compton <= 6.52 (0.4969)
# Removed: Bremsstrahlung > 4.15 -> Ag compton <= 2.96 (0.1118) | Kept: Ag compton <= 2.96 -> Bremsstrahlung > 4.15 (0.4426)
# Removed: Bremsstrahlung > -9.06 -> Bremsstrahlung > 4.15 (0.1920) | Kept: Bremsstrahlung > 4.15 -> Bremsstrahlung > -9.06 (0.2254)
# Removed: Bremsstrahlung > 4.15 -> Ag ka > 5.37 (0.1109) | Kept: Ag ka > 5.37 -> Bremsstrahlung > 4.15 (0.3138)
# Removed: Ag compton > 2.96 -> Ag ka > -7.06 (0.0500) | Kept: Ag ka > -7.06 -> Ag compton > 2.96 (0.2579)
# Removed: Ag compton <= 2.96 -> Ag compton <= -1.09 (0.3497) | Kept: Ag compton <= -1.09 -> Ag compton <= 2.96 (1.0967)
# Removed: Ag ka > 5.37 -> Ag compton <= -1.09 (0.3127) | Kept: Ag compton <= -1.09 -> Ag ka > 5.37 (0.3850)
# Removed: Ag compton > -6.71 -> Ag compton <= -1.09 (0.1457) | Kept: Ag compton <= -1.09 -> Ag compton > -6.71 (0.3205)
# Removed: Ag compton <= 2.96 -> Bremsstrahlung > -1.54 (0.1834) | Kept: Bremsstrahlung > -1.54 -> Ag compton <= 2.96 (0.2091)
# Removed: Ag Lb > 2.36 -> Ag ka <= 5.37 (0.0975) | Kept: Ag ka <= 5.37 -> Ag Lb > 2.36 (0.1206)
# Removed: Bremsstrahlung > -1.54 -> Bremsstrahlung > -9.06 (0.1725) | Kept: Bremsstrahlung > -9.06 -> Bremsstrahlung > -1.54 (0.2400)
# Removed: Bremsstrahlung > -1.54 -> Ag ka > -11.59 (0.0612) | Kept: Ag ka > -11.59 -> Bremsstrahlung > -1.54 (0.2021)
# Removed: Bremsstrahlung > -9.06 -> Ag ka <= 20.95 (0.0908) | Kept: Ag ka <= 20.95 -> Bremsstrahlung > -9.06 (0.3436)
# Removed: Bremsstrahlung > -9.06 -> Ag compton > -1.09 (0.0770) | Kept: Ag compton > -1.09 -> Bremsstrahlung > -9.06 (0.1561)
# Removed: Bremsstrahlung > -9.06 -> Ag ka > 5.37 (0.1272) | Kept: Ag ka > 5.37 -> Bremsstrahlung > -9.06 (0.3795)
# Removed: Ag ka <= 20.95 -> Ag compton > -1.09 (0.2040) | Kept: Ag compton > -1.09 -> Ag ka <= 20.95 (0.2562)
# Removed: Ag ka <= 20.95 -> Ag La > 2.70 (0.1588) | Kept: Ag La > 2.70 -> Ag ka <= 20.95 (0.2389)
# Removed: Ag compton > -1.09 -> Ag compton > -6.71 (0.2621) | Kept: Ag compton > -6.71 -> Ag compton > -1.09 (0.8539)
# Removed: Ag compton > -6.71 -> Ag ka > -11.59 (0.1250) | Kept: Ag ka > -11.59 -> Ag compton > -6.71 (0.2152)
# Removed: Ag ka > -11.59 -> Ag ka > 5.37 (0.1505) | Kept: Ag ka > 5.37 -> Ag ka > -11.59 (0.2060)
# Removed: Ag Lb > 2.36 -> Ag compton > 2.96 (0.1385) | Kept: Ag compton > 2.96 -> Ag Lb > 2.36 (0.2582)
# Removed: Ag La > 2.70 -> Ag Lb > 2.36 (0.1330) | Kept: Ag Lb > 2.36 -> Ag La > 2.70 (0.5060)
# Removed: Zn > 0.56 -> Ca <= -0.68 (0.0155) | Kept: Ca <= -0.68 -> Zn > 0.56 (0.0208)
# Removed: Fe > -1.18 -> Fe > -0.36 (0.0127) | Kept: Fe > -0.36 -> Fe > -1.18 (0.0192)
# Removed: Fe > -1.18 -> Ca > 0.46 (0.0167) | Kept: Ca > 0.46 -> Fe > -1.18 (0.0192)
# Removed: Fe > -1.18 -> Zn > 0.56 (0.0117) | Kept: Zn > 0.56 -> Fe > -1.18 (0.0138)
# Removed: Ca > -1.79 -> Fe > -1.18 (0.0221) | Kept: Fe > -1.18 -> Ca > -1.79 (0.0294)
# Removed: Zn > 0.56 -> Fe > -0.36 (0.0116) | Kept: Fe > -0.36 -> Zn > 0.56 (0.0294)
# Removed: Ca > -1.79 -> Zn > 0.56 (0.0199) | Kept: Zn > 0.56 -> Ca > -1.79 (0.0474)
# Removed: Ca > 0.46 -> Ca > -1.79 (0.0240) | Kept: Ca > -1.79 -> Ca > 0.46 (0.0370)
# Removed: background > -1.23 -> Ca > -0.68 (0.0014) | Kept: Ca > -0.68 -> background > -1.23 (0.0099)
# Removed: Ca > -0.68 -> Ca <= 0.46 (0.0108) | Kept: Ca <= 0.46 -> Ca > -0.68 (0.0149)
# Removed: Cu > -0.64 -> Fe <= 1.20 (0.0061) | Kept: Fe <= 1.20 -> Cu > -0.64 (0.0077)
# Removed: background <= 0.40 -> Cu > -0.64 (0.0023) | Kept: Cu > -0.64 -> background <= 0.40 (0.0107)
# Removed: Cu > -0.64 -> Cu > -1.74 (0.0123) | Kept: Cu > -1.74 -> Cu > -0.64 (0.0141)
# Removed: Fe > 0.31 -> Zn > -0.39 (0.0082) | Kept: Zn > -0.39 -> Fe > 0.31 (0.0150)
# Removed: Fe > 0.31 -> Cu <= 1.92 (0.0046) | Kept: Cu <= 1.92 -> Fe > 0.31 (0.0054)
# Removed: background <= 1.29 -> Zn > -0.39 (0.0017) | Kept: Zn > -0.39 -> background <= 1.29 (0.0112)
# Removed: Zn > -0.39 -> Fe <= 1.20 (0.0059) | Kept: Fe <= 1.20 -> Zn > -0.39 (0.0064)
# Removed: background <= 1.29 -> Zn <= 1.56 (0.0022) | Kept: Zn <= 1.56 -> background <= 1.29 (0.0212)
# Removed: Fe <= 0.31 -> Zn <= 1.56 (0.0031) | Kept: Zn <= 1.56 -> Fe <= 0.31 (0.0056)
# Removed: background > -1.23 -> Zn > -1.47 (0.0032) | Kept: Zn > -1.47 -> background > -1.23 (0.0101)
# Removed: background > -1.23 -> Zn <= -0.39 (0.0018) | Kept: Zn <= -0.39 -> background > -1.23 (0.0106)
# Removed: background > -1.23 -> Ca <= 0.46 (0.0026) | Kept: Ca <= 0.46 -> background > -1.23 (0.0119)
# Removed: background > -0.46 -> Fe <= 1.20 (0.0036) | Kept: Fe <= 1.20 -> background > -0.46 (0.0050)
# Removed: background > 0.40 -> Ca <= 0.46 (0.0015) | Kept: Ca <= 0.46 -> background > 0.40 (0.0105)
# Removed: background > 0.40 -> background <= -0.46 (0.0007) | Kept: background <= -0.46 -> background > 0.40 (0.0009)
# Removed: Ca <= 1.81 -> Ag Lb > 6.48 (0.0101) | Kept: Ag Lb > 6.48 -> Ca <= 1.81 (0.0507)
# Removed: Zn > -1.47 -> Ag Lb > 6.48 (0.0083) | Kept: Ag Lb > 6.48 -> Zn > -1.47 (0.0399)
# Removed: background <= -0.46 -> Cu <= 1.92 (0.0013) | Kept: Cu <= 1.92 -> background <= -0.46 (0.0030)
# Removed: Cu <= -0.64 -> Fe <= 0.31 (0.0045) | Kept: Fe <= 0.31 -> Cu <= -0.64 (0.0067)
# Removed: Cu <= -0.64 -> Cu <= 0.32 (0.0011) | Kept: Cu <= 0.32 -> Cu <= -0.64 (0.0018)
# Removed: Fe <= -0.36 -> Cu <= -0.64 (0.0045) | Kept: Cu <= -0.64 -> Fe <= -0.36 (0.0046)
# Removed: Fe <= -0.36 -> Ag La > 7.76 (0.0042) | Kept: Ag La > 7.76 -> Fe <= -0.36 (0.0317)
#
# ======================================================================
# CONSTRUCTED GRAPH SUMMARY
# ======================================================================
# Initial edges: 409 | Removed: 67
# Predicate nodes: 60
# Metric: Covariance
# Weighting by explained variance: ENABLED
#
# ======================================================================
# Processando Grafo - Semente: 2
# ======================================================================
#
#
# Total bidirectional pairs found: 67
# Removed: Ag Lb <= 6.48 -> Ag La <= 2.70 (5.0678) | Kept: Ag La <= 2.70 -> Ag Lb <= 6.48 (12.5398)
# Removed: Ag La <= 9.01 -> Ag La <= 2.70 (4.7469) | Kept: Ag La <= 2.70 -> Ag La <= 9.01 (4.8833)
# Removed: Ag La <= 9.01 -> Ag Lb <= 2.36 (2.2910) | Kept: Ag Lb <= 2.36 -> Ag La <= 9.01 (9.5021)
# Removed: Ag Lb <= 8.04 -> Ag La <= 2.70 (2.2696) | Kept: Ag La <= 2.70 -> Ag Lb <= 8.04 (4.4925)
# Removed: Ag Lb <= 2.36 -> Ag Lb <= 8.04 (2.2637) | Kept: Ag Lb <= 8.04 -> Ag Lb <= 2.36 (9.1491)
# Removed: Bremsstrahlung > -9.06 -> Ag ka <= -7.06 (0.1806) | Kept: Ag ka <= -7.06 -> Bremsstrahlung > -9.06 (0.2916)
# Removed: Bremsstrahlung <= -1.54 -> Ag La > -18.52 (0.3916) | Kept: Ag La > -18.52 -> Bremsstrahlung <= -1.54 (1.8629)
# Removed: Ag ka > 5.37 -> Ag La > -18.52 (0.5282) | Kept: Ag La > -18.52 -> Ag ka > 5.37 (0.5881)
# Removed: Bremsstrahlung <= 4.15 -> Bremsstrahlung <= -1.54 (0.1764) | Kept: Bremsstrahlung <= -1.54 -> Bremsstrahlung <= 4.15 (0.3806)
# Removed: Bremsstrahlung <= 9.64 -> Bremsstrahlung <= 4.15 (0.1245) | Kept: Bremsstrahlung <= 4.15 -> Bremsstrahlung <= 9.64 (1.1071)
# Removed: Ag compton <= 6.52 -> Bremsstrahlung <= -1.54 (0.2805) | Kept: Bremsstrahlung <= -1.54 -> Ag compton <= 6.52 (0.3550)
# Removed: Bremsstrahlung > 4.15 -> Ag compton <= 6.52 (0.1596) | Kept: Ag compton <= 6.52 -> Bremsstrahlung > 4.15 (0.2020)
# Removed: Ag compton <= 6.52 -> Ag Lb > -15.87 (0.2309) | Kept: Ag Lb > -15.87 -> Ag compton <= 6.52 (0.3328)
# Removed: Bremsstrahlung <= 9.64 -> Ag Lb > -15.87 (0.1665) | Kept: Ag Lb > -15.87 -> Bremsstrahlung <= 9.64 (0.4362)
# Removed: Ag ka > -11.59 -> Ag ka <= 5.37 (0.1397) | Kept: Ag ka <= 5.37 -> Ag ka > -11.59 (0.2065)
# Removed: Ag compton <= -1.09 -> Ag Lb > -15.87 (0.2036) | Kept: Ag Lb > -15.87 -> Ag compton <= -1.09 (0.7705)
# Removed: Ag compton <= 2.96 -> Ag Lb > -15.87 (0.1743) | Kept: Ag Lb > -15.87 -> Ag compton <= 2.96 (0.3384)
# Removed: Bremsstrahlung > 4.15 -> Ag Lb > -15.87 (0.1250) | Kept: Ag Lb > -15.87 -> Bremsstrahlung > 4.15 (0.8843)
# Removed: Ag compton > 2.96 -> Ag ka <= 5.37 (0.1261) | Kept: Ag ka <= 5.37 -> Ag compton > 2.96 (0.1448)
# Removed: Fe <= -0.36 -> Ag ka <= 5.37 (0.0043) | Kept: Ag ka <= 5.37 -> Fe <= -0.36 (0.0206)
# Removed: Bremsstrahlung > -9.06 -> Ag compton <= -1.09 (0.1016) | Kept: Ag compton <= -1.09 -> Bremsstrahlung > -9.06 (0.3876)
# Removed: Bremsstrahlung > 4.15 -> Ag compton > -6.71 (0.1153) | Kept: Ag compton > -6.71 -> Bremsstrahlung > 4.15 (0.2145)
# Removed: Ag compton <= 2.96 -> Ag compton > -6.71 (0.3152) | Kept: Ag compton > -6.71 -> Ag compton <= 2.96 (0.3721)
# Removed: Ag compton > -6.71 -> Bremsstrahlung > -1.54 (0.1201) | Kept: Bremsstrahlung > -1.54 -> Ag compton > -6.71 (0.2700)
# Removed: Ag compton <= 2.96 -> Ag compton > -1.09 (0.1820) | Kept: Ag compton > -1.09 -> Ag compton <= 2.96 (0.3511)
# Removed: Ag compton <= -1.09 -> Ag ka <= 20.95 (0.1512) | Kept: Ag ka <= 20.95 -> Ag compton <= -1.09 (0.2717)
# Removed: Ag ka > 5.37 -> Ag La > 2.70 (0.1366) | Kept: Ag La > 2.70 -> Ag ka > 5.37 (0.1469)
# Removed: Cu > 0.32 -> Ag La > 2.70 (0.0127) | Kept: Ag La > 2.70 -> Cu > 0.32 (0.2467)
# Removed: Ag ka > 5.37 -> Ag compton > 2.96 (0.1186) | Kept: Ag compton > 2.96 -> Ag ka > 5.37 (0.1558)
# Removed: Cu > 0.32 -> Ag compton > 2.96 (0.0132) | Kept: Ag compton > 2.96 -> Cu > 0.32 (0.0703)
# Removed: Cu > 0.32 -> Ag Lb > 2.36 (0.0111) | Kept: Ag Lb > 2.36 -> Cu > 0.32 (0.2646)
# Removed: Ag Lb > 2.36 -> Ag ka <= 20.95 (0.1105) | Kept: Ag ka <= 20.95 -> Ag Lb > 2.36 (0.3843)
# Removed: Cu > 0.32 -> Ca <= -0.68 (0.0126) | Kept: Ca <= -0.68 -> Cu > 0.32 (0.0689)
# Removed: Zn > 0.56 -> Ca <= -0.68 (0.0187) | Kept: Ca <= -0.68 -> Zn > 0.56 (0.0444)
# Removed: Zn > 0.56 -> Ag ka > -7.06 (0.0127) | Kept: Ag ka > -7.06 -> Zn > 0.56 (0.0579)
# Removed: Ca > -1.79 -> Ca <= -0.68 (0.0203) | Kept: Ca <= -0.68 -> Ca > -1.79 (0.0222)
# Removed: Fe > -0.36 -> Ca > -1.79 (0.0109) | Kept: Ca > -1.79 -> Fe > -0.36 (0.0128)
# Removed: Fe > -1.18 -> Ca > -0.68 (0.0112) | Kept: Ca > -0.68 -> Fe > -1.18 (0.0152)
# Removed: Fe > -1.18 -> Fe > -0.36 (0.0212) | Kept: Fe > -0.36 -> Fe > -1.18 (0.0220)
# Removed: Ca <= 1.81 -> Zn > -0.39 (0.0131) | Kept: Zn > -0.39 -> Ca <= 1.81 (0.0191)
# Removed: Fe > 0.31 -> Zn > -0.39 (0.0035) | Kept: Zn > -0.39 -> Fe > 0.31 (0.0103)
# Removed: Zn > -1.47 -> Ca > 0.46 (0.0062) | Kept: Ca > 0.46 -> Zn > -1.47 (0.0169)
# Removed: Ca > -0.68 -> Zn > -1.47 (0.0081) | Kept: Zn > -1.47 -> Ca > -0.68 (0.0127)
# Removed: Zn > -1.47 -> Zn <= 1.56 (0.0070) | Kept: Zn <= 1.56 -> Zn > -1.47 (0.0253)
# Removed: Ca > -0.68 -> Ca <= 0.46 (0.0167) | Kept: Ca <= 0.46 -> Ca > -0.68 (0.0279)
# Removed: background > -1.23 -> Ca > -0.68 (0.0019) | Kept: Ca > -0.68 -> background > -1.23 (0.0140)
# Removed: background <= 1.29 -> Fe > 0.31 (0.0039) | Kept: Fe > 0.31 -> background <= 1.29 (0.0052)
# Removed: background <= 1.29 -> Cu > -0.64 (0.0025) | Kept: Cu > -0.64 -> background <= 1.29 (0.0035)
# Removed: background <= 1.29 -> Zn <= 1.56 (0.0045) | Kept: Zn <= 1.56 -> background <= 1.29 (0.0096)
# Removed: Ca <= 1.81 -> Ag Lb > 6.48 (0.0119) | Kept: Ag Lb > 6.48 -> Ca <= 1.81 (0.0689)
# Removed: Cu > -0.64 -> Fe > -0.36 (0.0082) | Kept: Fe > -0.36 -> Cu > -0.64 (0.0092)
# Removed: background <= 0.40 -> Fe > -0.36 (0.0021) | Kept: Fe > -0.36 -> background <= 0.40 (0.0073)
# Removed: background > 0.40 -> Cu <= 1.92 (0.0018) | Kept: Cu <= 1.92 -> background > 0.40 (0.0055)
# Removed: Cu <= 1.92 -> Fe > 0.31 (0.0048) | Kept: Fe > 0.31 -> Cu <= 1.92 (0.0068)
# Removed: background > -1.23 -> Cu > -1.74 (0.0022) | Kept: Cu > -1.74 -> background > -1.23 (0.0082)
# Removed: background > -1.23 -> Fe <= 1.20 (0.0016) | Kept: Fe <= 1.20 -> background > -1.23 (0.0128)
# Removed: Fe <= 1.20 -> Fe > 0.31 (0.0114) | Kept: Fe > 0.31 -> Fe <= 1.20 (0.0200)
# Removed: background > -0.46 -> Fe <= 1.20 (0.0016) | Kept: Fe <= 1.20 -> background > -0.46 (0.0058)
# Removed: background > -0.46 -> Ag Lb > 6.48 (0.0012) | Kept: Ag Lb > 6.48 -> background > -0.46 (0.0417)
# Removed: Cu <= -0.64 -> Zn <= -0.39 (0.0028) | Kept: Zn <= -0.39 -> Cu <= -0.64 (0.0046)
# Removed: Cu <= -0.64 -> Fe <= -0.36 (0.0024) | Kept: Fe <= -0.36 -> Cu <= -0.64 (0.0026)
# Removed: background <= -0.46 -> Cu <= -0.64 (0.0012) | Kept: Cu <= -0.64 -> background <= -0.46 (0.0017)
# Removed: background > 0.40 -> Fe <= 0.31 (0.0006) | Kept: Fe <= 0.31 -> background > 0.40 (0.0026)
# Removed: background <= -0.46 -> Zn <= 0.56 (0.0010) | Kept: Zn <= 0.56 -> background <= -0.46 (0.0192)
# Removed: background > -0.46 -> Zn <= 0.56 (0.0011) | Kept: Zn <= 0.56 -> background > -0.46 (0.0049)
# Removed: Fe <= 0.31 -> Zn <= 0.56 (0.0022) | Kept: Zn <= 0.56 -> Fe <= 0.31 (0.0044)
# Removed: Fe <= 0.31 -> Fe <= -0.36 (0.0022) | Kept: Fe <= -0.36 -> Fe <= 0.31 (0.0029)
#
# ======================================================================
# CONSTRUCTED GRAPH SUMMARY
# ======================================================================
# Initial edges: 415 | Removed: 67
# Predicate nodes: 60
# Metric: Covariance
# Weighting by explained variance: ENABLED
#
# ======================================================================
# Processando Grafo - Semente: 3
# ======================================================================
#
#
# Total bidirectional pairs found: 69
# Removed: Ag Lb <= 6.48 -> Ag La <= 2.70 (4.9762) | Kept: Ag La <= 2.70 -> Ag Lb <= 6.48 (14.8118)
# Removed: Ag La <= 2.70 -> Ag La <= 9.01 (4.8086) | Kept: Ag La <= 9.01 -> Ag La <= 2.70 (4.8410)
# Removed: Ag Lb <= 2.36 -> Ag La <= 9.01 (7.0864) | Kept: Ag La <= 9.01 -> Ag Lb <= 2.36 (9.1352)
# Removed: Ag Lb <= 8.04 -> Ag Lb <= 2.36 (4.6209) | Kept: Ag Lb <= 2.36 -> Ag Lb <= 8.04 (11.3233)
# Removed: Ag La > -18.52 -> Ag ka <= -7.06 (1.2141) | Kept: Ag ka <= -7.06 -> Ag La > -18.52 (1.3058)
# Removed: Bremsstrahlung <= 9.64 -> Ag ka <= -7.06 (0.1382) | Kept: Ag ka <= -7.06 -> Bremsstrahlung <= 9.64 (0.8810)
# Removed: Bremsstrahlung <= -1.54 -> Ag ka <= -7.06 (0.2015) | Kept: Ag ka <= -7.06 -> Bremsstrahlung <= -1.54 (0.4538)
# Removed: Bremsstrahlung <= 4.15 -> Ag Lb > -15.87 (0.3599) | Kept: Ag Lb > -15.87 -> Bremsstrahlung <= 4.15 (0.4405)
# Removed: Bremsstrahlung <= 4.15 -> Ag compton <= 6.52 (0.1202) | Kept: Ag compton <= 6.52 -> Bremsstrahlung <= 4.15 (0.5544)
# Removed: Bremsstrahlung <= -1.54 -> Bremsstrahlung <= 4.15 (0.1659) | Kept: Bremsstrahlung <= 4.15 -> Bremsstrahlung <= -1.54 (0.3145)
# Removed: Bremsstrahlung <= 9.64 -> Bremsstrahlung <= -1.54 (0.1839) | Kept: Bremsstrahlung <= -1.54 -> Bremsstrahlung <= 9.64 (0.3133)
# Removed: Bremsstrahlung <= 9.64 -> Ag ka > 5.37 (0.1552) | Kept: Ag ka > 5.37 -> Bremsstrahlung <= 9.64 (0.4441)
# Removed: Bremsstrahlung <= 9.64 -> Bremsstrahlung > 4.15 (0.1215) | Kept: Bremsstrahlung > 4.15 -> Bremsstrahlung <= 9.64 (0.2699)
# Removed: Bremsstrahlung <= 9.64 -> Ag compton <= 6.52 (0.1677) | Kept: Ag compton <= 6.52 -> Bremsstrahlung <= 9.64 (0.4966)
# Removed: Bremsstrahlung > -9.06 -> Bremsstrahlung <= -1.54 (0.1235) | Kept: Bremsstrahlung <= -1.54 -> Bremsstrahlung > -9.06 (0.1294)
# Removed: Ag compton <= 6.52 -> Ag ka > 5.37 (0.2731) | Kept: Ag ka > 5.37 -> Ag compton <= 6.52 (0.3881)
# Removed: Ag Lb > -15.87 -> Ag ka > 5.37 (0.3205) | Kept: Ag ka > 5.37 -> Ag Lb > -15.87 (0.3235)
# Removed: Bremsstrahlung > 4.15 -> Ag ka > 5.37 (0.0862) | Kept: Ag ka > 5.37 -> Bremsstrahlung > 4.15 (0.3705)
# Removed: Ag compton <= 6.52 -> Ag Lb > -15.87 (0.1951) | Kept: Ag Lb > -15.87 -> Ag compton <= 6.52 (0.9270)
# Removed: Bremsstrahlung > -9.06 -> Ag ka <= 20.95 (0.0756) | Kept: Ag ka <= 20.95 -> Bremsstrahlung > -9.06 (0.2964)
# Removed: Ag compton > -6.71 -> Ag compton > -1.09 (0.1445) | Kept: Ag compton > -1.09 -> Ag compton > -6.71 (0.1490)
# Removed: Ag compton > -6.71 -> Ag ka <= 5.37 (0.1144) | Kept: Ag ka <= 5.37 -> Ag compton > -6.71 (0.2304)
# Removed: Ag compton > -6.71 -> Ag ka > -11.59 (0.1673) | Kept: Ag ka > -11.59 -> Ag compton > -6.71 (0.2328)
# Removed: Bremsstrahlung > 4.15 -> Ag ka > -11.59 (0.1038) | Kept: Ag ka > -11.59 -> Bremsstrahlung > 4.15 (0.5246)
# Removed: Ag compton > -1.09 -> Bremsstrahlung > -1.54 (0.1425) | Kept: Bremsstrahlung > -1.54 -> Ag compton > -1.09 (0.1625)
# Removed: Ag compton <= 2.96 -> Ag compton > -1.09 (0.1465) | Kept: Ag compton > -1.09 -> Ag compton <= 2.96 (0.3016)
# Removed: Bremsstrahlung > -1.54 -> Ag compton <= -1.09 (0.1200) | Kept: Ag compton <= -1.09 -> Bremsstrahlung > -1.54 (0.1964)
# Removed: Ag compton <= 2.96 -> Ag compton <= -1.09 (0.4628) | Kept: Ag compton <= -1.09 -> Ag compton <= 2.96 (0.5860)
# Removed: Ag ka <= 20.95 -> Ag Lb > 2.36 (0.1164) | Kept: Ag Lb > 2.36 -> Ag ka <= 20.95 (0.2372)
# Removed: Ag Lb > 2.36 -> Ag La > 2.70 (0.2797) | Kept: Ag La > 2.70 -> Ag Lb > 2.36 (0.5862)
# Removed: Cu > 0.32 -> Ag Lb > 2.36 (0.0256) | Kept: Ag Lb > 2.36 -> Cu > 0.32 (0.0989)
# Removed: Ag La > 2.70 -> Ag compton > 2.96 (0.1243) | Kept: Ag compton > 2.96 -> Ag La > 2.70 (0.3379)
# Removed: Cu > 0.32 -> Ag compton > 2.96 (0.0091) | Kept: Ag compton > 2.96 -> Cu > 0.32 (0.0733)
# Removed: Ag compton > 2.96 -> Ag ka <= 20.95 (0.0798) | Kept: Ag ka <= 20.95 -> Ag compton > 2.96 (0.1851)
# Removed: Cu > 0.32 -> Ag La > 2.70 (0.0120) | Kept: Ag La > 2.70 -> Cu > 0.32 (0.3614)
# Removed: Fe > -1.18 -> Zn > 0.56 (0.0103) | Kept: Zn > 0.56 -> Fe > -1.18 (0.0308)
# Removed: Fe > -0.36 -> Zn > 0.56 (0.0187) | Kept: Zn > 0.56 -> Fe > -0.36 (0.0236)
# Removed: Fe > -1.18 -> Ca <= -0.68 (0.0108) | Kept: Ca <= -0.68 -> Fe > -1.18 (0.0374)
# Removed: Fe > -1.18 -> Ca > -1.79 (0.0102) | Kept: Ca > -1.79 -> Fe > -1.18 (0.0590)
# Removed: Cu > -1.74 -> Fe > -1.18 (0.0075) | Kept: Fe > -1.18 -> Cu > -1.74 (0.0129)
# Removed: Cu > -0.64 -> Fe > -0.36 (0.0064) | Kept: Fe > -0.36 -> Cu > -0.64 (0.0170)
# Removed: Cu > -1.74 -> Cu <= 1.92 (0.0059) | Kept: Cu <= 1.92 -> Cu > -1.74 (0.0062)
# Removed: background > 0.40 -> Zn > -1.47 (0.0018) | Kept: Zn > -1.47 -> background > 0.40 (0.0031)
# Removed: Zn > -1.47 -> Ca <= 0.46 (0.0076) | Kept: Ca <= 0.46 -> Zn > -1.47 (0.0105)
# Removed: Cu <= -0.64 -> Ag Lb > 6.48 (0.0043) | Kept: Ag Lb > 6.48 -> Cu <= -0.64 (0.0342)
# Removed: Zn <= 1.56 -> Ca > -1.79 (0.0121) | Kept: Ca > -1.79 -> Zn <= 1.56 (0.0157)
# Removed: background <= 1.29 -> Zn <= 1.56 (0.0041) | Kept: Zn <= 1.56 -> background <= 1.29 (0.0153)
# Removed: Ca > -0.68 -> Ca > -1.79 (0.0204) | Kept: Ca > -1.79 -> Ca > -0.68 (0.0205)
# Removed: Ca > -1.79 -> Ca <= -0.68 (0.0185) | Kept: Ca <= -0.68 -> Ca > -1.79 (0.0202)
# Removed: background <= 0.40 -> Fe <= 1.20 (0.0020) | Kept: Fe <= 1.20 -> background <= 0.40 (0.0141)
# Removed: background > -1.23 -> Fe <= 1.20 (0.0015) | Kept: Fe <= 1.20 -> background > -1.23 (0.0050)
# Removed: background <= -0.46 -> Fe <= 1.20 (0.0015) | Kept: Fe <= 1.20 -> background <= -0.46 (0.0061)
# Removed: background > -1.23 -> Ca <= 0.46 (0.0020) | Kept: Ca <= 0.46 -> background > -1.23 (0.0174)
# Removed: background > -1.23 -> background <= 0.40 (0.0019) | Kept: background <= 0.40 -> background > -1.23 (0.0033)
# Removed: background > -1.23 -> background <= 1.29 (0.0015) | Kept: background <= 1.29 -> background > -1.23 (0.0046)
# Removed: background > -1.23 -> Ca > 0.46 (0.0023) | Kept: Ca > 0.46 -> background > -1.23 (0.0093)
# Removed: background > 0.40 -> Zn > -0.39 (0.0014) | Kept: Zn > -0.39 -> background > 0.40 (0.0084)
# Removed: background > 0.40 -> background > -0.46 (0.0010) | Kept: background > -0.46 -> background > 0.40 (0.0033)
# Removed: Cu > -1.74 -> Ca > 0.46 (0.0081) | Kept: Ca > 0.46 -> Cu > -1.74 (0.0130)
# Removed: Cu > -1.74 -> Ca > -0.68 (0.0065) | Kept: Ca > -0.68 -> Cu > -1.74 (0.0069)
# Removed: Cu > -0.64 -> Zn > -0.39 (0.0047) | Kept: Zn > -0.39 -> Cu > -0.64 (0.0090)
# Removed: Cu > -0.64 -> Ca <= 0.46 (0.0070) | Kept: Ca <= 0.46 -> Cu > -0.64 (0.0089)
# Removed: Cu > -1.74 -> Zn > -0.39 (0.0049) | Kept: Zn > -0.39 -> Cu > -1.74 (0.0111)
# Removed: Fe > 0.31 -> Ca <= 0.46 (0.0063) | Kept: Ca <= 0.46 -> Fe > 0.31 (0.0092)
# Removed: Fe <= -0.36 -> Ca <= 1.81 (0.0052) | Kept: Ca <= 1.81 -> Fe <= -0.36 (0.0071)
# Removed: Cu <= -0.64 -> Fe <= -0.36 (0.0030) | Kept: Fe <= -0.36 -> Cu <= -0.64 (0.0033)
# Removed: background <= -0.46 -> Fe <= 0.31 (0.0013) | Kept: Fe <= 0.31 -> background <= -0.46 (0.0043)
# Removed: Fe <= 0.31 -> Cu <= 0.32 (0.0038) | Kept: Cu <= 0.32 -> Fe <= 0.31 (0.0058)
# Removed: Zn <= 0.56 -> Ag La > 7.76 (0.0042) | Kept: Ag La > 7.76 -> Zn <= 0.56 (0.0463)
#
# ======================================================================
# CONSTRUCTED GRAPH SUMMARY
# ======================================================================
# Initial edges: 434 | Removed: 69
# Predicate nodes: 60
# Metric: Covariance
# Weighting by explained variance: ENABLED
#
# Processing graph LRC...
#
# Processing graph LRC...
#
# Processing graph LRC...
#
# Processing graph LRC...
#    Predicate_Cov_Seed_0 Predicate_Cov_Seed_1 Predicate_Cov_Seed_2  \
# 0         Ag La <= 7.76        Ag La <= 7.76        Ag La <= 7.76
# 1         Ag Lb <= 6.48        Ag Lb <= 6.48        Ag La <= 9.01
# 2         Ag La <= 9.01        Ag Lb <= 2.36        Ag La <= 2.70
# 3         Ag Lb <= 2.36        Ag La <= 2.70        Ag Lb <= 6.48
# 4         Ag La <= 2.70        Ag La <= 9.01        Ag Lb <= 8.04
# ..                  ...                  ...                  ...
# 57           Cu <= 0.32         Ag La > 7.76          Cu <= -0.64
# 58           Fe > -0.36   background > -1.23         Ag La > 7.76
# 59           Ca <= 1.81   background > -0.46          Fe <= -0.36
# 60              Class_A              Class_A              Class_A
# 61              Class_B              Class_B              Class_B
#
#    Predicate_Cov_Seed_3
# 0         Ag La <= 2.70
# 1         Ag La <= 7.76
# 2         Ag Lb <= 6.48
# 3         Ag Lb <= 2.36
# 4         Ag La <= 9.01
# ..                  ...
# 57  background <= -0.46
# 58           Zn > -0.39
# 59          Fe <= -0.36
# 60              Class_A
# 61              Class_B
#
# [62 rows x 4 columns]

# %%
# Somar LRCs de predicados equivalentes entre diferentes seeds
lrc_combined_list = []

for seed in random_seeds:
    lrc_df = lrc_cov_by_seed[seed].copy()
    lrc_combined_list.append(lrc_df) # o append adiciona o dataframe ao final da lista

# Concatenar todos os dataframes
lrc_all_seeds = pd.concat(lrc_combined_list, ignore_index=True) 

# Agrupar por predicado (Node) e somar as LRCs, mantendo Zone, Threshold e Operator
lrc_summed_df_cov = lrc_all_seeds.groupby('Node').agg({ # o .agg pode ser usado para aplicar múltiplas funções de agregação
    'Local_Reaching_Centrality': 'mean', # sum = somando as LRCs, poderia ser média ou outro agregado
    'Zone': 'first',
    'Threshold': 'first',
    'Operator': 'first'
}).reset_index()

# Ordenar pelo valor de LRC somado (maior para menor)
lrc_summed_df_cov = lrc_summed_df_cov.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
# vamoss pegar so os valore sunicos de lrc_summed_df baseado na zona espectral
lrc_summed_unique_df_cov = lrc_summed_df_cov.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
#lrc_summed_unique_df_cov = lrc_summed_unique_df_cov.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
lrc_summed_unique_df_cov
# Out:
#                        Node  Local_Reaching_Centrality            Zone  \
# 0             Ag La <= 7.76                  15.238107           Ag La
# 1             Ag Lb <= 6.48                  12.796752           Ag Lb
# 2            Ag ka <= -7.06                   1.051320           Ag ka
# 3   Bremsstrahlung <= -1.54                   0.704951  Bremsstrahlung
# 4        Ag compton <= 6.52                   0.690518      Ag compton
# 5                Fe > -0.36                   0.372494              Fe
# 6                 Ca > 0.46                   0.346512              Ca
# 7                 Cu > 0.32                   0.320718              Cu
# 8                 Zn > 0.56                   0.262477              Zn
# 9       background <= -0.46                   0.228033      background
# 10                  Class_A                   0.000000            None
#
#    Threshold Operator
# 0       7.76       <=
# 1       6.48       <=
# 2      -7.06       <=
# 3      -1.54       <=
# 4       6.52       <=
# 5      -0.36        >
# 6       0.46        >
# 7       0.32        >
# 8       0.56        >
# 9      -0.46       <=
# 10      None     None

# %%
# Criar zone_sums_df para dados NÃO pré-processados (Xcalclass)
spectral_zones_original = exp.extract_spectral_zones(Xcalclass, spectral_cuts)
zones_original = exp.aggregate_spectral_zones_pca(spectral_zones_original) # apca aggregation

# Aplicar o mapeamento
lrc_summed_df_cov_natural = exp.map_thresholds_to_natural(
    lrc_df=lrc_summed_df_cov,
    zone_sums_preprocessed=zone_scores_df,
    zone_sums_natural=zones_original[0]
)

lrc_summed_df_cov_natural
# Out:
# Zone 'Ag La': VE = 91.39%, dim = 18 variables
# Zone 'Ag Lb': VE = 90.27%, dim = 15 variables
# Zone 'Ca': VE = 27.70%, dim = 19 variables
# Zone 'background': VE = 3.72%, dim = 87 variables
# Zone 'Fe': VE = 14.68%, dim = 23 variables
# Zone 'Cu': VE = 15.48%, dim = 66 variables
# Zone 'Zn': VE = 21.60%, dim = 29 variables
# Zone 'Bremsstrahlung': VE = 38.87%, dim = 429 variables
# Zone 'Ag compton': VE = 52.69%, dim = 62 variables
# Zone 'Ag ka': VE = 80.83%, dim = 45 variables
#                  Node  Local_Reaching_Centrality        Zone Threshold  \
# 0       Ag La <= 7.76                  15.238107       Ag La      7.76
# 1       Ag Lb <= 6.48                  12.796752       Ag Lb      6.48
# 2       Ag La <= 9.01                  10.618027       Ag La      9.01
# 3       Ag La <= 2.70                   9.734752       Ag La      2.70
# 4       Ag Lb <= 2.36                   8.027932       Ag Lb      2.36
# ..                ...                        ...         ...       ...
# 57  background > 0.40                   0.170777  background      0.40
# 58       Ag La > 7.76                   0.167815       Ag La      7.76
# 59        Fe <= -0.36                   0.154303          Fe     -0.36
# 60            Class_A                   0.000000        None      None
# 61            Class_B                   0.000000        None      None
#
#    Operator  Threshold_Natural  Reference_Sample_Index  Approximation_Error  \
# 0        <=         105.814886                    78.0             0.002963
# 1        <=          75.496450                    98.0             0.013050
# 2        <=         126.903607                   239.0             0.004801
# 3        <=          34.935039                    86.0             0.021418
# 4        <=          30.578162                     0.0             0.008013
# ..      ...                ...                     ...                  ...
# 57        >           4.852293                   186.0             0.003287
# 58        >         105.814886                    78.0             0.002963
# 59       <=           0.719116                     9.0             0.001198
# 60     None                NaN                     NaN                  NaN
# 61     None                NaN                     NaN                  NaN
#
#              Node_Natural
# 0     Ag La <= 105.814886
# 1      Ag Lb <= 75.496450
# 2     Ag La <= 126.903607
# 3      Ag La <= 34.935039
# 4      Ag Lb <= 30.578162
# ..                    ...
# 57  background > 4.852293
# 58     Ag La > 105.814886
# 59         Fe <= 0.719116
# 60                   None
# 61                   None
#
# [62 rows x 9 columns]

# %% [markdown]
# ## Reconstrução de Thresholds Multivariados
#
# Agora vamos pegar os thresholds dos predicados mais importantes e reconstruí-los como espectros completos.

# %%
import plotly.graph_objects as go

n = 1
zone_name = lrc_summed_df_cov_natural.iloc[n]['Zone']
threshold_score = float(lrc_summed_df_cov_natural.iloc[n]['Threshold_Natural'])  # Corrigido: usa n em vez de 7

# Usar pca_info_dict dos dados ORIGINAIS (zones_original[1])
pca_info_dict_original = zones_original[1]

# Reconstrução: τ = mean + threshold * loadings (no espaço original)
threshold_spectrum = exp.reconstruct_threshold_to_spectrum(
    threshold_value=threshold_score,
    zone_name=zone_name,
    pca_info_dict=pca_info_dict_original
)
print(f"\nEspectro de threshold reconstruído para zona '{zone_name}':")
print(f"  - Dimensão: {len(threshold_spectrum)} variáveis espectrais")
print(f"  - Range de energias: {threshold_spectrum.index[0]} - {threshold_spectrum.index[-1]}")
print(f"  - Variância explicada pela PC1: {pca_info_dict_original[zone_name]['variance_explained']:.2%}")

# Usar dados ORIGINAIS para plotar (spectral_zones_original)
zone_df = spectral_zones_original[zone_name]

# Plotar zona com threshold (inline)
fig = go.Figure()
x_values = pd.to_numeric(zone_df.columns, errors='coerce')

# Plotar espectros das amostras coloridas por classe
colors = {'A': 'gold', 'B': 'blue'}
for idx, row in zone_df.iterrows():
    class_label = ycalclass.iloc[idx] if idx < len(ycalclass) else 'Unknown'
    fig.add_trace(go.Scatter(
        x=x_values,
        y=row.values,
        mode='lines',
        line=dict(color=colors.get(class_label, 'rgba(128,128,128,0.3)'), width=0.5),
        name=f'Class {class_label}',
        showlegend=False,
        hoverinfo='skip'
    ))

# Plotar espectro de threshold (destaque)
fig.add_trace(go.Scatter(
    x=x_values,
    y=threshold_spectrum.values,
    mode='lines',
    line=dict(color='red', width=4, dash='dash'),
    name=f'Threshold Spectrum ({threshold_spectrum.name})'
))

# Layout do gráfico
fig.update_layout(
    title=f"Zona '{zone_name}' com Threshold Multivariado (Predicado: {lrc_summed_df_cov_natural.iloc[n]['Node_Natural']})",
    xaxis_title='Energia / Comprimento de Onda',
    yaxis_title='Intensidade',
    template='plotly_white',
    showlegend=True,
    legend=dict(yanchor="top", y=0.99, xanchor="left", x=0.01)
)

fig.show()
# Out:
# Espectro de threshold reconstruído para zona 'Ag Lb':
#   - Dimensão: 15 variáveis espectrais
#   - Range de energias: 3.10 - 3.46
#   - Variância explicada pela PC1: 90.27%

# %%
import explaining as exp

# LISTA DE SEMENTES A TESTAR
random_seeds = [0, 1, 2, 3]

all_results_pert = {}
training_samples = len(Xcalclass)

# LOOP: PROCESSAR CADA SEMENTE
y_pred_conticted_numeric = pd.Series(y_pred_cont) # predições numéricas do modelo

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando semente: {seed}")
    print(f"{'='*70}\n")
    # Bagging
    bags_result_seed = exp.bagging_predicates(
        zone_sums_df=zone_scores_df,
        y_predicted_numeric=y_pred_conticted_numeric,
        predicates_df=predicates_quantiles[0],
        n_bags=10,
        #n_predicates_per_bag=40,
        n_samples_per_bag=int(training_samples*0.8), # 80 % da base para amostrar (convertido para int)
        min_samples_per_predicate=int(training_samples*0.2), # 20 % da base para limitar (convertido para int)
        replace=False,
        sample_bagging=True,
        predicate_bagging=False,
        random_seed=seed
    )
    # Inserir classe prevista
    for bag_name, pred_dict in bags_result_seed.items(): # iterando sobre cada bag
        for pred_rule, df_info in pred_dict.items():
            df_info['Class_Predicted'] = np.where(df_info['Predicted_Y'] >= 0.5, 'A', 'B') # binarizando com threshold 0.5, A = eut, B = dist

    pert_results_seed = exp.calculate_predicate_perturbation(
        estimator=pls_model,
        Xcalclass_prep=Xcalclass_prep,
        folds_struct=bags_result_seed,
        predicates_df=predicates_quantiles[0],
        spectral_cuts=spectral_cuts,
        #perturbation_value=0,
        perturbation_mode='median', # valores entre 'mean' ou 'min'
        stats_source='full', # full indica usar todas as amostras para calcular estatísticas enquanto que 'fold' usa apenas as amostras do fold atual
        #metric='mean_abs_diff',   # Média com sinal (pode ser negativo)
        aim='regression',
        metric='mean_abs_diff', 
        verbose=True
    )

    # Salvar no dicionário principal
    all_results_pert[seed] = {
        'bags_result': bags_result_seed,
        'pert_results_dict': pert_results_seed
    }

# CONSTRUÇÃO DE GRAFOS PARA MÚLTIPLAS SEMENTES (LOOP EXTERNO)
# Dicionário para armazenar grafos
graphs_pert_by_seed = {}

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando Grafo - Semente: {seed}")
    print(f"{'='*70}\n")
    
    # Construir grafo para esta semente (sem predicates_df - extraído da regra)
    DG = exp.build_predicate_graph(
        bags_result=all_results_pert[seed]['bags_result'],
        predicate_ranking_dict=all_results_pert[seed]['pert_results_dict'],
        metric_column='Perturbation',
        random_state=seed,
        show_details=True,
        var_exp=True,
        pca_info_dict=pca_info_dict
    )

    # Armazenar grafo
    graphs_pert_by_seed[seed] = DG  

# Calcular LRC usando a função pronta do explaining.py
lrc_pert_by_seed = {}
for seed in random_seeds:
    DG = graphs_pert_by_seed[seed]
    lrc_pert_df_seed = exp.calculate_lrc_single_graph(DG, predicates_quantiles[0])
    lrc_pert_df_seed['Seed'] = seed  # Adicionar coluna com a semente
    lrc_pert_by_seed[seed] = lrc_pert_df_seed

# junando todas as colunas 'Node' de lrc_by_seed em um único dataframe
lrc_pert_all_seeds_df = pd.DataFrame()
for seed in random_seeds:
    lrc_pert_df_seed = lrc_pert_by_seed[seed].rename(columns={'Node': f'Predicate_pert_Seed_{seed}'})
    lrc_pert_all_seeds_df = pd.concat([lrc_pert_all_seeds_df, lrc_pert_df_seed[[f'Predicate_pert_Seed_{seed}']]], axis=1)

# vamos filtrar lrc_by_seed em cada semente para manter apenas as zonas espectrais únicas com maior LRC em um mesmo dataframe
lrc_pert_unique_by_seed = {}
for seed, lrc_df in lrc_pert_by_seed.items():
    lrc_pert_unique_df = lrc_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
    lrc_pert_unique_df = lrc_pert_unique_df.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
    lrc_pert_unique_by_seed[seed] = lrc_pert_unique_df

lrc_pert_all_seeds_df # exibindo o dataframe consolidado com predicados de todas as sementes
# Out:
# ======================================================================
# Processando semente: 0
# ======================================================================
#
# Bag_1 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_2 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_3 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_4 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_5 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_6 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_7 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_8 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_9 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# Bag_10 | Samples: Yes | Predicates: No (All) | Valid: 60 | Discarded: 20
# ======================================================================
# PERTURBATION IMPORTANCE FOR PREDICATES
# ======================================================================
# Task type (aim): regression
# Perturbation mode: median
# Statistics source: full
# Metric: mean_abs_diff
# Total folds: 10
#
#
# [Bag_1] Processing 60 predicates...
#   Predicate: Ag La > -18.52 (n=176)
#     Zone: 18 columns
#     Importance: 0.087337
#   Predicate: Ag La <= 2.70 (n=81)
#     Zone: 18 columns
#     Importance: 0.270392
#   Predicate: Ag La > 2.70 (n=133)
#     Zone: 18 columns
#     Importance: 0.062898
#   Predicate: Ag La <= 7.76 (n=130)
#     Zone: 18 columns
#     Importance: 0.181371
#   Predicate: Ag La > 7.76 (n=84)
#     Zone: 18 columns
#     Importance: 0.079630
#   Predicate: Ag La <= 9.01 (n=171)
#     Zone: 18 columns
#     Importance: 0.152026
#   Predicate: Ag Lb > -15.87 (n=173)
#     Zone: 15 columns
#     Importance: 0.045745
#   Predicate: Ag Lb <= 2.36 (n=82)
#     Zone: 15 columns
#     Importance: 0.163421
#   Predicate: Ag Lb > 2.36 (n=132)
#     Zone: 15 columns
#     Importance: 0.032449
#   Predicate: Ag Lb <= 6.48 (n=129)
#     Zone: 15 columns
#     Importance: 0.112102
#   Predicate: Ag Lb > 6.48 (n=85)
#     Zone: 15 columns
#     Importance: 0.037914
#   Predicate: Ag Lb <= 8.04 (n=170)
#     Zone: 15 columns
#     Importance: 0.093077
#   Predicate: Ca > -1.79 (n=172)
#     Zone: 19 columns
#     Importance: 0.010478
#   Predicate: Ca <= -0.68 (n=85)
#     Zone: 19 columns
#     Importance: 0.011549
#   Predicate: Ca > -0.68 (n=129)
#     Zone: 19 columns
#     Importance: 0.011596
#   Predicate: Ca <= 0.46 (n=128)
#     Zone: 19 columns
#     Importance: 0.009957
#   Predicate: Ca > 0.46 (n=86)
#     Zone: 19 columns
#     Importance: 0.013989
#   Predicate: Ca <= 1.81 (n=175)
#     Zone: 19 columns
#     Importance: 0.009892
#   Predicate: background > -1.23 (n=175)
#     Zone: 87 columns
#     Importance: 0.014087
#   Predicate: background <= -0.46 (n=84)
#     Zone: 87 columns
#     Importance: 0.013469
#   Predicate: background > -0.46 (n=130)
#     Zone: 87 columns
#     Importance: 0.013587
#   Predicate: background <= 0.40 (n=127)
#     Zone: 87 columns
#     Importance: 0.013417
#   Predicate: background > 0.40 (n=87)
#     Zone: 87 columns
#     Importance: 0.013721
#   Predicate: background <= 1.29 (n=172)
#     Zone: 87 columns
#     Importance: 0.013314
#   Predicate: Fe > -1.18 (n=173)
#     Zone: 23 columns
#     Importance: 0.019822
#   Predicate: Fe <= -0.36 (n=81)
#     Zone: 23 columns
#     Importance: 0.016333
#   Predicate: Fe > -0.36 (n=133)
#     Zone: 23 columns
#     Importance: 0.021346
#   Predicate: Fe <= 0.31 (n=122)
#     Zone: 23 columns
#     Importance: 0.017743
#   Predicate: Fe > 0.31 (n=92)
#     Zone: 23 columns
#     Importance: 0.021710
#   Predicate: Fe <= 1.20 (n=167)
#     Zone: 23 columns
#     Importance: 0.017541
#   Predicate: Cu > -1.74 (n=167)
#     Zone: 66 columns
#     Importance: 0.012041
#   Predicate: Cu <= -0.64 (n=86)
#     Zone: 66 columns
#     Importance: 0.012350
#   Predicate: Cu > -0.64 (n=128)
#     Zone: 66 columns
#     Importance: 0.012151
#   Predicate: Cu <= 0.32 (n=125)
#     Zone: 66 columns
#     Importance: 0.012139
#   Predicate: Cu > 0.32 (n=89)
#     Zone: 66 columns
#     Importance: 0.012359
#   Predicate: Cu <= 1.92 (n=167)
#     Zone: 66 columns
#     Importance: 0.012180
#   Predicate: Zn > -1.47 (n=174)
#     Zone: 29 columns
#     Importance: 0.025574
#   Predicate: Zn <= -0.39 (n=82)
#     Zone: 29 columns
#     Importance: 0.025040
#   Predicate: Zn > -0.39 (n=132)
#     Zone: 29 columns
#     Importance: 0.024839
#   Predicate: Zn <= 0.56 (n=130)
#     Zone: 29 columns
#     Importance: 0.023613
#   Predicate: Zn > 0.56 (n=84)
#     Zone: 29 columns
#     Importance: 0.026932
#   Predicate: Zn <= 1.56 (n=171)
#     Zone: 29 columns
#     Importance: 0.023495
#   Predicate: Bremsstrahlung > -9.06 (n=170)
#     Zone: 429 columns
#     Importance: 0.106075
#   Predicate: Bremsstrahlung <= -1.54 (n=84)
#     Zone: 429 columns
#     Importance: 0.128461
#   Predicate: Bremsstrahlung > -1.54 (n=130)
#     Zone: 429 columns
#     Importance: 0.099710
#   Predicate: Bremsstrahlung <= 4.15 (n=127)
#     Zone: 429 columns
#     Importance: 0.122365
#   Predicate: Bremsstrahlung > 4.15 (n=87)
#     Zone: 429 columns
#     Importance: 0.094399
#   Predicate: Bremsstrahlung <= 9.64 (n=166)
#     Zone: 429 columns
#     Importance: 0.117885
#   Predicate: Ag compton > -6.71 (n=174)
#     Zone: 62 columns
#     Importance: 0.040379
#   Predicate: Ag compton <= -1.09 (n=83)
#     Zone: 62 columns
#     Importance: 0.059071
#   Predicate: Ag compton > -1.09 (n=131)
#     Zone: 62 columns
#     Importance: 0.043147
#   Predicate: Ag compton <= 2.96 (n=127)
#     Zone: 62 columns
#     Importance: 0.044200
#   Predicate: Ag compton > 2.96 (n=87)
#     Zone: 62 columns
#     Importance: 0.056801
#   Predicate: Ag compton <= 6.52 (n=168)
#     Zone: 62 columns
#     Importance: 0.043524
#   Predicate: Ag ka > -11.59 (n=174)
#     Zone: 45 columns
#     Importance: 0.110362
#   Predicate: Ag ka <= -7.06 (n=85)
#     Zone: 45 columns
#     Importance: 0.149678
#   Predicate: Ag ka > -7.06 (n=129)
#     Zone: 45 columns
#     Importance: 0.108118
#   Predicate: Ag ka <= 5.37 (n=126)
#     Zone: 45 columns
#     Importance: 0.125895
#   Predicate: Ag ka > 5.37 (n=88)
#     Zone: 45 columns
#     Importance: 0.122808
#   Predicate: Ag ka <= 20.95 (n=168)
#     Zone: 45 columns
#     Importance: 0.126122
#
# [Bag_2] Processing 60 predicates...
#   Predicate: Ag La > -18.52 (n=170)
#     Zone: 18 columns
#     Importance: 0.085641
#   Predicate: Ag La <= 2.70 (n=87)
#     Zone: 18 columns
#     Importance: 0.274772
#   Predicate: Ag La > 2.70 (n=127)
#     Zone: 18 columns
#     Importance: 0.062353
#   Predicate: Ag La <= 7.76 (n=132)
#     Zone: 18 columns
#     Importance: 0.192493
#   Predicate: Ag La > 7.76 (n=82)
#     Zone: 18 columns
#     Importance: 0.078231
#   Predicate: Ag La <= 9.01 (n=175)
#     Zone: 18 columns
#     Importance: 0.159847
#   Predicate: Ag Lb > -15.87 (n=171)
#     Zone: 15 columns
#     Importance: 0.049668
#   Predicate: Ag Lb <= 2.36 (n=87)
#     Zone: 15 columns
#     Importance: 0.168010
#   Predicate: Ag Lb > 2.36 (n=127)
#     Zone: 15 columns
#     Importance: 0.032627
#   Predicate: Ag Lb <= 6.48 (n=131)
#     Zone: 15 columns
#     Importance: 0.119125
#   Predicate: Ag Lb > 6.48 (n=83)
#     Zone: 15 columns
#     Importance: 0.038016
#   Predicate: Ag Lb <= 8.04 (n=174)
#     Zone: 15 columns
#     Importance: 0.097742
#   Predicate: Ca > -1.79 (n=165)
#     Zone: 19 columns
#     Importance: 0.011603
#   Predicate: Ca <= -0.68 (n=83)
#     Zone: 19 columns
#     Importance: 0.013235
#   Predicate: Ca > -0.68 (n=131)
#     Zone: 19 columns
#     Importance: 0.012488
#   Predicate: Ca <= 0.46 (n=128)
#     Zone: 19 columns
#     Importance: 0.011026
#   Predicate: Ca > 0.46 (n=86)
#     Zone: 19 columns
#     Importance: 0.015384
#   Predicate: Ca <= 1.81 (n=173)
#     Zone: 19 columns
#     Importance: 0.010837
#   Predicate: background > -1.23 (n=168)
#     Zone: 87 columns
#     Importance: 0.013217
#   Predicate: background <= -0.46 (n=89)
#     Zone: 87 columns
#     Importance: 0.012685
#   Predicate: background > -0.46 (n=125)
#     Zone: 87 columns
#     Importance: 0.012947
#   Predicate: background <= 0.40 (n=126)
#     Zone: 87 columns
#     Importance: 0.012978
#   Predicate: background > 0.40 (n=88)
#     Zone: 87 columns
#     Importance: 0.012636
#   Predicate: background <= 1.29 (n=172)
#     Zone: 87 columns
#     Importance: 0.012785
#   Predicate: Fe > -1.18 (n=169)
#     Zone: 23 columns
#     Importance: 0.020276
#   Predicate: Fe <= -0.36 (n=87)
#     Zone: 23 columns
#     Importance: 0.016622
#   Predicate: Fe > -0.36 (n=127)
#     Zone: 23 columns
#     Importance: 0.021561
#   Predicate: Fe <= 0.31 (n=127)
#     Zone: 23 columns
#     Importance: 0.017948
#   Predicate: Fe > 0.31 (n=87)
#     Zone: 23 columns
#     Importance: 0.021897
#   Predicate: Fe <= 1.20 (n=169)
#     Zone: 23 columns
#     Importance: 0.017628
#   Predicate: Cu > -1.74 (n=166)
#     Zone: 66 columns
#     Importance: 0.012308
#   Predicate: Cu <= -0.64 (n=90)
#     Zone: 66 columns
#     Importance: 0.012323
#   Predicate: Cu > -0.64 (n=124)
#     Zone: 66 columns
#     Importance: 0.012515
#   Predicate: Cu <= 0.32 (n=129)
#     Zone: 66 columns
#     Importance: 0.012064
#   Predicate: Cu > 0.32 (n=85)
#     Zone: 66 columns
#     Importance: 0.012995
#   Predicate: Cu <= 1.92 (n=170)
#     Zone: 66 columns
#     Importance: 0.012369
#   Predicate: Zn > -1.47 (n=169)
#     Zone: 29 columns
#     Importance: 0.025698
#   Predicate: Zn <= -0.39 (n=86)
#     Zone: 29 columns
#     Importance: 0.023625
#   Predicate: Zn > -0.39 (n=128)
#     Zone: 29 columns
#     Importance: 0.025838
#   Predicate: Zn <= 0.56 (n=132)
#     Zone: 29 columns
#     Importance: 0.023571
#   Predicate: Zn > 0.56 (n=82)
#     Zone: 29 columns
#     Importance: 0.027167
#   Predicate: Zn <= 1.56 (n=169)
#     Zone: 29 columns
#     Importance: 0.023325
#   Predicate: Bremsstrahlung > -9.06 (n=173)
#     Zone: 429 columns
#     Importance: 0.104432
#   Predicate: Bremsstrahlung <= -1.54 (n=87)
#     Zone: 429 columns
#     Importance: 0.119262
#   Predicate: Bremsstrahlung > -1.54 (n=127)
#     Zone: 429 columns
#     Importance: 0.098288
#   Predicate: Bremsstrahlung <= 4.15 (n=134)
#     Zone: 429 columns
#     Importance: 0.118350
#   Predicate: Bremsstrahlung > 4.15 (n=80)
#     Zone: 429 columns
#     Importance: 0.087493
#   Predicate: Bremsstrahlung <= 9.64 (n=170)
#     Zone: 429 columns
#     Importance: 0.112345
#   Predicate: Ag compton > -6.71 (n=171)
#     Zone: 62 columns
#     Importance: 0.038799
#   Predicate: Ag compton <= -1.09 (n=84)
#     Zone: 62 columns
#     Importance: 0.060904
#   Predicate: Ag compton > -1.09 (n=130)
#     Zone: 62 columns
#     Importance: 0.041042
#   Predicate: Ag compton <= 2.96 (n=130)
#     Zone: 62 columns
#     Importance: 0.044954
#   Predicate: Ag compton > 2.96 (n=84)
#     Zone: 62 columns
#     Importance: 0.054850
#   Predicate: Ag compton <= 6.52 (n=173)
#     Zone: 62 columns
#     Importance: 0.043828
#   Predicate: Ag ka > -11.59 (n=169)
#     Zone: 45 columns
#     Importance: 0.111692
#   Predicate: Ag ka <= -7.06 (n=84)
#     Zone: 45 columns
#     Importance: 0.154619
#   Predicate: Ag ka > -7.06 (n=130)
#     Zone: 45 columns
#     Importance: 0.109105
#   Predicate: Ag ka <= 5.37 (n=125)
#     Zone: 45 columns
#     Importance: 0.130947
#   Predicate: Ag ka > 5.37 (n=89)
#     Zone: 45 columns
#     Importance: 0.121384
#   Predicate: Ag ka <= 20.95 (n=166)
#     Zone: 45 columns
#     Importance: 0.127634
#
# [Bag_3] Processing 60 predicates...
#   Predicate: Ag La > -18.52 (n=174)
#     Zone: 18 columns
#     Importance: 0.088169
#   Predicate: Ag La <= 2.70 (n=84)
#     Zone: 18 columns
#     Importance: 0.271111
#   Predicate: Ag La > 2.70 (n=130)
#     Zone: 18 columns
#     Importance: 0.064482
#   Predicate: Ag La <= 7.76 (n=128)
#     Zone: 18 columns
#     Importance: 0.189852
#   Predicate: Ag La > 7.76 (n=86)
#     Zone: 18 columns
#     Importance: 0.079709
#   Predicate: Ag La <= 9.01 (n=169)
#     Zone: 18 columns
#     Importance: 0.158019
#   Predicate: Ag Lb > -15.87 (n=173)
#     Zone: 15 columns
#     Importance: 0.047786
#   Predicate: Ag Lb <= 2.36 (n=84)
#     Zone: 15 columns
#     Importance: 0.164796
#   Predicate: Ag Lb > 2.36 (n=130)
#     Zone: 15 columns
#     Importance: 0.032090
#   Predicate: Ag Lb <= 6.48 (n=127)
#     Zone: 15 columns
#     Importance: 0.116463
#   Predicate: Ag Lb > 6.48 (n=87)
#     Zone: 15 columns
#     Importance: 0.037055
#   Predicate: Ag Lb <= 8.04 (n=169)
#     Zone: 15 columns
#     Importance: 0.095447
#   Predicate: Ca > -1.79 (n=171)
#     Zone: 19 columns
#     Importance: 0.011203
#   Predicate: Ca <= -0.68 (n=79)
#     Zone: 19 columns
#     Importance: 0.012287
#   Predicate: Ca > -0.68 (n=135)
#     Zone: 19 columns
#     Importance: 0.011982
#   Predicate: Ca <= 0.46 (n=126)
#     Zone: 19 columns
#     Importance: 0.010356
#   Predicate: Ca > 0.46 (n=88)
#     Zone: 19 columns
#     Importance: 0.014584
#   Predicate: Ca <= 1.81 (n=170)
#     Zone: 19 columns
#     Importance: 0.010035
#   Predicate: background > -1.23 (n=169)
#     Zone: 87 columns
#     Importance: 0.013475
#   Predicate: background <= -0.46 (n=89)
#     Zone: 87 columns
#     Importance: 0.013659
#   Predicate: background > -0.46 (n=125)
#     Zone: 87 columns
#     Importance: 0.012778
#   Predicate: background <= 0.40 (n=133)
#     Zone: 87 columns
#     Importance: 0.013767
#   Predicate: background > 0.40 (n=81)
#     Zone: 87 columns
#     Importance: 0.012123
#   Predicate: background <= 1.29 (n=174)
#     Zone: 87 columns
#     Importance: 0.013375
#   Predicate: Fe > -1.18 (n=174)
#     Zone: 23 columns
#     Importance: 0.020676
#   Predicate: Fe <= -0.36 (n=76)
#     Zone: 23 columns
#     Importance: 0.017216
#   Predicate: Fe > -0.36 (n=138)
#     Zone: 23 columns
#     Importance: 0.021858
#   Predicate: Fe <= 0.31 (n=124)
#     Zone: 23 columns
#     Importance: 0.018340
#   Predicate: Fe > 0.31 (n=90)
#     Zone: 23 columns
#     Importance: 0.022785
#   Predicate: Fe <= 1.20 (n=170)
#     Zone: 23 columns
#     Importance: 0.018033
#   Predicate: Cu > -1.74 (n=173)
#     Zone: 66 columns
#     Importance: 0.012153
#   Predicate: Cu <= -0.64 (n=84)
#     Zone: 66 columns
#     Importance: 0.011257
#   Predicate: Cu > -0.64 (n=130)
#     Zone: 66 columns
#     Importance: 0.012635
#   Predicate: Cu <= 0.32 (n=125)
#     Zone: 66 columns
#     Importance: 0.011576
#   Predicate: Cu > 0.32 (n=89)
#     Zone: 66 columns
#     Importance: 0.012821
#   Predicate: Cu <= 1.92 (n=171)
#     Zone: 66 columns
#     Importance: 0.011986
#   Predicate: Zn > -1.47 (n=170)
#     Zone: 29 columns
#     Importance: 0.026081
#   Predicate: Zn <= -0.39 (n=89)
#     Zone: 29 columns
#     Importance: 0.023675
#   Predicate: Zn > -0.39 (n=125)
#     Zone: 29 columns
#     Importance: 0.026368
#   Predicate: Zn <= 0.56 (n=130)
#     Zone: 29 columns
#     Importance: 0.023671
#   Predicate: Zn > 0.56 (n=84)
#     Zone: 29 columns
#     Importance: 0.027689
#   Predicate: Zn <= 1.56 (n=173)
#     Zone: 29 columns
#     Importance: 0.023320
#   Predicate: Bremsstrahlung > -9.06 (n=167)
#     Zone: 429 columns
#     Importance: 0.111050
#   Predicate: Bremsstrahlung <= -1.54 (n=84)
#     Zone: 429 columns
#     Importance: 0.128353
#   Predicate: Bremsstrahlung > -1.54 (n=130)
#     Zone: 429 columns
#     Importance: 0.103589
#   Predicate: Bremsstrahlung <= 4.15 (n=129)
#     Zone: 429 columns
#     Importance: 0.123859
#   Predicate: Bremsstrahlung > 4.15 (n=85)
#     Zone: 429 columns
#     Importance: 0.097300
#   Predicate: Bremsstrahlung <= 9.64 (n=173)
#     Zone: 429 columns
#     Importance: 0.119558
#   Predicate: Ag compton > -6.71 (n=170)
#     Zone: 62 columns
#     Importance: 0.040883
#   Predicate: Ag compton <= -1.09 (n=89)
#     Zone: 62 columns
#     Importance: 0.060190
#   Predicate: Ag compton > -1.09 (n=125)
#     Zone: 62 columns
#     Importance: 0.043999
#   Predicate: Ag compton <= 2.96 (n=132)
#     Zone: 62 columns
#     Importance: 0.045796
#   Predicate: Ag compton > 2.96 (n=82)
#     Zone: 62 columns
#     Importance: 0.058679
#   Predicate: Ag compton <= 6.52 (n=172)
#     Zone: 62 columns
#     Importance: 0.044713
#   Predicate: Ag ka > -11.59 (n=168)
#     Zone: 45 columns
#     Importance: 0.113530
#   Predicate: Ag ka <= -7.06 (n=91)
#     Zone: 45 columns
#     Importance: 0.147584
#   Predicate: Ag ka > -7.06 (n=123)
#     Zone: 45 columns
#     Importance: 0.112673
#   Predicate: Ag ka <= 5.37 (n=131)
#     Zone: 45 columns
#     Importance: 0.125921
#   Predicate: Ag ka > 5.37 (n=83)
#     Zone: 45 columns
#     Importance: 0.130040
#   Predicate: Ag ka <= 20.95 (n=173)
#     Zone: 45 columns
#     Importance: 0.124896
#
# [Bag_4] Processing 60 predicates...
#   Predicate: Ag La > -18.52 (n=172)
#     Zone: 18 columns
#     Importance: 0.088772
#   Predicate: Ag La <= 2.70 (n=86)
#     Zone: 18 columns
#     Importance: 0.273264
#   Predicate: Ag La > 2.70 (n=128)
#     Zone: 18 columns
#     Importance: 0.064911
#   Predicate: Ag La <= 7.76 (n=128)
#     Zone: 18 columns
#     Importance: 0.195544
#   Predicate: Ag La > 7.76 (n=86)
#     Zone: 18 columns
#     Importance: 0.078833
#   Predicate: Ag La <= 9.01 (n=172)
#     Zone: 18 columns
#     Importance: 0.160539
#   Predicate: Ag Lb > -15.87 (n=168)
#     Zone: 15 columns
#     Importance: 0.045979
#   Predicate: Ag Lb <= 2.36 (n=88)
#     Zone: 15 columns
#     Importance: 0.164089
#   Predicate: Ag Lb > 2.36 (n=126)
#     Zone: 15 columns
#     Importance: 0.033511
#   Predicate: Ag Lb <= 6.48 (n=128)
#     Zone: 15 columns
#     Importance: 0.119750
#   Predicate: Ag Lb > 6.48 (n=86)
#     Zone: 15 columns
#     Importance: 0.038770
#   Predicate: Ag Lb <= 8.04 (n=167)
#     Zone: 15 columns
#     Importance: 0.099862
#   Predicate: Ca > -1.79 (n=165)
#     Zone: 19 columns
#     Importance: 0.011534
#   Predicate: Ca <= -0.68 (n=90)
#     Zone: 19 columns
#     Importance: 0.012636
#   Predicate: Ca > -0.68 (n=124)
#     Zone: 19 columns
#     Importance: 0.012604
#   Predicate: Ca <= 0.46 (n=129)
#     Zone: 19 columns
#     Importance: 0.010993
#   Predicate: Ca > 0.46 (n=85)
#     Zone: 19 columns
#     Importance: 0.015084
#   Predicate: Ca <= 1.81 (n=171)
#     Zone: 19 columns
#     Importance: 0.010604
#   Predicate: background > -1.23 (n=170)
#     Zone: 87 columns
#     Importance: 0.013652
#   Predicate: background <= -0.46 (n=85)
#     Zone: 87 columns
#     Importance: 0.013450
#   Predicate: background > -0.46 (n=129)
#     Zone: 87 columns
#     Importance: 0.012987
#   Predicate: background <= 0.40 (n=127)
#     Zone: 87 columns
#     Importance: 0.013699
#   Predicate: background > 0.40 (n=87)
#     Zone: 87 columns
#     Importance: 0.012400
#   Predicate: background <= 1.29 (n=171)
#     Zone: 87 columns
#     Importance: 0.013319
#   Predicate: Fe > -1.18 (n=173)
#     Zone: 23 columns
#     Importance: 0.020736
#   Predicate: Fe <= -0.36 (n=82)
#     Zone: 23 columns
#     Importance: 0.016463
#   Predicate: Fe > -0.36 (n=132)
#     Zone: 23 columns
#     Importance: 0.022236
#   Predicate: Fe <= 0.31 (n=128)
#     Zone: 23 columns
#     Importance: 0.017660
#   Predicate: Fe > 0.31 (n=86)
#     Zone: 23 columns
#     Importance: 0.023542
#   Predicate: Fe <= 1.20 (n=169)
#     Zone: 23 columns
#     Importance: 0.017700
#   Predicate: Cu > -1.74 (n=169)
#     Zone: 66 columns
#     Importance: 0.012126
#   Predicate: Cu <= -0.64 (n=89)
#     Zone: 66 columns
#     Importance: 0.011797
#   Predicate: Cu > -0.64 (n=125)
#     Zone: 66 columns
#     Importance: 0.012530
#   Predicate: Cu <= 0.32 (n=128)
#     Zone: 66 columns
#     Importance: 0.011667
#   Predicate: Cu > 0.32 (n=86)
#     Zone: 66 columns
#     Importance: 0.013055
#   Predicate: Cu <= 1.92 (n=170)
#     Zone: 66 columns
#     Importance: 0.011987
#   Predicate: Zn > -1.47 (n=170)
#     Zone: 29 columns
#     Importance: 0.025680
#   Predicate: Zn <= -0.39 (n=86)
#     Zone: 29 columns
#     Importance: 0.025227
#   Predicate: Zn > -0.39 (n=128)
#     Zone: 29 columns
#     Importance: 0.024548
#   Predicate: Zn <= 0.56 (n=132)
#     Zone: 29 columns
#     Importance: 0.023467
#   Predicate: Zn > 0.56 (n=82)
#     Zone: 29 columns
#     Importance: 0.027001
#   Predicate: Zn <= 1.56 (n=172)
#     Zone: 29 columns
#     Importance: 0.023440
#   Predicate: Bremsstrahlung > -9.06 (n=173)
#     Zone: 429 columns
#     Importance: 0.107839
#   Predicate: Bremsstrahlung <= -1.54 (n=84)
#     Zone: 429 columns
#     Importance: 0.113211
#   Predicate: Bremsstrahlung > -1.54 (n=130)
#     Zone: 429 columns
#     Importance: 0.101448
#   Predicate: Bremsstrahlung <= 4.15 (n=130)
#     Zone: 429 columns
#     Importance: 0.112943
#   Predicate: Bremsstrahlung > 4.15 (n=84)
#     Zone: 429 columns
#     Importance: 0.095422
#   Predicate: Bremsstrahlung <= 9.64 (n=174)
#     Zone: 429 columns
#     Importance: 0.110988
#   Predicate: Ag compton > -6.71 (n=171)
#     Zone: 62 columns
#     Importance: 0.039807
#   Predicate: Ag compton <= -1.09 (n=87)
#     Zone: 62 columns
#     Importance: 0.056778
#   Predicate: Ag compton > -1.09 (n=127)
#     Zone: 62 columns
#     Importance: 0.043181
#   Predicate: Ag compton <= 2.96 (n=127)
#     Zone: 62 columns
#     Importance: 0.044011
#   Predicate: Ag compton > 2.96 (n=87)
#     Zone: 62 columns
#     Importance: 0.055566
#   Predicate: Ag compton <= 6.52 (n=171)
#     Zone: 62 columns
#     Importance: 0.043185
#   Predicate: Ag ka > -11.59 (n=173)
#     Zone: 45 columns
#     Importance: 0.108939
#   Predicate: Ag ka <= -7.06 (n=86)
#     Zone: 45 columns
#     Importance: 0.147896
#   Predicate: Ag ka > -7.06 (n=128)
#     Zone: 45 columns
#     Importance: 0.106727
#   Predicate: Ag ka <= 5.37 (n=127)
#     Zone: 45 columns
#     Importance: 0.125321
#   Predicate: Ag ka > 5.37 (n=87)
#     Zone: 45 columns
#     Importance: 0.120279
#   Predicate: Ag ka <= 20.95 (n=172)
#     Zone: 45 columns
#     Importance: 0.124388
#
# [Bag_5] Processing 60 predicates...
#   Predicate: Ag La > -18.52 (n=170)
#     Zone: 18 columns
#     Importance: 0.085679
#   Predicate: Ag La <= 2.70 (n=86)
#     Zone: 18 columns
#     Importance: 0.276322
#   Predicate: Ag La > 2.70 (n=128)
#     Zone: 18 columns
#     Importance: 0.062451
#   Predicate: Ag La <= 7.76 (n=129)
#     Zone: 18 columns
#     Importance: 0.195438
#   Predicate: Ag La > 7.76 (n=85)
#     Zone: 18 columns
#     Importance: 0.077011
#   Predicate: Ag La <= 9.01 (n=173)
#     Zone: 18 columns
#     Importance: 0.160686
#   Predicate: Ag Lb > -15.87 (n=169)
#     Zone: 15 columns
#     Importance: 0.047014
#   Predicate: Ag Lb <= 2.36 (n=87)
#     Zone: 15 columns
#     Importance: 0.167944
#   Predicate: Ag Lb > 2.36 (n=127)
#     Zone: 15 columns
#     Importance: 0.031819
#   Predicate: Ag Lb <= 6.48 (n=132)
#     Zone: 15 columns
#     Importance: 0.118175
#   Predicate: Ag Lb > 6.48 (n=82)
#     Zone: 15 columns
#     Importance: 0.037232
#   Predicate: Ag Lb <= 8.04 (n=174)
#     Zone: 15 columns
#     Importance: 0.097610
#   Predicate: Ca > -1.79 (n=168)
#     Zone: 19 columns
#     Importance: 0.011447
#   Predicate: Ca <= -0.68 (n=86)
#     Zone: 19 columns
#     Importance: 0.011991
#   Predicate: Ca > -0.68 (n=128)
#     Zone: 19 columns
#     Importance: 0.012656
#   Predicate: Ca <= 0.46 (n=126)
#     Zone: 19 columns
#     Importance: 0.010318
#   Predicate: Ca > 0.46 (n=88)
#     Zone: 19 columns
#     Importance: 0.015352
#   Predicate: Ca <= 1.81 (n=167)
#     Zone: 19 columns
#     Importance: 0.010187
#   Predicate: background > -1.23 (n=171)
#     Zone: 87 columns
#     Importance: 0.013885
#   Predicate: background <= -0.46 (n=87)
#     Zone: 87 columns
#     Importance: 0.012672
#   Predicate: background > -0.46 (n=127)
#     Zone: 87 columns
#     Importance: 0.014052
#   Predicate: background <= 0.40 (n=130)
#     Zone: 87 columns
#     Importance: 0.013318
#   Predicate: background > 0.40 (n=84)
#     Zone: 87 columns
#     Importance: 0.013759
#   Predicate: background <= 1.29 (n=175)
#     Zone: 87 columns
#     Importance: 0.013252
#   Predicate: Fe > -1.18 (n=173)
#     Zone: 23 columns
#     Importance: 0.020281
#   Predicate: Fe <= -0.36 (n=83)
#     Zone: 23 columns
#     Importance: 0.017617
#   Predicate: Fe > -0.36 (n=131)
#     Zone: 23 columns
#     Importance: 0.021266
#   Predicate: Fe <= 0.31 (n=127)
#     Zone: 23 columns
#     Importance: 0.018394
#   Predicate: Fe > 0.31 (n=87)
#     Zone: 23 columns
#     Importance: 0.021977
#   Predicate: Fe <= 1.20 (n=171)
#     Zone: 23 columns
#     Importance: 0.017857
#   Predicate: Cu > -1.74 (n=172)
#     Zone: 66 columns
#     Importance: 0.011910
#   Predicate: Cu <= -0.64 (n=87)
#     Zone: 66 columns
#     Importance: 0.012097
#   Predicate: Cu > -0.64 (n=127)
#     Zone: 66 columns
#     Importance: 0.011974
#   Predicate: Cu <= 0.32 (n=132)
#     Zone: 66 columns
#     Importance: 0.011702
#   Predicate: Cu > 0.32 (n=82)
#     Zone: 66 columns
#     Importance: 0.012542
#   Predicate: Cu <= 1.92 (n=173)
#     Zone: 66 columns
#     Importance: 0.012087
#   Predicate: Zn > -1.47 (n=176)
#     Zone: 29 columns
#     Importance: 0.025963
#   Predicate: Zn <= -0.39 (n=82)
#     Zone: 29 columns
#     Importance: 0.025313
#   Predicate: Zn > -0.39 (n=132)
#     Zone: 29 columns
#     Importance: 0.025608
#   Predicate: Zn <= 0.56 (n=127)
#     Zone: 29 columns
#     Importance: 0.024664
#   Predicate: Zn > 0.56 (n=87)
#     Zone: 29 columns
#     Importance: 0.026707
#   Predicate: Zn <= 1.56 (n=168)
#     Zone: 29 columns
#     Importance: 0.024524
#   Predicate: Bremsstrahlung > -9.06 (n=169)
#     Zone: 429 columns
#     Importance: 0.104683
#   Predicate: Bremsstrahlung <= -1.54 (n=87)
#     Zone: 429 columns
#     Importance: 0.120199
#   Predicate: Bremsstrahlung > -1.54 (n=127)
#     Zone: 429 columns
#     Importance: 0.097206
#   Predicate: Bremsstrahlung <= 4.15 (n=130)
#     Zone: 429 columns
#     Importance: 0.116586
#   Predicate: Bremsstrahlung > 4.15 (n=84)
#     Zone: 429 columns
#     Importance: 0.091026
#   Predicate: Bremsstrahlung <= 9.64 (n=170)
#     Zone: 429 columns
#     Importance: 0.111600
#   Predicate: Ag compton > -6.71 (n=170)
#     Zone: 62 columns
#     Importance: 0.039325
#   Predicate: Ag compton <= -1.09 (n=89)
#     Zone: 62 columns
#     Importance: 0.057538
#   Predicate: Ag compton > -1.09 (n=125)
#     Zone: 62 columns
#     Importance: 0.042764
#   Predicate: Ag compton <= 2.96 (n=129)
#     Zone: 62 columns
#     Importance: 0.044563
#   Predicate: Ag compton > 2.96 (n=85)
#     Zone: 62 columns
#     Importance: 0.055503
#   Predicate: Ag compton <= 6.52 (n=172)
#     Zone: 62 columns
#     Importance: 0.043641
#   Predicate: Ag ka > -11.59 (n=171)
#     Zone: 45 columns
#     Importance: 0.115437
#   Predicate: Ag ka <= -7.06 (n=87)
#     Zone: 45 columns
#     Importance: 0.155809
#   Predicate: Ag ka > -7.06 (n=127)
#     Zone: 45 columns
#     Importance: 0.111856
#   Predicate: Ag ka <= 5.37 (n=125)
#     Zone: 45 columns
#     Importance: 0.132982
#   Predicate: Ag ka > 5.37 (n=89)
#     Zone: 45 columns
#     Importance: 0.125150
#   Predicate: Ag ka <= 20.95 (n=167)
#     Zone: 45 columns
#     Importance: 0.131089
#
# [Bag_6] Processing 60 predicates...
#   Predicate: Ag La > -18.52 (n=170)
#     Zone: 18 columns
#     Importance: 0.082405
#   Predicate: Ag La <= 2.70 (n=83)
#     Zone: 18 columns
#     Importance: 0.273391
#   Predicate: Ag La > 2.70 (n=131)
#     Zone: 18 columns
#     Importance: 0.065567
#   Predicate: Ag La <= 7.76 (n=125)
#     Zone: 18 columns
#     Importance: 0.193312
#   Predicate: Ag La > 7.76 (n=89)
#     Zone: 18 columns
#     Importance: 0.079963
#   Predicate: Ag La <= 9.01 (n=173)
#     Zone: 18 columns
#     Importance: 0.155901
#   Predicate: Ag Lb > -15.87 (n=171)
#     Zone: 15 columns
#     Importance: 0.045535
#   Predicate: Ag Lb <= 2.36 (n=83)
#     Zone: 15 columns
#     Importance: 0.167465
#   Predicate: Ag Lb > 2.36 (n=131)
#     Zone: 15 columns
#     Importance: 0.031275
#   Predicate: Ag Lb <= 6.48 (n=126)
#     Zone: 15 columns
#     Importance: 0.117618
#   Predicate: Ag Lb > 6.48 (n=88)
#     Zone: 15 columns
#     Importance: 0.036100
#   Predicate: Ag Lb <= 8.04 (n=170)
#     Zone: 15 columns
#     Importance: 0.095195
#   Predicate: Ca > -1.79 (n=171)
#     Zone: 19 columns
#     Importance: 0.011011
#   Predicate: Ca <= -0.68 (n=88)
#     Zone: 19 columns
#     Importance: 0.011449
#   Predicate: Ca > -0.68 (n=126)
#     Zone: 19 columns
#     Importance: 0.012242
#   Predicate: Ca <= 0.46 (n=131)
#     Zone: 19 columns
#     Importance: 0.009853
#   Predicate: Ca > 0.46 (n=83)
#     Zone: 19 columns
#     Importance: 0.015172
#   Predicate: Ca <= 1.81 (n=172)
#     Zone: 19 columns
#     Importance: 0.009920
#   Predicate: background > -1.23 (n=167)
#     Zone: 87 columns
#     Importance: 0.014059
#   Predicate: background <= -0.46 (n=92)
#     Zone: 87 columns
#     Importance: 0.013960
#   Predicate: background > -0.46 (n=122)
#     Zone: 87 columns
#     Importance: 0.013236
#   Predicate: background <= 0.40 (n=136)
#     Zone: 87 columns
#     Importance: 0.014401
#   Predicate: background > 0.40 (n=78)
#     Zone: 87 columns
#     Importance: 0.012060
#   Predicate: background <= 1.29 (n=178)
#     Zone: 87 columns
#     Importance: 0.013669
#   Predicate: Fe > -1.18 (n=173)
#     Zone: 23 columns
#     Importance: 0.020529
#   Predicate: Fe <= -0.36 (n=86)
#     Zone: 23 columns
#     Importance: 0.017465
#   Predicate: Fe > -0.36 (n=128)
#     Zone: 23 columns
#     Importance: 0.022034
#   Predicate: Fe <= 0.31 (n=128)
#     Zone: 23 columns
#     Importance: 0.018654
#   Predicate: Fe > 0.31 (n=86)
#     Zone: 23 columns
#     Importance: 0.022496
#   Predicate: Fe <= 1.20 (n=176)
#     Zone: 23 columns
#     Importance: 0.018344
#   Predicate: Cu > -1.74 (n=175)
#     Zone: 66 columns
#     Importance: 0.011974
#   Predicate: Cu <= -0.64 (n=82)
#     Zone: 66 columns
#     Importance: 0.012614
#   Predicate: Cu > -0.64 (n=132)
#     Zone: 66 columns
#     Importance: 0.012175
#   Predicate: Cu <= 0.32 (n=129)
#     Zone: 66 columns
#     Importance: 0.012206
#   Predicate: Cu > 0.32 (n=85)
#     Zone: 66 columns
#     Importance: 0.012552
#   Predicate: Cu <= 1.92 (n=170)
#     Zone: 66 columns
#     Importance: 0.012359
#   Predicate: Zn > -1.47 (n=168)
#     Zone: 29 columns
#     Importance: 0.026179
#   Predicate: Zn <= -0.39 (n=85)
#     Zone: 29 columns
#     Importance: 0.025746
#   Predicate: Zn > -0.39 (n=129)
#     Zone: 29 columns
#     Importance: 0.025528
#   Predicate: Zn <= 0.56 (n=131)
#     Zone: 29 columns
#     Importance: 0.024638
#   Predicate: Zn > 0.56 (n=83)
#     Zone: 29 columns
#     Importance: 0.027156
#   Predicate: Zn <= 1.56 (n=170)
#     Zone: 29 columns
#     Importance: 0.024150
#   Predicate: Bremsstrahlung > -9.06 (n=168)
#     Zone: 429 columns
#     Importance: 0.102683
#   Predicate: Bremsstrahlung <= -1.54 (n=91)
#     Zone: 429 columns
#     Importance: 0.115816
#   Predicate: Bremsstrahlung > -1.54 (n=123)
#     Zone: 429 columns
#     Importance: 0.098469
#   Predicate: Bremsstrahlung <= 4.15 (n=132)
#     Zone: 429 columns
#     Importance: 0.114461
#   Predicate: Bremsstrahlung > 4.15 (n=82)
#     Zone: 429 columns
#     Importance: 0.091976
#   Predicate: Bremsstrahlung <= 9.64 (n=177)
#     Zone: 429 columns
#     Importance: 0.110162
#   Predicate: Ag compton > -6.71 (n=172)
#     Zone: 62 columns
#     Importance: 0.036372
#   Predicate: Ag compton <= -1.09 (n=89)
#     Zone: 62 columns
#     Importance: 0.056767
#   Predicate: Ag compton > -1.09 (n=125)
#     Zone: 62 columns
#     Importance: 0.038490
#   Predicate: Ag compton <= 2.96 (n=137)
#     Zone: 62 columns
#     Importance: 0.042031
#   Predicate: Ag compton > 2.96 (n=77)
#     Zone: 62 columns
#     Importance: 0.053315
#   Predicate: Ag compton <= 6.52 (n=177)
#     Zone: 62 columns
#     Importance: 0.041982
#   Predicate: Ag ka > -11.59 (n=174)
#     Zone: 45 columns
#     Importance: 0.114502
#   Predicate: Ag ka <= -7.06 (n=83)
#     Zone: 45 columns
#     Importance: 0.145051
#   Predicate: Ag ka > -7.06 (n=131)
#     Zone: 45 columns
#     Importance: 0.115874
#   Predicate: Ag ka <= 5.37 (n=126)
#     Zone: 45 columns
#     Importance: 0.124186
#   Predicate: Ag ka > 5.37 (n=88)
#     Zone: 45 columns
#     Importance: 0.131493
#   Predicate: Ag ka <= 20.95 (n=171)
#     Zone: 45 columns
#     Importance: 0.125552
#
# [Bag_7] Processing 60 predicates...
#   Predicate: Ag La > -18.52 (n=170)
#     Zone: 18 columns
#     Importance: 0.083966
#   Predicate: Ag La <= 2.70 (n=85)
#     Zone: 18 columns
#     Importance: 0.276111
#   Predicate: Ag La > 2.70 (n=129)
#     Zone: 18 columns
#     Importance: 0.062391
#   Predicate: Ag La <= 7.76 (n=130)
#     Zone: 18 columns
#     Importance: 0.192983
#   Predicate: Ag La > 7.76 (n=84)
#     Zone: 18 columns
#     Importance: 0.076549
#   Predicate: Ag La <= 9.01 (n=174)
#     Zone: 18 columns
#     Importance: 0.158998
#   Predicate: Ag Lb > -15.87 (n=173)
#     Zone: 15 columns
#     Importance: 0.050031
#   Predicate: Ag Lb <= 2.36 (n=86)
#     Zone: 15 columns
#     Importance: 0.166657
#   Predicate: Ag Lb > 2.36 (n=128)
#     Zone: 15 columns
#     Importance: 0.032205
#   Predicate: Ag Lb <= 6.48 (n=128)
#     Zone: 15 columns
#     Importance: 0.118953
#   Predicate: Ag Lb > 6.48 (n=86)
#     Zone: 15 columns
#     Importance: 0.037544
#   Predicate: Ag Lb <= 8.04 (n=170)
#     Zone: 15 columns
#     Importance: 0.097864
#   Predicate: Ca > -1.79 (n=172)
#     Zone: 19 columns
#     Importance: 0.011358
#   Predicate: Ca <= -0.68 (n=84)
#     Zone: 19 columns
#     Importance: 0.012623
#   Predicate: Ca > -0.68 (n=130)
#     Zone: 19 columns
#     Importance: 0.012473
#   Predicate: Ca <= 0.46 (n=126)
#     Zone: 19 columns
#     Importance: 0.010667
#   Predicate: Ca > 0.46 (n=88)
#     Zone: 19 columns
#     Importance: 0.015202
#   Predicate: Ca <= 1.81 (n=172)
#     Zone: 19 columns
#     Importance: 0.010583
#   Predicate: background > -1.23 (n=174)
#     Zone: 87 columns
#     Importance: 0.013493
#   Predicate: background <= -0.46 (n=81)
#     Zone: 87 columns
#     Importance: 0.012696
#   Predicate: background > -0.46 (n=133)
#     Zone: 87 columns
#     Importance: 0.013029
#   Predicate: background <= 0.40 (n=125)
#     Zone: 87 columns
#     Importance: 0.013011
#   Predicate: background > 0.40 (n=89)
#     Zone: 87 columns
#     Importance: 0.012750
#   Predicate: background <= 1.29 (n=170)
#     Zone: 87 columns
#     Importance: 0.012936
#   Predicate: Fe > -1.18 (n=168)
#     Zone: 23 columns
#     Importance: 0.019798
#   Predicate: Fe <= -0.36 (n=82)
#     Zone: 23 columns
#     Importance: 0.017804
#   Predicate: Fe > -0.36 (n=132)
#     Zone: 23 columns
#     Importance: 0.020882
#   Predicate: Fe <= 0.31 (n=126)
#     Zone: 23 columns
#     Importance: 0.018187
#   Predicate: Fe > 0.31 (n=88)
#     Zone: 23 columns
#     Importance: 0.021872
#   Predicate: Fe <= 1.20 (n=167)
#     Zone: 23 columns
#     Importance: 0.017621
#   Predicate: Cu > -1.74 (n=175)
#     Zone: 66 columns
#     Importance: 0.012019
#   Predicate: Cu <= -0.64 (n=90)
#     Zone: 66 columns
#     Importance: 0.012032
#   Predicate: Cu > -0.64 (n=124)
#     Zone: 66 columns
#     Importance: 0.012629
#   Predicate: Cu <= 0.32 (n=132)
#     Zone: 66 columns
#     Importance: 0.012000
#   Predicate: Cu > 0.32 (n=82)
#     Zone: 66 columns
#     Importance: 0.012986
#   Predicate: Cu <= 1.92 (n=172)
#     Zone: 66 columns
#     Importance: 0.012090
#   Predicate: Zn > -1.47 (n=172)
#     Zone: 29 columns
#     Importance: 0.026732
#   Predicate: Zn <= -0.39 (n=87)
#     Zone: 29 columns
#     Importance: 0.025207
#   Predicate: Zn > -0.39 (n=127)
#     Zone: 29 columns
#     Importance: 0.026042
#   Predicate: Zn <= 0.56 (n=127)
#     Zone: 29 columns
#     Importance: 0.024739
#   Predicate: Zn > 0.56 (n=87)
#     Zone: 29 columns
#     Importance: 0.027109
#   Predicate: Zn <= 1.56 (n=167)
#     Zone: 29 columns
#     Importance: 0.023975
#   Predicate: Bremsstrahlung > -9.06 (n=172)
#     Zone: 429 columns
#     Importance: 0.102372
#   Predicate: Bremsstrahlung <= -1.54 (n=81)
#     Zone: 429 columns
#     Importance: 0.118245
#   Predicate: Bremsstrahlung > -1.54 (n=133)
#     Zone: 429 columns
#     Importance: 0.095300
#   Predicate: Bremsstrahlung <= 4.15 (n=119)
#     Zone: 429 columns
#     Importance: 0.109978
#   Predicate: Bremsstrahlung > 4.15 (n=95)
#     Zone: 429 columns
#     Importance: 0.096478
#   Predicate: Bremsstrahlung <= 9.64 (n=165)
#     Zone: 429 columns
#     Importance: 0.108823
#   Predicate: Ag compton > -6.71 (n=174)
#     Zone: 62 columns
#     Importance: 0.040331
#   Predicate: Ag compton <= -1.09 (n=80)
#     Zone: 62 columns
#     Importance: 0.061579
#   Predicate: Ag compton > -1.09 (n=134)
#     Zone: 62 columns
#     Importance: 0.043001
#   Predicate: Ag compton <= 2.96 (n=121)
#     Zone: 62 columns
#     Importance: 0.046255
#   Predicate: Ag compton > 2.96 (n=93)
#     Zone: 62 columns
#     Importance: 0.054749
#   Predicate: Ag compton <= 6.52 (n=168)
#     Zone: 62 columns
#     Importance: 0.044417
#   Predicate: Ag ka > -11.59 (n=171)
#     Zone: 45 columns
#     Importance: 0.113267
#   Predicate: Ag ka <= -7.06 (n=89)
#     Zone: 45 columns
#     Importance: 0.143743
#   Predicate: Ag ka > -7.06 (n=125)
#     Zone: 45 columns
#     Importance: 0.112599
#   Predicate: Ag ka <= 5.37 (n=130)
#     Zone: 45 columns
#     Importance: 0.122387
#   Predicate: Ag ka > 5.37 (n=84)
#     Zone: 45 columns
#     Importance: 0.130449
#   Predicate: Ag ka <= 20.95 (n=174)
#     Zone: 45 columns
#     Importance: 0.122889
#
# [Bag_8] Processing 60 predicates...
#   Predicate: Ag La > -18.52 (n=168)
#     Zone: 18 columns
#     Importance: 0.087330
#   Predicate: Ag La <= 2.70 (n=83)
#     Zone: 18 columns
#     Importance: 0.292254
#   Predicate: Ag La > 2.70 (n=131)
#     Zone: 18 columns
#     Importance: 0.063922
#   Predicate: Ag La <= 7.76 (n=125)
#     Zone: 18 columns
#     Importance: 0.205874
#   Predicate: Ag La > 7.76 (n=89)
#     Zone: 18 columns
#     Importance: 0.077489
#   Predicate: Ag La <= 9.01 (n=172)
#     Zone: 18 columns
#     Importance: 0.165941
#   Predicate: Ag Lb > -15.87 (n=168)
#     Zone: 15 columns
#     Importance: 0.048136
#   Predicate: Ag Lb <= 2.36 (n=83)
#     Zone: 15 columns
#     Importance: 0.178997
#   Predicate: Ag Lb > 2.36 (n=131)
#     Zone: 15 columns
#     Importance: 0.031663
#   Predicate: Ag Lb <= 6.48 (n=125)
#     Zone: 15 columns
#     Importance: 0.125604
#   Predicate: Ag Lb > 6.48 (n=89)
#     Zone: 15 columns
#     Importance: 0.037124
#   Predicate: Ag Lb <= 8.04 (n=170)
#     Zone: 15 columns
#     Importance: 0.100937
#   Predicate: Ca > -1.79 (n=173)
#     Zone: 19 columns
#     Importance: 0.011716
#   Predicate: Ca <= -0.68 (n=87)
#     Zone: 19 columns
#     Importance: 0.011969
#   Predicate: Ca > -0.68 (n=127)
#     Zone: 19 columns
#     Importance: 0.013123
#   Predicate: Ca <= 0.46 (n=121)
#     Zone: 19 columns
#     Importance: 0.010561
#   Predicate: Ca > 0.46 (n=93)
#     Zone: 19 columns
#     Importance: 0.015377
#   Predicate: Ca <= 1.81 (n=166)
#     Zone: 19 columns
#     Importance: 0.010331
#   Predicate: background > -1.23 (n=167)
#     Zone: 87 columns
#     Importance: 0.014460
#   Predicate: background <= -0.46 (n=94)
#     Zone: 87 columns
#     Importance: 0.013781
#   Predicate: background > -0.46 (n=120)
#     Zone: 87 columns
#     Importance: 0.013847
#   Predicate: background <= 0.40 (n=132)
#     Zone: 87 columns
#     Importance: 0.014045
#   Predicate: background > 0.40 (n=82)
#     Zone: 87 columns
#     Importance: 0.013453
#   Predicate: background <= 1.29 (n=171)
#     Zone: 87 columns
#     Importance: 0.013738
#   Predicate: Fe > -1.18 (n=174)
#     Zone: 23 columns
#     Importance: 0.019999
#   Predicate: Fe <= -0.36 (n=89)
#     Zone: 23 columns
#     Importance: 0.016803
#   Predicate: Fe > -0.36 (n=125)
#     Zone: 23 columns
#     Importance: 0.021782
#   Predicate: Fe <= 0.31 (n=136)
#     Zone: 23 columns
#     Importance: 0.017161
#   Predicate: Fe > 0.31 (n=78)
#     Zone: 23 columns
#     Importance: 0.024157
#   Predicate: Fe <= 1.20 (n=174)
#     Zone: 23 columns
#     Importance: 0.017019
#   Predicate: Cu > -1.74 (n=170)
#     Zone: 66 columns
#     Importance: 0.011965
#   Predicate: Cu <= -0.64 (n=89)
#     Zone: 66 columns
#     Importance: 0.012587
#   Predicate: Cu > -0.64 (n=125)
#     Zone: 66 columns
#     Importance: 0.012327
#   Predicate: Cu <= 0.32 (n=131)
#     Zone: 66 columns
#     Importance: 0.012318
#   Predicate: Cu > 0.32 (n=83)
#     Zone: 66 columns
#     Importance: 0.012621
#   Predicate: Cu <= 1.92 (n=172)
#     Zone: 66 columns
#     Importance: 0.012440
#   Predicate: Zn > -1.47 (n=171)
#     Zone: 29 columns
#     Importance: 0.027087
#   Predicate: Zn <= -0.39 (n=86)
#     Zone: 29 columns
#     Importance: 0.025871
#   Predicate: Zn > -0.39 (n=128)
#     Zone: 29 columns
#     Importance: 0.026489
#   Predicate: Zn <= 0.56 (n=135)
#     Zone: 29 columns
#     Importance: 0.024597
#   Predicate: Zn > 0.56 (n=79)
#     Zone: 29 columns
#     Importance: 0.029048
#   Predicate: Zn <= 1.56 (n=175)
#     Zone: 29 columns
#     Importance: 0.024317
#   Predicate: Bremsstrahlung > -9.06 (n=171)
#     Zone: 429 columns
#     Importance: 0.113820
#   Predicate: Bremsstrahlung <= -1.54 (n=89)
#     Zone: 429 columns
#     Importance: 0.127188
#   Predicate: Bremsstrahlung > -1.54 (n=125)
#     Zone: 429 columns
#     Importance: 0.106066
#   Predicate: Bremsstrahlung <= 4.15 (n=133)
#     Zone: 429 columns
#     Importance: 0.122840
#   Predicate: Bremsstrahlung > 4.15 (n=81)
#     Zone: 429 columns
#     Importance: 0.101732
#   Predicate: Bremsstrahlung <= 9.64 (n=174)
#     Zone: 429 columns
#     Importance: 0.119621
#   Predicate: Ag compton > -6.71 (n=171)
#     Zone: 62 columns
#     Importance: 0.040163
#   Predicate: Ag compton <= -1.09 (n=86)
#     Zone: 62 columns
#     Importance: 0.058315
#   Predicate: Ag compton > -1.09 (n=128)
#     Zone: 62 columns
#     Importance: 0.042603
#   Predicate: Ag compton <= 2.96 (n=130)
#     Zone: 62 columns
#     Importance: 0.043892
#   Predicate: Ag compton > 2.96 (n=84)
#     Zone: 62 columns
#     Importance: 0.056695
#   Predicate: Ag compton <= 6.52 (n=172)
#     Zone: 62 columns
#     Importance: 0.043358
#   Predicate: Ag ka > -11.59 (n=172)
#     Zone: 45 columns
#     Importance: 0.111126
#   Predicate: Ag ka <= -7.06 (n=85)
#     Zone: 45 columns
#     Importance: 0.143972
#   Predicate: Ag ka > -7.06 (n=129)
#     Zone: 45 columns
#     Importance: 0.110448
#   Predicate: Ag ka <= 5.37 (n=131)
#     Zone: 45 columns
#     Importance: 0.120840
#   Predicate: Ag ka > 5.37 (n=83)
#     Zone: 45 columns
#     Importance: 0.128379
#   Predicate: Ag ka <= 20.95 (n=165)
#     Zone: 45 columns
#     Importance: 0.122765
#
# [Bag_9] Processing 60 predicates...
#   Predicate: Ag La > -18.52 (n=173)
#     Zone: 18 columns
#     Importance: 0.091036
#   Predicate: Ag La <= 2.70 (n=86)
#     Zone: 18 columns
#     Importance: 0.274287
#   Predicate: Ag La > 2.70 (n=128)
#     Zone: 18 columns
#     Importance: 0.065024
#   Predicate: Ag La <= 7.76 (n=133)
#     Zone: 18 columns
#     Importance: 0.189902
#   Predicate: Ag La > 7.76 (n=81)
#     Zone: 18 columns
#     Importance: 0.082158
#   Predicate: Ag La <= 9.01 (n=167)
#     Zone: 18 columns
#     Importance: 0.163172
#   Predicate: Ag Lb > -15.87 (n=172)
#     Zone: 15 columns
#     Importance: 0.048949
#   Predicate: Ag Lb <= 2.36 (n=87)
#     Zone: 15 columns
#     Importance: 0.164908
#   Predicate: Ag Lb > 2.36 (n=127)
#     Zone: 15 columns
#     Importance: 0.032017
#   Predicate: Ag Lb <= 6.48 (n=129)
#     Zone: 15 columns
#     Importance: 0.117714
#   Predicate: Ag Lb > 6.48 (n=85)
#     Zone: 15 columns
#     Importance: 0.037977
#   Predicate: Ag Lb <= 8.04 (n=168)
#     Zone: 15 columns
#     Importance: 0.097917
#   Predicate: Ca > -1.79 (n=174)
#     Zone: 19 columns
#     Importance: 0.010999
#   Predicate: Ca <= -0.68 (n=86)
#     Zone: 19 columns
#     Importance: 0.011494
#   Predicate: Ca > -0.68 (n=128)
#     Zone: 19 columns
#     Importance: 0.012043
#   Predicate: Ca <= 0.46 (n=130)
#     Zone: 19 columns
#     Importance: 0.009805
#   Predicate: Ca > 0.46 (n=84)
#     Zone: 19 columns
#     Importance: 0.014945
#   Predicate: Ca <= 1.81 (n=172)
#     Zone: 19 columns
#     Importance: 0.009536
#   Predicate: background > -1.23 (n=169)
#     Zone: 87 columns
#     Importance: 0.013413
#   Predicate: background <= -0.46 (n=84)
#     Zone: 87 columns
#     Importance: 0.013256
#   Predicate: background > -0.46 (n=130)
#     Zone: 87 columns
#     Importance: 0.012803
#   Predicate: background <= 0.40 (n=127)
#     Zone: 87 columns
#     Importance: 0.013396
#   Predicate: background > 0.40 (n=87)
#     Zone: 87 columns
#     Importance: 0.012375
#   Predicate: background <= 1.29 (n=168)
#     Zone: 87 columns
#     Importance: 0.012932
#   Predicate: Fe > -1.18 (n=173)
#     Zone: 23 columns
#     Importance: 0.018334
#   Predicate: Fe <= -0.36 (n=81)
#     Zone: 23 columns
#     Importance: 0.015747
#   Predicate: Fe > -0.36 (n=133)
#     Zone: 23 columns
#     Importance: 0.019746
#   Predicate: Fe <= 0.31 (n=128)
#     Zone: 23 columns
#     Importance: 0.016861
#   Predicate: Fe > 0.31 (n=86)
#     Zone: 23 columns
#     Importance: 0.020273
#   Predicate: Fe <= 1.20 (n=171)
#     Zone: 23 columns
#     Importance: 0.016570
#   Predicate: Cu > -1.74 (n=169)
#     Zone: 66 columns
#     Importance: 0.011518
#   Predicate: Cu <= -0.64 (n=85)
#     Zone: 66 columns
#     Importance: 0.011340
#   Predicate: Cu > -0.64 (n=129)
#     Zone: 66 columns
#     Importance: 0.011952
#   Predicate: Cu <= 0.32 (n=124)
#     Zone: 66 columns
#     Importance: 0.011028
#   Predicate: Cu > 0.32 (n=90)
#     Zone: 66 columns
#     Importance: 0.012647
#   Predicate: Cu <= 1.92 (n=166)
#     Zone: 66 columns
#     Importance: 0.011333
#   Predicate: Zn > -1.47 (n=170)
#     Zone: 29 columns
#     Importance: 0.026503
#   Predicate: Zn <= -0.39 (n=85)
#     Zone: 29 columns
#     Importance: 0.023404
#   Predicate: Zn > -0.39 (n=129)
#     Zone: 29 columns
#     Importance: 0.026635
#   Predicate: Zn <= 0.56 (n=134)
#     Zone: 29 columns
#     Importance: 0.023242
#   Predicate: Zn > 0.56 (n=80)
#     Zone: 29 columns
#     Importance: 0.028885
#   Predicate: Zn <= 1.56 (n=173)
#     Zone: 29 columns
#     Importance: 0.023654
#   Predicate: Bremsstrahlung > -9.06 (n=171)
#     Zone: 429 columns
#     Importance: 0.110819
#   Predicate: Bremsstrahlung <= -1.54 (n=84)
#     Zone: 429 columns
#     Importance: 0.129863
#   Predicate: Bremsstrahlung > -1.54 (n=130)
#     Zone: 429 columns
#     Importance: 0.104666
#   Predicate: Bremsstrahlung <= 4.15 (n=127)
#     Zone: 429 columns
#     Importance: 0.126114
#   Predicate: Bremsstrahlung > 4.15 (n=87)
#     Zone: 429 columns
#     Importance: 0.097684
#   Predicate: Bremsstrahlung <= 9.64 (n=170)
#     Zone: 429 columns
#     Importance: 0.121934
#   Predicate: Ag compton > -6.71 (n=174)
#     Zone: 62 columns
#     Importance: 0.040143
#   Predicate: Ag compton <= -1.09 (n=82)
#     Zone: 62 columns
#     Importance: 0.062481
#   Predicate: Ag compton > -1.09 (n=132)
#     Zone: 62 columns
#     Importance: 0.043021
#   Predicate: Ag compton <= 2.96 (n=126)
#     Zone: 62 columns
#     Importance: 0.046326
#   Predicate: Ag compton > 2.96 (n=88)
#     Zone: 62 columns
#     Importance: 0.056422
#   Predicate: Ag compton <= 6.52 (n=172)
#     Zone: 62 columns
#     Importance: 0.045164
#   Predicate: Ag ka > -11.59 (n=168)
#     Zone: 45 columns
#     Importance: 0.110750
#   Predicate: Ag ka <= -7.06 (n=85)
#     Zone: 45 columns
#     Importance: 0.145663
#   Predicate: Ag ka > -7.06 (n=129)
#     Zone: 45 columns
#     Importance: 0.107686
#   Predicate: Ag ka <= 5.37 (n=129)
#     Zone: 45 columns
#     Importance: 0.123085
#   Predicate: Ag ka > 5.37 (n=85)
#     Zone: 45 columns
#     Importance: 0.122293
#   Predicate: Ag ka <= 20.95 (n=171)
#     Zone: 45 columns
#     Importance: 0.123537
#
# [Bag_10] Processing 60 predicates...
#   Predicate: Ag La > -18.52 (n=174)
#     Zone: 18 columns
#     Importance: 0.088328
#   Predicate: Ag La <= 2.70 (n=80)
#     Zone: 18 columns
#     Importance: 0.279578
#   Predicate: Ag La > 2.70 (n=134)
#     Zone: 18 columns
#     Importance: 0.065370
#   Predicate: Ag La <= 7.76 (n=125)
#     Zone: 18 columns
#     Importance: 0.191659
#   Predicate: Ag La > 7.76 (n=89)
#     Zone: 18 columns
#     Importance: 0.080544
#   Predicate: Ag La <= 9.01 (n=169)
#     Zone: 18 columns
#     Importance: 0.157246
#   Predicate: Ag Lb > -15.87 (n=173)
#     Zone: 15 columns
#     Importance: 0.046849
#   Predicate: Ag Lb <= 2.36 (n=80)
#     Zone: 15 columns
#     Importance: 0.169400
#   Predicate: Ag Lb > 2.36 (n=134)
#     Zone: 15 columns
#     Importance: 0.032052
#   Predicate: Ag Lb <= 6.48 (n=125)
#     Zone: 15 columns
#     Importance: 0.116048
#   Predicate: Ag Lb > 6.48 (n=89)
#     Zone: 15 columns
#     Importance: 0.037539
#   Predicate: Ag Lb <= 8.04 (n=166)
#     Zone: 15 columns
#     Importance: 0.095358
#   Predicate: Ca > -1.79 (n=168)
#     Zone: 19 columns
#     Importance: 0.011573
#   Predicate: Ca <= -0.68 (n=89)
#     Zone: 19 columns
#     Importance: 0.012172
#   Predicate: Ca > -0.68 (n=125)
#     Zone: 19 columns
#     Importance: 0.012645
#   Predicate: Ca <= 0.46 (n=128)
#     Zone: 19 columns
#     Importance: 0.010659
#   Predicate: Ca > 0.46 (n=86)
#     Zone: 19 columns
#     Importance: 0.015111
#   Predicate: Ca <= 1.81 (n=175)
#     Zone: 19 columns
#     Importance: 0.010548
#   Predicate: background > -1.23 (n=170)
#     Zone: 87 columns
#     Importance: 0.013937
#   Predicate: background <= -0.46 (n=87)
#     Zone: 87 columns
#     Importance: 0.012988
#   Predicate: background > -0.46 (n=127)
#     Zone: 87 columns
#     Importance: 0.013628
#   Predicate: background <= 0.40 (n=129)
#     Zone: 87 columns
#     Importance: 0.013566
#   Predicate: background > 0.40 (n=85)
#     Zone: 87 columns
#     Importance: 0.013068
#   Predicate: background <= 1.29 (n=173)
#     Zone: 87 columns
#     Importance: 0.013288
#   Predicate: Fe > -1.18 (n=175)
#     Zone: 23 columns
#     Importance: 0.020020
#   Predicate: Fe <= -0.36 (n=77)
#     Zone: 23 columns
#     Importance: 0.015592
#   Predicate: Fe > -0.36 (n=137)
#     Zone: 23 columns
#     Importance: 0.021373
#   Predicate: Fe <= 0.31 (n=121)
#     Zone: 23 columns
#     Importance: 0.016183
#   Predicate: Fe > 0.31 (n=93)
#     Zone: 23 columns
#     Importance: 0.023339
#   Predicate: Fe <= 1.20 (n=170)
#     Zone: 23 columns
#     Importance: 0.016519
#   Predicate: Cu > -1.74 (n=173)
# ...
# Removed: background > -1.23 -> background <= 1.29 (0.0005) | Kept: background <= 1.29 -> background > -1.23 (0.0005)
# Removed: background <= -0.46 -> background <= 0.40 (0.0005) | Kept: background <= 0.40 -> background <= -0.46 (0.0014)
# Removed: background <= 1.29 -> background <= -0.46 (0.0005) | Kept: background <= -0.46 -> background <= 1.29 (0.0005)
# Removed: background > -0.46 -> background <= -0.46 (0.0005) | Kept: background <= -0.46 -> background > -0.46 (0.0005)
# Removed: background <= -0.46 -> Ca <= -0.68 (0.0013) | Kept: Ca <= -0.68 -> background <= -0.46 (0.0028)
# Removed: background > 0.40 -> Cu > 0.32 (0.0009) | Kept: Cu > 0.32 -> background > 0.40 (0.0023)
# Removed: background > 0.40 -> Ca > -0.68 (0.0009) | Kept: Ca > -0.68 -> background > 0.40 (0.0027)
# Removed: background > 0.40 -> Cu <= 1.92 (0.0008) | Kept: Cu <= 1.92 -> background > 0.40 (0.0012)
# Removed: background > 0.40 -> Cu > -0.64 (0.0004) | Kept: Cu > -0.64 -> background > 0.40 (0.0011)
# Removed: Cu <= -0.64 -> Cu > 0.32 (0.0011) | Kept: Cu > 0.32 -> Cu <= -0.64 (0.0023)
# Removed: Cu > -0.64 -> Cu > 0.32 (0.0011) | Kept: Cu > 0.32 -> Cu > -0.64 (0.0012)
# Removed: Ca <= -0.68 -> Ca > -0.68 (0.0053) | Kept: Ca > -0.68 -> Ca <= -0.68 (0.0081)
# Removed: Cu > -0.64 -> Ca > -0.68 (0.0012) | Kept: Ca > -0.68 -> Cu > -0.64 (0.0027)
# Removed: Cu <= -0.64 -> Ca <= -0.68 (0.0012) | Kept: Ca <= -0.68 -> Cu <= -0.64 (0.0080)
# Removed: Cu <= 1.92 -> Cu <= -0.64 (0.0011) | Kept: Cu <= -0.64 -> Cu <= 1.92 (0.0011)
# Removed: Cu <= 0.32 -> Cu <= -0.64 (0.0011) | Kept: Cu <= -0.64 -> Cu <= 0.32 (0.0022)
# Removed: Cu <= -0.64 -> Ca > -1.79 (0.0011) | Kept: Ca > -1.79 -> Cu <= -0.64 (0.0024)
# Removed: Cu <= 1.92 -> Cu > -0.64 (0.0022) | Kept: Cu > -0.64 -> Cu <= 1.92 (0.0022)
# Removed: Cu <= 1.92 -> Cu > -1.74 (0.0022) | Kept: Cu > -1.74 -> Cu <= 1.92 (0.0022)
# Removed: Cu <= 0.32 -> Cu > -0.64 (0.0011) | Kept: Cu > -0.64 -> Cu <= 0.32 (0.0011)
# Removed: Cu > -0.64 -> Ca > -1.79 (0.0011) | Kept: Ca > -1.79 -> Cu > -0.64 (0.0025)
# Removed: Cu > -1.74 -> Cu <= 0.32 (0.0032) | Kept: Cu <= 0.32 -> Cu > -1.74 (0.0033)
# Removed: Cu > -1.74 -> Ca > -1.79 (0.0022) | Kept: Ca > -1.79 -> Cu > -1.74 (0.0024)
# Removed: Ca <= 1.81 -> Ca <= 0.46 (0.0045) | Kept: Ca <= 0.46 -> Ca <= 1.81 (0.0184)
#
# ======================================================================
# CONSTRUCTED GRAPH SUMMARY
# ======================================================================
# Initial edges: 221 | Removed: 52
# Predicate nodes: 60
# Metric: Perturbation
# Weighting by explained variance: ENABLED
#
# ======================================================================
# Processando Grafo - Semente: 2
# ======================================================================
#
#
# Total bidirectional pairs found: 52
# Removed: Ag ka <= -7.06 -> Ag La <= 9.01 (0.1190) | Kept: Ag La <= 9.01 -> Ag ka <= -7.06 (1.2155)
# Removed: Bremsstrahlung <= -1.54 -> Ag ka <= 20.95 (0.0393) | Kept: Ag ka <= 20.95 -> Bremsstrahlung <= -1.54 (0.0979)
# Removed: Bremsstrahlung <= 4.15 -> Bremsstrahlung <= -1.54 (0.0722) | Kept: Bremsstrahlung <= -1.54 -> Bremsstrahlung <= 4.15 (0.1120)
# Removed: Bremsstrahlung <= -1.54 -> Ag ka <= 5.37 (0.0764) | Kept: Ag ka <= 5.37 -> Bremsstrahlung <= -1.54 (0.1923)
# Removed: Bremsstrahlung <= -1.54 -> Ag Lb <= 6.48 (0.0368) | Kept: Ag Lb <= 6.48 -> Bremsstrahlung <= -1.54 (0.1031)
# Removed: Ag ka <= 5.37 -> Ag ka <= 20.95 (0.2902) | Kept: Ag ka <= 20.95 -> Ag ka <= 5.37 (0.4802)
# Removed: Ag ka <= 20.95 -> Ag ka > 5.37 (0.1897) | Kept: Ag ka > 5.37 -> Ag ka <= 20.95 (0.4899)
# Removed: Bremsstrahlung <= 4.15 -> Ag ka <= 5.37 (0.0390) | Kept: Ag ka <= 5.37 -> Bremsstrahlung <= 4.15 (0.1908)
# Removed: Ag ka > 5.37 -> Ag Lb <= 6.48 (0.0925) | Kept: Ag Lb <= 6.48 -> Ag ka > 5.37 (0.1059)
# Removed: Bremsstrahlung <= 4.15 -> Ag Lb <= 6.48 (0.0379) | Kept: Ag Lb <= 6.48 -> Bremsstrahlung <= 4.15 (0.3083)
# Removed: Bremsstrahlung <= 9.64 -> Bremsstrahlung <= 4.15 (0.0358) | Kept: Bremsstrahlung <= 4.15 -> Bremsstrahlung <= 9.64 (0.1078)
# Removed: Bremsstrahlung <= 9.64 -> Ag Lb <= 6.48 (0.0728) | Kept: Ag Lb <= 6.48 -> Bremsstrahlung <= 9.64 (0.1041)
# Removed: Bremsstrahlung <= 9.64 -> Ag ka > -11.59 (0.1746) | Kept: Ag ka > -11.59 -> Bremsstrahlung <= 9.64 (0.1774)
# Removed: Ag ka > -7.06 -> Ag ka > -11.59 (0.0849) | Kept: Ag ka > -11.59 -> Ag ka > -7.06 (0.3442)
# Removed: Bremsstrahlung > -9.06 -> Ag ka > -7.06 (0.0983) | Kept: Ag ka > -7.06 -> Bremsstrahlung > -9.06 (0.3397)
# Removed: Bremsstrahlung > -1.54 -> Ag Lb <= 8.04 (0.1235) | Kept: Ag Lb <= 8.04 -> Bremsstrahlung > -1.54 (0.1738)
# Removed: Bremsstrahlung > 4.15 -> Ag Lb <= 8.04 (0.1178) | Kept: Ag Lb <= 8.04 -> Bremsstrahlung > 4.15 (0.3361)
# Removed: Ag La > -18.52 -> Bremsstrahlung > 4.15 (0.0766) | Kept: Bremsstrahlung > 4.15 -> Ag La > -18.52 (0.1416)
# Removed: Ag compton <= -1.09 -> Ag La > 2.70 (0.0342) | Kept: Ag La > 2.70 -> Ag compton <= -1.09 (0.4435)
# Removed: Ag compton > 2.96 -> Ag compton <= -1.09 (0.0297) | Kept: Ag compton <= -1.09 -> Ag compton > 2.96 (0.2495)
# Removed: Ag compton <= 2.96 -> Ag Lb > -15.87 (0.0237) | Kept: Ag Lb > -15.87 -> Ag compton <= 2.96 (0.2825)
# Removed: Ag compton <= 6.52 -> Ag Lb > -15.87 (0.0237) | Kept: Ag Lb > -15.87 -> Ag compton <= 6.52 (0.0777)
# Removed: Ag compton <= 6.52 -> Ag compton <= 2.96 (0.0215) | Kept: Ag compton <= 2.96 -> Ag compton <= 6.52 (0.1681)
# Removed: Ag compton > -1.09 -> Ag compton <= 6.52 (0.0221) | Kept: Ag compton <= 6.52 -> Ag compton > -1.09 (0.1621)
# Removed: Zn > -0.39 -> Zn > -1.47 (0.0087) | Kept: Zn > -1.47 -> Zn > -0.39 (0.0322)
# Removed: Zn <= -0.39 -> Zn > -0.39 (0.0046) | Kept: Zn > -0.39 -> Zn <= -0.39 (0.0316)
# Removed: Fe <= 1.20 -> Fe <= 0.31 (0.0067) | Kept: Fe <= 0.31 -> Fe <= 1.20 (0.0113)
# Removed: Fe <= -0.36 -> Fe <= 1.20 (0.0045) | Kept: Fe <= 1.20 -> Fe <= -0.36 (0.0112)
# Removed: background > -1.23 -> background <= -0.46 (0.0005) | Kept: background <= -0.46 -> background > -1.23 (0.0009)
# Removed: background > -1.23 -> Cu > 0.32 (0.0005) | Kept: Cu > 0.32 -> background > -1.23 (0.0025)
# Removed: background <= -0.46 -> background > 0.40 (0.0005) | Kept: background > 0.40 -> background <= -0.46 (0.0010)
# Removed: background > 0.40 -> Ca <= -0.68 (0.0004) | Kept: Ca <= -0.68 -> background > 0.40 (0.0054)
# Removed: background > 0.40 -> Cu <= -0.64 (0.0005) | Kept: Cu <= -0.64 -> background > 0.40 (0.0012)
# Removed: background > 0.40 -> background > -0.46 (0.0005) | Kept: background > -0.46 -> background > 0.40 (0.0009)
# Removed: background > 0.40 -> Cu > 0.32 (0.0004) | Kept: Cu > 0.32 -> background > 0.40 (0.0011)
# Removed: background > -0.46 -> background <= -0.46 (0.0005) | Kept: background <= -0.46 -> background > -0.46 (0.0019)
# Removed: background <= -0.46 -> background <= 0.40 (0.0005) | Kept: background <= 0.40 -> background <= -0.46 (0.0014)
# Removed: background <= -0.46 -> background <= 1.29 (0.0004) | Kept: background <= 1.29 -> background <= -0.46 (0.0009)
# Removed: background <= 1.29 -> background > -0.46 (0.0009) | Kept: background > -0.46 -> background <= 1.29 (0.0014)
# Removed: background <= 1.29 -> background <= 0.40 (0.0014) | Kept: background <= 0.40 -> background <= 1.29 (0.0014)
# Removed: background <= 1.29 -> Cu > -0.64 (0.0009) | Kept: Cu > -0.64 -> background <= 1.29 (0.0012)
# Removed: Cu <= 1.92 -> Ca <= -0.68 (0.0011) | Kept: Ca <= -0.68 -> Cu <= 1.92 (0.0027)
# Removed: Ca > -1.79 -> Ca <= -0.68 (0.0025) | Kept: Ca <= -0.68 -> Ca > -1.79 (0.0077)
# Removed: Ca <= -0.68 -> Cu > -1.74 (0.0026) | Kept: Cu > -1.74 -> Ca <= -0.68 (0.0045)
# Removed: Cu <= -0.64 -> Ca > -0.68 (0.0023) | Kept: Ca > -0.68 -> Cu <= -0.64 (0.0028)
# Removed: Cu > -0.64 -> Cu > 0.32 (0.0011) | Kept: Cu > 0.32 -> Cu > -0.64 (0.0046)
# Removed: Cu <= -0.64 -> Cu <= 1.92 (0.0011) | Kept: Cu <= 1.92 -> Cu <= -0.64 (0.0023)
# Removed: Cu <= 0.32 -> Cu <= -0.64 (0.0011) | Kept: Cu <= -0.64 -> Cu <= 0.32 (0.0034)
# Removed: Cu <= -0.64 -> Cu > -1.74 (0.0011) | Kept: Cu > -1.74 -> Cu <= -0.64 (0.0011)
# Removed: Cu > -0.64 -> Cu <= 1.92 (0.0023) | Kept: Cu <= 1.92 -> Cu > -0.64 (0.0034)
# Removed: Cu <= 0.32 -> Cu <= 1.92 (0.0012) | Kept: Cu <= 1.92 -> Cu <= 0.32 (0.0034)
# Removed: Ca <= 1.81 -> Ca <= 0.46 (0.0045) | Kept: Ca <= 0.46 -> Ca <= 1.81 (0.0183)
#
# ======================================================================
# CONSTRUCTED GRAPH SUMMARY
# ======================================================================
# Initial edges: 214 | Removed: 52
# Predicate nodes: 60
# Metric: Perturbation
# Weighting by explained variance: ENABLED
#
# ======================================================================
# Processando Grafo - Semente: 3
# ======================================================================
#
#
# Total bidirectional pairs found: 56
# Removed: Ag ka <= 20.95 -> Ag ka <= 5.37 (0.2893) | Kept: Ag ka <= 5.37 -> Ag ka <= 20.95 (0.2964)
# Removed: Bremsstrahlung <= 9.64 -> Ag ka <= 5.37 (0.0355) | Kept: Ag ka <= 5.37 -> Bremsstrahlung <= 9.64 (0.0920)
# Removed: Ag ka > 5.37 -> Ag ka <= 5.37 (0.0930) | Kept: Ag ka <= 5.37 -> Ag ka > 5.37 (0.1958)
# Removed: Ag ka > 5.37 -> Ag ka <= 20.95 (0.2941) | Kept: Ag ka <= 20.95 -> Ag ka > 5.37 (0.3880)
# Removed: Bremsstrahlung <= 4.15 -> Ag ka <= 20.95 (0.0376) | Kept: Ag ka <= 20.95 -> Bremsstrahlung <= 4.15 (0.0905)
# Removed: Bremsstrahlung <= -1.54 -> Ag Lb <= 6.48 (0.0374) | Kept: Ag Lb <= 6.48 -> Bremsstrahlung <= -1.54 (0.3136)
# Removed: Bremsstrahlung <= 4.15 -> Ag Lb <= 6.48 (0.0737) | Kept: Ag Lb <= 6.48 -> Bremsstrahlung <= 4.15 (0.1015)
# Removed: Ag ka > -11.59 -> Ag Lb <= 6.48 (0.0873) | Kept: Ag Lb <= 6.48 -> Ag ka > -11.59 (0.2023)
# Removed: Bremsstrahlung <= 9.64 -> Ag Lb <= 6.48 (0.0361) | Kept: Ag Lb <= 6.48 -> Bremsstrahlung <= 9.64 (0.1031)
# Removed: Bremsstrahlung <= 9.64 -> Ag ka > -11.59 (0.1063) | Kept: Ag ka > -11.59 -> Bremsstrahlung <= 9.64 (0.1743)
# Removed: Ag ka > -7.06 -> Bremsstrahlung <= 9.64 (0.0844) | Kept: Bremsstrahlung <= 9.64 -> Ag ka > -7.06 (0.1047)
# Removed: Ag ka > -7.06 -> Ag ka > -11.59 (0.1701) | Kept: Ag ka > -11.59 -> Ag ka > -7.06 (0.3448)
# Removed: Bremsstrahlung > -9.06 -> Ag ka > -11.59 (0.0338) | Kept: Ag ka > -11.59 -> Bremsstrahlung > -9.06 (0.2531)
# Removed: Bremsstrahlung > -9.06 -> Ag ka > -7.06 (0.0336) | Kept: Ag ka > -7.06 -> Bremsstrahlung > -9.06 (0.4292)
# Removed: Ag Lb <= 8.04 -> Bremsstrahlung > -9.06 (0.0856) | Kept: Bremsstrahlung > -9.06 -> Ag Lb <= 8.04 (0.1280)
# Removed: Bremsstrahlung > -1.54 -> Ag Lb <= 8.04 (0.0630) | Kept: Ag Lb <= 8.04 -> Bremsstrahlung > -1.54 (0.3421)
# Removed: Bremsstrahlung > 4.15 -> Ag Lb <= 8.04 (0.0895) | Kept: Ag Lb <= 8.04 -> Bremsstrahlung > 4.15 (0.1678)
# Removed: Bremsstrahlung > 4.15 -> Ag La > -18.52 (0.1416) | Kept: Ag La > -18.52 -> Bremsstrahlung > 4.15 (0.1527)
# Removed: Ag compton <= 2.96 -> Ag Lb > -15.87 (0.0240) | Kept: Ag Lb > -15.87 -> Ag compton <= 2.96 (0.3658)
# Removed: Ag compton > -1.09 -> Ag compton <= 6.52 (0.0226) | Kept: Ag compton <= 6.52 -> Ag compton > -1.09 (0.2053)
# Removed: Ag Lb > 6.48 -> Ag compton > -6.71 (0.0323) | Kept: Ag compton > -6.71 -> Ag Lb > 6.48 (0.1849)
# Removed: Zn > -0.39 -> Zn > -1.47 (0.0135) | Kept: Zn > -1.47 -> Zn > -0.39 (0.0225)
# Removed: Zn <= -0.39 -> Zn > -0.39 (0.0087) | Kept: Zn > -0.39 -> Zn <= -0.39 (0.0178)
# Removed: Zn <= -0.39 -> Zn > -1.47 (0.0045) | Kept: Zn > -1.47 -> Zn <= -0.39 (0.0223)
# Removed: Zn <= 1.56 -> Zn <= 0.56 (0.0041) | Kept: Zn <= 0.56 -> Zn <= 1.56 (0.0330)
# Removed: Fe > 0.31 -> Zn <= 1.56 (0.0032) | Kept: Zn <= 1.56 -> Fe > 0.31 (0.0326)
# Removed: Fe <= 1.20 -> Fe <= 0.31 (0.0068) | Kept: Fe <= 0.31 -> Fe <= 1.20 (0.0090)
# Removed: Fe <= -0.36 -> Fe <= 1.20 (0.0068) | Kept: Fe <= 1.20 -> Fe <= -0.36 (0.0089)
# Removed: background <= 0.40 -> background > -1.23 (0.0014) | Kept: background > -1.23 -> background <= 0.40 (0.0019)
# Removed: background <= 0.40 -> background > -0.46 (0.0005) | Kept: background > -0.46 -> background <= 0.40 (0.0009)
# Removed: background > 0.40 -> background > -0.46 (0.0005) | Kept: background > -0.46 -> background > 0.40 (0.0009)
# Removed: background > -0.46 -> background <= 1.29 (0.0005) | Kept: background <= 1.29 -> background > -0.46 (0.0023)
# Removed: background <= -0.46 -> background > -0.46 (0.0004) | Kept: background > -0.46 -> background <= -0.46 (0.0005)
# Removed: background <= 1.29 -> background <= -0.46 (0.0004) | Kept: background <= -0.46 -> background <= 1.29 (0.0023)
# Removed: background <= 1.29 -> Cu > 0.32 (0.0005) | Kept: Cu > 0.32 -> background <= 1.29 (0.0012)
# Removed: background > 0.40 -> Cu > 0.32 (0.0009) | Kept: Cu > 0.32 -> background > 0.40 (0.0012)
# Removed: background > 0.40 -> background <= -0.46 (0.0004) | Kept: background <= -0.46 -> background > 0.40 (0.0005)
# Removed: background > 0.40 -> Ca <= -0.68 (0.0009) | Kept: Ca <= -0.68 -> background > 0.40 (0.0027)
# Removed: Cu > 0.32 -> Ca > -0.68 (0.0024) | Kept: Ca > -0.68 -> Cu > 0.32 (0.0054)
# Removed: Cu > -0.64 -> Cu > 0.32 (0.0011) | Kept: Cu > 0.32 -> Cu > -0.64 (0.0012)
# Removed: background <= -0.46 -> Cu > -0.64 (0.0004) | Kept: Cu > -0.64 -> background <= -0.46 (0.0012)
# Removed: Ca > -0.68 -> Ca <= -0.68 (0.0027) | Kept: Ca <= -0.68 -> Ca > -0.68 (0.0027)
# Removed: Cu <= -0.64 -> Ca <= -0.68 (0.0011) | Kept: Ca <= -0.68 -> Cu <= -0.64 (0.0053)
# Removed: Cu > -1.74 -> Ca <= -0.68 (0.0012) | Kept: Ca <= -0.68 -> Cu > -1.74 (0.0027)
# Removed: Cu <= 1.92 -> Ca <= -0.68 (0.0011) | Kept: Ca <= -0.68 -> Cu <= 1.92 (0.0026)
# Removed: Cu <= 1.92 -> Ca > -0.68 (0.0011) | Kept: Ca > -0.68 -> Cu <= 1.92 (0.0027)
# Removed: Cu <= -0.64 -> Ca > -0.68 (0.0011) | Kept: Ca > -0.68 -> Cu <= -0.64 (0.0052)
# Removed: Cu <= 1.92 -> Cu > -0.64 (0.0022) | Kept: Cu > -0.64 -> Cu <= 1.92 (0.0023)
# Removed: Cu <= 0.32 -> Cu > -0.64 (0.0011) | Kept: Cu > -0.64 -> Cu <= 0.32 (0.0023)
# Removed: Cu <= 0.32 -> Cu <= 1.92 (0.0011) | Kept: Cu <= 1.92 -> Cu <= 0.32 (0.0023)
# Removed: Cu <= -0.64 -> Cu <= 1.92 (0.0011) | Kept: Cu <= 1.92 -> Cu <= -0.64 (0.0012)
# Removed: Cu > -1.74 -> Cu <= 0.32 (0.0022) | Kept: Cu <= 0.32 -> Cu > -1.74 (0.0033)
# Removed: Cu > -1.74 -> Cu <= -0.64 (0.0011) | Kept: Cu <= -0.64 -> Cu > -1.74 (0.0012)
# Removed: Cu <= 0.32 -> Cu <= -0.64 (0.0033) | Kept: Cu <= -0.64 -> Cu <= 0.32 (0.0033)
# Removed: Cu <= -0.64 -> Ca > -1.79 (0.0021) | Kept: Ca > -1.79 -> Cu <= -0.64 (0.0027)
# Removed: Ca <= 1.81 -> Ca <= 0.46 (0.0023) | Kept: Ca <= 0.46 -> Ca <= 1.81 (0.0205)
#
# ======================================================================
# CONSTRUCTED GRAPH SUMMARY
# ======================================================================
# Initial edges: 215 | Removed: 56
# Predicate nodes: 60
# Metric: Perturbation
# Weighting by explained variance: ENABLED
#
# Processing graph LRC...
#
# Processing graph LRC...
#
# Processing graph LRC...
#
# Processing graph LRC...
#    Predicate_pert_Seed_0 Predicate_pert_Seed_1 Predicate_pert_Seed_2  \
# 0          Ag La <= 2.70         Ag La <= 2.70         Ag La <= 2.70
# 1          Ag La <= 7.76         Ag La <= 7.76         Ag La <= 7.76
# 2          Ag Lb <= 2.36         Ag Lb <= 2.36         Ag Lb <= 2.36
# 3          Ag La <= 9.01         Ag La <= 9.01         Ag La <= 9.01
# 4         Ag ka > -11.59        Ag ka > -11.59        Ag ka <= -7.06
# ..                   ...                   ...                   ...
# 57            Ca <= 0.46     background > 0.40    background <= 1.29
# 58    background > -1.23            Ca <= 0.46            Ca <= 0.46
# 59            Ca <= 1.81            Ca <= 1.81            Ca <= 1.81
# 60               Class_A               Class_A               Class_A
# 61               Class_B               Class_B               Class_B
#
#    Predicate_pert_Seed_3
# 0          Ag La <= 2.70
# 1          Ag La <= 7.76
# 2          Ag Lb <= 2.36
# 3          Ag La <= 9.01
# 4         Ag ka <= -7.06
# ..                   ...
# 57    background > -1.23
# 58            Ca <= 0.46
# 59            Ca <= 1.81
# 60               Class_A
# 61               Class_B
#
# [62 rows x 4 columns]

# %%
all_results_pert[0]['pert_results_dict']['Bag_1']
# Out:
#                   Predicate  Perturbation
# 0             Ag La <= 2.70      0.270392
# 1             Ag La <= 7.76      0.181371
# 2             Ag Lb <= 2.36      0.163421
# 3             Ag La <= 9.01      0.152026
# 4            Ag ka <= -7.06      0.149678
# 5   Bremsstrahlung <= -1.54      0.128461
# 6            Ag ka <= 20.95      0.126122
# 7             Ag ka <= 5.37      0.125895
# 8              Ag ka > 5.37      0.122808
# 9    Bremsstrahlung <= 4.15      0.122365
# 10   Bremsstrahlung <= 9.64      0.117885
# 11            Ag Lb <= 6.48      0.112102
# 12           Ag ka > -11.59      0.110362
# 13            Ag ka > -7.06      0.108118
# 14   Bremsstrahlung > -9.06      0.106075
# 15   Bremsstrahlung > -1.54      0.099710
# 16    Bremsstrahlung > 4.15      0.094399
# 17            Ag Lb <= 8.04      0.093077
# 18           Ag La > -18.52      0.087337
# 19             Ag La > 7.76      0.079630
# 20             Ag La > 2.70      0.062898
# 21      Ag compton <= -1.09      0.059071
# 22        Ag compton > 2.96      0.056801
# 23           Ag Lb > -15.87      0.045745
# 24       Ag compton <= 2.96      0.044200
# 25       Ag compton <= 6.52      0.043524
# 26       Ag compton > -1.09      0.043147
# 27       Ag compton > -6.71      0.040379
# 28             Ag Lb > 6.48      0.037914
# 29             Ag Lb > 2.36      0.032449
# 30                Zn > 0.56      0.026932
# 31               Zn > -1.47      0.025574
# 32              Zn <= -0.39      0.025040
# 33               Zn > -0.39      0.024839
# 34               Zn <= 0.56      0.023613
# 35               Zn <= 1.56      0.023495
# 36                Fe > 0.31      0.021710
# 37               Fe > -0.36      0.021346
# 38               Fe > -1.18      0.019822
# 39               Fe <= 0.31      0.017743
# 40               Fe <= 1.20      0.017541
# 41              Fe <= -0.36      0.016333
# 42       background > -1.23      0.014087
# 43                Ca > 0.46      0.013989
# 44        background > 0.40      0.013721
# 45       background > -0.46      0.013587
# 46      background <= -0.46      0.013469
# 47       background <= 0.40      0.013417
# 48       background <= 1.29      0.013314
# 49                Cu > 0.32      0.012359
# 50              Cu <= -0.64      0.012350
# 51               Cu <= 1.92      0.012180
# 52               Cu > -0.64      0.012151
# 53               Cu <= 0.32      0.012139
# 54               Cu > -1.74      0.012041
# 55               Ca > -0.68      0.011596
# 56              Ca <= -0.68      0.011549
# 57               Ca > -1.79      0.010478
# 58               Ca <= 0.46      0.009957
# 59               Ca <= 1.81      0.009892

# %%
# Somar LRCs de predicados equivalentes entre diferentes seeds
lrc_combined_list = []

for seed in random_seeds:
    lrc_df = lrc_pert_by_seed[seed].copy()
    lrc_combined_list.append(lrc_df) # o append adiciona o dataframe ao final da lista

# Concatenar todos os dataframes
lrc_all_seeds = pd.concat(lrc_combined_list, ignore_index=True) 

# Agrupar por predicado (Node) e somar as LRCs, mantendo Zone, Threshold e Operator
lrc_summed_df_pert = lrc_all_seeds.groupby('Node').agg({ # o .agg pode ser usado para aplicar múltiplas funções de agregação
    'Local_Reaching_Centrality': 'mean', # sum = somando as LRCs, poderia ser média ou outro agregado
    'Zone': 'first',
    'Threshold': 'first',
    'Operator': 'first'
}).reset_index()

# Ordenar pelo valor de LRC somado (maior para menor)
lrc_summed_df_pert = lrc_summed_df_pert.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
# vamoss pegar so os valore sunicos de lrc_summed_df baseado na zona espectral
lrc_summed_unique_df_pert = lrc_summed_df_pert.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
lrc_summed_unique_df_pert = lrc_summed_unique_df_pert.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
lrc_summed_unique_df_pert
# Out:
#                       Node  Local_Reaching_Centrality            Zone  \
# 0            Ag La <= 2.70                   5.762044           Ag La
# 1            Ag Lb <= 2.36                   3.706879           Ag Lb
# 2           Ag ka <= -7.06                   2.027356           Ag ka
# 3   Bremsstrahlung <= 9.64                   1.556894  Bremsstrahlung
# 4      Ag compton <= -1.09                   0.865729      Ag compton
# 5                Zn > 0.56                   0.095506              Zn
# 6                Fe > 0.31                   0.056914              Fe
# 7                Ca > 0.46                   0.015623              Ca
# 8               Cu <= 0.32                   0.011015              Cu
# 9        background > 0.40                   0.007564      background
# 10                 Class_B                   0.000000            None
#
#    Threshold Operator
# 0       2.70       <=
# 1       2.36       <=
# 2      -7.06       <=
# 3       9.64       <=
# 4      -1.09       <=
# 5       0.56        >
# 6       0.31        >
# 7       0.46        >
# 8       0.32       <=
# 9       0.40        >
# 10      None     None

# %%
# Aplicar o mapeamento
lrc_summed_df_pert_natural = exp.map_thresholds_to_natural(
    lrc_df=lrc_summed_df_pert,
    zone_sums_preprocessed=zone_scores_df,
    zone_sums_natural=zones_original[0]
)

lrc_summed_df_pert_natural
# Out:
#                   Node  Local_Reaching_Centrality        Zone Threshold  \
# 0        Ag La <= 2.70                   5.762044       Ag La      2.70
# 1        Ag La <= 7.76                   4.528915       Ag La      7.76
# 2        Ag Lb <= 2.36                   3.706879       Ag Lb      2.36
# 3        Ag La <= 9.01                   2.963346       Ag La      9.01
# 4       Ag ka <= -7.06                   2.027356       Ag ka     -7.06
# ..                 ...                        ...         ...       ...
# 57  background > -1.23                   0.006802  background     -1.23
# 58          Ca <= 0.46                   0.005171          Ca      0.46
# 59          Ca <= 1.81                   0.002553          Ca      1.81
# 60             Class_B                   0.000000        None      None
# 61             Class_A                   0.000000        None      None
#
#    Operator  Threshold_Natural  Reference_Sample_Index  Approximation_Error  \
# 0        <=          34.935039                    86.0             0.021418
# 1        <=         105.814886                    78.0             0.002963
# 2        <=          30.578162                     0.0             0.008013
# 3        <=         126.903607                   239.0             0.004801
# 4        <=        -250.573937                    70.0             0.012824
# ..      ...                ...                     ...                  ...
# 57        >           1.242244                    67.0             0.007894
# 58       <=           3.531024                    28.0             0.010826
# 59       <=          -2.575534                   222.0             0.044016
# 60     None                NaN                     NaN                  NaN
# 61     None                NaN                     NaN                  NaN
#
#              Node_Natural
# 0      Ag La <= 34.935039
# 1     Ag La <= 105.814886
# 2      Ag Lb <= 30.578162
# 3     Ag La <= 126.903607
# 4    Ag ka <= -250.573937
# ..                    ...
# 57  background > 1.242244
# 58         Ca <= 3.531024
# 59        Ca <= -2.575534
# 60                   None
# 61                   None
#
# [62 rows x 9 columns]

# %%
import plotly.graph_objects as go

n = 0
zone_name = lrc_summed_df_pert_natural.iloc[n]['Zone'] # o n indica a linha do dataframe lrc_summed_df_pert_natural que queremos acessar para pegar o nome da zona espectral (coluna 'Zone')
threshold_score = float(lrc_summed_df_pert_natural.iloc[n]['Threshold_Natural']) # o iloc acessa a linha n e a coluna 'Threshold_Natural' para pegar o valor do threshold já mapeado para o espaço natural (não pré-processado)

# Usar pca_info_dict dos dados ORIGINAIS (zones_original[1])
pca_info_dict_original = zones_original[1]

# Reconstrução: τ = mean + threshold * loadings (no espaço original)
threshold_spectrum = exp.reconstruct_threshold_to_spectrum(
    threshold_value=threshold_score,
    zone_name=zone_name,
    pca_info_dict=pca_info_dict_original
)
print(f"\nEspectro de threshold reconstruído para zona '{zone_name}':")
print(f"  - Dimensão: {len(threshold_spectrum)} variáveis espectrais")
#print(f"  - Range de energias: {threshold_spectrum.index[n]} - {threshold_spectrum.index[-1]}")
print(f"  - Variância explicada pela PC1: {pca_info_dict_original[zone_name]['variance_explained']:.2%}")

# Usar dados ORIGINAIS para plotar (spectral_zones_original)
zone_df = spectral_zones_original[zone_name]

# Plotar zona com threshold (inline)
fig = go.Figure()
x_values = pd.to_numeric(zone_df.columns, errors='coerce')

# Plotar espectros das amostras coloridas por classe
colors = {'A': 'gold', 'B': 'blue'}
for idx, row in zone_df.iterrows():
    class_label = ycalclass.iloc[idx] if idx < len(ycalclass) else 'Unknown'
    fig.add_trace(go.Scatter(
        x=x_values,
        y=row.values,
        mode='lines',
        line=dict(color=colors.get(class_label, 'rgba(128,128,128,0.3)'), width=0.5),
        name=f'Class {class_label}',
        showlegend=False,
        hoverinfo='skip'
    ))

# Plotar espectro de threshold (destaque)
fig.add_trace(go.Scatter(
    x=x_values,
    y=threshold_spectrum.values,
    mode='lines',
    line=dict(color='red', width=4, dash='dash'),
    name=f'Threshold Spectrum ({threshold_spectrum.name})'
))

# Layout do gráfico
fig.update_layout(
    title=f"Zona '{zone_name}' com Threshold Multivariado (Predicado: {lrc_summed_df_pert_natural.iloc[n]['Node_Natural']})",
    xaxis_title='Energia / Comprimento de Onda',
    yaxis_title='Intensidade',
    template='plotly_white',
    showlegend=True,
    legend=dict(yanchor="top", y=0.99, xanchor="left", x=0.01)
)

fig.show()
# Out:
# Espectro de threshold reconstruído para zona 'Ag La':
#   - Dimensão: 18 variáveis espectrais
#   - Variância explicada pela PC1: 91.39%

# %%
# Permutation importance baseado em mudança nas predições do modelo PLS
# Medimos a média da diferença absoluta entre as predições originais e as predições
# obtidas após permutar cada variável. Isso fornece uma métrica contínua de importância.
n_repeats = 10
rng = np.random.RandomState(42)
# Predições base do modelo PLS
baseline_pred = pls_model.predict(Xcalclass_prep)
importance_list = []
X_arr = Xcalclass_prep.copy()
for col in Xcalclass_prep.columns:
    diffs = []
    for _ in range(n_repeats):
        X_perm = X_arr.copy()
        X_perm[col] = rng.permutation(X_perm[col].values)
        perm_pred = pls_model.predict(X_perm)
        diffs.append(np.mean(np.abs(baseline_pred - perm_pred)))
    importance_list.append(np.mean(diffs))

permutation_df = pd.DataFrame({
    'energy': Xcalclass_prep.columns,
    'Permutation_importance': importance_list
})
permutation_df.sort_values(by='Permutation_importance', ascending=False, inplace=True)
energy_to_zone_vip = {}
for zone_name, start, end in spectral_cuts:
    for e in permutation_df['energy']:
        ef = float(e)
        if start <= ef <= end:
            energy_to_zone_vip[e] = zone_name
permutation_df['Zone'] = permutation_df['energy'].map(energy_to_zone_vip)
permutation_unique_df = permutation_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
permutation_unique_df = permutation_unique_df.sort_values(by='Permutation_importance', ascending=False)
permutation_unique_df
# Out:
#   energy  Permutation_importance            Zone
# 0  22.23                0.058491           Ag ka
# 1   2.99                0.055478           Ag La
# 2   3.22                0.026814           Ag Lb
# 3   8.75                0.013365              Zn
# 4   6.35                0.011798              Fe
# 5  21.41                0.009460      Ag compton
# 6  18.27                0.008225  Bremsstrahlung
# 7   3.74                0.006772              Ca
# 8   7.80                0.006045              Cu
# 9   4.84                0.005265      background

# %%
import numpy as np

max_len = max(
    len(vip_scores_unique_df['Zone']),
    len(reg_vet_unique_df['Zone']),
    len(shap_unique_df['Zone']),
    len(permutation_unique_df['Zone']),
    len(lrc_summed_unique_df_pert['Zone']),
    len(lrc_summed_unique_df_cov['Zone'])
)

def pad_list(lst, length):
    return list(lst) + [None] * (length - len(lst))

features_importance = pd.DataFrame({
    'VIP_Score': pad_list(vip_scores_unique_df['Zone'], max_len),
    'Reg_Coefficient' : pad_list(reg_vet_unique_df['Zone'], max_len),
    'Shap': pad_list(shap_unique_df['Zone'], max_len),
    'Permutation' : pad_list(permutation_unique_df['Zone'], max_len),
    'LRC_perturbation' : pad_list(lrc_summed_unique_df_pert['Zone'], max_len),
    'LRC_covariance' : pad_list(lrc_summed_unique_df_cov['Zone'], max_len),
})

features_importance.to_csv('feature_importance.csv', index=False, sep=';')
features_importance
# Out:
#          VIP_Score Reg_Coefficient            Shap     Permutation  \
# 0            Ag La           Ag ka           Ag La           Ag ka
# 1            Ag Lb              Zn           Ag ka           Ag La
# 2            Ag ka           Ag La           Ag Lb           Ag Lb
# 3               Zn              Fe              Fe              Zn
# 4       Ag compton           Ag Lb              Zn              Fe
# 5               Fe  Bremsstrahlung      Ag compton      Ag compton
# 6   Bremsstrahlung      Ag compton  Bremsstrahlung  Bremsstrahlung
# 7               Ca              Ca              Ca              Ca
# 8       background      background              Cu              Cu
# 9               Cu              Cu      background      background
# 10            None            None            None            None
#
#    LRC_perturbation  LRC_covariance
# 0             Ag La           Ag La
# 1             Ag Lb           Ag Lb
# 2             Ag ka           Ag ka
# 3    Bremsstrahlung  Bremsstrahlung
# 4        Ag compton      Ag compton
# 5                Zn              Fe
# 6                Fe              Ca
# 7                Ca              Cu
# 8                Cu              Zn
# 9        background      background
# 10             None            None

# %%
import rbo
rbo_comparison = pd.DataFrame(columns=['Method_1', 'Method_2', 'RBO_Score'])
methods = features_importance.columns.tolist()
for i in range(len(methods)):
    for j in range(i + 1, len(methods)):
        method_1 = methods[i]
        method_2 = methods[j]
        # Remove None values from the lists
        list_1 = [x for x in features_importance[method_1].tolist() if x is not None]
        list_2 = [x for x in features_importance[method_2].tolist() if x is not None]
        # Truncate both lists to the same length (minimum of both)
        min_len = min(len(list_1), len(list_2))
        list_1_trunc = list_1[:min_len]
        list_2_trunc = list_2[:min_len]
        rbo_score = rbo.RankingSimilarity(list_1_trunc, list_2_trunc).rbo(p=0.7, k=10)
        rbo_comparison = pd.concat([rbo_comparison, pd.DataFrame({
            'Method_1': [method_1],
            'Method_2': [method_2],
            'RBO_Score': [rbo_score]
        })], ignore_index=True)
rbo_comparison.sort_values(by='RBO_Score', ascending=False, inplace=True)
rbo_comparison.to_csv('rbo_rank.csv', index=False, sep=';')
rbo_comparison
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_23376\3097109587.py:16: FutureWarning:
#
# The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#             Method_1          Method_2  RBO_Score
# 14  LRC_perturbation    LRC_covariance   0.955219
# 3          VIP_Score  LRC_perturbation   0.921296
# 4          VIP_Score    LRC_covariance   0.913166
# 1          VIP_Score              Shap   0.824700
# 10              Shap  LRC_perturbation   0.803812
# 11              Shap    LRC_covariance   0.795682
# 6    Reg_Coefficient       Permutation   0.781702
# 9               Shap       Permutation   0.646027
# 2          VIP_Score       Permutation   0.550425
# 12       Permutation  LRC_perturbation   0.503812
# 13       Permutation    LRC_covariance   0.495682
# 5    Reg_Coefficient              Shap   0.481702
# 0          VIP_Score   Reg_Coefficient   0.364218
# 7    Reg_Coefficient  LRC_perturbation   0.322165
# 8    Reg_Coefficient    LRC_covariance   0.314035

# %%
lrc_summed_df_cov_natural.to_csv('lrc_cov_natural.csv', index=False, sep=';')
lrc_summed_df_pert_natural.to_csv('lrc_pert_natural.csv', index=False, sep=';')
